# %%
library(lindia)
library(tidyverse)
library(caret)
library(sjPlot) #plot estiamte
library(webshot)
#library(leaps)
#library(MASS)
#library(lme4) #random effect
library(lmerTest) #like lmer but with p-value
library(effects)#calculate and display model estimates
library(ggplot2)
library(pbkrtest) #backward test for glmer
library(DHARMa) #simulaed residual for glmer
library(Cairo)
library(cowplot) #several plot together
library(interactions ) #visualise continuous interactions effect
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.0.6     v dplyr   1.0.3
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Loading required package: lattice
#
#
# Attaching package: 'caret'
#
#
# The following object is masked from 'package:purrr':
#
#     lift
#
#
# Warning message:
# "package 'sjPlot' was built under R version 4.0.4"
# Warning message:
# "package 'webshot' was built under R version 4.0.5"
# Loading required package: lme4
#
# Loading required package: Matrix
#
#
# Attaching package: 'Matrix'
#
#
# The following objects are masked from 'package:tidyr':
#
#     expand, pack, unpack
#
#
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Warning message:
# "package 'effects' was built under R version 4.0.5"
# Loading required package: carData
#
# Use the command
#     lattice::trellis.par.set(effectsTheme())
#   to customize lattice options for effects plots.
# See ?effectsTheme for details.
#
# This is DHARMa 0.3.3.0. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa') Note: Syntax of plotResiduals has changed in 0.3.0, see ?plotResiduals for details
#
# Warning message:
# "package 'Cairo' was built under R version 4.0.5"
# Warning message:
# "package 'cowplot' was built under R version 4.0.5"
#
# Attaching package: 'cowplot'
#
#
# The following objects are masked from 'package:sjPlot':
#
#     plot_grid, save_plot

# %%
#install.packages("webshot")
library(DHARMa)
library(lindia)
library(modEvA)
library(dplyr)
library(lme4) #random effect
library(broom)
library(ggpubr) 
library(rstatix)
library(WRS2) #robust ancova
library(emmeans)

# %% [raw]
# "Model assumptions (normality of errors and homoscedasticity) were checked through graphical analysis of residuals.
# For GLMER models, residuals were simulated using package‘DHARMa’(Hartig, 2018).
# The final models were obtained by a stepwise backwards reduction of the full model using parametric bootstrap tests with package ‘pbkrtest’(Halekohand Højsgaard, 2014) for model comparison and a p-value of > 0.05 as the criterion for exclusion.
# The package‘effects’(Fox,2003) was used to calculate and display model estimates."
# pb-modcomp: Model comparison using parametric bootstrap methods.
# "Final model selection for non-random effects followed a  backwards  stepwise  procedure  where  the  most  non-significant  term  in  the  model  was  removed  at  each  step,  three-way  then  two-way  interactions  were  removed  first  followed  by  non-interacting  terms,  until  obtaining  a  final  model  where  terms  that  explained  a  significant  amount  of   variation  were  retained."

# %%
#df_ = df[ which(df$PenID %in% c('pen3','pen4','pen5','pen10','pen11','pen12')), ]

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/Productivity'
df = read.csv(file.path(path_,'mvt_egg.csv'), header = TRUE, sep = ";")
df$DIB = as.factor(df$DIB) 
df$PenID = as.factor(df$PenID) 
print(dim(df))
summary(df)
# Out:
# [1] 224  27
#     Datum             Vers..Tag       Ab.gÃ.nge        Kanni.balis.
#  Length:224         Min.   : 1.00   Min.   :0.00000   Min.   :0
#  Class :character   1st Qu.: 7.00   1st Qu.:0.00000   1st Qu.:0
#  Mode  :character   Median :12.50   Median :0.00000   Median :0
#                     Mean   :13.93   Mean   :0.08036   Mean   :0
#                     3rd Qu.:21.25   3rd Qu.:0.00000   3rd Qu.:0
#                     Max.   :28.00   Max.   :2.00000   Max.   :0
#
#  spez..VerÃ.nderung Anfangs.Bestand  Tier.bestand      ver.legt
#  Mode:logical       Min.   :223.0   Min.   :219.0   Min.   : 1.000
#  NA's:224           1st Qu.:223.0   1st Qu.:222.0   1st Qu.: 2.000
#                     Median :223.0   Median :223.0   Median : 3.000
#                     Mean   :223.8   Mean   :223.2   Mean   : 3.925
#                     3rd Qu.:225.0   3rd Qu.:225.0   3rd Qu.: 5.000
#                     Max.   :225.0   Max.   :226.0   Max.   :13.000
#                                                     NA's   :77
#    Nest.eier          Total           Scha.len        X
#  Min.   :  1.00   Min.   :  0.00   Min.   :1.000   Mode:logical
#  1st Qu.: 11.50   1st Qu.:  2.00   1st Qu.:1.000   NA's:224
#  Median : 49.00   Median : 27.50   Median :1.000
#  Mean   : 63.56   Mean   : 53.70   Mean   :1.431
#  3rd Qu.:112.00   3rd Qu.: 97.25   3rd Qu.:2.000
#  Max.   :186.00   Max.   :190.00   Max.   :4.000
#  NA's   :45                        NA's   :173
#    X.1          LayingPhase            PenID     X.eggPerTier
#  Mode:logical   Length:224         3      :28   Min.   :0.000000
#  NA's:224       Class :character   4      :28   1st Qu.:0.007778
#                 Mode  :character   5      :28   Median :0.112108
#                                    8      :28   Mean   :0.228789
#                                    9      :28   3rd Qu.:0.420992
#                                    10     :28   Max.   :0.834081
#                                    (Other):56
#  X.eggOutsideBoxPerTier  Early_death           DOA             WOA
#  Min.   :0.000000       Min.   :0.00000   Min.   :119.0   Min.   :17.00
#  1st Qu.:0.000000       1st Qu.:0.00000   1st Qu.:125.8   1st Qu.:18.00
#  Median :0.008969       Median :0.00000   Median :134.5   Median :20.00
#  Mean   :0.011585       Mean   :0.08036   Mean   :133.9   Mean   :19.54
#  3rd Qu.:0.018120       3rd Qu.:0.00000   3rd Qu.:141.2   3rd Qu.:21.00
#  Max.   :0.058559       Max.   :2.00000   Max.   :148.0   Max.   :22.00
#
#   Treatment         Treatment_allpens     level
#  Length:224         Length:224         Length:224
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  Total_number_transition    nbr_obs       perc_nnmovt          DIB
#  Length:224              Min.   :17.00   Min.   : 0.000   1      :  8
#  Class :character        1st Qu.:19.75   1st Qu.: 0.000   2      :  8
#  Mode  :character        Median :21.00   Median : 9.091   3      :  8
#                          Mean   :20.52   Mean   :10.969   4      :  8
#                          3rd Qu.:22.00   3rd Qu.:19.048   5      :  8
#                          Max.   :23.00   Max.   :52.941   6      :  8
#                                                           (Other):176

# %% [markdown]
# # Linear mixed effect model

# %%
#For model PLOT in poster
#only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
fit = lmerTest::lmer(X.eggPerTier ~ perc_nnmovt +Treatment+ (1|PenID) +(1|DIB), data=df)
anova(fit)
effCoef(fit)

#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
#Assumptions
###### normally distributed residuals
#qqmath(fit, id=0.05)
qqnorm(resid(fit), main = "Residuals")
qqline(resid(fit))
###### normally of random effects
qqmath(ranef(fit,postVar = TRUE))
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(fit)

#plot estimates
plot_model(fit, vline.color = "red")
# Out:
#             Sum Sq       Mean Sq      NumDF DenDF      F value  Pr(>F)
# perc_nnmovt 0.0001156563 0.0001156563 1     192.085828 0.199882 0.6553198
# Treatment   0.0007043086 0.0007043086 1       6.231609 1.217216 0.3106809
#   (Intercept)   perc_nnmovt TreatmentTRAN
#  0.2244678425 -0.0001011066  0.0108606662
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: X.eggPerTier ~ perc_nnmovt + Treatment + (1 | PenID) + (1 | DIB)
#    Data: df
#
# REML criterion at convergence: -804.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1580 -0.5084 -0.0364  0.5169  3.5855
#
# Random effects:
#  Groups   Name        Variance  Std.Dev.
#  DIB      (Intercept) 0.0661231 0.25714
#  PenID    (Intercept) 0.0001692 0.01301
#  Residual             0.0005786 0.02405
# Number of obs: 224, groups:  DIB, 28; PenID, 8
#
# Fixed effects:
#                 Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)    2.245e-01  4.918e-02  2.818e+01   4.564 9.02e-05 ***
# perc_nnmovt   -1.011e-04  2.261e-04  1.921e+02  -0.447    0.655
# TreatmentTRAN  1.086e-02  9.844e-03  6.232e+00   1.103    0.311
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) prc_nn
# perc_nnmovt -0.065
# TretmntTRAN -0.107  0.143
# Warning message in ranef.merMod(fit, postVar = TRUE):
# "'postVar' is deprecated: please use 'condVar' instead"
# Plot with title "Residuals"
# $DIB
#
# $PenID
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# tab_model(fit, file=file.path(path_adapt,'LMERFeather.html'))
# #then take this html file and make .png file
# webshot(file.path(path_adapt,'LMERFeather.html'), file.path(path_adapt,'LMERFeather.png'), zoom=3, cliprect = c(0, 5, 600, 270))

# %%
interact_plot(fit, pred = perc_nnmovt, modx = DIB, plot.points = TRUE)
# Out:
# Warning message:
# "perc_nnmovt and DIB are not included in an interaction with one another in
# the model."
# Error: Only 7 or fewer colors are supported with the CUD Bright color class.
# Traceback:
#
# 1. interact_plot(fit, pred = perc_nnmovt, modx = DIB, plot.points = TRUE)
# 2. plot_mod_continuous(predictions = pm, pred = pred, modx = modx,
#  .     resp = resp, mod2 = mod2, data = d, plot.points = plot.points |
#  .         partial.residuals, interval = interval, linearity.check = linearity.check,
#  .     x.label = x.label, y.label = y.label, pred.labels = pred.labels,
#  .     modx.labels = modx.labels, mod2.labels = mod2.labels, main.title = main.title,
#  .     legend.main = legend.main, colors = colors, line.thickness = line.thickness,
#  .     vary.lty = vary.lty, jitter = jitter, modxvals2 = modxvals2,
#  .     mod2vals2 = mod2vals2, weights = weights, rug = rug, rug.sides = rug.sides,
#  .     point.size = point.size, point.shape = point.shape, facet.modx = facet.modx,
#  .     point.alpha = point.alpha)
# 3. suppressWarnings(get_colors(colors, length(modx.labels), gradient = gradient))
# 4. withCallingHandlers(expr, warning = function(w) if (inherits(w,
#  .     classes)) tryInvokeRestart("muffleWarning"))
# 5. get_colors(colors, length(modx.labels), gradient = gradient)
# 6. stop_wrap("Only ", length(cudb), " or fewer colors are supported with\n                  the CUD Bright color class.")
# 7. do.call(rlang::abort, abort_args)
# 8. (function (message = NULL, class = NULL, ..., trace = NULL, parent = NULL,
#  .     .subclass = deprecated())
#  . {
#  .     validate_signal_args(.subclass)
#  .     if (is_null(trace) && is_null(peek_option("rlang:::disable_trace_capture"))) {
#  .         with_options(`rlang:::disable_trace_capture` = TRUE,
#  .             {
#  .                 trace <- trace_back()
#  .                 if (is_null(parent)) {
#  .                   context <- trace_length(trace)
#  .                 }
#  .                 else {
#  .                   context <- trace_capture_depth(trace)
#  .                 }
#  .                 trace <- trace_trim_context(trace, context)
#  .             })
#  .     }
#  .     message <- validate_signal_message(message, class)
#  .     message <- collapse_cnd_message(message)
#  .     cnd <- error_cnd(class, ..., message = message, parent = parent,
#  .         trace = trace)
#  .     signal_abort(cnd)
#  . })(message = "\033Only 7 or fewer colors are supported with the CUD Bright color class.\033",
#  .     trace = structure(list(calls = list(IRkernel::main(), kernel$run(),
#  .         IRkernel:::handle_shell(), executor$execute(msg), base::tryCatch(evaluate(request$content$code,
#  .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#  .             interrupt = function(cond) {
#  .                 log_debug("Interrupt during execution")
#  .                 interrupted <<- TRUE
#  .             }, error = .self$handle_error), base:::tryCatchList(expr,
#  .             classes, parentenv, handlers), base:::tryCatchOne(tryCatchList(expr,
#  .             names[-nh], parentenv, handlers[-nh]), names[nh],
#  .             parentenv, handlers[[nh]]), base:::doTryCatch(return(expr),
#  .             name, parentenv, handler), base:::tryCatchList(expr,
#  .             names[-nh], parentenv, handlers[-nh]), base:::tryCatchOne(expr,
#  .             names, parentenv, handlers[[1L]]), base:::doTryCatch(return(expr),
#  .             name, parentenv, handler), evaluate::evaluate(request$content$code,
#  .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#  .         evaluate:::evaluate_call(expr, parsed$src[[i]], envir = envir,
#  .             enclos = enclos, debug = debug, last = i == length(out),
#  .             use_try = stop_on_error != 2L, keep_warning = keep_warning,
#  .             keep_message = keep_message, output_handler = output_handler,
#  .             include_timing = include_timing), evaluate:::timing_fn(handle(ev <- withCallingHandlers(withVisible(eval(expr,
#  .             envir, enclos)), warning = wHandler, error = eHandler,
#  .             message = mHandler))), evaluate:::handle(ev <- withCallingHandlers(withVisible(eval(expr,
#  .             envir, enclos)), warning = wHandler, error = eHandler,
#  .             message = mHandler)), base::try(f, silent = TRUE),
#  .         base::tryCatch(expr, error = function(e) {
#  .             call <- conditionCall(e)
#  .             if (!is.null(call)) {
#  .                 if (identical(call[[1L]], quote(doTryCatch)))
#  .                   call <- sys.call(-4L)
#  .                 dcall <- deparse(call)[1L]
#  .                 prefix <- paste("Error in", dcall, ": ")
#  .                 LONG <- 75L
#  .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#  .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#  .                   type = "w")
#  .                 if (is.na(w))
#  .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#  .                     type = "b")
#  .                 if (w > LONG)
#  .                   prefix <- paste0(prefix, "\n  ")
#  .             }
#  .             else prefix <- "Error : "
#  .             msg <- paste0(prefix, conditionMessage(e), "\n")
#  .             .Internal(seterrmessage(msg[1L]))
#  .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#  .                 cat(msg, file = outFile)
#  .                 .Internal(printDeferredWarnings())
#  .             }
#  .             invisible(structure(msg, class = "try-error", condition = e))
#  .         }), base:::tryCatchList(expr, classes, parentenv, handlers),
#  .         base:::tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#  .         base:::doTryCatch(return(expr), name, parentenv, handler),
#  .         base::withCallingHandlers(withVisible(eval(expr, envir,
#  .             enclos)), warning = wHandler, error = eHandler, message = mHandler),
#  .         base::withVisible(eval(expr, envir, enclos)), base::eval(expr,
#  .             envir, enclos), base::eval(expr, envir, enclos),
#  .         interactions::interact_plot(fit, pred = perc_nnmovt,
#  .             modx = DIB, plot.points = TRUE), interactions:::plot_mod_continuous(predictions = pm,
#  .             pred = pred, modx = modx, resp = resp, mod2 = mod2,
#  .             data = d, plot.points = plot.points | partial.residuals,
#  .             interval = interval, linearity.check = linearity.check,
#  .             x.label = x.label, y.label = y.label, pred.labels = pred.labels,
#  .             modx.labels = modx.labels, mod2.labels = mod2.labels,
#  .             main.title = main.title, legend.main = legend.main,
#  .             colors = colors, line.thickness = line.thickness,
#  .             vary.lty = vary.lty, jitter = jitter, modxvals2 = modxvals2,
#  .             mod2vals2 = mod2vals2, weights = weights, rug = rug,
#  .             rug.sides = rug.sides, point.size = point.size, point.shape = point.shape,
#  .             facet.modx = facet.modx, point.alpha = point.alpha),
#  .         base::suppressWarnings(get_colors(colors, length(modx.labels),
#  .             gradient = gradient)), base::withCallingHandlers(expr,
#  .             warning = function(w) if (inherits(w, classes)) tryInvokeRestart("muffleWarning")),
#  .         jtools::get_colors(colors, length(modx.labels), gradient = gradient)),
#  .         parents = c(0L, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L,
#  .         4L, 12L, 13L, 13L, 15L, 16L, 17L, 18L, 19L, 13L, 13L,
#  .         13L, 23L, 0L, 25L, 26L, 27L, 26L), indices = 1:29), class = "rlang_trace", version = 1L))
# 9. signal_abort(cnd)

# %%
interact_plot(fit, pred = DIB, modx = perc_nnmovt, plot.points = TRUE)

# %%
sjPlot::plot_model(fit, type = "pred", terms = c("perc_nnmovt")) + xlab("perc_nnmovt")+ylab('#egg per tier')+
      theme(plot.background = element_rect(fill = "transparent",colour = NA), 
            axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
           axis.text.y = element_text(color="black"))
#ggsave(file.path(path_adapt,'PRED_Feather_mean_perc_duration_3_Zone.png'), width = 4, height = 4, bg = "transparent")
# Out:
# plot without title

# %% [markdown]
# sjPlot::plot_model(fit, type = "pred", terms = c("nbr_days_4zonevisited"))+ xlab("Number of the first 3 days with 4 zone visited")+ylab('Feather coverage')+
#       theme(plot.background = element_rect(fill = "transparent",colour = NA),
#             axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
#            axis.text.y = element_text(color="black"))+ ylim(75, 100)
# ggsave(file.path(path_adapt,'PRED_Feather_nbr_days_4zonevisited.png'),width=4, height=4, bg = "transparent")

# %% [markdown]
# sjPlot::plot_model(fit, type = "pred", terms = c("mean_percentage_time_outside_while_WG_open"))+ xlab("Mean percentage of time spent in winter garden")+ylab('Feather coverage')+
#       theme(plot.background = element_rect(fill = "transparent",colour = NA),
#            axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
#            axis.text.y = element_text(color="black"))+ ylim(75, 100)
# ggsave(file.path(path_adapt,'PRED_Feather_WG.png'),width=4, height=4, bg = "transparent")

# %% [markdown]
# p1 = sjPlot::plot_model(fit, type = "pred", terms = c("mean_perc_duration_3_Zone"), title='')+xlab("Mean percentage of time spent in Lower perch")+ylab('Feather coverage')+ylab('Feather coverage') +
#       theme(plot.background = element_rect(fill = "transparent",colour = NA),
#             axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
#            axis.text.y = element_text(color="black"))+ ylim(75, 100)
#
# p2 = sjPlot::plot_model(fit, type = "pred", terms = c("nbr_days_4zonevisited"), title='')+ xlab("Number of the first 3 days with 4 zone visited")+ylab('Feather coverage')+
#       theme(plot.background = element_rect(fill = "transparent",colour = NA),
#             axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
#            axis.text.y = element_text(color="black"))+ ylim(75, 100)
#
# p3 = sjPlot::plot_model(fit, type = "pred", terms = c("mean_percentage_time_outside_while_WG_open"), title='')+ xlab("Mean percentage of time spent in winter garden")+ylab('Feather coverage')+
#       theme(plot.background = element_rect(fill = "transparent",colour = NA),
#            axis.text.x = element_text(color="black"), axis.ticks = element_line(color = "black"),
#            axis.text.y = element_text(color="black"))+ ylim(75, 100)
#
# p = plot_grid(p3,p2,p1, ncol=3, nrow=1)
# title = ggdraw() + draw_label("Predicted Value of Feather Coverage (higher values indicate more feathers present) from LMER", fontface='bold')
# plot_grid(title, p, ncol=1, rel_heights=c(0.1, 1)) # rel_heights values control title margins
#
# ggsave(file.path(path_adapt,'PRED_Feather_ALL.png'),width=12, height=4, bg = "transparent")

# %% [markdown]
# ggscatter(
#   df, x = "mean_perc_duration_3_Zone", y = "Feathers",
#   color = "PenID", add = "reg.line"
#   )+
#   stat_regline_equation(
#     aes(label =  paste(..eq.label.., ..rr.label.., sep = "~~~~"), color = PenID)
#     )
# ggsave(file.path(path_adapt,'Feather_mean_perc_duration_3_Zone.png'),width=5, height=5)

# %%
ggscatter(df, x = "mean_perc_duration_3_Zone", y = "Feathers",color = "PenID")+ xlab("Mean percentage of time spent in Lower perch")+ylab('Feather coverage')+ylab('Feather coverage')
ggsave(file.path(path_adapt,'Feather_mean_perc_duration_3_Zone.png'),width=5, height=5)
# Out:
# plot without title

# %%
ggscatter(df, x = "nbr_days_4zonevisited", y = "Feathers",color = "PenID")+ xlab("Number of the first 3 days with 4 zone visited")+ylab('Feather coverage')
ggsave(file.path(path_adapt,'Feather_nbr_days_4zonevisited.png'),width=5, height=5)
# Out:
# plot without title

# %%
ggscatter(df, x = "mean_percentage_time_outside_while_WG_open", y = "Feathers",color = "PenID")+ xlab("Mean percentage of time spent in winter garden")+ylab('Feather coverage')
ggsave(file.path(path_adapt,'Feather_WG.png'),width=5, height=5)
# Out:
# plot without title

# %% [markdown]
# ## KBF

# %%
hist(df$severity)
# Out:
# Plot with title "Histogram of df$severity"

# %%
#only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
fit_ = lmerTest::lmer(severity ~ nbr_obs_perc_duration_5_Zone +nbr_days_4zonevisited + nbr_days_nomvt + Treatment + mean_perc_duration_5_Zone + mean_perc_duration_3_Zone + mean_perc_duration_2_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID), 
           data=df)
# Backward elimination using terms with default alpha-levels:
step_res = step(fit_)
#show elimination results
step_res
# Out:
# Backward reduced random-effect table:
#
#             Eliminated npar  logLik    AIC   LRT Df Pr(>Chisq)
# <none>                   12 -389.98 803.95
# (1 | PenID)          1   11 -391.06 804.12 2.173  1     0.1405
#
# Backward reduced fixed-effect table:
#                                            Eliminated Df Sum of Sq   RSS    AIC
# mean_perc_duration_2_Zone                           1  1      0.05 18802 533.16
# mean_perc_duration_5_Zone                           2  1     25.09 18827 531.29
# nbr_days_4zonevisited                               3  1     84.59 18912 529.73
# mean_vertical_travel_distance_perh                  4  1    149.05 19061 528.50
# mean_percentage_time_outside_while_WG_open          5  1    160.49 19221 527.32
# mean_perc_duration_3_Zone                           6  1    216.79 19438 526.42
# nbr_days_nomvt                                      7  1    232.00 19670 525.58
# nbr_obs_perc_duration_5_Zone                        8  1    358.17 20028 525.35
# Treatment                                           9  1    404.34 20433 525.31
#                                            F value Pr(>F)
# mean_perc_duration_2_Zone                   0.0002 0.9881
# mean_perc_duration_5_Zone                   0.1188 0.7312
# nbr_days_4zonevisited                       0.4044 0.5265
# mean_vertical_travel_distance_perh          0.7172 0.3993
# mean_percentage_time_outside_while_WG_open  0.7746 0.3811
# mean_perc_duration_3_Zone                   1.0489 0.3084
# nbr_days_nomvt                              1.1219 0.2922
# nbr_obs_perc_duration_5_Zone                1.7299 0.1916
# Treatment                                   1.9381 0.1671
#
# Model found:
# severity ~ 1
