# %%
#basic package
import tqdm
import os
import numpy as np
import pandas as pd
import sys
import time
import datetime as dt
import itertools
import math
import random
import pickle
from scipy import stats
from scipy.stats import pearsonr, spearmanr
#plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PACKAGE_PARENT = '../'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))
import config_origins as config

path_extracted_data = config.path_extracted_data
id_run = config.id_run
print(id_run)
# Out:
# ALLDATA_

# %% [markdown]
# # Dowload meand and CI estimates

# %%
df_IC = pd.read_csv(os.path.join(path_extracted_data,'df_CI_BRMS_BS_pred_allvar_moreit.csv'), sep=',')
print(df_IC.shape) 
display(df_IC.head(3))

df_mean = pd.read_csv(os.path.join(path_extracted_data,'df_mean_BRMS_BS_pred_allvar_moreit.csv'), sep=',')
print(df_mean.shape) 
display(df_mean.head(3))

df = pd.merge(df_mean, df_IC, on=['Unnamed: 0'], how='outer')
df.rename(columns={'Unnamed: 0':'parameter','x':'value_mean'}, inplace=True)
print(df.shape) 
display(df.head(3))
# Out:
# (996, 3)
#                                    Unnamed: 0     lower     upper
# 0  b_foodrelatedbehaviorfinalinvcst_Intercept -0.230217 -0.121372
# 1                        b_scaleVTD_Intercept -0.165241  0.172547
# 2              b_midcumZ4secMorning_Intercept  1.462905  1.523883
# (996, 2)
#                                    Unnamed: 0         x
# 0  b_foodrelatedbehaviorfinalinvcst_Intercept -0.172938
# 1                        b_scaleVTD_Intercept -0.001629
# 2              b_midcumZ4secMorning_Intercept  1.492448
# (996, 4)
#                                     parameter  value_mean     lower     upper
# 0  b_foodrelatedbehaviorfinalinvcst_Intercept   -0.172938 -0.230217 -0.121372
# 1                        b_scaleVTD_Intercept   -0.001629 -0.165241  0.172547
# 2              b_midcumZ4secMorning_Intercept    1.492448  1.462905  1.523883

# %%
df['parameter'].unique()
# Out:
# array(['b_foodrelatedbehaviorfinalinvcst_Intercept',
#        'b_scaleVTD_Intercept', 'b_midcumZ4secMorning_Intercept',
#        'b_SleepingNotUppest_Intercept',
#        'b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'b_foodrelatedbehaviorfinalinvcst_TreatmentOFH',
#        'b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID5M8',
#        'b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID9M12',
#        'b_foodrelatedbehaviorfinalinvcst_scaleweightInterp',
#        'b_foodrelatedbehaviorfinalinvcst_scaleKBFInterp',
#        'b_foodrelatedbehaviorfinalinvcst_scaleDIB',
#        'b_scaleVTD_TreatmentOFH', 'b_scaleVTD_scaleweightInterp',
#        'b_scaleVTD_scaleKBFInterp', 'b_scaleVTD_scaleDIB',
#        'b_scaleVTD_scaleIDIBE2', 'b_midcumZ4secMorning_TreatmentOFH',
#        'b_midcumZ4secMorning_scaleweightInterp',
#        'b_midcumZ4secMorning_scaleKBFInterp',
#        'b_midcumZ4secMorning_scaleDIB',
#        'b_SleepingNotUppest_TreatmentOFH',
#        'b_SleepingNotUppest_scaleweight_interp',
#        'b_SleepingNotUppest_scaleKBF_interp',
#        'b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_TreatmentOFH',
#        'b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleDIB',
#        'b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleweight_interp',
#        'b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleKBF_interp',
#        'sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept',
#        'sd_HenID__scaleVTD_Intercept',
#        'sd_HenID__midcumZ4secMorning_Intercept',
#        'sd_HenID__SleepingNotUppest_Intercept',
#        'sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept',
#        'cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept',
#        'cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept',
#        'cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept',
#        'cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept',
#        'cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept',
#        'cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#        'shape_foodrelatedbehaviorfinalinvcst', 'shape_midcumZ4secMorning',
#        'sigma_scaleVTD',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_1,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_10,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_101,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_102,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_105,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_106,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_107,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_108,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_109,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_111,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_112,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_113,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_115,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_116,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_118,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_119,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_12,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_120,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_122,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_123,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_124,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_126,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_127,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_128,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_13,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_131,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_133,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_134,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_135,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_136,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_137,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_138,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_139,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_14,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_140,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_141,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_142,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_143,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_144,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_145,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_146,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_147,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_149,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_15,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_150,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_151,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_152,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_153,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_154,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_155,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_156,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_158,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_159,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_163,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_164,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_165,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_166,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_167,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_168,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_169,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_17,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_170,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_171,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_172,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_173,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_174,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_175,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_177,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_18,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_180,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_181,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_182,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_183,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_184,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_185,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_186,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_187,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_188,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_189,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_19,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_190,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_191,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_192,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_193,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_194,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_195,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_196,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_197,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_198,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_199,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_2,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_20,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_200,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_201,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_202,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_203,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_204,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_205,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_206,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_207,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_208,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_209,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_21,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_210,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_211,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_212,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_214,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_215,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_216,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_217,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_218,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_219,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_22,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_220,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_221,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_222,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_223,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_224,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_225,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_226,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_227,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_228,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_229,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_23,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_230,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_231,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_232,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_233,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_24,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_25,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_26,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_27,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_28,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_29,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_3,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_32,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_34,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_39,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_4,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_40,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_41,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_42,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_45,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_48,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_49,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_5,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_50,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_51,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_52,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_54,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_56,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_57,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_58,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_59,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_6,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_60,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_61,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_62,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_64,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_65,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_66,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_67,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_68,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_69,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_7,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_71,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_72,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_73,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_75,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_76,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_77,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_78,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_79,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_8,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_80,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_81,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_82,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_83,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_84,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_85,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_86,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_87,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_89,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_9,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_90,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_92,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_93,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_95,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_98,Intercept]',
#        'r_HenID__foodrelatedbehaviorfinalinvcst[hen_99,Intercept]',
#        'r_HenID__scaleVTD[hen_1,Intercept]',
#        'r_HenID__scaleVTD[hen_10,Intercept]',
#        'r_HenID__scaleVTD[hen_101,Intercept]',
#        'r_HenID__scaleVTD[hen_102,Intercept]',
#        'r_HenID__scaleVTD[hen_105,Intercept]',
#        'r_HenID__scaleVTD[hen_106,Intercept]',
#        'r_HenID__scaleVTD[hen_107,Intercept]',
#        'r_HenID__scaleVTD[hen_108,Intercept]',
#        'r_HenID__scaleVTD[hen_109,Intercept]',
#        'r_HenID__scaleVTD[hen_111,Intercept]',
#        'r_HenID__scaleVTD[hen_112,Intercept]',
#        'r_HenID__scaleVTD[hen_113,Intercept]',
#        'r_HenID__scaleVTD[hen_115,Intercept]',
#        'r_HenID__scaleVTD[hen_116,Intercept]',
#        'r_HenID__scaleVTD[hen_118,Intercept]',
#        'r_HenID__scaleVTD[hen_119,Intercept]',
#        'r_HenID__scaleVTD[hen_12,Intercept]',
#        'r_HenID__scaleVTD[hen_120,Intercept]',
#        'r_HenID__scaleVTD[hen_122,Intercept]',
#        'r_HenID__scaleVTD[hen_123,Intercept]',
#        'r_HenID__scaleVTD[hen_124,Intercept]',
#        'r_HenID__scaleVTD[hen_126,Intercept]',
#        'r_HenID__scaleVTD[hen_127,Intercept]',
#        'r_HenID__scaleVTD[hen_128,Intercept]',
#        'r_HenID__scaleVTD[hen_13,Intercept]',
#        'r_HenID__scaleVTD[hen_131,Intercept]',
#        'r_HenID__scaleVTD[hen_133,Intercept]',
#        'r_HenID__scaleVTD[hen_134,Intercept]',
#        'r_HenID__scaleVTD[hen_135,Intercept]',
#        'r_HenID__scaleVTD[hen_136,Intercept]',
#        'r_HenID__scaleVTD[hen_137,Intercept]',
#        'r_HenID__scaleVTD[hen_138,Intercept]',
#        'r_HenID__scaleVTD[hen_139,Intercept]',
#        'r_HenID__scaleVTD[hen_14,Intercept]',
#        'r_HenID__scaleVTD[hen_140,Intercept]',
#        'r_HenID__scaleVTD[hen_141,Intercept]',
#        'r_HenID__scaleVTD[hen_142,Intercept]',
#        'r_HenID__scaleVTD[hen_143,Intercept]',
#        'r_HenID__scaleVTD[hen_144,Intercept]',
#        'r_HenID__scaleVTD[hen_145,Intercept]',
#        'r_HenID__scaleVTD[hen_146,Intercept]',
#        'r_HenID__scaleVTD[hen_147,Intercept]',
#        'r_HenID__scaleVTD[hen_149,Intercept]',
#        'r_HenID__scaleVTD[hen_15,Intercept]',
#        'r_HenID__scaleVTD[hen_150,Intercept]',
#        'r_HenID__scaleVTD[hen_151,Intercept]',
#        'r_HenID__scaleVTD[hen_152,Intercept]',
#        'r_HenID__scaleVTD[hen_153,Intercept]',
#        'r_HenID__scaleVTD[hen_154,Intercept]',
#        'r_HenID__scaleVTD[hen_155,Intercept]',
#        'r_HenID__scaleVTD[hen_156,Intercept]',
#        'r_HenID__scaleVTD[hen_158,Intercept]',
#        'r_HenID__scaleVTD[hen_159,Intercept]',
#        'r_HenID__scaleVTD[hen_163,Intercept]',
#        'r_HenID__scaleVTD[hen_164,Intercept]',
#        'r_HenID__scaleVTD[hen_165,Intercept]',
#        'r_HenID__scaleVTD[hen_166,Intercept]',
#        'r_HenID__scaleVTD[hen_167,Intercept]',
#        'r_HenID__scaleVTD[hen_168,Intercept]',
#        'r_HenID__scaleVTD[hen_169,Intercept]',
#        'r_HenID__scaleVTD[hen_17,Intercept]',
#        'r_HenID__scaleVTD[hen_170,Intercept]',
#        'r_HenID__scaleVTD[hen_171,Intercept]',
#        'r_HenID__scaleVTD[hen_172,Intercept]',
#        'r_HenID__scaleVTD[hen_173,Intercept]',
#        'r_HenID__scaleVTD[hen_174,Intercept]',
#        'r_HenID__scaleVTD[hen_175,Intercept]',
#        'r_HenID__scaleVTD[hen_177,Intercept]',
#        'r_HenID__scaleVTD[hen_18,Intercept]',
#        'r_HenID__scaleVTD[hen_180,Intercept]',
#        'r_HenID__scaleVTD[hen_181,Intercept]',
#        'r_HenID__scaleVTD[hen_182,Intercept]',
#        'r_HenID__scaleVTD[hen_183,Intercept]',
#        'r_HenID__scaleVTD[hen_184,Intercept]',
#        'r_HenID__scaleVTD[hen_185,Intercept]',
#        'r_HenID__scaleVTD[hen_186,Intercept]',
#        'r_HenID__scaleVTD[hen_187,Intercept]',
#        'r_HenID__scaleVTD[hen_188,Intercept]',
#        'r_HenID__scaleVTD[hen_189,Intercept]',
#        'r_HenID__scaleVTD[hen_19,Intercept]',
#        'r_HenID__scaleVTD[hen_190,Intercept]',
#        'r_HenID__scaleVTD[hen_191,Intercept]',
#        'r_HenID__scaleVTD[hen_192,Intercept]',
#        'r_HenID__scaleVTD[hen_193,Intercept]',
#        'r_HenID__scaleVTD[hen_194,Intercept]',
#        'r_HenID__scaleVTD[hen_195,Intercept]',
#        'r_HenID__scaleVTD[hen_196,Intercept]',
#        'r_HenID__scaleVTD[hen_197,Intercept]',
#        'r_HenID__scaleVTD[hen_198,Intercept]',
#        'r_HenID__scaleVTD[hen_199,Intercept]',
#        'r_HenID__scaleVTD[hen_2,Intercept]',
#        'r_HenID__scaleVTD[hen_20,Intercept]',
#        'r_HenID__scaleVTD[hen_200,Intercept]',
#        'r_HenID__scaleVTD[hen_201,Intercept]',
#        'r_HenID__scaleVTD[hen_202,Intercept]',
#        'r_HenID__scaleVTD[hen_203,Intercept]',
#        'r_HenID__scaleVTD[hen_204,Intercept]',
#        'r_HenID__scaleVTD[hen_205,Intercept]',
#        'r_HenID__scaleVTD[hen_206,Intercept]',
#        'r_HenID__scaleVTD[hen_207,Intercept]',
#        'r_HenID__scaleVTD[hen_208,Intercept]',
#        'r_HenID__scaleVTD[hen_209,Intercept]',
#        'r_HenID__scaleVTD[hen_21,Intercept]',
#        'r_HenID__scaleVTD[hen_210,Intercept]',
#        'r_HenID__scaleVTD[hen_211,Intercept]',
#        'r_HenID__scaleVTD[hen_212,Intercept]',
#        'r_HenID__scaleVTD[hen_214,Intercept]',
#        'r_HenID__scaleVTD[hen_215,Intercept]',
#        'r_HenID__scaleVTD[hen_216,Intercept]',
#        'r_HenID__scaleVTD[hen_217,Intercept]',
#        'r_HenID__scaleVTD[hen_218,Intercept]',
#        'r_HenID__scaleVTD[hen_219,Intercept]',
#        'r_HenID__scaleVTD[hen_22,Intercept]',
#        'r_HenID__scaleVTD[hen_220,Intercept]',
#        'r_HenID__scaleVTD[hen_221,Intercept]',
#        'r_HenID__scaleVTD[hen_222,Intercept]',
#        'r_HenID__scaleVTD[hen_223,Intercept]',
#        'r_HenID__scaleVTD[hen_224,Intercept]',
#        'r_HenID__scaleVTD[hen_225,Intercept]',
#        'r_HenID__scaleVTD[hen_226,Intercept]',
#        'r_HenID__scaleVTD[hen_227,Intercept]',
#        'r_HenID__scaleVTD[hen_228,Intercept]',
#        'r_HenID__scaleVTD[hen_229,Intercept]',
#        'r_HenID__scaleVTD[hen_23,Intercept]',
#        'r_HenID__scaleVTD[hen_230,Intercept]',
#        'r_HenID__scaleVTD[hen_231,Intercept]',
#        'r_HenID__scaleVTD[hen_232,Intercept]',
#        'r_HenID__scaleVTD[hen_233,Intercept]',
#        'r_HenID__scaleVTD[hen_24,Intercept]',
#        'r_HenID__scaleVTD[hen_25,Intercept]',
#        'r_HenID__scaleVTD[hen_26,Intercept]',
#        'r_HenID__scaleVTD[hen_27,Intercept]',
#        'r_HenID__scaleVTD[hen_28,Intercept]',
#        'r_HenID__scaleVTD[hen_29,Intercept]',
#        'r_HenID__scaleVTD[hen_3,Intercept]',
#        'r_HenID__scaleVTD[hen_32,Intercept]',
#        'r_HenID__scaleVTD[hen_34,Intercept]',
#        'r_HenID__scaleVTD[hen_39,Intercept]',
#        'r_HenID__scaleVTD[hen_4,Intercept]',
#        'r_HenID__scaleVTD[hen_40,Intercept]',
#        'r_HenID__scaleVTD[hen_41,Intercept]',
#        'r_HenID__scaleVTD[hen_42,Intercept]',
#        'r_HenID__scaleVTD[hen_45,Intercept]',
#        'r_HenID__scaleVTD[hen_48,Intercept]',
#        'r_HenID__scaleVTD[hen_49,Intercept]',
#        'r_HenID__scaleVTD[hen_5,Intercept]',
#        'r_HenID__scaleVTD[hen_50,Intercept]',
#        'r_HenID__scaleVTD[hen_51,Intercept]',
#        'r_HenID__scaleVTD[hen_52,Intercept]',
#        'r_HenID__scaleVTD[hen_54,Intercept]',
#        'r_HenID__scaleVTD[hen_56,Intercept]',
#        'r_HenID__scaleVTD[hen_57,Intercept]',
#        'r_HenID__scaleVTD[hen_58,Intercept]',
#        'r_HenID__scaleVTD[hen_59,Intercept]',
#        'r_HenID__scaleVTD[hen_6,Intercept]',
#        'r_HenID__scaleVTD[hen_60,Intercept]',
#        'r_HenID__scaleVTD[hen_61,Intercept]',
#        'r_HenID__scaleVTD[hen_62,Intercept]',
#        'r_HenID__scaleVTD[hen_64,Intercept]',
#        'r_HenID__scaleVTD[hen_65,Intercept]',
#        'r_HenID__scaleVTD[hen_66,Intercept]',
#        'r_HenID__scaleVTD[hen_67,Intercept]',
#        'r_HenID__scaleVTD[hen_68,Intercept]',
#        'r_HenID__scaleVTD[hen_69,Intercept]',
#        'r_HenID__scaleVTD[hen_7,Intercept]',
#        'r_HenID__scaleVTD[hen_71,Intercept]',
#        'r_HenID__scaleVTD[hen_72,Intercept]',
#        'r_HenID__scaleVTD[hen_73,Intercept]',
#        'r_HenID__scaleVTD[hen_75,Intercept]',
#        'r_HenID__scaleVTD[hen_76,Intercept]',
#        'r_HenID__scaleVTD[hen_77,Intercept]',
#        'r_HenID__scaleVTD[hen_78,Intercept]',
#        'r_HenID__scaleVTD[hen_79,Intercept]',
#        'r_HenID__scaleVTD[hen_8,Intercept]',
#        'r_HenID__scaleVTD[hen_80,Intercept]',
#        'r_HenID__scaleVTD[hen_81,Intercept]',
#        'r_HenID__scaleVTD[hen_82,Intercept]',
#        'r_HenID__scaleVTD[hen_83,Intercept]',
#        'r_HenID__scaleVTD[hen_84,Intercept]',
#        'r_HenID__scaleVTD[hen_85,Intercept]',
#        'r_HenID__scaleVTD[hen_86,Intercept]',
#        'r_HenID__scaleVTD[hen_87,Intercept]',
#        'r_HenID__scaleVTD[hen_89,Intercept]',
#        'r_HenID__scaleVTD[hen_9,Intercept]',
#        'r_HenID__scaleVTD[hen_90,Intercept]',
#        'r_HenID__scaleVTD[hen_92,Intercept]',
#        'r_HenID__scaleVTD[hen_93,Intercept]',
#        'r_HenID__scaleVTD[hen_95,Intercept]',
#        'r_HenID__scaleVTD[hen_98,Intercept]',
#        'r_HenID__scaleVTD[hen_99,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_1,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_10,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_101,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_102,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_105,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_106,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_107,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_108,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_109,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_111,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_112,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_113,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_115,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_116,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_118,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_119,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_12,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_120,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_122,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_123,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_124,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_126,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_127,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_128,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_13,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_131,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_133,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_134,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_135,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_136,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_137,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_138,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_139,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_14,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_140,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_141,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_142,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_143,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_144,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_145,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_146,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_147,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_149,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_15,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_150,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_151,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_152,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_153,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_154,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_155,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_156,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_158,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_159,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_163,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_164,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_165,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_166,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_167,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_168,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_169,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_17,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_170,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_171,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_172,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_173,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_174,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_175,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_177,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_18,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_180,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_181,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_182,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_183,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_184,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_185,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_186,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_187,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_188,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_189,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_19,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_190,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_191,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_192,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_193,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_194,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_195,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_196,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_197,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_198,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_199,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_2,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_20,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_200,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_201,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_202,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_203,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_204,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_205,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_206,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_207,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_208,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_209,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_21,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_210,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_211,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_212,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_214,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_215,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_216,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_217,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_218,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_219,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_22,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_220,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_221,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_222,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_223,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_224,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_225,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_226,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_227,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_228,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_229,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_23,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_230,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_231,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_232,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_233,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_24,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_25,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_26,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_27,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_28,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_29,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_3,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_32,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_34,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_39,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_4,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_40,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_41,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_42,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_45,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_48,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_49,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_5,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_50,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_51,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_52,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_54,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_56,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_57,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_58,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_59,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_6,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_60,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_61,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_62,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_64,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_65,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_66,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_67,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_68,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_69,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_7,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_71,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_72,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_73,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_75,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_76,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_77,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_78,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_79,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_8,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_80,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_81,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_82,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_83,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_84,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_85,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_86,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_87,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_89,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_9,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_90,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_92,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_93,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_95,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_98,Intercept]',
#        'r_HenID__midcumZ4secMorning[hen_99,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_1,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_10,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_101,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_102,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_105,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_106,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_107,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_108,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_109,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_111,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_112,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_113,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_115,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_116,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_118,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_119,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_12,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_120,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_122,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_123,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_124,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_126,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_127,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_128,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_13,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_131,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_133,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_134,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_135,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_136,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_137,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_138,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_139,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_14,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_140,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_141,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_142,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_143,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_144,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_145,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_146,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_147,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_149,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_15,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_150,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_151,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_152,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_153,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_154,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_155,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_156,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_158,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_159,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_163,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_164,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_165,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_166,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_167,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_168,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_169,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_17,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_170,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_171,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_172,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_173,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_174,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_175,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_177,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_18,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_180,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_181,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_182,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_183,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_184,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_185,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_186,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_187,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_188,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_189,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_19,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_190,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_191,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_192,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_193,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_194,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_195,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_196,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_197,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_198,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_199,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_2,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_20,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_200,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_201,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_202,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_203,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_204,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_205,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_206,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_207,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_208,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_209,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_21,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_210,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_211,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_212,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_214,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_215,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_216,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_217,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_218,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_219,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_22,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_220,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_221,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_222,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_223,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_224,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_225,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_226,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_227,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_228,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_229,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_23,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_230,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_231,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_232,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_233,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_24,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_25,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_26,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_27,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_28,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_29,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_3,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_32,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_34,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_39,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_4,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_40,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_41,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_42,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_45,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_48,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_49,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_5,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_50,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_51,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_52,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_54,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_56,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_57,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_58,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_59,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_6,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_60,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_61,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_62,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_64,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_65,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_66,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_67,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_68,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_69,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_7,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_71,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_72,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_73,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_75,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_76,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_77,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_78,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_79,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_8,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_80,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_81,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_82,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_83,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_84,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_85,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_86,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_87,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_89,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_9,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_90,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_92,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_93,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_95,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_98,Intercept]',
#        'r_HenID__SleepingNotUppest[hen_99,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_1,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_10,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_101,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_102,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_105,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_106,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_107,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_108,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_109,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_111,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_112,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_113,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_115,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_116,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_118,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_119,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_12,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_120,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_122,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_123,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_124,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_126,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_127,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_128,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_13,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_131,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_133,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_134,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_135,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_136,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_137,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_138,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_139,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_14,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_140,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_141,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_142,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_143,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_144,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_145,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_146,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_147,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_149,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_15,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_150,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_151,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_152,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_153,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_154,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_155,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_156,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_158,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_159,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_163,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_164,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_165,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_166,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_167,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_168,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_169,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_17,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_170,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_171,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_172,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_173,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_174,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_175,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_177,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_18,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_180,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_181,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_182,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_183,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_184,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_185,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_186,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_187,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_188,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_189,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_19,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_190,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_191,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_192,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_193,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_194,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_195,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_196,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_197,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_198,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_199,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_2,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_20,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_200,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_201,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_202,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_203,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_204,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_205,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_206,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_207,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_208,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_209,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_21,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_210,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_211,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_212,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_214,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_215,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_216,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_217,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_218,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_219,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_22,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_220,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_221,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_222,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_223,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_224,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_225,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_226,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_227,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_228,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_229,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_23,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_230,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_231,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_232,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_233,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_24,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_25,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_26,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_27,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_28,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_29,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_3,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_32,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_34,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_39,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_4,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_40,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_41,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_42,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_45,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_48,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_49,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_5,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_50,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_51,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_52,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_54,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_56,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_57,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_58,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_59,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_6,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_60,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_61,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_62,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_64,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_65,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_66,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_67,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_68,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_69,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_7,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_71,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_72,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_73,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_75,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_76,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_77,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_78,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_79,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_8,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_80,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_81,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_82,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_83,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_84,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_85,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_86,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_87,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_89,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_9,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_90,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_92,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_93,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_95,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_98,Intercept]',
#        'r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind[hen_99,Intercept]',
#        'lp__'], dtype=object)

# %%
df['type'] = df['parameter'].map(lambda x: x.split('_')[0])
df['type'].value_counts()
# Out:
# r        950
# b         27
# cor       10
# sd         5
# shape      2
# sigma      1
# lp         1
# Name: type, dtype: int64

# %%
#henID intercept random intercept
df['HenID'] = df['parameter'].map(lambda x: x.split(',')[0].split('[')[-1] if 'hen_' in x else None)
#else None, otherwise will utput the entire name (i.e. x)
df['HenID'].unique()
# Out:
# array([None, 'hen_1', 'hen_10', 'hen_101', 'hen_102', 'hen_105',
#        'hen_106', 'hen_107', 'hen_108', 'hen_109', 'hen_111', 'hen_112',
#        'hen_113', 'hen_115', 'hen_116', 'hen_118', 'hen_119', 'hen_12',
#        'hen_120', 'hen_122', 'hen_123', 'hen_124', 'hen_126', 'hen_127',
#        'hen_128', 'hen_13', 'hen_131', 'hen_133', 'hen_134', 'hen_135',
#        'hen_136', 'hen_137', 'hen_138', 'hen_139', 'hen_14', 'hen_140',
#        'hen_141', 'hen_142', 'hen_143', 'hen_144', 'hen_145', 'hen_146',
#        'hen_147', 'hen_149', 'hen_15', 'hen_150', 'hen_151', 'hen_152',
#        'hen_153', 'hen_154', 'hen_155', 'hen_156', 'hen_158', 'hen_159',
#        'hen_163', 'hen_164', 'hen_165', 'hen_166', 'hen_167', 'hen_168',
#        'hen_169', 'hen_17', 'hen_170', 'hen_171', 'hen_172', 'hen_173',
#        'hen_174', 'hen_175', 'hen_177', 'hen_18', 'hen_180', 'hen_181',
#        'hen_182', 'hen_183', 'hen_184', 'hen_185', 'hen_186', 'hen_187',
#        'hen_188', 'hen_189', 'hen_19', 'hen_190', 'hen_191', 'hen_192',
#        'hen_193', 'hen_194', 'hen_195', 'hen_196', 'hen_197', 'hen_198',
#        'hen_199', 'hen_2', 'hen_20', 'hen_200', 'hen_201', 'hen_202',
#        'hen_203', 'hen_204', 'hen_205', 'hen_206', 'hen_207', 'hen_208',
#        'hen_209', 'hen_21', 'hen_210', 'hen_211', 'hen_212', 'hen_214',
#        'hen_215', 'hen_216', 'hen_217', 'hen_218', 'hen_219', 'hen_22',
#        'hen_220', 'hen_221', 'hen_222', 'hen_223', 'hen_224', 'hen_225',
#        'hen_226', 'hen_227', 'hen_228', 'hen_229', 'hen_23', 'hen_230',
#        'hen_231', 'hen_232', 'hen_233', 'hen_24', 'hen_25', 'hen_26',
#        'hen_27', 'hen_28', 'hen_29', 'hen_3', 'hen_32', 'hen_34',
#        'hen_39', 'hen_4', 'hen_40', 'hen_41', 'hen_42', 'hen_45',
#        'hen_48', 'hen_49', 'hen_5', 'hen_50', 'hen_51', 'hen_52',
#        'hen_54', 'hen_56', 'hen_57', 'hen_58', 'hen_59', 'hen_6',
#        'hen_60', 'hen_61', 'hen_62', 'hen_64', 'hen_65', 'hen_66',
#        'hen_67', 'hen_68', 'hen_69', 'hen_7', 'hen_71', 'hen_72',
#        'hen_73', 'hen_75', 'hen_76', 'hen_77', 'hen_78', 'hen_79',
#        'hen_8', 'hen_80', 'hen_81', 'hen_82', 'hen_83', 'hen_84',
#        'hen_85', 'hen_86', 'hen_87', 'hen_89', 'hen_9', 'hen_90',
#        'hen_92', 'hen_93', 'hen_95', 'hen_98', 'hen_99'], dtype=object)

# %%
#mvt variable for the hen intercepts to be visualised
df['mvtvariable'] = df['parameter'].map(lambda x: x.split('r_HenID__')[-1].split('[')[0] if ('r_HenID__' in x) \
                                        & ('cor_HenID' not in x) else None)
li_mvt = [i for i in df['mvtvariable'].unique() if i!=None]
li_mvt
# Out:
# ['foodrelatedbehaviorfinalinvcst',
#  'scaleVTD',
#  'midcumZ4secMorning',
#  'SleepingNotUppest',
#  'mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind']

# %%
df_cor_summarized
# Out:
#                                             parameter  value_mean     lower  \
# 32  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.315395 -0.447813
# 33  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...    0.055655 -0.107592
# 34  cor_HenID__scaleVTD_Intercept__midcumZ4secMorn...    0.004897 -0.147220
# 35  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.096045 -0.252674
# 36  cor_HenID__scaleVTD_Intercept__SleepingNotUppe...    0.217018  0.065649
# 37  cor_HenID__midcumZ4secMorning_Intercept__Sleep...    0.003471 -0.164045
# 38  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.238760 -0.392401
# 39  cor_HenID__scaleVTD_Intercept__mulatency1Zone1...    0.491053  0.371738
# 40  cor_HenID__midcumZ4secMorning_Intercept__mulat...   -0.150524 -0.292266
# 41  cor_HenID__SleepingNotUppest_Intercept__mulate...    0.029939 -0.133890
#
#        upper type HenID mvtvariable
# 32 -0.180327  cor  None        None
# 33  0.212908  cor  None        None
# 34  0.155296  cor  None        None
# 35  0.063320  cor  None        None
# 36  0.372034  cor  None        None
# 37  0.169169  cor  None        None
# 38 -0.101184  cor  None        None
# 39  0.602453  cor  None        None
# 40  0.006058  cor  None        None
# 41  0.198504  cor  None        None

# %%
#correlations
df_cor_summarized = df[df['type']=='cor'].copy()
for mvt in li_mvt:
    df_cor_summarized[mvt] = df_cor_summarized['parameter'].map(lambda x: mvt in x)
df_cor_summarized
# Out:
#                                             parameter  value_mean     lower  \
# 32  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.315395 -0.447813
# 33  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...    0.055655 -0.107592
# 34  cor_HenID__scaleVTD_Intercept__midcumZ4secMorn...    0.004897 -0.147220
# 35  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.096045 -0.252674
# 36  cor_HenID__scaleVTD_Intercept__SleepingNotUppe...    0.217018  0.065649
# 37  cor_HenID__midcumZ4secMorning_Intercept__Sleep...    0.003471 -0.164045
# 38  cor_HenID__foodrelatedbehaviorfinalinvcst_Inte...   -0.238760 -0.392401
# 39  cor_HenID__scaleVTD_Intercept__mulatency1Zone1...    0.491053  0.371738
# 40  cor_HenID__midcumZ4secMorning_Intercept__mulat...   -0.150524 -0.292266
# 41  cor_HenID__SleepingNotUppest_Intercept__mulate...    0.029939 -0.133890
#
#        upper type HenID mvtvariable  foodrelatedbehaviorfinalinvcst  scaleVTD  \
# 32 -0.180327  cor  None        None                            True      True
# 33  0.212908  cor  None        None                            True     False
# 34  0.155296  cor  None        None                           False      True
# 35  0.063320  cor  None        None                            True     False
# 36  0.372034  cor  None        None                           False      True
# 37  0.169169  cor  None        None                           False     False
# 38 -0.101184  cor  None        None                            True     False
# 39  0.602453  cor  None        None                           False      True
# 40  0.006058  cor  None        None                           False     False
# 41  0.198504  cor  None        None                           False     False
#
#     midcumZ4secMorning  SleepingNotUppest  \
# 32               False              False
# 33                True              False
# 34                True              False
# 35               False               True
# 36               False               True
# 37                True               True
# 38               False              False
# 39               False              False
# 40                True              False
# 41               False               True
#
#     mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 32                                           False
# 33                                           False
# 34                                           False
# 35                                           False
# 36                                           False
# 37                                           False
# 38                                            True
# 39                                            True
# 40                                            True
# 41                                            True

# %%
li_mvt
# Out:
# ['foodrelatedbehaviorfinalinvcst',
#  'scaleVTD',
#  'midcumZ4secMorning',
#  'SleepingNotUppest',
#  'mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind']

# %%
#sd
df_sd_summarized = df[df['type']=='sd'].copy()
df_sd_summarized['parameter'] = df_sd_summarized['parameter'].map(lambda x: x.split('sd_HenID__')[-1])
df_sd_summarized
# Out:
#                                             parameter  value_mean     lower  \
# 27           foodrelatedbehaviorfinalinvcst_Intercept    0.164588  0.146020
# 28                                 scaleVTD_Intercept    0.835997  0.750709
# 29                       midcumZ4secMorning_Intercept    0.150481  0.134459
# 30                        SleepingNotUppest_Intercept    2.386883  2.040603
# 31  mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind...    2.405209  2.114488
#
#        upper type HenID mvtvariable
# 27  0.184162   sd  None        None
# 28  0.924998   sd  None        None
# 29  0.167454   sd  None        None
# 30  2.771719   sd  None        None
# 31  2.707781   sd  None        None

# %% [markdown]
# # visualise

# %%
#df[df['HenID'].isnull()].shape
df_plt = df[~df['HenID'].isnull()].pivot(index='HenID', columns='mvtvariable', values=['value_mean',
                                                                                       'lower','upper']).reset_index()
df_plt.columns = ['_'.join(col) for col in df_plt.columns.values] #joining name from different index
display(df_plt.head(3))
for i in range(0,len(li_mvt)-1):
    for j in range(i+1,len(li_mvt)):
        mvtx = li_mvt[i]
        mvty = li_mvt[j]
        print(mvtx)
        print(mvty)
        cor_mvtx_mvty = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['value_mean'].iloc[0]
        cor_mvtx_mvty_upper = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['upper'].iloc[0]
        cor_mvtx_mvty_lower = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['lower'].iloc[0]
        print(cor_mvtx_mvty)
        sd_mvtx = df_sd_summarized[df_sd_summarized['parameter']==mvtx+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvtx)
        sd_mvty = df_sd_summarized[df_sd_summarized['parameter']==mvty+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvty)        
        slope = cor_mvtx_mvty*sd_mvtx*sd_mvty/(sd_mvtx*sd_mvtx)
        print(slope)
        plt.figure(figsize=(8,8))
        #ax = sns.scatterplot(data=df_plt, x='value_mean_'+mvtx,  y='value_mean_'+mvty)#,  size="size", sizes=(20, 200))
        plt.scatter(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(), color='r', s=5)
        plt.errorbar(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(),
                     xerr=[df_plt['lower_'+mvtx].tolist(),df_plt['upper_'+mvtx].tolist()], 
                     yerr=[df_plt['lower_'+mvty].tolist(),df_plt['upper_'+mvty].tolist()],
                     fmt="o", color="r", alpha=0.2,ms=5)
        plt.xlabel(mvtx)
        plt.ylabel(mvty)
        x_min = min(df_plt['value_mean_'+mvtx].tolist())
        y_min = x_min*slope
        x_max = max(df_plt['value_mean_'+mvtx].tolist())
        y_max = x_max*slope
        plt.plot([x_min, x_max], [y_min, y_max], color='black')
        text_ = 'r = '+str(round(cor_mvtx_mvty,2))+' ['+str(round(cor_mvtx_mvty_lower,2))+', '+str(round(cor_mvtx_mvty_upper,2))+']'
        plt.text(max(df_plt['upper_'+mvtx].tolist())*0.5, max(df_plt['upper_'+mvty].tolist())*1.3, text_, fontsize=12)
        #plt.set_xlim([x_min, x_max])   
        plt.savefig(os.path.join(path_extracted_data,'BS_'+mvtx+'_'+mvty+'.png'),dpi=300,format='png',bbox_inches='tight')
        plt.show();
# Out:
#     HenID_  value_mean_SleepingNotUppest  \
# 0    hen_1                     -1.676103
# 1   hen_10                      5.474904
# 2  hen_101                      2.109420
#
#    value_mean_foodrelatedbehaviorfinalinvcst  value_mean_midcumZ4secMorning  \
# 0                                  -0.011007                      -0.062319
# 1                                   0.124863                      -0.179903
# 2                                   0.062946                      -0.007826
#
#    value_mean_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind  \
# 0                                           2.741808
# 1                                           0.239241
# 2                                           1.356340
#
#    value_mean_scaleVTD  lower_SleepingNotUppest  \
# 0            -0.052239                -5.107141
# 1            -0.765943                 3.498311
# 2             0.208961                 1.089132
#
#    lower_foodrelatedbehaviorfinalinvcst  lower_midcumZ4secMorning  \
# 0                             -0.169723                 -0.201717
# 1                              0.035262                 -0.250944
# 2                             -0.036025                 -0.073495
#
#    lower_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind  lower_scaleVTD  \
# 0                                           1.916904          -0.571826
# 1                                          -0.332458          -1.063989
# 2                                           0.848178          -0.081188
#
#    upper_SleepingNotUppest  upper_foodrelatedbehaviorfinalinvcst  \
# 0                 1.361240                              0.149115
# 1                 7.539483                              0.219840
# 2                 3.115702                              0.151243
#
#    upper_midcumZ4secMorning  \
# 0                  0.065233
# 1                 -0.105226
# 2                  0.070261
#
#    upper_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind  upper_scaleVTD
# 0                                           3.486139           0.469644
# 1                                           0.856803          -0.462837
# 2                                           1.952388           0.498116
# foodrelatedbehaviorfinalinvcst
# scaleVTD
# -0.315394892518086
# 0.1645882071183
# 0.835996586388652
# -1.6019923791989545
# foodrelatedbehaviorfinalinvcst
# midcumZ4secMorning
# 0.0556554971922554
# 0.1645882071183
# 0.150480893814172
# 0.05088510963086818
# foodrelatedbehaviorfinalinvcst
# SleepingNotUppest
# -0.0960448449823785
# 0.1645882071183
# 2.38688275884909
# -1.3928566850479018
# foodrelatedbehaviorfinalinvcst
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# -0.238760111896534
# 0.1645882071183
# 2.4052088487491
# -3.489119566440784
# scaleVTD
# midcumZ4secMorning
# 0.0048968741086607
# 0.835996586388652
# 0.150480893814172
# 0.0008814461742600502
# scaleVTD
# SleepingNotUppest
# 0.217018269398382
# 0.835996586388652
# 2.38688275884909
# 0.6196163644877013
# scaleVTD
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 0.491053371111825
# 0.835996586388652
# 2.4052088487491
# 1.412787961860354
# midcumZ4secMorning
# SleepingNotUppest
# 0.0034705643132431
# 0.150480893814172
# 2.38688275884909
# 0.05504904917023249
# midcumZ4secMorning
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# -0.150524112932934
# 0.150480893814172
# 2.4052088487491
# -2.4058996408107807
# SleepingNotUppest
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 0.0299393493156181
# 2.38688275884909
# 2.4052088487491
# 0.03016921867349573

# %% [markdown]
# # Download all data

# %%
df_BLUP_var = pd.read_csv(os.path.join(path_extracted_data,'BRMS_BS_pred_allvar.csv'), sep=',')
print(df_BLUP_var.shape) 
display(df_BLUP_var.head(3))
print(list(df_BLUP_var.columns))
# Out:
# (1000, 3984)
#    X1.b_foodrelatedbehaviorfinalinvcst_Intercept  X1.b_scaleVTD_Intercept  \
# 0                                      -0.156256                 0.126751
# 1                                      -0.147821                 0.036411
# 2                                      -0.150971                 0.023112
#
#    X1.b_midcumZ4secMorning_Intercept  X1.b_SleepingNotUppest_Intercept  \
# 0                           1.500100                         -1.215451
# 1                           1.503082                         -1.181332
# 2                           1.503244                         -1.033960
#
#    X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept  \
# 0                                          -0.608450
# 1                                          -0.702484
# 2                                          -0.941951
#
#    X1.b_foodrelatedbehaviorfinalinvcst_TreatmentOFH  \
# 0                                          0.055572
# 1                                          0.048587
# 2                                          0.021373
#
#    X1.b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID5M8  \
# 0                                          -0.043022
# 1                                          -0.021751
# 2                                          -0.012694
#
#    X1.b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID9M12  \
# 0                                          -0.002710
# 1                                           0.006928
# 2                                           0.024425
#
#    X1.b_foodrelatedbehaviorfinalinvcst_scaleweightInterp  \
# 0                                           0.014987
# 1                                           0.002466
# 2                                           0.006604
#
#    X1.b_foodrelatedbehaviorfinalinvcst_scaleKBFInterp  ...  \
# 0                                          -0.013182   ...
# 1                                          -0.000881   ...
# 2                                          -0.004923   ...
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.  \
# 0                                          -2.541553
# 1                                          -3.114152
# 2                                          -2.325067
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_89.Intercept.  \
# 0                                          -3.259883
# 1                                          -4.744467
# 2                                          -2.288065
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_9.Intercept.  \
# 0                                           1.915973
# 1                                           1.418008
# 2                                           1.725570
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_90.Intercept.  \
# 0                                           2.124837
# 1                                           2.015098
# 2                                           2.258131
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_92.Intercept.  \
# 0                                           0.205291
# 1                                           0.205378
# 2                                           0.276022
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_93.Intercept.  \
# 0                                          -3.756945
# 1                                          -3.948223
# 2                                          -5.090294
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_95.Intercept.  \
# 0                                           0.946815
# 1                                           0.365273
# 2                                           0.969293
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_98.Intercept.  \
# 0                                           2.838521
# 1                                           2.352747
# 2                                           2.371698
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_99.Intercept.  \
# 0                                           1.625051
# 1                                           1.250970
# 2                                           1.414232
#
#         X4.lp__
# 0 -20258.215901
# 1 -20260.371054
# 2 -20261.512168
#
# [3 rows x 3984 columns]
# ['X1.b_foodrelatedbehaviorfinalinvcst_Intercept', 'X1.b_scaleVTD_Intercept', 'X1.b_midcumZ4secMorning_Intercept', 'X1.b_SleepingNotUppest_Intercept', 'X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.b_foodrelatedbehaviorfinalinvcst_TreatmentOFH', 'X1.b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID5M8', 'X1.b_foodrelatedbehaviorfinalinvcst_FoodPenIDFoodPenID9M12', 'X1.b_foodrelatedbehaviorfinalinvcst_scaleweightInterp', 'X1.b_foodrelatedbehaviorfinalinvcst_scaleKBFInterp', 'X1.b_foodrelatedbehaviorfinalinvcst_scaleDIB', 'X1.b_scaleVTD_TreatmentOFH', 'X1.b_scaleVTD_scaleweightInterp', 'X1.b_scaleVTD_scaleKBFInterp', 'X1.b_scaleVTD_scaleDIB', 'X1.b_scaleVTD_scaleIDIBE2', 'X1.b_midcumZ4secMorning_TreatmentOFH', 'X1.b_midcumZ4secMorning_scaleweightInterp', 'X1.b_midcumZ4secMorning_scaleKBFInterp', 'X1.b_midcumZ4secMorning_scaleDIB', 'X1.b_SleepingNotUppest_TreatmentOFH', 'X1.b_SleepingNotUppest_scaleweight_interp', 'X1.b_SleepingNotUppest_scaleKBF_interp', 'X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_TreatmentOFH', 'X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleDIB', 'X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleweight_interp', 'X1.b_mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_scaleKBF_interp', 'X1.sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept', 'X1.sd_HenID__scaleVTD_Intercept', 'X1.sd_HenID__midcumZ4secMorning_Intercept', 'X1.sd_HenID__SleepingNotUppest_Intercept', 'X1.sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept', 'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept', 'X1.cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept', 'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept', 'X1.cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept', 'X1.cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept', 'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept', 'X1.shape_foodrelatedbehaviorfinalinvcst', 'X1.shape_midcumZ4secMorning', 'X1.sigma_scaleVTD', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_1.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_10.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_101.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_102.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_105.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_106.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_107.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_108.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_109.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_111.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_112.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_113.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_115.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_116.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_118.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_119.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_12.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_120.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_122.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_123.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_124.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_126.Intercept.', 'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_127.Intercept.', 'X1.r_HenID__food ...

# %%
#check availabilities for a random hen
display(set([x if 'hen_87' in x  else '' for x in list(df_BLUP_var.columns)])) #X*, where * is the number of chain
# Out:
# {'',
#  'X1.r_HenID__SleepingNotUppest.hen_87.Intercept.',
#  'X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_87.Intercept.',
#  'X1.r_HenID__midcumZ4secMorning.hen_87.Intercept.',
#  'X1.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.',
#  'X1.r_HenID__scaleVTD.hen_87.Intercept.',
#  'X2.r_HenID__SleepingNotUppest.hen_87.Intercept.',
#  'X2.r_HenID__foodrelatedbehaviorfinalinvcst.hen_87.Intercept.',
#  'X2.r_HenID__midcumZ4secMorning.hen_87.Intercept.',
#  'X2.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.',
#  'X2.r_HenID__scaleVTD.hen_87.Intercept.',
#  'X3.r_HenID__SleepingNotUppest.hen_87.Intercept.',
#  'X3.r_HenID__foodrelatedbehaviorfinalinvcst.hen_87.Intercept.',
#  'X3.r_HenID__midcumZ4secMorning.hen_87.Intercept.',
#  'X3.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.',
#  'X3.r_HenID__scaleVTD.hen_87.Intercept.',
#  'X4.r_HenID__SleepingNotUppest.hen_87.Intercept.',
#  'X4.r_HenID__foodrelatedbehaviorfinalinvcst.hen_87.Intercept.',
#  'X4.r_HenID__midcumZ4secMorning.hen_87.Intercept.',
#  'X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.',
#  'X4.r_HenID__scaleVTD.hen_87.Intercept.'}

# %%
#correlation
li_col = set([x for x in list(df_BLUP_var.columns) if 'cor_HenID__' in x]) #X*, where * is the number of chain
display(li_col)
df_cor = df_BLUP_var[li_col].copy()
df_cor['run'] = df_cor.index
df_cor = pd.melt(df_cor, id_vars=['run'], value_vars=li_col)
#df_cor['chainID'] = df_cor['variable'].map(lambda x: x.split('.')[0])
#df_cor['var1'] = df_cor['variable'].map(lambda x: x.split('__')[1].strip('Intercept'))
#df_cor['var2'] = df_cor['variable'].map(lambda x: x.split('__')[2].strip('Intercept'))
df_cor['var1var2'] = df_cor['variable'].map(lambda x: x.split('.cor_HenID__')[1])
print(df_cor.shape)
display(df_cor.head(3))

df_cor_summarized = df_cor.groupby(['var1var2'])['value'].agg(lambda x: list(x)).reset_index()
df_cor_summarized['value_mean'] = df_cor_summarized['value'].map(lambda x: np.mean(x))
df_cor_summarized['value_sd'] = df_cor_summarized['value'].map(lambda x: np.std(x))
print(df_cor_summarized.shape)
display(df_cor_summarized)
# Out:
# {'X1.cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept',
#  'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept',
#  'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X1.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept',
#  'X1.cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept',
#  'X1.cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X1.cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept',
#  'X1.cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept',
#  'X1.cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X2.cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X2.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept',
#  'X2.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept',
#  'X2.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X2.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept',
#  'X2.cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept',
#  'X2.cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X2.cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept',
#  'X2.cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept',
#  'X2.cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X3.cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X3.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept',
#  'X3.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept',
#  'X3.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X3.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept',
#  'X3.cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept',
#  'X3.cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X3.cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept',
#  'X3.cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept',
#  'X3.cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X4.cor_HenID__SleepingNotUppest_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X4.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__SleepingNotUppest_Intercept',
#  'X4.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__midcumZ4secMorning_Intercept',
#  'X4.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X4.cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept',
#  'X4.cor_HenID__midcumZ4secMorning_Intercept__SleepingNotUppest_Intercept',
#  'X4.cor_HenID__midcumZ4secMorning_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X4.cor_HenID__scaleVTD_Intercept__SleepingNotUppest_Intercept',
#  'X4.cor_HenID__scaleVTD_Intercept__midcumZ4secMorning_Intercept',
#  'X4.cor_HenID__scaleVTD_Intercept__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept'}
# (40000, 4)
#    run                                           variable     value  \
# 0    0  X3.cor_HenID__foodrelatedbehaviorfinalinvcst_I... -0.525084
# 1    1  X3.cor_HenID__foodrelatedbehaviorfinalinvcst_I... -0.481112
# 2    2  X3.cor_HenID__foodrelatedbehaviorfinalinvcst_I... -0.426055
#
#                                             var1var2
# 0  foodrelatedbehaviorfinalinvcst_Intercept__scal...
# 1  foodrelatedbehaviorfinalinvcst_Intercept__scal...
# 2  foodrelatedbehaviorfinalinvcst_Intercept__scal...
# (10, 4)
#                                             var1var2  \
# 0  SleepingNotUppest_Intercept__mulatency1Zone15m...
# 1  foodrelatedbehaviorfinalinvcst_Intercept__Slee...
# 2  foodrelatedbehaviorfinalinvcst_Intercept__midc...
# 3  foodrelatedbehaviorfinalinvcst_Intercept__mula...
# 4  foodrelatedbehaviorfinalinvcst_Intercept__scal...
# 5  midcumZ4secMorning_Intercept__SleepingNotUppes...
# 6  midcumZ4secMorning_Intercept__mulatency1Zone15...
# 7    scaleVTD_Intercept__SleepingNotUppest_Intercept
# 8   scaleVTD_Intercept__midcumZ4secMorning_Intercept
# 9  scaleVTD_Intercept__mulatency1Zone15mn3hOPP_la...
#
#                                                value  value_mean  value_sd
# 0  [0.146255013309696, 0.0587914232823501, 0.0521...    0.029939  0.084975
# 1  [-0.265491804716187, -0.312459057858454, -0.31...   -0.096045  0.082211
# 2  [-0.0263628063556332, -0.0990584087337265, -0....    0.055655  0.082947
# 3  [-0.267030859173138, -0.326035551593807, -0.27...   -0.238760  0.074718
# 4  [-0.525083666165678, -0.481112008112693, -0.42...   -0.315395  0.068772
# 5  [-0.116359640392252, 0.0461876737689497, 0.060...    0.003471  0.085031
# 6  [-0.130749858508119, -0.107486337134019, -0.02...   -0.150524  0.076064
# 7  [0.287107013011435, 0.0465600780145065, 0.1760...    0.217018  0.079104
# 8  [0.0903876826491821, 0.0745974998203062, 0.022...    0.004897  0.077116
# 9  [0.490187671877486, 0.505683176654037, 0.49010...    0.491053  0.059645

# %%
#SD
li_col = set([x for x in list(df_BLUP_var.columns) if '.sd_HenID__' in x]) #X*, where * is the number of chain
display(li_col)
df_sd = df_BLUP_var[li_col].copy()
df_sd['run'] = df_sd.index
df_sd = pd.melt(df_sd, id_vars=['run'], value_vars=li_col)
#df_sd['chainID'] = df_sd['variable'].map(lambda x: x.split('.')[0])
#df_sd['var1'] = df_sd['variable'].map(lambda x: x.split('__')[1].strip('Intercept'))
#df_sd['var2'] = df_sd['variable'].map(lambda x: x.split('__')[2].strip('Intercept'))
df_sd['var'] = df_sd['variable'].map(lambda x: x.split('.sd_HenID__')[1])
print(df_sd.shape)
display(df_sd.head(3))

df_sd_summarized = df_sd.groupby(['var'])['value'].agg(lambda x: list(x)).reset_index()
df_sd_summarized['value_mean'] = df_sd_summarized['value'].map(lambda x: np.mean(x))
df_sd_summarized['value_sd'] = df_sd_summarized['value'].map(lambda x: np.std(x))
print(df_sd_summarized.shape)
display(df_sd_summarized)
# Out:
# {'X1.sd_HenID__SleepingNotUppest_Intercept',
#  'X1.sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept',
#  'X1.sd_HenID__midcumZ4secMorning_Intercept',
#  'X1.sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X1.sd_HenID__scaleVTD_Intercept',
#  'X2.sd_HenID__SleepingNotUppest_Intercept',
#  'X2.sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept',
#  'X2.sd_HenID__midcumZ4secMorning_Intercept',
#  'X2.sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X2.sd_HenID__scaleVTD_Intercept',
#  'X3.sd_HenID__SleepingNotUppest_Intercept',
#  'X3.sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept',
#  'X3.sd_HenID__midcumZ4secMorning_Intercept',
#  'X3.sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X3.sd_HenID__scaleVTD_Intercept',
#  'X4.sd_HenID__SleepingNotUppest_Intercept',
#  'X4.sd_HenID__foodrelatedbehaviorfinalinvcst_Intercept',
#  'X4.sd_HenID__midcumZ4secMorning_Intercept',
#  'X4.sd_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept',
#  'X4.sd_HenID__scaleVTD_Intercept'}
# (20000, 4)
#    run                         variable     value                 var
# 0    0  X1.sd_HenID__scaleVTD_Intercept  0.823730  scaleVTD_Intercept
# 1    1  X1.sd_HenID__scaleVTD_Intercept  0.826924  scaleVTD_Intercept
# 2    2  X1.sd_HenID__scaleVTD_Intercept  0.803449  scaleVTD_Intercept
# (5, 4)
#                                                  var  \
# 0                        SleepingNotUppest_Intercept
# 1           foodrelatedbehaviorfinalinvcst_Intercept
# 2                       midcumZ4secMorning_Intercept
# 3  mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind...
# 4                                 scaleVTD_Intercept
#
#                                                value  value_mean  value_sd
# 0  [2.32261050609496, 2.19816678633369, 2.4387678...    2.386883  0.188367
# 1  [0.186684381896474, 0.170956090341713, 0.15766...    0.164588  0.009655
# 2  [0.144516978263763, 0.149622570578545, 0.15017...    0.150481  0.008637
# 3  [2.23038176807283, 2.25272761083463, 2.2934408...    2.405209  0.152640
# 4  [0.823729711278948, 0.826924182035739, 0.80344...    0.835997  0.044847

# %%
li_col = [x for x in df_BLUP_var.columns if '.r_HenID__' in x] #
df_BLUP_var = df_BLUP_var[li_col].copy()
print(df_BLUP_var.shape)
display(df_BLUP_var.head(3))

#melt data for simplicity
df_BLUP_var['run'] = df_BLUP_var.index
df_BLUP_var = pd.melt(df_BLUP_var, id_vars=['run'], value_vars=li_col)
print(df_BLUP_var.shape)
display(df_BLUP_var.head(3))

df_BLUP_var['HenID'] = df_BLUP_var['variable'].map(lambda x: x.split('.Intercept')[0].split('.')[-1])
display(df_BLUP_var['HenID'].unique())
df_BLUP_var['chainID'] = df_BLUP_var['variable'].map(lambda x: x.split('.')[0])
df_BLUP_var['mvtvariable'] = df_BLUP_var['variable'].map(lambda x: x.split('.r_HenID__')[1].split('.')[0])
display(df_BLUP_var['chainID'].unique())
display(df_BLUP_var['mvtvariable'].unique())
print(df_BLUP_var.shape)
df_BLUP_var.head(3)

df_BLUP_var_summarized = df_BLUP_var.groupby(['HenID','mvtvariable'])['value'].agg(lambda x: list(x)).reset_index()
df_BLUP_var_summarized['value_mean'] = df_BLUP_var_summarized['value'].map(lambda x: np.mean(x))
df_BLUP_var_summarized['value_sd'] = df_BLUP_var_summarized['value'].map(lambda x: np.std(x))



print(df_BLUP_var_summarized.shape)
display(df_BLUP_var_summarized.head(3))
# Out:
# (1000, 3800)
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_1.Intercept.  \
# 0                                           0.102869
# 1                                           0.062603
# 2                                          -0.062697
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_10.Intercept.  \
# 0                                           0.147142
# 1                                           0.055474
# 2                                           0.139501
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_101.Intercept.  \
# 0                                           0.015415
# 1                                           0.060843
# 2                                           0.032371
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_102.Intercept.  \
# 0                                           0.073835
# 1                                           0.001115
# 2                                           0.054041
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_105.Intercept.  \
# 0                                          -0.019721
# 1                                          -0.141028
# 2                                          -0.097738
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_106.Intercept.  \
# 0                                           0.027271
# 1                                           0.083776
# 2                                           0.072882
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_107.Intercept.  \
# 0                                           0.304435
# 1                                           0.358535
# 2                                           0.344638
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_108.Intercept.  \
# 0                                           0.172625
# 1                                           0.070092
# 2                                           0.053679
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_109.Intercept.  \
# 0                                           0.316778
# 1                                           0.197820
# 2                                           0.179386
#
#    X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen_111.Intercept.  ...  \
# 0                                          -0.001071              ...
# 1                                           0.043608              ...
# 2                                           0.002106              ...
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_86.Intercept.  \
# 0                                           4.837169
# 1                                           5.989085
# 2                                           4.833207
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_87.Intercept.  \
# 0                                          -2.541553
# 1                                          -3.114152
# 2                                          -2.325067
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_89.Intercept.  \
# 0                                          -3.259883
# 1                                          -4.744467
# 2                                          -2.288065
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_9.Intercept.  \
# 0                                           1.915973
# 1                                           1.418008
# 2                                           1.725570
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_90.Intercept.  \
# 0                                           2.124837
# 1                                           2.015098
# 2                                           2.258131
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_92.Intercept.  \
# 0                                           0.205291
# 1                                           0.205378
# 2                                           0.276022
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_93.Intercept.  \
# 0                                          -3.756945
# 1                                          -3.948223
# 2                                          -5.090294
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_95.Intercept.  \
# 0                                           0.946815
# 1                                           0.365273
# 2                                           0.969293
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_98.Intercept.  \
# 0                                           2.838521
# 1                                           2.352747
# 2                                           2.371698
#
#    X4.r_HenID__mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind.hen_99.Intercept.
# 0                                           1.625051
# 1                                           1.250970
# 2                                           1.414232
#
# [3 rows x 3800 columns]
# (3800000, 3)
#    run                                           variable     value
# 0    0  X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen...  0.102869
# 1    1  X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen...  0.062603
# 2    2  X1.r_HenID__foodrelatedbehaviorfinalinvcst.hen... -0.062697
# array(['hen_1', 'hen_10', 'hen_101', 'hen_102', 'hen_105', 'hen_106',
#        'hen_107', 'hen_108', 'hen_109', 'hen_111', 'hen_112', 'hen_113',
#        'hen_115', 'hen_116', 'hen_118', 'hen_119', 'hen_12', 'hen_120',
#        'hen_122', 'hen_123', 'hen_124', 'hen_126', 'hen_127', 'hen_128',
#        'hen_13', 'hen_131', 'hen_133', 'hen_134', 'hen_135', 'hen_136',
#        'hen_137', 'hen_138', 'hen_139', 'hen_14', 'hen_140', 'hen_141',
#        'hen_142', 'hen_143', 'hen_144', 'hen_145', 'hen_146', 'hen_147',
#        'hen_149', 'hen_15', 'hen_150', 'hen_151', 'hen_152', 'hen_153',
#        'hen_154', 'hen_155', 'hen_156', 'hen_158', 'hen_159', 'hen_163',
#        'hen_164', 'hen_165', 'hen_166', 'hen_167', 'hen_168', 'hen_169',
#        'hen_17', 'hen_170', 'hen_171', 'hen_172', 'hen_173', 'hen_174',
#        'hen_175', 'hen_177', 'hen_18', 'hen_180', 'hen_181', 'hen_182',
#        'hen_183', 'hen_184', 'hen_185', 'hen_186', 'hen_187', 'hen_188',
#        'hen_189', 'hen_19', 'hen_190', 'hen_191', 'hen_192', 'hen_193',
#        'hen_194', 'hen_195', 'hen_196', 'hen_197', 'hen_198', 'hen_199',
#        'hen_2', 'hen_20', 'hen_200', 'hen_201', 'hen_202', 'hen_203',
#        'hen_204', 'hen_205', 'hen_206', 'hen_207', 'hen_208', 'hen_209',
#        'hen_21', 'hen_210', 'hen_211', 'hen_212', 'hen_214', 'hen_215',
#        'hen_216', 'hen_217', 'hen_218', 'hen_219', 'hen_22', 'hen_220',
#        'hen_221', 'hen_222', 'hen_223', 'hen_224', 'hen_225', 'hen_226',
#        'hen_227', 'hen_228', 'hen_229', 'hen_23', 'hen_230', 'hen_231',
#        'hen_232', 'hen_233', 'hen_24', 'hen_25', 'hen_26', 'hen_27',
#        'hen_28', 'hen_29', 'hen_3', 'hen_32', 'hen_34', 'hen_39', 'hen_4',
#        'hen_40', 'hen_41', 'hen_42', 'hen_45', 'hen_48', 'hen_49',
#        'hen_5', 'hen_50', 'hen_51', 'hen_52', 'hen_54', 'hen_56',
#        'hen_57', 'hen_58', 'hen_59', 'hen_6', 'hen_60', 'hen_61',
#        'hen_62', 'hen_64', 'hen_65', 'hen_66', 'hen_67', 'hen_68',
#        'hen_69', 'hen_7', 'hen_71', 'hen_72', 'hen_73', 'hen_75',
#        'hen_76', 'hen_77', 'hen_78', 'hen_79', 'hen_8', 'hen_80',
#        'hen_81', 'hen_82', 'hen_83', 'hen_84', 'hen_85', 'hen_86',
#        'hen_87', 'hen_89', 'hen_9', 'hen_90', 'hen_92', 'hen_93',
#        'hen_95', 'hen_98', 'hen_99'], dtype=object)
# array(['X1', 'X2', 'X3', 'X4'], dtype=object)
# array(['foodrelatedbehaviorfinalinvcst', 'scaleVTD', 'midcumZ4secMorning',
#        'SleepingNotUppest',
#        'mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind'], dtype=object)
# (3800000, 6)
# (950, 5)
#    HenID                     mvtvariable  \
# 0  hen_1               SleepingNotUppest
# 1  hen_1  foodrelatedbehaviorfinalinvcst
# 2  hen_1              midcumZ4secMorning
#
#                                                value  value_mean  value_sd
# 0  [-2.23304394856033, -1.3640821814961, -1.12767...   -1.676103  1.697018
# 1  [0.102869412491423, 0.0626028801092981, -0.062...   -0.011007  0.081707
# 2  [-0.150774401421008, -0.108884805740338, -0.13...   -0.062319  0.068184

# %% [markdown]
# # Visualise with slope

# %%
li_mvt = list(df_BLUP_var['mvtvariable'].unique())
li_mvt
# Out:
# ['foodrelatedbehaviorfinalinvcst',
#  'scaleVTD',
#  'midcumZ4secMorning',
#  'SleepingNotUppest',
#  'mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind']

# %%
#slope of a fitted line = Cov(X,Y)/Var(X) = corr(X,Y) * SD(X) * SD(Y) /Var(X)
#                                         = corr(X,Y) * sqrt(var(X)) * sqrt(var(Y)) /Var(X)
#Reference: https://www.physicsforums.com/threads/slope-of-ls-line-cov-x-y-var-x-intuitive-explanation.880963/
display(df_sd_summarized)
for mvt in li_mvt:
    df_cor_summarized[mvt] = df_cor_summarized['var1var2'].map(lambda x: mvt in x)
df_cor_summarized
# Out:
#                                                  var  \
# 0                        SleepingNotUppest_Intercept
# 1           foodrelatedbehaviorfinalinvcst_Intercept
# 2                       midcumZ4secMorning_Intercept
# 3  mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind...
# 4                                 scaleVTD_Intercept
#
#                                                value  value_mean  value_sd
# 0  [2.32261050609496, 2.19816678633369, 2.4387678...    2.386883  0.188367
# 1  [0.186684381896474, 0.170956090341713, 0.15766...    0.164588  0.009655
# 2  [0.144516978263763, 0.149622570578545, 0.15017...    0.150481  0.008637
# 3  [2.23038176807283, 2.25272761083463, 2.2934408...    2.405209  0.152640
# 4  [0.823729711278948, 0.826924182035739, 0.80344...    0.835997  0.044847
#                                             var1var2  \
# 0  SleepingNotUppest_Intercept__mulatency1Zone15m...
# 1  foodrelatedbehaviorfinalinvcst_Intercept__Slee...
# 2  foodrelatedbehaviorfinalinvcst_Intercept__midc...
# 3  foodrelatedbehaviorfinalinvcst_Intercept__mula...
# 4  foodrelatedbehaviorfinalinvcst_Intercept__scal...
# 5  midcumZ4secMorning_Intercept__SleepingNotUppes...
# 6  midcumZ4secMorning_Intercept__mulatency1Zone15...
# 7    scaleVTD_Intercept__SleepingNotUppest_Intercept
# 8   scaleVTD_Intercept__midcumZ4secMorning_Intercept
# 9  scaleVTD_Intercept__mulatency1Zone15mn3hOPP_la...
#
#                                                value  value_mean  value_sd  \
# 0  [0.146255013309696, 0.0587914232823501, 0.0521...    0.029939  0.084975
# 1  [-0.265491804716187, -0.312459057858454, -0.31...   -0.096045  0.082211
# 2  [-0.0263628063556332, -0.0990584087337265, -0....    0.055655  0.082947
# 3  [-0.267030859173138, -0.326035551593807, -0.27...   -0.238760  0.074718
# 4  [-0.525083666165678, -0.481112008112693, -0.42...   -0.315395  0.068772
# 5  [-0.116359640392252, 0.0461876737689497, 0.060...    0.003471  0.085031
# 6  [-0.130749858508119, -0.107486337134019, -0.02...   -0.150524  0.076064
# 7  [0.287107013011435, 0.0465600780145065, 0.1760...    0.217018  0.079104
# 8  [0.0903876826491821, 0.0745974998203062, 0.022...    0.004897  0.077116
# 9  [0.490187671877486, 0.505683176654037, 0.49010...    0.491053  0.059645
#
#    foodrelatedbehaviorfinalinvcst  scaleVTD  midcumZ4secMorning  \
# 0                           False     False               False
# 1                            True     False               False
# 2                            True     False                True
# 3                            True     False               False
# 4                            True      True               False
# 5                           False     False                True
# 6                           False     False                True
# 7                           False      True               False
# 8                           False      True                True
# 9                           False      True               False
#
#    SleepingNotUppest  mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 0               True                                            True
# 1               True                                           False
# 2              False                                           False
# 3              False                                            True
# 4              False                                           False
# 5               True                                           False
# 6              False                                            True
# 7               True                                           False
# 8              False                                           False
# 9              False                                            True

# %%
df_plt = df_BLUP_var_summarized.pivot(index='HenID', columns='mvtvariable', values=['value_mean','value_sd']).reset_index()
df_plt.columns = ['_'.join(col) for col in df_plt.columns.values] #joining name from different index
df_plt.head(3)
for i in range(0,len(li_mvt)-1):
    for j in range(i+1, len(li_mvt)):
        mvtx = li_mvt[i]
        mvty = li_mvt[j]
        print(mvtx)
        print(mvty)
        cor_mvtx_mvty = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['value_mean'].iloc[0]
        print(cor_mvtx_mvty)
        sd_mvtx = df_sd_summarized[df_sd_summarized['var']==mvtx+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvtx)
        sd_mvty = df_sd_summarized[df_sd_summarized['var']==mvty+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvty)        
        slope = cor_mvtx_mvty*sd_mvtx*sd_mvty/(sd_mvtx*sd_mvtx)
        print(slope)
        plt.figure(figsize=(5,5))
        #ax = sns.scatterplot(data=df_plt, x='value_mean_'+mvtx,  y='value_mean_'+mvty)#,  size="size", sizes=(20, 200))
        plt.scatter(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(), color='r', s=5)
        plt.errorbar(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(),
                     xerr=df_plt['value_sd_'+mvtx].tolist(), yerr=df_plt['value_sd_'+mvty].tolist(),
                     fmt="o", color="r", alpha=0.2, ms=5)
        plt.xlabel(mvtx)
        plt.ylabel(mvty)
        x_min = min(df_plt['value_mean_'+mvtx].tolist())
        y_min = x_min*slope
        x_max = max(df_plt['value_mean_'+mvtx].tolist())
        y_max = x_max*slope
        plt.plot([x_min, x_max], [y_min, y_max], color='black')
        plt.text(x_min, min(df_plt['value_mean_'+mvty].tolist()), 'r = '+str(round(cor_mvtx_mvty,2)), fontsize=12)
        #plt.set_xlim([x_min, x_max])        
        plt.show();
# Out:
# foodrelatedbehaviorfinalinvcst
# scaleVTD
# -0.3153948925180862
# 0.16458820711830038
# 0.835996586388652
# -1.6019923791989517
# foodrelatedbehaviorfinalinvcst
# midcumZ4secMorning
# 0.055655497192255356
# 0.16458820711830038
# 0.15048089381417248
# 0.050885109630868175
# foodrelatedbehaviorfinalinvcst
# SleepingNotUppest
# -0.09604484498237852
# 0.16458820711830038
# 2.38688275884909
# -1.3928566850478985
# foodrelatedbehaviorfinalinvcst
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# -0.23876011189653354
# 0.16458820711830038
# 2.4052088487490964
# -3.4891195664407633
# scaleVTD
# midcumZ4secMorning
# 0.004896874108660782
# 0.835996586388652
# 0.15048089381417248
# 0.0008814461742600678
# scaleVTD
# SleepingNotUppest
# 0.21701826939838173
# 0.835996586388652
# 2.38688275884909
# 0.6196163644877005
# scaleVTD
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 0.49105337111182507
# 0.835996586388652
# 2.4052088487490964
# 1.412787961860352
# midcumZ4secMorning
# SleepingNotUppest
# 0.003470564313243134
# 0.15048089381417248
# 2.38688275884909
# 0.05504904917023285
# midcumZ4secMorning
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# -0.15052411293293416
# 0.15048089381417248
# 2.4052088487490964
# -2.4058996408107722
# SleepingNotUppest
# mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind
# 0.0299393493156181
# 2.38688275884909
# 2.4052088487490964
# 0.03016921867349568

# %%
maybe to add

# %% [markdown]
# # Select individuals to highlight in visuals

# %%
#select 5 hens to highlight within the plot: two most extremes intercept (min, max), two most extreme plasticity (min, max) 
#and one?

#Behavioural type
li = df_BLUP_int.sort_values('BLUPIntercept', ascending=True)['groupID'].tolist()
li_int = [li[-1], li[0]]
print(li_int)

#Plasticity
li1 = df_BLUP_RR[df_BLUP_RR['term']=='BLUP_slopes1'].sort_values('mean', ascending=True)['groupID'].tolist()
li2 = df_BLUP_RR[df_BLUP_RR['term']=='BLUP_slopes2'].sort_values('mean', ascending=True)['groupID'].tolist()
li_plasticity1 = [li1[0]] #for visibility purposes: does not add anything to the plot except removing visibility: li1[-1]
li_plasticity2 = [li2[-1], li2[0]]
print(li_plasticity1)
print(li_plasticity2)

#predictability
df_BLUP_var_summarized = df_BLUP_var.groupby('HenID')['Predictability'].agg(lambda x: list(x)).reset_index()
df_BLUP_var_summarized['Predictability_mean'] = df_BLUP_var_summarized['Predictability'].map(lambda x: np.mean(x))
df_BLUP_var_summarized['Predictability_sd'] = df_BLUP_var_summarized['Predictability'].map(lambda x: np.std(x))
display(df_BLUP_var_summarized.head(3))
li = df_BLUP_var_summarized.sort_values('Predictability_mean')['HenID'].tolist()
li_pred = [li[-1], li[0]]
print(li_pred)

#selected hens: for visibility purposes we cannot show all hens
li_hen_visual = list(set(li_int+li_plasticity2)) 
print('selected hens: %s' %' '.join(li_hen_visual))
# Out:
# ['hen_9', 'hen_145']
# ['hen_5']
# ['hen_69', 'hen_109']
#      HenID                                     Predictability  \
# 0   hen_10  [-1.0176055718243788, -1.1994922607609264, -1....
# 1  hen_101  [-1.1221725672194474, -1.5363625570416004, -1....
# 2  hen_102  [-0.8022388204168472, -0.6215303576634553, -0....
#
#    Predictability_mean  Predictability_sd
# 0            -1.038280           0.112738
# 1            -1.361887           0.156616
# 2            -0.635288           0.078090
# ['hen_145', 'hen_109']
# selected hens: hen_9 hen_145 hen_69 hen_109

# %%
#higher score means higher dispertion so we want brither for higher score
df_henorder = df_BLUP_var_summarized[df_BLUP_var_summarized['HenID'].isin(li_hen_visual)].sort_values(['Predictability_mean'], 
                                                                                              ascending=True)
display(df_henorder)
li_hen_order = df_henorder['HenID'].tolist()
# Out:
#       HenID                                     Predictability  \
# 5   hen_109  [-1.597481809223428, -1.9766772688133487, -1.9...
# 61   hen_69  [-1.2354341300122667, -1.4618116338604756, -1....
# 73    hen_9  [-0.6369065013091803, -0.9197935451853531, -0....
# 23  hen_145  [-0.5847526109949581, -0.5253454615899612, -0....
#
#     Predictability_mean  Predictability_sd
# 5             -1.695992           0.191910
# 61            -1.281980           0.139682
# 73            -0.747125           0.088016
# 23            -0.568843           0.070712

# %%
#choose color: https://matplotlib.org/stable/gallery/color/named_colors.html
#define the color based on the predictability for visual purposes: more predictable darker, less predictbale brighter
#'crimson','olive','orangered',
#li_nicecolor_brighter = ['blue','fuchsia','orange','lime','cyan','yellow'] #art
li_nicecolor_brighter = ['mediumblue','deeppink','goldenrod','green','cyan','yellow']

#exchange two colors for visual purpose, no rule to implement
#li_nicecolor_brighter = ['blue','fuchsia','orange','lime','cyan','yellow','crimson','olive'] #art
li_nicecolor_brighter = ['mediumblue','deeppink','goldenrod','green','cyan','yellow','crimson','olive'] #art
li_all_hen =  df_BLUP_RR['groupID'].unique()
pal_ = {henID:'black' for henID in li_all_hen}
pal_ = {'Other Hens':'black'}
for i,henID in enumerate(li_hen_order):
    pal_[henID] = li_nicecolor_brighter[i]

# %% [markdown]
# # Visualise Estimates

# %%
#behavioural type
df_plt = df_BLUP_int.sort_values(['BLUPIntercept'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
#hue_order = li_hen_visual + ['Other Hens']
plt.figure(figsize=(3.5,4.5))
ax = sns.boxplot(x='groupID', y='BLUPIntercept', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2, 
            ecolor=df_plt['color']);
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['BLUPIntercept'], yerr=df_plt_['sd'], fmt=' ', alpha=0.9, elinewidth=10,
ecolor=df_plt_['color']);
plt.xticks([]) #remove xlabel annotations
plt.xlabel('')
plt.ylabel('')
plt.title('Intercepts', size=15);
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_adapt,'BLUPs_intercepts.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['BLUPIntercept'], yerr=df_plt['sd'], fmt=' ', alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/354407454.py:14: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([]) #remove xlabel annotations

# %%
#plasticity
df_plt = df_BLUP_RR[df_BLUP_RR['term']=='BLUP_slopes1'].sort_values(['mean'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
plt.figure(figsize=(3.5,4.5))
ax = sns.boxplot(x='groupID', y='mean', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2, 
            ecolor=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['mean'], yerr=df_plt_['sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            ecolor=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('')
plt.ylabel('')
plt.title('Linear slope', size=15);
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_adapt,'BLUPS_linear_slope.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/4196866395.py:13: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([]) #remove xlabel annotations

# %%
#plasticity
df_plt = df_BLUP_RR[df_BLUP_RR['term']=='BLUP_slopes2'].sort_values(['mean'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
plt.figure(figsize=(3.5,4.5))
ax = sns.boxplot(x='groupID', y='mean', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2, 
            ecolor=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['mean'], yerr=df_plt_['sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            ecolor=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('')
plt.ylabel('')
plt.title('Quadratic slope', size=15);
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_adapt,'BLUPS_quadratic_slope.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:7: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/534138934.py:13: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([]) #remove xlabel annotations

# %%
#predictability
df_plt = df_BLUP_var_summarized.sort_values(['Predictability_mean']).copy()
df_plt[' '] = df_plt['HenID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
#hue_order = li_hen_visual + ['Other Hens']
plt.figure(figsize=(3.5,4.5))
ax = sns.boxplot(x='HenID', y='Predictability_mean', data=df_plt, color='grey');
ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2, 
            ecolor=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['HenID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['HenID'], df_plt_['Predictability_mean'], yerr=df_plt_['Predictability_sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            ecolor=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('HenID')
plt.ylabel('')
plt.title('Predictability', size=15);
plt.savefig(os.path.join(path_adapt,'BLUPS_predictability.png'), bbox_inches='tight')
plt.show();
df_BLUP_varorder = df_BLUP_var_summarized[df_BLUP_var_summarized['HenID'].isin(li_hen_visual)].sort_values(['Predictability_mean'], ascending=True).copy()
display(df_BLUP_varorder)
#li_orderedhenselected_pred = df_BLUP_varorder['HenID'].tolist()
#hens with higher rIIV are less predictable than individualswith lower rIIV (Fig )
#The most predictable individual (hen 39) has an average residual variance of 0.01 around its behavioral mean, whereas the 
#least predictable individual (hen 109) has an average residual variance of 0.27km
# Out:
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:8: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2,
# C:\Users\camil\AppData\Local\Temp/ipykernel_16656/1712250246.py:14: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.xticks([]) #remove xlabel annotations
#       HenID                                     Predictability  \
# 5   hen_109  [-1.597481809223428, -1.9766772688133487, -1.9...
# 61   hen_69  [-1.2354341300122667, -1.4618116338604756, -1....
# 73    hen_9  [-0.6369065013091803, -0.9197935451853531, -0....
# 23  hen_145  [-0.5847526109949581, -0.5253454615899612, -0....
#
#     Predictability_mean  Predictability_sd
# 5             -1.695992           0.191910
# 61            -1.281980           0.139682
# 73            -0.747125           0.088016
# 23            -0.568843           0.070712

# %% [markdown]
# # Visualise Raw & Predictions data

# %%
pal_all = {k.split(':')[0]:v for k,v in pal_.items()}
hue_order_all=[h.split(':')[0] for h in li_hen_visual]+['Other Hens']

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_adapt,'Prediction_RI.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.ylabel('PC1 (composite movement variable)')
plt.xlabel('time')
plt.text(28, 2.8, '─ ─ ─ RI predictions of PC1', color='black')
plt.ylim((-3,3))
plt.savefig(os.path.join(path_adapt,'Raw&predicionRI.png'), bbox_inches='tight')
# Out:
# Other Hens    3070
# hen_69          43
# hen_145         42
# hen_9           42
# hen_109         33
# Name: HenID , dtype: int64
# (3230, 36)
#      HenID  DIB CLASS  PenID  temperature_C_avg  tobeusedPCA  InitialWeight  \
# 0  hen_134   11  MEXP  pen10          11.500000            1           1112
# 1  hen_134   12  MEXP  pen10          10.166667            0           1112
# 2  hen_134   13  MEXP  pen10           9.000000            0           1112
#
#   Treatment  perc_duration_5_Zone  perc_duration_4_Zone  ...  cDIB  \
# 0      TRAN                   100                     0  ...     0
# 1      TRAN                    86                     0  ...     1
# 2      TRAN                   100                     0  ...     2
#
#    temperature_C_avg_scale      time     time2     time3  avgDIB_scale  \
# 0                 0.208097  0.000000  0.000000  0.000000     -0.367755
# 1                -0.211212  0.081155  0.006586  0.000534     -0.367755
# 2                -0.578107  0.162309  0.026344  0.004276     -0.367755
#
#    InitialWeight_scale  pred_pop  pred_HenID      HenID
# 0            -0.914296 -0.581911   -1.006008  Other Hens
# 1            -0.914296 -0.485739   -0.909836  Other Hens
# 2            -0.914296 -0.394108   -0.818205  Other Hens
#
# [3 rows x 36 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_adapt,'Prediction_RR_linear.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.ylabel('PC1 (composite movement variable)')
plt.xlabel('time')
plt.text(28, 2.8, '─ ─ ─ RS1 predictions of PC1', color='black')
plt.ylim((-3,3))
plt.savefig(os.path.join(path_adapt,'Raw&predictionRS1.png'), bbox_inches='tight')
# Out:
# Other Hens    3070
# hen_69          43
# hen_145         42
# hen_9           42
# hen_109         33
# Name: HenID , dtype: int64
# (3230, 36)
#      HenID  DIB CLASS  PenID  temperature_C_avg  tobeusedPCA  InitialWeight  \
# 0  hen_134   11  MEXP  pen10          11.500000            1           1112
# 1  hen_134   12  MEXP  pen10          10.166667            0           1112
# 2  hen_134   13  MEXP  pen10           9.000000            0           1112
#
#   Treatment  perc_duration_5_Zone  perc_duration_4_Zone  ...  cDIB  \
# 0      TRAN                   100                     0  ...     0
# 1      TRAN                    86                     0  ...     1
# 2      TRAN                   100                     0  ...     2
#
#    temperature_C_avg_scale      time     time2     time3  avgDIB_scale  \
# 0                 0.208097  0.000000  0.000000  0.000000     -0.367755
# 1                -0.211212  0.081155  0.006586  0.000534     -0.367755
# 2                -0.578107  0.162309  0.026344  0.004276     -0.367755
#
#    InitialWeight_scale  pred_pop  pred_HenID      HenID
# 0            -0.914296 -0.593008   -1.840952  Other Hens
# 1            -0.914296 -0.494215   -1.706140  Other Hens
# 2            -0.914296 -0.400097   -1.576002  Other Hens
#
# [3 rows x 36 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_adapt,'Prediction_RR_quadratic.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)

#add max error
df_PL = df_PL.sort_values(['DIB'], ascending=False)
df_ = df_PL.groupby('HenID')[['pred_HenID','PC1']].agg(lambda x: list(x)).reset_index()
df_['diff'] = df_.apply(lambda x: [abs(x['pred_HenID'][i]-x['PC1'][i]) for i in range(0,len(x['pred_HenID']))], axis=1)
df_['max_error'] = df_['diff'].map(lambda x: max(x))
display(df_.head(3))
df_PL['max_error'] = df_PL['HenID'].map(lambda x: df_[df_['HenID']==x]['max_error'].values[0])
for henID in ['hen_109', 'hen_145']:
    y = df_PL[df_PL['HenID ']==henID]['pred_HenID']
    err = df_PL[df_PL['HenID ']==henID]['max_error']
    x = df_PL[df_PL['HenID ']==henID]['DIB']
    plt.plot(x, y-err, color=pal_[henID], alpha=0.2)
    plt.plot(x, y+err, color=pal_[henID], alpha=0.2)
    plt.fill_between(x, y-err, y+err, alpha=0.05, color=pal_[henID])
#plt.text(11, 1.4, '─ ─ ─ estimated slopes', color='black')
#remove all borders

#plt.title('Individual plasticity');
plt.grid()
plt.ylabel('PC1 (composite movement variable)')
plt.xlabel('time')
plt.text(28, 2.8, '─ ─ ─ RS2 predictions of PC1', color='black')
plt.ylim((-3,3))
plt.savefig(os.path.join(path_adapt,'Raw&predictionRS2.png'), bbox_inches='tight')
# Out:
# Other Hens    3070
# hen_69          43
# hen_145         42
# hen_9           42
# hen_109         33
# Name: HenID , dtype: int64
# (3230, 36)
#      HenID  DIB CLASS  PenID  temperature_C_avg  tobeusedPCA  InitialWeight  \
# 0  hen_134   11  MEXP  pen10          11.500000            1           1112
# 1  hen_134   12  MEXP  pen10          10.166667            0           1112
# 2  hen_134   13  MEXP  pen10           9.000000            0           1112
#
#   Treatment  perc_duration_5_Zone  perc_duration_4_Zone  ...  cDIB  \
# 0      TRAN                   100                     0  ...     0
# 1      TRAN                    86                     0  ...     1
# 2      TRAN                   100                     0  ...     2
#
#    temperature_C_avg_scale      time     time2     time3  avgDIB_scale  \
# 0                 0.208097  0.000000  0.000000  0.000000     -0.367755
# 1                -0.211212  0.081155  0.006586  0.000534     -0.367755
# 2                -0.578107  0.162309  0.026344  0.004276     -0.367755
#
#    InitialWeight_scale  pred_pop  pred_HenID      HenID
# 0            -0.914296 -0.631429   -1.920829  Other Hens
# 1            -0.914296 -0.530077   -1.775826  Other Hens
# 2            -0.914296 -0.433534   -1.635993  Other Hens
#
# [3 rows x 36 columns]
#      HenID                                         pred_HenID  \
# 0   hen_10  [0.429243125485483, 0.410231574229223, 0.36487...
# 1  hen_101  [-0.0318597065066978, 0.0536528755862544, 0.11...
# 2  hen_102  [-1.10377691058963, -1.08014134066411, -1.0837...
#
#                                                  PC1  \
# 0  [0.0617182970403908, 0.535233840014037, 0.6118...
# 1  [0.722654827284217, 0.693184418813745, 0.54033...
# 2  [-0.783997251768188, -0.999198002587304, -1.10...
#
#                                                 diff  max_error
# 0  [0.3675248284450922, 0.12500226578481394, 0.24...   1.043797
# 1  [0.7545145337909148, 0.6395315432274906, 0.429...   1.321515
# 2  [0.319779658821442, 0.08094333807680609, 0.019...   0.498763

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_adapt,'Prediction_RR_quadratic.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)

#plt.title('Individual plasticity');
plt.grid()
plt.ylabel('PC1 (composite movement variable)')
plt.xlabel('time')
plt.text(28, 2.8, '─ ─ ─ RS2 predictions of PC1', color='black')
plt.ylim((-3,3))
plt.savefig(os.path.join(path_adapt,'Raw&predictionRS2_nopredictabiltiy.png'), bbox_inches='tight')
# Out:
# Other Hens    3070
# hen_69          43
# hen_145         42
# hen_9           42
# hen_109         33
# Name: HenID , dtype: int64
# (3230, 36)
#      HenID  DIB CLASS  PenID  temperature_C_avg  tobeusedPCA  InitialWeight  \
# 0  hen_134   11  MEXP  pen10          11.500000            1           1112
# 1  hen_134   12  MEXP  pen10          10.166667            0           1112
# 2  hen_134   13  MEXP  pen10           9.000000            0           1112
#
#   Treatment  perc_duration_5_Zone  perc_duration_4_Zone  ...  cDIB  \
# 0      TRAN                   100                     0  ...     0
# 1      TRAN                    86                     0  ...     1
# 2      TRAN                   100                     0  ...     2
#
#    temperature_C_avg_scale      time     time2     time3  avgDIB_scale  \
# 0                 0.208097  0.000000  0.000000  0.000000     -0.367755
# 1                -0.211212  0.081155  0.006586  0.000534     -0.367755
# 2                -0.578107  0.162309  0.026344  0.004276     -0.367755
#
#    InitialWeight_scale  pred_pop  pred_HenID      HenID
# 0            -0.914296 -0.631429   -1.920829  Other Hens
# 1            -0.914296 -0.530077   -1.775826  Other Hens
# 2            -0.914296 -0.433534   -1.635993  Other Hens
#
# [3 rows x 36 columns]

# %% [raw]
# We observe a general positive trend in the average vertical travel distance per hour as number of days post-transfer increases, but also that variance in the average vertical travel distance per hour is greater at the first days post-transferd compared to the 40th day post-transfer onward and there appears to be some non-linearity, and therefore we will investigate whether the fixed effect of number of days post-transfer on the average vertical travel distance per hour could be modelled with either a linear model or a quadratic model.

# %% [markdown]
# #plot plasticity over time
# #TODO: add pred_HenID1.4
# sns.lineplot(x='DIB', y='pred_HenID1.4', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all);
# plt.title('Individual plasticity');
# plt.savefig(os.path.join(path_adapt,'EstimatedPlastictyOvertime.png'), bbox_inches='tight')

# %%
#all in once
#change order of hen just for visual purpose
df_PL = df_PL.sort_values(['HenID '], ascending=False)
#behavioural type
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
g = sns.FacetGrid(df_PL, row="HenID ", hue="HenID ", aspect=8, height=0.8, palette=pal_all)
#densities
g.map(sns.kdeplot, "PC1", fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "PC1", color="w", lw=2)
#Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(-0.3, .2, label, fontweight="bold", fontsize=16, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "PC1")
#Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.8)

#remove axes info that don't play well with overlap
g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True);
plt.xlabel('PC1 (composite movement variable)')
plt.savefig(os.path.join(path_adapt,'Rawdensity.png'), bbox_inches='tight') #, pad_inches=-0.1)
plt.show()

# %% [markdown]
# # Merge all individual information

# %%
display(df_BLUP_var_summarized.head(3))
df_ = df_BLUP_RR.pivot(columns='term', index='groupID',values='mean').reset_index()
display(df_.head(3))
df_BLUP_RRall = pd.merge(df_[['groupID','BLUP_slopes1','BLUP_slopes2']], df_BLUP_var_summarized, left_on='groupID', right_on='HenID', how='outer')
print(df_BLUP_RRall.shape)
display(df_BLUP_RRall.head(3))
# Out:
#      HenID                                     Predictability  \
# 0   hen_10  [-1.0176055718243788, -1.1994922607609264, -1....
# 1  hen_101  [-1.1221725672194474, -1.5363625570416004, -1....
# 2  hen_102  [-0.8022388204168472, -0.6215303576634553, -0....
#
#    Predictability_mean  Predictability_sd
# 0            -1.038280           0.112738
# 1            -1.361887           0.156616
# 2            -0.635288           0.078090
# term  groupID  BLUP_int  BLUP_slopes1  BLUP_slopes2
# 0      hen_10 -0.586199     -0.446985      0.208133
# 1     hen_101  1.332849     -0.524468      0.032831
# 2     hen_102 -1.050846     -0.512248      0.141956
# (80, 7)
#    groupID  BLUP_slopes1  BLUP_slopes2    HenID  \
# 0   hen_10     -0.446985      0.208133   hen_10
# 1  hen_101     -0.524468      0.032831  hen_101
# 2  hen_102     -0.512248      0.141956  hen_102
#
#                                       Predictability  Predictability_mean  \
# 0  [-1.0176055718243788, -1.1994922607609264, -1....            -1.038280
# 1  [-1.1221725672194474, -1.5363625570416004, -1....            -1.361887
# 2  [-0.8022388204168472, -0.6215303576634553, -0....            -0.635288
#
#    Predictability_sd
# 0           0.112738
# 1           0.156616
# 2           0.078090

# %%
display(df_BLUP_int.head(3))
df_BLUP_RRall = pd.merge(df_BLUP_RRall, df_BLUP_int[['groupID','BLUPIntercept']], on='groupID', how='outer')
print(df_BLUP_RRall.shape)
df_BLUP_RRall.head(3)
# Out:
#   groupFctr  groupID         term  BLUPIntercept    median        sd
# 0     HenID   hen_10  (Intercept)      -0.462990 -0.457868  0.192958
# 1     HenID  hen_101  (Intercept)       0.504909  0.504094  0.186326
# 2     HenID  hen_102  (Intercept)      -1.371668 -1.365408  0.170115
# (80, 8)
#    groupID  BLUP_slopes1  BLUP_slopes2    HenID  \
# 0   hen_10     -0.446985      0.208133   hen_10
# 1  hen_101     -0.524468      0.032831  hen_101
# 2  hen_102     -0.512248      0.141956  hen_102
#
#                                       Predictability  Predictability_mean  \
# 0  [-1.0176055718243788, -1.1994922607609264, -1....            -1.038280
# 1  [-1.1221725672194474, -1.5363625570416004, -1....            -1.361887
# 2  [-0.8022388204168472, -0.6215303576634553, -0....            -0.635288
#
#    Predictability_sd  BLUPIntercept
# 0           0.112738      -0.462990
# 1           0.156616       0.504909
# 2           0.078090      -1.371668

# %% [markdown]
# # Dataframe for stats ~ health

# %%
li_selected_hens = pickle.load(open(os.path.join(path_adapt, 'li_selected_hens.pkl'), 'rb'))
print(len(li_selected_hens))
# Out:
# 80

# %%
#HA&KBF&weight
df_HA = pd.read_csv(os.path.join(path_extracted_data, 'df_all_HA.csv'), sep=';', parse_dates=['date'], dayfirst=True) 
print(df_HA.shape)
df_HA = df_HA[df_HA['HenID'].isin(li_selected_hens)]
#display(df_HA.groupby(['HAID'])['date'].agg(lambda x: set(x)).reset_index())
display(df_HA['HAID'].value_counts())
#info on date
display(df_HA.groupby(['HAID','date','WOA','DOA'])['HenID'].count().reset_index())
print(df_HA.shape)
df_HA.head(3)
# Out:
# (846, 58)
# HA2    80
# HA5    80
# HA1    80
# HA3    80
# HA4    80
# Name: HAID, dtype: int64
#   HAID       date   WOA    DOA  HenID
# 0  HA1 2020-11-23  25.0  173.0     80
# 1  HA2 2021-01-04  31.0  215.0     80
# 2  HA3 2021-02-01  35.0  243.0     80
# 3  HA4 2021-04-12  45.0  313.0     80
# 4  HA5 2021-07-25  60.0  417.0     80
# (400, 58)
#    Person_toe   Time  PenID FocalLegringName BirdType  CombPecks Toes  \
# 4           C  08:58  pen12         32orange   normal       25.0  NaN
# 6           C    NaN   pen5           41grey   normal       20.0    0
# 14          M  10:23   pen8          71black   normal       25.0  NaN
#
#     RFPododermatitis  RFBumblefoot  RFinjuries  ...  \
# 4                0.0           0.0         0.0  ...
# 6                0.0           0.0         0.0  ...
# 14               0.0           0.0         0.0  ...
#
#                                       actual_path_img  imageID  random_order1  \
# 4   G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...     68.0          319.0
# 6   G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...     42.0          192.0
# 14  G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...    311.0          255.0
#
#     severity  has_gap        BirdID uncertainty (0:certain:1 random)  \
# 4          2      0.0  32orange12sb                              NaN
# 6         84      0.0    41grey5gwb                              NaN
# 14        12      0.0    71black8ps                              NaN
#
#    Unnamed: 9                              Info backpack
# 4         NaN  ['', '32', 'orange', '12', 'sb']       sb
# 6         NaN    ['', '41', 'grey', '5', 'gwb']      gwb
# 14        NaN    ['', '71', 'black', '8', 'ps']       ps
#
# [3 rows x 58 columns]

# %%
##### to add info on the first week
df_MVT_ALL = pd.read_csv(os.path.join(path_extracted_data, id_run+'_daily_ALL_variables_verified_earlymvt.csv'), sep=';', 
                     parse_dates=['level'], dayfirst=True) 
print(df_MVT_ALL.shape)
df_MVT_ALL = df_MVT_ALL[df_MVT_ALL['HenID'].isin(li_selected_hens)]
#restrict to the adaptability study timeframe
df_MVT_ALL = df_MVT_ALL[df_MVT_ALL['level']<=config.max_date_adaptability]
print(df_MVT_ALL.shape)
#make sure we have their mvt
df_MVT_ALL = df_MVT_ALL[~df_MVT_ALL['perc_duration_5_Zone'].isnull()]
print(df_MVT_ALL.shape)
df_MVT_ALL.head(3)
# Out:
# (42300, 63)
# (3750, 63)
# (3750, 63)
#        HenID  PenID CLASS    TagID FocalLegringName  R-Pen  \
# 114  hen_134  pen10  MEXP  tag_122          22black    4.0
# 115  hen_134  pen10  MEXP  tag_122          22black    4.0
# 116  hen_134  pen10  MEXP  tag_122          22black    4.0
#
#         InitialStartDate Treatment      level  DIB  ...  \
# 114  2020-06-10 00:00:00      TRAN 2020-09-30    1  ...
# 115  2020-06-10 00:00:00      TRAN 2020-10-01    2  ...
# 116  2020-06-10 00:00:00      TRAN 2020-10-02    3  ...
#
#      percChaoticTransition  night_Max_duration_zones  is_mvt_night  \
# 114                   18.0                    5_Zone           0.0
# 115                    0.0                    5_Zone           0.0
# 116                    0.0                    3_Zone           1.0
#
#      empproba_3_Zone empproba_4_Zone  empproba_2_Zone  in_WG_15mnAfterOpening  \
# 114             80.0            20.0            100.0                     NaN
# 115              0.0             0.0              0.0                     NaN
# 116             50.0            25.0            100.0                     NaN
#
#      Max_duration_WG_h  perc_1_Zone_while_WG_open  SleepingHeight
# 114                NaN                        NaN               3
# 115                NaN                        NaN               3
# 116                NaN                        NaN               1
#
# [3 rows x 63 columns]

# %%
##### mvt since DIB 11
df_MVT = pd.read_csv(os.path.join(path_adapt,'df_MVT_4individuality.csv'), sep=';')
print(df_MVT.shape)
df_MVT.head(3)
# Out:
# (3230, 25)
#      HenID  DIB CLASS  PenID  temperature_C_avg  tobeusedPCA  InitialWeight  \
# 0  hen_134   11  MEXP  pen10          11.500000            1         1112.0
# 1  hen_134   12  MEXP  pen10          10.166667            0         1112.0
# 2  hen_134   13  MEXP  pen10           9.000000            0         1112.0
#
#   Treatment  perc_duration_5_Zone  perc_duration_4_Zone  ...  \
# 0      TRAN                 100.0                   0.0  ...
# 1      TRAN                  86.0                   0.0  ...
# 2      TRAN                 100.0                   0.0  ...
#
#    nbr_stays_3_Zone_perh  nbr_stays_5_Zone_perh  nbr_stays_1_Zone_perh  \
# 0                    0.0                    0.1                    0.0
# 1                    0.1                    0.2                    0.0
# 2                    0.0                    0.1                    0.0
#
#    in_WG_15mnAfterOpening  SleepingHeight  vertical_travel_distance_perh  \
# 0                       0               3                            0.0
# 1                       0               3                            0.6
# 2                       0               3                            0.0
#
#    DIB_startat11     avgDIB  severity  Feathers
# 0              0  22.357143        34      73.0
# 1              1  22.357143        34      73.0
# 2              2  22.357143        34      73.0
#
# [3 rows x 25 columns]

# %%
df_MVT['SleepingHeight'].value_counts()
# Out:
# 3    2203
# 1     610
# 2     398
# 0      19
# Name: SleepingHeight, dtype: int64

# %%
df_MVT_ALL.columns
# Out:
# Index(['HenID', 'PenID', 'CLASS', 'TagID', 'FocalLegringName', 'R-Pen',
#        'InitialStartDate', 'Treatment', 'level', 'DIB', 'WIB', 'DOA', 'WOA',
#        'verification_daily_total_duration', 'TrackingSystemID',
#        'perc_duration_2_Zone', 'perc_duration_3_Zone', 'perc_duration_4_Zone',
#        'perc_duration_5_Zone', 'duration_1_Zone', 'duration_2_Zone',
#        'duration_3_Zone', 'duration_4_Zone', 'duration_5_Zone',
#        'nbr_stays_1_Zone', 'nbr_stays_2_Zone', 'nbr_stays_3_Zone',
#        'nbr_stays_4_Zone', 'nbr_stays_5_Zone', 'nbr_stays_1_Zone_perh',
#        'nbr_stays_2_Zone_perh', 'nbr_stays_3_Zone_perh',
#        'nbr_stays_4_Zone_perh', 'nbr_stays_5_Zone_perh',
#        'ratio_percdur_percstays_2_Zone', 'ratio_percdur_percstays_3_Zone',
#        'ratio_percdur_percstays_4_Zone', 'ratio_percdur_percstays_5_Zone',
#        'latency_2_Zone_h', 'latency_3_Zone_h', 'latency_4_Zone_h',
#        'latency_5_Zone_h', 'latency_since15mnnestbox_h',
#        'Total_number_transition', 'nbr_stays_total', 'distribution_entropy',
#        'Total_number_zone', 'Max_duration_zones', 'vertical_travel_distance',
#        'vertical_travel_distance_perh', 'activity_5percentile_h',
#        'activity_50percentile_h', 'activity_95percentile_h',
#        'percChaoticTransition', 'night_Max_duration_zones', 'is_mvt_night',
#        'empproba_3_Zone', 'empproba_4_Zone', 'empproba_2_Zone',
#        'in_WG_15mnAfterOpening', 'Max_duration_WG_h',
#        'perc_1_Zone_while_WG_open', 'SleepingHeight'],
#       dtype='object')

# %%
#################### initialweight ####################
df_4stat = df_MVT[['HenID','InitialWeight']].drop_duplicates()
#note: InitialWeight: have same value all the time, so mean/median is good too
print(df_4stat.shape)
df_4stat.head(3)

#################### add nbr days within first three without mvt ####################
m = df_MVT_ALL['DIB'].min()
print(m)
df_nomvt = df_MVT_ALL[df_MVT_ALL['DIB'].isin([m,m+1,m+2])].groupby('HenID')[['Total_number_zone']].agg(lambda x: list(x)).reset_index()
df_nomvt['nbr_daysnomvt_over_3days'] = df_nomvt['Total_number_zone'].agg(lambda x: sum([i==1 for i in x]))
display(df_nomvt['nbr_daysnomvt_over_3days'].value_counts())
print(df_nomvt.shape)
df_nomvt.head(3)
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_nomvt[['HenID','nbr_daysnomvt_over_3days']],  on='HenID', how='outer')
df_4stat['atleast1day_nomvt'] = df_4stat['nbr_daysnomvt_over_3days'].map(lambda x: x!=0)
display(df_4stat['atleast1day_nomvt'].value_counts())
print(df_4stat.shape)

df_nomvt = df_MVT_ALL[df_MVT_ALL['DIB'].isin([m,m+1,m+2])].groupby('HenID')[['vertical_travel_distance_perh']].agg(lambda x: np.mean(x)).reset_index()
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_nomvt[['HenID','vertical_travel_distance_perh']],  on='HenID', how='outer')
print(df_4stat.shape)


#################### add BLUP estimates ####################
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_BLUP_RRall[['HenID','BLUPIntercept','BLUP_slopes1','BLUP_slopes2','Predictability_mean']], on='HenID', how='inner')
print(df_4stat.shape)

#################### add HA ####################
df_4statmodel = pd.merge(df_4stat, df_HA[df_HA['HAID']=='HA5'][['HenID','PenID',
                                                'CLASS','Treatment','severity','weight','Feathers','HAID']], on='HenID',how='inner')
#df_4statmodel.to_csv(os.path.join(path_adapt,'df_MVT_4stat.csv'), index=False, sep=';')
print(df_4statmodel.shape)
display(df_4statmodel['HAID'].value_counts())
df_4statmodel.head(3)

#################### save ####################
#df_4statmodel.to_csv(os.path.join(path_adapt,'df_MVT_4stat.csv'), index=False, sep=';')
print(df_4statmodel.shape)
df_4statmodel.head(3)
# Out:
# (80, 2)
# 1
# 0    52
# 1    16
# 2     7
# 3     5
# Name: nbr_daysnomvt_over_3days, dtype: int64
# (80, 3)
# (80, 2)
# False    52
# True     28
# Name: atleast1day_nomvt, dtype: int64
# (80, 4)
# (80, 4)
# (80, 5)
# (80, 5)
# (80, 9)
# (80, 16)
# HA5    80
# Name: HAID, dtype: int64
# (80, 16)
#      HenID  InitialWeight  nbr_daysnomvt_over_3days  atleast1day_nomvt  \
# 0  hen_134         1112.0                         1               True
# 1  hen_138         1244.0                         0              False
# 2  hen_139         1350.0                         0              False
#
#    vertical_travel_distance_perh  BLUPIntercept  BLUP_slopes1  BLUP_slopes2  \
# 0                       0.907407      -0.423952      0.542737     -0.028174
# 1                       2.097222       0.545032     -0.925662      0.244716
# 2                       1.629630      -0.024258     -0.774272      0.043529
#
#    Predictability_mean  PenID  CLASS Treatment  severity  weight   Feathers  \
# 0            -0.869390  pen10   MEXP      TRAN        34  1771.7  73.000000
# 1            -0.840499  pen10   MEXP      TRAN        44  2100.5  80.000000
# 2            -1.078165  pen10  Other      TRAN        30  2038.7  73.666667
#
#   HAID
# 0  HA5
# 1  HA5
# 2  HA5

# %%
(16+7+5)/(52+16+7+5)*100
# Out:
# 35.0

# %% [markdown]
# ## Correlations

# %%
#with nbr_daysnomvt_over_3days
li_mvtvar = ['BLUPIntercept','BLUP_slopes1','BLUP_slopes2','Predictability_mean']
li_df = []
for v1 in li_mvtvar:
    coeff, pval = pearsonr(df_4statmodel[v1].tolist(), df_4statmodel['nbr_daysnomvt_over_3days'].tolist())
    li_df.append({'coeff':coeff, 'pval':pval,'var1':v1,'var2':'nbr_daysnomvt_over_3days'})
df_corr = pd.DataFrame(li_df)
df_corr
# Out:
#       coeff      pval                 var1                      var2
# 0 -0.356793  0.001160        BLUPIntercept  nbr_daysnomvt_over_3days
# 1  0.119815  0.289776         BLUP_slopes1  nbr_daysnomvt_over_3days
# 2 -0.024131  0.831744         BLUP_slopes2  nbr_daysnomvt_over_3days
# 3 -0.127844  0.258425  Predictability_mean  nbr_daysnomvt_over_3days

# %%
#with Predictability_mean
li_mvtvar = ['BLUPIntercept','BLUP_slopes1','BLUP_slopes2','nbr_daysnomvt_over_3days']
li_df = []
for v1 in li_mvtvar:
    coeff, pval = pearsonr(df_4statmodel[v1].tolist(), df_4statmodel['Predictability_mean'].tolist())
    li_df.append({'coeff':coeff, 'pval':pval,'var1':v1,'var2':'Predictability_mean'})
df_corr = pd.DataFrame(li_df)
df_corr
# Out:
#       coeff      pval                      var1                 var2
# 0 -0.093410  0.409862             BLUPIntercept  Predictability_mean
# 1 -0.222032  0.047766              BLUP_slopes1  Predictability_mean
# 2  0.215872  0.054459              BLUP_slopes2  Predictability_mean
# 3 -0.127844  0.258425  nbr_daysnomvt_over_3days  Predictability_mean

# %% [markdown]
# # Visualise raw data

# %%
df_rawmvt = pd.read_csv(os.path.join(path_extracted_data, id_run+'_CLEANEDDATA.csv'), sep=';', parse_dates=['Timestamp','date'],
                dayfirst=True) 
print(df_rawmvt.shape)
df_rawmvt.head(3)
# Out:
# (2681720, 18)
#    HenID PenID system    Zone  model_prediction           Timestamp  \
# 0  hen_1  pen9  8 - 9  2_Zone               1.0 2020-09-29 09:50:00
# 1  hen_1  pen9  8 - 9  3_Zone               1.0 2020-09-29 17:56:25
# 2  hen_1  pen9  8 - 9  5_Zone               1.0 2020-09-30 09:55:59
#
#         date     next_record_date         duration previous_record_date  \
# 0 2020-09-29  2020-09-29 17:56:25  0 days 08:06:25                  NaN
# 1 2020-09-29  2020-09-30 09:55:59  0 days 02:52:35  2020-09-29 09:50:00
# 2 2020-09-30  2020-09-30 11:34:30  0 days 01:32:11  2020-09-30 09:51:57
#
#   previous_duration next_zone previous_zone previous_previous_zone  \
# 0               NaN    3_Zone           NaN                    NaN
# 1   0 days 08:06:25    3_Zone        2_Zone                    NaN
# 2   0 days 00:04:02    5_Zone        3_Zone                 3_Zone
#
#    correction_is_consecutive_equal_initial_zone  is_WG_open  duration_mn  \
# 0                                         False       False   486.416667
# 1                                         False       False   959.566667
# 2                                         False       False    98.516667
#
#    is_day
# 0    True
# 1   False
# 2    True

# %%
#first observation of each week per bird 
df_4plt = df_MVT_ALL.groupby(['WIB','HenID'])[['DIB','level']].agg(lambda x: min(list(x))).reset_index()
print(df_4plt.shape)
display(df_4plt.head(3))
df_4plt = df_4plt.groupby(['HenID'])['level'].agg(lambda x: list(x)).reset_index()
dico_hen_DIB = dict(zip(df_4plt['HenID'].tolist(), df_4plt['level'].tolist()))
dico_hen_DIB
# Out:
# (640, 4)
#    WIB    HenID  DIB      level
# 0    1   hen_10    1 2020-09-30
# 1    1  hen_101    1 2020-09-30
# 2    1  hen_102    1 2020-09-30
# {'hen_10': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_101': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_102': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_106': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_107': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_109': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_112': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_116': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_118': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_119': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_124': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_127': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_128': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_13': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_134': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_136': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_137': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_138': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_139': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_14': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_140': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_143': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_144': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_145': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_147': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_149': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_150': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_151': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_153': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-16 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_155': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_158': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_17': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_18': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_19': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_2': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_20': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_21': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_23': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_24': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_25': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_26': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_28': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_3': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_32': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_4': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_42': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_48': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_5': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_51': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_56': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_57': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_58': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_59': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_6': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_60': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_61': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_64': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_65': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_66': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_67': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_68': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_69': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_7': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_73': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_76': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_78': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_79': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_8': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_80': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_83': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_84': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_85': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-10 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_87': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_9': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_90': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_92': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_95': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_97': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_98': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')],
#  'hen_99': [Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-10-07 00:00:00'),
#   Timestamp('2020-10-15 00:00:00'),
#   Timestamp('2020-10-21 00:00:00'),
#   Timestamp('2020-10-28 00:00:00'),
#   Timestamp('2020-11-04 00:00:00'),
#   Timestamp('2020-11-11 00:00:00'),
#   Timestamp('2020-11-18 00:00:00')]}

# %%
df_MVT_ALL.groupby(['WIB'])['DIB'].agg(lambda x: set(x)).reset_index() #--> remove week 8?
# Out:
#    WIB                           DIB
# 0    1         {1, 2, 3, 4, 5, 6, 7}
# 1    2           {8, 11, 12, 13, 14}
# 2    3      {16, 17, 18, 19, 20, 21}
# 3    4  {22, 23, 24, 25, 26, 27, 28}
# 4    5  {32, 33, 34, 35, 29, 30, 31}
# 5    6  {36, 37, 38, 39, 40, 41, 42}
# 6    7  {43, 44, 45, 46, 47, 48, 49}
# 7    8          {50, 51, 52, 53, 54}

# %%
c = len(li_hen_visual)
#remove week 1 as not used in estimating individual estimates
li_date = df_MVT_ALL[df_MVT_ALL['WIB']!=1]['WIB'].unique()
l = len(li_date)
img_w = 3 #shape[1]
img_h = 1 #shape[0]
dico_zone_order = {'1_Zone':0, '2_Zone':1, '3_Zone':2, '4_Zone':3, '5_Zone':4} #to sort the yaxis
i = 0
fig = plt.figure(figsize=(int(c*img_w), int(l*img_h)))
for x in tqdm.tqdm(range(len(li_date))):
    for henID in li_hen_visual:
        d = dico_hen_DIB[henID][x]
        plt.subplot(l,c,i+1)
        i = i+1
        #keep the previous day to have a full time serie (not missing info before any transitions occured that day)
        #-8 for hens that did not moved during several consecutive days
        df_plt = df_rawmvt[((d-dt.timedelta(hours=24*8))<=df_rawmvt['date'])&(df_rawmvt['date']<=d)\
                           &(df_rawmvt['HenID']==henID)].copy()
        df_plt = df_plt.sort_values(['Timestamp']).copy()
        Daterange = pd.date_range(start=d-dt.timedelta(hours=10), end=d+dt.timedelta(hours=24), freq='S') 
        df_plt.set_index('Timestamp', inplace=True)
        df_plt_ = df_plt.reindex(Daterange, method='ffill').reset_index()
        df_plt_.rename(columns={'index':'Timestamp'}, inplace=True)
        #add date again, as the reindexing also extended the date
        df_plt_['date'] = df_plt_['Timestamp'].map(lambda x: dt.datetime.date(x))
        #keep only the date of interest
        df_plt_ = df_plt_[df_plt_['date']==dt.datetime.date(d)]
        #put xlabel into numbers for the ploting
        df_plt_['Zone'] = df_plt_['Zone'].map(lambda x: int(dico_zone_order[x]))    
        plt.plot(df_plt_['Timestamp'].tolist(), df_plt_['Zone'].tolist(), linewidth=1, color=pal_[henID])
        #add title on the top figure only
        if i<=c:
            plt.title(henID, size=15, color=pal_[henID]) #as small verification
        #remove x and y axis annotations
        plt.xticks([])
        plt.yticks([])
        #except: y-axis info on the right figures only
        if i%c==1:
            plt.yticks([0,1,2,3,4], ['Winter garden', 'Litter', 'Lower perch','Nestbox','Top floor'])
            plt.yticks(fontsize=9.8)
        #except: x-axis info on the bottom figures only
        if i>(l*c-c):
            li_hour = pd.date_range(start = d,  end = d+dt.timedelta(days=1), freq = '4H') #xlabel: every 4h for readibility
            plt.xticks(li_hour, [str(i.hour)+'h' for i in li_hour], fontsize=10)      
            plt.yticks(fontsize=9.8)
        plt.ylim(0, 4.2)     
plt.savefig(os.path.join(path_adapt, 'Rawdata.png'), bbox_inches='tight', dpi=400)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:47<00:00,  6.77s/it]
