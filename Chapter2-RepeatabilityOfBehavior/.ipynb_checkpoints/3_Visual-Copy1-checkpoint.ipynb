# %%
#basic package
import tqdm
import os
import numpy as np
import pandas as pd
import sys
import time
import glob
import datetime as dt
import itertools
import math
import random
import pickle
from scipy import stats
from numpy.linalg import eig #eigenvector decomposition

#plot
import matplotlib.pyplot as plt
import seaborn as sns
from  matplotlib.colors import LinearSegmentedColormap  # to define our own palette for plots
from matplotlib import pyplot #barplot
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\camil\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\camil\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
PACKAGE_PARENT = '../'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))
import config_origins as config

# %% [markdown]
# # Define parameters

# %%
#should be consistent across all notebooks
#ADD YOUR PATH TO SAVE OUTPUT (e.g.: 'G:\\VPHI\\Welfare\\2- Research Projects\\OFHE2.OriginsE2\\DataOutput\\')
path_extracted_data = 'TO ADD'
#ADD A NAME in case you want multiple run with all output saved each time
saving_name = 'TO ADD'
#choose better naming of behaviour (different names from the behavioural syndrome csv file than repeatbatility, so that 4 of the 
#behaviours have to be defined two times
dico_mvt_name = {'scalefoodsameDurTimingr50final':'fresh food experience index',
                 'scaleverticaltraveldistancefulllightperinsideh':'vertical travelled distance',
                 'midcumZ4hMorning':'mid-nestbox zone usage',
                 'SleepingUppest':'has slept on top tier',
                 'WentinWG':'has been outside',
                'food_sameDurTiming_r50_final':'fresh food experience index',
                'Sleeping_Uppest':'has slept on top tier',
                'vertical_travel_distance_fulllight_perinsideh':'vertical travelled distance',
                'mid_cum_Z4_h_Morning':'mid-nestbox zone usage'}

# %%
#TO DELETE WHEN SENDING TO PUBLICATION
path_extracted_data = config.path_extracted_data
saving_name = 'ALLOBS'

# %% [markdown]
# # Behavioural syndrome

# %% [markdown]
# ### Download mean and CI estimates

# %%
df_IC = pd.read_csv(os.path.join(path_extracted_data,saving_name+'_df_CI_BRMS_BS_pred_allvar_FINAL.csv'), sep=',')
print(df_IC.shape) 
display(df_IC.head(3))

df_mean = pd.read_csv(os.path.join(path_extracted_data,saving_name+'_df_mean_BRMS_BS_pred_allvar_FINAL.csv'), sep=',')
print(df_mean.shape) 
display(df_mean.head(3))

#merge both estimates and the CI
df = pd.merge(df_mean, df_IC, on=['Unnamed: 0'], how='outer')
df.rename(columns={'Unnamed: 0':'parameter','x':'value_mean'}, inplace=True)
df['text'] = df.apply(lambda x: "%.2f" % round(x['value_mean'],2)+' ['+"%.2f" % round(x['lower'],2)+', '+"%.2f" % round(x['upper'],2)+']', 
                          axis=1)
#separate parameters family (random effect, fexed effect, sigma, correlatiom)
display(list(df['parameter'].unique()))
df['type'] = df['parameter'].map(lambda x: x.split('_')[0])
display(df['type'].value_counts())

#henID intercept random intercept
df['HenID'] = df['parameter'].map(lambda x: x.split(',')[0].split('[')[-1] if 'hen_' in x else None)
#else None, otherwise will utput the entire name (i.e. x)
print(df['HenID'].unique())

#mvt variable for the hen intercepts to be visualised
df['mvtvariable'] = df['parameter'].map(lambda x: x.split('r_HenID__')[-1].split('[')[0] if ('r_HenID__' in x) \
                                        & ('cor_HenID' not in x) else None)
li_mvt = [i for i in df['mvtvariable'].unique() if i!=None]
print(li_mvt)
print('------------------all dataframe')
print(df.shape) 
display(df.head(3))

#correlations dataframe
df_cor_summarized = df[df['type']=='cor'].copy()
for mvt in li_mvt:
    df_cor_summarized[mvt] = df_cor_summarized['parameter'].map(lambda x: mvt in x)
print('------------------correlations dataframe')
display(df_cor_summarized)

#sd dataframe
df_sd_summarized = df[df['type']=='sd'].copy()
df_sd_summarized['parameter'] = df_sd_summarized['parameter'].map(lambda x: x.split('sd_HenID__')[-1])
print('------------------sd dataframe')
display(df_sd_summarized)
# Out:
# (1026, 3)
#                                           Unnamed: 0     lower     upper
# 0         b_scalefoodsameDurTimingr50final_Intercept -0.064798  0.300854
# 1  b_scaleverticaltraveldistancefulllightperinsid... -0.197497  0.181067
# 2                       b_midcumZ4hMorning_Intercept  1.456759  1.520648
# (1026, 2)
#                                           Unnamed: 0         x
# 0         b_scalefoodsameDurTimingr50final_Intercept  0.113984
# 1  b_scaleverticaltraveldistancefulllightperinsid... -0.013670
# 2                       b_midcumZ4hMorning_Intercept  1.487247
# ['b_scalefoodsameDurTimingr50final_Intercept',
#  'b_scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'b_midcumZ4hMorning_Intercept',
#  'b_SleepingUppest_Intercept',
#  'b_WentinWG_Intercept',
#  'b_scalefoodsameDurTimingr50final_TreatmentOFH',
#  'b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8',
#  'b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12',
#  'b_scalefoodsameDurTimingr50final_scaleweightInterp',
#  'b_scalefoodsameDurTimingr50final_scaleKBFInterp',
#  'b_scalefoodsameDurTimingr50final_scaleDIB',
#  'b_scalefoodsameDurTimingr50final_CLASSLEXP',
#  'b_scalefoodsameDurTimingr50final_CLASSMEXP',
#  'b_scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH',
#  'b_scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp',
#  'b_scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp',
#  'b_scaleverticaltraveldistancefulllightperinsideh_scaleDIB',
#  'b_scaleverticaltraveldistancefulllightperinsideh_CLASSLEXP',
#  'b_scaleverticaltraveldistancefulllightperinsideh_CLASSMEXP',
#  'b_midcumZ4hMorning_TreatmentOFH',
#  'b_midcumZ4hMorning_scaleweightInterp',
#  'b_midcumZ4hMorning_scaleKBFInterp',
#  'b_midcumZ4hMorning_scaleDIB',
#  'b_midcumZ4hMorning_CLASSLEXP',
#  'b_midcumZ4hMorning_CLASSMEXP',
#  'b_SleepingUppest_TreatmentOFH',
#  'b_SleepingUppest_scaleweightInterp',
#  'b_SleepingUppest_scaleKBFInterp',
#  'b_SleepingUppest_scaleDIB',
#  'b_SleepingUppest_CLASSLEXP',
#  'b_SleepingUppest_CLASSMEXP',
#  'b_WentinWG_TreatmentOFH',
#  'b_WentinWG_scaleweightInterp',
#  'b_WentinWG_scaleKBFInterp',
#  'b_WentinWG_scaleDIB',
#  'b_WentinWG_CLASSLEXP',
#  'b_WentinWG_CLASSMEXP',
#  'sd_HenID__scalefoodsameDurTimingr50final_Intercept',
#  'sd_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'sd_HenID__midcumZ4hMorning_Intercept',
#  'sd_HenID__SleepingUppest_Intercept',
#  'sd_HenID__WentinWG_Intercept',
#  'cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept',
#  'cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept',
#  'cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept',
#  'cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept',
#  'cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept',
#  'cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept',
#  'cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept',
#  'cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept',
#  'cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept',
#  'sigma_scalefoodsameDurTimingr50final',
#  'sigma_scaleverticaltraveldistancefulllightperinsideh',
#  'shape_midcumZ4hMorning',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_1,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_10,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_101,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_102,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_105,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_106,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_107,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_108,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_109,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_111,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_112,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_113,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_115,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_116,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_118,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_119,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_12,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_120,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_122,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_123,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_124,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_126,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_127,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_128,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_13,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_131,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_133,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_134,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_135,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_136,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_137,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_138,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_139,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_14,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_140,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_141,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_142,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_143,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_144,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_145,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_146,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_147,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_149,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_15,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_150,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_151,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_152,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_153,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_154,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_155,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_156,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_158,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_159,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_163,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_164,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_165,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_166,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_167,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_168,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_169,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_17,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_170,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_171,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_172,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_173,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_174,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_175,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_177,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_18,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_180,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_181,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_182,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_183,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_184,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_185,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_186,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_187,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_188,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_189,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_19,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_190,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_191,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_192,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_193,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_194,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_195,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_196,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_197,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_198,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_199,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_2,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_20,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_200,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_201,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_202,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_203,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_204,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_205,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_206,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_207,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_208,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_209,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_21,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_210,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_211,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_212,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_213,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_214,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_215,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_216,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_217,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_218,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_219,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_22,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_220,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_221,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_222,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_223,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_224,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_225,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_226,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_227,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_228,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_229,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_23,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_230,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_231,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_232,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_233,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_24,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_25,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_26,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_27,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_28,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_29,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_3,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_32,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_34,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_39,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_4,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_40,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_41,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_42,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_45,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_48,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_49,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_5,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_50,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_51,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_52,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_54,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_56,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_57,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_58,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_59,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_6,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_60,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_61,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_62,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_64,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_65,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_66,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_67,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_68,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_69,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_7,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_71,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_72,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_73,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_75,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_76,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_77,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_78,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_79,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_8,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_80,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_81,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_82,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_83,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_84,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_85,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_86,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_87,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_89,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_9,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_90,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_92,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_93,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_94,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_95,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_96,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_97,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_98,Intercept]',
#  'r_HenID__scalefoodsameDurTimingr50final[hen_99,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_1,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_10,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_101,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_102,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_105,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_106,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_107,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_108,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_109,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_111,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_112,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_113,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_115,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_116,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_118,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_119,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_12,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_120,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_122,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_123,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_124,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_126,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_127,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_128,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_13,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_131,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_133,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_134,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_135,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_136,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_137,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_138,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_139,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_14,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_140,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_141,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_142,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_143,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_144,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_145,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_146,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_147,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_149,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_15,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_150,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_151,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_152,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_153,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_154,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_155,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_156,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_158,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_159,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_163,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_164,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_165,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_166,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_167,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_168,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_169,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_17,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_170,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_171,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_172,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_173,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_174,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_175,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_177,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_18,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_180,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_181,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_182,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_183,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_184,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_185,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_186,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_187,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_188,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_189,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_19,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_190,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_191,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_192,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_193,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_194,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_195,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_196,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_197,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_198,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_199,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_2,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_20,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_200,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_201,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_202,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_203,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_204,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_205,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_206,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_207,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_208,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_209,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_21,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_210,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_211,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_212,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_213,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_214,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_215,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_216,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_217,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_218,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_219,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_22,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_220,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_221,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_222,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_223,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_224,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_225,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_226,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_227,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_228,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_229,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_23,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_230,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_231,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_232,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_233,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_24,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_25,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_26,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_27,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_28,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_29,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_3,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_32,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_34,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_39,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_4,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_40,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_41,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_42,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_45,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_48,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_49,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_5,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_50,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_51,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_52,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_54,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_56,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_57,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_58,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_59,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_6,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_60,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_61,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_62,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_64,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_65,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_66,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_67,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_68,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_69,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_7,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_71,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_72,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_73,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_75,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_76,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_77,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_78,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_79,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_8,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_80,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_81,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_82,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_83,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_84,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_85,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_86,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_87,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_89,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_9,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_90,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_92,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_93,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_94,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_95,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_96,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_97,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_98,Intercept]',
#  'r_HenID__scaleverticaltraveldistancefulllightperinsideh[hen_99,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_1,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_10,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_101,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_102,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_105,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_106,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_107,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_108,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_109,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_111,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_112,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_113,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_115,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_116,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_118,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_119,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_12,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_120,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_122,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_123,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_124,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_126,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_127,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_128,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_13,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_131,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_133,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_134,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_135,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_136,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_137,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_138,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_139,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_14,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_140,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_141,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_142,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_143,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_144,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_145,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_146,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_147,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_149,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_15,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_150,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_151,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_152,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_153,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_154,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_155,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_156,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_158,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_159,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_163,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_164,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_165,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_166,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_167,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_168,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_169,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_17,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_170,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_171,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_172,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_173,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_174,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_175,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_177,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_18,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_180,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_181,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_182,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_183,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_184,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_185,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_186,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_187,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_188,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_189,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_19,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_190,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_191,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_192,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_193,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_194,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_195,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_196,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_197,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_198,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_199,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_2,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_20,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_200,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_201,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_202,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_203,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_204,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_205,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_206,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_207,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_208,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_209,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_21,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_210,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_211,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_212,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_213,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_214,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_215,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_216,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_217,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_218,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_219,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_22,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_220,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_221,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_222,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_223,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_224,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_225,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_226,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_227,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_228,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_229,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_23,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_230,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_231,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_232,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_233,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_24,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_25,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_26,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_27,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_28,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_29,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_3,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_32,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_34,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_39,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_4,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_40,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_41,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_42,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_45,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_48,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_49,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_5,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_50,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_51,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_52,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_54,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_56,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_57,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_58,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_59,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_6,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_60,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_61,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_62,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_64,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_65,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_66,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_67,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_68,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_69,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_7,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_71,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_72,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_73,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_75,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_76,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_77,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_78,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_79,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_8,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_80,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_81,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_82,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_83,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_84,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_85,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_86,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_87,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_89,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_9,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_90,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_92,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_93,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_94,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_95,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_96,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_97,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_98,Intercept]',
#  'r_HenID__midcumZ4hMorning[hen_99,Intercept]',
#  'r_HenID__SleepingUppest[hen_1,Intercept]',
#  'r_HenID__SleepingUppest[hen_10,Intercept]',
#  'r_HenID__SleepingUppest[hen_101,Intercept]',
#  'r_HenID__SleepingUppest[hen_102,Intercept]',
#  'r_HenID__SleepingUppest[hen_105,Intercept]',
#  'r_HenID__SleepingUppest[hen_106,Intercept]',
#  'r_HenID__SleepingUppest[hen_107,Intercept]',
#  'r_HenID__SleepingUppest[hen_108,Intercept]',
#  'r_HenID__SleepingUppest[hen_109,Intercept]',
#  'r_HenID__SleepingUppest[hen_111,Intercept]',
#  'r_HenID__SleepingUppest[hen_112,Intercept]',
#  'r_HenID__SleepingUppest[hen_113,Intercept]',
#  'r_HenID__SleepingUppest[hen_115,Intercept]',
#  'r_HenID__SleepingUppest[hen_116,Intercept]',
#  'r_HenID__SleepingUppest[hen_118,Intercept]',
#  'r_HenID__SleepingUppest[hen_119,Intercept]',
#  'r_HenID__SleepingUppest[hen_12,Intercept]',
#  'r_HenID__SleepingUppest[hen_120,Intercept]',
#  'r_HenID__SleepingUppest[hen_122,Intercept]',
#  'r_HenID__SleepingUppest[hen_123,Intercept]',
#  'r_HenID__SleepingUppest[hen_124,Intercept]',
#  'r_HenID__SleepingUppest[hen_126,Intercept]',
#  'r_HenID__SleepingUppest[hen_127,Intercept]',
#  'r_HenID__SleepingUppest[hen_128,Intercept]',
#  'r_HenID__SleepingUppest[hen_13,Intercept]',
#  'r_HenID__SleepingUppest[hen_131,Intercept]',
#  'r_HenID__SleepingUppest[hen_133,Intercept]',
#  'r_HenID__SleepingUppest[hen_134,Intercept]',
#  'r_HenID__SleepingUppest[hen_135,Intercept]',
#  'r_HenID__SleepingUppest[hen_136,Intercept]',
#  'r_HenID__SleepingUppest[hen_137,Intercept]',
#  'r_HenID__SleepingUppest[hen_138,Intercept]',
#  'r_HenID__SleepingUppest[hen_139,Intercept]',
#  'r_HenID__SleepingUppest[hen_14,Intercept]',
#  'r_HenID__SleepingUppest[hen_140,Intercept]',
#  'r_HenID__SleepingUppest[hen_141,Intercept]',
#  'r_HenID__SleepingUppest[hen_142,Intercept]',
#  'r_HenID__SleepingUppest[hen_143,Intercept]',
#  'r_HenID__SleepingUppest[hen_144,Intercept]',
#  'r_HenID__SleepingUppest[hen_145,Intercept]',
#  'r_HenID__SleepingUppest[hen_146,Intercept]',
#  'r_HenID__SleepingUppest[hen_147,Intercept]',
#  'r_HenID__SleepingUppest[hen_149,Intercept]',
#  'r_HenID__SleepingUppest[hen_15,Intercept]',
#  'r_HenID__SleepingUppest[hen_150,Intercept]',
#  'r_HenID__SleepingUppest[hen_151,Intercept]',
#  'r_HenID__SleepingUppest[hen_152,Intercept]',
#  'r_HenID__SleepingUppest[hen_153,Intercept]',
#  'r_HenID__SleepingUppest[hen_154,Intercept]',
#  'r_HenID__SleepingUppest[hen_155,Intercept]',
#  'r_HenID__SleepingUppest[hen_156,Intercept]',
#  'r_HenID__SleepingUppest[hen_158,Intercept]',
#  'r_HenID__SleepingUppest[hen_159,Intercept]',
#  'r_HenID__SleepingUppest[hen_163,Intercept]',
#  'r_HenID__SleepingUppest[hen_164,Intercept]',
#  'r_HenID__SleepingUppest[hen_165,Intercept]',
#  'r_HenID__SleepingUppest[hen_166,Intercept]',
#  'r_HenID__SleepingUppest[hen_167,Intercept]',
#  'r_HenID__SleepingUppest[hen_168,Intercept]',
#  'r_HenID__SleepingUppest[hen_169,Intercept]',
#  'r_HenID__SleepingUppest[hen_17,Intercept]',
#  'r_HenID__SleepingUppest[hen_170,Intercept]',
#  'r_HenID__SleepingUppest[hen_171,Intercept]',
#  'r_HenID__SleepingUppest[hen_172,Intercept]',
#  'r_HenID__SleepingUppest[hen_173,Intercept]',
#  'r_HenID__SleepingUppest[hen_174,Intercept]',
#  'r_HenID__SleepingUppest[hen_175,Intercept]',
#  'r_HenID__SleepingUppest[hen_177,Intercept]',
#  'r_HenID__SleepingUppest[hen_18,Intercept]',
#  'r_HenID__SleepingUppest[hen_180,Intercept]',
#  'r_HenID__SleepingUppest[hen_181,Intercept]',
#  'r_HenID__SleepingUppest[hen_182,Intercept]',
#  'r_HenID__SleepingUppest[hen_183,Intercept]',
#  'r_HenID__SleepingUppest[hen_184,Intercept]',
#  'r_HenID__SleepingUppest[hen_185,Intercept]',
#  'r_HenID__SleepingUppest[hen_186,Intercept]',
#  'r_HenID__SleepingUppest[hen_187,Intercept]',
#  'r_HenID__SleepingUppest[hen_188,Intercept]',
#  'r_HenID__SleepingUppest[hen_189,Intercept]',
#  'r_HenID__SleepingUppest[hen_19,Intercept]',
#  'r_HenID__SleepingUppest[hen_190,Intercept]',
#  'r_HenID__SleepingUppest[hen_191,Intercept]',
#  'r_HenID__SleepingUppest[hen_192,Intercept]',
#  'r_HenID__SleepingUppest[hen_193,Intercept]',
#  'r_HenID__SleepingUppest[hen_194,Intercept]',
#  'r_HenID__SleepingUppest[hen_195,Intercept]',
#  'r_HenID__SleepingUppest[hen_196,Intercept]',
#  'r_HenID__SleepingUppest[hen_197,Intercept]',
#  'r_HenID__SleepingUppest[hen_198,Intercept]',
#  'r_HenID__SleepingUppest[hen_199,Intercept]',
#  'r_HenID__SleepingUppest[hen_2,Intercept]',
#  'r_HenID__SleepingUppest[hen_20,Intercept]',
#  'r_HenID__SleepingUppest[hen_200,Intercept]',
#  'r_HenID__SleepingUppest[hen_201,Intercept]',
#  'r_HenID__SleepingUppest[hen_202,Intercept]',
#  'r_HenID__SleepingUppest[hen_203,Intercept]',
#  'r_HenID__SleepingUppest[hen_204,Intercept]',
#  'r_HenID__SleepingUppest[hen_205,Intercept]',
#  'r_HenID__SleepingUppest[hen_206,Intercept]',
#  'r_HenID__SleepingUppest[hen_207,Intercept]',
#  'r_HenID__SleepingUppest[hen_208,Intercept]',
#  'r_HenID__SleepingUppest[hen_209,Intercept]',
#  'r_HenID__SleepingUppest[hen_21,Intercept]',
#  'r_HenID__SleepingUppest[hen_210,Intercept]',
#  'r_HenID__SleepingUppest[hen_211,Intercept]',
#  'r_HenID__SleepingUppest[hen_212,Intercept]',
#  'r_HenID__SleepingUppest[hen_213,Intercept]',
#  'r_HenID__SleepingUppest[hen_214,Intercept]',
#  'r_HenID__SleepingUppest[hen_215,Intercept]',
#  'r_HenID__SleepingUppest[hen_216,Intercept]',
#  'r_HenID__SleepingUppest[hen_217,Intercept]',
#  'r_HenID__SleepingUppest[hen_218,Intercept]',
#  'r_HenID__SleepingUppest[hen_219,Intercept]',
#  'r_HenID__SleepingUppest[hen_22,Intercept]',
#  'r_HenID__SleepingUppest[hen_220,Intercept]',
#  'r_HenID__SleepingUppest[hen_221,Intercept]',
#  'r_HenID__SleepingUppest[hen_222,Intercept]',
#  'r_HenID__SleepingUppest[hen_223,Intercept]',
#  'r_HenID__SleepingUppest[hen_224,Intercept]',
#  'r_HenID__SleepingUppest[hen_225,Intercept]',
#  'r_HenID__SleepingUppest[hen_226,Intercept]',
#  'r_HenID__SleepingUppest[hen_227,Intercept]',
#  'r_HenID__SleepingUppest[hen_228,Intercept]',
#  'r_HenID__SleepingUppest[hen_229,Intercept]',
#  'r_HenID__SleepingUppest[hen_23,Intercept]',
#  'r_HenID__SleepingUppest[hen_230,Intercept]',
#  'r_HenID__SleepingUppest[hen_231,Intercept]',
#  'r_HenID__SleepingUppest[hen_232,Intercept]',
#  'r_HenID__SleepingUppest[hen_233,Intercept]',
#  'r_HenID__SleepingUppest[hen_24,Intercept]',
#  'r_HenID__SleepingUppest[hen_25,Intercept]',
#  'r_HenID__SleepingUppest[hen_26,Intercept]',
#  'r_HenID__SleepingUppest[hen_27,Intercept]',
#  'r_HenID__SleepingUppest[hen_28,Intercept]',
#  'r_HenID__SleepingUppest[hen_29,Intercept]',
#  'r_HenID__SleepingUppest[hen_3,Intercept]',
#  'r_HenID__SleepingUppest[hen_32,Intercept]',
#  'r_HenID__SleepingUppest[hen_34,Intercept]',
#  'r_HenID__SleepingUppest[hen_39,Intercept]',
#  'r_HenID__SleepingUppest[hen_4,Intercept]',
#  'r_HenID__SleepingUppest[hen_40,Intercept]',
#  'r_HenID__SleepingUppest[hen_41,Intercept]',
#  'r_HenID__SleepingUppest[hen_42,Intercept]',
#  'r_HenID__SleepingUppest[hen_45,Intercept]',
#  'r_HenID__SleepingUppest[hen_48,Intercept]',
#  'r_HenID__SleepingUppest[hen_49,Intercept]',
#  'r_HenID__SleepingUppest[hen_5,Intercept]',
#  'r_HenID__SleepingUppest[hen_50,Intercept]',
#  'r_HenID__SleepingUppest[hen_51,Intercept]',
#  'r_HenID__SleepingUppest[hen_52,Intercept]',
#  'r_HenID__SleepingUppest[hen_54,Intercept]',
#  'r_HenID__SleepingUppest[hen_56,Intercept]',
#  'r_HenID__SleepingUppest[hen_57,Intercept]',
#  'r_HenID__SleepingUppest[hen_58,Intercept]',
#  'r_HenID__SleepingUppest[hen_59,Intercept]',
#  'r_HenID__SleepingUppest[hen_6,Intercept]',
#  'r_HenID__SleepingUppest[hen_60,Intercept]',
#  'r_HenID__SleepingUppest[hen_61,Intercept]',
#  'r_HenID__SleepingUppest[hen_62,Intercept]',
#  'r_HenID__SleepingUppest[hen_64,Intercept]',
#  'r_HenID__SleepingUppest[hen_65,Intercept]',
#  'r_HenID__SleepingUppest[hen_66,Intercept]',
#  'r_HenID__SleepingUppest[hen_67,Intercept]',
#  'r_HenID__SleepingUppest[hen_68,Intercept]',
#  'r_HenID__SleepingUppest[hen_69,Intercept]',
#  'r_HenID__SleepingUppest[hen_7,Intercept]',
#  'r_HenID__SleepingUppest[hen_71,Intercept]',
#  'r_HenID__SleepingUppest[hen_72,Intercept]',
#  'r_HenID__SleepingUppest[hen_73,Intercept]',
#  'r_HenID__SleepingUppest[hen_75,Intercept]',
#  'r_HenID__SleepingUppest[hen_76,Intercept]',
#  'r_HenID__SleepingUppest[hen_77,Intercept]',
#  'r_HenID__SleepingUppest[hen_78,Intercept]',
#  'r_HenID__SleepingUppest[hen_79,Intercept]',
#  'r_HenID__SleepingUppest[hen_8,Intercept]',
#  'r_HenID__SleepingUppest[hen_80,Intercept]',
#  'r_HenID__SleepingUppest[hen_81,Intercept]',
#  'r_HenID__SleepingUppest[hen_82,Intercept]',
#  'r_HenID__SleepingUppest[hen_83,Intercept]',
#  'r_HenID__SleepingUppest[hen_84,Intercept]',
#  'r_HenID__SleepingUppest[hen_85,Intercept]',
#  'r_HenID__SleepingUppest[hen_86,Intercept]',
#  'r_HenID__SleepingUppest[hen_87,Intercept]',
#  'r_HenID__SleepingUppest[hen_89,Intercept]',
#  'r_HenID__SleepingUppest[hen_9,Intercept]',
#  'r_HenID__SleepingUppest[hen_90,Intercept]',
#  'r_HenID__SleepingUppest[hen_92,Intercept]',
#  'r_HenID__SleepingUppest[hen_93,Intercept]',
#  'r_HenID__SleepingUppest[hen_94,Intercept]',
#  'r_HenID__SleepingUppest[hen_95,Intercept]',
#  'r_HenID__SleepingUppest[hen_96,Intercept]',
#  'r_HenID__SleepingUppest[hen_97,Intercept]',
#  'r_HenID__SleepingUppest[hen_98,Intercept]',
#  'r_HenID__SleepingUppest[hen_99,Intercept]',
#  'r_HenID__WentinWG[hen_1,Intercept]',
#  'r_HenID__WentinWG[hen_10,Intercept]',
#  'r_HenID__WentinWG[hen_101,Intercept]',
#  'r_HenID__WentinWG[hen_102,Intercept]',
#  'r_HenID__WentinWG[hen_105,Intercept]',
#  'r_HenID__WentinWG[hen_106,Intercept]',
#  'r_HenID__WentinWG[hen_107,Intercept]',
#  'r_HenID__WentinWG[hen_108,Intercept]',
#  'r_HenID__WentinWG[hen_109,Intercept]',
#  'r_HenID__WentinWG[hen_111,Intercept]',
#  'r_HenID__WentinWG[hen_112,Intercept]',
#  'r_HenID__WentinWG[hen_113,Intercept]',
#  'r_HenID__WentinWG[hen_115,Intercept]',
#  'r_HenID__WentinWG[hen_116,Intercept]',
#  'r_HenID__WentinWG[hen_118,Intercept]',
#  'r_HenID__WentinWG[hen_119,Intercept]',
#  'r_HenID__WentinWG[hen_12,Intercept]',
#  'r_HenID__WentinWG[hen_120,Intercept]',
#  'r_HenID__WentinWG[hen_122,Intercept]',
#  'r_HenID__WentinWG[hen_123,Intercept]',
#  'r_HenID__WentinWG[hen_124,Intercept]',
#  'r_HenID__WentinWG[hen_126,Intercept]',
#  'r_HenID__WentinWG[hen_127,Intercept]',
#  'r_HenID__WentinWG[hen_128,Intercept]',
#  'r_HenID__WentinWG[hen_13,Intercept]',
#  'r_HenID__WentinWG[hen_131,Intercept]',
#  'r_HenID__WentinWG[hen_133,Intercept]',
#  'r_HenID__WentinWG[hen_134,Intercept]',
#  'r_HenID__WentinWG[hen_135,Intercept]',
#  'r_HenID__WentinWG[hen_136,Intercept]',
#  'r_HenID__WentinWG[hen_137,Intercept]',
#  'r_HenID__WentinWG[hen_138,Intercept]',
#  'r_HenID__WentinWG[hen_139,Intercept]',
#  'r_HenID__WentinWG[hen_14,Intercept]',
#  'r_HenID__WentinWG[hen_140,Intercept]',
#  'r_HenID__WentinWG[hen_141,Intercept]',
#  'r_HenID__WentinWG[hen_142,Intercept]',
#  'r_HenID__WentinWG[hen_143,Intercept]',
#  'r_HenID__WentinWG[hen_144,Intercept]',
#  'r_HenID__WentinWG[hen_145,Intercept]',
#  'r_HenID__WentinWG[hen_146,Intercept]',
#  'r_HenID__WentinWG[hen_147,Intercept]',
#  'r_HenID__WentinWG[hen_149,Intercept]',
#  'r_HenID__WentinWG[hen_15,Intercept]',
#  'r_HenID__WentinWG[hen_150,Intercept]',
#  'r_HenID__WentinWG[hen_151,Intercept]',
#  'r_HenID__WentinWG[hen_152,Intercept]',
#  'r_HenID__WentinWG[hen_153,Intercept]',
#  'r_HenID__WentinWG[hen_154,Intercept]',
#  'r_HenID__WentinWG[hen_155,Intercept]',
#  'r_HenID__WentinWG[hen_156,Intercept]',
#  'r_HenID__WentinWG[hen_158,Intercept]',
#  'r_HenID__WentinWG[hen_159,Intercept]',
#  'r_HenID__WentinWG[hen_163,Intercept]',
#  'r_HenID__WentinWG[hen_164,Intercept]',
#  'r_HenID__WentinWG[hen_165,Intercept]',
#  'r_HenID__WentinWG[hen_166,Intercept]',
#  'r_HenID__WentinWG[hen_167,Intercept]',
#  'r_HenID__WentinWG[hen_168,Intercept]',
#  'r_HenID__WentinWG[hen_169,Intercept]',
#  'r_HenID__WentinWG[hen_17,Intercept]',
#  'r_HenID__WentinWG[hen_170,Intercept]',
#  'r_HenID__WentinWG[hen_171,Intercept]',
#  'r_HenID__WentinWG[hen_172,Intercept]',
#  'r_HenID__WentinWG[hen_173,Intercept]',
#  'r_HenID__WentinWG[hen_174,Intercept]',
#  'r_HenID__WentinWG[hen_175,Intercept]',
#  'r_HenID__WentinWG[hen_177,Intercept]',
#  'r_HenID__WentinWG[hen_18,Intercept]',
#  'r_HenID__WentinWG[hen_180,Intercept]',
#  'r_HenID__WentinWG[hen_181,Intercept]',
#  'r_HenID__WentinWG[hen_182,Intercept]',
#  'r_HenID__WentinWG[hen_183,Intercept]',
#  'r_HenID__WentinWG[hen_184,Intercept]',
#  'r_HenID__WentinWG[hen_185,Intercept]',
#  'r_HenID__WentinWG[hen_186,Intercept]',
#  'r_HenID__WentinWG[hen_187,Intercept]',
#  'r_HenID__WentinWG[hen_188,Intercept]',
#  'r_HenID__WentinWG[hen_189,Intercept]',
#  'r_HenID__WentinWG[hen_19,Intercept]',
#  'r_HenID__WentinWG[hen_190,Intercept]',
#  'r_HenID__WentinWG[hen_191,Intercept]',
#  'r_HenID__WentinWG[hen_192,Intercept]',
#  'r_HenID__WentinWG[hen_193,Intercept]',
#  'r_HenID__WentinWG[hen_194,Intercept]',
#  'r_HenID__WentinWG[hen_195,Intercept]',
#  'r_HenID__WentinWG[hen_196,Intercept]',
#  'r_HenID__WentinWG[hen_197,Intercept]',
#  'r_HenID__WentinWG[hen_198,Intercept]',
#  'r_HenID__WentinWG[hen_199,Intercept]',
#  'r_HenID__WentinWG[hen_2,Intercept]',
#  'r_HenID__WentinWG[hen_20,Intercept]',
#  'r_HenID__WentinWG[hen_200,Intercept]',
#  'r_HenID__WentinWG[hen_201,Intercept]',
#  'r_HenID__WentinWG[hen_202,Intercept]',
#  'r_HenID__WentinWG[hen_203,Intercept]',
#  'r_HenID__WentinWG[hen_204,Intercept]',
#  'r_HenID__WentinWG[hen_205,Intercept]',
#  'r_HenID__WentinWG[hen_206,Intercept]',
#  'r_HenID__WentinWG[hen_207,Intercept]',
#  'r_HenID__WentinWG[hen_208,Intercept]',
#  'r_HenID__WentinWG[hen_209,Intercept]',
#  'r_HenID__WentinWG[hen_21,Intercept]',
#  'r_HenID__WentinWG[hen_210,Intercept]',
#  'r_HenID__WentinWG[hen_211,Intercept]',
#  'r_HenID__WentinWG[hen_212,Intercept]',
#  'r_HenID__WentinWG[hen_213,Intercept]',
#  'r_HenID__WentinWG[hen_214,Intercept]',
#  'r_HenID__WentinWG[hen_215,Intercept]',
#  'r_HenID__WentinWG[hen_216,Intercept]',
#  'r_HenID__WentinWG[hen_217,Intercept]',
#  'r_HenID__WentinWG[hen_218,Intercept]',
#  'r_HenID__WentinWG[hen_219,Intercept]',
#  'r_HenID__WentinWG[hen_22,Intercept]',
#  'r_HenID__WentinWG[hen_220,Intercept]',
#  'r_HenID__WentinWG[hen_221,Intercept]',
#  'r_HenID__WentinWG[hen_222,Intercept]',
#  'r_HenID__WentinWG[hen_223,Intercept]',
#  'r_HenID__WentinWG[hen_224,Intercept]',
#  'r_HenID__WentinWG[hen_225,Intercept]',
#  'r_HenID__WentinWG[hen_226,Intercept]',
#  'r_HenID__WentinWG[hen_227,Intercept]',
#  'r_HenID__WentinWG[hen_228,Intercept]',
#  'r_HenID__WentinWG[hen_229,Intercept]',
#  'r_HenID__WentinWG[hen_23,Intercept]',
#  'r_HenID__WentinWG[hen_230,Intercept]',
#  'r_HenID__WentinWG[hen_231,Intercept]',
#  'r_HenID__WentinWG[hen_232,Intercept]',
#  'r_HenID__WentinWG[hen_233,Intercept]',
#  'r_HenID__WentinWG[hen_24,Intercept]',
#  'r_HenID__WentinWG[hen_25,Intercept]',
#  'r_HenID__WentinWG[hen_26,Intercept]',
#  'r_HenID__WentinWG[hen_27,Intercept]',
#  'r_HenID__WentinWG[hen_28,Intercept]',
#  'r_HenID__WentinWG[hen_29,Intercept]',
#  'r_HenID__WentinWG[hen_3,Intercept]',
#  'r_HenID__WentinWG[hen_32,Intercept]',
#  'r_HenID__WentinWG[hen_34,Intercept]',
#  'r_HenID__WentinWG[hen_39,Intercept]',
#  'r_HenID__WentinWG[hen_4,Intercept]',
#  'r_HenID__WentinWG[hen_40,Intercept]',
#  'r_HenID__WentinWG[hen_41,Intercept]',
#  'r_HenID__WentinWG[hen_42,Intercept]',
#  'r_HenID__WentinWG[hen_45,Intercept]',
#  'r_HenID__WentinWG[hen_48,Intercept]',
#  'r_HenID__WentinWG[hen_49,Intercept]',
#  'r_HenID__WentinWG[hen_5,Intercept]',
#  'r_HenID__WentinWG[hen_50,Intercept]',
#  'r_HenID__WentinWG[hen_51,Intercept]',
#  'r_HenID__WentinWG[hen_52,Intercept]',
#  'r_HenID__WentinWG[hen_54,Intercept]',
#  'r_HenID__WentinWG[hen_56,Intercept]',
#  'r_HenID__WentinWG[hen_57,Intercept]',
#  'r_HenID__WentinWG[hen_58,Intercept]',
#  'r_HenID__WentinWG[hen_59,Intercept]',
#  'r_HenID__WentinWG[hen_6,Intercept]',
#  'r_HenID__WentinWG[hen_60,Intercept]',
#  'r_HenID__WentinWG[hen_61,Intercept]',
#  'r_HenID__WentinWG[hen_62,Intercept]',
#  'r_HenID__WentinWG[hen_64,Intercept]',
#  'r_HenID__WentinWG[hen_65,Intercept]',
#  'r_HenID__WentinWG[hen_66,Intercept]',
#  'r_HenID__WentinWG[hen_67,Intercept]',
#  'r_HenID__WentinWG[hen_68,Intercept]',
#  'r_HenID__WentinWG[hen_69,Intercept]',
#  'r_HenID__WentinWG[hen_7,Intercept]',
#  'r_HenID__WentinWG[hen_71,Intercept]',
#  'r_HenID__WentinWG[hen_72,Intercept]',
#  'r_HenID__WentinWG[hen_73,Intercept]',
#  ...]
# r        970
# b         37
# cor       10
# sd         5
# sigma      2
# shape      1
# lp         1
# Name: type, dtype: int64
# [None 'hen_1' 'hen_10' 'hen_101' 'hen_102' 'hen_105' 'hen_106' 'hen_107'
#  'hen_108' 'hen_109' 'hen_111' 'hen_112' 'hen_113' 'hen_115' 'hen_116'
#  'hen_118' 'hen_119' 'hen_12' 'hen_120' 'hen_122' 'hen_123' 'hen_124'
#  'hen_126' 'hen_127' 'hen_128' 'hen_13' 'hen_131' 'hen_133' 'hen_134'
#  'hen_135' 'hen_136' 'hen_137' 'hen_138' 'hen_139' 'hen_14' 'hen_140'
#  'hen_141' 'hen_142' 'hen_143' 'hen_144' 'hen_145' 'hen_146' 'hen_147'
#  'hen_149' 'hen_15' 'hen_150' 'hen_151' 'hen_152' 'hen_153' 'hen_154'
#  'hen_155' 'hen_156' 'hen_158' 'hen_159' 'hen_163' 'hen_164' 'hen_165'
#  'hen_166' 'hen_167' 'hen_168' 'hen_169' 'hen_17' 'hen_170' 'hen_171'
#  'hen_172' 'hen_173' 'hen_174' 'hen_175' 'hen_177' 'hen_18' 'hen_180'
#  'hen_181' 'hen_182' 'hen_183' 'hen_184' 'hen_185' 'hen_186' 'hen_187'
#  'hen_188' 'hen_189' 'hen_19' 'hen_190' 'hen_191' 'hen_192' 'hen_193'
#  'hen_194' 'hen_195' 'hen_196' 'hen_197' 'hen_198' 'hen_199' 'hen_2'
#  'hen_20' 'hen_200' 'hen_201' 'hen_202' 'hen_203' 'hen_204' 'hen_205'
#  'hen_206' 'hen_207' 'hen_208' 'hen_209' 'hen_21' 'hen_210' 'hen_211'
#  'hen_212' 'hen_213' 'hen_214' 'hen_215' 'hen_216' 'hen_217' 'hen_218'
#  'hen_219' 'hen_22' 'hen_220' 'hen_221' 'hen_222' 'hen_223' 'hen_224'
#  'hen_225' 'hen_226' 'hen_227' 'hen_228' 'hen_229' 'hen_23' 'hen_230'
#  'hen_231' 'hen_232' 'hen_233' 'hen_24' 'hen_25' 'hen_26' 'hen_27'
#  'hen_28' 'hen_29' 'hen_3' 'hen_32' 'hen_34' 'hen_39' 'hen_4' 'hen_40'
#  'hen_41' 'hen_42' 'hen_45' 'hen_48' 'hen_49' 'hen_5' 'hen_50' 'hen_51'
#  'hen_52' 'hen_54' 'hen_56' 'hen_57' 'hen_58' 'hen_59' 'hen_6' 'hen_60'
#  'hen_61' 'hen_62' 'hen_64' 'hen_65' 'hen_66' 'hen_67' 'hen_68' 'hen_69'
#  'hen_7' 'hen_71' 'hen_72' 'hen_73' 'hen_75' 'hen_76' 'hen_77' 'hen_78'
#  'hen_79' 'hen_8' 'hen_80' 'hen_81' 'hen_82' 'hen_83' 'hen_84' 'hen_85'
#  'hen_86' 'hen_87' 'hen_89' 'hen_9' 'hen_90' 'hen_92' 'hen_93' 'hen_94'
#  'hen_95' 'hen_96' 'hen_97' 'hen_98' 'hen_99']
# ['scalefoodsameDurTimingr50final', 'scaleverticaltraveldistancefulllightperinsideh', 'midcumZ4hMorning', 'SleepingUppest', 'WentinWG']
# ------------------all dataframe
# (1026, 8)
#                                            parameter  value_mean     lower  \
# 0         b_scalefoodsameDurTimingr50final_Intercept    0.113984 -0.064798
# 1  b_scaleverticaltraveldistancefulllightperinsid...   -0.013670 -0.197497
# 2                       b_midcumZ4hMorning_Intercept    1.487247  1.456759
#
#       upper                 text type HenID mvtvariable
# 0  0.300854   0.11 [-0.06, 0.30]    b  None        None
# 1  0.181067  -0.01 [-0.20, 0.18]    b  None        None
# 2  1.520648    1.49 [1.46, 1.52]    b  None        None
# ------------------correlations dataframe
#                                             parameter  value_mean     lower  \
# 42  cor_HenID__scalefoodsameDurTimingr50final_Inte...    0.466077  0.348321
# 43  cor_HenID__scalefoodsameDurTimingr50final_Inte...   -0.082449 -0.236499
# 44  cor_HenID__scaleverticaltraveldistancefullligh...   -0.022486 -0.175245
# 45  cor_HenID__scalefoodsameDurTimingr50final_Inte...   -0.209279 -0.362715
# 46  cor_HenID__scaleverticaltraveldistancefullligh...   -0.229544 -0.387820
# 47  cor_HenID__midcumZ4hMorning_Intercept__Sleepin...   -0.037200 -0.196273
# 48  cor_HenID__scalefoodsameDurTimingr50final_Inte...    0.267421  0.109879
# 49  cor_HenID__scaleverticaltraveldistancefullligh...    0.496877  0.379948
# 50  cor_HenID__midcumZ4hMorning_Intercept__WentinW...   -0.038097 -0.192731
# 51  cor_HenID__SleepingUppest_Intercept__WentinWG_...    0.101758 -0.059288
#
#        upper                  text type HenID mvtvariable  \
# 42  0.592172     0.47 [0.35, 0.59]  cor  None        None
# 43  0.069314   -0.08 [-0.24, 0.07]  cor  None        None
# 44  0.119477   -0.02 [-0.18, 0.12]  cor  None        None
# 45 -0.053929  -0.21 [-0.36, -0.05]  cor  None        None
# 46 -0.082061  -0.23 [-0.39, -0.08]  cor  None        None
# 47  0.114593   -0.04 [-0.20, 0.11]  cor  None        None
# 48  0.413426     0.27 [0.11, 0.41]  cor  None        None
# 49  0.613067     0.50 [0.38, 0.61]  cor  None        None
# 50  0.117521   -0.04 [-0.19, 0.12]  cor  None        None
# 51  0.264532    0.10 [-0.06, 0.26]  cor  None        None
#
#     scalefoodsameDurTimingr50final  \
# 42                            True
# 43                            True
# 44                           False
# 45                            True
# 46                           False
# 47                           False
# 48                            True
# 49                           False
# 50                           False
# 51                           False
#
#     scaleverticaltraveldistancefulllightperinsideh  midcumZ4hMorning  \
# 42                                            True             False
# 43                                           False              True
# 44                                            True              True
# 45                                           False             False
# 46                                            True             False
# 47                                           False              True
# 48                                           False             False
# 49                                            True             False
# 50                                           False              True
# 51                                           False             False
#
#     SleepingUppest  WentinWG
# 42           False     False
# 43           False     False
# 44           False     False
# 45            True     False
# 46            True     False
# 47            True     False
# 48           False      True
# 49           False      True
# 50           False      True
# 51            True      True
# ------------------sd dataframe
#                                             parameter  value_mean     lower  \
# 37           scalefoodsameDurTimingr50final_Intercept    0.555801  0.494286
# 38  scaleverticaltraveldistancefulllightperinsideh...    0.827021  0.737570
# 39                         midcumZ4hMorning_Intercept    0.138385  0.123121
# 40                           SleepingUppest_Intercept    2.260037  1.966648
# 41                                 WentinWG_Intercept    2.108675  1.812398
#
#        upper               text type HenID mvtvariable
# 37  0.619322  0.56 [0.49, 0.62]   sd  None        None
# 38  0.913644  0.83 [0.74, 0.91]   sd  None        None
# 39  0.154022  0.14 [0.12, 0.15]   sd  None        None
# 40  2.597894  2.26 [1.97, 2.60]   sd  None        None
# 41  2.390951  2.11 [1.81, 2.39]   sd  None        None

# %% [markdown]
# ### correlation matrix

# %%
#build the correlation matrix
CorrM = np.zeros(shape=(len(li_mvt), len(li_mvt)))
labels_ = np.array([['                                '] * len(li_mvt)] * len(li_mvt))
for i in range(0,len(li_mvt)):
    CorrM[i][i] = np.nan
    for j in range(i+1,len(li_mvt)):
        mvt1 = li_mvt[i]
        mvt2 = li_mvt[j]
        v = df_cor_summarized[(df_cor_summarized[mvt1])&(df_cor_summarized[mvt2])]['value_mean'].values[0]     
        CorrM[i][j] = v
        CorrM[j][i] = np.nan
        t = df_cor_summarized[(df_cor_summarized[mvt1])&(df_cor_summarized[mvt2])]['text'].values[0] 
        t = t.replace(' [','\n [')
        labels_[i][j] = t
        labels_[j][i] = ''
print(CorrM)
#print(labels_)
plt.figure(figsize=(14,3)) #9, 6.5
sns.heatmap(CorrM, cmap='RdYlGn', annot=labels_, fmt = '', 
            xticklabels=[dico_mvt_name[i] for i in li_mvt], yticklabels=[dico_mvt_name[i] for i in li_mvt],
           vmin=-0.55, vmax=0.55)
plt.xticks(rotation=10)
#fmt = ''is required for string labels
plt.xlabel('');
plt.ylabel('');
plt.savefig(os.path.join(path_extracted_data,'BS_corr.png'),dpi=300,format='png',bbox_inches='tight')
plt.show();
# Out:
# [[        nan  0.46607736 -0.08244943 -0.2092789   0.26742055]
#  [        nan         nan -0.02248604 -0.22954395  0.49687734]
#  [        nan         nan         nan -0.03720046 -0.03809713]
#  [        nan         nan         nan         nan  0.10175779]
#  [        nan         nan         nan         nan         nan]]

# %% [markdown]
# ### eigenvector decomposition

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html
#chose behaviour we want in the pca and assocaite them to a name
li_mvt_pc = ['scalefoodsameDurTimingr50final', 'scaleverticaltraveldistancefulllightperinsideh', 'SleepingUppest', 'WentinWG']
#midcumZ4hMorning
Corr = np.zeros(shape=(len(li_mvt_pc), len(li_mvt_pc)))
for i in range(0,len(li_mvt_pc)):
    Corr[i][i] = 1
    for j in range(i+1,len(li_mvt_pc)):
        mvt1 = li_mvt_pc[i]
        mvt2 = li_mvt_pc[j]
        v = df_cor_summarized[(df_cor_summarized[mvt1])&(df_cor_summarized[mvt2])]['value_mean'].values[0]     
        Corr[i][j] = v
        Corr[j][i] = v
print(Corr)
#eigen decomposition sorted by biggest eingenvalues
eigenValues, eigenVectors = eig(Corr)
idx = eigenValues.argsort()[::-1]   
eigenValues = eigenValues[idx]
eigenVectors = eigenVectors[:,idx]
#in R would simply be: eigen(Corr). same result
print(li_mvt_pc)
print(eigenValues)
comp1 = list(eigenVectors[:,0])
comp2 = list(eigenVectors[:,1])
#unit length vector
print(np.sqrt(sum([i*i for i in comp1])))
print(eigenVectors)#first columns: pc1 (multiple 0,0 by limvt0, 1,0 by VTD,... ;  second: pc2
print('Explained var:')
li_exvar = [i/sum(eigenValues) for i in eigenValues]
print(sum(li_exvar))
li_exvar
# Out:
# [[ 1.          0.46607736 -0.2092789   0.26742055]
#  [ 0.46607736  1.         -0.22954395  0.49687734]
#  [-0.2092789  -0.22954395  1.          0.10175779]
#  [ 0.26742055  0.49687734  0.10175779  1.        ]]
# ['scalefoodsameDurTimingr50final', 'scaleverticaltraveldistancefulllightperinsideh', 'SleepingUppest', 'WentinWG']
# [1.87726781 1.1000841  0.62905116 0.39359693]
# 1.0
# [[-0.54433334  0.16220583 -0.79337437 -0.21896936]
#  [-0.63276934 -0.02673094  0.22425284  0.74067475]
#  [ 0.23780474 -0.82601987 -0.4145204   0.29885268]
#  [-0.49674248 -0.5391344   0.3852799  -0.5604823 ]]
# Explained var:
# 1.0
# [0.4693169528518232,
#  0.2750210248576597,
#  0.1572627893503771,
#  0.09839923294014004]

# %% [markdown]
# ### standard deviation of the loadings

# %%
#download all posterior samples to compute std dev of the PCs
df_allit = pd.read_csv(os.path.join(path_extracted_data,'BRMS_BS_pred_allvar_FINAL.csv'), sep=',')
print(df_allit.shape)  #(1250, 4044) ou (5000, 1011)
li_col = set([x for x in list(df_allit.columns) if 'cor_HenID__' in x]) #X*, where * is the number of chain
print(len(li_col))
display(li_col)
df_allit = df_allit[li_col].copy()
df_allit['run'] = df_allit.index
print(df_allit.shape)
display(df_allit.head(3))
# Out:
# (5000, 4045)
# 40
# {'X1.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept',
#  'X1.cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept',
#  'X1.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept',
#  'X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept',
#  'X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept',
#  'X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept',
#  'X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'X1.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept',
#  'X1.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept',
#  'X1.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept',
#  'X2.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept',
#  'X2.cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept',
#  'X2.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept',
#  'X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept',
#  'X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept',
#  'X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept',
#  'X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'X2.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept',
#  'X2.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept',
#  'X2.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept',
#  'X3.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept',
#  'X3.cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept',
#  'X3.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept',
#  'X3.cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept',
#  'X3.cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept',
#  'X3.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept',
#  'X3.cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'X3.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept',
#  'X3.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept',
#  'X3.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept',
#  'X4.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept',
#  'X4.cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept',
#  'X4.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept',
#  'X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept',
#  'X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept',
#  'X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept',
#  'X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept',
#  'X4.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept',
#  'X4.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept',
#  'X4.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept'}
# (5000, 41)
#    X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept  \
# 0                                           0.416718
# 1                                           0.488321
# 2                                           0.487346
#
#    X3.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept  \
# 0                                           0.525469
# 1                                           0.463858
# 2                                           0.595698
#
#    X2.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.043429
# 1                                          -0.097742
# 2                                          -0.027590
#
#    X3.cor_HenID__midcumZ4hMorning_Intercept__SleepingUppest_Intercept  \
# 0                                           0.036837
# 1                                           0.079840
# 2                                           0.003905
#
#    X4.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept  \
# 0                                           0.006467
# 1                                           0.106936
# 2                                           0.019773
#
#    X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.316375
# 1                                          -0.182857
# 2                                          -0.134110
#
#    X2.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept  \
# 0                                           0.024900
# 1                                           0.008102
# 2                                          -0.091898
#
#    X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept  \
# 0                                           0.235906
# 1                                           0.212064
# 2                                           0.271531
#
#    X4.cor_HenID__midcumZ4hMorning_Intercept__WentinWG_Intercept  \
# 0                                          -0.067894
# 1                                          -0.051530
# 2                                          -0.034900
#
#    X4.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.170298
# 1                                          -0.141374
# 2                                          -0.101741
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#    X4.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept  \
# 0                                           0.552173
# 1                                           0.480239
# 2                                           0.527145
#
#    X2.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.197158
# 1                                          -0.246443
# 2                                          -0.130428
#
#    X1.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.091828
# 1                                          -0.063516
# 2                                          -0.060840
#
#    X3.cor_HenID__scalefoodsameDurTimingr50final_Intercept__midcumZ4hMorning_Intercept  \
# 0                                          -0.007498
# 1                                          -0.097633
# 2                                          -0.107470
#
#    X1.cor_HenID__SleepingUppest_Intercept__WentinWG_Intercept  \
# 0                                           0.207784
# 1                                           0.157137
# 2                                           0.134503
#
#    X4.cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept  \
# 0                                          -0.214182
# 1                                          -0.051746
# 2                                          -0.050993
#
#    X1.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept  \
# 0                                          -0.183866
# 1                                          -0.202466
# 2                                          -0.196612
#
#    X3.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept  \
# 0                                          -0.152226
# 1                                          -0.101934
# 2                                          -0.115650
#
#    X2.cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept  \
# 0                                          -0.288674
# 1                                          -0.147638
# 2                                          -0.192428
#
#    run
# 0    0
# 1    1
# 2    2
#
# [3 rows x 41 columns]

# %%
#find std deviation of pcs
li_comp1 = []
li_comp2 = []
li_chain = list(set([x.split('.')[0] for x in list(df_allit.columns) if 'X' in x]))
print(li_chain)
for run in tqdm.tqdm(df_allit['run'].unique()):
    for chain in li_chain:
        df_ = df_allit[df_allit['run']==run][[x for x in list(df_allit.columns) if 'X1' in x]].copy()
        M = np.zeros(shape=(len(li_mvt_pc), len(li_mvt_pc)))
        for i in range(0,len(li_mvt_pc)):
            M[i][i] = 1
            for j in range(i+1,len(li_mvt_pc)):
                mvt1 = li_mvt_pc[i]
                mvt2 = li_mvt_pc[j]
                vc = [x for x in list(df_.columns) if (mvt1 in x)&(mvt2 in x)]
                if len(vc)!=1:
                    print('ERROR')
                    print(vc)
                    sys.exit()
                v = df_[vc[0]].values[0]
                M[i][j] = v
                M[j][i] = v
        #print(M)
        #eigen decomposition sorted by biggest eingenvalues
        eigenValues, eigenVectors = eig(M)
        idx = eigenValues.argsort()[::-1]   
        eigenValues = eigenValues[idx]
        eigenVectors = eigenVectors[:,idx]
        #extract first and second column
        li_comp1.append(eigenVectors[:,0])
        li_comp2.append(eigenVectors[:,1])
df_pc1loading = pd.DataFrame(li_comp1, columns=li_mvt_pc)
df_pc2loading = pd.DataFrame(li_comp2, columns=li_mvt_pc)
print(df_pc1loading.shape)
display(df_pc1loading.head(5))

#because Eigenvectors are not unique & multiplying by any constant, including -1 (which simply changes the sign), gives 
#another valid eigenvector, we have to account for this and ensure for isntace that one of the behaviour is always positive
#and if not,  multiplying all behaviours by -1
df_pc1loading['scaleverticaltraveldistancefulllightperinsideh'] = np.where(df_pc1loading['scalefoodsameDurTimingr50final']>0, 
                                 df_pc1loading['scaleverticaltraveldistancefulllightperinsideh'], #where condition is True (>0:keep)
                                 df_pc1loading['scaleverticaltraveldistancefulllightperinsideh']*-1)
#df_pc1loading['midcumZ4hMorning'] = np.where(df_pc1loading['scalefoodsameDurTimingr50final']>0, 
#                                 df_pc1loading['midcumZ4hMorning'], #where condition is True
#                                 df_pc1loading['midcumZ4hMorning']*-1)
df_pc1loading['SleepingUppest'] = np.where(df_pc1loading['scalefoodsameDurTimingr50final']>0, 
                                 df_pc1loading['SleepingUppest'], #where condition is True
                                 df_pc1loading['SleepingUppest']*-1)
df_pc1loading['WentinWG'] = np.where(df_pc1loading['scalefoodsameDurTimingr50final']>0, 
                                 df_pc1loading['WentinWG'], #where condition is True
                                 df_pc1loading['WentinWG']*-1)
#Note: this behaviours have to be done after all others
df_pc1loading['scalefoodsameDurTimingr50final'] = np.where(df_pc1loading['scalefoodsameDurTimingr50final']>0, 
                                 df_pc1loading['scalefoodsameDurTimingr50final'], #where condition is True
                                 df_pc1loading['scalefoodsameDurTimingr50final']*-1)
df_pc1loading.head(5)
# Out:
# ['X2', 'X3', 'X4', 'X1']
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:19<00:00, 250.63it/s]
# (20000, 4)
#    scalefoodsameDurTimingr50final  \
# 0                       -0.520160
# 1                       -0.520160
# 2                       -0.520160
# 3                       -0.520160
# 4                       -0.544775
#
#    scaleverticaltraveldistancefulllightperinsideh  SleepingUppest  WentinWG
# 0                                       -0.658647        0.112399 -0.531963
# 1                                       -0.658647        0.112399 -0.531963
# 2                                       -0.658647        0.112399 -0.531963
# 3                                       -0.658647        0.112399 -0.531963
# 4                                       -0.636501        0.136555 -0.528621
#    scalefoodsameDurTimingr50final  \
# 0                        0.520160
# 1                        0.520160
# 2                        0.520160
# 3                        0.520160
# 4                        0.544775
#
#    scaleverticaltraveldistancefulllightperinsideh  SleepingUppest  WentinWG
# 0                                        0.658647       -0.112399  0.531963
# 1                                        0.658647       -0.112399  0.531963
# 2                                        0.658647       -0.112399  0.531963
# 3                                        0.658647       -0.112399  0.531963
# 4                                        0.636501       -0.136555  0.528621

# %% [markdown]
# ### visualise results

# %%
plt.figure(figsize=(13,1.3))
cmap_ = LinearSegmentedColormap.from_list('rg',["lightgrey", "black"], N=256) 
labels_ = np.array([['                   '] * len(li_mvt_pc)] * 2)
for i in range(0,len(li_mvt_pc)):
    labels_[0][i] = '%.2f' %round(comp1[i],2)+'\n  (±'+'%.2f' %round(np.std(abs(df_pc1loading[li_mvt_pc[i]])),2) +')'
    labels_[1][i] = '%.2f' %round(comp2[i],2)+'\n  (±'+'%.2f' %round(np.std(abs(df_pc2loading[li_mvt_pc[i]])),2) +')'
sns.heatmap(np.array([[i for i in comp1], [i for i in comp2]]), annot=labels_, fmt = '', cmap='RdYlGn',vmin=-1, vmax=1,
            yticklabels=['PC1 \n('+str(round(li_exvar[0]*100))+'%)', 'PC2 \n('+str(round(li_exvar[1]*100))+'%)'], 
            xticklabels=[dico_mvt_name[i] for i in li_mvt_pc]);
plt.yticks(rotation=0) 
plt.xticks(rotation=0) 
plt.savefig(os.path.join(path_extracted_data,'BS_PrincComp_loadings.png'),dpi=300,format='png',bbox_inches='tight')
plt.show();

# %% [markdown]
# ### visualise among behaviours correlation

# %% [raw]
# #slope of a fitted line = Cov(X,Y)/Var(X) = corr(X,Y) * SD(X) * SD(Y) /Var(X)
# #                                         = corr(X,Y) * sqrt(var(X)) * sqrt(var(Y)) /Var(X)
# #Reference: https://www.physicsforums.com/threads/slope-of-ls-line-cov-x-y-var-x-intuitive-explanation.880963/

# %%
li_mvt = ['scalefoodsameDurTimingr50final','scaleverticaltraveldistancefulllightperinsideh', 'midcumZ4hMorning',
          'SleepingUppest', 'WentinWG']

# %%
#choose color: https://matplotlib.org/stable/gallery/color/named_colors.html
#df[df['HenID'].isnull()].shape
df_plt = df[~df['HenID'].isnull()].pivot(index='HenID', columns='mvtvariable', values=['value_mean',
                                                                                       'lower','upper']).reset_index()
df_plt.columns = ['_'.join(col) for col in df_plt.columns.values] #joining name from different index
display(df_plt.head(3))
# Out:
#     HenID_  value_mean_SleepingUppest  value_mean_WentinWG  \
# 0    hen_1                   2.168087             2.482377
# 1   hen_10                  -4.072455            -1.155278
# 2  hen_101                  -1.056717             1.482310
#
#    value_mean_midcumZ4hMorning  value_mean_scalefoodsameDurTimingr50final  \
# 0                    -0.138005                                   0.035182
# 1                    -0.140978                                  -0.518432
# 2                    -0.043479                                   0.422137
#
#    value_mean_scaleverticaltraveldistancefulllightperinsideh  \
# 0                                          -0.238263
# 1                                          -0.556875
# 2                                           0.449101
#
#    lower_SleepingUppest  lower_WentinWG  lower_midcumZ4hMorning  \
# 0             -0.701850        0.446157               -0.231612
# 1             -5.840210       -2.284900               -0.221297
# 2             -2.144804        0.186286               -0.115040
#
#    lower_scalefoodsameDurTimingr50final  \
# 0                             -0.430900
# 1                             -0.870103
# 2                              0.080748
#
#    lower_scaleverticaltraveldistancefulllightperinsideh  upper_SleepingUppest  \
# 0                                          -0.653349                 5.433254
# 1                                          -0.932892                -2.491253
# 2                                           0.101407                 0.040973
#
#    upper_WentinWG  upper_midcumZ4hMorning  \
# 0        4.674269               -0.045641
# 1       -0.061911               -0.066420
# 2        2.869173                0.027654
#
#    upper_scalefoodsameDurTimingr50final  \
# 0                              0.479239
# 1                             -0.161925
# 2                              0.794990
#
#    upper_scaleverticaltraveldistancefulllightperinsideh
# 0                                           0.139143
# 1                                          -0.156775
# 2                                           0.798888

# %%
for mvt in li_mvt:
    df_plt['ERRORlower_'+mvt] = df_plt.apply(lambda x: x['value_mean_'+mvt]-x['lower_'+mvt], axis=1)
    df_plt['ERRORupper_'+mvt] = df_plt.apply(lambda x: x['upper_'+mvt]-x['value_mean_'+mvt], axis=1)
#small check
display(df_plt[['ERRORupper_'+mvt,'upper_'+mvt, 'ERRORlower_'+mvt,'lower_'+mvt,'value_mean_'+mvt]].head(5))
# Out:
#    ERRORupper_WentinWG  upper_WentinWG  ERRORlower_WentinWG  lower_WentinWG  \
# 0             2.191893        4.674269             2.036220        0.446157
# 1             1.093367       -0.061911             1.129622       -2.284900
# 2             1.386863        2.869173             1.296024        0.186286
# 3             1.714684        4.009018             1.580367        0.713967
# 4             1.184390        1.854599             1.152317       -0.482108
#
#    value_mean_WentinWG
# 0             2.482377
# 1            -1.155278
# 2             1.482310
# 3             2.294334
# 4             0.670209

# %%
#choose color: https://matplotlib.org/stable/gallery/color/named_colors.html
#df[df['HenID'].isnull()].shape
df_plt = df[~df['HenID'].isnull()].pivot(index='HenID', columns='mvtvariable', values=['value_mean',
                                                                                       'lower','upper']).reset_index()
df_plt.columns = ['_'.join(col) for col in df_plt.columns.values] #joining name from different index
display(df_plt.head(3))
#we plot the error, not the upper and lower bound value!!
for mvt in li_mvt:
    df_plt['ERRORlower_'+mvt] = df_plt.apply(lambda x: x['value_mean_'+mvt]-x['lower_'+mvt], axis=1)
    df_plt['ERRORupper_'+mvt] = df_plt.apply(lambda x: x['upper_'+mvt]-x['value_mean_'+mvt], axis=1)
#small check
display(df_plt[['ERRORupper_'+mvt,'upper_'+mvt, 'ERRORlower_'+mvt,'lower_'+mvt,'value_mean_'+mvt]].head(5))
for i in range(0,len(li_mvt)-1):
    for j in range(i+1,len(li_mvt)):
        mvtx = li_mvt[i]
        mvty = li_mvt[j]
        print(mvtx)
        print(mvty)
        cor_mvtx_mvty = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['value_mean'].iloc[0]
        cor_mvtx_mvty_upper = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['upper'].iloc[0]
        cor_mvtx_mvty_lower = df_cor_summarized[(df_cor_summarized[mvtx])&(df_cor_summarized[mvty])]['lower'].iloc[0]
        print(cor_mvtx_mvty)
        sd_mvtx = df_sd_summarized[df_sd_summarized['parameter']==mvtx+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvtx)
        sd_mvty = df_sd_summarized[df_sd_summarized['parameter']==mvty+'_Intercept']['value_mean'].iloc[0]
        print(sd_mvty)        
        slope = cor_mvtx_mvty*sd_mvtx*sd_mvty/(sd_mvtx*sd_mvtx)
        print(slope)
        #choose color:
        li_ = [mvtx, mvty]
        if ('scalefoodsameDurTimingr50final' in li_) & ('scaleverticaltraveldistancefulllightperinsideh' in li_):
            color_ = 'green'
        elif ('scalefoodsameDurTimingr50final' in li_) & ('WentinWG' in li_):
            color_ = 'yellowgreen' #lightsalmon
        elif ('scaleverticaltraveldistancefulllightperinsideh' in li_) & ('SleepingUppest' in li_):
            color_ = 'sandybrown'
        elif ('scaleverticaltraveldistancefulllightperinsideh' in li_) & ('WentinWG' in li_):
            color_ = 'darkgreen'
        else:
            color_ = 'black'
        plt.figure(figsize=(5,5))
        #ax = sns.scatterplot(data=df_plt, x='value_mean_'+mvtx,  y='value_mean_'+mvty)#,  size="size", sizes=(20, 200))
        plt.scatter(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(), color=color_, s=5)
        plt.errorbar(df_plt['value_mean_'+mvtx].tolist(), df_plt['value_mean_'+mvty].tolist(),
                     xerr=[df_plt['ERRORlower_'+mvtx].tolist(),df_plt['ERRORupper_'+mvtx].tolist()], 
                     yerr=[df_plt['ERRORlower_'+mvty].tolist(),df_plt['ERRORupper_'+mvty].tolist()],
                     fmt="o", color=color_, alpha=0.2,ms=5)
        plt.xlabel(mvtx)
        plt.ylabel(mvty)
        x_min = min(df_plt['value_mean_'+mvtx].tolist())
        y_min = x_min*slope
        x_max = max(df_plt['value_mean_'+mvtx].tolist())
        y_max = x_max*slope
        plt.plot([x_min, x_max], [y_min, y_max], color='black')
        text_ = 'r = '+"%.2f" % round(cor_mvtx_mvty,2)+' ['+"%.2f" % round(cor_mvtx_mvty_lower,2)+', '+"%.2f" % round(cor_mvtx_mvty_upper,2)+']'
        plt.text(max(df_plt['value_mean_'+mvtx].tolist())*(-0.08), max(df_plt['value_mean_'+mvty].tolist())*1.1, text_, fontsize=13)
        #plt.set_xlim([x_min, x_max])   
        plt.savefig(os.path.join(path_extracted_data,'BS_'+mvtx+'_'+mvty+'.png'),dpi=300,format='png',bbox_inches='tight')
        plt.show();
# Out:
#     HenID_  value_mean_SleepingUppest  value_mean_WentinWG  \
# 0    hen_1                   2.168087             2.482377
# 1   hen_10                  -4.072455            -1.155278
# 2  hen_101                  -1.056717             1.482310
#
#    value_mean_midcumZ4hMorning  value_mean_scalefoodsameDurTimingr50final  \
# 0                    -0.138005                                   0.035182
# 1                    -0.140978                                  -0.518432
# 2                    -0.043479                                   0.422137
#
#    value_mean_scaleverticaltraveldistancefulllightperinsideh  \
# 0                                          -0.238263
# 1                                          -0.556875
# 2                                           0.449101
#
#    lower_SleepingUppest  lower_WentinWG  lower_midcumZ4hMorning  \
# 0             -0.701850        0.446157               -0.231612
# 1             -5.840210       -2.284900               -0.221297
# 2             -2.144804        0.186286               -0.115040
#
#    lower_scalefoodsameDurTimingr50final  \
# 0                             -0.430900
# 1                             -0.870103
# 2                              0.080748
#
#    lower_scaleverticaltraveldistancefulllightperinsideh  upper_SleepingUppest  \
# 0                                          -0.653349                 5.433254
# 1                                          -0.932892                -2.491253
# 2                                           0.101407                 0.040973
#
#    upper_WentinWG  upper_midcumZ4hMorning  \
# 0        4.674269               -0.045641
# 1       -0.061911               -0.066420
# 2        2.869173                0.027654
#
#    upper_scalefoodsameDurTimingr50final  \
# 0                              0.479239
# 1                             -0.161925
# 2                              0.794990
#
#    upper_scaleverticaltraveldistancefulllightperinsideh
# 0                                           0.139143
# 1                                          -0.156775
# 2                                           0.798888
#    ERRORupper_WentinWG  upper_WentinWG  ERRORlower_WentinWG  lower_WentinWG  \
# 0             2.191893        4.674269             2.036220        0.446157
# 1             1.093367       -0.061911             1.129622       -2.284900
# 2             1.386863        2.869173             1.296024        0.186286
# 3             1.714684        4.009018             1.580367        0.713967
# 4             1.184390        1.854599             1.152317       -0.482108
#
#    value_mean_WentinWG
# 0             2.482377
# 1            -1.155278
# 2             1.482310
# 3             2.294334
# 4             0.670209
# scalefoodsameDurTimingr50final
# scaleverticaltraveldistancefulllightperinsideh
# 0.466077362818603
# 0.555801108308764
# 0.827020660081571
# 0.6935135653475288
# scalefoodsameDurTimingr50final
# midcumZ4hMorning
# -0.0824494332279047
# 0.555801108308764
# 0.138384903871554
# -0.020528488916163233
# scalefoodsameDurTimingr50final
# SleepingUppest
# -0.209278898024454
# 0.555801108308764
# 2.26003706090946
# -0.8509843872761843
# scalefoodsameDurTimingr50final
# WentinWG
# 0.267420547333166
# 0.555801108308764
# 2.10867478439155
# 1.014576899109689
# scaleverticaltraveldistancefulllightperinsideh
# midcumZ4hMorning
# -0.0224860363355574
# 0.827020660081571
# 0.138384903871554
# -0.003762575866534536
# scaleverticaltraveldistancefulllightperinsideh
# SleepingUppest
# -0.22954395077251
# 0.827020660081571
# 2.26003706090946
# -0.6272852189717739
# scaleverticaltraveldistancefulllightperinsideh
# WentinWG
# 0.496877344568195
# 0.827020660081571
# 2.10867478439155
# 1.2669003061217867
# midcumZ4hMorning
# SleepingUppest
# -0.0372004604370543
# 0.138384903871554
# 2.26003706090946
# -0.607540395798338
# midcumZ4hMorning
# WentinWG
# -0.0380971345644939
# 0.138384903871554
# 2.10867478439155
# -0.5805146715156506
# SleepingUppest
# WentinWG
# 0.101757786606917
# 2.26003706090946
# 2.10867478439155
# 0.09494272569457575

# %% [markdown]
# # Repeatability

# %%
#search for the repeatability csv files, download each file and concatenate them
li_df = []
for path_ in glob.glob(os.path.join(path_extracted_data,'R_estimates_*.csv')):
    print('--------------------- files %s'%path_.split('\\')[-1])
    df_ = pd.read_csv(path_, sep=',', index_col=0)
    print(df_.shape) 
    display(df_.head(3))
    li_df.append(df_)
print('------------------------- ALL TOGETHER:')
df_R = pd.concat(li_df)  
df_R['VI_LL'] = df_R['li_VI'].map(lambda x: float(x.split(', ')[0].split('[')[1]))
df_R['VI_UL'] = df_R['li_VI'].map(lambda x: float(x.split(', ')[1].strip(']')))
df_R['VE_LL'] = df_R['li_VE'].map(lambda x: float(x.split(', ')[0].split('[')[1]))
df_R['VE_UL'] = df_R['li_VE'].map(lambda x: float(x.split(', ')[1].strip(']')))
df_R['VI'] = df_R['li_VI'].map(lambda x:float(x.split(' ')[0]))
df_R['VE'] = df_R['li_VE'].map(lambda x:float(x.split(' ')[0]))
display(df_R[['li_VI','li_VE','VI','VE','VI_LL','VI_UL','VE_LL','VE_UL']].head(3))
df_R['li_mvt_named'] = df_R['li_mvt'].map(lambda x: dico_mvt_name[x])
print(df_R.shape) 
display(df_R.head(3))
# Out:
# --------------------- files R_estimates_MZ4.csv
# (6, 13)
#        li_R    li_CIL    li_CIU  li_CILbasic  li_CIUbasic li_BStype  \
# 1  0.516955  0.479049  0.561229     0.397739     0.479919      time
# 2  0.690166  0.597521  0.783263     0.267171     0.452913       LP2
# 3  0.584569  0.410891  0.751580    -0.051347     0.289342      LP10
#
#                  li_mvt  li_mvtmean                    li_VI  \
# 1  mid_cum_Z4_h_Morning    4.498069  0.0227 [0.0202, 0.0256]
# 2  mid_cum_Z4_h_Morning    4.365981  0.0235 [0.0191, 0.0283]
# 3  mid_cum_Z4_h_Morning    5.329441   0.023 [0.0156, 0.0322]
#
#                      li_VE         li_popintercept                   li_CVI  \
# 1  0.0212 [0.0193, 0.0229]  4.385 [4.3339, 4.4353]  0.0719 [0.0678, 0.0765]
# 2  0.0105 [0.0074, 0.0142]  4.2545 [4.171, 4.3366]  0.0742 [0.0672, 0.0819]
# 3  0.0163 [0.0098, 0.0244]  5.275 [5.1579, 5.4022]  0.0658 [0.0544, 0.0782]
#
#                     li_CVE
# 1  0.0694 [0.0664, 0.0724]
# 2  0.0496 [0.0418, 0.0576]
# 3   0.0553 [0.0432, 0.068]
# --------------------- files R_estimates_SNU.csv
# (6, 10)
#        li_R    li_CIL    li_CIU  li_ngroup  li_nobs li_BStype  \
# 1  0.479898  0.375183  0.540256        194     3196      time
# 2  0.555357  0.338020  0.696312        157      468       LP2
# 3  0.812636  0.652210  0.975295        153      444      LP10
#
#             li_mvt  li_mvtmean                       li_VI  \
# 1  Sleeping_Uppest    0.702441     4.4144 [3.0213, 5.5413]
# 2  Sleeping_Uppest    0.685897    5.7974 [2.4709, 11.2963]
# 3  Sleeping_Uppest    0.585586  17.8725 [7.7162, 162.8591]
#
#                      li_VE
# 1  4.7843 [4.4535, 5.3423]
# 2  4.6416 [4.3344, 5.3953]
# 3  4.1207 [4.0209, 4.5154]
# --------------------- files R_estimates_WG.csv
# (6, 10)
#        li_R    li_CIL    li_CIU  li_ngroup  li_nobs li_BStype    li_mvt  \
# 1  0.495627  0.407240  0.557160        194     3196      time  WentinWG
# 2  0.599639  0.391043  0.685535        157      468       LP2  WentinWG
# 3  0.593369  0.347224  0.769232        153      444      LP10  WentinWG
#
#    li_mvtmean                     li_VI                    li_VE
# 1    0.646746   4.3011 [3.0493, 5.3606]    4.377 [4.147, 4.6539]
# 2    0.617521   6.3413 [2.7791, 9.5586]  4.2339 [4.0812, 4.6416]
# 3    0.691441  6.8396 [2.6394, 21.4634]  4.6871 [4.3748, 5.2706]
# --------------------- files R_estimates_VTD.csv
# (6, 13)
#        li_R    li_CIL    li_CIU  li_ngroup  li_nobs li_BStype  \
# 1  0.659077  0.605899  0.704475        194     3196      time
# 2  0.786395  0.735052  0.832179        157      468       LP2
# 3  0.781175  0.727389  0.831525        153      444      LP10
#
#                                           li_mvt  li_mvtmean  \
# 1  vertical_travel_distance_fulllight_perinsideh    4.310258
# 2  vertical_travel_distance_fulllight_perinsideh    3.882524
# 3  vertical_travel_distance_fulllight_perinsideh    3.421423
#
#                      li_VI                    li_VE          li_popintercept  \
# 1   2.1752 [2.0159, 2.329]  1.1252 [1.0774, 1.1818]  4.2406 [3.9287, 4.5808]
# 2  2.1004 [1.9076, 2.3104]     0.5705 [0.5, 0.6533]  4.1882 [3.7681, 4.5909]
# 3  1.2722 [1.1551, 1.4065]  0.3564 [0.3157, 0.4079]  3.4221 [3.1134, 3.7371]
#
#                     li_CVI                   li_CVE
# 1  0.7162 [0.6794, 0.7553]  0.5151 [0.4932, 0.5406]
# 2  0.7082 [0.6654, 0.7613]  0.3691 [0.3422, 0.4019]
# 3  0.6097 [0.5743, 0.6571]  0.3227 [0.2998, 0.3513]
# --------------------- files R_estimates_FOOD.csv
# (6, 13)
#        li_R    li_CIL    li_CIU  li_ngroup  li_nobs li_BStype  \
# 1  0.334778  0.281040  0.385040        194     3196      time
# 2  0.362964  0.267997  0.461123        157      468       LP2
# 3  0.368903  0.272744  0.481675        153      444      LP10
#
#                          li_mvt  li_mvtmean                    li_VI  \
# 1  food_sameDurTiming_r50_final    0.207158  0.0286 [0.0255, 0.0315]
# 2  food_sameDurTiming_r50_final    0.207158  0.0271 [0.0227, 0.0322]
# 3  food_sameDurTiming_r50_final    0.251194  0.0333 [0.0274, 0.0402]
#
#                      li_VE          li_popintercept  li_CVI  li_CVE
# 1  0.0568 [0.0542, 0.0596]  0.2778 [0.2177, 0.3399]     NaN     NaN
# 2   0.0476 [0.042, 0.0546]  0.2678 [0.1965, 0.3445]     NaN     NaN
# 3   0.057 [0.0499, 0.0655]  0.2195 [0.1336, 0.3114]     NaN     NaN
# ------------------------- ALL TOGETHER:
#                      li_VI                    li_VE      VI      VE   VI_LL  \
# 1  0.0227 [0.0202, 0.0256]  0.0212 [0.0193, 0.0229]  0.0227  0.0212  0.0202
# 2  0.0235 [0.0191, 0.0283]  0.0105 [0.0074, 0.0142]  0.0235  0.0105  0.0191
# 3   0.023 [0.0156, 0.0322]  0.0163 [0.0098, 0.0244]  0.0230  0.0163  0.0156
#
#     VI_UL   VE_LL   VE_UL
# 1  0.0256  0.0193  0.0229
# 2  0.0283  0.0074  0.0142
# 3  0.0322  0.0098  0.0244
# (30, 22)
#        li_R    li_CIL    li_CIU  li_CILbasic  li_CIUbasic li_BStype  \
# 1  0.516955  0.479049  0.561229     0.397739     0.479919      time
# 2  0.690166  0.597521  0.783263     0.267171     0.452913       LP2
# 3  0.584569  0.410891  0.751580    -0.051347     0.289342      LP10
#
#                  li_mvt  li_mvtmean                    li_VI  \
# 1  mid_cum_Z4_h_Morning    4.498069  0.0227 [0.0202, 0.0256]
# 2  mid_cum_Z4_h_Morning    4.365981  0.0235 [0.0191, 0.0283]
# 3  mid_cum_Z4_h_Morning    5.329441   0.023 [0.0156, 0.0322]
#
#                      li_VE  ...                   li_CVE li_ngroup li_nobs  \
# 1  0.0212 [0.0193, 0.0229]  ...  0.0694 [0.0664, 0.0724]       NaN     NaN
# 2  0.0105 [0.0074, 0.0142]  ...  0.0496 [0.0418, 0.0576]       NaN     NaN
# 3  0.0163 [0.0098, 0.0244]  ...   0.0553 [0.0432, 0.068]       NaN     NaN
#
#     VI_LL   VI_UL   VE_LL   VE_UL      VI      VE            li_mvt_named
# 1  0.0202  0.0256  0.0193  0.0229  0.0227  0.0212  mid-nestbox zone usage
# 2  0.0191  0.0283  0.0074  0.0142  0.0235  0.0105  mid-nestbox zone usage
# 3  0.0156  0.0322  0.0098  0.0244  0.0230  0.0163  mid-nestbox zone usage
#
# [3 rows x 22 columns]

# %%
#add nice text to output in the paper (i.e. with specific number of values after the comma, adding useless 0)
#add R and 95% interval as a text column
df_R['text'] = df_R.apply(lambda x: ("%.2f" % x['li_R'])+' ['+("%.2f" % x['li_CIL'])+', '+("%.2f" % x['li_CIU'])+']', 
                          axis=1)
df_R['li_VI'] = df_R.apply(lambda x: ("%.4f" % x['VI'])+' ['+("%.4f" % x['VI_LL'])+', '+("%.4f" % x['VI_UL'])+']', 
                          axis=1)
df_R['li_VE'] = df_R.apply(lambda x: ("%.4f" % x['VE'])+' ['+("%.4f" % x['VE_LL'])+', '+("%.4f" % x['VE_UL'])+']', 
                          axis=1)
df_R.head(3)
# Out:
#        li_R    li_CIL    li_CIU  li_CILbasic  li_CIUbasic li_BStype  \
# 1  0.516955  0.479049  0.561229     0.397739     0.479919      time
# 2  0.690166  0.597521  0.783263     0.267171     0.452913       LP2
# 3  0.584569  0.410891  0.751580    -0.051347     0.289342      LP10
#
#                  li_mvt  li_mvtmean                    li_VI  \
# 1  mid_cum_Z4_h_Morning    4.498069  0.0227 [0.0202, 0.0256]
# 2  mid_cum_Z4_h_Morning    4.365981  0.0235 [0.0191, 0.0283]
# 3  mid_cum_Z4_h_Morning    5.329441  0.0230 [0.0156, 0.0322]
#
#                      li_VE  ... li_ngroup li_nobs   VI_LL   VI_UL   VE_LL  \
# 1  0.0212 [0.0193, 0.0229]  ...       NaN     NaN  0.0202  0.0256  0.0193
# 2  0.0105 [0.0074, 0.0142]  ...       NaN     NaN  0.0191  0.0283  0.0074
# 3  0.0163 [0.0098, 0.0244]  ...       NaN     NaN  0.0156  0.0322  0.0098
#
#     VE_UL      VI      VE            li_mvt_named               text
# 1  0.0229  0.0227  0.0212  mid-nestbox zone usage  0.52 [0.48, 0.56]
# 2  0.0142  0.0235  0.0105  mid-nestbox zone usage  0.69 [0.60, 0.78]
# 3  0.0244  0.0230  0.0163  mid-nestbox zone usage  0.58 [0.41, 0.75]
#
# [3 rows x 23 columns]

# %%
#create a matrix with each row corresponding to a movement behavior and each column a situation (over time, wihtin a context,
#across context). sort matrix by specific order
dico_bstype_order = {'AC':6, 'LP10':5, 'LP2':2, 'VD':4, 'cold':3, 'time':1}
dico_bstype_name = {'AC':'AC', 'LP10':'LLS', 'LP2':'ELS', 'VD':'VD', 'cold':'CET', 'time':'OT'}
df_R['order'] = df_R['li_BStype'].map(lambda x: dico_bstype_order[x])
df_R['li_BStype'] = df_R['li_BStype'].map(lambda x: dico_bstype_name[x])
df_R = df_R.sort_values(['order'])
#all R with CI
df_plt = df_R.pivot(index='li_mvt_named', columns='li_BStype', values='text').reset_index()
df_plt = df_plt[['li_mvt_named','OT','ELS','CET','VD','LLS','AC']]
dico_bstype_name = {'AC':'across context',
                    'OT':'over time',
                    'LLS':'late life stage',
                    'ELS':'early life stage',
                    'VD':'vaccination disturbance',
                    'CET':'cold external temperature'}
df_plt = df_plt.rename(columns=dico_bstype_name)
#save
df_plt.to_csv(os.path.join(path_extracted_data,'Table1.csv'), index=False, sep=',')
df_plt
# Out:
# li_BStype                 li_mvt_named          over time   early life stage  \
# 0          fresh food experience index  0.33 [0.28, 0.39]  0.36 [0.27, 0.46]
# 1                     has been outside  0.50 [0.41, 0.56]  0.60 [0.39, 0.69]
# 2                has slept on top tier  0.48 [0.38, 0.54]  0.56 [0.34, 0.70]
# 3               mid-nestbox zone usage  0.52 [0.48, 0.56]  0.69 [0.60, 0.78]
# 4          vertical travelled distance  0.66 [0.61, 0.70]  0.79 [0.74, 0.83]
#
# li_BStype cold external temperature vaccination disturbance  \
# 0                 0.42 [0.33, 0.52]       0.23 [0.13, 0.35]
# 1                 0.55 [0.33, 0.64]       0.30 [0.10, 0.38]
# 2                 0.54 [0.31, 0.68]       0.50 [0.27, 0.72]
# 3                 0.71 [0.63, 0.79]       0.57 [0.44, 0.70]
# 4                 0.73 [0.67, 0.79]       0.52 [0.43, 0.61]
#
# li_BStype    late life stage     across context
# 0          0.37 [0.27, 0.48]  0.24 [0.16, 0.33]
# 1          0.59 [0.35, 0.77]  0.25 [0.10, 0.31]
# 2          0.81 [0.65, 0.98]  0.41 [0.22, 0.51]
# 3          0.58 [0.41, 0.75]  0.47 [0.36, 0.59]
# 4          0.78 [0.73, 0.83]  0.48 [0.40, 0.56]

# %% [markdown]
# ### visualise

# %%
cmap_ = LinearSegmentedColormap.from_list('rg',["lightgrey", "black"], N=256) 
df_plt = df_R.pivot(index='li_mvt_named', columns='li_BStype', values='li_R')#.reset_index()
df_plt = df_plt[['OT','ELS','CET','VD','LLS','AC']]
#df_plt
li_col = list(df_R['li_BStype'].unique())

########################## normalize by row ##########################
plt.figure(figsize=(5,2))
df_plt_nr = df_plt.copy()
for mv in list(df_plt_nr.index): 
    df_plt_nr.loc[mv] = (df_plt_nr.loc[mv]-df_plt_nr.loc[mv].min())/(df_plt_nr.loc[mv].max()-df_plt_nr.loc[mv].min())
display(df_plt_nr)
sns.heatmap(df_plt_nr, cmap=cmap_, annot=False,
        xticklabels=list(df_plt_nr.columns), yticklabels=list(df_plt_nr.index),linewidths=1.8)
plt.xlabel('');
plt.ylabel('');
plt.title('Repeatability normalized by rows \n (comparison between contexts)', size=10.5)
plt.savefig(os.path.join(path_extracted_data,'R_normalizedrowwise.png'),dpi=300,format='png',bbox_inches='tight')
plt.show();

########################## normalize by columns ##########################
plt.figure(figsize=(5,2))
df_plt_nc = (df_plt[li_col]-df_plt[li_col].min())/(df_plt[li_col].max()-df_plt[li_col].min())
display(df_plt_nc)
sns.heatmap(df_plt_nc, cmap=cmap_, annot=False,
            xticklabels=list(df_plt_nc.columns), yticklabels=list(df_plt_nc.index),linewidths=1.8)
plt.xlabel('');
plt.ylabel('');
plt.title('Repeatability normalized by columns \n (comparison between behaviours)', size=10.5)
plt.savefig(os.path.join(path_extracted_data,'R_normalizedcolumnwise.png'),dpi=300,format='png',bbox_inches='tight')
plt.show();
# Out:
# li_BStype                          OT      ELS       CET        VD       LLS  \
# li_mvt_named
# fresh food experience index  0.536664  0.68323  1.000000  0.000000  0.714117
# has been outside             0.705209  1.00000  0.860845  0.158155  0.982230
# has slept on top tier        0.173401  0.36086  0.312080  0.218727  1.000000
# mid-nestbox zone usage       0.197782  0.90352  1.000000  0.425928  0.473270
# vertical travelled distance  0.585696  1.00000  0.822346  0.148210  0.983016
#
# li_BStype                          AC
# li_mvt_named
# fresh food experience index  0.062451
# has been outside             0.000000
# has slept on top tier        0.000000
# mid-nestbox zone usage       0.000000
# vertical travelled distance  0.000000
# li_BStype                          OT       ELS       CET        VD       LLS  \
# li_mvt_named
# fresh food experience index  0.000000  0.000000  0.000000  0.000000  0.000000
# has been outside             0.495989  0.558948  0.411340  0.208082  0.505858
# has slept on top tier        0.447486  0.454368  0.363214  0.780868  1.000000
# mid-nestbox zone usage       0.561756  0.772742  0.941689  1.000000  0.486025
# vertical travelled distance  1.000000  1.000000  1.000000  0.858475  0.929099
#
# li_BStype                          AC
# li_mvt_named
# fresh food experience index  0.000000
# has been outside             0.013682
# has slept on top tier        0.707041
# mid-nestbox zone usage       0.954658
# vertical travelled distance  1.000000

# %% [markdown]
# ### check #obs and #individual

# %%
#check metadata
#small check: (the gamma  : nestbox zone behaviour) family should have NAN everywhere, but is base dont he exact same dataset
display(df_R[['li_BStype','li_mvt','li_ngroup','li_nobs']].sort_values(['li_BStype','li_mvt'])) #CORRECT!
df_R[df_R['li_mvt']=='vertical_travel_distance_fulllight_perinsideh'][['li_BStype','li_ngroup','li_nobs']]
# Out:
#   li_BStype                                         li_mvt  li_ngroup  li_nobs
# 6        AC                                Sleeping_Uppest      190.0    613.0
# 6        AC                                       WentinWG      190.0    613.0
# 6        AC                   food_sameDurTiming_r50_final      190.0    613.0
# 6        AC                           mid_cum_Z4_h_Morning        NaN      NaN
# 6        AC  vertical_travel_distance_fulllight_perinsideh      190.0    613.0
# 4       CET                                Sleeping_Uppest      159.0    471.0
# 4       CET                                       WentinWG      159.0    471.0
# 4       CET                   food_sameDurTiming_r50_final      159.0    471.0
# 4       CET                           mid_cum_Z4_h_Morning        NaN      NaN
# 4       CET  vertical_travel_distance_fulllight_perinsideh      159.0    471.0
# 2       ELS                                Sleeping_Uppest      157.0    468.0
# 2       ELS                                       WentinWG      157.0    468.0
# 2       ELS                   food_sameDurTiming_r50_final      157.0    468.0
# 2       ELS                           mid_cum_Z4_h_Morning        NaN      NaN
# 2       ELS  vertical_travel_distance_fulllight_perinsideh      157.0    468.0
# 3       LLS                                Sleeping_Uppest      153.0    444.0
# 3       LLS                                       WentinWG      153.0    444.0
# 3       LLS                   food_sameDurTiming_r50_final      153.0    444.0
# 3       LLS                           mid_cum_Z4_h_Morning        NaN      NaN
# 3       LLS  vertical_travel_distance_fulllight_perinsideh      153.0    444.0
# 1        OT                                Sleeping_Uppest      194.0   3196.0
# 1        OT                                       WentinWG      194.0   3196.0
# 1        OT                   food_sameDurTiming_r50_final      194.0   3196.0
# 1        OT                           mid_cum_Z4_h_Morning        NaN      NaN
# 1        OT  vertical_travel_distance_fulllight_perinsideh      194.0   3196.0
# 5        VD                                Sleeping_Uppest      193.0    468.0
# 5        VD                                       WentinWG      193.0    468.0
# 5        VD                   food_sameDurTiming_r50_final      193.0    468.0
# 5        VD                           mid_cum_Z4_h_Morning        NaN      NaN
# 5        VD  vertical_travel_distance_fulllight_perinsideh      193.0    468.0
#   li_BStype  li_ngroup  li_nobs
# 1        OT      194.0   3196.0
# 2       ELS      157.0    468.0
# 4       CET      159.0    471.0
# 5        VD      193.0    468.0
# 3       LLS      153.0    444.0
# 6        AC      190.0    613.0

# %%
#verification of R based on VI, VE
#in the binary the VE is the residual variance, which is define a s w(math.pi**2/3) innakawaga paper
#in the gamma the VE is define as trigamma(shape) innakawaga paper
df_R['verification'] = df_R.apply(lambda x: x['VI']/(x['VI']+x['VE']), axis=1)
df_R['isequal'] = df_R.apply(lambda x: x['li_R']-x['verification']<0.01, axis=1)
if df_R[~df_R['isequal']].shape[0]!=0:
    print('ERROR in your within / between individual variance!')
    display(df_R[~df_R['isequal']][['li_BStype','li_R','li_mvt','verification','VI','VE']].head(15))
    sys.exit()

# %%
dico_bstype_name = {'AC':'across context',
                    'OT':'over time',
                    'LLS':'late life stage',
                    'ELS':'early life stage',
                    'VD':'vaccination disturbance',
                    'CET':'cold external temperature'}
df_VIVEM = df_R.sort_values(['li_mvt'])[['li_BStype','li_mvt','li_VI','li_VE','li_mvtmean']].copy()
df_VIVEM['li_mvt'] = df_VIVEM['li_mvt'].apply(lambda x: dico_mvt_name[x])
df_VIVEM['li_BStype'] = df_VIVEM['li_BStype'].apply(lambda x: dico_bstype_name[x])
df_VIVEM.rename(columns={'li_mvt': 'movement behaviour', 'li_BStype':'situations',
                        'li_VI':'between-individual variance',
                        'li_VE':'within-individual variance',
                        'li_mvtmean':'trait meant'}, inplace=True)
df_VIVEM.to_csv(os.path.join(path_extracted_data,'BS_df_VI_VE_TraitMean.csv'), index=False, sep=',')
df_VIVEM
# Out:
#                   situations           movement behaviour  \
# 6             across context        has slept on top tier
# 1                  over time        has slept on top tier
# 3            late life stage        has slept on top tier
# 2           early life stage        has slept on top tier
# 5    vaccination disturbance        has slept on top tier
# 4  cold external temperature        has slept on top tier
# 6             across context             has been outside
# 1                  over time             has been outside
# 3            late life stage             has been outside
# 2           early life stage             has been outside
# 5    vaccination disturbance             has been outside
# 4  cold external temperature             has been outside
# 3            late life stage  fresh food experience index
# 5    vaccination disturbance  fresh food experience index
# 1                  over time  fresh food experience index
# 4  cold external temperature  fresh food experience index
# 2           early life stage  fresh food experience index
# 6             across context  fresh food experience index
# 5    vaccination disturbance       mid-nestbox zone usage
# 2           early life stage       mid-nestbox zone usage
# 3            late life stage       mid-nestbox zone usage
# 1                  over time       mid-nestbox zone usage
# 6             across context       mid-nestbox zone usage
# 4  cold external temperature       mid-nestbox zone usage
# 4  cold external temperature  vertical travelled distance
# 2           early life stage  vertical travelled distance
# 5    vaccination disturbance  vertical travelled distance
# 3            late life stage  vertical travelled distance
# 1                  over time  vertical travelled distance
# 6             across context  vertical travelled distance
#
#   between-individual variance within-individual variance  trait meant
# 6     3.2504 [1.4561, 4.9528]    4.6755 [4.4202, 5.2933]     0.690049
# 1     4.4144 [3.0213, 5.5413]    4.7843 [4.4535, 5.3423]     0.702441
# 3  17.8725 [7.7162, 162.8591]    4.1207 [4.0209, 4.5154]     0.585586
# 2    5.7974 [2.4709, 11.2963]    4.6416 [4.3344, 5.3953]     0.685897
# 5    4.7942 [1.8252, 15.1296]    4.8300 [4.5294, 5.7079]     0.707265
# 4    5.4575 [2.3229, 12.7610]    4.7297 [4.4317, 5.4838]     0.696391
# 6     1.3285 [0.4789, 1.8552]    4.0544 [4.0024, 4.1853]     0.557912
# 1     4.3011 [3.0493, 5.3606]    4.3770 [4.1470, 4.6539]     0.646746
# 3    6.8396 [2.6394, 21.4634]    4.6871 [4.3748, 5.2706]     0.691441
# 2     6.3413 [2.7791, 9.5586]    4.2339 [4.0812, 4.6416]     0.617521
# 5     1.8258 [0.5130, 2.6556]    4.2078 [4.0581, 4.4717]     0.611111
# 4     5.1074 [2.0420, 7.2195]    4.1696 [4.0305, 4.4858]     0.600849
# 3     0.0333 [0.0274, 0.0402]    0.0570 [0.0499, 0.0655]     0.251194
# 5     0.0151 [0.0123, 0.0185]    0.0500 [0.0442, 0.0569]     0.200556
# 1     0.0286 [0.0255, 0.0315]    0.0568 [0.0542, 0.0596]     0.207158
# 4     0.0324 [0.0273, 0.0386]    0.0440 [0.0385, 0.0506]     0.228705
# 2     0.0271 [0.0227, 0.0322]    0.0476 [0.0420, 0.0546]     0.207158
# 6     0.0186 [0.0152, 0.0223]    0.0579 [0.0515, 0.0648]     0.208320
# 5     0.0241 [0.0175, 0.0308]    0.0179 [0.0124, 0.0237]     4.485654
# 2     0.0235 [0.0191, 0.0283]    0.0105 [0.0074, 0.0142]     4.365981
# 3     0.0230 [0.0156, 0.0322]    0.0163 [0.0098, 0.0244]     5.329441
# 1     0.0227 [0.0202, 0.0256]    0.0212 [0.0193, 0.0229]     4.498069
# 6     0.0173 [0.0127, 0.0229]    0.0196 [0.0147, 0.0247]     4.629122
# 4     0.0277 [0.0232, 0.0320]    0.0111 [0.0081, 0.0145]     4.242055
# 4     2.4867 [2.2420, 2.7667]    0.9113 [0.8048, 1.0435]     4.249749
# 2     2.1004 [1.9076, 2.3104]    0.5705 [0.5000, 0.6533]     3.882524
# 5     1.6241 [1.4019, 1.8718]    1.4715 [1.2945, 1.6906]     4.312052
# 3     1.2722 [1.1551, 1.4065]    0.3564 [0.3157, 0.4079]     3.421423
# 1     2.1752 [2.0159, 2.3290]    1.1252 [1.0774, 1.1818]     4.310258
# 6     1.4117 [1.2358, 1.6634]    1.5349 [1.3796, 1.7226]     3.867475

# %% [markdown]
# ### Dataframe for metadata significance

# %%
dico_c_meannbr = {'OT':60, 
                  'ELS':9, 
                  'CET':9, 
                  'VD':85, 
                  'LLS':9, 
                  'AC':128}
df_R['meannbrdays'] = df_R['li_BStype'].map(lambda x: dico_c_meannbr[x])
#remove the outlier
df_R[['li_R','li_mvt','li_BStype','meannbrdays','VI','VE']].to_csv(os.path.join(path_extracted_data,'BS_lm_metadata.csv'), index=False, sep=',')
df_R.head(3)
# Out:
#        li_R    li_CIL    li_CIU  li_ngroup  li_nobs li_BStype  \
# 1  0.334778  0.281040  0.385040      194.0   3196.0        OT
# 1  0.659077  0.605899  0.704475      194.0   3196.0        OT
# 1  0.479898  0.375183  0.540256      194.0   3196.0        OT
#
#                                           li_mvt  li_mvtmean  \
# 1                   food_sameDurTiming_r50_final    0.207158
# 1  vertical_travel_distance_fulllight_perinsideh    4.310258
# 1                                Sleeping_Uppest    0.702441
#
#                      li_VI                    li_VE  ...   VE_LL   VE_UL  \
# 1  0.0286 [0.0255, 0.0315]  0.0568 [0.0542, 0.0596]  ...  0.0542  0.0596
# 1  2.1752 [2.0159, 2.3290]  1.1252 [1.0774, 1.1818]  ...  1.0774  1.1818
# 1  4.4144 [3.0213, 5.5413]  4.7843 [4.4535, 5.3423]  ...  4.4535  5.3423
#
#        VI      VE                 li_mvt_named               text  order  \
# 1  0.0286  0.0568  fresh food experience index  0.33 [0.28, 0.39]      1
# 1  2.1752  1.1252  vertical travelled distance  0.66 [0.61, 0.70]      1
# 1  4.4144  4.7843        has slept on top tier  0.48 [0.38, 0.54]      1
#
#    verification  isequal  meannbrdays
# 1      0.334895     True           60
# 1      0.659072     True           60
# 1      0.479894     True           60
#
# [3 rows x 27 columns]

# %%
plt.hist(df_R['li_R']);

# %%
dico_mvt_name
# Out:
# {'scalefoodsameDurTimingr50final': 'fresh food experience index',
#  'scaleverticaltraveldistancefulllightperinsideh': 'vertical travelled distance',
#  'midcumZ4hMorning': 'mid-nestbox zone usage',
#  'SleepingUppest': 'has slept on top tier',
#  'WentinWG': 'has been outside',
#  'food_sameDurTiming_r50_final': 'fresh food experience index',
#  'Sleeping_Uppest': 'has slept on top tier',
#  'vertical_travel_distance_fulllight_perinsideh': 'vertical travelled distance',
#  'mid_cum_Z4_h_Morning': 'mid-nestbox zone usage'}

# %%
df_ = pd.melt(df_R, id_vars=['li_mvt','li_BStype','meannbrdays'], value_vars=['VI','VE'], value_name = 'value')
dico_V_named = {'VI':'between-individual \n variance', 'VE':'within-individual \n variance'}
df_['variable'] = df_['variable'].map(lambda x: dico_V_named[x])
dico_mvt_name2 = {'WentinWG': 'has been outside',
                 'food_sameDurTiming_r50_final': 'fresh food experience \nindex',
                 'Sleeping_Uppest': 'has slept on top tier',
                 'vertical_travel_distance_fulllight_perinsideh': 'vertical travelled \ndistance',
                 'mid_cum_Z4_h_Morning': 'mid-nestbox zone \nusage'}
df_['li_mvt_named'] = df_['li_mvt'].map(lambda x: dico_mvt_name2[x])
pal_ = {'between-individual \n variance':'black', 'within-individual \n variance':'grey'}
display(df_.head(3))
plt.figure(figsize=(10,1.1))
l=1
c=5
for i,(mvt, df_plt) in enumerate(df_.groupby(['li_mvt_named'])):
    plt.subplot(l,c,i+1)
    plt.ylim(0,df_plt['value'].max()*1.1)
    if i==0:
        sns.lineplot(x='meannbrdays',y='value', data=df_plt, hue='variable', palette=pal_, legend=True);
        plt.legend(bbox_to_anchor=(-0.04, 0), loc='lower right', borderaxespad=0)
    else:
        sns.lineplot(x='meannbrdays',y='value', data=df_plt, hue='variable', palette=pal_, legend=False);
    if i==2:
        plt.xlabel('mean number of days between any 2 observations')
    else:
        plt.xlabel('')
    plt.ylabel('')
    plt.yticks([])
    plt.title(mvt, size=10)
    #plt.show();
plt.savefig(os.path.join(path_extracted_data,'Within_between_var.png'),dpi=300,format='png',bbox_inches='tight')
# Out:
#                                           li_mvt li_BStype  meannbrdays  \
# 0                   food_sameDurTiming_r50_final        OT           60
# 1  vertical_travel_distance_fulllight_perinsideh        OT           60
# 2                                Sleeping_Uppest        OT           60
#
#                          variable   value                   li_mvt_named
# 0  between-individual \n variance  0.0286  fresh food experience \nindex
# 1  between-individual \n variance  2.1752  vertical travelled \ndistance
# 2  between-individual \n variance  4.4144          has slept on top tier
