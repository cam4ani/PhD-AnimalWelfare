# %%
library(dplyr) #%>%
library(tidyr) #drop_na
library(piecewiseSEM) 
library(nlme)
library(lme4) #glmer
library(diagram) #visual
library(lcsm) #latent change score model
# Out:
# Warning message:
# "le package 'dplyr' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'dplyr'
#
#
# Les objets suivants sont masqués depuis 'package:stats':
#
#     filter, lag
#
#
# Les objets suivants sont masqués depuis 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "le package 'tidyr' a été compilé avec la version R 4.1.2"
# Warning message:
# "le package 'piecewiseSEM' a été compilé avec la version R 4.1.2"
#
#   This is piecewiseSEM version 2.1.0.
#
#
#   Questions or bugs can be addressed to <LefcheckJ@si.edu>.
#
# Warning message:
# "le package 'nlme' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'nlme'
#
#
# L'objet suivant est masqué depuis 'package:dplyr':
#
#     collapse
#
#
# Warning message:
# "le package 'lme4' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : Matrix
#
# Warning message:
# "le package 'Matrix' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'Matrix'
#
#
# Les objets suivants sont masqués depuis 'package:tidyr':
#
#     expand, pack, unpack
#
#
#
# Attachement du package : 'lme4'
#
#
# L'objet suivant est masqué depuis 'package:nlme':
#
#     lmList
#
#
# Le chargement a nécessité le package : shape
#
# Warning message:
# "le package 'lcsm' a été compilé avec la version R 4.1.2"

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_/chapter2'
df = read.csv(file.path(path_,'df_lcsm_CR.csv'), header = TRUE, sep = ",")
df$HenID = as.factor(df$HenID)   
print(dim(df))
summary(df)
# Out:
# [1] 58 23
#     HenID_          severity_div10_ts_10 severity_div10_ts_11
#  Length:58          Min.   : 2.000       Min.   : 1.900
#  Class :character   1st Qu.: 5.275       1st Qu.: 5.900
#  Mode  :character   Median : 7.250       Median : 7.600
#                     Mean   : 6.817       Mean   : 6.967
#                     3rd Qu.: 8.200       3rd Qu.: 8.350
#                     Max.   :10.000       Max.   :10.000
#                     NA's   :12           NA's   :15
#  severity_div10_ts_5 severity_div10_ts_6 severity_div10_ts_7
#  Min.   :0.000       Min.   :0.000       Min.   :0.000
#  1st Qu.:2.300       1st Qu.:3.900       1st Qu.:4.500
#  Median :4.500       Median :4.800       Median :5.650
#  Mean   :4.290       Mean   :5.065       Mean   :5.783
#  3rd Qu.:5.675       3rd Qu.:6.600       3rd Qu.:7.650
#  Max.   :9.800       Max.   :9.800       Max.   :9.800
#                      NA's   :3           NA's   :4
#  severity_div10_ts_8 severity_div10_ts_9 duration_5_Zone_min_ts_10
#  Min.   :1.600       Min.   :1.000       Min.   :  0.0
#  1st Qu.:4.550       1st Qu.:4.950       1st Qu.:181.1
#  Median :6.500       Median :6.750       Median :446.3
#  Mean   :5.896       Mean   :6.377       Mean   :456.4
#  3rd Qu.:7.650       3rd Qu.:7.925       3rd Qu.:774.3
#  Max.   :9.900       Max.   :9.800       Max.   :923.8
#  NA's   :3           NA's   :10          NA's   :12
#  duration_5_Zone_min_ts_11 duration_5_Zone_min_ts_5 duration_5_Zone_min_ts_6
#  Min.   :  0.00            Min.   :  0.000          Min.   :  0.00
#  1st Qu.: 83.17            1st Qu.:  6.667          1st Qu.: 11.78
#  Median :447.50            Median :228.000          Median :203.83
#  Mean   :426.63            Mean   :282.566          Mean   :301.03
#  3rd Qu.:729.00            3rd Qu.:477.875          3rd Qu.:519.83
#  Max.   :900.17            Max.   :919.333          Max.   :917.17
#  NA's   :15                                         NA's   :3
#  duration_5_Zone_min_ts_7 duration_5_Zone_min_ts_8 duration_5_Zone_min_ts_9
#  Min.   :  0.000          Min.   :  0.000          Min.   :  0.0
#  1st Qu.:  8.333          1st Qu.:  1.583          1st Qu.: 88.0
#  Median :281.083          Median :254.000          Median :342.1
#  Mean   :340.572          Mean   :321.324          Mean   :386.3
#  3rd Qu.:587.625          3rd Qu.:607.417          3rd Qu.:672.1
#  Max.   :917.200          Max.   :901.333          Max.   :871.5
#  NA's   :4                NA's   :3                NA's   :10
#  duration_1_Zone_min_ts_10 duration_1_Zone_min_ts_11 duration_1_Zone_min_ts_5
#  Min.   :  0.00            Min.   :  0.00            Min.   :  0.00
#  1st Qu.: 11.90            1st Qu.: 19.17            1st Qu.: 41.75
#  Median : 40.70            Median : 90.33            Median :104.00
#  Mean   : 72.18            Mean   : 98.16            Mean   :112.45
#  3rd Qu.:123.65            3rd Qu.:147.33            3rd Qu.:183.21
#  Max.   :232.50            Max.   :251.00            Max.   :249.67
#  NA's   :12                NA's   :15
#  duration_1_Zone_min_ts_6 duration_1_Zone_min_ts_7 duration_1_Zone_min_ts_8
#  Min.   :  0.00           Min.   :  0.00           Min.   :  0.0
#  1st Qu.: 48.08           1st Qu.: 13.46           1st Qu.: 17.5
#  Median :105.20           Median : 97.58           Median :112.3
#  Mean   :102.73           Mean   :112.22           Mean   :109.9
#  3rd Qu.:172.58           3rd Qu.:190.79           3rd Qu.:190.0
#  Max.   :233.67           Max.   :299.50           Max.   :279.5
#  NA's   :3                NA's   :4                NA's   :3
#  duration_1_Zone_min_ts_9      HenID
#  Min.   :  0.00           Chen_100: 1
#  1st Qu.: 26.00           Chen_101: 1
#  Median : 87.08           Chen_102: 1
#  Mean   :107.82           Chen_103: 1
#  3rd Qu.:189.62           Chen_104: 1
#  Max.   :277.67           Chen_105: 1
#  NA's   :10               (Other) :52

# %%
#df = df %>% drop_na(age, Feathers, mean_perc_duration_1_Zone, mean_temperature_C_avg)
#dim(df)

# %%
df[rowSums(is.na(df)) > 0,]
# Out:
#    HenID_   severity_div10_ts_10 severity_div10_ts_11 severity_div10_ts_5
# 1  Chen_100 8.7                   NA                  4.3
# 3  Chen_102  NA                   NA                  4.3
# 8  Chen_107 6.3                  6.2                  5.6
# 9  Chen_108  NA                   NA                  3.0
# 12 Chen_111  NA                  8.3                  7.1
# 15 Chen_114 7.5                  7.2                  7.2
# 16 Chen_115  NA                  7.1                  0.0
# 20 Chen_119 8.2                  8.2                  7.9
# 25 Chen_44  5.2                   NA                  2.2
# 28 Chen_48   NA                   NA                  0.2
# 29 Chen_49   NA                   NA                  7.3
# 30 Chen_50  7.2                   NA                  5.1
# 33 Chen_54   NA                   NA                  8.3
# 38 Chen_59  9.7                  9.7                  9.8
# 39 Chen_60   NA                  1.9                  1.6
# 40 Chen_81   NA                  6.6                  0.4
# 42 Chen_83  4.2                   NA                  3.5
# 43 Chen_84  6.3                   NA                  4.4
# 45 Chen_86  7.9                   NA                  1.0
# 47 Chen_88  3.3                  3.2                  2.1
# 48 Chen_89  4.9                   NA                  5.0
# 49 Chen_90  4.8                  4.8                  3.7
# 50 Chen_91   NA                  7.8                  6.0
# 51 Chen_92   NA                  5.8                  2.6
# 52 Chen_93   NA                   NA                  0.9
# 53 Chen_94  7.3                   NA                  7.7
# 55 Chen_96  9.6                   NA                  9.3
#    severity_div10_ts_6 severity_div10_ts_7 severity_div10_ts_8
# 1   NA                 8.5                 8.6
# 3  3.2                 2.8                 2.9
# 8  5.8                 5.6                 5.6
# 9  1.3                  NA                  NA
# 12 7.4                 7.7                 7.6
# 15 6.8                  NA                 6.8
# 16 6.6                 6.5                 6.1
# 20 6.6                 8.0                 8.0
# 25 4.3                 4.7                 4.8
# 28 0.4                 0.7                 1.6
# 29 9.8                 9.8                 9.9
# 30 5.2                 5.2                 6.5
# 33  NA                  NA                  NA
# 38 9.6                 9.7                  NA
# 39 1.8                 2.1                 1.8
# 40 2.7                 1.9                 2.0
# 42 3.4                 3.6                 3.3
# 43 4.0                 7.0                 6.7
# 45 3.8                 6.3                 4.0
# 47 4.8                  NA                 3.1
# 48 4.6                 5.2                 4.8
# 49 4.4                 5.1                 4.8
# 50 8.5                 8.0                 8.1
# 51 2.5                 2.8                 5.7
# 52  NA                 1.8                 1.6
# 53 7.4                 7.3                 7.4
# 55 9.6                 9.5                 9.5
#    severity_div10_ts_9 duration_5_Zone_min_ts_10 duration_5_Zone_min_ts_11 ...
# 1   NA                 705.6000                        NA                  ...
# 3   NA                       NA                        NA                  ...
# 8   NA                 896.2000                  900.1667                  ...
# 9   NA                       NA                        NA                  ...
# 12 7.5                       NA                  622.3333                  ...
# 15 7.1                   0.2000                    0.0000                  ...
# 16 6.4                       NA                  158.0000                  ...
# 20  NA                 870.0000                  879.6667                  ...
# 25 5.0                 564.1667                        NA                  ...
# 28  NA                       NA                        NA                  ...
# 29 9.8                       NA                        NA                  ...
# 30 6.9                 780.8333                        NA                  ...
# 33  NA                       NA                        NA                  ...
# 38 9.8                 923.8333                  867.1667                  ...
# 39 2.0                       NA                  481.3333                  ...
# 40 6.5                       NA                    0.0000                  ...
# 42 4.8                   3.0000                        NA                  ...
# 43  NA                 158.2000                        NA                  ...
# 45 4.2                 719.5000                        NA                  ...
# 47 3.2                 480.8000                  424.0000                  ...
# 48 4.7                 333.6000                        NA                  ...
# 49  NA                   0.0000                    0.0000                  ...
# 50  NA                       NA                  447.5000                  ...
# 51 5.5                       NA                    0.5000                  ...
# 52 1.9                       NA                        NA                  ...
# 53 7.3                 235.7500                        NA                  ...
# 55 9.7                 861.0000                        NA                  ...
#    duration_5_Zone_min_ts_8 duration_5_Zone_min_ts_9 duration_1_Zone_min_ts_10
# 1    7.8333333                       NA               13.60000
# 3   98.8333333                       NA                     NA
# 8  767.3333333                       NA                0.40000
# 9           NA                       NA                     NA
# 12 467.5000000              632.5000000                     NA
# 15   1.3333333                0.8333333              202.00000
# 16 248.6666667              307.1666667                     NA
# 20 805.5000000                       NA                0.00000
# 25 609.5000000              667.1666667               19.33333
# 28   0.0000000                       NA                     NA
# 29 883.0000000              871.5000000                     NA
# 30 826.1666667              807.5000000               15.16667
# 33          NA                       NA                     NA
# 38          NA              845.5000000                0.00000
# 39 254.0000000              290.6666667                     NA
# 40   0.8333333               20.0000000                     NA
# 42   0.5000000                7.6666667                2.00000
# 43  66.8333333                       NA              124.00000
# 45 648.1666667              686.8333333               16.75000
# 47 414.6666667              392.8333333              127.40000
# 48 341.0000000              384.8333333               30.80000
# 49   0.0000000                       NA              165.00000
# 50 270.0000000                       NA                     NA
# 51   0.0000000                1.0000000                     NA
# 52 150.3333333              297.3333333                     NA
# 53 221.0000000              243.5000000               27.50000
# 55 444.5000000              622.3333333                1.00000
#    duration_1_Zone_min_ts_11 duration_1_Zone_min_ts_5 duration_1_Zone_min_ts_6
# 1          NA                161.50000                        NA
# 3          NA                 97.00000                 48.000000
# 8    2.666667                149.16667                  1.666667
# 9          NA                 74.33333                 82.166667
# 12   8.666667                233.83333                126.833333
# 15 204.000000                168.66667                105.200000
# 16 251.000000                242.83333                187.000000
# 20   0.000000                104.16667                  4.833333
# 25         NA                 72.16667                 57.833333
# 28         NA                 94.50000                173.500000
# 29         NA                 52.00000                 73.500000
# 30         NA                  0.00000                  9.333333
# 33         NA                191.00000                        NA
# 38   0.000000                  0.00000                  0.000000
# 39 128.666667                235.66667                200.333333
# 40   0.000000                  0.00000                 27.166667
# 42         NA                103.83333                 61.166667
# 43         NA                150.50000                 86.666667
# 45         NA                 17.00000                  1.500000
# 47 234.000000                 46.50000                192.500000
# 48         NA                 71.16667                 81.000000
# 49 227.333333                214.16667                181.166667
# 50  73.500000                 76.50000                163.000000
# 51 118.166667                168.00000                168.000000
# 52         NA                150.66667                        NA
# 53         NA                 91.50000                  5.666667
# 55         NA                 36.50000                 50.166667
#    duration_1_Zone_min_ts_7 duration_1_Zone_min_ts_8 duration_1_Zone_min_ts_9
# 1  128.0000000               99.000000                       NA
# 3   61.8333333               42.166667                       NA
# 8    0.0000000                7.166667                       NA
# 9           NA                      NA                       NA
# 12  87.3333333              112.666667                83.500000
# 15          NA              204.666667               232.166667
# 16 191.1666667              173.000000               176.000000
# 20   0.0000000                0.000000                       NA
# 25  61.3333333               46.500000                57.333333
# 28  82.5000000              132.000000                       NA
# 29   9.3333333                0.000000                 0.000000
# 30   9.6666667               21.000000                42.833333
# 33          NA                      NA                       NA
# 38   0.1666667                      NA                 1.666667
# 39 265.1666667              197.333333               235.833333
# 40  24.8333333               11.666667                 2.833333
# 42  76.1666667               49.500000                45.000000
# 43 232.0000000              135.333333                       NA
# 45   8.3333333               18.833333                46.333333
# 47          NA              220.666667               205.166667
# 48 107.5000000              112.333333                94.666667
# 49 216.1666667              230.333333                       NA
# 50  62.0000000               68.666667                       NA
# 51 177.8333333              189.000000               166.833333
# 52 204.1666667              135.166667                83.000000
# 53   0.0000000                3.333333                38.500000
# 55  34.8333333                0.500000                 4.500000
#    HenID
# 1  Chen_100
# 3  Chen_102
# 8  Chen_107
# 9  Chen_108
# 12 Chen_111
# 15 Chen_114
# 16 Chen_115
# 20 Chen_119
# 25 Chen_44
# 28 Chen_48
# 29 Chen_49
# 30 Chen_50
# 33 Chen_54
# 38 Chen_59
# 39 Chen_60
# 40 Chen_81
# 42 Chen_83
# 43 Chen_84
# 45 Chen_86
# 47 Chen_88
# 48 Chen_89
# 49 Chen_90
# 50 Chen_91
# 51 Chen_92
# 52 Chen_93
# 53 Chen_94
# 55 Chen_96

# %%
#remove birds that have no health on HA4 as it means it wont have HA5 either
df_ = subset(df, !is.na(severity_HA4))
dim(df_)
# Out:
# [1] 157 117

# %%
dim(df)
# Out:
# [1] 191 117

# %% [raw]
# #to define param appropriately
# https://github.com/milanwiedemann/lcsm
# from sempiecewise, to lavaan, to lcsm, to ctsem
# library("ctsem") #but I think its better to model the change than taking into account the time

# %% [markdown]
# # KBF

# %% [markdown]
# ### duration in top tier

# %%
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
bi_lavaan_results <- fit_bi_lcsm(data = df, 
                                 var_y = c("duration_1_Zone_min_ts_5", "duration_1_Zone_min_ts_6", "duration_1_Zone_min_ts_7", 
                                           "duration_1_Zone_min_ts_8","duration_1_Zone_min_ts_9", "duration_1_Zone_min_ts_10", 
                                           "duration_1_Zone_min_ts_11"),
                                 var_x = c("severity_div10_ts_5", "severity_div10_ts_6", "severity_div10_ts_7",
                                          "severity_div10_ts_8", "severity_div10_ts_9", "severity_div10_ts_10",
                                          "severity_div10_ts_11"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE,  #not sure!!
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(delta_lag_xy = TRUE, 
                                                 xi_con_yx = TRUE))

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df, 
                                 var_y = c("duration_1_Zone_min_ts_5", "duration_1_Zone_min_ts_6", "duration_1_Zone_min_ts_7", 
                                           "duration_1_Zone_min_ts_8","duration_1_Zone_min_ts_9", "duration_1_Zone_min_ts_10", 
                                           "duration_1_Zone_min_ts_11"),
                                 var_x = c("severity_div10_ts_5", "severity_div10_ts_6", "severity_div10_ts_7",
                                          "severity_div10_ts_8", "severity_div10_ts_9", "severity_div10_ts_10",   
                                          "severity_div10_ts_11"),
                                model_x = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = FALSE),
                                model_y = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = TRUE),
                                 coupling = list(delta_lag_xy = TRUE, 
                                                 xi_con_yx = TRUE),
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H")

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Warning message in lav_data_full(data = data, group = group, cluster = cluster, :
# "lavaan WARNING: some observed variances are (at least) a factor 1000 times larger than others; use varTable(fit) to investigate"
# Warning message in lav_object_post_check(object):
# "lavaan WARNING: covariance matrix of latent variables
#                 is not positive definite;
#                 use lavInspect(fit, "cov.lv") to investigate."
# lavaan 0.6-10 ended normally after 675 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        64
#   Number of equality constraints                    42
#
#   Number of observations                            58
#   Number of missing patterns                        14
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                276.714     257.665
#   Degrees of freedom                                 97          97
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.074
#        Yuan-Bentler correction (Mplus variant)
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 =~
#     x1                1.000
#   lx2 =~
#     x2                1.000
#   lx3 =~
#     x3                1.000
#   lx4 =~
#     x4                1.000
#   lx5 =~
#     x5                1.000
#   lx6 =~
#     x6                1.000
#   lx7 =~
#     x7                1.000
#   dx2 =~
#     lx2               1.000
#   dx3 =~
#     lx3               1.000
#   dx4 =~
#     lx4               1.000
#   dx5 =~
#     lx5               1.000
#   dx6 =~
#     lx6               1.000
#   dx7 =~
#     lx7               1.000
#   g2 =~
#     dx2               1.000
#     dx3               1.000
#     dx4               1.000
#     dx5               1.000
#     dx6               1.000
#     dx7               1.000
#   ly1 =~
#     y1                1.000
#   ly2 =~
#     y2                1.000
#   ly3 =~
#     y3                1.000
#   ly4 =~
#     y4                1.000
#   ly5 =~
#     y5                1.000
#   ly6 =~
#     y6                1.000
#   ly7 =~
#     y7                1.000
#   dy2 =~
#     ly2               1.000
#   dy3 =~
#     ly3               1.000
#   dy4 =~
#     ly4               1.000
#   dy5 =~
#     ly5               1.000
#   dy6 =~
#     ly6               1.000
#   dy7 =~
#     ly7               1.000
#   j2 =~
#     dy2               1.000
#     dy3               1.000
#     dy4               1.000
#     dy5               1.000
#     dy6               1.000
#     dy7               1.000
#
# Regressions:
#                    Estimate  Std.Err  z-value   P(>|z|)
#   lx2 ~
#     lx1               1.000
#   lx3 ~
#     lx2               1.000
#   lx4 ~
#     lx3               1.000
#   lx5 ~
#     lx4               1.000
#   lx6 ~
#     lx5               1.000
#   lx7 ~
#     lx6               1.000
#   dx2 ~
#     lx1     (bt_x)   -0.357    0.098    -3.629    0.000
#   dx3 ~
#     lx2     (bt_x)   -0.357    0.098    -3.629    0.000
#   dx4 ~
#     lx3     (bt_x)   -0.357    0.098    -3.629    0.000
#   dx5 ~
#     lx4     (bt_x)   -0.357    0.098    -3.629    0.000
#   dx6 ~
#     lx5     (bt_x)   -0.357    0.098    -3.629    0.000
#   dx7 ~
#     lx6     (bt_x)   -0.357    0.098    -3.629    0.000
#   ly2 ~
#     ly1               1.000
#   ly3 ~
#     ly2               1.000
#   ly4 ~
#     ly3               1.000
#   ly5 ~
#     ly4               1.000
#   ly6 ~
#     ly5               1.000
#   ly7 ~
#     ly6               1.000
#   dy2 ~
#     ly1     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy3 ~
#     ly2     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy4 ~
#     ly3     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy5 ~
#     ly4     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy6 ~
#     ly5     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy7 ~
#     ly6     (bt_y)   -0.043    0.028    -1.537    0.124
#   dy3 ~
#     dy2     (ph_y)   -1.542    0.089   -17.294    0.000
#   dy4 ~
#     dy3     (ph_y)   -1.542    0.089   -17.294    0.000
#   dy5 ~
#     dy4     (ph_y)   -1.542    0.089   -17.294    0.000
#   dy6 ~
#     dy5     (ph_y)   -1.542    0.089   -17.294    0.000
#   dy7 ~
#     dy6     (ph_y)   -1.542    0.089   -17.294    0.000
#   dx2 ~
#     ly1     (dl__)   -0.008    0.004    -1.884    0.060
#   dx3 ~
#     ly2     (dl__)   -0.008    0.004    -1.888    0.059
#   dx4 ~
#     ly3     (dl__)   -0.008    0.004    -1.885    0.059
#   dx5 ~
#     ly4     (dl__)   -0.008    0.004    -1.886    0.059
#   dx6 ~
#     ly5     (dl__)   -0.008    0.004    -1.884    0.060
#   dx7 ~
#     ly6     (dl__)   -0.008    0.004    -1.884    0.060
#   dy2 ~
#     dx2     (x_c_)   16.289    4.921     3.310    0.001
#   dy3 ~
#     dx3     (x_c_)   16.289    4.921     3.310    0.001
#   dy4 ~
#     dx4     (x_c_)   16.289    4.921     3.310    0.001
#   dy5 ~
#     dx5     (x_c_)   16.289    4.921     3.310    0.001
#   dy6 ~
#     dx6     (x_c_)   16.289    4.921     3.310    0.001
#   dy7 ~
#     dx7     (x_c_)   16.289    4.921     3.310    0.001
#
# Covariances:
#                    Estimate  Std.Err  z-value   P(>|z|)
#   lx1 ~~
#     g2 (sgm_g2lx1)    0.905    0.387     2.339    0.019
#   ly1 ~~
#     j2 (sgm_j2ly1)  137.754    0.156   885.202    0.000
#  .x1 ~~
#    .y1      (sgm_)    6.588    2.254     2.922    0.003
#  .x2 ~~
#    .y2      (sgm_)    6.588    2.254     2.922    0.003
#  .x3 ~~
#    .y3      (sgm_)    6.588    2.254     2.922    0.003
#  .x4 ~~
#    .y4      (sgm_)    6.588    2.254     2.922    0.003
#  .x5 ~~
#    .y5      (sgm_)    6.588    2.254     2.922    0.003
#  .x6 ~~
#    .y6      (sgm_)    6.588    2.254     2.922    0.003
#  .x7 ~~
#    .y7      (sgm_)    6.588    2.254     2.922    0.003
#   lx1 ~~
#     l1      (s_11)  -57.928   25.855    -2.241    0.025
#   g2 ~~
#     l1 (sgm_g2ly1)   31.435   22.328     1.408    0.159
#   lx1 ~~
#     j2 (sgm_j2lx1)   10.337    4.754     2.175    0.030
#   g2 ~~
#     j2      (s_22)   -2.198    1.544    -1.424    0.154
#
# Intercepts:
#                    Estimate  Std.Err  z-value   P(>|z|)
#     lx1  (gmm_lx1)    4.255    0.324    13.126    0.000
#    .lx2               0.000
#    .lx3               0.000
#    .lx4               0.000
#    .lx5               0.000
#    .lx6               0.000
#    .lx7               0.000
#    .x1                0.000
#    .x2                0.000
#    .x3                0.000
#    .x4                0.000
#    .x5                0.000
#    .x6                0.000
#    .x7                0.000
#    .dx2               0.000
#    .dx3               0.000
#    .dx4               0.000
#    .dx5               0.000
#    .dx6               0.000
#    .dx7               0.000
#     g2   (alph_g2)    3.284    0.899     3.654    0.000
#     ly1  (gmm_ly1)  113.767   10.214    11.138    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .ly4               0.000
#    .ly5               0.000
#    .ly6               0.000
#    .ly7               0.000
#    .y1                0.000
#    .y2                0.000
#    .y3                0.000
#    .y4                0.000
#    .y5                0.000
#    .y6                0.000
#    .y7                0.000
#    .dy2               0.000
#    .dy3               0.000
#    .dy4               0.000
#    .dy5               0.000
#    .dy6               0.000
#    .dy7               0.000
#     j2   (alph_j2)  -13.176    4.225    -3.118    0.002
#
# Variances:
#                    Estimate  Std.Err  z-value   P(>|z|)
#     lx1 (sgm2_lx1)    5.563    1.048     5.308    0.000
#    .lx2               0.000
#    .lx3               0.000
#    .lx4               0.000
#    .lx5               0.000
#    .lx6               0.000
#    .lx7               0.000
#    .x1    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x2    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x3    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x4    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x5    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x6    (sgm2_x)    0.850    0.131     6.473    0.000
#    .x7    (sgm2_x)    0.850    0.131     6.473    0.000
#    .dx2               0.000
#    .dx3               0.000
#    .dx4               0.000
#    .dx5               0.000
#    .dx6               0.000
#    .dx7               0.000
#     g2   (sgm2_g2)    0.775    0.491     1.577    0.115
#     ly1 (sgm2_ly1) 5684.892    0.251 22659.803    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .ly4               0.000
#    .ly5               0.000
#    .ly6               0.000
#    .ly7               0.000
#    .y1    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y2    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y3    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y4    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y5    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y6    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .y7    (sgm2_y) 1500.183    0.093 16079.532    0.000
#    .dy2               0.000
#    .dy3               0.000
#    .dy4               0.000
#    .dy5               0.000
#    .dy6               0.000
#    .dy7               0.000
#     j2   (sgm2_j2)  112.913    3.171    35.613    0.000
# plot without title

# %%
#library('lavaan')
lavInspect(bi_lavaan_results, "cov.lv")
# Out:
#     lx1        lx2        lx3         dx2         dx3        g2
# lx1  83.331306  105.03522  124.730238   21.703911  19.695020    26.776652
# lx2 105.035217  122.27496  133.427798   17.239747  11.152834    20.063148
# lx3 124.730238  133.42780  137.248439    8.697561   3.820641    16.662321
# dx2  21.703911   17.23975    8.697561   -4.464164  -8.542187    -6.713504
# dx3  19.695020   11.15283    3.820641   -8.542187  -7.332193    -3.400827
# g2   26.776652   20.06315   16.662321   -6.713504  -3.400827    52.000158
# ly1  57.988063  173.70598   76.317096  115.717917 -97.388884 -1589.929642
# ly2  53.713104   43.75200  -40.137817   -9.961108 -83.889813 -1512.769547
# ly3  67.631318  -44.83947 -124.903320 -112.470786 -80.063852 -1457.363173
# dy2  -4.274958 -129.95398 -116.454913 -125.679025  13.499071    77.160095
# dy3  13.918214  -88.59146  -84.765503 -102.509678   3.825961    55.406374
# j2  203.307499   47.24113  -28.150360 -156.066373 -75.391486  -138.641687
#     ly1           ly2          ly3         dy2          dy3
# lx1    57.9880629    53.713104    67.63132    -4.274958    13.918214
# lx2   173.7059799    43.751996   -44.83947  -129.953983   -88.591465
# lx3    76.3170958   -40.137817  -124.90332  -116.454913   -84.765503
# dx2   115.7179170    -9.961108  -112.47079  -125.679025  -102.509678
# dx3   -97.3888841   -83.889813   -80.06385    13.499071     3.825961
# g2  -1589.9296417 -1512.769547 -1457.36317    77.160095    55.406374
# ly1 48203.3451956 42477.224278 38060.86092 -5726.120918 -4416.363359
# ly2 42477.2242778 40369.965110 38702.86163 -2107.259168 -1667.103479
# ly3 38060.8609188 38702.861631 39118.77977   642.000712   415.918136
# dy2 -5726.1209178 -2107.259168   642.00071  3618.861750  2749.259880
# dy3 -4416.3633590 -1667.103479   415.91814  2749.259880  2083.021614
# j2     -0.7847317  1896.240754  3265.59694  1897.025486  1369.356189
#     j2
# lx1  203.3074989
# lx2   47.2411257
# lx3  -28.1503601
# dx2 -156.0663732
# dx3  -75.3914859
# g2  -138.6416871
# ly1   -0.7847317
# ly2 1896.2407543
# ly3 3265.5969429
# dy2 1897.0254859
# dy3 1369.3561887
# j2   444.4962036

# %% [markdown]
# ### Went in WG

# %%
#without HA 3: keep 15 weeks in between
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
#estimator find list here MLR, though we want FILM: Full Information Maximum Likelihood (FIML)  as in the dev. cognitive paper
#to ebst handle missing data, but it does not exist in lavaan,  we cant use it (from my understanding). 
# "The only exception is when data are missing and full information ML is used (via missing = "ML")."
bi_lavaan_results <- fit_bi_lcsm(data = df_, 
                                 var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                 var_x = c("severity_div10_HA2", "severity_div10_HA4", "severity_div10_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE,  #not sure!!
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(delta_lag_xy = TRUE, 
                                                 xi_con_yx = TRUE),
                                 missing = "ML")

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df_, 
                                var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                 var_x = c("severity_div10_HA2", "severity_div10_HA4", "severity_div10_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE,  #not sure!!
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(delta_lag_xy = TRUE, 
                                                 xi_con_yx = TRUE),
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H",
                                missing = "ML")

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Warning message in lav_model_vcov(lavmodel = lavmodel, lavsamplestats = lavsamplestats, :
# "lavaan WARNING:
#     The variance-covariance matrix of the estimated parameters (vcov)
#     does not appear to be positive definite! The smallest eigenvalue
#     (= 5.922262e-17) is close to zero. This may be a symptom that the
#     model is not identified."
# Warning message in lav_object_post_check(object):
# "lavaan WARNING: some estimated lv variances are negative"
# lavaan 0.6-10 ended normally after 83 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        32
#   Number of equality constraints                    10
#
#   Number of observations                           157
#   Number of missing patterns                         3
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                  3.291       4.321
#   Degrees of freedom                                  5           5
#   P-value (Chi-square)                            0.655       0.504
#   Scaling correction factor                                   0.762
#        Yuan-Bentler correction (Mplus variant)
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 =~
#     x1                1.000
#   lx2 =~
#     x2                1.000
#   lx3 =~
#     x3                1.000
#   dx2 =~
#     lx2               1.000
#   dx3 =~
#     lx3               1.000
#   g2 =~
#     dx2               1.000
#     dx3               1.000
#   ly1 =~
#     y1                1.000
#   ly2 =~
#     y2                1.000
#   ly3 =~
#     y3                1.000
#   dy2 =~
#     ly2               1.000
#   dy3 =~
#     ly3               1.000
#   j2 =~
#     dy2               1.000
#     dy3               1.000
#
# Regressions:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx2 ~
#     lx1               1.000
#   lx3 ~
#     lx2               1.000
#   dx2 ~
#     lx1     (bt_x)   -0.220    0.202   -1.087    0.277
#   dx3 ~
#     lx2     (bt_x)   -0.220    0.202   -1.087    0.277
#   ly2 ~
#     ly1               1.000
#   ly3 ~
#     ly2               1.000
#   dy2 ~
#     ly1     (bt_y)   -0.609    1.269   -0.480    0.631
#   dy3 ~
#     ly2     (bt_y)   -0.609    1.255   -0.486    0.627
#     dy2     (ph_y)   -1.069    2.167   -0.493    0.622
#   dx2 ~
#     ly1     (dl__)   -0.720    6.160   -0.117    0.907
#   dx3 ~
#     ly2     (dl__)   -0.720    6.160   -0.117    0.907
#   dy2 ~
#     dx2     (x_c_)    0.151    0.194    0.777    0.437
#   dy3 ~
#     dx3     (x_c_)    0.151    0.194    0.777    0.437
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 ~~
#     g2 (sgm_g2lx1)    0.329    0.757    0.435    0.663
#   ly1 ~~
#     j2 (sgm_j2ly1)    0.039    0.055    0.705    0.481
#  .x1 ~~
#    .y1      (sgm_)   -0.010    0.029   -0.323    0.746
#  .x2 ~~
#    .y2      (sgm_)   -0.010    0.029   -0.323    0.746
#  .x3 ~~
#    .y3      (sgm_)   -0.010    0.029   -0.323    0.746
#   lx1 ~~
#     l1      (s_11)   -0.095    0.042   -2.287    0.022
#   g2 ~~
#     l1 (sgm_g2ly1)    0.024    0.329    0.072    0.943
#   lx1 ~~
#     j2 (sgm_j2lx1)   -0.091    0.141   -0.642    0.521
#   g2 ~~
#     j2      (s_22)    0.032    0.212    0.152    0.879
#
# Intercepts:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1  (gmm_lx1)    1.578    0.121   13.053    0.000
#    .lx2               0.000
#    .lx3               0.000
#    .x1                0.000
#    .x2                0.000
#    .x3                0.000
#    .dx2               0.000
#    .dx3               0.000
#     g2   (alph_g2)    2.045    3.847    0.532    0.595
#     ly1  (gmm_ly1)    0.653    0.030   21.984    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .y1                0.000
#    .y2                0.000
#    .y3                0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (alph_j2)    0.253    0.818    0.309    0.757
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1 (sgm2_lx1)    0.916    0.317    2.894    0.004
#    .lx2               0.000
#    .lx3               0.000
#    .x1    (sgm2_x)    1.141    0.216    5.281    0.000
#    .x2    (sgm2_x)    1.141    0.216    5.281    0.000
#    .x3    (sgm2_x)    1.141    0.216    5.281    0.000
#    .dx2               0.000
#    .dx3               0.000
#     g2   (sgm2_g2)    0.088    0.303    0.292    0.770
#     ly1 (sgm2_ly1)    0.048    0.017    2.841    0.005
#    .ly2               0.000
#    .ly3               0.000
#    .y1    (sgm2_y)    0.086    0.012    7.181    0.000
#    .y2    (sgm2_y)    0.086    0.012    7.181    0.000
#    .y3    (sgm2_y)    0.086    0.012    7.181    0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (sgm2_j2)   -0.006    0.126   -0.047    0.962
# plot without title

# %% [markdown]
# # Feather Damage

# %% [markdown]
# ### Went in WG

# %%
hist(sqrt(df$WentinWG_HA2))
# Out:
# Plot with title "Histogram of sqrt(df$WentinWG_HA2)"

# %%
#without HA 3: keep 15 weeks in between
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
#estimator find list here MLR, though we want FILM: Full Information Maximum Likelihood (FIML)  as in the dev. cognitive paper
#to ebst handle missing data, but it does not exist in lavaan,  we cant use it (from my understanding). 
# "The only exception is when data are missing and full information ML is used (via missing = "ML")."
bi_lavaan_results <- fit_bi_lcsm(data = df_, 
                                 var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                 var_x = c("FD_div10_HA2", "FD_div10_HA4", "FD_div10_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE,  #not sure!!
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(xi_con_xy = TRUE, 
                                                 xi_con_yx = TRUE),
                                 missing = "ML")

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df_, 
                                var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                 var_x = c("FD_div10_HA2", "FD_div10_HA4", "FD_div10_HA5"),
                                model_x = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = FALSE),
                                model_y = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = TRUE),
                                coupling = list(xi_con_xy = TRUE,
                                                xi_con_yx = TRUE), 
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H",
                                missing = "ML")

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Warning message in lav_object_post_check(object):
# "lavaan WARNING: some estimated lv variances are negative"
# lavaan 0.6-10 ended normally after 272 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        32
#   Number of equality constraints                    10
#
#   Number of observations                           157
#   Number of missing patterns                         6
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                  4.599       3.533
#   Degrees of freedom                                  5           5
#   P-value (Chi-square)                            0.467       0.618
#   Scaling correction factor                                   1.302
#        Yuan-Bentler correction (Mplus variant)
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 =~
#     x1                1.000
#   lx2 =~
#     x2                1.000
#   lx3 =~
#     x3                1.000
#   dx2 =~
#     lx2               1.000
#   dx3 =~
#     lx3               1.000
#   g2 =~
#     dx2               1.000
#     dx3               1.000
#   ly1 =~
#     y1                1.000
#   ly2 =~
#     y2                1.000
#   ly3 =~
#     y3                1.000
#   dy2 =~
#     ly2               1.000
#   dy3 =~
#     ly3               1.000
#   j2 =~
#     dy2               1.000
#     dy3               1.000
#
# Regressions:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx2 ~
#     lx1               1.000
#   lx3 ~
#     lx2               1.000
#   dx2 ~
#     lx1     (bt_x)   16.906   19.994    0.846    0.398
#   dx3 ~
#     lx2     (bt_x)   16.906   19.994    0.846    0.398
#   ly2 ~
#     ly1               1.000
#   ly3 ~
#     ly2               1.000
#   dy2 ~
#     ly1     (bt_y)   -5.364   21.430   -0.250    0.802
#   dy3 ~
#     ly2     (bt_y)   -5.364   21.430   -0.250    0.802
#     dy2     (ph_y)  470.032 2481.558    0.189    0.850
#   dx2 ~
#     dy2   (x_cn_x)  456.816  497.234    0.919    0.358
#   dx3 ~
#     dy3   (x_cn_x)  456.816  497.234    0.919    0.358
#   dy2 ~
#     dx2   (x_cn_y)   -7.594   23.443   -0.324    0.746
#   dy3 ~
#     dx3   (x_cn_y)   -7.594   23.443   -0.324    0.746
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 ~~
#     g2 (sgm_g2lx1)    3.277    6.383    0.513    0.608
#   ly1 ~~
#     j2 (sgm_j2ly1)   -0.018    0.120   -0.147    0.883
#  .x1 ~~
#    .y1      (sgm_)   -0.019    0.013   -1.420    0.156
#  .x2 ~~
#    .y2      (sgm_)   -0.019    0.013   -1.420    0.156
#  .x3 ~~
#    .y3      (sgm_)   -0.019    0.013   -1.420    0.156
#   lx1 ~~
#     l1      (s_11)   -0.001    0.019   -0.031    0.976
#   g2 ~~
#     l1 (sgm_g2ly1)   -0.487    1.405   -0.347    0.729
#   lx1 ~~
#     j2 (sgm_j2lx1)    1.801    6.480    0.278    0.781
#   g2 ~~
#     j2      (s_22)  -29.110  104.320   -0.279    0.780
#
# Intercepts:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1  (gmm_lx1)    0.299    0.038    7.966    0.000
#    .lx2               0.000
#    .lx3               0.000
#    .x1                0.000
#    .x2                0.000
#    .x3                0.000
#    .dx2               0.000
#    .dx3               0.000
#     g2   (alph_g2)   -5.235   10.516   -0.498    0.619
#     ly1  (gmm_ly1)    0.672    0.026   26.256    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .y1                0.000
#    .y2                0.000
#    .y3                0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (alph_j2)   14.580   48.230    0.302    0.762
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1 (sgm2_lx1)   -0.036    0.151   -0.241    0.810
#    .lx2               0.000
#    .lx3               0.000
#    .x1    (sgm2_x)    0.263    0.144    1.826    0.068
#    .x2    (sgm2_x)    0.263    0.144    1.826    0.068
#    .x3    (sgm2_x)    0.263    0.144    1.826    0.068
#    .dx2               0.000
#    .dx3               0.000
#     g2   (sgm2_g2)  -69.860  118.167   -0.591    0.554
#     ly1 (sgm2_ly1)    0.052    0.010    5.320    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .y1    (sgm2_y)    0.077    0.006   11.884    0.000
#    .y2    (sgm2_y)    0.077    0.006   11.884    0.000
#    .y3    (sgm2_y)    0.077    0.006   11.884    0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (sgm2_j2)    8.066   35.995    0.224    0.823
# plot without title

# %%
#without HA 3: keep 15 weeks in between
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
bi_lavaan_results <- fit_bi_lcsm(data = df, 
                                 var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                 var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE,  #not sure!!
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(xi_con_yx = TRUE, 
                                                 xi_con_xy = TRUE),
                                estimator='mlr',missing='fiml')

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df, 
                                var_y = c("WentinWG_HA2", "WentinWG_HA4", "WentinWG_HA5"),
                                var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                model_x = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = FALSE),
                                model_y = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = TRUE),
                                coupling = list(xi_con_yx = TRUE,
                                                xi_con_xy = TRUE), #estimate whether changes in x at time t are predicting subsequent changes in y at time t+1
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H",
                               estimator='mlr',missing='fiml')

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Warning message in lav_object_post_check(object):
# "lavaan WARNING: some estimated lv variances are negative"
# lavaan 0.6-10 ended normally after 410 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        32
#   Number of equality constraints                    10
#
#   Number of observations                           191
#   Number of missing patterns                        11
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 21.624       9.908
#   Degrees of freedom                                  5           5
#   P-value (Chi-square)                            0.001       0.078
#   Scaling correction factor                                   2.183
#        Yuan-Bentler correction (Mplus variant)
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate   Std.Err  z-value  P(>|z|)
#   lx1 =~
#     x1                 1.000
#   lx2 =~
#     x2                 1.000
#   lx3 =~
#     x3                 1.000
#   dx2 =~
#     lx2                1.000
#   dx3 =~
#     lx3                1.000
#   g2 =~
#     dx2                1.000
#     dx3                1.000
#   ly1 =~
#     y1                 1.000
#   ly2 =~
#     y2                 1.000
#   ly3 =~
#     y3                 1.000
#   dy2 =~
#     ly2                1.000
#   dy3 =~
#     ly3                1.000
#   j2 =~
#     dy2                1.000
#     dy3                1.000
#
# Regressions:
#                    Estimate   Std.Err  z-value  P(>|z|)
#   lx2 ~
#     lx1                1.000
#   lx3 ~
#     lx2                1.000
#   dx2 ~
#     lx1     (bt_x)   281.198  120.784    2.328    0.020
#   dx3 ~
#     lx2     (bt_x)   281.198  120.784    2.328    0.020
#   ly2 ~
#     ly1                1.000
#   ly3 ~
#     ly2                1.000
#   dy2 ~
#     ly1     (bt_y)     7.031    5.228    1.345    0.179
#   dy3 ~
#     ly2     (bt_y)     7.031    5.228    1.345    0.179
#     dy2     (ph_y)  -702.552  517.656   -1.357    0.175
#   dx2 ~
#     dy2   (x_cn_x)  1002.542  567.784    1.766    0.077
#   dx3 ~
#     dy3   (x_cn_x)  1002.542  567.784    1.766    0.077
#   dy2 ~
#     dx2   (x_cn_y)  -211.726   81.708   -2.591    0.010
#   dy3 ~
#     dx3   (x_cn_y)  -211.726   81.708   -2.591    0.010
#
# Covariances:
#                    Estimate   Std.Err  z-value  P(>|z|)
#   lx1 ~~
#     g2 (sgm_g2lx1) -6345.496 3396.554   -1.868    0.062
#   ly1 ~~
#     j2 (sgm_j2ly1) -2531.480 1712.206   -1.478    0.139
#  .x1 ~~
#    .y1      (sgm_)    -9.662   11.388   -0.848    0.396
#  .x2 ~~
#    .y2      (sgm_)    -9.662   11.388   -0.848    0.396
#  .x3 ~~
#    .y3      (sgm_)    -9.662   11.388   -0.848    0.396
#   lx1 ~~
#     l1      (s_11)   -15.310   13.100   -1.169    0.243
#   g2 ~~
#     l1 (sgm_g2ly1) -1122.415 1224.970   -0.916    0.360
#   lx1 ~~
#     j2 (sgm_j2lx1)  7752.468 2932.433    2.644    0.008
#   g2 ~~
#     j2      (s_22)   221.196  498.497    0.444    0.657
#
# Intercepts:
#                    Estimate   Std.Err  z-value  P(>|z|)
#     lx1  (gmm_lx1)     2.950    0.348    8.468    0.000
#    .lx2                0.000
#    .lx3                0.000
#    .x1                 0.000
#    .x2                 0.000
#    .x3                 0.000
#    .dx2                0.000
#    .dx3                0.000
#     g2   (alph_g2)  -187.962  482.024   -0.390    0.697
#     ly1  (gmm_ly1)    66.477    2.392   27.796    0.000
#    .ly2                0.000
#    .ly3                0.000
#    .y1                 0.000
#    .y2                 0.000
#    .y3                 0.000
#    .dy2                0.000
#    .dy3                0.000
#     j2   (alph_j2)  2566.881 1132.151    2.267    0.023
#
# Variances:
#                    Estimate   Std.Err  z-value  P(>|z|)
#     lx1 (sgm2_lx1)   -20.509    4.344   -4.721    0.000
#    .lx2                0.000
#    .lx3                0.000
#    .x1    (sgm2_x)    41.805    3.592   11.640    0.000
#    .x2    (sgm2_x)    41.805    3.592   11.640    0.000
#    .x3    (sgm2_x)    41.805    3.592   11.640    0.000
#    .dx2                0.000
#    .dx3                0.000
#     g2   (sgm2_g2)   -39.655   28.995   -1.368    0.171
#     ly1 (sgm2_ly1)   556.944   94.887    5.870    0.000
#    .ly2                0.000
#    .ly3                0.000
#    .y1    (sgm2_y)   819.951   69.258   11.839    0.000
#    .y2    (sgm2_y)   819.951   69.258   11.839    0.000
#    .y3    (sgm2_y)   819.951   69.258   11.839    0.000
#    .dy2                0.000
#    .dy3                0.000
#     j2   (sgm2_j2)  -751.049 1890.037   -0.397    0.691
# plot without title

# %% [markdown]
# ### %time in WG

# %%
hist(df$FD_HA2) #ISSUE
# Out:
# Plot with title "Histogram of df_lcsm$FD_HA2"

# %%
hist(sqrt(sqrt(df$percZ1_HA5)))
# Out:
# Plot with title "Histogram of sqrt(sqrt(df_lcsm$percZ1_HA5))"

# %%
df$percZ1_HA2_sqrtsqrt = sqrt(sqrt(df$percZ1_HA2)
df$percZ1_HA4_sqrtsqrt = sqrt(sqrt(df$percZ1_HA4)
df$percZ1_HA5_sqrtsqrt = sqrt(sqrt(df$percZ1_HA5)
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:1: symbole inattendu
# 1: df_lcsm$percZ1_HA2_sqrtsqrt = sqrt(sqrt(df_lcsm$percZ1_HA2)
# 2: df_lcsm
#    ^
# Traceback:

# %%
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
bi_lavaan_results <- fit_bi_lcsm(data = df, 
                                 var_y = c("percZ1_HA2_sqrtsqrt", "percZ1_HA4_sqrtsqrt", "percZ1_HA5_sqrtsqrt"),
                                 var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(xi_con_yx = TRUE, 
                                                 xi_con_xy = FALSE))

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df, 
                                 var_y = c("percZ1_HA2_sqrtsqrt", "percZ1_HA4_sqrtsqrt", "percZ1_HA5_sqrtsqrt"),
                                var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                model_x = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = FALSE),
                                model_y = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = TRUE),
                                coupling = list(xi_con_yx = TRUE,
                                                xi_con_xy = FALSE), #estimate whether changes in x at time t are predicting subsequent changes in y at time t+1
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H")

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Error in lavaan::lavaan(data = data_lcsm, model = model_bi, meanstructure = TRUE, : lavaan ERROR: missing observed variables in dataset: y1 y2 y3
# Traceback:
#
# 1. fit_bi_lcsm(data = df_lcsm, var_y = c("percZ1_HA2_sqrtsqrt",
#  .     "percZ1_HA4_sqrtsqrt", "percZ1_HA5_sqrtsqrt"), var_x = c("FD_HA2",
#  .     "FD_HA4", "FD_HA5"), model_x = list(alpha_constant = TRUE,
#  .     beta = TRUE, phi = FALSE), model_y = list(alpha_constant = TRUE,
#  .     beta = TRUE, phi = TRUE), coupling = list(xi_con_yx = TRUE,
#  .     xi_con_xy = FALSE))
# 2. lavaan::lavaan(data = data_lcsm, model = model_bi, meanstructure = TRUE,
#  .     fixed.x = FALSE, control = list(iter.max = 10000), verbose = FALSE,
#  .     mimic = mimic, estimator = estimator, missing = missing,
#  .     ...)
# 3. stop("lavaan ERROR: missing observed variables in dataset: ",
#  .     paste(OV.names.y[idx.missing], collapse = " "))

# %%
#https://www.rdocumentation.org/packages/lcsm/versions/0.1.2/topics/fit_bi_lcsm
# Fit bivariate lcsm and save the results 
bi_lavaan_results <- fit_bi_lcsm(data = df, 
                                 var_y = c("percZ1_HA2", "percZ1_HA4", "percZ1_HA5"),
                                 var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                 model_x = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = FALSE),
                                 model_y = list(alpha_constant = TRUE, 
                                                beta = TRUE, 
                                                phi = TRUE),
                                 coupling = list(xi_con_xy = TRUE, 
                                                 xi_con_yx = FALSE))

# Save the lavaan syntax that is used to create the layout matrix for semPlot
bi_lavaan_syntax <- fit_bi_lcsm(data = df, 
                                var_y = c("percZ1_HA2", "percZ1_HA4", "percZ1_HA5"),
                                var_x = c("FD_HA2", "FD_HA4", "FD_HA5"),
                                model_x = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = FALSE),
                                model_y = list(alpha_constant = TRUE, 
                                               beta = TRUE, 
                                               phi = TRUE),
                                coupling = list(xi_con_xy = TRUE,
                                                xi_con_yx = FALSE), #estimate whether changes in x at time t are predicting subsequent changes in y at time t+1
                                return_lavaan_syntax = TRUE,
                                change_letter_x = "M",
                                change_letter_y = "H")

#result
summary(bi_lavaan_results)

# Plot the results
plot_lcsm(lavaan_object = bi_lavaan_results, 
          lavaan_syntax = bi_lavaan_syntax,
          lcsm_colours = TRUE,
          lcsm = "bivariate")
# Out:
# Warning message in lav_object_post_check(object):
# "lavaan WARNING: some estimated lv variances are negative"
# lavaan 0.6-10 ended normally after 168 iterations
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of model parameters                        30
#   Number of equality constraints                     9
#
#   Number of observations                           191
#   Number of missing patterns                        11
#
# Model Test User Model:
#                                                Standard      Robust
#   Test Statistic                                 50.510      47.453
#   Degrees of freedom                                  6           6
#   P-value (Chi-square)                            0.000       0.000
#   Scaling correction factor                                   1.064
#        Yuan-Bentler correction (Mplus variant)
#
# Parameter Estimates:
#
#   Standard errors                             Sandwich
#   Information bread                           Observed
#   Observed information based on                Hessian
#
# Latent Variables:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 =~
#     x1                1.000
#   lx2 =~
#     x2                1.000
#   lx3 =~
#     x3                1.000
#   dx2 =~
#     lx2               1.000
#   dx3 =~
#     lx3               1.000
#   g2 =~
#     dx2               1.000
#     dx3               1.000
#   ly1 =~
#     y1                1.000
#   ly2 =~
#     y2                1.000
#   ly3 =~
#     y3                1.000
#   dy2 =~
#     ly2               1.000
#   dy3 =~
#     ly3               1.000
#   j2 =~
#     dy2               1.000
#     dy3               1.000
#
# Regressions:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx2 ~
#     lx1               1.000
#   lx3 ~
#     lx2               1.000
#   dx2 ~
#     lx1     (bt_x)    0.059    0.113    0.524    0.600
#   dx3 ~
#     lx2     (bt_x)    0.059    0.113    0.524    0.600
#   ly2 ~
#     ly1               1.000
#   ly3 ~
#     ly2               1.000
#   dy2 ~
#     ly1     (bt_y)    0.072    0.123    0.589    0.556
#   dy3 ~
#     ly2     (bt_y)    0.072    0.124    0.584    0.560
#     dy2     (ph_y)    2.966    1.716    1.728    0.084
#   dx2 ~
#     dy2     (x_c_)    0.378    0.578    0.654    0.513
#   dx3 ~
#     dy3     (x_c_)    0.378    0.578    0.654    0.513
#
# Covariances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#   lx1 ~~
#     g2 (sgm_g2lx1)   11.675    5.414    2.156    0.031
#   ly1 ~~
#     j2 (sgm_j2ly1)   -0.304    2.640   -0.115    0.908
#  .x1 ~~
#    .y1      (sgm_)   -2.532    3.868   -0.655    0.513
#  .x2 ~~
#    .y2      (sgm_)   -2.532    3.868   -0.655    0.513
#  .x3 ~~
#    .y3      (sgm_)   -2.532    3.868   -0.655    0.513
#   lx1 ~~
#     l1      (s_11)   -1.972    4.699   -0.420    0.675
#   g2 ~~
#     l1 (sgm_g2ly1)   -4.510    5.236   -0.861    0.389
#   lx1 ~~
#     j2 (sgm_j2lx1)   -1.089    1.124   -0.969    0.333
#   g2 ~~
#     j2      (s_22)   -1.751    2.505   -0.699    0.485
#
# Intercepts:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1  (gmm_lx1)    2.963    0.380    7.796    0.000
#    .lx2               0.000
#    .lx3               0.000
#    .x1                0.000
#    .x2                0.000
#    .x3                0.000
#    .dx2               0.000
#    .dx3               0.000
#     g2   (alph_g2)   14.146    0.878   16.109    0.000
#     ly1  (gmm_ly1)    4.028    0.434    9.277    0.000
#    .ly2               0.000
#    .ly3               0.000
#    .y1                0.000
#    .y2                0.000
#    .y3                0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (alph_j2)    0.283    0.528    0.536    0.592
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     lx1 (sgm2_lx1)   -2.237    6.475   -0.345    0.730
#    .lx2               0.000
#    .lx3               0.000
#    .x1    (sgm2_x)   35.406    4.715    7.509    0.000
#    .x2    (sgm2_x)   35.406    4.715    7.509    0.000
#    .x3    (sgm2_x)   35.406    4.715    7.509    0.000
#    .dx2               0.000
#    .dx3               0.000
#     g2   (sgm2_g2)   19.074    8.186    2.330    0.020
#     ly1 (sgm2_ly1)   25.278    8.594    2.941    0.003
#    .ly2               0.000
#    .ly3               0.000
#    .y1    (sgm2_y)   10.783    2.354    4.581    0.000
#    .y2    (sgm2_y)   10.783    2.354    4.581    0.000
#    .y3    (sgm2_y)   10.783    2.354    4.581    0.000
#    .dy2               0.000
#    .dy3               0.000
#     j2   (sgm2_j2)    2.584    2.161    1.196    0.232
# plot without title
