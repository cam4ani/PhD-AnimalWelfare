# %%
library(brms) #predictability: Double hierearchical model
library(MCMCglmm) #HPDinterval
library(dplyr) #%>%
library(lmerTest) #lmer
#library(MuMIn) #r2
#library(merTools) #sim
library(sjPlot) #plot coeff
library(ggplot2) #ylim in plot
library(rstan) #model diagnostic
# Out:
# Warning message:
# "le package 'brms' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : Rcpp
#
# Warning message:
# "le package 'Rcpp' a été compilé avec la version R 4.1.2"
# Loading 'brms' package (version 2.16.3). Useful instructions
# can be found by typing help('brms'). A more detailed introduction
# to the package is available through vignette('brms_overview').
#
#
# Attachement du package : 'brms'
#
#
# L'objet suivant est masqué depuis 'package:stats':
#
#     ar
#
#
# Warning message:
# "le package 'MCMCglmm' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : Matrix
#
# Warning message:
# "le package 'Matrix' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : coda
#
# Warning message:
# "le package 'coda' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : ape
#
# Warning message:
# "le package 'ape' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'MCMCglmm'
#
#
# L'objet suivant est masqué depuis 'package:brms':
#
#     me
#
#
# Warning message:
# "le package 'dplyr' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'dplyr'
#
#
# Les objets suivants sont masqués depuis 'package:stats':
#
#     filter, lag
#
#
# Les objets suivants sont masqués depuis 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "le package 'lmerTest' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : lme4
#
# Warning message:
# "le package 'lme4' a été compilé avec la version R 4.1.2"
#
# Attachement du package : 'lme4'
#
#
# L'objet suivant est masqué depuis 'package:brms':
#
#     ngrps
#
#
#
# Attachement du package : 'lmerTest'
#
#
# L'objet suivant est masqué depuis 'package:lme4':
#
#     lmer
#
#
# L'objet suivant est masqué depuis 'package:stats':
#
#     step
#
#
# Warning message:
# "le package 'sjPlot' a été compilé avec la version R 4.1.2"
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!
#
# Warning message:
# "le package 'ggplot2' a été compilé avec la version R 4.1.2"
# Warning message:
# "le package 'rstan' a été compilé avec la version R 4.1.2"
# Le chargement a nécessité le package : StanHeaders
#
# Warning message:
# "le package 'StanHeaders' a été compilé avec la version R 4.1.2"
# rstan (Version 2.21.2, GitRev: 2e1f913d3ca3)
#
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
#
# Do not specify '-march=native' in 'LOCAL_CPPFLAGS' or a Makevars file
#
#
# Attachement du package : 'rstan'
#
#
# L'objet suivant est masqué depuis 'package:coda':
#
#     traceplot

# %%
library(parallel)
my.cores = detectCores()-1 #minus 1 to avoid bocking the computer
my.cores
# Out:
# [1] 11

# %%
#df[rowSums(is.na(df)) > 0,]

# %% [markdown]
# # Behavioural syndrome

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
#df = read.csv(file.path(path_,'df_daily_aggregatedHA.csv'), header = TRUE, sep = ",")
df = read.csv(file.path(path_,'df_BS.csv'), header = TRUE, sep = ",")

df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID)
df$TrackingSystemID = as.factor(df$TrackingSystemID)
df$level = as.factor(df$level) 
df$FoodPenID = as.factor(df$FoodPenID) 
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment)

#scale: mean-centering of the environmental variable so that intercepts reflect average values for the HenID and ind. 
#df$temperature_C_avg_scale = scale(df$temperature_C_avg, center=TRUE, scale=TRUE)

#setting reference group
df <- df %>% mutate(Treatment = relevel(Treatment, ref = "TRAN"))
contrasts(df$Treatment)
df <- df %>% mutate(CLASS = relevel(CLASS, ref = "REXP"))
contrasts(df$CLASS)
print(dim(df))
summary(df)

df$WentinWG = as.integer(df$WentinWG)
df$Sleeping_Uppest = as.integer(df$Sleeping_Uppest)

df$KBFInterp = df$KBF_interp
df$weightInterp = df$weight_interp


dim(df)
df_time = df[df$BS_type=='time',]
dim(df_time)

df_LP2 = df[df$BS_type=='LP2',]
dim(df_LP2)

df_LP10 = df[df$BS_type=='LP10',]
dim(df_LP10)

df_cold = df[df$BS_type=='cold',]
dim(df_cold)

df_vacc = df[df$BS_type=='TypicalVaccinationDay',]
dim(df_vacc)

df_AC = df[df$across_context==1,]
dim(df_AC)
# Out:
#      TRAN
# OFH  0
# TRAN 1
#      OFH
# TRAN 0
# OFH  1
#             MEXP NewAfterEpi REXP
# LEXP        0    0           0
# MEXP        1    0           0
# NewAfterEpi 0    1           0
# REXP        0    0           1
#             MEXP NewAfterEpi REXP
# LEXP        0    0           0
# MEXP        1    0           0
# NewAfterEpi 0    1           0
# REXP        0    0           1
# [1] 4892   22
#              TrackingSystemID        level           DOA             DIB
#  TrackingSystem 10-12:1848    2021-01-17: 159   Min.   :179.0   Min.   : 61.0
#  TrackingSystem 3-5  :1864    2021-04-18: 159   1st Qu.:216.0   1st Qu.: 98.0
#  TrackingSystem 8-9  :1180    2021-01-24: 158   Median :284.0   Median :166.0
#                               2021-05-07: 157   Mean   :285.2   Mean   :167.2
#                               2020-12-06: 156   3rd Qu.:340.0   3rd Qu.:222.0
#                               2020-12-20: 156   Max.   :410.0   Max.   :292.0
#                               (Other)   :3947
#          FoodPenID      BS_type          Treatment           CLASS
#  FoodPenID1-4 :1225   Length:4892        TRAN:2413   LEXP       : 916
#  FoodPenID5-8 :1206   Class :character   OFH :2479   MEXP       :1134
#  FoodPenID9-12:2461   Mode  :character               NewAfterEpi:1480
#                                                      REXP       :1362
#
#
#
#      PenID      temperature_C_avg  HenID_WIB             HenID
#  pen5   : 639   Min.   :-2.000    Length:4892        hen_10 :  32
#  pen11  : 628   1st Qu.: 3.333    Class :character   hen_101:  32
#  pen10  : 627   Median : 7.167    Mode  :character   hen_102:  32
#  pen4   : 626   Mean   : 9.274                       hen_107:  32
#  pen9   : 613   3rd Qu.:15.000                       hen_109:  32
#  pen3   : 599   Max.   :24.000                       hen_112:  32
#  (Other):1160                                        (Other):4700
#  across_context     KBF_interp    weight_interp     WentinWG
#  Min.   :0.0000   Min.   : 0.00   Min.   :1237   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:10.66   1st Qu.:1724   1st Qu.:0.0000
#  Median :0.0000   Median :21.88   Median :1821   Median :1.0000
#  Mean   :0.1255   Mean   :23.37   Mean   :1827   Mean   :0.6838
#  3rd Qu.:0.0000   3rd Qu.:35.24   3rd Qu.:1929   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :81.17   Max.   :2329   Max.   :1.0000
#
#  mid_cum_Z4_h_Morning Sleeping_Uppest
#  Min.   :2.037        Min.   :0.0000
#  1st Qu.:3.806        1st Qu.:0.0000
#  Median :4.402        Median :1.0000
#  Mean   :4.527        Mean   :0.6991
#  3rd Qu.:5.165        3rd Qu.:1.0000
#  Max.   :7.983        Max.   :1.0000
#
#  vertical_travel_distance_fulllight_perinsideh food_sameDurTiming_r50_final
#  Min.   : 0.1353                               Min.   :-0.7600
#  1st Qu.: 3.0002                               1st Qu.: 0.0300
#  Median : 4.1263                               Median : 0.2400
#  Mean   : 4.2031                               Mean   : 0.2334
#  3rd Qu.: 5.2393                               3rd Qu.: 0.4500
#  Max.   :13.5731                               Max.   : 0.9000
#
#  food_sameDurTiming_r50_AB_final food_sameDurTiming_r50_AP_final
#  Min.   :-0.82000                Min.   :-0.76000
#  1st Qu.:-0.14000                1st Qu.:-0.16000
#  Median : 0.03000                Median : 0.02000
#  Mean   : 0.02784                Mean   : 0.01911
#  3rd Qu.: 0.20000                3rd Qu.: 0.19000
#  Max.   : 0.83000                Max.   : 0.85000
# [1] 4892   24
# [1] 3196   24
# [1] 466  24
# [1] 450  24
# [1] 312  24
# [1] 468  24
# [1] 614  24

# %% [markdown]
# # Choose Data & Saving name

# %%
saving_name = 'ELS'
#choose you dataframe
df = df_LP2
iter_ = 1000000
iter_wu = 600000

# %% [markdown]
# # Multivariate models with correlated multilevel structure

# %% [raw]
# For better model fitting we willscalebehaviors, meaning that we center each behaviorat its mean value and standardize it to units of 1 phenotypic standard deviation. As all three behaviors arenow on the same scale, it is easier to interpret the model estimates.

# %% [markdown]
# #Get information on all parameters (and parameter classes) for which priors may be specified including default priors:
# get_prior(formula = scale(food_related_behavior_final_inv_cst) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
#           data=df_time, family = gaussian())

# %%
#Get information on all parameters (and parameter classes) for which priors may be specified including default priors:
FA = bf(scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(Sleeping_Uppest ~ Treatment + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
WG = bf(WentinWG ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
get_prior(formula = FA + VTD + TM + SD + WG +
                    set_rescor(FALSE), 
          data=df, family = bernoulli())
# Out:
#    prior                  class     coef                   group
# 1                         b
# 2  lkj(1)                 cor
# 3                         cor                              HenID
# 4                         Intercept
# 5                         b
# 6                         b         scaleDIB
# 7                         b         scaleKBFInterp
# 8                         b         scaleweightInterp
# 9                         b         TreatmentOFH
# 10 student_t(3, 1.4, 2.5) Intercept
# 11 student_t(3, 0, 2.5)   sd
# 12                        sd                               HenID
# 13                        sd        Intercept              HenID
# 14 gamma(0.01, 0.01)      shape
# 15                        b
# 16                        b         FoodPenIDFoodPenID5M8
# 17                        b         FoodPenIDFoodPenID9M12
# 18                        b         scaleDIB
# 19                        b         scaleKBFInterp
# 20                        b         scaleweightInterp
# 21                        b         TreatmentOFH
# 22 student_t(3, 0, 2.5)   Intercept
# 23 student_t(3, 0, 2.5)   sd
# 24                        sd                               HenID
# 25                        sd        Intercept              HenID
# 26 student_t(3, 0, 2.5)   sigma
# 27                        b
# 28                        b         scaleDIB
# 29                        b         scaleKBFInterp
# 30                        b         scaleweightInterp
# 31                        b         TreatmentOFH
# 32 student_t(3, 0, 2.5)   Intercept
# 33 student_t(3, 0, 2.5)   sd
# 34                        sd                               HenID
# 35                        sd        Intercept              HenID
# 36 student_t(3, 0, 2.5)   sigma
# 37                        b
# 38                        b         scaleDIB
# 39                        b         scaleKBFInterp
# 40                        b         scaleweightInterp
# 41                        b         TreatmentOFH
# 42 student_t(3, 0, 2.5)   Intercept
# 43 student_t(3, 0, 2.5)   sd
# 44                        sd                               HenID
# 45                        sd        Intercept              HenID
# 46                        b
# 47                        b         scaleDIB
# 48                        b         scaleKBFInterp
# 49                        b         scaleweightInterp
# 50                        b         TreatmentOFH
# 51 student_t(3, 0, 2.5)   Intercept
# 52 student_t(3, 0, 2.5)   sd
# 53                        sd                               HenID
# 54                        sd        Intercept              HenID
#    resp                                           dpar nlpar bound source
# 1                                                                  default
# 2                                                                  default
# 3                                                                  default
# 4                                                                  default
# 5  midcumZ4hMorning                                                default
# 6  midcumZ4hMorning                                                default
# 7  midcumZ4hMorning                                                default
# 8  midcumZ4hMorning                                                default
# 9  midcumZ4hMorning                                                default
# 10 midcumZ4hMorning                                                default
# 11 midcumZ4hMorning                                                default
# 12 midcumZ4hMorning                                                default
# 13 midcumZ4hMorning                                                default
# 14 midcumZ4hMorning                                                default
# 15 scalefoodsameDurTimingr50final                                  default
# 16 scalefoodsameDurTimingr50final                                  default
# 17 scalefoodsameDurTimingr50final                                  default
# 18 scalefoodsameDurTimingr50final                                  default
# 19 scalefoodsameDurTimingr50final                                  default
# 20 scalefoodsameDurTimingr50final                                  default
# 21 scalefoodsameDurTimingr50final                                  default
# 22 scalefoodsameDurTimingr50final                                  default
# 23 scalefoodsameDurTimingr50final                                  default
# 24 scalefoodsameDurTimingr50final                                  default
# 25 scalefoodsameDurTimingr50final                                  default
# 26 scalefoodsameDurTimingr50final                                  default
# 27 scaleverticaltraveldistancefulllightperinsideh                  default
# 28 scaleverticaltraveldistancefulllightperinsideh                  default
# 29 scaleverticaltraveldistancefulllightperinsideh                  default
# 30 scaleverticaltraveldistancefulllightperinsideh                  default
# 31 scaleverticaltraveldistancefulllightperinsideh                  default
# 32 scaleverticaltraveldistancefulllightperinsideh                  default
# 33 scaleverticaltraveldistancefulllightperinsideh                  default
# 34 scaleverticaltraveldistancefulllightperinsideh                  default
# 35 scaleverticaltraveldistancefulllightperinsideh                  default
# 36 scaleverticaltraveldistancefulllightperinsideh                  default
# 37 SleepingUppest                                                  default
# 38 SleepingUppest                                                  default
# 39 SleepingUppest                                                  default
# 40 SleepingUppest                                                  default
# 41 SleepingUppest                                                  default
# 42 SleepingUppest                                                  default
# 43 SleepingUppest                                                  default
# 44 SleepingUppest                                                  default
# 45 SleepingUppest                                                  default
# 46 WentinWG                                                        default
# 47 WentinWG                                                        default
# 48 WentinWG                                                        default
# 49 WentinWG                                                        default
# 50 WentinWG                                                        default
# 51 WentinWG                                                        default
# 52 WentinWG                                                        default
# 53 WentinWG                                                        default
# 54 WentinWG                                                        default

# %%
FA = bf(scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(Sleeping_Uppest ~ Treatment + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
WG = bf(WentinWG ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
#by default, the first category will serve as the reference (https://discourse.mc-stan.org/t/example-with-family-multinomial/8707/3)
#so latency_1_Zone_15mn_3h will be left out and latency_1_Zone_15mn_3hOPP will be shown
#WG = bf(latency_1_Zone_15mn_3h_bind | trials(size) ~ Treatment +scale(DIB)+scale(weight_interp)+scale(KBF_interp)+(1|a|HenID), 
#        family = multinomial()) 
#NV = bf(nbr_visit_Z4_Morning_more60sec ~ Treatment +scale(weight_interp) + scale(DIB) + scale(KBF_interp) +(1|a|HenID),
#        family=poisson)
Multi_DHGLM = brm(FA + VTD + TM + SD + WG +
                    set_rescor(FALSE),
                    data = df,
                    iter = iter_, warmup = iter_wu, thin = 50,
                    chains = 4, cores =my.cores, seed = 12345)
summary(Multi_DHGLM) #95% Posterior HPD Interval
#save model (from: https://bookdown.org/ajkurz/Statistical_Rethinking_recoded/horoscopes-insights.html#save-your-model-fits)
save(Multi_DHGLM, file = file.path(path_, paste0(saving_name, '_Multi_DHGLM_all_var_FINAL.rda')))
#load(file.path(path_,"Multi_DHGLM_allvar.rda")) #do not put modelreload = load(file.path(path_,"Multi_DHGLM_allvar_Food2.rda"))
# Out:
# Compiling Stan program...
#
# Start sampling
#  Family: MV(gaussian, gaussian, bernoulli, bernoulli)
#   Links: mu = identity; sigma = identity
#          mu = identity; sigma = identity
#          mu = logit
#          mu = logit
# Formula: scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          Sleeping_Uppest ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          WentinWG ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#    Data: df (Number of observations: 466)
#   Draws: 4 chains, each with iter = 250000; warmup = 150000; thin = 4;
#          total post-warmup draws = 1e+05
#
# Group-Level Effects:
# ~HenID (Number of levels: 156)
#                                                                                                        Estimate
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.65
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.85
# sd(SleepingUppest_Intercept)                                                                               3.54
# sd(WentinWG_Intercept)                                                                                     2.98
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.44
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                    -0.24
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.35
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.26
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.43
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           0.15
#                                                                                                        Est.Error
# sd(scalefoodsameDurTimingr50final_Intercept)                                                                0.06
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                                0.05
# sd(SleepingUppest_Intercept)                                                                                0.58
# sd(WentinWG_Intercept)                                                                                      0.47
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)      0.09
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                      0.12
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                      0.10
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                            0.12
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                            0.09
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                            0.12
#                                                                                                        l-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.55
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.75
# sd(SleepingUppest_Intercept)                                                                               2.55
# sd(WentinWG_Intercept)                                                                                     2.16
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.26
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                    -0.46
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.53
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.03
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.24
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                          -0.08
#                                                                                                        u-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.77
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.97
# sd(SleepingUppest_Intercept)                                                                               4.82
# sd(WentinWG_Intercept)                                                                                     4.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.60
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                    -0.01
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.15
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.48
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.59
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           0.38
#                                                                                                        Rhat
# sd(scalefoodsameDurTimingr50final_Intercept)                                                           1.00
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                           1.00
# sd(SleepingUppest_Intercept)                                                                           1.00
# sd(WentinWG_Intercept)                                                                                 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept) 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                 1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                       1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                       1.00
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                       1.00
#                                                                                                        Bulk_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                             354328
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                             312868
# sd(SleepingUppest_Intercept)                                                                             344524
# sd(WentinWG_Intercept)                                                                                   342307
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)   214626
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                   301468
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                   364213
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                         304754
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                         373434
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                         333553
#                                                                                                        Tail_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                             386495
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                             364417
# sd(SleepingUppest_Intercept)                                                                             378768
# sd(WentinWG_Intercept)                                                                                   381401
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)   317533
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                   365948
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                   386444
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                         364823
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                         388095
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                         373262
#
# Population-Level Effects:
#                                                                  Estimate
# scalefoodsameDurTimingr50final_Intercept                             0.13
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.19
# SleepingUppest_Intercept                                             1.86
# WentinWG_Intercept                                                   1.76
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.16
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.03
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.09
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.05
# scalefoodsameDurTimingr50final_scaleKBFInterp                       -0.03
# scalefoodsameDurTimingr50final_scaleDIB                              0.03
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.37
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp    -0.13
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp       -0.09
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              0.14
# SleepingUppest_TreatmentOFH                                          1.14
# SleepingUppest_scaleweightInterp                                    -0.13
# SleepingUppest_scaleKBFInterp                                       -0.02
# SleepingUppest_scaleDIB                                              0.07
# WentinWG_TreatmentOFH                                               -0.25
# WentinWG_scaleweightInterp                                          -0.09
# WentinWG_scaleKBFInterp                                             -0.76
# WentinWG_scaleDIB                                                    0.80
#                                                                  Est.Error
# scalefoodsameDurTimingr50final_Intercept                              0.14
# scaleverticaltraveldistancefulllightperinsideh_Intercept              0.10
# SleepingUppest_Intercept                                              0.53
# WentinWG_Intercept                                                    0.47
# scalefoodsameDurTimingr50final_TreatmentOFH                           0.13
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                  0.17
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                 0.15
# scalefoodsameDurTimingr50final_scaleweightInterp                      0.06
# scalefoodsameDurTimingr50final_scaleKBFInterp                         0.06
# scalefoodsameDurTimingr50final_scaleDIB                               0.04
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH           0.14
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp      0.07
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp         0.06
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB               0.02
# SleepingUppest_TreatmentOFH                                           0.75
# SleepingUppest_scaleweightInterp                                      0.36
# SleepingUppest_scaleKBFInterp                                         0.34
# SleepingUppest_scaleDIB                                               0.17
# WentinWG_TreatmentOFH                                                 0.60
# WentinWG_scaleweightInterp                                            0.30
# WentinWG_scaleKBFInterp                                               0.29
# WentinWG_scaleDIB                                                     0.17
#                                                                  l-95% CI
# scalefoodsameDurTimingr50final_Intercept                            -0.13
# scaleverticaltraveldistancefulllightperinsideh_Intercept            -0.02
# SleepingUppest_Intercept                                             0.89
# WentinWG_Intercept                                                   0.90
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.41
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.37
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.37
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.18
# scalefoodsameDurTimingr50final_scaleKBFInterp                       -0.15
# scalefoodsameDurTimingr50final_scaleDIB                             -0.05
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.65
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp    -0.27
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp       -0.21
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              0.09
# SleepingUppest_TreatmentOFH                                         -0.26
# SleepingUppest_scaleweightInterp                                    -0.83
# SleepingUppest_scaleKBFInterp                                       -0.70
# SleepingUppest_scaleDIB                                             -0.26
# WentinWG_TreatmentOFH                                               -1.45
# WentinWG_scaleweightInterp                                          -0.67
# WentinWG_scaleKBFInterp                                             -1.36
# WentinWG_scaleDIB                                                    0.47
#                                                                  u-95% CI Rhat
# scalefoodsameDurTimingr50final_Intercept                             0.40 1.00
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.39 1.00
# SleepingUppest_Intercept                                             2.98 1.00
# WentinWG_Intercept                                                   2.75 1.00
# scalefoodsameDurTimingr50final_TreatmentOFH                          0.09 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 0.30 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                0.20 1.00
# scalefoodsameDurTimingr50final_scaleweightInterp                     0.08 1.00
# scalefoodsameDurTimingr50final_scaleKBFInterp                        0.09 1.00
# scalefoodsameDurTimingr50final_scaleDIB                              0.10 1.00
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.08 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     0.00 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.03 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              0.19 1.00
# SleepingUppest_TreatmentOFH                                          2.68 1.00
# SleepingUppest_scaleweightInterp                                     0.57 1.00
# SleepingUppest_scaleKBFInterp                                        0.65 1.00
# SleepingUppest_scaleDIB                                              0.41 1.00
# WentinWG_TreatmentOFH                                                0.92 1.00
# WentinWG_scaleweightInterp                                           0.49 1.00
# WentinWG_scaleKBFInterp                                             -0.22 1.00
# WentinWG_scaleDIB                                                    1.15 1.00
#                                                                  Bulk_ESS
# scalefoodsameDurTimingr50final_Intercept                           380462
# scaleverticaltraveldistancefulllightperinsideh_Intercept           353697
# SleepingUppest_Intercept                                           381786
# WentinWG_Intercept                                                 375291
# scalefoodsameDurTimingr50final_TreatmentOFH                        388111
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8               379891
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12              370947
# scalefoodsameDurTimingr50final_scaleweightInterp                   390560
# scalefoodsameDurTimingr50final_scaleKBFInterp                      395273
# scalefoodsameDurTimingr50final_scaleDIB                            379162
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH        355079
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp   364404
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp      385270
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB            374265
# SleepingUppest_TreatmentOFH                                        376720
# SleepingUppest_scaleweightInterp                                   384078
# SleepingUppest_scaleKBFInterp                                      394032
# SleepingUppest_scaleDIB                                            376730
# WentinWG_TreatmentOFH                                              381953
# WentinWG_scaleweightInterp                                         391405
# WentinWG_scaleKBFInterp                                            387052
# WentinWG_scaleDIB                                                  382186
#                                                                  Tail_ESS
# scalefoodsameDurTimingr50final_Intercept                           391312
# scaleverticaltraveldistancefulllightperinsideh_Intercept           384117
# SleepingUppest_Intercept                                           392462
# WentinWG_Intercept                                                 387744
# scalefoodsameDurTimingr50final_TreatmentOFH                        392762
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8               393570
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12              389214
# scalefoodsameDurTimingr50final_scaleweightInterp                   395970
# scalefoodsameDurTimingr50final_scaleKBFInterp                      397032
# scalefoodsameDurTimingr50final_scaleDIB                            382832
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH        381850
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp   383748
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp      395243
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB            386805
# SleepingUppest_TreatmentOFH                                        389081
# SleepingUppest_scaleweightInterp                                   392559
# SleepingUppest_scaleKBFInterp                                      395353
# SleepingUppest_scaleDIB                                            386151
# WentinWG_TreatmentOFH                                              392655
# WentinWG_scaleweightInterp                                         394568
# WentinWG_scaleKBFInterp                                            393658
# WentinWG_scaleDIB                                                  383891
#
# Family Specific Parameters:
#                                                      Estimate Est.Error
# sigma_scalefoodsameDurTimingr50final                     0.77      0.03
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.47      0.02
#                                                      l-95% CI u-95% CI Rhat
# sigma_scalefoodsameDurTimingr50final                     0.71     0.84 1.00
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.44     0.51 1.00
#                                                      Bulk_ESS Tail_ESS
# sigma_scalefoodsameDurTimingr50final                   370848   381918
# sigma_scaleverticaltraveldistancefulllightperinsideh   370508   387664
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### saving some outputs

# %%
#coefficient of variation in predictability” (CVP)
#log.norm.res = exp(posterior_samples(Multi_DHGLM)$"sd_HenID__sigma_Intercept"^2)
#CVP = sqrt(log.norm.res-1)
#mean(CVP);HPDinterval(as.mcmc(CVP),0.95)

#posterior samples dimensionality of the dataframe:
#nrw=(iter-warup)/thin * chain
#ncol=#param to estimate
prior_summary(Multi_DHGLM)

#all data, sd in python
#extract samples (draw) from the posterior distribution, including all variables
#df_pred = posterior_samples(modelPred) #depreciated but still work well. we will instead use:
colnames(posterior_samples(Multi_DHGLM))[1:30]
df_pred = as_draws(Multi_DHGLM)
length(df_pred[[1]]) #nbr param
length(df_pred[[1]][[1]]) #nbr posterior samples we got per chain
write.csv(df_pred, file.path(path_,paste0(saving_name,'_BRMS_BS_pred_allvar_FINAL.csv')), row.names = TRUE)

#only mean and CI from R
df_pred = posterior_samples(Multi_DHGLM)
dim(df_pred) # nbr posterior samles we got, #param
#--> (1250, 4044) ou (5000, 1011)
df_mean = colMeans(df_pred)
df_CI = HPDinterval(as.mcmc(df_pred))
dim(df_CI)
write.csv(df_CI, file.path(path_,paste0(saving_name,'_df_CI_BRMS_BS_pred_allvar_FINAL.csv')), row.names = TRUE)
write.csv(df_mean, file.path(path_,paste0(saving_name,'_df_mean_BRMS_BS_pred_allvar_FINAL.csv')), row.names = TRUE)
dim(df)

# %%
#mean population-level estimates
fixef(Multi_DHGLM)
p1 = plot_model(Multi_DHGLM,  show.values = TRUE, title='Population-Level Effects', 
            rm.terms = c('FoodPenIDFoodPenID9M12','FoodPenIDFoodPenID5M8'), #TreatmentOFH
                type = "est", colors = c("red3", "forestgreen"))+ ylim(-.6, .6)
ggsave(file.path(path_,paste0(saving_name,'_Multi_fixedestimate_withOFH_FINAL.png')), plot=p1, height=5, width=12, dpi=600) 

p1 = plot_model(Multi_DHGLM,  show.values = TRUE, title='Population-Level Effects', 
            rm.terms = c('TreatmentOFH','FoodPenIDFoodPenID9M12','FoodPenIDFoodPenID5M8'), #TreatmentOFH
                type = "est", colors = c("red3", "forestgreen"))+ ylim(-.6, .6)
ggsave(file.path(path_,paste0(saving_name,'_Multi_fixedestimate_withoutOFH_FINAL.png')), plot=p1, height=5, width=12, dpi=600) 
#or in terms of density: https://www.rensvandeschoot.com/tutorials/generalised-linear-models-with-brms/
#stanplot(Multi_DHGLM, type = "areas", prob = 0.95)
#darkgreen, forestgreen ; firebrick, red3
#ex of interpretation: https://www.rensvandeschoot.com/tutorials/generalised-linear-models-with-brms/

# %%
colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__scalefoodsameDurTimingr50final_Intercept__scaleverticaltraveldistancefulllightperinsideh_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation food behavior & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation sleep up & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__scalefoodsameDurTimingr50final_Intercept__WentinWG_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation food behavior & went outside",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation went outside & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__scalefoodsameDurTimingr50final_Intercept__SleepingUppest_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation went outside & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %% [markdown]
# ### model diagnostic

# %%
load(file.path(path_,paste0(saving_name, '_Multi_DHGLM_all_var_FINAL.rda')))

# %%
############## Loo-cv and waic ##############
#conditional_effects(Multi_DHGLM)
Multi_DHGLM = add_criterion(Multi_DHGLM, criterion=c('waic','loo'), file=file.path(path_,paste0(saving_name,'_Multi_DHGLM_allvar_FINAL')))
#head(get_variables(modelPred),10)
print('----------------------- waic')
print(Multi_DHGLM$criteria$waic)

print('----------------------- loo-cv')
#approximative leave-one-out cross validation
print(Multi_DHGLM$criteria$loo)

print('----------------------- loo2')
#check highly influential observations
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-moment-matching.html
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-example.html
#"If we had a well-specified model we would expect the estimated effective number of parameters (p_loo) to be smaller than or 
#similar to the total number of parameters in the model."
loo2 = loo(Multi_DHGLM, moment_match = TRUE)
loo2
plot(loo2, label_points = TRUE)

# %%
############## posterior predictive check ##############
pp_check(Multi_DHGLM, resp='scalefoodsameDurTimingr50final',ndraws = 100)
pp_check(Multi_DHGLM, resp='scaleverticaltraveldistancefulllightperinsideh',ndraws = 100)
pp_check(Multi_DHGLM, resp='midcumZ4hMorning',ndraws = 100)
pp_check(Multi_DHGLM, resp='SleepingUppest',ndraws = 100)
pp_check(Multi_DHGLM, resp='WentinWG',ndraws = 100)
# Out:
# plot without title
# Error: Invalid argument 'resp'. Valid response variables are: 'scalefoodsameDurTimingr50final', 'scaleverticaltraveldistancefulllightperinsideh', 'SleepingUppest', 'WentinWG'
# Traceback:
#
# 1. pp_check(Multi_DHGLM, resp = "midcumZ4hMorning", ndraws = 100)
# 2. pp_check.brmsfit(Multi_DHGLM, resp = "midcumZ4hMorning", ndraws = 100)
# 3. validate_resp(resp, object, multiple = FALSE)
# 4. stop2("Invalid argument 'resp'. Valid response ", "variables are: ",
#  .     collapse_comma(x))
# 5. stop(..., call. = FALSE)
# plot without title

# %%
############## trace plot ##############
#variables(Multi_DHGLM) #extract parameter names
length(variables(Multi_DHGLM)) #nbr of param
li_param = variables(Multi_DHGLM)
cond = lapply(li_param, function(x) !startsWith(x, 'r_'))
li_param_notR = li_param[unlist(cond)]
length(li_param_notR) #nbr param without random intercepts
li_param_notR
              
#44 plots (I guess its all param without random effects. 44 plots, 46 param withour r_, so 2 are missing: probably lp & shape
             #from the gamma family)
#mcmc_plot(Multi_DHGLM, type = "trace", variable=li_param_notR)#previously: stanplot #to small plots
plot(Multi_DHGLM)

# %%
############## Gelman-Rubin diagnostic ##############
#is automatically given in the summary of brms under the column Rhat!
#lets give for all except random intercept (else 1011 plot!!)
modelposterior = as.mcmc(Multi_DHGLM) # with as.mcmc() we can use all the CODA package cvg statistics & plotting options
gelman.diag(modelposterior[, li_param_notR])
gelman.plot(modelposterior[, li_param_notR])

# %%
############## Geweke diagnostic ##############
#shows the z-scores for a test of equality of means between the first and last parts of each chain, which should be <1.96
geweke.diag(modelposterior[, li_param_notR])
geweke.plot(modelposterior[, li_param_notR])
#sd_HenID__foodsameDurTimingr50final_Intercept : BAD: 2.61144, with more iterations we have: 0.94243 
#cor_HenID__foodsameDurTimingr50final_Intercept__SleepingUppest_Intercept : 2.11821, with more iterations we have: 1.18771
#others too
#each [[*]] correspond to chain *
#sigma_scaleverticaltraveldistancefulllightperinsideh stil to large, b_SleepingUppest_TreatmentOFH too etc

# %%
############## do the chains exhibit a strong degree of autocorrelation? ##############
#if we want to do, read this paper first On thinning of chains in MCMC
cond = lapply(li_param, function(x) startsWith(x, 'cor_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[1:5])
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[5:length(li_param_)])

cond = lapply(li_param, function(x) startsWith(x, 'b_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[1:5])   
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[5:10])  
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[10:15])  
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[15:20])    
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[20:25])   
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_[25:length(li_param_)])   
             
cond = lapply(li_param, function(x) startsWith(x, 'sigma_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_)   
              
cond = lapply(li_param, function(x) startsWith(x, 'sd_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_)   
                            
cond = lapply(li_param, function(x) startsWith(x, 'shape_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_)   

cond = lapply(li_param, function(x) startsWith(x, 'lp_'))
li_param_ = li_param[unlist(cond)]
length(li_param_) #nbr param without random intercepts
mcmc_plot(Multi_DHGLM, type = "acf", variable=li_param_)

# %%
############## results differ when augmenting the number of iteration? check for bais ##############
#from: https://www.rensvandeschoot.com/tutorials/wambs-checklist-in-r-using-brms/
#To get the relative bias simply save the means of the regression coefficients and other parameters (ignore lp__ for now) for the two different analyses and compute the bias.
FA = bf(scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(Sleeping_Uppest ~ Treatment + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
WG = bf(WentinWG ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli(link = "logit")) #binary logistic regression
model_moreiter = brm(FA + VTD + TM + SD + WG +
                    set_rescor(FALSE),
                    data = df,
                    iter = round(iter_*1.3,0), warmup = round(iter_wu*1.3,2), thin = 4,
                    chains = 4, cores =my.cores, seed = 12345
                    )
summary(model_moreiter)
round(100*((posterior_summary(model_moreiter)[,"Estimate"] - posterior_summary(Multi_DHGLM)[,"Estimate"]) / posterior_summary(Multi_DHGLM)[,"Estimate"]), 4)
#If the relative bias is small enough (<5%), do not worry about it.
