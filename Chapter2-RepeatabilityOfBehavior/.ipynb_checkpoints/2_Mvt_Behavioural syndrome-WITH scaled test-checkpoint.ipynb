# %%
library(brms) #predictability: Double hierearchical model
library(MCMCglmm) #HPDinterval
library(dplyr) #%>%
library(lmerTest) #lmer
#library(MuMIn) #r2
#library(merTools) #sim
library(sjPlot) #plot coeff
library(ggplot2) #ylim in plot

# %%
library(parallel)
my.cores = detectCores()-1 #minus 1 to avoid bocking the computer
my.cores
# Out:
# [1] 11

# %%
#df[rowSums(is.na(df)) > 0,]

# %% [markdown]
# # Behavioural syndrome

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
#df = read.csv(file.path(path_,'df_daily_aggregatedHA.csv'), header = TRUE, sep = ",")
df = read.csv(file.path(path_,'df_BS.csv'), header = TRUE, sep = ",")

df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID)
df$TrackingSystemID = as.factor(df$TrackingSystemID)
df$level = as.factor(df$level) 
df$FoodPenID = as.factor(df$FoodPenID) 
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment)

#scale: mean-centering of the environmental variable so that intercepts reflect average values for the HenID and ind. 
#df$temperature_C_avg_scale = scale(df$temperature_C_avg, center=TRUE, scale=TRUE)

#setting reference group
contrasts(df$Treatment)
df <- df %>% mutate(Treatment = relevel(Treatment, ref = "TRAN"))
contrasts(df$Treatment)

contrasts(df$CLASS)
df <- df %>% mutate(CLASS = relevel(CLASS, ref = "LEXP"))
contrasts(df$CLASS)
print(dim(df))
summary(df)

df$WentinWG = as.integer(df$WentinWG)
df$Sleeping_Uppest = as.integer(df$Sleeping_Uppest)

df$KBFInterp = df$KBF_interp
df$weightInterp = df$weight_interp


dim(df)
df_time = df[df$BS_type=='time',]
dim(df_time)

df_LP2 = df[df$BS_type=='LP2',]
dim(df_LP2)

df_LP10 = df[df$BS_type=='LP10',]
dim(df_LP10)

df_cold = df[df$BS_type=='cold',]
dim(df_cold)

df_vacc = df[df$BS_type=='TypicalVaccinationDay',]
dim(df_vacc)

df_AC = df[df$across_context==1,]
dim(df_AC)
# Out:
#      TRAN
# OFH  0
# TRAN 1
#      OFH
# TRAN 0
# OFH  1
#             MEXP NewAfterEpi REXP
# LEXP        0    0           0
# MEXP        1    0           0
# NewAfterEpi 0    1           0
# REXP        0    0           1
#             MEXP NewAfterEpi REXP
# LEXP        0    0           0
# MEXP        1    0           0
# NewAfterEpi 0    1           0
# REXP        0    0           1
# [1] 4892   22
#              TrackingSystemID        level           DOA             DIB
#  TrackingSystem 10-12:1848    2021-01-17: 159   Min.   :179.0   Min.   : 61.0
#  TrackingSystem 3-5  :1864    2021-04-18: 159   1st Qu.:216.0   1st Qu.: 98.0
#  TrackingSystem 8-9  :1180    2021-01-24: 158   Median :284.0   Median :166.0
#                               2021-05-07: 157   Mean   :285.2   Mean   :167.2
#                               2020-12-06: 156   3rd Qu.:340.0   3rd Qu.:222.0
#                               2020-12-20: 156   Max.   :410.0   Max.   :292.0
#                               (Other)   :3947
#          FoodPenID      BS_type          Treatment           CLASS
#  FoodPenID1-4 :1225   Length:4892        TRAN:2413   LEXP       : 916
#  FoodPenID5-8 :1206   Class :character   OFH :2479   MEXP       :1134
#  FoodPenID9-12:2461   Mode  :character               NewAfterEpi:1480
#                                                      REXP       :1362
#
#
#
#      PenID      temperature_C_avg  HenID_WIB             HenID
#  pen5   : 639   Min.   :-2.000    Length:4892        hen_10 :  32
#  pen11  : 628   1st Qu.: 3.333    Class :character   hen_101:  32
#  pen10  : 627   Median : 7.167    Mode  :character   hen_102:  32
#  pen4   : 626   Mean   : 9.274                       hen_107:  32
#  pen9   : 613   3rd Qu.:15.000                       hen_109:  32
#  pen3   : 599   Max.   :24.000                       hen_112:  32
#  (Other):1160                                        (Other):4700
#  across_context     KBF_interp    weight_interp     WentinWG
#  Min.   :0.0000   Min.   : 0.00   Min.   :1237   Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:10.66   1st Qu.:1724   1st Qu.:0.0000
#  Median :0.0000   Median :21.88   Median :1821   Median :1.0000
#  Mean   :0.1255   Mean   :23.37   Mean   :1827   Mean   :0.6838
#  3rd Qu.:0.0000   3rd Qu.:35.24   3rd Qu.:1929   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :81.17   Max.   :2329   Max.   :1.0000
#
#  mid_cum_Z4_h_Morning Sleeping_Uppest
#  Min.   :2.037        Min.   :0.0000
#  1st Qu.:3.806        1st Qu.:0.0000
#  Median :4.402        Median :1.0000
#  Mean   :4.527        Mean   :0.6991
#  3rd Qu.:5.165        3rd Qu.:1.0000
#  Max.   :7.983        Max.   :1.0000
#
#  vertical_travel_distance_fulllight_perinsideh food_sameDurTiming_r50_final
#  Min.   : 0.1353                               Min.   :-0.650991
#  1st Qu.: 3.0002                               1st Qu.: 0.001901
#  Median : 4.1263                               Median : 0.181700
#  Mean   : 4.2031                               Mean   : 0.183458
#  3rd Qu.: 5.2393                               3rd Qu.: 0.367917
#  Max.   :13.5731                               Max.   : 0.945750
#
#  food_sameDurTiming_r50_AB_final food_sameDurTiming_r50_AP_final
#  Min.   :-0.75563                Min.   :-0.64230
#  1st Qu.:-0.12925                1st Qu.:-0.14153
#  Median : 0.01679                Median : 0.01249
#  Mean   : 0.02150                Mean   : 0.01893
#  3rd Qu.: 0.17210                3rd Qu.: 0.17655
#  Max.   : 0.79792                Max.   : 0.88596
# [1] 4892   24
# [1] 3196   24
# [1] 466  24
# [1] 450  24
# [1] 312  24
# [1] 468  24
# [1] 614  24

# %% [raw]
# #brms family: https://paul-buerkner.github.io/brms/reference/brmsfamily.html
# Families bernoulli and binomial can be used for binary regression (i.e., most commonly logistic regression)

# %% [raw]
# #for later analysis:
# #interesting brms models: https://discourse.mc-stan.org/t/brms-non-linear-models-correlated-random-effects/12852
# priors:
# https://discourse.mc-stan.org/t/repeated-measures-ordinal-model-with-brms-how-to-specify-correlation-structure/14352
# prior = c(set_prior(prior = "normal(0,10)", class = "Intercept"),
#                      set_prior(prior = "normal(0,5)", class = "b"),
#                      set_prior(prior = "normal(0,5)", class = "sd")

# %% [markdown]
# # Multivariate models with correlated multilevel structure

# %% [raw]
# For better model fitting we willscalebehaviors, meaning that we center each behaviorat its mean value and standardize it to units of 1 phenotypic standard deviation. As all three behaviors arenow on the same scale, it is easier to interpret the model estimates.

# %% [markdown]
# #Get information on all parameters (and parameter classes) for which priors may be specified including default priors:
# get_prior(formula = scale(food_related_behavior_final_inv_cst) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
#           data=df_time, family = gaussian())

# %% [markdown]
# #Get information on all parameters (and parameter classes) for which priors may be specified including default priors:
# get_prior(formula = Sleeping_NotUppest ~ Treatment + scale(weight_interp)+scale(KBF_interp) + (1|a|HenID),
#           data=df_time, family = bernoulli())

# %% [raw]
# if not correlated inside the birds, but outside the birds yes, then its mroe likely true behavioural correlation instead of just intrasinc correlation

# %%
#not scaling, keeping most possible original scale
#food_sameDurTiming_r50_final, food_reactivity_index_cst
FA = bf(food_sameDurTiming_r50_final ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(Sleeping_Uppest ~ Treatment + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli()) 
#by default, the first category will serve as the reference (https://discourse.mc-stan.org/t/example-with-family-multinomial/8707/3)
#so latency_1_Zone_15mn_3h will be left out and latency_1_Zone_15mn_3hOPP will be shown
#WG = bf(latency_1_Zone_15mn_3h_bind | trials(size) ~ Treatment +scale(DIB)+scale(weight_interp)+scale(KBF_interp)+(1|a|HenID), 
#        family = multinomial()) 
WG = bf(WentinWG ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli()) 
#NV = bf(nbr_visit_Z4_Morning_more60sec ~ Treatment +scale(weight_interp) + scale(DIB) + scale(KBF_interp) +(1|a|HenID),
#        family=poisson)
Multi_DHGLM = brm(FA + VTD + TM + SD + WG +
                    set_rescor(FALSE),
                    data = df,
                    iter = 20000, warmup = 15000, thin = 4,
                    chains = 4, cores =my.cores, seed = 12345
                    )

#save model (from: https://bookdown.org/ajkurz/Statistical_Rethinking_recoded/horoscopes-insights.html#save-your-model-fits)
save(Multi_DHGLM, file = file.path(path_,"Multi_DHGLM_allvar_Food2.rda"))
#load(file.path(path_,"Multi_DHGLM_allvar.rda")) #do not put modelreload = load(file.path(path_,"Multi_DHGLM_allvar_Food2.rda"))

summary(Multi_DHGLM)
#cor(scaleVTD_Intercept,mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept)  : the more you move vertically, the more
#latency1Zone15mn3hOPP is high, i.e. the more you go in the WG earlier
# Out:
# Compiling Stan program...
#
# Start sampling
#  Family: MV(gaussian, gaussian, gamma, bernoulli, bernoulli)
#   Links: mu = identity; sigma = identity
#          mu = identity; sigma = identity
#          mu = log; shape = identity
#          mu = logit
#          mu = logit
# Formula: food_sameDurTiming_r50_final ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          Sleeping_Uppest ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          WentinWG ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#    Data: df (Number of observations: 4892)
#   Draws: 4 chains, each with iter = 5000; warmup = 3750; thin = 4;
#          total post-warmup draws = 1250
#
# Group-Level Effects:
# ~HenID (Number of levels: 193)
#                                                                                              Estimate
# sd(foodsameDurTimingr50final_Intercept)                                                          0.14
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                          1.47
# sd(midcumZ4hMorning_Intercept)                                                                   0.14
# sd(SleepingUppest_Intercept)                                                                     2.28
# sd(WentinWG_Intercept)                                                                           2.20
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)     0.43
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                             -0.07
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)             -0.02
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                               -0.15
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)               -0.24
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                        -0.04
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                      0.28
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                      0.52
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                              -0.04
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                 0.05
#                                                                                              Est.Error
# sd(foodsameDurTimingr50final_Intercept)                                                           0.01
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                           0.08
# sd(midcumZ4hMorning_Intercept)                                                                    0.01
# sd(SleepingUppest_Intercept)                                                                      0.16
# sd(WentinWG_Intercept)                                                                            0.15
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)      0.07
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                               0.08
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)               0.08
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                 0.08
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                 0.08
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                          0.08
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                       0.08
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                       0.06
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                0.08
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                  0.08
#                                                                                              l-95% CI
# sd(foodsameDurTimingr50final_Intercept)                                                          0.12
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                          1.33
# sd(midcumZ4hMorning_Intercept)                                                                   0.13
# sd(SleepingUppest_Intercept)                                                                     2.00
# sd(WentinWG_Intercept)                                                                           1.91
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)     0.30
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                             -0.22
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)             -0.17
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                               -0.30
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)               -0.39
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                        -0.19
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                      0.12
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                      0.40
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                              -0.19
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                -0.10
#                                                                                              u-95% CI
# sd(foodsameDurTimingr50final_Intercept)                                                          0.16
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                          1.63
# sd(midcumZ4hMorning_Intercept)                                                                   0.16
# sd(SleepingUppest_Intercept)                                                                     2.61
# sd(WentinWG_Intercept)                                                                           2.51
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)     0.56
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                              0.09
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)              0.13
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                0.01
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)               -0.10
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                         0.12
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                      0.42
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                      0.63
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                               0.12
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                 0.21
#                                                                                              Rhat
# sd(foodsameDurTimingr50final_Intercept)                                                      1.00
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                      1.00
# sd(midcumZ4hMorning_Intercept)                                                               1.00
# sd(SleepingUppest_Intercept)                                                                 1.00
# sd(WentinWG_Intercept)                                                                       1.00
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept) 1.00
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                          1.00
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)          1.00
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                            1.00
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)            1.00
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                     1.00
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                  1.00
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                  1.00
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                           1.00
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                             1.00
#                                                                                              Bulk_ESS
# sd(foodsameDurTimingr50final_Intercept)                                                          3230
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                          1622
# sd(midcumZ4hMorning_Intercept)                                                                   2284
# sd(SleepingUppest_Intercept)                                                                     2786
# sd(WentinWG_Intercept)                                                                           3178
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)     1074
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                              1260
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)              1508
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                1781
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                2087
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                         1670
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                      1560
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                      2595
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                               2035
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                 2098
#                                                                                              Tail_ESS
# sd(foodsameDurTimingr50final_Intercept)                                                          4058
# sd(verticaltraveldistancefulllightperinsideh_Intercept)                                          2931
# sd(midcumZ4hMorning_Intercept)                                                                   3573
# sd(SleepingUppest_Intercept)                                                                     4110
# sd(WentinWG_Intercept)                                                                           4316
# cor(foodsameDurTimingr50final_Intercept,verticaltraveldistancefulllightperinsideh_Intercept)     2075
# cor(foodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                              2152
# cor(verticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)              2587
# cor(foodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                3082
# cor(verticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                3073
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                         2842
# cor(foodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                      2742
# cor(verticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                      3833
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                               3146
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                 3363
#
# Population-Level Effects:
#                                                             Estimate Est.Error
# foodsameDurTimingr50final_Intercept                             0.22      0.02
# verticaltraveldistancefulllightperinsideh_Intercept             4.24      0.15
# midcumZ4hMorning_Intercept                                      1.50      0.01
# SleepingUppest_Intercept                                        1.37      0.25
# WentinWG_Intercept                                              1.25      0.24
# foodsameDurTimingr50final_TreatmentOFH                         -0.03      0.02
# foodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.00      0.03
# foodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.04      0.02
# foodsameDurTimingr50final_scaleweightInterp                    -0.01      0.01
# foodsameDurTimingr50final_scaleKBFInterp                        0.01      0.01
# foodsameDurTimingr50final_scaleDIB                              0.02      0.01
# verticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.24      0.22
# verticaltraveldistancefulllightperinsideh_scaleweightInterp     0.03      0.05
# verticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.07      0.03
# verticaltraveldistancefulllightperinsideh_scaleDIB             -0.21      0.03
# midcumZ4hMorning_TreatmentOFH                                  -0.01      0.02
# midcumZ4hMorning_scaleweightInterp                             -0.07      0.01
# midcumZ4hMorning_scaleKBFInterp                                -0.01      0.00
# midcumZ4hMorning_scaleDIB                                       0.10      0.00
# SleepingUppest_TreatmentOFH                                     0.40      0.36
# SleepingUppest_scaleweightInterp                                0.07      0.12
# SleepingUppest_scaleKBFInterp                                   0.08      0.09
# SleepingUppest_scaleDIB                                        -0.40      0.07
# WentinWG_TreatmentOFH                                          -0.10      0.34
# WentinWG_scaleweightInterp                                     -0.15      0.11
# WentinWG_scaleKBFInterp                                        -0.09      0.08
# WentinWG_scaleDIB                                               0.39      0.07
#                                                             l-95% CI u-95% CI
# foodsameDurTimingr50final_Intercept                             0.17     0.26
# verticaltraveldistancefulllightperinsideh_Intercept             3.95     4.55
# midcumZ4hMorning_Intercept                                      1.47     1.53
# SleepingUppest_Intercept                                        0.87     1.86
# WentinWG_Intercept                                              0.78     1.73
# foodsameDurTimingr50final_TreatmentOFH                         -0.07     0.01
# foodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.06     0.05
# foodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.09     0.01
# foodsameDurTimingr50final_scaleweightInterp                    -0.03     0.00
# foodsameDurTimingr50final_scaleKBFInterp                       -0.00     0.02
# foodsameDurTimingr50final_scaleDIB                              0.01     0.03
# verticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.67     0.19
# verticaltraveldistancefulllightperinsideh_scaleweightInterp    -0.06     0.12
# verticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.01     0.14
# verticaltraveldistancefulllightperinsideh_scaleDIB             -0.26    -0.16
# midcumZ4hMorning_TreatmentOFH                                  -0.05     0.03
# midcumZ4hMorning_scaleweightInterp                             -0.08    -0.05
# midcumZ4hMorning_scaleKBFInterp                                -0.02    -0.00
# midcumZ4hMorning_scaleDIB                                       0.09     0.11
# SleepingUppest_TreatmentOFH                                    -0.30     1.11
# SleepingUppest_scaleweightInterp                               -0.16     0.30
# SleepingUppest_scaleKBFInterp                                  -0.09     0.26
# SleepingUppest_scaleDIB                                        -0.54    -0.26
# WentinWG_TreatmentOFH                                          -0.76     0.56
# WentinWG_scaleweightInterp                                     -0.37     0.07
# WentinWG_scaleKBFInterp                                        -0.25     0.07
# WentinWG_scaleDIB                                               0.25     0.53
#                                                             Rhat Bulk_ESS
# foodsameDurTimingr50final_Intercept                         1.00     1649
# verticaltraveldistancefulllightperinsideh_Intercept         1.00     1262
# midcumZ4hMorning_Intercept                                  1.00     1375
# SleepingUppest_Intercept                                    1.00     1600
# WentinWG_Intercept                                          1.00     2085
# foodsameDurTimingr50final_TreatmentOFH                      1.00     1705
# foodsameDurTimingr50final_FoodPenIDFoodPenID5M8             1.00     1762
# foodsameDurTimingr50final_FoodPenIDFoodPenID9M12            1.00     1680
# foodsameDurTimingr50final_scaleweightInterp                 1.00     2381
# foodsameDurTimingr50final_scaleKBFInterp                    1.00     3672
# foodsameDurTimingr50final_scaleDIB                          1.00     3103
# verticaltraveldistancefulllightperinsideh_TreatmentOFH      1.00     1217
# verticaltraveldistancefulllightperinsideh_scaleweightInterp 1.00     3786
# verticaltraveldistancefulllightperinsideh_scaleKBFInterp    1.00     4704
# verticaltraveldistancefulllightperinsideh_scaleDIB          1.00     4397
# midcumZ4hMorning_TreatmentOFH                               1.00     1386
# midcumZ4hMorning_scaleweightInterp                          1.00     3664
# midcumZ4hMorning_scaleKBFInterp                             1.00     4093
# midcumZ4hMorning_scaleDIB                                   1.00     4228
# SleepingUppest_TreatmentOFH                                 1.00     1794
# SleepingUppest_scaleweightInterp                            1.00     3703
# SleepingUppest_scaleKBFInterp                               1.00     4701
# SleepingUppest_scaleDIB                                     1.00     4363
# WentinWG_TreatmentOFH                                       1.00     2051
# WentinWG_scaleweightInterp                                  1.00     3904
# WentinWG_scaleKBFInterp                                     1.00     4654
# WentinWG_scaleDIB                                           1.00     4253
#                                                             Tail_ESS
# foodsameDurTimingr50final_Intercept                             2773
# verticaltraveldistancefulllightperinsideh_Intercept             2288
# midcumZ4hMorning_Intercept                                      2198
# SleepingUppest_Intercept                                        2970
# WentinWG_Intercept                                              3010
# foodsameDurTimingr50final_TreatmentOFH                          3081
# foodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 2742
# foodsameDurTimingr50final_FoodPenIDFoodPenID9M12                2662
# foodsameDurTimingr50final_scaleweightInterp                     3437
# foodsameDurTimingr50final_scaleKBFInterp                        4163
# foodsameDurTimingr50final_scaleDIB                              4433
# verticaltraveldistancefulllightperinsideh_TreatmentOFH          2206
# verticaltraveldistancefulllightperinsideh_scaleweightInterp     4359
# verticaltraveldistancefulllightperinsideh_scaleKBFInterp        4678
# verticaltraveldistancefulllightperinsideh_scaleDIB              4792
# midcumZ4hMorning_TreatmentOFH                                   2410
# midcumZ4hMorning_scaleweightInterp                              4432
# midcumZ4hMorning_scaleKBFInterp                                 4328
# midcumZ4hMorning_scaleDIB                                       4509
# SleepingUppest_TreatmentOFH                                     3454
# SleepingUppest_scaleweightInterp                                4298
# SleepingUppest_scaleKBFInterp                                   4408
# SleepingUppest_scaleDIB                                         4254
# WentinWG_TreatmentOFH                                           3145
# WentinWG_scaleweightInterp                                      4716
# WentinWG_scaleKBFInterp                                         4669
# WentinWG_scaleDIB                                               4535
#
# Family Specific Parameters:
#                                                 Estimate Est.Error l-95% CI
# sigma_foodsameDurTimingr50final                     0.22      0.00     0.22
# sigma_verticaltraveldistancefulllightperinsideh     1.03      0.01     1.01
# shape_midcumZ4hMorning                             40.19      0.83    38.56
#                                                 u-95% CI Rhat Bulk_ESS Tail_ESS
# sigma_foodsameDurTimingr50final                     0.23 1.00     5128     4409
# sigma_verticaltraveldistancefulllightperinsideh     1.06 1.00     4998     4951
# shape_midcumZ4hMorning                             41.76 1.00     5274     5121
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %% [markdown]
# ### saving some outputs

# %%
#coefficient of variation in predictability” (CVP)
#log.norm.res = exp(posterior_samples(Multi_DHGLM)$"sd_HenID__sigma_Intercept"^2)
#CVP = sqrt(log.norm.res-1)
#mean(CVP);HPDinterval(as.mcmc(CVP),0.95)

#posterior samples dimensionality of the dataframe:
#nrw=(iter-warup)/thin * chain
#ncol=#param to estimate
prior_summary(Multi_DHGLM)

#all data, sd in python
#extract samples (draw) from the posterior distribution, including all variables
#df_pred = posterior_samples(modelPred) #depreciated but still work well. we will instead use:
colnames(posterior_samples(Multi_DHGLM))[1:30]
df_pred = as_draws(Multi_DHGLM)
length(df_pred[[1]]) #nbr param
length(df_pred[[1]][[1]]) #nbr posterio samples we got
write.csv(df_pred, file.path(path_,'BRMS_BS_pred_allvar_moreit.csv'), row.names = TRUE)

#only mean and CI from R
df_pred = posterior_samples(Multi_DHGLM)
dim(df_pred) # nbr posterior samles we got, #param
#--> (1250, 4044) ou (5000, 1011)
df_mean = colMeans(df_pred)
df_CI = HPDinterval(as.mcmc(df_pred))
dim(df_CI)
write.csv(df_CI, file.path(path_,'df_CI_BRMS_BS_pred_allvar_moreit.csv'), row.names = TRUE)
write.csv(df_mean, file.path(path_,'df_mean_BRMS_BS_pred_allvar_moreit.csv'), row.names = TRUE)
dim(df)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
#    prior                  class     coef                   group
# 1                         b
# 2                         b         FoodPenIDFoodPenID5M8
# 3                         b         FoodPenIDFoodPenID9M12
# 4                         b         scaleDIB
# 5                         b         scaleKBFInterp
# 6                         b         scaleweightInterp
# 7                         b         TreatmentOFH
# 8                         b
# 9                         b         scaleDIB
# 10                        b         scaleKBFInterp
# 11                        b         scaleweightInterp
# 12                        b         TreatmentOFH
# 13                        b
# 14                        b         scaleDIB
# 15                        b         scaleKBFInterp
# 16                        b         scaleweightInterp
# 17                        b         TreatmentOFH
# 18                        b
# 19                        b         scaleDIB
# 20                        b         scaleKBFInterp
# 21                        b         scaleweightInterp
# 22                        b         TreatmentOFH
# 23                        b
# 24                        b         scaleDIB
# 25                        b         scaleKBFInterp
# 26                        b         scaleweightInterp
# 27                        b         TreatmentOFH
# 28 student_t(3, 0.2, 2.5) Intercept
# 29 student_t(3, 1.5, 2.5) Intercept
# 30 student_t(3, 0, 2.5)   Intercept
# 31 student_t(3, 4.1, 2.5) Intercept
# 32 student_t(3, 0, 2.5)   Intercept
# 33 lkj_corr_cholesky(1)   L
# 34                        L                                HenID
# 35 student_t(3, 0, 2.5)   sd
# 36 student_t(3, 0, 2.5)   sd
# 37 student_t(3, 0, 2.5)   sd
# 38 student_t(3, 0, 2.5)   sd
# 39 student_t(3, 0, 2.5)   sd
# 40                        sd                               HenID
# 41                        sd        Intercept              HenID
# 42                        sd                               HenID
# 43                        sd        Intercept              HenID
# 44                        sd                               HenID
# 45                        sd        Intercept              HenID
# 46                        sd                               HenID
# 47                        sd        Intercept              HenID
# 48                        sd                               HenID
# 49                        sd        Intercept              HenID
# 50 gamma(0.01, 0.01)      shape
# 51 student_t(3, 0, 2.5)   sigma
# 52 student_t(3, 0, 2.5)   sigma
#    resp                                      dpar nlpar bound source
# 1  foodsameDurTimingr50final                                  default
# 2  foodsameDurTimingr50final                                  default
# 3  foodsameDurTimingr50final                                  default
# 4  foodsameDurTimingr50final                                  default
# 5  foodsameDurTimingr50final                                  default
# 6  foodsameDurTimingr50final                                  default
# 7  foodsameDurTimingr50final                                  default
# 8  midcumZ4hMorning                                           default
# 9  midcumZ4hMorning                                           default
# 10 midcumZ4hMorning                                           default
# 11 midcumZ4hMorning                                           default
# 12 midcumZ4hMorning                                           default
# 13 SleepingUppest                                             default
# 14 SleepingUppest                                             default
# 15 SleepingUppest                                             default
# 16 SleepingUppest                                             default
# 17 SleepingUppest                                             default
# 18 verticaltraveldistancefulllightperinsideh                  default
# 19 verticaltraveldistancefulllightperinsideh                  default
# 20 verticaltraveldistancefulllightperinsideh                  default
# 21 verticaltraveldistancefulllightperinsideh                  default
# 22 verticaltraveldistancefulllightperinsideh                  default
# 23 WentinWG                                                   default
# 24 WentinWG                                                   default
# 25 WentinWG                                                   default
# 26 WentinWG                                                   default
# 27 WentinWG                                                   default
# 28 foodsameDurTimingr50final                                  default
# 29 midcumZ4hMorning                                           default
# 30 SleepingUppest                                             default
# 31 verticaltraveldistancefulllightperinsideh                  default
# 32 WentinWG                                                   default
# 33                                                            default
# 34                                                            default
# 35 foodsameDurTimingr50final                                  default
# 36 midcumZ4hMorning                                           default
# 37 SleepingUppest                                             default
# 38 verticaltraveldistancefulllightperinsideh                  default
# 39 WentinWG                                                   default
# 40 foodsameDurTimingr50final                                  default
# 41 foodsameDurTimingr50final                                  default
# 42 midcumZ4hMorning                                           default
# 43 midcumZ4hMorning                                           default
# 44 SleepingUppest                                             default
# 45 SleepingUppest                                             default
# 46 verticaltraveldistancefulllightperinsideh                  default
# 47 verticaltraveldistancefulllightperinsideh                  default
# 48 WentinWG                                                   default
# 49 WentinWG                                                   default
# 50 midcumZ4hMorning                                           default
# 51 foodsameDurTimingr50final                                  default
# 52 verticaltraveldistancefulllightperinsideh                  default
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
#  [1] "b_foodsameDurTimingr50final_Intercept"
#  [2] "b_verticaltraveldistancefulllightperinsideh_Intercept"
#  [3] "b_midcumZ4hMorning_Intercept"
#  [4] "b_SleepingUppest_Intercept"
#  [5] "b_WentinWG_Intercept"
#  [6] "b_foodsameDurTimingr50final_TreatmentOFH"
#  [7] "b_foodsameDurTimingr50final_FoodPenIDFoodPenID5M8"
#  [8] "b_foodsameDurTimingr50final_FoodPenIDFoodPenID9M12"
#  [9] "b_foodsameDurTimingr50final_scaleweightInterp"
# [10] "b_foodsameDurTimingr50final_scaleKBFInterp"
# [11] "b_foodsameDurTimingr50final_scaleDIB"
# [12] "b_verticaltraveldistancefulllightperinsideh_TreatmentOFH"
# [13] "b_verticaltraveldistancefulllightperinsideh_scaleweightInterp"
# [14] "b_verticaltraveldistancefulllightperinsideh_scaleKBFInterp"
# [15] "b_verticaltraveldistancefulllightperinsideh_scaleDIB"
# [16] "b_midcumZ4hMorning_TreatmentOFH"
# [17] "b_midcumZ4hMorning_scaleweightInterp"
# [18] "b_midcumZ4hMorning_scaleKBFInterp"
# [19] "b_midcumZ4hMorning_scaleDIB"
# [20] "b_SleepingUppest_TreatmentOFH"
# [21] "b_SleepingUppest_scaleweightInterp"
# [22] "b_SleepingUppest_scaleKBFInterp"
# [23] "b_SleepingUppest_scaleDIB"
# [24] "b_WentinWG_TreatmentOFH"
# [25] "b_WentinWG_scaleweightInterp"
# [26] "b_WentinWG_scaleKBFInterp"
# [27] "b_WentinWG_scaleDIB"
# [28] "sd_HenID__foodsameDurTimingr50final_Intercept"
# [29] "sd_HenID__verticaltraveldistancefulllightperinsideh_Intercept"
# [30] "sd_HenID__midcumZ4hMorning_Intercept"
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# [1] 5000 1011
# [1] 1011    2
# [1] 1011    2
# [1] 4892   24
# plot without title

# %%
#mean population-level estimates
fixef(Multi_DHGLM)
p1 = plot_model(Multi_DHGLM,  show.values = TRUE, title='Population-Level Effects', 
            rm.terms = c("TreatmentOFH",'FoodPenIDFoodPenID9M12','FoodPenIDFoodPenID5M8'), 
                type = "est", colors = c("red3", "forestgreen"))+ ylim(-.6, .6)
ggsave(file.path(path_,"Multi_fixedestimate.png"), plot=p1, height=5, width=12, dpi=600) 
#darkgreen, forestgreen ; firebrick, red3

# %%
colnames(posterior_samples(Multi_DHGLM))[1:60]

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__foodsameDurTimingr50final_Intercept__verticaltraveldistancefulllightperinsideh_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation foodescapingbehavior & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__verticaltraveldistancefulllightperinsideh_Intercept__SleepingUppest_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation foodescapingbehavior & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__foodsameDurTimingr50final_Intercept__WentinWG_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation foodescapingbehavior & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %%
#colnames(posterior_samples(Multi_DHGLM))[1:60]
#plot the among individual correlation of behaviors: Correlation between mean behavioral expression of MVT1 and MVT2, where the dashedlines 
#indicate the 95% credible interval of the posterior distribution.
food_VT = posterior_samples(Multi_DHGLM)[,'cor_HenID__verticaltraveldistancefulllightperinsideh_Intercept__WentinWG_Intercept']
#same:
#food_VT <-posterior_samples(Multi_DHGLM)$cor_HenID__foodrelatedbehaviorfinalinvcst_Intercept__scaleVTD_Intercept
par(mar=c(2, 2, 3, 2))
plot(density(food_VT),main="Correlation foodescapingbehavior & vertical travelled distance",xlab="",ylab="",cex.main=0.8)
abline(v=0,col="red",lwd=2)
abline(v=mean(food_VT),col="black",lwd=2)
abline(v=HPDinterval(as.mcmc(food_VT))[1],col="black",lty=2)
abline(v=HPDinterval(as.mcmc(food_VT))[2],col="black",lty=2)
HPDinterval(as.mcmc(food_VT))

# %% [markdown]
# ### model diagnostic

# %%
#load(file.path(path_,"Multi_DHGLM_allvar_Food2.rda"))

# %%
############## Loo-cv and waic ##############
#conditional_effects(Multi_DHGLM)
Multi_DHGLM = add_criterion(Multi_DHGLM, criterion=c('waic','loo'), file=file.path(path_,'Multi_DHGLM_allvar_Food2'))
#head(get_variables(modelPred),10)
print(Multi_DHGLM$criteria$waic)
#approximative leave-one-out cross validation
print(Multi_DHGLM$criteria$loo)

print('----------------------- loo2')
#check highly influential observations
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-moment-matching.html
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-example.html
#"If we had a well-specified model we would expect the estimated effective number of parameters (p_loo) to be smaller than or 
#similar to the total number of parameters in the model."
loo2 = loo(Multi_DHGLM, moment_match = TRUE)
loo2
plot(loo2, label_points = TRUE)
# Out:
# Warning message:
# "
# 377 (7.7%) p_waic estimates greater than 0.4. We recommend trying loo instead."
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
#    prior                  class     coef                   group
# 1                         b
# 2                         b         FoodPenIDFoodPenID5M8
# 3                         b         FoodPenIDFoodPenID9M12
# 4                         b         scaleDIB
# 5                         b         scaleKBFInterp
# 6                         b         scaleweightInterp
# 7                         b         TreatmentOFH
# 8                         b
# 9                         b         scaleDIB
# 10                        b         scaleKBFInterp
# 11                        b         scaleweightInterp
# 12                        b         TreatmentOFH
# 13                        b
# 14                        b         scaleDIB
# 15                        b         scaleKBFInterp
# 16                        b         scaleweightInterp
# 17                        b         TreatmentOFH
# 18                        b
# 19                        b         scaleDIB
# 20                        b         scaleKBFInterp
# 21                        b         scaleweightInterp
# 22                        b         TreatmentOFH
# 23                        b
# 24                        b         scaleDIB
# 25                        b         scaleKBFInterp
# 26                        b         scaleweightInterp
# 27                        b         TreatmentOFH
# 28 student_t(3, 0.2, 2.5) Intercept
# 29 student_t(3, 1.5, 2.5) Intercept
# 30 student_t(3, 0, 2.5)   Intercept
# 31 student_t(3, 4.1, 2.5) Intercept
# 32 student_t(3, 0, 2.5)   Intercept
# 33 lkj_corr_cholesky(1)   L
# 34                        L                                HenID
# 35 student_t(3, 0, 2.5)   sd
# 36 student_t(3, 0, 2.5)   sd
# 37 student_t(3, 0, 2.5)   sd
# 38 student_t(3, 0, 2.5)   sd
# 39 student_t(3, 0, 2.5)   sd
# 40                        sd                               HenID
# 41                        sd        Intercept              HenID
# 42                        sd                               HenID
# 43                        sd        Intercept              HenID
# 44                        sd                               HenID
# 45                        sd        Intercept              HenID
# 46                        sd                               HenID
# 47                        sd        Intercept              HenID
# 48                        sd                               HenID
# 49                        sd        Intercept              HenID
# 50 gamma(0.01, 0.01)      shape
# 51 student_t(3, 0, 2.5)   sigma
# 52 student_t(3, 0, 2.5)   sigma
#    resp                                      dpar nlpar bound source
# 1  foodsameDurTimingr50final                                  default
# 2  foodsameDurTimingr50final                                  default
# 3  foodsameDurTimingr50final                                  default
# 4  foodsameDurTimingr50final                                  default
# 5  foodsameDurTimingr50final                                  default
# 6  foodsameDurTimingr50final                                  default
# 7  foodsameDurTimingr50final                                  default
# 8  midcumZ4hMorning                                           default
# 9  midcumZ4hMorning                                           default
# 10 midcumZ4hMorning                                           default
# 11 midcumZ4hMorning                                           default
# 12 midcumZ4hMorning                                           default
# 13 SleepingUppest                                             default
# 14 SleepingUppest                                             default
# 15 SleepingUppest                                             default
# 16 SleepingUppest                                             default
# 17 SleepingUppest                                             default
# 18 verticaltraveldistancefulllightperinsideh                  default
# 19 verticaltraveldistancefulllightperinsideh                  default
# 20 verticaltraveldistancefulllightperinsideh                  default
# 21 verticaltraveldistancefulllightperinsideh                  default
# 22 verticaltraveldistancefulllightperinsideh                  default
# 23 WentinWG                                                   default
# 24 WentinWG                                                   default
# 25 WentinWG                                                   default
# 26 WentinWG                                                   default
# 27 WentinWG                                                   default
# 28 foodsameDurTimingr50final                                  default
# 29 midcumZ4hMorning                                           default
# 30 SleepingUppest                                             default
# 31 verticaltraveldistancefulllightperinsideh                  default
# 32 WentinWG                                                   default
# 33                                                            default
# 34                                                            default
# 35 foodsameDurTimingr50final                                  default
# 36 midcumZ4hMorning                                           default
# 37 SleepingUppest                                             default
# 38 verticaltraveldistancefulllightperinsideh                  default
# 39 WentinWG                                                   default
# 40 foodsameDurTimingr50final                                  default
# 41 foodsameDurTimingr50final                                  default
# 42 midcumZ4hMorning                                           default
# 43 midcumZ4hMorning                                           default
# 44 SleepingUppest                                             default
# 45 SleepingUppest                                             default
# 46 verticaltraveldistancefulllightperinsideh                  default
# 47 verticaltraveldistancefulllightperinsideh                  default
# 48 WentinWG                                                   default
# 49 WentinWG                                                   default
# 50 midcumZ4hMorning                                           default
# 51 foodsameDurTimingr50final                                  default
# 52 verticaltraveldistancefulllightperinsideh                  default
# plot without title

# %%
############## posterior predictive check ##############
pp_check(Multi_DHGLM, resp='foodsameDurTimingr50final',ndraws = 100)
pp_check(Multi_DHGLM, resp='verticaltraveldistancefulllightperinsideh',ndraws = 100)
pp_check(Multi_DHGLM, resp='midcumZ4hMorning',ndraws = 100)
pp_check(Multi_DHGLM, resp='SleepingUppest',ndraws = 100)
pp_check(Multi_DHGLM, resp='WentinWG',ndraws = 100)

# %%
############## trace plot ##############
#44 parameters: 44 plots
plot(Multi_DHGLM)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
############## Gelman-Rubin diagnostic ##############
#is automatically given in the summary of brms under the column Rhat!

# %%
############## Geweke diagnostic ##############
geweke.plot(modelposterior)

# %%
mcmc_plot(Multi_DHGLM, type = "trace")[1:5] #previously: stanplot
# Out:
# No divergences to plot.
# $data
# # A tibble: 220,000 x 10
#    parameter value value_rank iteration chain n_chains n_iterations n_parameters
#    <fct>     <dbl>      <dbl>     <int> <fct>    <int>        <int>        <int>
#  1 b_foodsa~ 0.273       4953         1 1            4         1250           44
#  2 b_foodsa~ 0.235       3846         2 1            4         1250           44
#  3 b_foodsa~ 0.228       3322         3 1            4         1250           44
#  4 b_foodsa~ 0.204       1307         4 1            4         1250           44
#  5 b_foodsa~ 0.222       2858         5 1            4         1250           44
#  6 b_foodsa~ 0.257       4774         6 1            4         1250           44
#  7 b_foodsa~ 0.195        765         7 1            4         1250           44
#  8 b_foodsa~ 0.217       2367         8 1            4         1250           44
#  9 b_foodsa~ 0.214       2101         9 1            4         1250           44
# 10 b_foodsa~ 0.237       3957        10 1            4         1250           44
# # ... with 219,990 more rows, and 2 more variables: highlight <lgl>,
# #   warmup <lgl>
#
# $layers
# $layers[[1]]
# geom_line: na.rm = FALSE, orientation = NA
# stat_identity: na.rm = FALSE
# position_identity
#
#
# $scales
# <ggproto object: Class ScalesList, gg>
#     add: function
#     clone: function
#     find: function
#     get_scales: function
#     has_scale: function
#     input: function
#     n: function
#     non_position_scales: function
#     scales: list
#     super:  <ggproto object: Class ScalesList, gg>
#
# $mapping
# Aesthetic mapping:
# * `colour` -> `chain`
# * `x`      -> `iteration`
# * `y`      -> `value`
#
# $theme
# List of 93
#  $ line                      :List of 6
#   ..$ colour       : chr "black"
#   ..$ size         : num 0.545
#   ..$ linetype     : num 1
#   ..$ lineend      : chr "butt"
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ rect                      :List of 5
#   ..$ fill         : chr "white"
#   ..$ colour       : chr "black"
#   ..$ size         : num 0.545
#   ..$ linetype     : num 1
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_rect" "element"
#  $ text                      :List of 11
#   ..$ family       : chr "serif"
#   ..$ face         : chr "plain"
#   ..$ colour       : chr "black"
#   ..$ size         : num 12
#   ..$ hjust        : num 0.5
#   ..$ vjust        : num 0.5
#   ..$ angle        : num 0
#   ..$ lineheight   : num 0.9
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ title                     : NULL
#  $ aspect.ratio              : NULL
#  $ axis.title                : NULL
#  $ axis.title.x              :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 1
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 3points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.title.x.top          :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 0
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 3points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.title.x.bottom       : NULL
#  $ axis.title.y              :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 1
#   ..$ angle        : num 90
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 3points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.title.y.left         : NULL
#  $ axis.title.y.right        :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 0
#   ..$ angle        : num -90
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 3points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.text                 :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : chr "grey30"
#   ..$ size         : 'rel' num 0.8
#   ..$ hjust        : NULL
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.text.x               :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 1
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 2.4points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.text.x.top           :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : num 0
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 2.4points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.text.x.bottom        : NULL
#  $ axis.text.y               :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : num 1
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 2.4points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.text.y.left          : NULL
#  $ axis.text.y.right         :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : num 0
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 2.4points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ axis.ticks                :List of 6
#   ..$ colour       : chr "grey20"
#   ..$ size         : num 0.3
#   ..$ linetype     : NULL
#   ..$ lineend      : NULL
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi FALSE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ axis.ticks.x              : NULL
#  $ axis.ticks.x.top          : NULL
#  $ axis.ticks.x.bottom       : NULL
#  $ axis.ticks.y              : NULL
#  $ axis.ticks.y.left         : NULL
#  $ axis.ticks.y.right        : NULL
#  $ axis.ticks.length         : 'simpleUnit' num 3points
#   ..- attr(*, "unit")= int 8
#  $ axis.ticks.length.x       : NULL
#  $ axis.ticks.length.x.top   : NULL
#  $ axis.ticks.length.x.bottom: NULL
#  $ axis.ticks.length.y       : NULL
#  $ axis.ticks.length.y.left  : NULL
#  $ axis.ticks.length.y.right : NULL
#  $ axis.line                 :List of 6
#   ..$ colour       : NULL
#   ..$ size         : num 0.4
#   ..$ linetype     : NULL
#   ..$ lineend      : NULL
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi FALSE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ axis.line.x               : NULL
#  $ axis.line.x.top           : NULL
#  $ axis.line.x.bottom        : NULL
#  $ axis.line.y               : NULL
#  $ axis.line.y.left          : NULL
#  $ axis.line.y.right         : NULL
#  $ legend.background         : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ legend.margin             : 'margin' num [1:4] 6points 6points 6points 6points
#   ..- attr(*, "unit")= int 8
#  $ legend.spacing            : 'simpleUnit' num 12points
#   ..- attr(*, "unit")= int 8
#  $ legend.spacing.x          : NULL
#  $ legend.spacing.y          : NULL
#  $ legend.key                : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ legend.key.size           : 'simpleUnit' num 1.2lines
#   ..- attr(*, "unit")= int 3
#  $ legend.key.height         : NULL
#  $ legend.key.width          : NULL
#  $ legend.text               :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : num 13
#   ..$ hjust        : NULL
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi FALSE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ legend.text.align         : num 0
#  $ legend.title              :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : num 0
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ legend.title.align        : NULL
#  $ legend.position           : chr "right"
#  $ legend.direction          : NULL
#  $ legend.justification      : chr "center"
#  $ legend.box                : NULL
#  $ legend.box.just           : NULL
#  $ legend.box.margin         : 'margin' num [1:4] 0cm 0cm 0cm 0cm
#   ..- attr(*, "unit")= int 1
#  $ legend.box.background     : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ legend.box.spacing        : 'simpleUnit' num 12points
#   ..- attr(*, "unit")= int 8
#  $ panel.background          : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ panel.border              : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ panel.spacing             : 'simpleUnit' num 1.5lines
#   ..- attr(*, "unit")= int 3
#  $ panel.spacing.x           : NULL
#  $ panel.spacing.y           : NULL
#  $ panel.grid                : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ panel.grid.major          : NULL
#  $ panel.grid.minor          :List of 6
#   ..$ colour       : NULL
#   ..$ size         : 'rel' num 0.5
#   ..$ linetype     : NULL
#   ..$ lineend      : NULL
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ panel.grid.major.x        : NULL
#  $ panel.grid.major.y        : NULL
#  $ panel.grid.minor.x        : NULL
#  $ panel.grid.minor.y        : NULL
#  $ panel.ontop               : logi FALSE
#  $ plot.background           : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ plot.title                :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : 'rel' num 1.2
#   ..$ hjust        : num 0
#   ..$ vjust        : num 1
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 6points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ plot.title.position       : chr "panel"
#  $ plot.subtitle             :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : num 0
#   ..$ vjust        : num 1
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 0points 0points 6points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ plot.caption              :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : 'rel' num 0.8
#   ..$ hjust        : num 1
#   ..$ vjust        : num 1
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 6points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ plot.caption.position     : chr "panel"
#  $ plot.tag                  :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : 'rel' num 1.2
#   ..$ hjust        : num 0.5
#   ..$ vjust        : num 0.5
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ plot.tag.position         : chr "topleft"
#  $ plot.margin               : 'margin' num [1:4] 6points 6points 6points 6points
#   ..- attr(*, "unit")= int 8
#  $ strip.background          : list()
#   ..- attr(*, "class")= chr [1:2] "element_blank" "element"
#  $ strip.background.x        : NULL
#  $ strip.background.y        : NULL
#  $ strip.placement           : chr "outside"
#  $ strip.text                :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : chr "grey10"
#   ..$ size         : 'rel' num 0.9
#   ..$ hjust        : NULL
#   ..$ vjust        : NULL
#   ..$ angle        : NULL
#   ..$ lineheight   : NULL
#   ..$ margin       : 'margin' num [1:4] 4.8points 4.8points 4.8points 4.8points
#   .. ..- attr(*, "unit")= int 8
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi FALSE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ strip.text.x              : NULL
#  $ strip.text.y              :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : NULL
#   ..$ angle        : num -90
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  $ strip.switch.pad.grid     : 'simpleUnit' num 3points
#   ..- attr(*, "unit")= int 8
#  $ strip.switch.pad.wrap     : 'simpleUnit' num 3points
#   ..- attr(*, "unit")= int 8
#  $ strip.text.y.left         :List of 11
#   ..$ family       : NULL
#   ..$ face         : NULL
#   ..$ colour       : NULL
#   ..$ size         : NULL
#   ..$ hjust        : NULL
#   ..$ vjust        : NULL
#   ..$ angle        : num 90
#   ..$ lineheight   : NULL
#   ..$ margin       : NULL
#   ..$ debug        : NULL
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_text" "element"
#  - attr(*, "class")= chr [1:2] "theme" "gg"
#  - attr(*, "complete")= logi TRUE
#  - attr(*, "validate")= logi TRUE

# %% [markdown]
# ## with scaled ALL

# %%
sd(df$mid_cum_Z4_h_Morning)
sd(df$Sleeping_Uppest)
sd(df$WentinWG)
sd(df$food_sameDurTiming_r50_final)
# Out:
# [1] 1.008965
# [1] 0.4586959
# [1] 0.4650516
# [1] 0.2619553

# %%
#not scaling, keeping most possible original scale
#food_sameDurTiming_r50_final, food_reactivity_index_cst
FA = bf(scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
#we wont do:scale(mid_cum_Z4_h_Morning, center=FALSE, scale=sd(df$mid_cum_Z4_h_Morning, na.rm = TRUE)), as it doe snot change
#anything: already 1.00896547944269 sd
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(scale(Sleeping_Uppest) ~ Treatment + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli()) 
#by default, the first category will serve as the reference (https://discourse.mc-stan.org/t/example-with-family-multinomial/8707/3)
#so latency_1_Zone_15mn_3h will be left out and latency_1_Zone_15mn_3hOPP will be shown
#WG = bf(latency_1_Zone_15mn_3h_bind | trials(size) ~ Treatment +scale(DIB)+scale(weight_interp)+scale(KBF_interp)+(1|a|HenID), 
#        family = multinomial()) 
WG = bf(scale(WentinWG) ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli()) 
#NV = bf(nbr_visit_Z4_Morning_more60sec ~ Treatment +scale(weight_interp) + scale(DIB) + scale(KBF_interp) +(1|a|HenID),
#        family=poisson)
Multi_DHGLM = brm(FA + VTD + TM + SD + WG +
                    set_rescor(FALSE),
                    data = df,
                    iter = 20000, warmup = 15000, thin = 4,
                    chains = 4, cores =my.cores, seed = 12345
                    )

#save model (from: https://bookdown.org/ajkurz/Statistical_Rethinking_recoded/horoscopes-insights.html#save-your-model-fits)
save(Multi_DHGLM, file = file.path(path_,"Multi_DHGLM_allvar_Food2_SCALEALL.rda"))
#load("Multi_DHGLM_allvar.rda") #do not put modelreload = load("Multi_DHGLM_allvar.rda")

summary(Multi_DHGLM)
#cor(scaleVTD_Intercept,mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept)  : the more you move vertically, the more
#latency1Zone15mn3hOPP is high, i.e. the more you go in the WG earlier
# Out:
# Compiling Stan program...
#
# Start sampling
#  Family: MV(gaussian, gaussian, gamma, bernoulli, bernoulli)
#   Links: mu = identity; sigma = identity
#          mu = identity; sigma = identity
#          mu = log; shape = identity
#          mu = logit
#          mu = logit
# Formula: scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          scale(Sleeping_Uppest) ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          scale(WentinWG) ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#    Data: df (Number of observations: 4892)
#   Draws: 4 chains, each with iter = 5000; warmup = 3750; thin = 4;
#          total post-warmup draws = 1250
#
# Group-Level Effects:
# ~HenID (Number of levels: 193)
#                                                                                                        Estimate
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.53
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.83
# sd(midcumZ4hMorning_Intercept)                                                                             0.14
# sd(scaleSleepingUppest_Intercept)                                                                          2.28
# sd(scaleWentinWG_Intercept)                                                                                2.20
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.44
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                  -0.06
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                  -0.02
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                               -0.15
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)               -0.24
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                             -0.05
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                      0.28
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                      0.52
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                   -0.04
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                 0.05
#                                                                                                        Est.Error
# sd(scalefoodsameDurTimingr50final_Intercept)                                                                0.03
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                                0.04
# sd(midcumZ4hMorning_Intercept)                                                                              0.01
# sd(scaleSleepingUppest_Intercept)                                                                           0.16
# sd(scaleWentinWG_Intercept)                                                                                 0.16
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)      0.06
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                    0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                    0.08
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                                 0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)                 0.07
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                               0.08
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                       0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                       0.06
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                     0.08
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                  0.08
#                                                                                                        l-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.48
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.75
# sd(midcumZ4hMorning_Intercept)                                                                             0.13
# sd(scaleSleepingUppest_Intercept)                                                                          1.98
# sd(scaleWentinWG_Intercept)                                                                                1.92
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.30
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                  -0.21
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                  -0.17
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                               -0.30
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)               -0.39
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                             -0.20
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                      0.13
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                      0.40
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                   -0.19
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                -0.11
#                                                                                                        u-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.60
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.92
# sd(midcumZ4hMorning_Intercept)                                                                             0.16
# sd(scaleSleepingUppest_Intercept)                                                                          2.61
# sd(scaleWentinWG_Intercept)                                                                                2.54
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.55
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   0.10
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   0.13
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                                0.01
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)               -0.09
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                              0.11
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                      0.43
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                      0.62
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                    0.12
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                 0.21
#                                                                                                        Rhat
# sd(scalefoodsameDurTimingr50final_Intercept)                                                           1.00
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                           1.00
# sd(midcumZ4hMorning_Intercept)                                                                         1.00
# sd(scaleSleepingUppest_Intercept)                                                                      1.00
# sd(scaleWentinWG_Intercept)                                                                            1.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept) 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                               1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)               1.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                            1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)            1.00
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                          1.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                  1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                  1.00
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                1.00
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                             1.00
#                                                                                                        Bulk_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               3005
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               2069
# sd(midcumZ4hMorning_Intercept)                                                                             2755
# sd(scaleSleepingUppest_Intercept)                                                                          2971
# sd(scaleWentinWG_Intercept)                                                                                3590
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     1327
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   1527
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   1774
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                                1984
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)                3027
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                              2503
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                      2050
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                      2814
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                    2653
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                 2341
#                                                                                                        Tail_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               4170
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               2625
# sd(midcumZ4hMorning_Intercept)                                                                             3982
# sd(scaleSleepingUppest_Intercept)                                                                          3735
# sd(scaleWentinWG_Intercept)                                                                                4514
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     2078
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   2383
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   2584
# cor(scalefoodsameDurTimingr50final_Intercept,scaleSleepingUppest_Intercept)                                3312
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleSleepingUppest_Intercept)                3590
# cor(midcumZ4hMorning_Intercept,scaleSleepingUppest_Intercept)                                              3642
# cor(scalefoodsameDurTimingr50final_Intercept,scaleWentinWG_Intercept)                                      3530
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,scaleWentinWG_Intercept)                      3567
# cor(midcumZ4hMorning_Intercept,scaleWentinWG_Intercept)                                                    3433
# cor(scaleSleepingUppest_Intercept,scaleWentinWG_Intercept)                                                 3409
#
# Population-Level Effects:
#                                                                  Estimate
# scalefoodsameDurTimingr50final_Intercept                             0.13
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.02
# midcumZ4hMorning_Intercept                                           1.50
# scaleSleepingUppest_Intercept                                        1.37
# scaleWentinWG_Intercept                                              1.24
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.12
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.02
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.15
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.04
# scalefoodsameDurTimingr50final_scaleKBFInterp                        0.04
# scalefoodsameDurTimingr50final_scaleDIB                              0.08
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.14
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     0.02
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.04
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.12
# midcumZ4hMorning_TreatmentOFH                                       -0.01
# midcumZ4hMorning_scaleweightInterp                                  -0.07
# midcumZ4hMorning_scaleKBFInterp                                     -0.01
# midcumZ4hMorning_scaleDIB                                            0.10
# scaleSleepingUppest_TreatmentOFH                                     0.40
# scaleSleepingUppest_scaleweightInterp                                0.07
# scaleSleepingUppest_scaleKBFInterp                                   0.08
# scaleSleepingUppest_scaleDIB                                        -0.40
# scaleWentinWG_TreatmentOFH                                          -0.09
# scaleWentinWG_scaleweightInterp                                     -0.15
# scaleWentinWG_scaleKBFInterp                                        -0.09
# scaleWentinWG_scaleDIB                                               0.39
#                                                                  Est.Error
# scalefoodsameDurTimingr50final_Intercept                              0.09
# scaleverticaltraveldistancefulllightperinsideh_Intercept              0.09
# midcumZ4hMorning_Intercept                                            0.01
# scaleSleepingUppest_Intercept                                         0.25
# scaleWentinWG_Intercept                                               0.24
# scalefoodsameDurTimingr50final_TreatmentOFH                           0.08
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                  0.11
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                 0.09
# scalefoodsameDurTimingr50final_scaleweightInterp                      0.03
# scalefoodsameDurTimingr50final_scaleKBFInterp                         0.02
# scalefoodsameDurTimingr50final_scaleDIB                               0.02
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH           0.12
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp      0.03
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp         0.02
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB               0.02
# midcumZ4hMorning_TreatmentOFH                                         0.02
# midcumZ4hMorning_scaleweightInterp                                    0.01
# midcumZ4hMorning_scaleKBFInterp                                       0.00
# midcumZ4hMorning_scaleDIB                                             0.00
# scaleSleepingUppest_TreatmentOFH                                      0.35
# scaleSleepingUppest_scaleweightInterp                                 0.11
# scaleSleepingUppest_scaleKBFInterp                                    0.09
# scaleSleepingUppest_scaleDIB                                          0.07
# scaleWentinWG_TreatmentOFH                                            0.35
# scaleWentinWG_scaleweightInterp                                       0.11
# scaleWentinWG_scaleKBFInterp                                          0.08
# scaleWentinWG_scaleDIB                                                0.07
#                                                                  l-95% CI
# scalefoodsameDurTimingr50final_Intercept                            -0.03
# scaleverticaltraveldistancefulllightperinsideh_Intercept            -0.14
# midcumZ4hMorning_Intercept                                           1.47
# scaleSleepingUppest_Intercept                                        0.88
# scaleWentinWG_Intercept                                              0.78
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.28
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.23
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.32
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.10
# scalefoodsameDurTimingr50final_scaleKBFInterp                       -0.01
# scalefoodsameDurTimingr50final_scaleDIB                              0.04
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.38
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp    -0.03
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.01
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.15
# midcumZ4hMorning_TreatmentOFH                                       -0.05
# midcumZ4hMorning_scaleweightInterp                                  -0.08
# midcumZ4hMorning_scaleKBFInterp                                     -0.02
# midcumZ4hMorning_scaleDIB                                            0.09
# scaleSleepingUppest_TreatmentOFH                                    -0.29
# scaleSleepingUppest_scaleweightInterp                               -0.16
# scaleSleepingUppest_scaleKBFInterp                                  -0.09
# scaleSleepingUppest_scaleDIB                                        -0.54
# scaleWentinWG_TreatmentOFH                                          -0.79
# scaleWentinWG_scaleweightInterp                                     -0.37
# scaleWentinWG_scaleKBFInterp                                        -0.25
# scaleWentinWG_scaleDIB                                               0.25
#                                                                  u-95% CI Rhat
# scalefoodsameDurTimingr50final_Intercept                             0.30 1.00
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.19 1.00
# midcumZ4hMorning_Intercept                                           1.53 1.00
# scaleSleepingUppest_Intercept                                        1.86 1.00
# scaleWentinWG_Intercept                                              1.70 1.00
# scalefoodsameDurTimingr50final_TreatmentOFH                          0.04 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 0.19 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                0.03 1.00
# scalefoodsameDurTimingr50final_scaleweightInterp                     0.02 1.00
# scalefoodsameDurTimingr50final_scaleKBFInterp                        0.09 1.00
# scalefoodsameDurTimingr50final_scaleDIB                              0.12 1.00
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          0.10 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     0.07 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.08 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.09 1.00
# midcumZ4hMorning_TreatmentOFH                                        0.03 1.00
# midcumZ4hMorning_scaleweightInterp                                  -0.05 1.00
# midcumZ4hMorning_scaleKBFInterp                                     -0.00 1.00
# midcumZ4hMorning_scaleDIB                                            0.11 1.00
# scaleSleepingUppest_TreatmentOFH                                     1.10 1.00
# scaleSleepingUppest_scaleweightInterp                                0.30 1.00
# scaleSleepingUppest_scaleKBFInterp                                   0.26 1.00
# scaleSleepingUppest_scaleDIB                                        -0.26 1.00
# scaleWentinWG_TreatmentOFH                                           0.58 1.00
# scaleWentinWG_scaleweightInterp                                      0.06 1.00
# scaleWentinWG_scaleKBFInterp                                         0.07 1.00
# scaleWentinWG_scaleDIB                                               0.52 1.00
#                                                                  Bulk_ESS
# scalefoodsameDurTimingr50final_Intercept                             2156
# scaleverticaltraveldistancefulllightperinsideh_Intercept             1730
# midcumZ4hMorning_Intercept                                           1706
# scaleSleepingUppest_Intercept                                        2558
# scaleWentinWG_Intercept                                              2446
# scalefoodsameDurTimingr50final_TreatmentOFH                          2416
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 2166
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                2136
# scalefoodsameDurTimingr50final_scaleweightInterp                     3250
# scalefoodsameDurTimingr50final_scaleKBFInterp                        4342
# scalefoodsameDurTimingr50final_scaleDIB                              4127
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          1719
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     3646
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        4802
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              4588
# midcumZ4hMorning_TreatmentOFH                                        1596
# midcumZ4hMorning_scaleweightInterp                                   3940
# midcumZ4hMorning_scaleKBFInterp                                      4414
# midcumZ4hMorning_scaleDIB                                            4080
# scaleSleepingUppest_TreatmentOFH                                     2372
# scaleSleepingUppest_scaleweightInterp                                4344
# scaleSleepingUppest_scaleKBFInterp                                   4675
# scaleSleepingUppest_scaleDIB                                         4599
# scaleWentinWG_TreatmentOFH                                           2397
# scaleWentinWG_scaleweightInterp                                      4328
# scaleWentinWG_scaleKBFInterp                                         4946
# scaleWentinWG_scaleDIB                                               4923
#                                                                  Tail_ESS
# scalefoodsameDurTimingr50final_Intercept                             2948
# scaleverticaltraveldistancefulllightperinsideh_Intercept             2771
# midcumZ4hMorning_Intercept                                           2912
# scaleSleepingUppest_Intercept                                        3709
# scaleWentinWG_Intercept                                              3432
# scalefoodsameDurTimingr50final_TreatmentOFH                          3631
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 2939
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                2906
# scalefoodsameDurTimingr50final_scaleweightInterp                     4138
# scalefoodsameDurTimingr50final_scaleKBFInterp                        4732
# scalefoodsameDurTimingr50final_scaleDIB                              4824
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          2255
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     4337
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        4984
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              4731
# midcumZ4hMorning_TreatmentOFH                                        2931
# midcumZ4hMorning_scaleweightInterp                                   4274
# midcumZ4hMorning_scaleKBFInterp                                      4380
# midcumZ4hMorning_scaleDIB                                            4453
# scaleSleepingUppest_TreatmentOFH                                     3516
# scaleSleepingUppest_scaleweightInterp                                4730
# scaleSleepingUppest_scaleKBFInterp                                   4830
# scaleSleepingUppest_scaleDIB                                         4735
# scaleWentinWG_TreatmentOFH                                           3397
# scaleWentinWG_scaleweightInterp                                      4647
# scaleWentinWG_scaleKBFInterp                                         4911
# scaleWentinWG_scaleDIB                                               4797
#
# Family Specific Parameters:
#                                                      Estimate Est.Error
# sigma_scalefoodsameDurTimingr50final                     0.84      0.01
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.58      0.01
# shape_midcumZ4hMorning                                  40.20      0.82
#                                                      l-95% CI u-95% CI Rhat
# sigma_scalefoodsameDurTimingr50final                     0.83     0.86 1.00
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.57     0.59 1.00
# shape_midcumZ4hMorning                                  38.60    41.83 1.00
#                                                      Bulk_ESS Tail_ESS
# sigma_scalefoodsameDurTimingr50final                     5244     4995
# sigma_scaleverticaltraveldistancefulllightperinsideh     4844     4884
# shape_midcumZ4hMorning                                   4419     4953
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %%
Multi_DHGLM = add_criterion(Multi_DHGLM, criterion=c('waic','loo'), file=file.path(path_,'Multi_DHGLM_allvar_Food2_SCALEALL'))
plot(Multi_DHGLM)
#head(get_variables(modelPred),10)

prior_summary(Multi_DHGLM)

#coefficient of variation in predictability” (CVP)
#log.norm.res = exp(posterior_samples(Multi_DHGLM)$"sd_HenID__sigma_Intercept"^2)
#CVP = sqrt(log.norm.res-1)
#mean(CVP);HPDinterval(as.mcmc(CVP),0.95)

#all data, sd in python
#extract samples (draw) from the posterior distribution, including all variables
#df_pred = posterior_samples(modelPred) #depreciated but still work well. we will instead use:
colnames(posterior_samples(Multi_DHGLM))[1:30]
df_pred = as_draws(Multi_DHGLM)
write.csv(df_pred, file.path(path_,'BRMS_BS_pred_allvar_moreit_SCALEALL.csv'), row.names = TRUE)

#only meand and CI from R
df_pred = posterior_samples(Multi_DHGLM)
dim(df_pred)
df_mean = colMeans(df_pred)
df_CI = HPDinterval(as.mcmc(df_pred))
dim(df_CI)
write.csv(df_CI, file.path(path_,'df_CI_BRMS_BS_pred_allvar_moreit_SCALEALL.csv'), row.names = TRUE)
write.csv(df_mean, file.path(path_,'df_mean_BRMS_BS_pred_allvar_moreit_SCALEALL.csv'), row.names = TRUE)
dim(df_CI)
dim(df)
# Out:
# Warning message:
# "
# 380 (7.8%) p_waic estimates greater than 0.4. We recommend trying loo instead."
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
#    prior                  class     coef                   group
# 1                         b
# 2                         b         scaleDIB
# 3                         b         scaleKBFInterp
# 4                         b         scaleweightInterp
# 5                         b         TreatmentOFH
# 6                         b
# 7                         b         FoodPenIDFoodPenID5M8
# 8                         b         FoodPenIDFoodPenID9M12
# 9                         b         scaleDIB
# 10                        b         scaleKBFInterp
# 11                        b         scaleweightInterp
# 12                        b         TreatmentOFH
# 13                        b
# 14                        b         scaleDIB
# 15                        b         scaleKBFInterp
# 16                        b         scaleweightInterp
# 17                        b         TreatmentOFH
# 18                        b
# 19                        b         scaleDIB
# 20                        b         scaleKBFInterp
# 21                        b         scaleweightInterp
# 22                        b         TreatmentOFH
# 23                        b
# 24                        b         scaleDIB
# 25                        b         scaleKBFInterp
# 26                        b         scaleweightInterp
# 27                        b         TreatmentOFH
# 28 student_t(3, 1.5, 2.5) Intercept
# 29 student_t(3, 0, 2.5)   Intercept
# 30 student_t(3, 0, 2.5)   Intercept
# 31 student_t(3, 0, 2.5)   Intercept
# 32 student_t(3, 0, 2.5)   Intercept
# 33 lkj_corr_cholesky(1)   L
# 34                        L                                HenID
# 35 student_t(3, 0, 2.5)   sd
# 36 student_t(3, 0, 2.5)   sd
# 37 student_t(3, 0, 2.5)   sd
# 38 student_t(3, 0, 2.5)   sd
# 39 student_t(3, 0, 2.5)   sd
# 40                        sd                               HenID
# 41                        sd        Intercept              HenID
# 42                        sd                               HenID
# 43                        sd        Intercept              HenID
# 44                        sd                               HenID
# 45                        sd        Intercept              HenID
# 46                        sd                               HenID
# 47                        sd        Intercept              HenID
# 48                        sd                               HenID
# 49                        sd        Intercept              HenID
# 50 gamma(0.01, 0.01)      shape
# 51 student_t(3, 0, 2.5)   sigma
# 52 student_t(3, 0, 2.5)   sigma
#    resp                                           dpar nlpar bound source
# 1  midcumZ4hMorning                                                default
# 2  midcumZ4hMorning                                                default
# 3  midcumZ4hMorning                                                default
# 4  midcumZ4hMorning                                                default
# 5  midcumZ4hMorning                                                default
# 6  scalefoodsameDurTimingr50final                                  default
# 7  scalefoodsameDurTimingr50final                                  default
# 8  scalefoodsameDurTimingr50final                                  default
# 9  scalefoodsameDurTimingr50final                                  default
# 10 scalefoodsameDurTimingr50final                                  default
# 11 scalefoodsameDurTimingr50final                                  default
# 12 scalefoodsameDurTimingr50final                                  default
# 13 scaleSleepingUppest                                             default
# 14 scaleSleepingUppest                                             default
# 15 scaleSleepingUppest                                             default
# 16 scaleSleepingUppest                                             default
# 17 scaleSleepingUppest                                             default
# 18 scaleverticaltraveldistancefulllightperinsideh                  default
# 19 scaleverticaltraveldistancefulllightperinsideh                  default
# 20 scaleverticaltraveldistancefulllightperinsideh                  default
# 21 scaleverticaltraveldistancefulllightperinsideh                  default
# 22 scaleverticaltraveldistancefulllightperinsideh                  default
# 23 scaleWentinWG                                                   default
# 24 scaleWentinWG                                                   default
# 25 scaleWentinWG                                                   default
# 26 scaleWentinWG                                                   default
# 27 scaleWentinWG                                                   default
# 28 midcumZ4hMorning                                                default
# 29 scalefoodsameDurTimingr50final                                  default
# 30 scaleSleepingUppest                                             default
# 31 scaleverticaltraveldistancefulllightperinsideh                  default
# 32 scaleWentinWG                                                   default
# 33                                                                 default
# 34                                                                 default
# 35 midcumZ4hMorning                                                default
# 36 scalefoodsameDurTimingr50final                                  default
# 37 scaleSleepingUppest                                             default
# 38 scaleverticaltraveldistancefulllightperinsideh                  default
# 39 scaleWentinWG                                                   default
# 40 midcumZ4hMorning                                                default
# 41 midcumZ4hMorning                                                default
# 42 scalefoodsameDurTimingr50final                                  default
# 43 scalefoodsameDurTimingr50final                                  default
# 44 scaleSleepingUppest                                             default
# 45 scaleSleepingUppest                                             default
# 46 scaleverticaltraveldistancefulllightperinsideh                  default
# 47 scaleverticaltraveldistancefulllightperinsideh                  default
# 48 scaleWentinWG                                                   default
# 49 scaleWentinWG                                                   default
# 50 midcumZ4hMorning                                                default
# 51 scalefoodsameDurTimingr50final                                  default
# 52 scaleverticaltraveldistancefulllightperinsideh                  default
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
#  [1] "b_scalefoodsameDurTimingr50final_Intercept"
#  [2] "b_scaleverticaltraveldistancefulllightperinsideh_Intercept"
#  [3] "b_midcumZ4hMorning_Intercept"
#  [4] "b_scaleSleepingUppest_Intercept"
#  [5] "b_scaleWentinWG_Intercept"
#  [6] "b_scalefoodsameDurTimingr50final_TreatmentOFH"
#  [7] "b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8"
#  [8] "b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12"
#  [9] "b_scalefoodsameDurTimingr50final_scaleweightInterp"
# [10] "b_scalefoodsameDurTimingr50final_scaleKBFInterp"
# [11] "b_scalefoodsameDurTimingr50final_scaleDIB"
# [12] "b_scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH"
# [13] "b_scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp"
# [14] "b_scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp"
# [15] "b_scaleverticaltraveldistancefulllightperinsideh_scaleDIB"
# [16] "b_midcumZ4hMorning_TreatmentOFH"
# [17] "b_midcumZ4hMorning_scaleweightInterp"
# [18] "b_midcumZ4hMorning_scaleKBFInterp"
# [19] "b_midcumZ4hMorning_scaleDIB"
# [20] "b_scaleSleepingUppest_TreatmentOFH"
# [21] "b_scaleSleepingUppest_scaleweightInterp"
# [22] "b_scaleSleepingUppest_scaleKBFInterp"
# [23] "b_scaleSleepingUppest_scaleDIB"
# [24] "b_scaleWentinWG_TreatmentOFH"
# [25] "b_scaleWentinWG_scaleweightInterp"
# [26] "b_scaleWentinWG_scaleKBFInterp"
# [27] "b_scaleWentinWG_scaleDIB"
# [28] "sd_HenID__scalefoodsameDurTimingr50final_Intercept"
# [29] "sd_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept"
# [30] "sd_HenID__midcumZ4hMorning_Intercept"
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# [1] 5000 1011
# [1] 1011    2
# [1] 1011    2
# [1] 4892   24
# plot without title

# %%
#mean population-level estiamtes
#fixef(Multi_DHGLM)
p1 = plot_model(Multi_DHGLM,  show.values = TRUE, title='Population-Level Effects', 
            rm.terms = c("TreatmentOFH",'FoodPenIDFoodPenID9M12','FoodPenIDFoodPenID5M8'), 
                type = "est", colors = c("red3", "forestgreen"))+ ylim(-.6, .6)
ggsave(file.path(path_,"Multi_fixedestimate_SCALEALL.png"), plot=p1, height=5, width=12, dpi=600) 
#darkgreen, forestgreen ; firebrick, red3
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of columns of result is not a multiple of vector length (arg 3)"
# Warning message in (function (..., deparse.level = 1) :
# "number of columns of result is not a multiple of vector length (arg 3)"
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.

# %%
print(Multi_DHGLM$criteria$waic)
#approximative leave-one-out cross validation
print(Multi_DHGLM$criteria$loo)

print('loo2')
#check highly influential observations
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-moment-matching.html
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-example.html
#"If we had a well-specified model we would expect the estimated effective number of parameters (p_loo) to be smaller than or 
#similar to the total number of parameters in the model."
loo2 = loo(Multi_DHGLM, moment_match = TRUE)
loo2
plot(loo2, label_points = TRUE)
# Out:
# Computed from 5000 by 4892 log-likelihood matrix
#
#           Estimate    SE
# elpd_waic -19906.8 136.6
# p_waic       835.3  12.8
# waic       39813.6 273.1
#
# 380 (7.8%) p_waic estimates greater than 0.4. We recommend trying loo instead.
#
# Computed from 5000 by 4892 log-likelihood matrix
#
#          Estimate    SE
# elpd_loo -19912.3 136.7
# p_loo       840.8  13.0
# looic     39824.6 273.3
# ------
# Monte Carlo SE of elpd_loo is 0.5.
#
# Pareto k diagnostic values:
#                          Count Pct.    Min. n_eff
# (-Inf, 0.5]   (good)     4860  99.3%   456
#  (0.5, 0.7]   (ok)         32   0.7%   239
#    (0.7, 1]   (bad)         0   0.0%   <NA>
#    (1, Inf)   (very bad)    0   0.0%   <NA>
#
# All Pareto k estimates are ok (k < 0.7).
# See help('pareto-k-diagnostic') for details.
# [1] "loo2"
# Computed from 5000 by 4892 log-likelihood matrix
#
#          Estimate    SE
# elpd_loo -19912.3 136.7
# p_loo       840.8  13.0
# looic     39824.6 273.3
# ------
# Monte Carlo SE of elpd_loo is 0.5.
#
# Pareto k diagnostic values:
#                          Count Pct.    Min. n_eff
# (-Inf, 0.5]   (good)     4860  99.3%   456
#  (0.5, 0.7]   (ok)         32   0.7%   239
#    (0.7, 1]   (bad)         0   0.0%   <NA>
#    (1, Inf)   (very bad)    0   0.0%   <NA>
#
# All Pareto k estimates are ok (k < 0.7).
# See help('pareto-k-diagnostic') for details.
# Plot with title "PSIS diagnostic plot"

# %% [markdown]
# ## with scaled gaussians

# %%
#not scaling, keeping most possible original scale
#food_sameDurTiming_r50_final, food_reactivity_index_cst
FA = bf(scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB)+ (1|a|HenID),
       family=gaussian)
VTD = bf(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp)+scale(KBFInterp)+scale(DIB) +(1|a|HenID),
        family=gaussian)
#we wont do:scale(mid_cum_Z4_h_Morning, center=FALSE, scale=sd(df$mid_cum_Z4_h_Morning, na.rm = TRUE)), as it doe snot change
#anything: already 1.00896547944269 sd
TM = bf(mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1|a|HenID),
       family=Gamma(link='log'))
SD = bf(Sleeping_Uppest ~ Treatmaent + scale(weightInterp)+scale(KBFInterp) + scale(DIB) + (1|a|HenID), 
        family = bernoulli()) 
#by default, the first category will serve as the reference (https://discourse.mc-stan.org/t/example-with-family-multinomial/8707/3)
#so latency_1_Zone_15mn_3h will be left out and latency_1_Zone_15mn_3hOPP will be shown
#WG = bf(latency_1_Zone_15mn_3h_bind | trials(size) ~ Treatment +scale(DIB)+scale(weight_interp)+scale(KBF_interp)+(1|a|HenID), 
#        family = multinomial()) 
WG = bf(WentinWG ~ Treatment+scale(weightInterp)+scale(KBFInterp) + scale(DIB)+(1|a|HenID), 
        family = bernoulli()) 
#NV = bf(nbr_visit_Z4_Morning_more60sec ~ Treatment +scale(weight_interp) + scale(DIB) + scale(KBF_interp) +(1|a|HenID),
#        family=poisson)
Multi_DHGLM = brm(FA + VTD + TM + SD + WG +
                    set_rescor(FALSE),
                    data = df,
                    iter = 20000, warmup = 15000, thin = 4,
                    chains = 4, cores =my.cores, seed = 12345
                    )

#save model (from: https://bookdown.org/ajkurz/Statistical_Rethinking_recoded/horoscopes-insights.html#save-your-model-fits)
save(Multi_DHGLM, file = file.path(path_,"Multi_DHGLM_allvar_Food2_SCALE.rda"))
#load("Multi_DHGLM_allvar.rda") #do not put modelreload = load("Multi_DHGLM_allvar.rda")

summary(Multi_DHGLM)
#cor(scaleVTD_Intercept,mulatency1Zone15mn3hOPP_latency1Zone15mn3hbind_Intercept)  : the more you move vertically, the more
#latency1Zone15mn3hOPP is high, i.e. the more you go in the WG earlier
# Out:
# Compiling Stan program...
#
# Start sampling
#  Family: MV(gaussian, gaussian, gamma, bernoulli, bernoulli)
#   Links: mu = identity; sigma = identity
#          mu = identity; sigma = identity
#          mu = log; shape = identity
#          mu = logit
#          mu = logit
# Formula: scale(food_sameDurTiming_r50_final) ~ Treatment + FoodPenID + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          mid_cum_Z4_h_Morning ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          Sleeping_Uppest ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#          WentinWG ~ Treatment + scale(weightInterp) + scale(KBFInterp) + scale(DIB) + (1 | a | HenID)
#    Data: df (Number of observations: 4892)
#   Draws: 4 chains, each with iter = 5000; warmup = 3750; thin = 4;
#          total post-warmup draws = 1250
#
# Group-Level Effects:
# ~HenID (Number of levels: 193)
#                                                                                                        Estimate
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.53
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.83
# sd(midcumZ4hMorning_Intercept)                                                                             0.14
# sd(SleepingUppest_Intercept)                                                                               2.28
# sd(WentinWG_Intercept)                                                                                     2.20
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.44
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                  -0.06
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                  -0.02
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                    -0.15
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.24
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                  -0.05
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.28
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.52
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                        -0.04
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           0.05
#                                                                                                        Est.Error
# sd(scalefoodsameDurTimingr50final_Intercept)                                                                0.03
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                                0.04
# sd(midcumZ4hMorning_Intercept)                                                                              0.01
# sd(SleepingUppest_Intercept)                                                                                0.16
# sd(WentinWG_Intercept)                                                                                      0.16
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)      0.06
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                    0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                    0.08
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                      0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                      0.07
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                    0.08
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                            0.08
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                            0.06
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                          0.08
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                            0.08
#                                                                                                        l-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.48
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.75
# sd(midcumZ4hMorning_Intercept)                                                                             0.13
# sd(SleepingUppest_Intercept)                                                                               1.98
# sd(WentinWG_Intercept)                                                                                     1.92
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.30
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                  -0.21
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                  -0.17
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                    -0.30
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.39
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                  -0.20
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.13
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.40
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                        -0.19
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                          -0.11
#                                                                                                        u-95% CI
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               0.60
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               0.92
# sd(midcumZ4hMorning_Intercept)                                                                             0.16
# sd(SleepingUppest_Intercept)                                                                               2.61
# sd(WentinWG_Intercept)                                                                                     2.54
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     0.55
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   0.10
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   0.13
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                     0.01
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                    -0.09
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                   0.11
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           0.43
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           0.62
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                         0.12
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           0.21
#                                                                                                        Rhat
# sd(scalefoodsameDurTimingr50final_Intercept)                                                           1.00
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                           1.00
# sd(midcumZ4hMorning_Intercept)                                                                         1.00
# sd(SleepingUppest_Intercept)                                                                           1.00
# sd(WentinWG_Intercept)                                                                                 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept) 1.00
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                               1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)               1.00
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                 1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                 1.00
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                               1.00
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                       1.00
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                       1.00
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                     1.00
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                       1.00
#                                                                                                        Bulk_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               3005
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               2069
# sd(midcumZ4hMorning_Intercept)                                                                             2755
# sd(SleepingUppest_Intercept)                                                                               2971
# sd(WentinWG_Intercept)                                                                                     3590
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     1327
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   1527
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   1774
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                     1984
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                     3027
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                   2503
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           2050
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           2814
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                         2653
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           2341
#                                                                                                        Tail_ESS
# sd(scalefoodsameDurTimingr50final_Intercept)                                                               4170
# sd(scaleverticaltraveldistancefulllightperinsideh_Intercept)                                               2625
# sd(midcumZ4hMorning_Intercept)                                                                             3982
# sd(SleepingUppest_Intercept)                                                                               3735
# sd(WentinWG_Intercept)                                                                                     4514
# cor(scalefoodsameDurTimingr50final_Intercept,scaleverticaltraveldistancefulllightperinsideh_Intercept)     2078
# cor(scalefoodsameDurTimingr50final_Intercept,midcumZ4hMorning_Intercept)                                   2383
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,midcumZ4hMorning_Intercept)                   2584
# cor(scalefoodsameDurTimingr50final_Intercept,SleepingUppest_Intercept)                                     3312
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,SleepingUppest_Intercept)                     3590
# cor(midcumZ4hMorning_Intercept,SleepingUppest_Intercept)                                                   3642
# cor(scalefoodsameDurTimingr50final_Intercept,WentinWG_Intercept)                                           3530
# cor(scaleverticaltraveldistancefulllightperinsideh_Intercept,WentinWG_Intercept)                           3567
# cor(midcumZ4hMorning_Intercept,WentinWG_Intercept)                                                         3433
# cor(SleepingUppest_Intercept,WentinWG_Intercept)                                                           3409
#
# Population-Level Effects:
#                                                                  Estimate
# scalefoodsameDurTimingr50final_Intercept                             0.13
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.02
# midcumZ4hMorning_Intercept                                           1.50
# SleepingUppest_Intercept                                             1.37
# WentinWG_Intercept                                                   1.24
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.12
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.02
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.15
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.04
# scalefoodsameDurTimingr50final_scaleKBFInterp                        0.04
# scalefoodsameDurTimingr50final_scaleDIB                              0.08
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.14
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     0.02
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.04
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.12
# midcumZ4hMorning_TreatmentOFH                                       -0.01
# midcumZ4hMorning_scaleweightInterp                                  -0.07
# midcumZ4hMorning_scaleKBFInterp                                     -0.01
# midcumZ4hMorning_scaleDIB                                            0.10
# SleepingUppest_TreatmentOFH                                          0.40
# SleepingUppest_scaleweightInterp                                     0.07
# SleepingUppest_scaleKBFInterp                                        0.08
# SleepingUppest_scaleDIB                                             -0.40
# WentinWG_TreatmentOFH                                               -0.09
# WentinWG_scaleweightInterp                                          -0.15
# WentinWG_scaleKBFInterp                                             -0.09
# WentinWG_scaleDIB                                                    0.39
#                                                                  Est.Error
# scalefoodsameDurTimingr50final_Intercept                              0.09
# scaleverticaltraveldistancefulllightperinsideh_Intercept              0.09
# midcumZ4hMorning_Intercept                                            0.01
# SleepingUppest_Intercept                                              0.25
# WentinWG_Intercept                                                    0.24
# scalefoodsameDurTimingr50final_TreatmentOFH                           0.08
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                  0.11
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                 0.09
# scalefoodsameDurTimingr50final_scaleweightInterp                      0.03
# scalefoodsameDurTimingr50final_scaleKBFInterp                         0.02
# scalefoodsameDurTimingr50final_scaleDIB                               0.02
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH           0.12
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp      0.03
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp         0.02
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB               0.02
# midcumZ4hMorning_TreatmentOFH                                         0.02
# midcumZ4hMorning_scaleweightInterp                                    0.01
# midcumZ4hMorning_scaleKBFInterp                                       0.00
# midcumZ4hMorning_scaleDIB                                             0.00
# SleepingUppest_TreatmentOFH                                           0.35
# SleepingUppest_scaleweightInterp                                      0.11
# SleepingUppest_scaleKBFInterp                                         0.09
# SleepingUppest_scaleDIB                                               0.07
# WentinWG_TreatmentOFH                                                 0.35
# WentinWG_scaleweightInterp                                            0.11
# WentinWG_scaleKBFInterp                                               0.08
# WentinWG_scaleDIB                                                     0.07
#                                                                  l-95% CI
# scalefoodsameDurTimingr50final_Intercept                            -0.03
# scaleverticaltraveldistancefulllightperinsideh_Intercept            -0.14
# midcumZ4hMorning_Intercept                                           1.47
# SleepingUppest_Intercept                                             0.88
# WentinWG_Intercept                                                   0.78
# scalefoodsameDurTimingr50final_TreatmentOFH                         -0.28
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                -0.23
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12               -0.32
# scalefoodsameDurTimingr50final_scaleweightInterp                    -0.10
# scalefoodsameDurTimingr50final_scaleKBFInterp                       -0.01
# scalefoodsameDurTimingr50final_scaleDIB                              0.04
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH         -0.38
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp    -0.03
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.01
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.15
# midcumZ4hMorning_TreatmentOFH                                       -0.05
# midcumZ4hMorning_scaleweightInterp                                  -0.08
# midcumZ4hMorning_scaleKBFInterp                                     -0.02
# midcumZ4hMorning_scaleDIB                                            0.09
# SleepingUppest_TreatmentOFH                                         -0.29
# SleepingUppest_scaleweightInterp                                    -0.16
# SleepingUppest_scaleKBFInterp                                       -0.09
# SleepingUppest_scaleDIB                                             -0.54
# WentinWG_TreatmentOFH                                               -0.79
# WentinWG_scaleweightInterp                                          -0.37
# WentinWG_scaleKBFInterp                                             -0.25
# WentinWG_scaleDIB                                                    0.25
#                                                                  u-95% CI Rhat
# scalefoodsameDurTimingr50final_Intercept                             0.30 1.00
# scaleverticaltraveldistancefulllightperinsideh_Intercept             0.19 1.00
# midcumZ4hMorning_Intercept                                           1.53 1.00
# SleepingUppest_Intercept                                             1.86 1.00
# WentinWG_Intercept                                                   1.70 1.00
# scalefoodsameDurTimingr50final_TreatmentOFH                          0.04 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 0.19 1.00
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                0.03 1.00
# scalefoodsameDurTimingr50final_scaleweightInterp                     0.02 1.00
# scalefoodsameDurTimingr50final_scaleKBFInterp                        0.09 1.00
# scalefoodsameDurTimingr50final_scaleDIB                              0.12 1.00
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          0.10 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     0.07 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        0.08 1.00
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB             -0.09 1.00
# midcumZ4hMorning_TreatmentOFH                                        0.03 1.00
# midcumZ4hMorning_scaleweightInterp                                  -0.05 1.00
# midcumZ4hMorning_scaleKBFInterp                                     -0.00 1.00
# midcumZ4hMorning_scaleDIB                                            0.11 1.00
# SleepingUppest_TreatmentOFH                                          1.10 1.00
# SleepingUppest_scaleweightInterp                                     0.30 1.00
# SleepingUppest_scaleKBFInterp                                        0.26 1.00
# SleepingUppest_scaleDIB                                             -0.26 1.00
# WentinWG_TreatmentOFH                                                0.58 1.00
# WentinWG_scaleweightInterp                                           0.06 1.00
# WentinWG_scaleKBFInterp                                              0.07 1.00
# WentinWG_scaleDIB                                                    0.52 1.00
#                                                                  Bulk_ESS
# scalefoodsameDurTimingr50final_Intercept                             2156
# scaleverticaltraveldistancefulllightperinsideh_Intercept             1730
# midcumZ4hMorning_Intercept                                           1706
# SleepingUppest_Intercept                                             2558
# WentinWG_Intercept                                                   2446
# scalefoodsameDurTimingr50final_TreatmentOFH                          2416
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 2166
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                2136
# scalefoodsameDurTimingr50final_scaleweightInterp                     3250
# scalefoodsameDurTimingr50final_scaleKBFInterp                        4342
# scalefoodsameDurTimingr50final_scaleDIB                              4127
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          1719
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     3646
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        4802
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              4588
# midcumZ4hMorning_TreatmentOFH                                        1596
# midcumZ4hMorning_scaleweightInterp                                   3940
# midcumZ4hMorning_scaleKBFInterp                                      4414
# midcumZ4hMorning_scaleDIB                                            4080
# SleepingUppest_TreatmentOFH                                          2372
# SleepingUppest_scaleweightInterp                                     4344
# SleepingUppest_scaleKBFInterp                                        4675
# SleepingUppest_scaleDIB                                              4599
# WentinWG_TreatmentOFH                                                2397
# WentinWG_scaleweightInterp                                           4328
# WentinWG_scaleKBFInterp                                              4946
# WentinWG_scaleDIB                                                    4923
#                                                                  Tail_ESS
# scalefoodsameDurTimingr50final_Intercept                             2948
# scaleverticaltraveldistancefulllightperinsideh_Intercept             2771
# midcumZ4hMorning_Intercept                                           2912
# SleepingUppest_Intercept                                             3709
# WentinWG_Intercept                                                   3432
# scalefoodsameDurTimingr50final_TreatmentOFH                          3631
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8                 2939
# scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12                2906
# scalefoodsameDurTimingr50final_scaleweightInterp                     4138
# scalefoodsameDurTimingr50final_scaleKBFInterp                        4732
# scalefoodsameDurTimingr50final_scaleDIB                              4824
# scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH          2255
# scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp     4337
# scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp        4984
# scaleverticaltraveldistancefulllightperinsideh_scaleDIB              4731
# midcumZ4hMorning_TreatmentOFH                                        2931
# midcumZ4hMorning_scaleweightInterp                                   4274
# midcumZ4hMorning_scaleKBFInterp                                      4380
# midcumZ4hMorning_scaleDIB                                            4453
# SleepingUppest_TreatmentOFH                                          3516
# SleepingUppest_scaleweightInterp                                     4730
# SleepingUppest_scaleKBFInterp                                        4830
# SleepingUppest_scaleDIB                                              4735
# WentinWG_TreatmentOFH                                                3397
# WentinWG_scaleweightInterp                                           4647
# WentinWG_scaleKBFInterp                                              4911
# WentinWG_scaleDIB                                                    4797
#
# Family Specific Parameters:
#                                                      Estimate Est.Error
# sigma_scalefoodsameDurTimingr50final                     0.84      0.01
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.58      0.01
# shape_midcumZ4hMorning                                  40.20      0.82
#                                                      l-95% CI u-95% CI Rhat
# sigma_scalefoodsameDurTimingr50final                     0.83     0.86 1.00
# sigma_scaleverticaltraveldistancefulllightperinsideh     0.57     0.59 1.00
# shape_midcumZ4hMorning                                  38.60    41.83 1.00
#                                                      Bulk_ESS Tail_ESS
# sigma_scalefoodsameDurTimingr50final                     5244     4995
# sigma_scaleverticaltraveldistancefulllightperinsideh     4844     4884
# shape_midcumZ4hMorning                                   4419     4953
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %%
Multi_DHGLM = add_criterion(Multi_DHGLM, criterion=c('waic','loo'), file=file.path(path_,'Multi_DHGLM_allvar_Food2_SCALE'))
plot(Multi_DHGLM)
#head(get_variables(modelPred),10)

prior_summary(Multi_DHGLM)

#coefficient of variation in predictability” (CVP)
#log.norm.res = exp(posterior_samples(Multi_DHGLM)$"sd_HenID__sigma_Intercept"^2)
#CVP = sqrt(log.norm.res-1)
#mean(CVP);HPDinterval(as.mcmc(CVP),0.95)

#all data, sd in python
#extract samples (draw) from the posterior distribution, including all variables
#df_pred = posterior_samples(modelPred) #depreciated but still work well. we will instead use:
colnames(posterior_samples(Multi_DHGLM))[1:30]
df_pred = as_draws(Multi_DHGLM)
write.csv(df_pred, file.path(path_,'BRMS_BS_pred_allvar_moreit_SCALE.csv'), row.names = TRUE)

#only meand and CI from R
df_pred = posterior_samples(Multi_DHGLM)
dim(df_pred)
df_mean = colMeans(df_pred)
df_CI = HPDinterval(as.mcmc(df_pred))
dim(df_CI)
write.csv(df_CI, file.path(path_,'df_CI_BRMS_BS_pred_allvar_moreit_SCALE.csv'), row.names = TRUE)
write.csv(df_mean, file.path(path_,'df_mean_BRMS_BS_pred_allvar_moreit_SCALE.csv'), row.names = TRUE)
dim(df_CI)
dim(df)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
#    prior                  class     coef                   group
# 1                         b
# 2                         b         scaleDIB
# 3                         b         scaleKBFInterp
# 4                         b         scaleweightInterp
# 5                         b         TreatmentOFH
# 6                         b
# 7                         b         FoodPenIDFoodPenID5M8
# 8                         b         FoodPenIDFoodPenID9M12
# 9                         b         scaleDIB
# 10                        b         scaleKBFInterp
# 11                        b         scaleweightInterp
# 12                        b         TreatmentOFH
# 13                        b
# 14                        b         scaleDIB
# 15                        b         scaleKBFInterp
# 16                        b         scaleweightInterp
# 17                        b         TreatmentOFH
# 18                        b
# 19                        b         scaleDIB
# 20                        b         scaleKBFInterp
# 21                        b         scaleweightInterp
# 22                        b         TreatmentOFH
# 23                        b
# 24                        b         scaleDIB
# 25                        b         scaleKBFInterp
# 26                        b         scaleweightInterp
# 27                        b         TreatmentOFH
# 28 student_t(3, 1.5, 2.5) Intercept
# 29 student_t(3, 0, 2.5)   Intercept
# 30 student_t(3, 0, 2.5)   Intercept
# 31 student_t(3, 0, 2.5)   Intercept
# 32 student_t(3, 0, 2.5)   Intercept
# 33 lkj_corr_cholesky(1)   L
# 34                        L                                HenID
# 35 student_t(3, 0, 2.5)   sd
# 36 student_t(3, 0, 2.5)   sd
# 37 student_t(3, 0, 2.5)   sd
# 38 student_t(3, 0, 2.5)   sd
# 39 student_t(3, 0, 2.5)   sd
# 40                        sd                               HenID
# 41                        sd        Intercept              HenID
# 42                        sd                               HenID
# 43                        sd        Intercept              HenID
# 44                        sd                               HenID
# 45                        sd        Intercept              HenID
# 46                        sd                               HenID
# 47                        sd        Intercept              HenID
# 48                        sd                               HenID
# 49                        sd        Intercept              HenID
# 50 gamma(0.01, 0.01)      shape
# 51 student_t(3, 0, 2.5)   sigma
# 52 student_t(3, 0, 2.5)   sigma
#    resp                                           dpar nlpar bound source
# 1  midcumZ4hMorning                                                default
# 2  midcumZ4hMorning                                                default
# 3  midcumZ4hMorning                                                default
# 4  midcumZ4hMorning                                                default
# 5  midcumZ4hMorning                                                default
# 6  scalefoodsameDurTimingr50final                                  default
# 7  scalefoodsameDurTimingr50final                                  default
# 8  scalefoodsameDurTimingr50final                                  default
# 9  scalefoodsameDurTimingr50final                                  default
# 10 scalefoodsameDurTimingr50final                                  default
# 11 scalefoodsameDurTimingr50final                                  default
# 12 scalefoodsameDurTimingr50final                                  default
# 13 scaleverticaltraveldistancefulllightperinsideh                  default
# 14 scaleverticaltraveldistancefulllightperinsideh                  default
# 15 scaleverticaltraveldistancefulllightperinsideh                  default
# 16 scaleverticaltraveldistancefulllightperinsideh                  default
# 17 scaleverticaltraveldistancefulllightperinsideh                  default
# 18 SleepingUppest                                                  default
# 19 SleepingUppest                                                  default
# 20 SleepingUppest                                                  default
# 21 SleepingUppest                                                  default
# 22 SleepingUppest                                                  default
# 23 WentinWG                                                        default
# 24 WentinWG                                                        default
# 25 WentinWG                                                        default
# 26 WentinWG                                                        default
# 27 WentinWG                                                        default
# 28 midcumZ4hMorning                                                default
# 29 scalefoodsameDurTimingr50final                                  default
# 30 scaleverticaltraveldistancefulllightperinsideh                  default
# 31 SleepingUppest                                                  default
# 32 WentinWG                                                        default
# 33                                                                 default
# 34                                                                 default
# 35 midcumZ4hMorning                                                default
# 36 scalefoodsameDurTimingr50final                                  default
# 37 scaleverticaltraveldistancefulllightperinsideh                  default
# 38 SleepingUppest                                                  default
# 39 WentinWG                                                        default
# 40 midcumZ4hMorning                                                default
# 41 midcumZ4hMorning                                                default
# 42 scalefoodsameDurTimingr50final                                  default
# 43 scalefoodsameDurTimingr50final                                  default
# 44 scaleverticaltraveldistancefulllightperinsideh                  default
# 45 scaleverticaltraveldistancefulllightperinsideh                  default
# 46 SleepingUppest                                                  default
# 47 SleepingUppest                                                  default
# 48 WentinWG                                                        default
# 49 WentinWG                                                        default
# 50 midcumZ4hMorning                                                default
# 51 scalefoodsameDurTimingr50final                                  default
# 52 scaleverticaltraveldistancefulllightperinsideh                  default
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
#  [1] "b_scalefoodsameDurTimingr50final_Intercept"
#  [2] "b_scaleverticaltraveldistancefulllightperinsideh_Intercept"
#  [3] "b_midcumZ4hMorning_Intercept"
#  [4] "b_SleepingUppest_Intercept"
#  [5] "b_WentinWG_Intercept"
#  [6] "b_scalefoodsameDurTimingr50final_TreatmentOFH"
#  [7] "b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID5M8"
#  [8] "b_scalefoodsameDurTimingr50final_FoodPenIDFoodPenID9M12"
#  [9] "b_scalefoodsameDurTimingr50final_scaleweightInterp"
# [10] "b_scalefoodsameDurTimingr50final_scaleKBFInterp"
# [11] "b_scalefoodsameDurTimingr50final_scaleDIB"
# [12] "b_scaleverticaltraveldistancefulllightperinsideh_TreatmentOFH"
# [13] "b_scaleverticaltraveldistancefulllightperinsideh_scaleweightInterp"
# [14] "b_scaleverticaltraveldistancefulllightperinsideh_scaleKBFInterp"
# [15] "b_scaleverticaltraveldistancefulllightperinsideh_scaleDIB"
# [16] "b_midcumZ4hMorning_TreatmentOFH"
# [17] "b_midcumZ4hMorning_scaleweightInterp"
# [18] "b_midcumZ4hMorning_scaleKBFInterp"
# [19] "b_midcumZ4hMorning_scaleDIB"
# [20] "b_SleepingUppest_TreatmentOFH"
# [21] "b_SleepingUppest_scaleweightInterp"
# [22] "b_SleepingUppest_scaleKBFInterp"
# [23] "b_SleepingUppest_scaleDIB"
# [24] "b_WentinWG_TreatmentOFH"
# [25] "b_WentinWG_scaleweightInterp"
# [26] "b_WentinWG_scaleKBFInterp"
# [27] "b_WentinWG_scaleDIB"
# [28] "sd_HenID__scalefoodsameDurTimingr50final_Intercept"
# [29] "sd_HenID__scaleverticaltraveldistancefulllightperinsideh_Intercept"
# [30] "sd_HenID__midcumZ4hMorning_Intercept"
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# [1] 5000 1011
# [1] 1011    2
# [1] 1011    2
# [1] 4892   24
# plot without title

# %%
#mean population-level estiamtes
#fixef(Multi_DHGLM)
p1 = plot_model(Multi_DHGLM,  show.values = TRUE, title='Population-Level Effects', 
            rm.terms = c("TreatmentOFH",'FoodPenIDFoodPenID9M12','FoodPenIDFoodPenID5M8'), 
                type = "est", colors = c("red3", "forestgreen"))+ ylim(-.6, .6)
ggsave(file.path(path_,"Multi_fixedestimate_SCALE.png"), plot=p1, height=5, width=12, dpi=600) 
#darkgreen, forestgreen ; firebrick, red3
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of columns of result is not a multiple of vector length (arg 3)"
# Warning message in (function (..., deparse.level = 1) :
# "number of columns of result is not a multiple of vector length (arg 3)"
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.

# %%
print(Multi_DHGLM$criteria$waic)
#approximative leave-one-out cross validation
print(Multi_DHGLM$criteria$loo)

print('loo2')
#check highly influential observations
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-moment-matching.html
#https://cran.r-project.org/web/packages/loo/vignettes/loo2-example.html
#"If we had a well-specified model we would expect the estimated effective number of parameters (p_loo) to be smaller than or 
#similar to the total number of parameters in the model."
loo2 = loo(Multi_DHGLM, moment_match = TRUE)
loo2
plot(loo2, label_points = TRUE)
# Out:
# Computed from 5000 by 4892 log-likelihood matrix
#
#           Estimate    SE
# elpd_waic -19906.8 136.6
# p_waic       835.3  12.8
# waic       39813.6 273.1
#
# 380 (7.8%) p_waic estimates greater than 0.4. We recommend trying loo instead.
#
# Computed from 5000 by 4892 log-likelihood matrix
#
#          Estimate    SE
# elpd_loo -19912.3 136.7
# p_loo       840.8  13.0
# looic     39824.6 273.3
# ------
# Monte Carlo SE of elpd_loo is 0.5.
#
# Pareto k diagnostic values:
#                          Count Pct.    Min. n_eff
# (-Inf, 0.5]   (good)     4860  99.3%   456
#  (0.5, 0.7]   (ok)         32   0.7%   239
#    (0.7, 1]   (bad)         0   0.0%   <NA>
#    (1, Inf)   (very bad)    0   0.0%   <NA>
#
# All Pareto k estimates are ok (k < 0.7).
# See help('pareto-k-diagnostic') for details.
# [1] "loo2"
# Computed from 5000 by 4892 log-likelihood matrix
#
#          Estimate    SE
# elpd_loo -19912.3 136.7
# p_loo       840.8  13.0
# looic     39824.6 273.3
# ------
# Monte Carlo SE of elpd_loo is 0.5.
#
# Pareto k diagnostic values:
#                          Count Pct.    Min. n_eff
# (-Inf, 0.5]   (good)     4860  99.3%   456
#  (0.5, 0.7]   (ok)         32   0.7%   239
#    (0.7, 1]   (bad)         0   0.0%   <NA>
#    (1, Inf)   (very bad)    0   0.0%   <NA>
#
# All Pareto k estimates are ok (k < 0.7).
# See help('pareto-k-diagnostic') for details.
# Plot with title "PSIS diagnostic plot"
