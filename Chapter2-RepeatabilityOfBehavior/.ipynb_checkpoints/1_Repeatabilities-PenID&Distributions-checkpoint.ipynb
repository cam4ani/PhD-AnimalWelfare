# %%
library(rptR)
library(ggplot2)
library(lindia)
library(tidyverse)
library(lmerTest) #lmer, glmer
library(DHARMa) #verify assumption of glm
library(merTools) #sim
library(MuMIn) #r2
library(glmmTMB)
library(glmmADMB)
library(lme4)
library(MASS)
library(boot) #bootstrap
# Out:
# Warning message:
# "package 'rptR' was built under R version 3.6.3"
# Warning message:
# "package 'lindia' was built under R version 3.6.3"
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
# v purrr   0.3.4
#
# Warning message:
# "package 'tibble' was built under R version 3.6.3"
# Warning message:
# "package 'tidyr' was built under R version 3.6.3"
# Warning message:
# "package 'readr' was built under R version 3.6.3"
# Warning message:
# "package 'purrr' was built under R version 3.6.3"
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Warning message:
# "package 'stringr' was built under R version 3.6.3"
# Warning message:
# "package 'forcats' was built under R version 3.6.3"
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Warning message:
# "package 'lmerTest' was built under R version 3.6.3"
# Loading required package: lme4
#
# Warning message:
# "package 'lme4' was built under R version 3.6.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 3.6.3"
#
# Attaching package: 'Matrix'
#
#
# The following objects are masked from 'package:tidyr':
#
#     expand, pack, unpack
#
#
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# This is DHARMa 0.4.5. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa')
#
# Warning message:
# "package 'merTools' was built under R version 3.6.3"
# Loading required package: arm
#
# Loading required package: MASS
#
# Warning message:
# "package 'MASS' was built under R version 3.6.3"
#
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:dplyr':
#
#     select
#
#
#
# arm (Version 1.12-2, built: 2021-10-15)
#
#
# Working directory is C:/Users/camil/Desktop/animals_code/PhD-AnimalWelfare/Chapter2-RepeatabilityOfBehavior
#
#
# Warning message:
# "package 'MuMIn' was built under R version 3.6.3"
# Warning message:
# "package 'glmmTMB' was built under R version 3.6.3"
#
# Attaching package: 'glmmADMB'
#
#
# The following object is masked from 'package:MASS':
#
#     stepAIC
#
#
# The following object is masked from 'package:lmerTest':
#
#     step
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Warning message:
# "package 'boot' was built under R version 3.6.3"
#
# Attaching package: 'boot'
#
#
# The following object is masked from 'package:arm':
#
#     logit

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
df = read.csv(file.path(path_,'df_BS.csv'), header = TRUE, sep = ",")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID)
df$TrackingSystemID = as.factor(df$TrackingSystemID)
df$level = as.factor(df$level) 
df$FoodPenID = as.factor(df$FoodPenID) 
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment)

#setting reference group
df <- df %>% mutate(Treatment = relevel(Treatment, ref = "TRAN"))
contrasts(df$Treatment)
df <- df %>% mutate(CLASS = relevel(CLASS, ref = "REXP"))
contrasts(df$CLASS)
print(dim(df))
summary(df)

#make sure its integer and not TRUE/FALSE
df$WentinWG = as.integer(df$WentinWG)
df$Sleeping_NotUppest = as.integer(df$Sleeping_Uppest)

df_time = df[df$BS_type=='time',]
dim(df_time)

df_LP2 = df[df$BS_type=='LP2',]
dim(df_LP2)

df_LP10 = df[df$BS_type=='LP10',]
dim(df_LP10)

df_cold = df[df$BS_type=='cold',]
dim(df_cold)

df_vacc = df[df$BS_type=='TypicalVaccinationDay',]
dim(df_vacc)

df_AC = df[df$across_context==1,]
dim(df_AC)
# Out:
#      OFH
# TRAN 0
# OFH  1
#      LEXP MEXP
# REXP 0    0
# LEXP 1    0
# MEXP 0    1
# [1] 5051   22
#              TrackingSystemID        level           DOA             WOA
#  TrackingSystem 10-12:1907    2021-01-09: 159   Min.   :179.0   Min.   :26.00
#  TrackingSystem 3-5  :1924    2021-01-17: 159   1st Qu.:220.0   1st Qu.:32.00
#  TrackingSystem 8-9  :1220    2021-04-18: 159   Median :279.0   Median :40.00
#                               2021-01-24: 158   Mean   :283.1   Mean   :40.86
#                               2021-05-07: 157   3rd Qu.:338.0   3rd Qu.:49.00
#                               2020-12-06: 156   Max.   :410.0   Max.   :59.00
#                               (Other)   :4103
#       DIB                FoodPenID                     BS_type     Treatment
#  Min.   : 61.0   FoodPenID1-4 :1265   cold                 : 471   TRAN:2492
#  1st Qu.:102.0   FoodPenID5-8 :1246   LP10                 : 450   OFH :2559
#  Median :161.0   FoodPenID9-12:2540   LP2                  : 466
#  Mean   :165.1                        time                 :3196
#  3rd Qu.:220.0                        TypicalVaccinationDay: 468
#  Max.   :292.0
#
#   CLASS          PenID      temperature_C_avg     HenID      across_context
#  REXP:2934   pen5   : 659   Min.   :-2.000    hen_10 :  33   Min.   :0.0000
#  LEXP: 946   pen11  : 648   1st Qu.: 3.333    hen_101:  33   1st Qu.:0.0000
#  MEXP:1171   pen10  : 647   Median : 7.167    hen_102:  33   Median :0.0000
#              pen4   : 646   Mean   : 8.940    hen_107:  33   Mean   :0.1216
#              pen9   : 633   3rd Qu.:15.000    hen_109:  33   3rd Qu.:0.0000
#              pen3   : 619   Max.   :24.000    hen_112:  33   Max.   :1.0000
#              (Other):1199                     (Other):4853
#    KBF_interp    weight_interp     WentinWG      mid_cum_Z4_h_Morning
#  Min.   : 0.00   Min.   :1237   Min.   :0.0000   Min.   :2.037
#  1st Qu.:10.29   1st Qu.:1723   1st Qu.:0.0000   1st Qu.:3.800
#  Median :21.71   Median :1820   Median :1.0000   Median :4.394
#  Mean   :23.14   Mean   :1826   Mean   :0.6818   Mean   :4.523
#  3rd Qu.:35.07   3rd Qu.:1927   3rd Qu.:1.0000   3rd Qu.:5.156
#  Max.   :81.17   Max.   :2329   Max.   :1.0000   Max.   :7.983
#
#  Sleeping_Uppest  vertical_travel_distance_fulllight_perinsideh
#  Min.   :0.0000   Min.   : 0.1353
#  1st Qu.:0.0000   1st Qu.: 3.0120
#  Median :1.0000   Median : 4.1263
#  Mean   :0.6979   Mean   : 4.2114
#  3rd Qu.:1.0000   3rd Qu.: 5.2553
#  Max.   :1.0000   Max.   :13.5731
#
#  food_sameDurTiming_r50_final food_sameDurTiming_r50_AB_final
#  Min.   :-0.7700              Min.   :-0.80000
#  1st Qu.: 0.0300              1st Qu.:-0.14000
#  Median : 0.2400              Median : 0.03000
#  Mean   : 0.2332              Mean   : 0.02907
#  3rd Qu.: 0.4500              3rd Qu.: 0.20000
#  Max.   : 0.9200              Max.   : 0.83000
#
#  food_sameDurTiming_r50_AP_final
#  Min.   :-0.7100
#  1st Qu.:-0.1600
#  Median : 0.0200
#  Mean   : 0.0195
#  3rd Qu.: 0.1900
#  Max.   : 0.8300
# [1] 3196   23
# [1] 466  23
# [1] 450  23
# [1] 471  23
# [1] 468  23
# [1] 614  23

# %%
citation('glmmTMB')
# Out:
# To cite glmmTMB in publications use:
#
#   Mollie E. Brooks, Kasper Kristensen, Koen J. van Benthem, Arni
#   Magnusson, Casper W. Berg, Anders Nielsen, Hans J. Skaug, Martin
#   Maechler and Benjamin M. Bolker (2017). glmmTMB Balances Speed and
#   Flexibility Among Packages for Zero-inflated Generalized Linear Mixed
#   Modeling. The R Journal, 9(2), 378-400.
#
# A BibTeX entry for LaTeX users is
#
#   @Article{,
#     author = {Mollie E. Brooks and Kasper Kristensen and Koen J. {van Benthem} and Arni Magnusson and Casper W. Berg and Anders Nielsen and Hans J. Skaug and Martin Maechler and Benjamin M. Bolker},
#     title = {{glmmTMB} Balances Speed and Flexibility Among Packages for Zero-inflated Generalized Linear Mixed Modeling},
#     year = {2017},
#     journal = {The R Journal},
#     url = {https://journal.r-project.org/archive/2017/RJ-2017-066/index.html},
#     pages = {378--400},
#     volume = {9},
#     number = {2},
#   }

# %% [raw]
# --> The identity of the pen was previously tested for each behaviour separately and then ignored until otherwise mentioned (ΔAIC<2 and delta R_conditional^2<0.01).

# %% [markdown]
# # 1. Sleeping_NotUppest

# %%
glmer(Sleeping_Uppest ~  Treatment + scale(weight_interp)+scale(KBF_interp)+CLASS + (1|PenID/HenID), data=df_time, family='binomial')
#penid as as random effect --> no cvg, penID have 0 var
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.0293448 (tol = 0.002, component 1)"
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# Sleeping_Uppest ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + (1 | PenID/HenID)
#    Data: df_time
#       AIC       BIC    logLik  deviance  df.resid
#  2781.316  2829.873 -1382.658  2765.316      3188
# Random effects:
#  Groups      Name        Std.Dev.
#  HenID:PenID (Intercept) 2.211489
#  PenID       (Intercept) 0.004657
# Number of obs: 3196, groups:  HenID:PenID, 193; PenID, 8
# Fixed Effects:
#          (Intercept)          TreatmentOFH  scale(weight_interp)
#               1.7073                0.5519               -0.2194
#    scale(KBF_interp)             CLASSLEXP             CLASSMEXP
#              -0.1046               -0.6268               -1.3625
# optimizer (Nelder_Mead) convergence code: 0 (OK) ; 0 optimizer warnings; 1 lme4 warnings

# %%
#same but with diff optimizer settings
glmer(Sleeping_Uppest ~  Treatment + scale(weight_interp)+scale(KBF_interp)+CLASS + (1|PenID/HenID), data=df_time, family='binomial',
      control = glmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
#penid as as random effect --> no cvg, penID have 0 var
# Out:
# Warning message in optimx.check(par, optcfg$ufn, optcfg$ugr, optcfg$uhess, lower, :
# "Parameters or bounds appear to have different scalings.
#   This can cause poor performance in optimization.
#   It is important for derivative free methods like BOBYQA, UOBYQA, NEWUOA."
# boundary (singular) fit: see ?isSingular
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# Sleeping_Uppest ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + (1 | PenID/HenID)
#    Data: df_time
#       AIC       BIC    logLik  deviance  df.resid
#  2781.316  2829.873 -1382.658  2765.316      3188
# Random effects:
#  Groups      Name        Std.Dev.
#  HenID:PenID (Intercept) 2.211
#  PenID       (Intercept) 0.000
# Number of obs: 3196, groups:  HenID:PenID, 193; PenID, 8
# Fixed Effects:
#          (Intercept)          TreatmentOFH  scale(weight_interp)
#               1.7072                0.5522               -0.2194
#    scale(KBF_interp)             CLASSLEXP             CLASSMEXP
#              -0.1048               -0.6271               -1.3629
# optimizer (optimx) convergence code: 0 (OK) ; 1 optimizer warnings; 1 lme4 warnings

# %%
#PenID as fixed effect
mod__1 = glmer(Sleeping_Uppest ~  Treatment+ scale(weight_interp)+scale(KBF_interp)+CLASS +(1|HenID), data=df_time, family='binomial',
      control = glmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))

mod__2 = glmer(Sleeping_Uppest ~  Treatment + scale(weight_interp)+scale(KBF_interp)+CLASS + PenID+(1|HenID), data=df_time, family='binomial',
      control = glmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
#cant do anova for binomial
#--> cant use, no var
summary(mod__1)
summary(mod__2)
AIC(mod__1,mod__2)
r.squaredGLMM(mod__1)
r.squaredGLMM(mod__2)
#Marginal R2 : variance explained only by fixed effects
#conditional R2 : variance explained by the entire model (fixed effects & random effect)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# Sleeping_Uppest ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + (1 | HenID)
#    Data: df_time
# Control: glmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   2779.3   2821.8  -1382.7   2765.3     3189
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5400 -0.3667  0.1954  0.4086  2.7418
#
# Random effects:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 4.891    2.211
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.70722    0.28426   6.006  1.9e-09 ***
# TreatmentOFH          0.55220    0.35954   1.536  0.12457
# scale(weight_interp) -0.21941    0.12699  -1.728  0.08402 .
# scale(KBF_interp)    -0.10480    0.09804  -1.069  0.28509
# CLASSLEXP            -0.62709    0.49565  -1.265  0.20580
# CLASSMEXP            -1.36291    0.44775  -3.044  0.00234 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ CLASSL
# TreatmntOFH -0.568
# scl(wght_n) -0.004 -0.005
# scl(KBF_nt)  0.033 -0.083 -0.332
# CLASSLEXP   -0.336 -0.069 -0.012 -0.012
# CLASSMEXP   -0.413 -0.023 -0.028  0.044  0.238
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# Sleeping_Uppest ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + PenID + (1 | HenID)
#    Data: df_time
# Control: glmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   2786.2   2865.1  -1380.1   2760.2     3183
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6254 -0.3648  0.1873  0.4036  2.7816
#
# Random effects:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 4.793    2.189
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.76005    0.52110   3.378 0.000731 ***
# TreatmentOFH          1.08878    0.72005   1.512 0.130512
# scale(weight_interp) -0.23681    0.12819  -1.847 0.064705 .
# scale(KBF_interp)    -0.09223    0.09843  -0.937 0.348747
# CLASSLEXP            -0.73075    0.49526  -1.475 0.140086
# CLASSMEXP            -1.41370    0.44518  -3.176 0.001496 **
# PenIDpen11           -0.78329    0.73606  -1.064 0.287253
# PenIDpen12            0.10359    0.69804   0.148 0.882025
# PenIDpen3            -0.10238    0.73215  -0.140 0.888794
# PenIDpen4             0.16101    0.69893   0.230 0.817806
# PenIDpen5            -1.30999    0.71859  -1.823 0.068304 .
# PenIDpen8            -0.37568    0.69625  -0.540 0.589483
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ CLASSL CLASSM PnID11 PnID12 PnIDp3
# TreatmntOFH -0.636
# scl(wght_n) -0.039 -0.037
# scl(KBF_nt)  0.035 -0.007 -0.340
# CLASSLEXP   -0.226 -0.052 -0.001 -0.019
# CLASSMEXP   -0.234 -0.036 -0.021  0.040  0.244
# PenIDpen11  -0.033 -0.514  0.136 -0.100  0.081  0.052
# PenIDpen12  -0.685  0.488  0.048 -0.029  0.015  0.008  0.009
# PenIDpen3   -0.006 -0.508  0.037 -0.029  0.020  0.007  0.503  0.002
# PenIDpen4   -0.686  0.488  0.017 -0.016  0.040  0.000  0.006  0.507  0.002
# PenIDpen5   -0.033 -0.527  0.058 -0.049  0.080  0.058  0.525  0.005  0.512
# PenIDpen8   -0.697  0.486  0.035 -0.001  0.067  0.016  0.010  0.510  0.002
#             PnIDp4 PnIDp5
# TreatmntOFH
# scl(wght_n)
# scl(KBF_nt)
# CLASSLEXP
# CLASSMEXP
# PenIDpen11
# PenIDpen12
# PenIDpen3
# PenIDpen4
# PenIDpen5    0.004
# PenIDpen8    0.510  0.008
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#        df AIC
# mod__1  7 2779.316
# mod__2 13 2786.189
# Warning message:
# "'r.squaredGLMM' now calculates a revised statistic. See the help page."
# Warning message:
# "The null model is correct only if all variables used by the original model remain unchanged."
#             R2m        R2c
# theoretical 0.05184361 0.6186864
# delta       0.04436696 0.5294622
# Warning message:
# "The null model is correct only if all variables used by the original model remain unchanged."
#             R2m        R2c
# theoretical 0.06944153 0.6212459
# delta       0.05948456 0.5321677

# %%
#by curiosity lets check the repeatabitlily of penid having also the henid
set.seed(1234)
mod_ = rpt(Sleeping_Uppest ~ Treatment + scale(weight_interp) + scale(KBF_interp)+CLASS + (1|PenID)+(1|HenID),
               grname=c('PenID',"HenID"), datatype="Binary", data=df_time, adjusted=TRUE, nboot=5, npermut=0,
               link='logit') 
mod_
sim_res = simulateResiduals(mod_$mod, n=1000)
plot(sim_res)
plot(mod_, grname = "HenID", type = "boot", cex.main = 0.8)
#--> R=0, singular value
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.0293448 (tol = 0.002, component 1)"
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.0293448 (tol = 0.002, component 1)"
# Bootstrap Progress:
# boundary (singular) fit: see ?isSingular
#
# boundary (singular) fit: see ?isSingular
# Repeatability estimation using the glmm method and logit link
#
# Repeatability for PenID
# --------------------------------
# Link-scale approximation:
# R  = 0
# SE = 0.002
# CI = [0, 0.004]
# P  = 1 [LRT]
#      NA [Permutation]
#
# Original-scale approximation:
# R  = 0
# SE = 0.003
# CI = [0, 0.006]
# P  = 1 [LRT]
#      NA [Permutation]
#
# Repeatability for HenID
# --------------------------------
# Link-scale approximation:
# R  = 0.504
# SE = 0.022
# CI = [0.444, 0.492]
# P  = 2.56e-227 [LRT]
#      NA [Permutation]
#
# Original-scale approximation:
# R  = 0.796
# SE = 0.062
# CI = [0.593, 0.751]
# P  = 2.56e-227 [LRT]
#      NA [Permutation]
# Plot with title "Residual vs. predicted"
# Plot with title "Link-scale approximation bootstrap
# repeatabilities for HenID"

# %% [raw]
# -->wont use penID!

# %% [markdown]
# # 2. food_related_behavior_final

# %% [markdown]
# ### check distribution - no need to test for penid, we will control for the penIDfood

# %%
hist(df_time$food_sameDurTiming_r50_final)
# Out:
# Plot with title "Histogram of df_time$food_sameDurTiming_r50_final"

# %%
########### GAUSSIAN
set.seed(1234)
mod_ = rpt(food_sameDurTiming_r50_final  ~ Treatment +FoodPenID+ scale(weight_interp)+scale(DIB)+scale(KBF_interp)+CLASS +(1|HenID), 
                       grname = c("HenID"), data = df_time, datatype = "Gaussian", adjusted =TRUE,
                       nboot = 30, npermut = 0)
print(mod_)
model_ = mod_$mod
summary(model_)
sim_res = simulateResiduals(model_, n=1000)
plot(sim_res)
testDispersion(sim_res)

par(mar = c(2, 2, 2, 2))
qqnorm(residuals(model_), main = NULL) 
qqline(residuals(model_))
hist(residuals(model_))
plot(model_)
# Out:
# Bootstrap Progress:
#
#
# Repeatability estimation using the lmm method
#
# Repeatability for HenID
# R  = 0.34
# SE = 0.022
# CI = [0.295, 0.373]
# P  = 4.14e-192 [LRT]
#      NA [Permutation]
# Linear mixed model fit by REML ['lmerMod']
# Formula:
# food_sameDurTiming_r50_final ~ Treatment + FoodPenID + scale(weight_interp) +
#     scale(DIB) + scale(KBF_interp) + CLASS + (1 | HenID)
#    Data: data
#
# REML criterion at convergence: 351
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2747 -0.6164  0.0856  0.6712  3.0147
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.02902  0.1704
#  Residual             0.05642  0.2375
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                          Estimate Std. Error t value
# (Intercept)             0.2769135  0.0310983   8.904
# TreatmentOFH           -0.0490093  0.0264012  -1.856
# FoodPenIDFoodPenID5-8  -0.0008233  0.0372060  -0.022
# FoodPenIDFoodPenID9-12 -0.0391091  0.0321294  -1.217
# scale(weight_interp)   -0.0221007  0.0109839  -2.012
# scale(DIB)              0.0114111  0.0063359   1.801
# scale(KBF_interp)       0.0158293  0.0090419   1.751
# CLASSLEXP              -0.0179332  0.0366414  -0.489
# CLASSMEXP               0.0410903  0.0334296   1.229
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH FPIDFPID5 FPIDFPID9 scl(_) s(DIB) s(KBF_ CLASSL
# TreatmntOFH -0.413
# FPIDFPID5-8 -0.609 -0.008
# FPIDFPID9-1 -0.695  0.000  0.578
# scl(wght_n) -0.002 -0.028  0.027     0.035
# scale(DIB)  -0.018  0.073 -0.019    -0.019    -0.459
# scl(KBF_nt)  0.048 -0.106  0.003     0.000     0.001 -0.542
# CLASSLEXP   -0.232 -0.052  0.046     0.003    -0.031  0.028 -0.032
# CLASSMEXP   -0.280  0.007  0.029     0.015    -0.041  0.006  0.023  0.222
# Plot with title "Residual vs. predicted"
# 	DHARMa nonparametric dispersion test via sd of residuals fitted vs.
# 	simulated
#
# data:  simulationOutput
# dispersion = 0.99029, p-value = 0.838
# alternative hypothesis: two.sided
# Plot with title "DHARMa nonparametric dispersion test via sd of
# residuals fitted vs. simulated
# "
# plot without title
# Plot with title "Histogram of residuals(model_)"
# plot without title

# %% [markdown]
# # 3. vertical_travel_distance_fulllight_perinsideh

# %% [markdown]
# ### check model distribution

# %% [markdown]
# #not poisson as we will loose some var by putting integer!
# mod_ = rpt(vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weight_interp)+scale(DIB)+scale(KBF_interp) +(1|HenID),
#                        grname = c("HenID"), data = df_time, datatype = "Poisson", adjusted =TRUE,
#                        nboot = 30, npermut = 0)
# print(mod_)
# model_ = mod_$mod
# summary(model_)
# sim_res = simulateResiduals(model_, n=1000)
# plot(sim_res)
# testDispersion(sim_res)

# %%
hist(df_time$vertical_travel_distance_fulllight_perinsideh)
# Out:
# Plot with title "Histogram of df_time$vertical_travel_distance_fulllight_perinsideh"

# %%
############ GAUSSIAN with sqrt (log not good)
#scale(I(DIB^2))+
hist(sqrt(df_time$vertical_travel_distance_fulllight_perinsideh))
mod_ = rpt(sqrt(vertical_travel_distance_fulllight_perinsideh) ~ Treatment + scale(weight_interp)+scale(DIB)+scale(KBF_interp)+CLASS +(1|HenID), 
                       grname = c("HenID"), data = df_time, datatype = "Gaussian", adjusted =TRUE,
                       nboot = 30, npermut = 0)
print(mod_)
model_ = mod_$mod
summary(model_)
sim_res = simulateResiduals(model_, n=1000)
plot(sim_res)
testDispersion(sim_res)

par(mar = c(2, 2, 2, 2))
qqnorm(residuals(model_), main = NULL) 
qqline(residuals(model_))
hist(residuals(model_))
plot(model_)
#scale(FeatherDamage_interp) not significant and is removing 315 rows due to NA : we wont use it
#fits better with +scale(I(DIB^2)), though not perfectly
# Out:
# Bootstrap Progress:
#
#
# Repeatability estimation using the lmm method
#
# Repeatability for HenID
# R  = 0.737
# SE = 0.027
# CI = [0.676, 0.767]
# P  = 0 [LRT]
#      NA [Permutation]
# Linear mixed model fit by REML ['lmerMod']
# Formula: sqrt(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +
#     scale(weight_interp) + scale(DIB) + scale(KBF_interp) + CLASS +
#     (1 | HenID)
#    Data: data
#
# REML criterion at convergence: 637.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.6951 -0.5767  0.0157  0.5974  4.2457
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.15818  0.3977
#  Residual             0.05634  0.2374
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                       Estimate Std. Error t value
# (Intercept)           1.995846   0.045971  43.416
# TreatmentOFH         -0.049533   0.058219  -0.851
# scale(weight_interp) -0.032709   0.015060  -2.172
# scale(DIB)           -0.023406   0.007243  -3.231
# scale(KBF_interp)    -0.001797   0.010503  -0.171
# CLASSLEXP             0.088267   0.081835   1.079
# CLASSMEXP             0.073047   0.074526   0.980
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(DIB) s(KBF_ CLASSL
# TreatmntOFH -0.618
# scl(wght_n)  0.020 -0.015
# scale(DIB)  -0.029  0.040 -0.551
# scl(KBF_nt)  0.038 -0.055  0.003 -0.556
# CLASSLEXP   -0.313 -0.055 -0.019  0.018 -0.017
# CLASSMEXP   -0.387  0.010 -0.027  0.007  0.013  0.214
# Plot with title "Histogram of sqrt(df_time$vertical_travel_distance_fulllight_perinsideh)"
# Plot with title "Residual vs. predicted"
# 	DHARMa nonparametric dispersion test via sd of residuals fitted vs.
# 	simulated
#
# data:  simulationOutput
# dispersion = 0.92837, p-value = 0.386
# alternative hypothesis: two.sided
# Plot with title "DHARMa nonparametric dispersion test via sd of
# residuals fitted vs. simulated
# "
# plot without title
# Plot with title "Histogram of residuals(model_)"
# plot without title

# %%
############ GAUSSIAN no transformation
hist(df_time$vertical_travel_distance_fulllight_perinsideh)
mod_ = rpt(vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weight_interp)+scale(DIB)+scale(KBF_interp)+CLASS +(1|HenID), 
                       grname = c("HenID"), data = df_time, datatype = "Gaussian", adjusted =TRUE,
                       nboot = 30, npermut = 0)
print(mod_)
model_ = mod_$mod
summary(model_)
sim_res = simulateResiduals(model_, n=1000)
plot(sim_res)
testDispersion(sim_res)

par(mar = c(2, 2, 2, 2))
qqnorm(residuals(model_), main = NULL) 
qqline(residuals(model_))
hist(residuals(model_))
plot(model_)
#scale(FeatherDamage_interp) not significant and is removing 315 rows due to NA : we wont use it
#fits better with +scale(I(DIB^2)), though not perfectly
# Out:
# Bootstrap Progress:
#
#
# Repeatability estimation using the lmm method
#
# Repeatability for HenID
# R  = 0.7
# SE = 0.019
# CI = [0.672, 0.736]
# P  = 0 [LRT]
#      NA [Permutation]
# Linear mixed model fit by REML ['lmerMod']
# Formula:
# vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weight_interp) +
#     scale(DIB) + scale(KBF_interp) + CLASS + (1 | HenID)
#    Data: data
#
# REML criterion at convergence: 9617.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1573 -0.5879 -0.0303  0.5418  6.4553
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 2.2162   1.4887
#  Residual             0.9515   0.9755
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                       Estimate Std. Error t value
# (Intercept)           4.223129   0.172597  24.468
# TreatmentOFH         -0.200767   0.218556  -0.919
# scale(weight_interp) -0.120061   0.060545  -1.983
# scale(DIB)           -0.119540   0.029478  -4.055
# scale(KBF_interp)    -0.001286   0.042781  -0.030
# CLASSLEXP             0.360226   0.306958   1.174
# CLASSMEXP             0.186963   0.279591   0.669
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(DIB) s(KBF_ CLASSL
# TreatmntOFH -0.618
# scl(wght_n)  0.022 -0.016
# scale(DIB)  -0.031  0.043 -0.544
# scl(KBF_nt)  0.041 -0.060  0.003 -0.556
# CLASSLEXP   -0.314 -0.054 -0.020  0.019 -0.018
# CLASSMEXP   -0.388  0.010 -0.029  0.007  0.014  0.214
# Plot with title "Histogram of df_time$vertical_travel_distance_fulllight_perinsideh"
# Plot with title "Residual vs. predicted"
# 	DHARMa nonparametric dispersion test via sd of residuals fitted vs.
# 	simulated
#
# data:  simulationOutput
# dispersion = 0.97079, p-value = 0.718
# alternative hypothesis: two.sided
# Plot with title "DHARMa nonparametric dispersion test via sd of
# residuals fitted vs. simulated
# "
# plot without title
# Plot with title "Histogram of residuals(model_)"
# plot without title

# %%
############ GAMMA
modF = glmmTMB(vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weight_interp)+scale(DIB)+scale(KBF_interp)+CLASS +(1|HenID), 
                family = Gamma(link="log"), data=df_time)
summary(modF)
sim_res = simulateResiduals(modF, n=500)
plot(sim_res)
testOutliers(sim_res)
#plot residual against predictors
plotResiduals(sim_res, form = df_time$DIB)
plotResiduals(sim_res, form = df_time$KBF_interp)
plotResiduals(sim_res, form = df_time$weight_interp)
plotResiduals(sim_res, form = df_time$Treatment)
# Out:
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
#  Family: Gamma  ( log )
# Formula:
# vertical_travel_distance_fulllight_perinsideh ~ Treatment + scale(weight_interp) +
#     scale(DIB) + scale(KBF_interp) + CLASS + (1 | HenID)
# Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   9878.3   9933.0  -4930.2   9860.3     3187
#
# Random effects:
#
# Conditional model:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 0.2246   0.4739
# Number of obs: 3196, groups:  HenID, 193
#
# Dispersion estimate for Gamma family (sigma^2): 0.0666
#
# Conditional model:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.343201   0.054643  24.581  < 2e-16 ***
# TreatmentOFH         -0.060923   0.069208  -0.880 0.378702
# scale(weight_interp) -0.056819   0.016598  -3.423 0.000619 ***
# scale(DIB)           -0.013469   0.007961  -1.692 0.090660 .
# scale(KBF_interp)    -0.004774   0.011600  -0.412 0.680704
# CLASSLEXP             0.096924   0.097343   0.996 0.319395
# CLASSMEXP             0.112077   0.088634   1.264 0.206054
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Plot with title "Residual vs. predicted"
# 	DHARMa outlier test based on exact binomial test with approximate
# 	expectations
#
# data:  sim_res
# outliers at both margin(s) = 50, observations = 3196, p-value =
# 1.981e-15
# alternative hypothesis: true probability of success is not equal to 0.003992016
# 95 percent confidence interval:
#  0.01163340 0.02057392
# sample estimates:
# frequency of outliers (expected: 0.00399201596806387 )
#                                             0.01564456
# Plot with title "Outlier test significant"
# Plot with title "Residual vs. predictor"
# Plot with title "Residual vs. predictor"
# Plot with title "Residual vs. predictor"
# plot without title

# %% [raw]
# CONLUSION
# gaussian fits better, though not perfectly. sqrt made it worse.
# gamma does not fit well.

# %% [markdown]
# ### check penID

# %%
#as random effect
mod__1 = lmer(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +scale(DIB)+scale(weight_interp)+ scale(KBF_interp)+CLASS +(1|HenID), 
              df_time)
mod__2 = lmer(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +scale(DIB)+scale(weight_interp)+ scale(KBF_interp)+CLASS + (1|PenID/HenID), 
              df_time)
summary(mod__1)
summary(mod__2)
AIC(mod__1,mod__2)
r.squaredGLMM(mod__1)
r.squaredGLMM(mod__2)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +
#     scale(DIB) + scale(weight_interp) + scale(KBF_interp) + CLASS +
#     (1 | HenID)
#    Data: df_time
#
# REML criterion at convergence: 5908.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1573 -0.5879 -0.0303  0.5418  6.4553
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.6927   0.8323
#  Residual             0.2974   0.5454
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                        Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)          -4.314e-02  9.650e-02  1.864e+02  -0.447   0.6553
# TreatmentOFH         -1.122e-01  1.222e-01  1.858e+02  -0.919   0.3595
# scale(DIB)           -6.683e-02  1.648e-02  3.019e+03  -4.055 5.13e-05 ***
# scale(weight_interp) -6.713e-02  3.385e-02  1.842e+03  -1.983   0.0475 *
# scale(KBF_interp)    -7.192e-04  2.392e-02  3.067e+03  -0.030   0.9760
# CLASSLEXP             2.014e-01  1.716e-01  1.821e+02   1.174   0.2421
# CLASSMEXP             1.045e-01  1.563e-01  1.829e+02   0.669   0.5045
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH s(DIB) scl(_) s(KBF_ CLASSL
# TreatmntOFH -0.618
# scale(DIB)  -0.031  0.043
# scl(wght_n)  0.022 -0.016 -0.544
# scl(KBF_nt)  0.041 -0.060 -0.556  0.003
# CLASSLEXP   -0.314 -0.054  0.019 -0.020 -0.018
# CLASSMEXP   -0.388  0.010  0.007 -0.029  0.014  0.214
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +
#     scale(DIB) + scale(weight_interp) + scale(KBF_interp) + CLASS +
#     (1 | PenID/HenID)
#    Data: df_time
#
# REML criterion at convergence: 5908.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1560 -0.5874 -0.0305  0.5426  6.4560
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  HenID:PenID (Intercept) 0.686920 0.82881
#  PenID       (Intercept) 0.007261 0.08521
#  Residual                0.297443 0.54538
# Number of obs: 3196, groups:  HenID:PenID, 193; PenID, 8
#
# Fixed effects:
#                        Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)          -4.316e-02  1.051e-01  8.639e+00  -0.411   0.6914
# TreatmentOFH         -1.124e-01  1.358e-01  6.030e+00  -0.827   0.4395
# scale(DIB)           -6.666e-02  1.648e-02  3.007e+03  -4.046 5.35e-05 ***
# scale(weight_interp) -6.773e-02  3.385e-02  1.841e+03  -2.001   0.0456 *
# scale(KBF_interp)    -7.786e-04  2.391e-02  3.061e+03  -0.033   0.9740
# CLASSLEXP             2.025e-01  1.711e-01  1.784e+02   1.184   0.2382
# CLASSMEXP             1.043e-01  1.557e-01  1.772e+02   0.670   0.5037
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH s(DIB) scl(_) s(KBF_ CLASSL
# TreatmntOFH -0.634
# scale(DIB)  -0.029  0.039
# scl(wght_n)  0.019 -0.015 -0.544
# scl(KBF_nt)  0.038 -0.054 -0.556  0.002
# CLASSLEXP   -0.287 -0.049  0.018 -0.019 -0.018
# CLASSMEXP   -0.355  0.009  0.007 -0.028  0.013  0.215
#        df AIC
# mod__1  9 5926.94
# mod__2 10 5928.79
#      R2m        R2c
# [1,] 0.02014285 0.7056668
#      R2m        R2c
# [1,] 0.02024171 0.7061162

# %%
#by curiostiy, as fixed effect with anova
mod__1 = lmer(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +scale(DIB)+scale(weight_interp)+ scale(KBF_interp) +CLASS+(1|HenID), 
              df_time)
mod__2 = lmer(scale(vertical_travel_distance_fulllight_perinsideh) ~ Treatment +scale(DIB)+scale(weight_interp)+ scale(KBF_interp)+CLASS + PenID+(1|HenID), 
              df_time)
anova(mod__1, mod__2)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# refitting model(s) with ML (instead of REML)
#        npar AIC      BIC      logLik    deviance Chisq    Df Pr(>Chisq)
# mod__1  9   5899.283 5953.910 -2940.641 5881.283       NA NA       NA
# mod__2 15   5903.523 5994.567 -2936.761 5873.523 7.760218  6 0.256202

# %% [raw]
# CONLUSION
# Penid explain almost no variation--> not penid

# %% [markdown]
# # 4. mid_cum_Z4_h_Morning

# %% [raw]
# from: http://cran.nexr.com/web/packages/glmmTMB/glmmTMB.pdf: "Internally, glmmTMB fits Gamma responses by fitting a mean and a shape parameter; sigma is estimated as (1/sqrt(shape)), which will typically be close (but not identical to) that estimated by stats:::sigma.default, which uses sqrt(deviance/df.residual)"
# so in glmmadmb we extracted nuN with modF$alpha, here he extract nuN with 1/sigma(modF)^2

# %%
#for gamma, dharma can be used: https://stats.stackexchange.com/questions/531749/interpretation-of-dharma-residuals-for-gamma-glmm

# %% [markdown]
# ### check model distribution

# %%
hist(df$mid_cum_Z4_h_Morning)
# Out:
# Plot with title "Histogram of df$mid_cum_Z4_h_Morning"

# %%
############ GAMMA
modF = glmmTMB(mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) + scale(DIB) +CLASS+ (1|HenID), 
                family = Gamma(link="log"), data=df_time)
summary(modF)
sim_res = simulateResiduals(modF, n=500)
plot(sim_res)
testOutliers(sim_res)
#plot residual against predictors
plotResiduals(sim_res, form = df_time$DIB)
plotResiduals(sim_res, form = df_time$KBF_interp)
plotResiduals(sim_res, form = df_time$weight_interp)
plotResiduals(sim_res, form = df_time$Treatment)
#fit perfectly!!!!! wop wooop
# Out:
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
#  Family: Gamma  ( log )
# Formula:
# mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     scale(DIB) + CLASS + (1 | HenID)
# Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   6917.3   6971.9  -3449.6   6899.3     3187
#
# Random effects:
#
# Conditional model:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 0.02147  0.1465
# Number of obs: 3196, groups:  HenID, 193
#
# Dispersion estimate for Gamma family (sigma^2): 0.0222
#
# Conditional model:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.483560   0.017401   85.26  < 2e-16 ***
# TreatmentOFH         -0.001003   0.022013   -0.05   0.9636
# scale(weight_interp) -0.062196   0.008140   -7.64 2.15e-14 ***
# scale(KBF_interp)    -0.011296   0.006183   -1.83   0.0677 .
# scale(DIB)            0.077479   0.004211   18.40  < 2e-16 ***
# CLASSLEXP            -0.002956   0.030723   -0.10   0.9234
# CLASSMEXP             0.035348   0.028021    1.26   0.2071
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Plot with title "Residual vs. predicted"
# 	DHARMa outlier test based on exact binomial test with approximate
# 	expectations
#
# data:  sim_res
# outliers at both margin(s) = 18, observations = 3196, p-value = 0.1572
# alternative hypothesis: true probability of success is not equal to 0.003992016
# 95 percent confidence interval:
#  0.003341218 0.008886499
# sample estimates:
# frequency of outliers (expected: 0.00399201596806387 )
#                                             0.00563204
# Plot with title "Outlier test n.s."
# Plot with title "Residual vs. predictor"
# Plot with title "Residual vs. predictor"
# Plot with title "Residual vs. predictor"
# plot without title

# %%
############ GAUSSIAN with no transformation
mod_ = rpt(mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) + scale(DIB)+CLASS +(1|HenID), 
                       grname = c("HenID"), data = df_time, datatype = "Gaussian", adjusted =TRUE,
                       nboot = 30, npermut = 0)
print(mod_)
model_ = mod_$mod
summary(model_)
par(mar = c(2, 2, 2, 2))
qqnorm(residuals(model_), main = NULL) 
qqline(residuals(model_))
hist(residuals(model_))
plot(model_)
sim_res = simulateResiduals(model_, n=1000)
plot(sim_res)
#fit badly
# Out:
# Bootstrap Progress:
#
#
# Repeatability estimation using the lmm method
#
# Repeatability for HenID
# R  = 0.489
# SE = 0.031
# CI = [0.43, 0.533]
# P  = 3.97e-318 [LRT]
#      NA [Permutation]
# Linear mixed model fit by REML ['lmerMod']
# Formula:
# mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     scale(DIB) + CLASS + (1 | HenID)
#    Data: data
#
# REML criterion at convergence: 7132
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.7649 -0.5567 -0.0968  0.4301  6.2663
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.4398   0.6632
#  Residual             0.4588   0.6774
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                      Estimate Std. Error t value
# (Intercept)           4.47294    0.07878  56.775
# TreatmentOFH         -0.02312    0.09965  -0.232
# scale(weight_interp) -0.27510    0.03626  -7.586
# scale(KBF_interp)    -0.04013    0.02782  -1.442
# scale(DIB)            0.34638    0.01920  18.041
# CLASSLEXP            -0.02263    0.13910  -0.163
# CLASSMEXP             0.16698    0.12686   1.316
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ s(DIB) CLASSL
# TreatmntOFH -0.618
# scl(wght_n)  0.030 -0.023
# scl(KBF_nt)  0.058 -0.085  0.002
# scale(DIB)  -0.043  0.060 -0.500 -0.553
# CLASSLEXP   -0.318 -0.053 -0.027 -0.026  0.025
# CLASSMEXP   -0.389  0.009 -0.038  0.019  0.007  0.217
# plot without title
# Plot with title "Histogram of residuals(model_)"
# plot without title
# Plot with title "Residual vs. predicted"

# %%
############ GAUSSIAN with sqrt() transformation
mod_ = rpt(sqrt(mid_cum_Z4_h_Morning) ~ Treatment + scale(weight_interp) + scale(KBF_interp) + scale(DIB)+CLASS +(1|HenID), 
                       grname = c("HenID"), data = df_time, datatype = "Gaussian", adjusted =TRUE,
                       nboot = 30, npermut = 0)
print(mod_)
model_ = mod_$mod
summary(model_)
par(mar = c(2, 2, 2, 2))
qqnorm(residuals(model_), main = NULL) 
qqline(residuals(model_))
hist(residuals(model_))
plot(model_)
sim_res = simulateResiduals(model_, n=1000)
plot(sim_res)
#doe snot fit well either
# Out:
# Bootstrap Progress:
#
#
# Repeatability estimation using the lmm method
#
# Repeatability for HenID
# R  = 0.497
# SE = 0.029
# CI = [0.461, 0.569]
# P  = 0 [LRT]
#      NA [Permutation]
# Linear mixed model fit by REML ['lmerMod']
# Formula: sqrt(mid_cum_Z4_h_Morning) ~ Treatment + scale(weight_interp) +
#     scale(KBF_interp) + scale(DIB) + CLASS + (1 | HenID)
#    Data: data
#
# REML criterion at convergence: -2192.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1565 -0.5578 -0.0687  0.4611  5.9071
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.02435  0.1561
#  Residual             0.02461  0.1569
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                       Estimate Std. Error t value
# (Intercept)           2.102164   0.018516 113.531
# TreatmentOFH         -0.003407   0.023422  -0.145
# scale(weight_interp) -0.063717   0.008454  -7.537
# scale(KBF_interp)    -0.010854   0.006463  -1.680
# scale(DIB)            0.082019   0.004459  18.395
# CLASSLEXP            -0.005097   0.032704  -0.156
# CLASSMEXP             0.036339   0.029824   1.218
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ s(DIB) CLASSL
# TreatmntOFH -0.618
# scl(wght_n)  0.030 -0.023
# scl(KBF_nt)  0.058 -0.084  0.002
# scale(DIB)  -0.043  0.060 -0.502 -0.553
# CLASSLEXP   -0.318 -0.053 -0.027 -0.026  0.025
# CLASSMEXP   -0.389  0.009 -0.037  0.019  0.007  0.217
# plot without title
# Plot with title "Histogram of residuals(model_)"
# plot without title
# Plot with title "Residual vs. predicted"

# %% [raw]
# # --> certainly gamma!! Because we have a continuous positive distribution skewed, and gamma with log link, fits better than gaussian and avoid the sqrt transforamtion needed for gaussian.

# %% [markdown]
# ### check PenID

# %%
#with gamma
mod__1 = glmmTMB(mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) + scale(DIB)+CLASS + (1|HenID), 
                family = Gamma(link="log"), data=df_time)
mod__2 = glmmTMB(mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) + scale(DIB)+CLASS + (1|PenID/HenID), 
                family = Gamma(link="log"), data=df_time)
summary(mod__1)
summary(mod__2)
AIC(mod__1,mod__2)
r.squaredGLMM(mod__1)
r.squaredGLMM(mod__2)
# Out:
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Warning message in Matrix::sparseMatrix(dims = c(0, 0), i = integer(0), j = integer(0), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
#  Family: Gamma  ( log )
# Formula:
# mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     scale(DIB) + CLASS + (1 | HenID)
# Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   6917.3   6971.9  -3449.6   6899.3     3187
#
# Random effects:
#
# Conditional model:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 0.02147  0.1465
# Number of obs: 3196, groups:  HenID, 193
#
# Dispersion estimate for Gamma family (sigma^2): 0.0222
#
# Conditional model:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.483560   0.017401   85.26  < 2e-16 ***
# TreatmentOFH         -0.001003   0.022013   -0.05   0.9636
# scale(weight_interp) -0.062196   0.008140   -7.64 2.15e-14 ***
# scale(KBF_interp)    -0.011296   0.006183   -1.83   0.0677 .
# scale(DIB)            0.077479   0.004211   18.40  < 2e-16 ***
# CLASSLEXP            -0.002956   0.030723   -0.10   0.9234
# CLASSMEXP             0.035348   0.028021    1.26   0.2071
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#  Family: Gamma  ( log )
# Formula:
# mid_cum_Z4_h_Morning ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     scale(DIB) + CLASS + (1 | PenID/HenID)
# Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   6918.8   6979.5  -3449.4   6898.8     3186
#
# Random effects:
#
# Conditional model:
#  Groups      Name        Variance  Std.Dev.
#  HenID:PenID (Intercept) 0.0211160 0.14531
#  PenID       (Intercept) 0.0003542 0.01882
# Number of obs: 3196, groups:  HenID:PenID, 193; PenID, 8
#
# Dispersion estimate for Gamma family (sigma^2): 0.0222
#
# Conditional model:
#                        Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.4837939  0.0196726   75.42  < 2e-16 ***
# TreatmentOFH         -0.0008087  0.0255821   -0.03   0.9748
# scale(weight_interp) -0.0621664  0.0081330   -7.64 2.11e-14 ***
# scale(KBF_interp)    -0.0113390  0.0061791   -1.84   0.0665 .
# scale(DIB)            0.0774856  0.0042065   18.42  < 2e-16 ***
# CLASSLEXP            -0.0046893  0.0306196   -0.15   0.8783
# CLASSMEXP             0.0348456  0.0278227    1.25   0.2104
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#        df AIC
# mod__1  9 6917.274
# mod__2 10 6918.848
#           R2m       R2c
# delta     0.1403600 0.5627988
# lognormal 0.1410350 0.5655053
# trigamma  0.1396766 0.5600585
#           R2m       R2c
# delta     0.1403884 0.5628414
# lognormal 0.1410635 0.5655479
# trigamma  0.1397049 0.5601013

# %% [raw]
# CONCLUSION
# no penid

# %% [markdown]
# # 5. wentinWG

# %%
mod__1 = glmer(WentinWG ~  Treatment + scale(weight_interp)+scale(KBF_interp)+CLASS + (1|HenID), data=df_time, family='binomial')
mod__2 = glmer(WentinWG ~  Treatment + scale(weight_interp)+scale(KBF_interp)+CLASS + (1|PenID/HenID), data=df_time, family='binomial')
summary(mod__1)
summary(mod__2)
AIC(mod__1,mod__2)
r.squaredGLMM(mod__1)
r.squaredGLMM(mod__2)
#Marginal R2 : variance explained only by fixed effects
#conditional R2 : variance explained by the entire model (fixed effects & random effect)
#once accounting for the explained variance by the random effect, the penid did not add any variance (<1%)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: WentinWG ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + (1 | HenID)
#    Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   2985.5   3028.0  -1485.7   2971.5     3189
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.4087 -0.3888  0.1769  0.4765  3.5701
#
# Random effects:
#  Groups Name        Variance Std.Dev.
#  HenID  (Intercept) 5.32     2.307
# Number of obs: 3196, groups:  HenID, 193
#
# Fixed effects:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.38589    0.28522   4.859 1.18e-06 ***
# TreatmentOFH         -0.13872    0.36030  -0.385    0.700
# scale(weight_interp)  0.10832    0.12390   0.874    0.382
# scale(KBF_interp)     0.09049    0.09355   0.967    0.333
# CLASSLEXP            -0.16809    0.50134  -0.335    0.737
# CLASSMEXP             0.11992    0.45696   0.262    0.793
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ CLASSL
# TreatmntOFH -0.607
# scl(wght_n)  0.030  0.017
# scl(KBF_nt)  0.046 -0.072 -0.384
# CLASSLEXP   -0.317 -0.063 -0.023 -0.014
# CLASSMEXP   -0.396  0.012 -0.047  0.031  0.220
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: WentinWG ~ Treatment + scale(weight_interp) + scale(KBF_interp) +
#     CLASS + (1 | PenID/HenID)
#    Data: df_time
#
#      AIC      BIC   logLik deviance df.resid
#   2984.9   3033.4  -1484.4   2968.9     3188
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3541 -0.3859  0.1782  0.4719  3.4395
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  HenID:PenID (Intercept) 5.0357   2.2440
#  PenID       (Intercept) 0.2826   0.5316
# Number of obs: 3196, groups:  HenID:PenID, 193; PenID, 8
#
# Fixed effects:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.39173    0.38505   3.614 0.000301 ***
# TreatmentOFH         -0.14007    0.51486  -0.272 0.785584
# scale(weight_interp)  0.08115    0.12413   0.654 0.513271
# scale(KBF_interp)     0.10140    0.09326   1.087 0.276934
# CLASSLEXP            -0.14689    0.49075  -0.299 0.764693
# CLASSMEXP             0.10888    0.44607   0.244 0.807158
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) TrtOFH scl(_) s(KBF_ CLASSL
# TreatmntOFH -0.656
# scl(wght_n)  0.020  0.012
# scl(KBF_nt)  0.036 -0.050 -0.388
# CLASSLEXP   -0.230 -0.043 -0.019 -0.018
# CLASSMEXP   -0.288  0.008 -0.043  0.027  0.222
#        df AIC
# mod__1 7  2985.479
# mod__2 8  2984.875
# Warning message:
# "The null model is correct only if all variables used by the original model remain unchanged."
#             R2m         R2c
# theoretical 0.003686302 0.6193139
# delta       0.003242549 0.5447616
# Warning message:
# "The null model is correct only if all variables used by the original model remain unchanged."
#             R2m         R2c
# theoretical 0.003081538 0.6190014
# delta       0.002709897 0.5443484
