# %%
#basic package
import os
import numpy as np
import pandas as pd
import sys
import time
import datetime as dt
import itertools
import math
import pickle #save and load dictionaries/lists

#plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PACKAGE_PARENT = '../'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))
import config_origins as config

# %%
print('change the configuration file if not done yet!')
path_extracted_data = config.path_extracted_data
id_run = config.id_run
max_date_adaptability = config.max_date_adaptability
pal_tr = config.pal_treat
# Out:
# change the configuration file if not done yet!

# %%
name = 'OFH'

# %% [markdown]
# # download data

# %%
df_raw = pd.read_csv(os.path.join(path_extracted_data, 'OFH_df_MVT_simpler3.csv'), sep=',')
print(df_raw.shape)
df_raw.head(3)
# Out:
# (1968, 88)
#      HenID       level  verification_daily_total_duration  \
# 0  hen_131  2020-11-29                            54000.0
# 1  hen_131  2020-12-06                            54000.0
# 2  hen_131  2020-12-13                            54000.0
#
#    verification_daily_total_nbr_hour  \
# 0                               15.0
# 1                               15.0
# 2                               15.0
#
#                                    dur_values  perc_duration_3_Zone  \
# 0  [2328.0, 24759.0, 19620.0, 3589.0, 3704.0]                  36.0
# 1  [2722.0, 22141.0, 19489.0, 1706.0, 7942.0]                  36.0
# 2  [2064.0, 23442.0, 17261.0, 3354.0, 7879.0]                  32.0
#
#    perc_duration_4_Zone  perc_duration_5_Zone  perc_duration_2_Zone  \
# 0                   7.0                   7.0                  46.0
# 1                   3.0                  15.0                  41.0
# 2                   6.0                  15.0                  43.0
#
#    perc_duration_1_Zone  ...  Has_been_toptier_wholeday  weekday  WentinWG  \
# 0                   4.0  ...                      False   sunday         1
# 1                   5.0  ...                      False   sunday         1
# 2                   4.0  ...                      False   sunday         1
#
#   Sleeping_Uppest                                  dico_indoorZ_prop  \
# 0               1  {'Z2': 0.4791660000000001, 'Z3': 0.375, 'Z4': ...
# 1               1  {'Z2': 0.431579, 'Z3': 0.378947, 'Z4': 0.03157...
# 2               1  {'Z2': 0.447917, 'Z3': 0.333333, 'Z4': 0.0625,...
#
#   propindoor_duration_2_Zone propindoor_duration_3_Zone  \
# 0                   0.479166                   0.375000
# 1                   0.431579                   0.378947
# 2                   0.447917                   0.333333
#
#   propindoor_duration_4_Zone  propindoor_duration_5_Zone  sum_prop
# 0                   0.072917                    0.072917       1.0
# 1                   0.031579                    0.157895       1.0
# 2                   0.062500                    0.156250       1.0
#
# [3 rows x 88 columns]

# %%
#prediction
#worked well: #df_pred_Test2 & df_pred_Test_newdata2 with OFH_df_MVT_simpler2.csv
df_pred = pd.read_csv(os.path.join(path_extracted_data, 'OFH_df_pred_all.csv'), sep=',')
print(df_pred.shape)
display(df_pred.head(3))
#new data which we based prediciton on
df_newdata = pd.read_csv(os.path.join(path_extracted_data, 'OFH_df_newdata_all.csv'), sep=',')
print(df_newdata.shape)
display(df_newdata.head(3))
#concat both
df = pd.concat([df_newdata, df_pred],axis=1)
print(df.shape)
df.head(3)
# Out:
# (960, 16)
#    Estimate.propindoor_duration_4_Zone  Est.Error.propindoor_duration_4_Zone  \
# 0                             0.079539                              0.065901
# 1                             0.079324                              0.063393
# 2                             0.079481                              0.062893
#
#    Q2.5.propindoor_duration_4_Zone  Q97.5.propindoor_duration_4_Zone  \
# 0                         0.003945                          0.248971
# 1                         0.004271                          0.238376
# 2                         0.004848                          0.239556
#
#    Estimate.propindoor_duration_2_Zone  Est.Error.propindoor_duration_2_Zone  \
# 0                             0.393014                              0.126911
# 1                             0.397306                              0.123558
# 2                             0.413680                              0.131377
#
#    Q2.5.propindoor_duration_2_Zone  Q97.5.propindoor_duration_2_Zone  \
# 0                         0.149292                          0.645349
# 1                         0.171576                          0.654001
# 2                         0.172883                          0.688240
#
#    Estimate.propindoor_duration_3_Zone  Est.Error.propindoor_duration_3_Zone  \
# 0                             0.368143                              0.128143
# 1                             0.368010                              0.128200
# 2                             0.370635                              0.130922
#
#    Q2.5.propindoor_duration_3_Zone  Q97.5.propindoor_duration_3_Zone  \
# 0                         0.145739                          0.637648
# 1                         0.133251                          0.625611
# 2                         0.135075                          0.650195
#
#    Estimate.propindoor_duration_5_Zone  Est.Error.propindoor_duration_5_Zone  \
# 0                             0.159304                              0.096328
# 1                             0.155360                              0.095354
# 2                             0.136204                              0.088643
#
#    Q2.5.propindoor_duration_5_Zone  Q97.5.propindoor_duration_5_Zone
# 0                         0.022160                          0.391735
# 1                         0.019462                          0.368631
# 2                         0.016413                          0.344344
# (960, 3)
#    WIB Treatment    HenID
# 0    1       OFH  hen_131
# 1    5       OFH  hen_131
# 2   10       OFH  hen_131
# (960, 19)
#    WIB Treatment    HenID  Estimate.propindoor_duration_4_Zone  \
# 0    1       OFH  hen_131                             0.079539
# 1    5       OFH  hen_131                             0.079324
# 2   10       OFH  hen_131                             0.079481
#
#    Est.Error.propindoor_duration_4_Zone  Q2.5.propindoor_duration_4_Zone  \
# 0                              0.065901                         0.003945
# 1                              0.063393                         0.004271
# 2                              0.062893                         0.004848
#
#    Q97.5.propindoor_duration_4_Zone  Estimate.propindoor_duration_2_Zone  \
# 0                          0.248971                             0.393014
# 1                          0.238376                             0.397306
# 2                          0.239556                             0.413680
#
#    Est.Error.propindoor_duration_2_Zone  Q2.5.propindoor_duration_2_Zone  \
# 0                              0.126911                         0.149292
# 1                              0.123558                         0.171576
# 2                              0.131377                         0.172883
#
#    Q97.5.propindoor_duration_2_Zone  Estimate.propindoor_duration_3_Zone  \
# 0                          0.645349                             0.368143
# 1                          0.654001                             0.368010
# 2                          0.688240                             0.370635
#
#    Est.Error.propindoor_duration_3_Zone  Q2.5.propindoor_duration_3_Zone  \
# 0                              0.128143                         0.145739
# 1                              0.128200                         0.133251
# 2                              0.130922                         0.135075
#
#    Q97.5.propindoor_duration_3_Zone  Estimate.propindoor_duration_5_Zone  \
# 0                          0.637648                             0.159304
# 1                          0.625611                             0.155360
# 2                          0.650195                             0.136204
#
#    Est.Error.propindoor_duration_5_Zone  Q2.5.propindoor_duration_5_Zone  \
# 0                              0.096328                         0.022160
# 1                              0.095354                         0.019462
# 2                              0.088643                         0.016413
#
#    Q97.5.propindoor_duration_5_Zone
# 0                          0.391735
# 1                          0.368631
# 2                          0.344344

# %% [markdown]
# ## Visual

# %%
df_plt = pd.melt(df, id_vars=['WIB','Treatment','HenID'], value_vars=['Estimate.propindoor_duration_2_Zone', 
                                       'Estimate.propindoor_duration_3_Zone',
                                       'Estimate.propindoor_duration_4_Zone',
                                       'Estimate.propindoor_duration_5_Zone'], value_name = 'prediction')
#match the name fro the raw data
df_plt['variable'] = df_plt['variable'].map(lambda x: x.replace('Estimate.propindoor_dur','propindoor_dur'))
df_plt.head(3)
# Out:
#    WIB Treatment    HenID                    variable  prediction
# 0    1       OFH  hen_131  propindoor_duration_2_Zone    0.393014
# 1    5       OFH  hen_131  propindoor_duration_2_Zone    0.397306
# 2   10       OFH  hen_131  propindoor_duration_2_Zone    0.413680

# %%
fig = plt.figure(figsize=(15, 4))
for i,(v, df_plt_) in enumerate(df_plt.groupby(['variable'])):
    plt.ylim((0,1))
    ax = plt.subplot(1,4,i+1)
    plt.tight_layout()
    #dont show y axis on all plot except the first one
    if i!=0:
        plt.setp(ax.get_yticklabels(), visible=False) 
        sns.lineplot(x='WIB',y='prediction',data=df_plt_, hue='Treatment', palette=pal_tr, legend=False)
        sns.scatterplot(x='WIB',y=v,data=df_raw, hue='Treatment', palette=pal_tr, alpha=0.2, legend=False)
    else:
        sns.lineplot(x='WIB',y='prediction',data=df_plt_, hue='Treatment', palette=pal_tr, legend=False)
        sns.scatterplot(x='WIB',y=v,data=df_raw, hue='Treatment', palette=pal_tr, alpha=0.2, legend=True)
    plt.title(v)
    #plt.show();
plt.savefig(os.path.join(path_extracted_data, name+'_indoozone_proportion_usage.png'),
                dpi=300,format='png',bbox_inches='tight')
plt.show();

# %% [markdown]
# #IN CASE: one plot at a time
# for v, df_plt_ in df_plt.groupby(['variable']):
#     #plt.ylim((0.05,0.5))
#     sns.lineplot('WIB','prediction',data=df_plt_, hue='Treatment', palette=pal_tr)
#     sns.scatterplot('WIB',v,data=df_raw, hue='Treatment', palette=pal_tr, alpha=0.1)
#     plt.title(v)
#     plt.show();
