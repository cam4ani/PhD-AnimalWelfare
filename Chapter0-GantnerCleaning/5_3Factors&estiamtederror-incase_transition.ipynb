# %%
library(lattice) 
library(lme4) #glm and random effect
library(DHARMa) #simulating residuals
library(glmmTMB) #beta regression with mixed effects
library(sjPlot) #tabmodel
# Out:
# Loading required package: Matrix
#
# This is DHARMa 0.3.3.0. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa') Note: Syntax of plotResiduals has changed in 0.3.0, see ?plotResiduals for details
#
# Warning message:
# "package 'glmmTMB' was built under R version 4.0.4"
# Warning message:
# "package 'sjPlot' was built under R version 4.0.4"
# Learn more about sjPlot with 'browseVignettes("sjPlot")'.

# %% [markdown]
# # Weather

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/CleaningAnalysis_/Cleaning/Raw&Cleaned'
df = read.csv(file.path(path_,'environmentalfactorestimatederrorrate.csv'), header = TRUE, sep = ";")
df$hour = as.integer(df$hour)   
df$PenID = as.factor(df$PenID) 
df$system = as.factor(df$system) 
df$humidity_divided_by_10 = df$humidity_avgpercent/10
print(dim(df))
summary(df)
# Out:
# [1] 2614   12
#  Timestamp_weather      PenID          hour           system
#  Length:2614        pen8   :336   Min.   :10.00   10 - 12:997
#  Class :character   pen9   :336   1st Qu.:11.00   3 - 5  :945
#  Mode  :character   pen12  :334   Median :13.00   8 - 9  :672
#                     pen10  :332   Mean   :12.52
#                     pen11  :331   3rd Qu.:14.00
#                     pen4   :321   Max.   :15.00
#                     (Other):624
#   prediction        temperature_C    humidity_avgpercent      IFR
#  Length:2614        Min.   :-6.000   Min.   : 49.00      Min.   : 0.000
#  Class :character   1st Qu.: 1.000   1st Qu.: 72.00      1st Qu.: 0.000
#  Mode  :character   Median : 2.000   Median : 84.00      Median : 1.000
#                     Mean   : 3.062   Mean   : 83.22      Mean   : 2.083
#                     3rd Qu.: 5.000   3rd Qu.: 97.00      3rd Qu.: 2.000
#                     Max.   :14.000   Max.   :100.00      Max.   :29.000
#
#  nbr.registrations estimated.error.rate estimated.transitions
#  Min.   : 1.000    Min.   :0.0000       Min.   : 0.000
#  1st Qu.: 5.000    1st Qu.:0.0000       1st Qu.: 4.000
#  Median : 8.000    Median :0.1111       Median : 6.000
#  Mean   : 8.748    Mean   :0.1834       Mean   : 6.666
#  3rd Qu.:11.000    3rd Qu.:0.3333       3rd Qu.: 9.000
#  Max.   :51.000    Max.   :1.0000       Max.   :37.000
#
#  humidity_divided_by_10
#  Min.   : 4.900
#  1st Qu.: 7.200
#  Median : 8.400
#  Mean   : 8.322
#  3rd Qu.: 9.700
#  Max.   :10.000

# %%
#Generalized linear mixed effect model
fit = glmer(cbind(IFR,nbr.registrations-IFR) ~ humidity_divided_by_10 + temperature_C + hour + (1|system/PenID), 
            family=binomial(link=logit), data=df)
summary(fit)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: cbind(IFR, nbr.registrations - IFR) ~ humidity_divided_by_10 +
#     temperature_C + hour + (1 | system/PenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6402.2   6437.4  -3195.1   6390.2     2608
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7067 -0.7531 -0.4249  0.6219  4.9628
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PenID:system (Intercept) 0.07253  0.2693
#  system       (Intercept) 1.04761  1.0235
# Number of obs: 2614, groups:  PenID:system, 8; system, 3
#
# Fixed effects:
#                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)            -0.756464   0.628938  -1.203 0.229067
# humidity_divided_by_10 -0.038419   0.012862  -2.987 0.002817 **
# temperature_C          -0.034218   0.004559  -7.506  6.1e-14 ***
# hour                   -0.034852   0.010552  -3.303 0.000957 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) h___10 tmpr_C
# hmdty_d__10 -0.226
# temperatr_C -0.019  0.133
# hour        -0.253  0.261 -0.122

# %%
histogram(df$temperature_C)
# Out:
# plot without title

# %%
histogram(df$humidity_divided_by_10)
# Out:
# plot without title

# %%
#save output for paper
#odds interpretations example: https://stackoverflow.com/questions/41384075/r-calculate-and-interpret-odds-ratio-in-logistic-regression
tab_model(fit, file=file.path(path_,'Weather.html'))

# %%
#https://cran.r-project.org/web/packages/glmmTMB/vignettes/model_evaluation.pdf
library(DHARMa)
res <- simulateResiduals(fit)
plot(res)
# Out:
# Plot with title "Residual vs. predicted"

# %% [markdown]
# # Estimated number of transitions

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/CleaningAnalysis_/Cleaning/Raw&Cleaned'
df = read.csv(file.path(path_,'estimatednumbertransitionsestimatederrorrate.csv'), header = TRUE, sep = ";")
df$HenID = as.factor(df$HenID) 
df$PenID = as.factor(df$PenID) 
df$system = as.factor(df$system) 
df$level = as.factor(df$level) 
#6h of WG open
df$Estimated_number_transition_perhour = df$Estimated_number_transition/6
df$Randomprocessing_number_transition = df$Randomprocessing_number_transition/6
print(dim(df))
summary(df)
# Out:
# [1] 7485   15
#      HenID          PenID          system            level
#  hen_1  :  56   pen4   : 972   10 - 12:2863   2020-11-14: 138
#  hen_10 :  56   pen3   : 965   3 - 5  :2839   2020-11-24: 138
#  hen_105:  56   pen10  : 959   8 - 9  :1783   2021-01-10: 138
#  hen_106:  56   pen9   : 955                  2021-01-11: 138
#  hen_108:  56   pen11  : 953                  2020-11-15: 137
#  hen_111:  56   pen12  : 951                  2020-11-16: 137
#  (Other):7149   (Other):1730                  (Other)   :6659
#   prediction        RandomPredictionns      IFR         nbr.registrations
#  Length:7485        Length:7485        Min.   : 0.000   Min.   :  1.00
#  Class :character   Class :character   1st Qu.: 1.000   1st Qu.: 48.00
#  Mode  :character   Mode  :character   Median : 2.000   Median : 76.00
#                                        Mean   : 3.719   Mean   : 77.75
#                                        3rd Qu.: 5.000   3rd Qu.:102.00
#                                        Max.   :51.000   Max.   :282.00
#
#       EER           Randomprocessing_IFR Randomprocessing_nbr_registrations
#  Min.   :0.000000   Min.   : 0.000       Min.   :  1.00
#  1st Qu.:0.005814   1st Qu.: 2.000       1st Qu.: 48.00
#  Median :0.031746   Median : 4.000       Median : 76.00
#  Mean   :0.051831   Mean   : 4.365       Mean   : 77.75
#  3rd Qu.:0.075676   3rd Qu.: 6.000       3rd Qu.:102.00
#  Max.   :0.523810   Max.   :23.000       Max.   :282.00
#
#  Randomprocessing_EER Estimated_number_transition
#  Min.   :0.00000      Min.   : 0.00
#  1st Qu.:0.03540      1st Qu.:21.00
#  Median :0.05376      Median :28.00
#  Mean   :0.05639      Mean   :28.85
#  3rd Qu.:0.07353      3rd Qu.:36.00
#  Max.   :1.00000      Max.   :95.00
#                       NA's   :1
#  Randomprocessing_number_transition Estimated_number_transition_perhour
#  Min.   : 0.000                     Min.   : 0.000
#  1st Qu.: 3.833                     1st Qu.: 3.500
#  Median : 5.333                     Median : 4.667
#  Mean   : 5.503                     Mean   : 4.808
#  3rd Qu.: 7.000                     3rd Qu.: 6.000
#  Max.   :20.333                     Max.   :15.833
#  NA's   :1                          NA's   :1

# %%
histogram(df$Estimated_number_transition_perhour)
# Out:
# plot without title

# %%
#Generalized linear mixed effect model
fit = glmer(cbind(Randomprocessing_IFR,Randomprocessing_nbr_registrations-Randomprocessing_IFR) ~ Randomprocessing_number_transition + (1|system/HenID) + (1|level), 
            family=binomial(link=logit), data=df)
summary(fit)
# Out:
# boundary (singular) fit: see ?isSingular
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: cbind(Randomprocessing_IFR, Randomprocessing_nbr_registrations -
#     Randomprocessing_IFR) ~ Randomprocessing_number_transition +
#     (1 | system/HenID) + (1 | level)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  29989.2  30023.8 -14989.6  29979.2     7479
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7877 -0.7333 -0.0936  0.6139  5.1128
#
# Random effects:
#  Groups       Name        Variance  Std.Dev.
#  HenID:system (Intercept) 0.0007972 0.02823
#  level        (Intercept) 0.0008996 0.02999
#  system       (Intercept) 0.0000000 0.00000
# Number of obs: 7484, groups:  HenID:system, 140; level, 56; system, 3
#
# Fixed effects:
#                                     Estimate Std. Error  z value Pr(>|z|)
# (Intercept)                        -2.716981   0.018042 -150.594  < 2e-16 ***
# Randomprocessing_number_transition -0.017012   0.002702   -6.295 3.07e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr)
# Rndmprcss__ -0.910
# optimizer (Nelder_Mead) convergence code: 0 (OK)
# boundary (singular) fit: see ?isSingular

# %%
#Generalized linear mixed effect model
fit = glmer(cbind(IFR,nbr.registrations-IFR) ~ Estimated_number_transition_perhour + (1|system/HenID) + (1|level), 
            family=binomial(link=logit), data=df)
summary(fit)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# cbind(IFR, nbr.registrations - IFR) ~ Estimated_number_transition_perhour +
#     (1 | system/HenID) + (1 | level)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  34377.2  34411.8 -17183.6  34367.2     7479
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.1023 -0.9834 -0.3902  0.6817 16.9877
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  HenID:system (Intercept) 0.8770   0.9365
#  level        (Intercept) 0.0257   0.1603
#  system       (Intercept) 0.1118   0.3344
# Number of obs: 7484, groups:  HenID:system, 140; level, 56; system, 3
#
# Fixed effects:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         -2.885781   0.212034  -13.61   <2e-16 ***
# Estimated_number_transition_perhour -0.063818   0.004811  -13.27   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr)
# Estmtd_nm__ -0.110

# %%
#https://cran.r-project.org/web/packages/glmmTMB/vignettes/model_evaluation.pdf
library(DHARMa)
res <- simulateResiduals(fit)
plot(res)
# Out:
# Plot with title "Residual vs. predicted"

# %%
#save output for paper
tab_model(fit, file=file.path(path_,'numbertransitions.html'))
