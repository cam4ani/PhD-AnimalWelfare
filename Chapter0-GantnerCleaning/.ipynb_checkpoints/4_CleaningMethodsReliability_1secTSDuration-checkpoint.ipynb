# %%
#install.packages("lubridate")
#install.packages("irr")
#install.packages("readr")
library ('irr')
library("readr")
library("tidyr")
library ('tidyverse')
library ("icr")
library('caret')
library('plyr') #for mapping fct

# %%
#v3_ still good?

# %%
path_records = 'R:\\VPHI\\Welfare\\2- Research Projects\\OFHE2.OriginsE2\\DataOutput\\TrackingSystem\\v3_\\Cleaning'

# %%
#open file
df = read_delim(file.path(path_records,'1secTimeSeries_reliability.csv'),';',trim_ws = TRUE)

#into factor for confusion matrix and test
df[c('ObservedZone','tracking_ObservedZone','model_ObservedZone','binning_zone','PenID')] = lapply(df[c('ObservedZone','tracking_ObservedZone',
                                                                                     'model_ObservedZone','binning_zone','PenID')], factor)
# Out:
# Parsed with column specification:
# cols(
#   Timestamp = col_datetime(format = ""),
#   tracking_ObservedZone = col_character(),
#   model_ObservedZone = col_character(),
#   ObservedZone = col_character(),
#   PenID = col_double(),
#   HenID = col_character(),
#   BatchID = col_character(),
#   VideoAnalyse = col_double(),
#   binning_zone = col_character(),
#   ts_mn = col_datetime(format = ""),
#   tracking_ObservedZone_previous_zone = col_character(),
#   tracking_ObservedZone_tr = col_logical(),
#   model_ObservedZone_previous_zone = col_character(),
#   model_ObservedZone_tr = col_logical(),
#   ObservedZone_previous_zone = col_character(),
#   ObservedZone_tr = col_logical(),
#   binning_zone_previous_zone = col_character(),
#   binning_zone_tr = col_logical()
# )

# %%
################################################################
######################## Tracking system #######################
################################################################

################ reliability
print('------------------------------------------------------------------------------------')
print('----------------------------------- RELIABILITY-------------------------------------')
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
kappa2(df[,c('ObservedZone','tracking_ObservedZone')], "unweighted")
agree(df[,c('ObservedZone','tracking_ObservedZone')], tolerance=0)

#reliability for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(kappa2(df_[,c('ObservedZone','tracking_ObservedZone')], "unweighted"))
    print(agree(df_[,c('ObservedZone','tracking_ObservedZone')], tolerance=0))
    }

################ mismatch
print('------------------------------------------------------------------------------------')
print('------------------------------------- MISMATCH -------------------------------------') 
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
confusionMatrix(df$tracking_ObservedZone, df$ObservedZone)

#mismatch for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(confusionMatrix(df_$tracking_ObservedZone, df_$ObservedZone))
    }
# Out:
# [1] "------------------------------------------------------------------------------------"
# [1] "----------------------------------- RELIABILITY-------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 525299
#    Raters = 2
#     Kappa = 0.996
#
#         z = 1017
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 525299
#    Raters = 2
#   %-agree = 99.9
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 32099
#    Raters = 2
#     Kappa = 0.996
#
#         z = 316
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 32099
#    Raters = 2
#   %-agree = 99.7
# [1] "-------------- pen: 8" "-------------- pen: 9"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 455340
#    Raters = 2
#     Kappa = 0.997
#
#         z = 860
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 455340
#    Raters = 2
#   %-agree = 100
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 37860
#    Raters = 2
#     Kappa = 0.989
#
#         z = 329
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 37860
#    Raters = 2
#   %-agree = 99.2
# [1] "------------------------------------------------------------------------------------"
# [1] "------------------------------------- MISMATCH -------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone   3273     94      0      0      0
#      2Zone      0  41479     11      0      0
#      3Zone      0    370  19426      0      0
#      4Zone      0      0      0  12240      0
#      5Zone      0      0     11      0 448395
#
# Overall Statistics
#
#                Accuracy : 0.9991
#                  95% CI : (0.999, 0.9992)
#     No Information Rate : 0.8536
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9965
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity              1.000000      0.98894      0.99887       1.0000
# Specificity              0.999820      0.99998      0.99927       1.0000
# Pos Pred Value           0.972082      0.99973      0.98131       1.0000
# Neg Pred Value           1.000000      0.99904      0.99996       1.0000
# Prevalence               0.006231      0.07985      0.03702       0.0233
# Detection Rate           0.006231      0.07896      0.03698       0.0233
# Detection Prevalence     0.006410      0.07898      0.03769       0.0233
# Balanced Accuracy        0.999910      0.99446      0.99907       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                0.9999
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.8536
# Detection Rate             0.8536
# Detection Prevalence       0.8536
# Balanced Accuracy          0.9999
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone  1709     0     0     0     0
#      2Zone     0 14397    11     0     0
#      3Zone     0    68  4895     0     0
#      4Zone     0     0     0  6203     0
#      5Zone     0     0    11     0  4805
#
# Overall Statistics
#
#                Accuracy : 0.9972
#                  95% CI : (0.9966, 0.9977)
#     No Information Rate : 0.4506
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9961
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               1.00000       0.9953       0.9955       1.0000
# Specificity               1.00000       0.9994       0.9975       1.0000
# Pos Pred Value            1.00000       0.9992       0.9863       1.0000
# Neg Pred Value            1.00000       0.9962       0.9992       1.0000
# Prevalence                0.05324       0.4506       0.1532       0.1932
# Detection Rate            0.05324       0.4485       0.1525       0.1932
# Detection Prevalence      0.05324       0.4489       0.1546       0.1932
# Balanced Accuracy         1.00000       0.9973       0.9965       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                0.9996
# Pos Pred Value             0.9977
# Neg Pred Value             1.0000
# Prevalence                 0.1497
# Detection Rate             0.1497
# Detection Prevalence       0.1500
# Balanced Accuracy          0.9998
# [1] "-------------- pen: 8" "-------------- pen: 9"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone    302     94      0      0      0
#      2Zone      0  11833      0      0      0
#      3Zone      0      0   4425      0      0
#      4Zone      0      0      0   1488      0
#      5Zone      0      0      0      0 437198
#
# Overall Statistics
#
#                Accuracy : 0.9998
#                  95% CI : (0.9997, 0.9998)
#     No Information Rate : 0.9602
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9973
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity             1.0000000      0.99212     1.000000     1.000000
# Specificity             0.9997934      1.00000     1.000000     1.000000
# Pos Pred Value          0.7626263      1.00000     1.000000     1.000000
# Neg Pred Value          1.0000000      0.99979     1.000000     1.000000
# Prevalence              0.0006632      0.02619     0.009718     0.003268
# Detection Rate          0.0006632      0.02599     0.009718     0.003268
# Detection Prevalence    0.0008697      0.02599     0.009718     0.003268
# Balanced Accuracy       0.9998967      0.99606     1.000000     1.000000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                1.0000
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.9602
# Detection Rate             0.9602
# Detection Prevalence       0.9602
# Balanced Accuracy          1.0000
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone  1262     0     0     0     0
#      2Zone     0 15249     0     0     0
#      3Zone     0   302 10106     0     0
#      4Zone     0     0     0  4549     0
#      5Zone     0     0     0     0  6392
#
# Overall Statistics
#
#                Accuracy : 0.992
#                  95% CI : (0.9911, 0.9929)
#     No Information Rate : 0.4108
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9889
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               1.00000       0.9806       1.0000       1.0000
# Specificity               1.00000       1.0000       0.9891       1.0000
# Pos Pred Value            1.00000       1.0000       0.9710       1.0000
# Neg Pred Value            1.00000       0.9866       1.0000       1.0000
# Prevalence                0.03333       0.4108       0.2669       0.1202
# Detection Rate            0.03333       0.4028       0.2669       0.1202
# Detection Prevalence      0.03333       0.4028       0.2749       0.1202
# Balanced Accuracy         1.00000       0.9903       0.9946       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                1.0000
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.1688
# Detection Rate             0.1688
# Detection Prevalence       0.1688
# Balanced Accuracy          1.0000

# %%
################################################################
############################ Model #############################
################################################################

################ reliability
print('------------------------------------------------------------------------------------')
print('----------------------------------- RELIABILITY-------------------------------------')
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
kappa2(df[,c('ObservedZone','model_ObservedZone')], "unweighted")
agree(df[,c('ObservedZone','model_ObservedZone')], tolerance=0)

#reliability for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(kappa2(df_[,c('ObservedZone','model_ObservedZone')], "unweighted"))
    print(agree(df_[,c('ObservedZone','model_ObservedZone')], tolerance=0))
    }

################ mismatch
print('------------------------------------------------------------------------------------')
print('------------------------------------- MISMATCH -------------------------------------') 
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
confusionMatrix(df$model_ObservedZone, df$ObservedZone)

#mismatch for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(confusionMatrix(df_$model_ObservedZone, df_$ObservedZone))
    }
# Out:
# [1] "------------------------------------------------------------------------------------"
# [1] "----------------------------------- RELIABILITY-------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 525299
#    Raters = 2
#     Kappa = 0.983
#
#         z = 990
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 525299
#    Raters = 2
#   %-agree = 99.6
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 32099
#    Raters = 2
#     Kappa = 0.966
#
#         z = 302
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 32099
#    Raters = 2
#   %-agree = 97.6
# [1] "-------------- pen: 8" "-------------- pen: 9"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 455340
#    Raters = 2
#     Kappa = 0.991
#
#         z = 847
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 455340
#    Raters = 2
#   %-agree = 99.9
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 37860
#    Raters = 2
#     Kappa = 0.953
#
#         z = 309
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 37860
#    Raters = 2
#   %-agree = 96.7
# [1] "------------------------------------------------------------------------------------"
# [1] "------------------------------------- MISMATCH -------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone    956      0      0      0      0
#      2Zone   2317  41943      0      0      0
#      3Zone      0      0  19430      0      0
#      4Zone      0      0      0  12240      0
#      5Zone      0      0     18      0 448395
#
# Overall Statistics
#
#                Accuracy : 0.9956
#                  95% CI : (0.9954, 0.9957)
#     No Information Rate : 0.8536
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9831
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity              0.292087      1.00000      0.99907       1.0000
# Specificity              1.000000      0.99521      1.00000       1.0000
# Pos Pred Value           1.000000      0.94765      1.00000       1.0000
# Neg Pred Value           0.995581      1.00000      0.99996       1.0000
# Prevalence               0.006231      0.07985      0.03702       0.0233
# Detection Rate           0.001820      0.07985      0.03699       0.0233
# Detection Prevalence     0.001820      0.08426      0.03699       0.0233
# Balanced Accuracy        0.646043      0.99760      0.99954       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                0.9998
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.8536
# Detection Rate             0.8536
# Detection Prevalence       0.8536
# Balanced Accuracy          0.9999
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone   956     0     0     0     0
#      2Zone   753 14465     0     0     0
#      3Zone     0     0  4899     0     0
#      4Zone     0     0     0  6203     0
#      5Zone     0     0    18     0  4805
#
# Overall Statistics
#
#                Accuracy : 0.976
#                  95% CI : (0.9742, 0.9776)
#     No Information Rate : 0.4506
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9658
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               0.55939       1.0000       0.9963       1.0000
# Specificity               1.00000       0.9573       1.0000       1.0000
# Pos Pred Value            1.00000       0.9505       1.0000       1.0000
# Neg Pred Value            0.97582       1.0000       0.9993       1.0000
# Prevalence                0.05324       0.4506       0.1532       0.1932
# Detection Rate            0.02978       0.4506       0.1526       0.1932
# Detection Prevalence      0.02978       0.4741       0.1526       0.1932
# Balanced Accuracy         0.77970       0.9786       0.9982       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                0.9993
# Pos Pred Value             0.9963
# Neg Pred Value             1.0000
# Prevalence                 0.1497
# Detection Rate             0.1497
# Detection Prevalence       0.1503
# Balanced Accuracy          0.9997
# [1] "-------------- pen: 8" "-------------- pen: 9"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone      0      0      0      0      0
#      2Zone    302  11927      0      0      0
#      3Zone      0      0   4425      0      0
#      4Zone      0      0      0   1488      0
#      5Zone      0      0      0      0 437198
#
# Overall Statistics
#
#                Accuracy : 0.9993
#                  95% CI : (0.9993, 0.9994)
#     No Information Rate : 0.9602
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9914
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity             0.0000000      1.00000     1.000000     1.000000
# Specificity             1.0000000      0.99932     1.000000     1.000000
# Pos Pred Value                NaN      0.97530     1.000000     1.000000
# Neg Pred Value          0.9993368      1.00000     1.000000     1.000000
# Prevalence              0.0006632      0.02619     0.009718     0.003268
# Detection Rate          0.0000000      0.02619     0.009718     0.003268
# Detection Prevalence    0.0000000      0.02686     0.009718     0.003268
# Balanced Accuracy       0.5000000      0.99966     1.000000     1.000000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                1.0000
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.9602
# Detection Rate             0.9602
# Detection Prevalence       0.9602
# Balanced Accuracy          1.0000
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone     0     0     0     0     0
#      2Zone  1262 15551     0     0     0
#      3Zone     0     0 10106     0     0
#      4Zone     0     0     0  4549     0
#      5Zone     0     0     0     0  6392
#
# Overall Statistics
#
#                Accuracy : 0.9667
#                  95% CI : (0.9648, 0.9685)
#     No Information Rate : 0.4108
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9526
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               0.00000       1.0000       1.0000       1.0000
# Specificity               1.00000       0.9434       1.0000       1.0000
# Pos Pred Value                NaN       0.9249       1.0000       1.0000
# Neg Pred Value            0.96667       1.0000       1.0000       1.0000
# Prevalence                0.03333       0.4108       0.2669       0.1202
# Detection Rate            0.00000       0.4108       0.2669       0.1202
# Detection Prevalence      0.00000       0.4441       0.2669       0.1202
# Balanced Accuracy         0.50000       0.9717       1.0000       1.0000
#                      Class: 5Zone
# Sensitivity                1.0000
# Specificity                1.0000
# Pos Pred Value             1.0000
# Neg Pred Value             1.0000
# Prevalence                 0.1688
# Detection Rate             0.1688
# Detection Prevalence       0.1688
# Balanced Accuracy          1.0000

# %%
################################################################
############################ Binning #############################
################################################################

################ reliability
print('------------------------------------------------------------------------------------')
print('----------------------------------- RELIABILITY-------------------------------------')
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
kappa2(df[,c('ObservedZone','binning_zone')], "unweighted")
agree(df[,c('ObservedZone','binning_zone')], tolerance=0)

#reliability for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(kappa2(df_[,c('ObservedZone','binning_zone')], "unweighted"))
    print(agree(df_[,c('ObservedZone','binning_zone')], tolerance=0))
    }

################ mismatch
print('------------------------------------------------------------------------------------')
print('------------------------------------- MISMATCH -------------------------------------') 
print('------------------------------------------------------------------------------------')

print('-------------- all pen')
confusionMatrix(df$binning_zone, df$ObservedZone)

#mismatch for each systems separately
c_pens = list(c(3,4,5),c(8,9),c(10,11,12))
for (c_pen in c_pens){
    df_ = subset(df, df$PenID %in% c_pen)
    print(paste0('-------------- pen: ',c_pen))
    print(confusionMatrix(df_$binning_zone, df_$ObservedZone))
    }
# Out:
# [1] "------------------------------------------------------------------------------------"
# [1] "----------------------------------- RELIABILITY-------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 525299
#    Raters = 2
#     Kappa = 0.951
#
#         z = 971
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 525299
#    Raters = 2
#   %-agree = 98.7
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 32099
#    Raters = 2
#     Kappa = 0.897
#
#         z = 285
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 32099
#    Raters = 2
#   %-agree = 92.7
# [1] "-------------- pen: 8" "-------------- pen: 9"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 455340
#    Raters = 2
#     Kappa = 0.962
#
#         z = 829
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 455340
#    Raters = 2
#   %-agree = 99.7
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
#  Cohen's Kappa for 2 Raters (Weights: unweighted)
#
#  Subjects = 37860
#    Raters = 2
#     Kappa = 0.887
#
#         z = 295
#   p-value = 0
#  Percentage agreement (Tolerance=0)
#
#  Subjects = 37860
#    Raters = 2
#   %-agree = 91.9
# [1] "------------------------------------------------------------------------------------"
# [1] "------------------------------------- MISMATCH -------------------------------------"
# [1] "------------------------------------------------------------------------------------"
# [1] "-------------- all pen"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone   2840    454    126      0      0
#      2Zone    433  39364   1574     29      0
#      3Zone      0   1942  17251    577    209
#      4Zone      0     62    432  11293    393
#      5Zone      0    121     65    341 447793
#
# Overall Statistics
#
#                Accuracy : 0.9871
#                  95% CI : (0.9868, 0.9874)
#     No Information Rate : 0.8536
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9511
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity              0.867705      0.93851      0.88703      0.92263
# Specificity              0.998889      0.99579      0.99461      0.99827
# Pos Pred Value           0.830409      0.95082      0.86346      0.92718
# Neg Pred Value           0.999170      0.99467      0.99565      0.99815
# Prevalence               0.006231      0.07985      0.03702      0.02330
# Detection Rate           0.005406      0.07494      0.03284      0.02150
# Detection Prevalence     0.006511      0.07881      0.03803      0.02319
# Balanced Accuracy        0.933297      0.96715      0.94082      0.96045
#                      Class: 5Zone
# Sensitivity                0.9987
# Specificity                0.9931
# Pos Pred Value             0.9988
# Neg Pred Value             0.9922
# Prevalence                 0.8536
# Detection Rate             0.8525
# Detection Prevalence       0.8535
# Balanced Accuracy          0.9959
# [1] "-------------- pen: 3" "-------------- pen: 4" "-------------- pen: 5"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone  1439   235   126     0     0
#      2Zone   270 13661   380    29     0
#      3Zone     0   516  4195   194    14
#      4Zone     0     0   200  5884   216
#      5Zone     0    53    16    96  4575
#
# Overall Statistics
#
#                Accuracy : 0.9269
#                  95% CI : (0.924, 0.9298)
#     No Information Rate : 0.4506
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.8974
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               0.84201       0.9444       0.8532       0.9486
# Specificity               0.98812       0.9615       0.9734       0.9839
# Pos Pred Value            0.79944       0.9526       0.8528       0.9340
# Neg Pred Value            0.99109       0.9547       0.9734       0.9876
# Prevalence                0.05324       0.4506       0.1532       0.1932
# Detection Rate            0.04483       0.4256       0.1307       0.1833
# Detection Prevalence      0.05608       0.4467       0.1532       0.1963
# Balanced Accuracy         0.91507       0.9530       0.9133       0.9663
#                      Class: 5Zone
# Sensitivity                0.9521
# Specificity                0.9940
# Pos Pred Value             0.9652
# Neg Pred Value             0.9916
# Prevalence                 0.1497
# Detection Rate             0.1425
# Detection Prevalence       0.1477
# Balanced Accuracy          0.9730
# [1] "-------------- pen: 8" "-------------- pen: 9"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1Zone  2Zone  3Zone  4Zone  5Zone
#      1Zone    261    159      0      0      0
#      2Zone     41  11328    451      0      0
#      3Zone      0    378   3921    163     38
#      4Zone      0     62     53   1325      0
#      5Zone      0      0      0      0 437160
#
# Overall Statistics
#
#                Accuracy : 0.997
#                  95% CI : (0.9969, 0.9972)
#     No Information Rate : 0.9602
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.9618
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity             0.8642384      0.94978     0.886102     0.890457
# Specificity             0.9996506      0.99889     0.998716     0.999747
# Pos Pred Value          0.6214286      0.95838     0.871333     0.920139
# Neg Pred Value          0.9999099      0.99865     0.998882     0.999641
# Prevalence              0.0006632      0.02619     0.009718     0.003268
# Detection Rate          0.0005732      0.02488     0.008611     0.002910
# Detection Prevalence    0.0009224      0.02596     0.009883     0.003162
# Balanced Accuracy       0.9319445      0.97433     0.942409     0.945102
#                      Class: 5Zone
# Sensitivity                0.9999
# Specificity                1.0000
# Pos Pred Value             1.0000
# Neg Pred Value             0.9979
# Prevalence                 0.9602
# Detection Rate             0.9601
# Detection Prevalence       0.9601
# Balanced Accuracy          1.0000
# [1] "-------------- pen: 10" "-------------- pen: 11" "-------------- pen: 12"
# Confusion Matrix and Statistics
#
#           Reference
# Prediction 1Zone 2Zone 3Zone 4Zone 5Zone
#      1Zone  1140    60     0     0     0
#      2Zone   122 14375   743     0     0
#      3Zone     0  1048  9135   220   157
#      4Zone     0     0   179  4084   177
#      5Zone     0    68    49   245  6058
#
# Overall Statistics
#
#                Accuracy : 0.919
#                  95% CI : (0.9162, 0.9217)
#     No Information Rate : 0.4108
#     P-Value [Acc > NIR] : < 2.2e-16
#
#                   Kappa : 0.8869
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: 1Zone Class: 2Zone Class: 3Zone Class: 4Zone
# Sensitivity               0.90333       0.9244       0.9039       0.8978
# Specificity               0.99836       0.9612       0.9487       0.9893
# Pos Pred Value            0.95000       0.9432       0.8651       0.9198
# Neg Pred Value            0.99667       0.9480       0.9644       0.9861
# Prevalence                0.03333       0.4108       0.2669       0.1202
# Detection Rate            0.03011       0.3797       0.2413       0.1079
# Detection Prevalence      0.03170       0.4025       0.2789       0.1173
# Balanced Accuracy         0.95084       0.9428       0.9263       0.9435
#                      Class: 5Zone
# Sensitivity                0.9477
# Specificity                0.9885
# Pos Pred Value             0.9436
# Neg Pred Value             0.9894
# Prevalence                 0.1688
# Detection Rate             0.1600
# Detection Prevalence       0.1696
# Balanced Accuracy          0.9681
