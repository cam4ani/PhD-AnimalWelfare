# %%
#install.packages("MuMIn")
library(MCMCglmm)
library(lme4) #random effect 
#'lmerTest' should be used in place of 'lme4', If lmer model p-values are desired 
library(rptR) 

library(ggplot2)
library(MuMIn) #r.squaredGLMM

library(dplyr) #to work easier with df (%>%)
#install.packages('merTools')
library(merTools) #simulations

#install.packages('optimx') #different optimizer to help model to converge
library(optimx)
# Out:
# Warning message:
# "package 'MCMCglmm' was built under R version 4.0.5"
# Loading required package: Matrix
#
# Loading required package: coda
#
# Warning message:
# "package 'coda' was built under R version 4.0.5"
# Loading required package: ape
#
# Warning message:
# "package 'rptR' was built under R version 4.0.5"
# Warning message:
# "package 'MuMIn' was built under R version 4.0.5"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'merTools' was built under R version 4.0.5"
# Loading required package: arm
#
# Warning message:
# "package 'arm' was built under R version 4.0.5"
# Loading required package: MASS
#
#
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:dplyr':
#
#     select
#
#
#
# arm (Version 1.11-2, built: 2020-7-27)
#
#
# Working directory is C:/Users/camil/Desktop/animals_code/PhD-AnimalWelfare/Chapter1-InterIntraAdaptability
#
#
#
# Attaching package: 'arm'
#
#
# The following object is masked from 'package:ape':
#
#     balance
#
#
# The following object is masked from 'package:coda':
#
#     traceplot
#
#
# Warning message:
# "package 'optimx' was built under R version 4.0.5"

# %% [markdown]
# library(lme4)
# library(arm)
# library(MuMIn)
# library(tidyverse)
# library(plyr)
# library(broom)
# library(coda)
# library(grid)
# library(gridExtra)
# library(brms)
# library(broom.mixed)
# library(merTools)
# library(tidybayes)
# library(parallel)

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
path_adapt = file.path(path_,'Adaptability')
path_model = file.path(path_adapt,'repeatability_model')
df = read.csv(file.path(path_adapt,'df_MVT_4individuality.csv'), header = TRUE, sep = ";")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID) 
df$WIB = as.factor(df$WIB) 
df$TrackingSystemID = as.factor(df$TrackingSystemID) 
#ean-centring of the environmental variable so that intercepts reflect average values for the population and individuals
#df$cDIB = scale(df$temperatute) #TODO
df$cDIB = as.integer(df$DIB) 
df$cDIBfact = as.factor(df$cDIB) 
df$RearingPenID = as.factor(df$RearingPenID) 
df$InitialWeight_kg = df$InitialWeight/1000
print(dim(df))
summary(df)
# Out:
# [1] 5259   42
#  WIB         HenID           DIB            avgDIB         CLASS
#  2:328   hen_1  :  43   Min.   :11.00   Min.   :11.00   Length:5259
#  3:777   hen_105:  43   1st Qu.:23.00   1st Qu.:25.00   Class :character
#  4:874   hen_110:  43   Median :34.00   Median :32.00   Mode  :character
#  5:910   hen_113:  43   Mean   :33.58   Mean   :33.58
#  6:814   hen_114:  43   3rd Qu.:44.00   3rd Qu.:46.00
#  7:910   hen_116:  43   Max.   :54.00   Max.   :52.00
#  8:646   (Other):5001
#              TrackingSystemID     PenID      temperature_C_avg  early_death
#  TrackingSystem 10-12:2138    pen10  : 756   Min.   : 4.000    Min.   :0.0000
#  TrackingSystem 3-5  :1746    pen11  : 756   1st Qu.: 8.667    1st Qu.:0.0000
#  TrackingSystem 8-9  :1375    pen8   : 688   Median :11.000    Median :0.0000
#                               pen9   : 687   Mean   :10.841    Mean   :0.0308
#                               pen12  : 626   3rd Qu.:12.667    3rd Qu.:0.0000
#                               pen4   : 620   Max.   :19.333    Max.   :1.0000
#                               (Other):1126
#  RearingPenID InitialWeight   Treatment         perc_duration_5_Zone
#  1:1190       Min.   :1024   Length:5259        Min.   :  0.00
#  2:1525       1st Qu.:1132   Class :character   1st Qu.: 12.00
#  3:1379       Median :1168   Mode  :character   Median : 32.00
#  4:1165       Mean   :1169                      Mean   : 38.81
#               3rd Qu.:1202                      3rd Qu.: 63.00
#               Max.   :1350                      Max.   :100.00
#
#  perc_duration_3_Zone perc_duration_2_Zone perc_1_Zone_while_WG_open
#  Min.   : 0.00        Min.   : 0.0         Min.   : 0.000
#  1st Qu.: 7.00        1st Qu.:15.0         1st Qu.: 0.000
#  Median :17.00        Median :33.0         Median : 1.619
#  Mean   :18.01        Mean   :32.1         Mean   : 6.889
#  3rd Qu.:27.00        3rd Qu.:47.0         3rd Qu.: 9.983
#  Max.   :70.00        Max.   :95.0         Max.   :91.194
#
#  nbr_stays_2_Zone_perh nbr_stays_3_Zone_perh nbr_stays_5_Zone_perh
#  Min.   :0.000         Min.   :0.0000        Min.   :0.0000
#  1st Qu.:0.500         1st Qu.:0.7143        1st Qu.:0.2000
#  Median :1.083         Median :1.3333        Median :0.3636
#  Mean   :1.117         Mean   :1.3145        Mean   :0.4369
#  3rd Qu.:1.643         3rd Qu.:1.8333        3rd Qu.:0.6000
#  Max.   :5.091         Max.   :5.1818        Max.   :3.1667
#
#  nbr_stays_1_Zone_perh in_WG_15mnAfterOpening distribution_entropy
#  Min.   :0.0000        Length:5259            Min.   :0.000
#  1st Qu.:0.0000        Class :character       1st Qu.:1.286
#  Median :0.1667        Mode  :character       Median :1.630
#  Mean   :0.4320                               Mean   :1.485
#  3rd Qu.:0.6795                               3rd Qu.:1.850
#  Max.   :3.8333                               Max.   :2.286
#
#  SleepingHeight  vertical_travel_distance_perh normalize_perc_duration_5_Zone
#  Min.   :2.000   Min.   : 0.000                Min.   :0.0000
#  1st Qu.:4.000   1st Qu.: 2.286                1st Qu.:0.1930
#  Median :5.000   Median : 3.600                Median :0.5815
#  Mean   :4.515   Mean   : 3.599                Mean   :0.5557
#  3rd Qu.:5.000   3rd Qu.: 4.833                3rd Qu.:0.9394
#  Max.   :5.000   Max.   :13.300                Max.   :0.9997
#
#  normalize_perc_duration_3_Zone normalize_perc_duration_2_Zone
#  Min.   :0.0000                 Min.   :0.0000
#  1st Qu.:0.1011                 1st Qu.:0.2322
#  Median :0.2758                 Median :0.5766
#  Mean   :0.2991                 Mean   :0.5177
#  3rd Qu.:0.4558                 3rd Qu.:0.7982
#  Max.   :0.9836                 Max.   :0.9977
#
#  normalize_perc_1_Zone_while_WG_open normalize_nbr_stays_2_Zone_perh
#  Min.   :0.00000                     Min.   :0.000000
#  1st Qu.:0.00000                     1st Qu.:0.007075
#  Median :0.02509                     Median :0.018206
#  Mean   :0.11210                     Mean   :0.018343
#  3rd Qu.:0.16463                     3rd Qu.:0.027126
#  Max.   :0.93366                     Max.   :0.071541
#
#  normalize_nbr_stays_3_Zone_perh normalize_nbr_stays_5_Zone_perh
#  Min.   :0.00000                 Min.   :0.000000
#  1st Qu.:0.01037                 1st Qu.:0.003027
#  Median :0.02174                 Median :0.005793
#  Mean   :0.02182                 Mean   :0.007106
#  3rd Qu.:0.03073                 3rd Qu.:0.009816
#  Max.   :0.14009                 Max.   :0.078749
#
#  normalize_nbr_stays_1_Zone_perh normalize_in_WG_15mnAfterOpening
#  Min.   :0.000000                Min.   :0.000000
#  1st Qu.:0.000000                1st Qu.:0.000000
#  Median :0.002844                Median :0.000000
#  Mean   :0.007148                Mean   :0.003521
#  3rd Qu.:0.011604                3rd Qu.:0.000000
#  Max.   :0.064748                Max.   :0.031164
#
#  normalize_distribution_entropy normalize_SleepingHeight
#  Min.   :0.00000                Min.   :0.02020
#  1st Qu.:0.01809                1st Qu.:0.05546
#  Median :0.02597                Median :0.07113
#  Mean   :0.02449                Mean   :0.07058
#  3rd Qu.:0.03227                3rd Qu.:0.08296
#  Max.   :0.08728                Max.   :0.99892
#
#  normalize_vertical_travel_distance_perh  tuple_PCA              PC1
#  Min.   :0.00000                         Length:5259        Min.   :-0.69849
#  1st Qu.:0.03361                         Class :character   1st Qu.:-0.45230
#  Median :0.05780                         Mode  :character   Median : 0.11685
#  Mean   :0.05955                                            Mean   : 0.04537
#  3rd Qu.:0.08074                                            3rd Qu.: 0.52226
#  Max.   :0.32522                                            Max.   : 0.71435
#
#  PC1_standardized       cDIB          cDIBfact    InitialWeight_kg
#  Min.   :-1.5171   Min.   :11.00   11     : 130   Min.   :1.024
#  1st Qu.:-1.0150   1st Qu.:23.00   18     : 130   1st Qu.:1.132
#  Median : 0.1458   Median :34.00   19     : 130   Median :1.168
#  Mean   : 0.0000   Mean   :33.58   21     : 130   Mean   :1.169
#  3rd Qu.: 0.9726   3rd Qu.:44.00   22     : 130   3rd Qu.:1.202
#  Max.   : 1.3644   Max.   :54.00   25     : 130   Max.   :1.350
#                                    (Other):4479

# %% [markdown]
# # Models

# %% [raw]
# TODO:
# temporal autocorrlation???!!!https://bbolker.github.io/mixedmodels-misc/notes/corr_braindump.html

# %% [raw]
# "Further, we specify that the mixed model is to be fitted using maximum likelihood (ML) rather than restricted maximum likelihood (REML) with the term REML = FALSEso that models that contain different fixed effects can be compared directly (Zuuret al., 2009)."
# we also added date as a random effect to take accountof the repeated measures at each day.
# "We can evaluate the model fit with an R2function from the MuMIn package(Bartoń, 2018), called r.squaredGLMM, which has been specifically designed for calculating model fit of linear mixed-effects models with a revised statistic (Nakagawa & Schielzeth, 2013; Johnson, 2014)."
# "We can now compare the two models using two methods. The first is to compare the log-likelihoods of the two models and perform a likelihood ratio test (LRT). We can also then balance the goodness-of-fit against the complexity of the
# 14models by comparing AkaikeInformation Criterion (AIC) values to help guide the model selectionprocess. The lower the AIC value, the more parsimonious the fitof the model is to the data."
#
# Interpreting the models outpus
# "Thus, model2 has an improved fit (if LRT better) to the dataand is more parsimonious than model. (If AIC better) "
# "Adding the random intercepts term in model3 explains far more residual variance than model2 without trading-off against increased model complexity: so much so that the p-value for the LRT is essentially zero and the difference in AIC values between model2 and model3 is huge."
# "The value of R2csuggests that the random regression that also allows genotype to vary in quadratic curvature has very marginally improved the model fit over the standard random regression model4 from R2=0.931 to R2= 0.933."
# "The additional complexity of curvature in model5 results in a non-significant LRT p-value and a larger AIC value over model4, so the slight improvement of model fit in terms of R2comes at a cost of model parsimony."
# "At this point, we have compared five models of increasing complexity and quantitatively determined that of these models, model4 is the best model for these data"

# %% [markdown]
# # Behavioural type

# %%
modelBT = lmer(PC1 ~ cDIB + RearingPenID + Treatment + CLASS + InitialWeight_kg + temperature_C_avg + (1|TrackingSystemID/HenID), REML = FALSE, data = df)
summary(modelBT)
r.squaredGLMM(modelBT)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + RearingPenID + Treatment + CLASS + InitialWeight_kg +
#     temperature_C_avg + (1 | TrackingSystemID/HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   4081.2   4160.0  -2028.6   4057.2     5247
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3211 -0.6001  0.0510  0.6671  3.4280
#
# Random effects:
#  Groups                 Name        Variance Std.Dev.
#  HenID:TrackingSystemID (Intercept) 0.097665 0.31251
#  TrackingSystemID       (Intercept) 0.002403 0.04902
#  Residual                           0.115941 0.34050
# Number of obs: 5259, groups:  HenID:TrackingSystemID, 130; TrackingSystemID, 3
#
# Fixed effects:
#                     Estimate Std. Error t value
# (Intercept)       -0.2061352  0.5682937  -0.363
# cDIB               0.0075991  0.0003983  19.079
# RearingPenID2      0.1925332  0.0817652   2.355
# RearingPenID3     -0.1102185  0.0811179  -1.359
# RearingPenID4      0.0306444  0.0862721   0.355
# CLASSMEXP          0.1638741  0.0840686   1.949
# CLASSOther         0.0953209  0.0737908   1.292
# InitialWeight_kg  -0.1584765  0.4727866  -0.335
# temperature_C_avg  0.0044012  0.0015402   2.858
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   RrPID2 RrPID3 RrPID4 CLASSM CLASSO IntlW_
# cDIB        -0.032
# RearngPnID2 -0.315  0.000
# RearngPnID3 -0.261  0.000  0.566
# RearngPnID4 -0.225  0.000  0.530  0.518
# CLASSMEXP   -0.014  0.000  0.031 -0.037 -0.153
# CLASSOther  -0.007  0.000 -0.072 -0.119 -0.119  0.644
# IntlWght_kg -0.988  0.001  0.246  0.197  0.169 -0.067 -0.078
# tmprtr_C_vg -0.036  0.281  0.001  0.000  0.001  0.000  0.000  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Warning message:
# "'r.squaredGLMM' now calculates a revised statistic. See the help page."
#      R2m        R2c
# [1,] 0.09805199 0.5158872

# %%
###### normally distributed residuals
qqnorm(resid(modelBT))
qqline(resid(modelBT))
hist(resid(modelBT))
######check homogeneity of variance (residuals has constant variance)
plot(modelBT)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(modelBT)"
# plot without title

# %%
#repeatabilities
print(VarCorr(modelBT),comp =c("Variance","Std.Dev."))
rep = VarCorr(modelBT)$"HenID:TrackingSystemID"[1]/
(VarCorr(modelBT)$"HenID:TrackingSystemID"[1]+
 VarCorr(modelBT)$"TrackingSystemID"[1]+
 attr(VarCorr(modelBT), "sc")^2) # equal to the varance of residual
#alternatively: 0.1027/(0.1027+0.000086313+0.11594)
rep
# Out:
#  Groups                 Name        Variance  Std.Dev.
#  HenID:TrackingSystemID (Intercept) 0.0976647 0.312514
#  TrackingSystemID       (Intercept) 0.0024034 0.049024
#  Residual                           0.1159410 0.340501
# [1] 0.4521324

# %%
#consistent among pen variation, i.e. if birds PC1 is consistently more or less in some pens
#birds do not show consisten moement variation between pens(PenID explains ~0.04% of the variation in the mvt)
#we may therefore simplify our mode lby removing the random intercept for PenID
VarCorr(modelBT)$"TrackingSystemID"[1]/
(VarCorr(modelBT)$"HenID:TrackingSystemID"[1]+
 VarCorr(modelBT)$"TrackingSystemID"[1]+
 attr(VarCorr(modelBT), "sc")^2)
# Out:
# [1] 0.01112619

# %%
set.seed(1)
simulated = sim(modelBT, n.sim = 1000)
posterior_HenID = apply(simulated@ranef$"HenID:TrackingSystemID"[ , , 1],1,var)
posterior_PenID = apply(simulated@ranef$"TrackingSystemID"[ , , 1],1,var)
posterior_residual  = simulated@sigma^2
#credible interval around our repeatability estimate for individual variation
#on average 49% of the remianing variance (after controlling or ext. temperature, weight and rearing pen identity) 
#in PC1 can be attributed to differences between individuals, suggesting that some birds always have lower PC1 
#compared to other birds, and this differenc eis naot cause by preditable weight, temeprature or rearign pen variation.
quantile(posterior_HenID/
         (posterior_HenID+posterior_PenID+posterior_residual),
         prob=c(0.025, 0.5, 0.975))
quantile(posterior_PenID/
         (posterior_HenID+posterior_PenID+posterior_residual),
         prob=c(0.025, 0.5, 0.975))
# Out:
#      2.5%       50%     97.5%
# 0.4396210 0.4641009 0.4929353
#         2.5%          50%        97.5%
# 0.0004064441 0.0089062859 0.0388882407

# %%
#behavioural type using the "merTools-package to obtain repeated samples from the posterior distribution
#of our model from which we can calculate the standard deviation for each level of the random effect"
randomSims = REsim(modelBT, n.sims = 1000)
head(randomSims[randomSims$groupFctr=="HenID:TrackingSystemID",])
#Use it for visual of behavioural type
# Out:
#   groupFctr              groupID                     term        mean
# 1 HenID:TrackingSystemID hen_1:TrackingSystem 8-9    (Intercept) -0.42389645
# 2 HenID:TrackingSystemID hen_10:TrackingSystem 10-12 (Intercept)  0.04180906
# 3 HenID:TrackingSystemID hen_101:TrackingSystem 3-5  (Intercept)  0.34949988
# 4 HenID:TrackingSystemID hen_102:TrackingSystem 3-5  (Intercept) -0.60861767
# 5 HenID:TrackingSystemID hen_103:TrackingSystem 3-5  (Intercept) -0.26492816
# 6 HenID:TrackingSystemID hen_104:TrackingSystem 3-5  (Intercept) -0.18253796
#   median      sd
# 1 -0.42295057 0.09103791
# 2  0.04325354 0.09916931
# 3  0.34937548 0.08434979
# 4 -0.61061247 0.09724161
# 5 -0.27002260 0.09525568
# 6 -0.18311623 0.09215759

# %%
write.csv(randomSims, file.path(path_,'Adaptability','BehaviouralType.csv'), row.names = FALSE)

# %% [markdown]
# # Plasticity

# %%
#do birds differ in how they shift their general mvements (PC1) across the #days post-transfer to a laying barn?
#individual variation in plasticity
#poly(cDIB, 2, raw = T)

# %%
#only a random intercept for hens
modelPL1 = lmer(PC1 ~ cDIB + RearingPenID + Treatment + CLASS + InitialWeight_kg + temperature_C_avg + (1|HenID), REML = FALSE, data = df,
                control = lmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
summary(modelPL1)
r.squaredGLMM(modelPL1)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + RearingPenID + Treatment + CLASS + InitialWeight_kg +
#     temperature_C_avg + (1 | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   4079.8   4152.1  -2028.9   4057.8     5248
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.3204 -0.5999  0.0487  0.6669  3.4254
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.09985  0.3160
#  Residual             0.11594  0.3405
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                     Estimate Std. Error t value
# (Intercept)       -0.1241492  0.5716055  -0.217
# cDIB               0.0076009  0.0003983  19.084
# RearingPenID2      0.1971658  0.0820462   2.403
# RearingPenID3     -0.1099719  0.0819932  -1.341
# RearingPenID4      0.0323505  0.0864542   0.374
# CLASSMEXP          0.1614697  0.0849657   1.900
# CLASSOther         0.0962189  0.0745859   1.290
# InitialWeight_kg  -0.2244434  0.4762287  -0.471
# temperature_C_avg  0.0044054  0.0015402   2.860
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   RrPID2 RrPID3 RrPID4 CLASSM CLASSO IntlW_
# cDIB        -0.032
# RearngPnID2 -0.322  0.001
# RearngPnID3 -0.262  0.000  0.571
# RearngPnID4 -0.229  0.001  0.522  0.524
# CLASSMEXP   -0.013  0.000  0.031 -0.036 -0.155
# CLASSOther  -0.007  0.000 -0.074 -0.119 -0.121  0.644
# IntlWght_kg -0.990  0.001  0.253  0.198  0.174 -0.069 -0.078
# tmprtr_C_vg -0.036  0.281  0.001  0.000  0.001  0.000  0.000  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#      R2m        R2c
# [1,] 0.09999937 0.5164551

# %%
###### normally distributed residuals
qqnorm(resid(modelPL1))
qqline(resid(modelPL1))
hist(resid(modelPL1))
######check homogeneity of variance (residuals has constant variance)
plot(modelPL1)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(modelPL1)"
# plot without title

# %%
#random interecepts and slopes over DIB for each animal (interactio between DIB and henID as a random effect)
modelPL2 = lmer(PC1 ~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS + temperature_C_avg + (1 + cDIB|HenID), REML = FALSE, data = df,
               control = lmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
summary(modelPL2)
r.squaredGLMM(modelPL2)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS +
#     temperature_C_avg + (1 + cDIB | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   2106.8   2192.2  -1040.4   2080.8     5246
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3728 -0.5697 -0.0141  0.5736  3.7292
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 0.377796 0.6147
#           cDIB        0.000279 0.0167   -0.86
#  Residual             0.072750 0.2697
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                    Estimate Std. Error t value
# (Intercept)       -0.230418   0.570278  -0.404
# cDIB               0.007662   0.001499   5.111
# RearingPenID2      0.205339   0.081610   2.516
# RearingPenID3     -0.104669   0.081547  -1.284
# RearingPenID4      0.033959   0.085996   0.395
# InitialWeight_kg  -0.145155   0.473706  -0.306
# CLASSMEXP          0.163171   0.084509   1.931
# CLASSOther         0.107311   0.074185   1.447
# temperature_C_avg  0.004501   0.001221   3.685
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   RrPID2 RrPID3 RrPID4 IntlW_ CLASSM CLASSO
# cDIB        -0.085
# RearngPnID2 -0.321  0.000
# RearngPnID3 -0.262  0.000  0.571
# RearngPnID4 -0.228  0.000  0.522  0.523
# IntlWght_kg -0.987  0.000  0.253  0.198  0.174
# CLASSMEXP   -0.013  0.000  0.031 -0.037 -0.155 -0.069
# CLASSOther  -0.007  0.000 -0.074 -0.119 -0.121 -0.078  0.644
# tmprtr_C_vg -0.029  0.060  0.001  0.000  0.001  0.000  0.000  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#      R2m       R2c
# [1,] 0.1014671 0.6972298

# %%
###### normally distributed residuals
qqnorm(resid(modelPL2))
qqline(resid(modelPL2))
hist(resid(modelPL2))
######check homogeneity of variance (residuals has constant variance)
plot(modelPL2)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(modelPL2)"
# plot without title

# %%
#assumptions not met!
#test whether a nonlinear random slope over DIB improve model fit
modelPL3 = lmer(PC1 ~ poly(cDIB, 2) + RearingPenID + InitialWeight_kg + Treatment + CLASS + temperature_C_avg + (1 + poly(cDIB, 2)|HenID), REML = FALSE, data = df,
               control = lmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
summary(modelPL3)
r.squaredGLMM(modelPL3)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ poly(cDIB, 2) + RearingPenID + InitialWeight_kg + Treatment +
#     CLASS + temperature_C_avg + (1 + poly(cDIB, 2) | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   1293.0   1404.7   -629.5   1259.0     5242
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2655 -0.5051  0.0169  0.5159  4.1221
#
# Random effects:
#  Groups   Name           Variance  Std.Dev. Corr
#  HenID    (Intercept)      0.10085  0.3176
#           poly(cDIB, 2)1 226.90364 15.0633   0.10
#           poly(cDIB, 2)2  58.84266  7.6709  -0.08 -0.10
#  Residual                  0.05837  0.2416
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                    Estimate Std. Error t value
# (Intercept)        0.088306   0.566025   0.156
# poly(cDIB, 2)1     6.260588   1.345922   4.652
# poly(cDIB, 2)2    -4.241797   0.726718  -5.837
# RearingPenID2      0.198775   0.081293   2.445
# RearingPenID3     -0.098957   0.081226  -1.218
# RearingPenID4      0.028864   0.085662   0.337
# InitialWeight_kg  -0.119767   0.471864  -0.254
# CLASSMEXP          0.164735   0.084180   1.957
# CLASSOther         0.110130   0.073897   1.490
# temperature_C_avg -0.003975   0.001224  -3.249
#
# Correlation of Fixed Effects:
#             (Intr) p(DIB,2)1 p(DIB,2)2 RrPID2 RrPID3 RrPID4 IntlW_ CLASSM
# ply(DIB,2)1  0.004
# ply(DIB,2)2 -0.007 -0.079
# RearngPnID2 -0.322  0.000     0.000
# RearngPnID3 -0.263  0.000     0.000     0.571
# RearngPnID4 -0.229  0.000     0.000     0.522  0.523
# IntlWght_kg -0.990  0.000     0.000     0.253  0.198  0.174
# CLASSMEXP   -0.013  0.000     0.000     0.031 -0.037 -0.155 -0.069
# CLASSOther  -0.008  0.000     0.000    -0.074 -0.119 -0.121 -0.078  0.644
# tmprtr_C_vg -0.024  0.058     0.168     0.001  0.000  0.001  0.000  0.000
#             CLASSO
# ply(DIB,2)1
# ply(DIB,2)2
# RearngPnID2
# RearngPnID3
# RearngPnID4
# IntlWght_kg
# CLASSMEXP
# CLASSOther
# tmprtr_C_vg  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#      R2m       R2c
# [1,] 0.1091753 0.7564996

# %%
###### normally distributed residuals
qqnorm(resid(modelPL3))
qqline(resid(modelPL3))
hist(resid(modelPL3))
######check homogeneity of variance (residuals has constant variance)
plot(modelPL3)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(modelPL3)"
# plot without title

# %%
#compare the log-likelihoods of the two models and perform a likelihood ratio test (LRT).
#Here, we take 2 ×the log-likelihood values from the model summaries to determine a 𝜒+value, 
#and then determine the p-value of the LRT from the 𝜒+value and the difference of the degrees of freedom(df) between the two models using the function 1-pchisq(chi2, df)
#CHECK df difference between models (by looking at the df within the models being compared)
summary(modelPL1)$logLik
summary(modelBT)$logLik
chi2 = 2*(summary(modelBT)$logLik -summary(modelPL1)$logLik)
1-pchisq(chi2,1) # chi2, df
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# 'log Lik.' -2028.921 (df=11)
# 'log Lik.' -2028.582 (df=12)
# 'log Lik.' 0.4105092 (df=12)

# %%
#compare the log-likelihoods of the two models and perform a likelihood ratio test (LRT).
#Here, we take 2 ×the log-likelihood values from the model summaries to determine a 𝜒+value, 
#and then determine the p-value of the LRT from the 𝜒+value and the difference of the degrees of freedom(df) between the two models using the function 1-pchisq(chi2, df)
#CHECK df difference between models (by looking at the df within the models being compared)
summary(modelPL1)$logLik
summary(modelPL2)$logLik
chi2 = 2*(summary(modelPL2)$logLik -summary(modelPL1)$logLik)
1-pchisq(chi2,2) # chi2, df
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# 'log Lik.' -2028.921 (df=11)
# 'log Lik.' -1040.412 (df=13)
# 'log Lik.' 0 (df=13)

# %%
AIC(modelPL1, modelBT,modelPL2)
#--> the more complex model fits better, sugegsting that individuals adapt their mvt differently over the first month in a laying barn
# Out:
#          df AIC
# modelPL1 11 4079.841
# modelBT  12 4081.164
# modelPL2 13 2106.823

# %%
summary(modelPL2)
#the negative correlation of 0.85 between the random intercept and slope indicates that thos individuals which
#had on average a higher PC1 in.... TODO
# Out:
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS +
#     temperature_C_avg + (1 + cDIB | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   2106.8   2192.2  -1040.4   2080.8     5246
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3728 -0.5697 -0.0141  0.5736  3.7292
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 0.377796 0.6147
#           cDIB        0.000279 0.0167   -0.86
#  Residual             0.072750 0.2697
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                    Estimate Std. Error t value
# (Intercept)       -0.230418   0.570278  -0.404
# cDIB               0.007662   0.001499   5.111
# RearingPenID2      0.205339   0.081610   2.516
# RearingPenID3     -0.104669   0.081547  -1.284
# RearingPenID4      0.033959   0.085996   0.395
# InitialWeight_kg  -0.145155   0.473706  -0.306
# CLASSMEXP          0.163171   0.084509   1.931
# CLASSOther         0.107311   0.074185   1.447
# temperature_C_avg  0.004501   0.001221   3.685
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   RrPID2 RrPID3 RrPID4 IntlW_ CLASSM CLASSO
# cDIB        -0.085
# RearngPnID2 -0.321  0.000
# RearngPnID3 -0.262  0.000  0.571
# RearngPnID4 -0.228  0.000  0.522  0.523
# IntlWght_kg -0.987  0.000  0.253  0.198  0.174
# CLASSMEXP   -0.013  0.000  0.031 -0.037 -0.155 -0.069
# CLASSOther  -0.007  0.000 -0.074 -0.119 -0.121 -0.078  0.644
# tmprtr_C_vg -0.029  0.060  0.001  0.000  0.001  0.000  0.000  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
0.379495       /(0.379495+0.000279      +0.072750     )
# Out:
# [1] 0.8386185

# %% [markdown]
# ## save individual values

# %%
summary(modelPL2)
# Out:
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS +
#     temperature_C_avg + (1 + cDIB | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
#      AIC      BIC   logLik deviance df.resid
#   2106.8   2192.2  -1040.4   2080.8     5246
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3728 -0.5697 -0.0141  0.5736  3.7292
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 0.377796 0.6147
#           cDIB        0.000279 0.0167   -0.86
#  Residual             0.072750 0.2697
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                    Estimate Std. Error t value
# (Intercept)       -0.230418   0.570278  -0.404
# cDIB               0.007662   0.001499   5.111
# RearingPenID2      0.205339   0.081610   2.516
# RearingPenID3     -0.104669   0.081547  -1.284
# RearingPenID4      0.033959   0.085996   0.395
# InitialWeight_kg  -0.145155   0.473706  -0.306
# CLASSMEXP          0.163171   0.084509   1.931
# CLASSOther         0.107311   0.074185   1.447
# temperature_C_avg  0.004501   0.001221   3.685
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   RrPID2 RrPID3 RrPID4 IntlW_ CLASSM CLASSO
# cDIB        -0.085
# RearngPnID2 -0.321  0.000
# RearngPnID3 -0.262  0.000  0.571
# RearngPnID4 -0.228  0.000  0.522  0.523
# IntlWght_kg -0.987  0.000  0.253  0.198  0.174
# CLASSMEXP   -0.013  0.000  0.031 -0.037 -0.155 -0.069
# CLASSOther  -0.007  0.000 -0.074 -0.119 -0.121 -0.078  0.644
# tmprtr_C_vg -0.029  0.060  0.001  0.000  0.001  0.000  0.000  0.000
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %% [markdown]
# ## predictions

# %%
df$pred_pop  = predict(modelPL2, re.form = NA)
df$pred_HenID = predict(modelPL2, re.form = ~(1 + cDIB|HenID))
head(df,3)
# Out:
#   WIB HenID   DIB avgDIB CLASS TrackingSystemID     PenID temperature_C_avg
# 1 2   hen_131 11  12     Other TrackingSystem 10-12 pen10 11.50000
# 2 2   hen_131 12  12     Other TrackingSystem 10-12 pen10 10.16667
# 3 2   hen_131 13  12     Other TrackingSystem 10-12 pen10  9.00000
#   early_death RearingPenID ... normalize_SleepingHeight
# 1 0           4            ... 0.07154178
# 2 0           4            ... 0.07035607
# 3 0           4            ... 0.05312489
#   normalize_vertical_travel_distance_perh tuple_PCA                   PC1
# 1 0.03577089                              [[0.69559999 0.08595714]]   0.6956000
# 2 0.02954955                              [[0.69962188 0.01017705]]   0.6996219
# 3 0.04249991                              [[ 0.11685466 -0.0045776 ]] 0.1168547
#   PC1_standardized cDIB cDIBfact InitialWeight_kg pred_pop   pred_HenID
# 1 1.326127         11   11       1.202            -0.1275840 0.5604035
# 2 1.334329         12   12       1.202            -0.1259227 0.5526367
# 3 0.145793         13   13       1.202            -0.1235114 0.5456201

# %%
#save
write.csv(df, file.path(path_,'Adaptability','EstimatedPlasticity.csv'), row.names = FALSE)

# %% [markdown]
# # Rank plasticity & Behavioural type

# %% [raw]
# We will proceed hereafter with model4 to extract the best linear unbiased predictors (BLUPs) for each individual
# "BLUPs estimated from linear mixed-effects regression models fitted in lme4are single point estimates that do not have associated measures of uncertainty. As a result, any derived statistics or formal interpretation of plasticity based on these BLUPs is potentially very dangerous and anti-conservative without properly accounting for estimation uncertainty. For using BLUPs beyond simple ranking (e.g., of the least to most plastic genotypes), we strongly encourage readers to read the references we provide here to avoid the misuse of BLUPs by using a Bayesian MCMC framework (e.g., by using the MCMCglmmpackage in R) to generate estimates of uncertainty around BLUPs (Hadfield, 2010; Hadfieldet al., 2010; Houslay & Wilson, 2017)."

# %% [raw]
# "The BLUP intercept and slope estimates are sometimes correlated. The correlation coefficient is given in the random effects correlation from the model4 summary, which is 0.8."
# "This positive relationship can clearly be seen in Fig. J, where the genotype with the most positive BLUP slope estimate has the highest positive intercept (Fig. J) and has the leastplasticity across growth temperatures (Fig. E): once the population-level average linear slope is added to the BLUP slope estimate, this estimate is closest to zero among all 20 genotypes (Fig. I)"

# %%
set.seed(1)
#REsim already synthesis results compare to the sim(). I verified manually
simulated_individuality = REsim(modelPL2, n.sim = 1000)
simulated_individuality
# Out:
#     groupFctr groupID term        mean          median        sd
# 1   HenID     hen_1   (Intercept) -0.81285986   -0.814168292  0.1389195
# 2   HenID     hen_10  (Intercept) -0.47855723   -0.479924699  0.1499685
# 3   HenID     hen_101 (Intercept)  0.90171887    0.903777971  0.1655860
# 4   HenID     hen_102 (Intercept) -0.39672080   -0.407494115  0.1549947
# 5   HenID     hen_103 (Intercept)  0.00388820    0.005348294  0.1530449
# 6   HenID     hen_104 (Intercept)  0.28137379    0.288238604  0.1461393
# 7   HenID     hen_105 (Intercept) -0.07945147   -0.077231423  0.1445450
# 8   HenID     hen_106 (Intercept) -0.41948210   -0.417335454  0.1484230
# 9   HenID     hen_107 (Intercept) -0.05525149   -0.051688983  0.1545548
# 10  HenID     hen_108 (Intercept)  0.85936696    0.861978279  0.1367136
# 11  HenID     hen_109 (Intercept)  0.54931138    0.548479255  0.1553852
# 12  HenID     hen_110 (Intercept) -0.33663863   -0.335939792  0.1465484
# 13  HenID     hen_111 (Intercept) -0.14206110   -0.136890154  0.1454104
# 14  HenID     hen_112 (Intercept)  0.99974921    1.001221371  0.1409863
# 252 HenID     hen_9   cDIB        -1.655540e-03 -1.783256e-03 0.002290522
# 253 HenID     hen_90  cDIB         1.601039e-02  1.596863e-02 0.002336205
# 254 HenID     hen_91  cDIB        -1.502353e-02 -1.496830e-02 0.001814179
# 255 HenID     hen_92  cDIB        -1.078482e-02 -1.072748e-02 0.002076872
# 256 HenID     hen_94  cDIB         8.936384e-03  9.026165e-03 0.002386771
# 257 HenID     hen_95  cDIB        -1.664890e-02 -1.662943e-02 0.002261462
# 258 HenID     hen_97  cDIB         3.547039e-03  3.644980e-03 0.002242479
# 259 HenID     hen_98  cDIB        -2.428868e-02 -2.424126e-02 0.002112349
# 260 HenID     hen_99  cDIB        -1.895449e-02 -1.890887e-02 0.002131023

# %% [raw]
# "s a reminder, because the population-level average response is negative, the most negative BLUP slope estimates represent steeper reaction norm slopes and hence greater plasticity, andmore positive BLUP slope estimates represent flatter reaction norms and less plasticity in the relative date of flowering in response to growth temperatures"

# %% [raw]
# This negative relationship between the intercepts and slopes estimates shows that hens with the most positive BLUP interccepts has the lowest BLUP slopes estimate and thus the greatest plasticity across # days post-transfer (mine).

# %%
#save
write.csv(simulated_individuality, file.path(path_,'Adaptability','Individuality.csv'), row.names = FALSE)

# %% [markdown]
# # Predictibility

# %%
#install.packages('brms')
library(brms)
# Out:
# Warning message:
# "package 'brms' was built under R version 4.0.5"
# Loading required package: Rcpp
#
# Loading 'brms' package (version 2.16.1). Useful instructions
# can be found by typing help('brms'). A more detailed introduction
# to the package is available through vignette('brms_overview').
#
#
# Attaching package: 'brms'
#
#
# The following object is masked from 'package:MuMIn':
#
#     loo
#
#
# The following object is masked from 'package:lme4':
#
#     ngrps
#
#
# The following object is masked from 'package:MCMCglmm':
#
#     me
#
#
# The following object is masked from 'package:stats':
#
#     ar

# %%
double_model = bf(PC1~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS + temperature_C_avg + (1+cDIB|HenID),
                  sigma~(1|HenID))
m3_brm = brm(double_model, data=df, warmup=200, iter=300, inits="random", seed = 12345) #thin=2, chains=2, warmup=500, iter=3000,
# Out:
# Compiling Stan program...
#
# recompiling to avoid crashing R session
#
# Start sampling
# SAMPLING FOR MODEL '1c99550d0f3c9a0809123a73526d97e6' NOW (CHAIN 1).
# Chain 1:
# Chain 1: Gradient evaluation took 0.002 seconds
# Chain 1: 1000 transitions using 10 leapfrog steps per transition would take 20 seconds.
# Chain 1: Adjust your expectations accordingly!
# Chain 1:
# Chain 1:
# Chain 1: Iteration:   1 / 300 [  0%]  (Warmup)
# Chain 1: Iteration:  30 / 300 [ 10%]  (Warmup)
# Chain 1: Iteration:  60 / 300 [ 20%]  (Warmup)
# Chain 1: Iteration:  90 / 300 [ 30%]  (Warmup)
# Chain 1: Iteration: 120 / 300 [ 40%]  (Warmup)
# Chain 1: Iteration: 150 / 300 [ 50%]  (Warmup)
# Chain 1: Iteration: 180 / 300 [ 60%]  (Warmup)
# Chain 1: Iteration: 201 / 300 [ 67%]  (Sampling)
# Chain 1: Iteration: 230 / 300 [ 76%]  (Sampling)
# Chain 1: Iteration: 260 / 300 [ 86%]  (Sampling)
# Chain 1: Iteration: 290 / 300 [ 96%]  (Sampling)
# Chain 1: Iteration: 300 / 300 [100%]  (Sampling)
# Chain 1:
# Chain 1:  Elapsed Time:
[100%]  (Sampling)
# Chain 4:
# Chain 4:  Elapsed Time: 211.045 seconds (Warm-up)
# Chain 4:                147.139 seconds (Sampling)
# Chain 4:                358.184 seconds (Total)
# Chain 4:
# Warning message:
# "There were 400 transitions after warmup that exceeded the maximum treedepth. Increase max_treedepth above 10. See
# http://mc-stan.org/misc/warnings.html#maximum-treedepth-exceeded"
# Warning message:
# "There were 1 chains where the estimated Bayesian Fraction of Missing Information was low. See
# http://mc-stan.org/misc/warnings.html#bfmi-low"
# Warning message:
# "Examine the pairs() plot to diagnose sampling problems
# "
# Warning message:
# "The largest R-hat is 1.78, indicating chains have not mixed.
# Running the chains for more iterations may help. See
# http://mc-stan.org/misc/warnings.html#r-hat"
# Warning message:
# "Bulk Effective Samples Size (ESS) is too low, indicating posterior means and medians may be unreliable.
# Running the chains for more iterations may help. See
# http://mc-stan.org/misc/warnings.html#bulk-ess"
# Warning message:
# "Tail Effective Samples Size (ESS) is too low, indicating posterior variances and tail quantiles may be unreliable.
# Running the chains for more iterations may help. See
# http://mc-stan.org/misc/warnings.html#tail-ess"

# %%
#m3_brm = readRDS("m3_brm.rds")
summary(m3_brm)
# Out:
# Warning message:
# "Parts of the model have not converged (some Rhats are > 1.05). Be careful when analysing the results! We recommend running more iterations and/or setting stronger priors."
#  Family: gaussian
#   Links: mu = identity; sigma = log
# Formula: PC1 ~ cDIB + RearingPenID + InitialWeight_kg + Treatment + CLASS + temperature_C_avg + (1 + cDIB | HenID)
#          sigma ~ (1 | HenID)
#    Data: df (Number of observations: 5259)
#   Draws: 4 chains, each with iter = 300; warmup = 200; thin = 1;
#          total post-warmup draws = 400
#
# Group-Level Effects:
# ~HenID (Number of levels: 130)
#                     Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS Tail_ESS
# sd(Intercept)           0.56      0.18     0.00     0.69 1.26       12       12
# sd(cDIB)                0.02      0.00     0.01     0.02 1.31       11       13
# sd(sigma_Intercept)     0.51      0.04     0.45     0.59 1.06       39       44
# cor(Intercept,cDIB)    -0.83      0.06    -0.89    -0.61 1.22       28       16
#
# Population-Level Effects:
#                   Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS Tail_ESS
# Intercept            -0.67      0.98    -3.44     0.62 1.28       12       12
# sigma_Intercept      -1.46      0.07    -1.56    -1.26 1.26       20       12
# cDIB                  0.01      0.00     0.00     0.01 1.14       21       15
# RearingPenID2        -5.36      5.81   -17.34     2.32 1.78        6       33
# RearingPenID3        -0.09      0.10    -0.32     0.07 1.21       15       71
# RearingPenID4        -5.57      5.84   -17.68     2.18 1.78        6       33
# InitialWeight_kg      0.25      0.79    -0.75     2.49 1.30       12       12
# TreatmentTRAN         5.61      5.85    -2.09    17.71 1.77        6       33
# CLASSMEXP             0.14      0.09    -0.05     0.31 1.12       25      136
# CLASSOther            0.10      0.07    -0.04     0.24 1.08       47      117
# temperature_C_avg     0.00      0.00    -0.00     0.00 1.02      407      204
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %%
var.res = exp(posterior_samples(m3_brm)$"sd_HenID__sigma_Intercept")^2
mean(var.res);HPDinterval(as.mcmc(var.res),0.95)
# Out:
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# 15   0.054294591 ... -0.5275714
# 16   0.140954039 ... -0.7203531
# 17   0.064263067 ... -0.8147104
# 18   0.010790059 ... -0.6066516
# 19   0.045461235 ... -0.6932629
# 20   0.041831559 ... -0.6045050
# 21   0.046225471 ... -0.7400240
# 22   0.017377361 ... -0.6095934
# 23   0.032412628 ... -0.6249287
# 24   0.040814956 ... -0.6299995
# 25   0.059839915 ... -0.6737462
# 26   0.039495620 ... -0.5289387
# 27   0.039864101 ... -0.6977192
# 28   0.021781166 ... -0.5617792
# 29   0.057906666 ... -0.7279083
# 30   0.062070001 ... -0.5997194
# ... ...              ...
# 371  0.158519040 ... -0.6086521
# 372  0.150722811 ... -0.5943301
# 373  0.165899431 ... -0.5261344
# 374  0.126546295 ... -0.3661542
# 375  0.145586248 ... -0.5823806
# 376  0.213981309 ... -0.5717742
# 377  0.217590028 ... -0.4165831
# 378  0.132037571 ... -0.6469814
# 379  0.111665885 ... -0.7042034
# 380  0.094352006 ... -0.7559877
# 381  0.138606503 ... -0.4478998
# 382  0.125365594 ... -0.8149400
# 383  0.126196427 ... -0.6273428
# 384  0.115781582 ... -0.6411747
# 385  0.014461871 ... -0.6198113
# 386  0.086810716 ... -0.4848250
# 387  0.101040023 ... -0.7583466
# 388  0.117404061 ... -0.4270951
# 389  0.109892361 ... -0.4708036
# 390  0.149299321 ... -0.7270187
# 391  0.134824803 ... -0.5875759
# 392  0.157176352 ... -0.7371524
# 393  0.074073088 ... -0.3712301
# 394 -0.020102735 ... -0.6416942
# 395  0.018835595 ... -0.6985929
# 396  0.007399711 ... -0.4267064
# 397  0.005519402 ... -0.5110219
# 398  0.013848963 ... -0.5932228
# 399 -0.055927224 ... -0.6502842
# 400 -0.076770118 ... -0.6436698
#     r_HenID__sigma[hen_90,Intercept] r_HenID__sigma[hen_91,Intercept]
# 1    0.237523394                     0.35763023
# 2    0.148344860                     0.39055526
# 3    0.073297797                     0.26735870
# 4    0.204339267                     0.09312297
# 5    0.223259237                     0.15887362
# 6    0.116458759                     0.52394001
# 7    0.074896643                     0.46025997
# 8    0.201576413                     0.24892145
# 9    0.101300545                     0.42087728
# 10   0.299230023                     0.43132755
# 11  -0.011392138                     0.30708294
# 12   0.402130370                     0.29812991
# 13   0.304974067                     0.17630809
# 14   0.081262983                     0.54048283
# 15   0.358609985                     0.30293723
# 16   0.159262424                     0.31693440
# 17   0.137744256                     0.35475023
# 18   0.215215066                     0.45660958
# 19   0.258793238                     0.35267711
# 20   0.222557264                     0.40711732
# 21   0.176471994                     0.43191065
# 22   0.008194279                     0.44794882
# 23   0.326731527                     0.24243356
# 24   0.374604103                     0.18031592
# 25   0.082864997                     0.22548903
# 26   0.250054180                     0.38484914
# 27   0.157790073                     0.33161224
# 28   0.233382810                     0.34648182
# 29   0.106563715                     0.31719345
# 30   0.272157134                     0.28864740
# ... ...                              ...
# 371 0.28922076                       0.3743757
# 372 0.32622960                       0.3358058
# 373 0.30787208                       0.3499999
# 399  0.286959726                      0.41178821
# 400  0.149447765                      0.34571099
#     r_HenID__sigma[hen_95,Intercept] r_HenID__sigma[hen_97,Intercept]
# 1   -0.21489234                      -0.03218867
# 2   -0.02820011                      -0.59261666
# 3   -0.27586687                      -0.35610030
# 4   -0.12244638                      -0.39371449
# 5   -0.02299524                      -0.63869863
# 6   -0.36314193                      -0.08068990
# 7   -0.37889311                      -0.08681863
# 8   -0.40419485                      -0.38788190
# 9    0.08933089                      -0.40597848
# 10  -0.08118838                      -0.47714371
# 11  -0.29600510                      -0.35503871
# 12  -0.08619236                      -0.61638324
# 13   0.13373301                      -0.59958831
# 14  -0.43055075                      -0.34973444
# 15  -0.30340021                      -0.71483186
# 16  -0.21101617                      -0.35152969
# 17  -0.11432158                      -0.42374314
# 18  -0.40438053                      -0.28011956
# 19   0.29803800                      -0.42674679
# 20   0.06561655                      -0.22928520
# 21   0.05329533                      -0.24989491
# 22   0.06768895                      -0.32846277
# 23  -0.31950937                      -0.45109647
# 24  -0.30355958                      -0.44068751
# 25  -0.37173348                      -0.41591423
# 26  -0.01338112                      -0.33363771
# 27  -0.26278100                      -0.40694440
# 28  -0.06889141                      -0.38927136
# 29  -0.25161451                      -0.35973386
# 30  -0.06437361                      -0.46220205
# ... ...                              ...
# 371 -0.096362484                     -0.344062172
# 372 -0.072411795                     -0.362951100
# 373 -0.124318005                     -0.475324736
# 374  0.002717034                     -0.296470900
# 375  0.034298185                     -0.269998183
# 376 -0.160193197                     -0.358551037
# 377 -0.185085010                     -0.605991878
# 378 -0.211646577                     -0.090667316
# 379 -0.074462684                     -0.008936348
# 380 -0.162347404                     -0.019648828
# 381 -0.018821278                     -0.637094827
# 382 -0.265459259                     -0.043955160
# 383 -0.160476760                     -0.204749387
# 384 -0.165543292                     -0.497699026
# 385 -0.137596625                     -0.155817113
# 386 -0.230551148                     -0.557878747
# 387 -0.003660391                     -0.199921755
# 388 -0.266508318                     -0.436018893
# 389 -0.302575888                     -0.433518991
# 390 -0.123710350                     -0.340857844
# 391 -0.105325218                     -0.431761688
# 392 -0.187503324                     -0.424964228
# 393 -0.205254694                     -0.405475279
# 394 -0.064560677                     -0.560064179
# 395 -0.254623404                     -0.243084851
# 396 -0.300976801                     -0.280432929
# 397 -0.159579678                     -0.372711378
# 398 -0.128465230                     -0.339453866
# 399 -0.121089394                     -0.358566852
# 400 -0.115739855                     -0.359679044
#     r_HenID__sigma[hen_98,Intercept] r_HenID__sigma[hen_99,Intercept] lp__
# 1   0.008862453                      -0.04492385                      -332.8646
# 2   0.515050129                      -0.39308312                      -348.7896
# 3   0.074139004                      -0.33008141                      -335.9800
# 4   0.281290165                      -0.25627342                      -334.8512
# 5   0.114573459                      -0.17870776                      -355.5388
# 6   0.389843014                      -0.28261830                      -370.8347
# 7   0.370641074                      -0.31255081                      -351.9584
# 8   0.133147710                      -0.12715915                      -342.7406
# 9   0.247499279                      -0.38221534                      -333.3878
# 10  0.215880848                      -0.20634528                      -336.5943
# 11  0.205715022                      -0.32842681                      -325.4139
# 12  0.183056449                      -0.21341600                      -333.3947
# 13  0.080211005                      -0.16860113                      -328.1305
# 14  0.283449251                      -0.39968741                      -337.4992
# 15  0.113177321                      -0.26895202                      -340.7097
# 16  0.137022567                      -0.24415901                      -335.5551
# 17  0.356881206                      -0.23666496                      -334.9595
# 18  0.141073609                      -0.15229663                      -313.6397
# 19  0.402117686                      -0.26930588                      -309.6996
# 20  0.364832483                      -0.09221946                      -315.5677
# 21  0.432291903                      -0.17399510                      -312.7587
# 22  0.086477711                      -0.18797166                      -323.7654
# 23  0.375267093                      -0.17080245                      -313.1452
# 24  0.414776679                      -0.07305902                      -302.7655
# 25  0.225856734                       0.10144065                      -300.3498
# 26  0.211166090                      -0.48635582                      -316.9902
# 27  0.289388079                       0.12024703                      -318.6012
# 28  0.272009910                      -0.37478180                      -330.8458
# 29  0.175662207                      -0.09807036                      -329.1528
# 30  0.121025844                      -0.38594363                      -320.9410
# ... ...                              ...                              ...
# 371 0.2611636                        -0.20082008                      -350.9138
# 372 0.2487869                        -0.10344961                      -330.9043
# 373 0.3739705                        -0.07592799                      -320.5470
# 374 0.3535853                        -0.22411963                      -336.2455
# 375 0.4028214                        -0.25123597                      -317.6830
# 376 0.1753720                        -0.07683662                      -339.8052
# 377 0.3231913                        -0.18903166                      -322.9673
# 378 0.2145974                        -0.31223635                      -341.0690
# 379 0.3192709                        -0.23684039                      -339.7725
# 380 0.3613857                        -0.31682975                      -346.3867
# 381 0.1771373                        -0.09809730                      -343.1288
# 382 0.3099098                        -0.27177963                      -341.3601
# 383 0.2323944                        -0.09135343                      -340.4544
# 384 0.3580447                        -0.31731464                      -350.8977
# 385 0.1387227                        -0.08648328                      -363.2962
# 386 0.2856964                        -0.39807510                      -367.5264
# 387 0.2348476                        -0.06016924                      -357.0373
# 388 0.2156662                        -0.31458495                      -333.5350
# 389 0.1798951                        -0.16394566                      -323.0102
# 390 0.2196771                        -0.26469720                      -334.1512
# 391 0.4526202                        -0.18160666                      -358.4071
# 392 0.3296435                        -0.34207894                      -346.0547
# 393 0.1408921                        -0.18663491                      -348.0342
# 394 0.2023357                        -0.24435754                      -350.6756
# 395 0.4403862                        -0.24370077                      -362.0415
# 396 0.1846963                        -0.37060027                      -339.9316
# 397 0.2078428                        -0.25564737                      -369.3553
# 398 0.2439394                        -0.24296758                      -372.5826
# 399 0.2519129                        -0.39469604                      -342.6273
# 400 0.3210650                        -0.38096163                      -334.2992

# %%
df_pred = posterior_samples(m3_brm)
# Out:
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."

# %%
write.csv(df_pred, file.path(path_,'Adaptability','EstimatedPredictability.csv'), row.names = FALSE)

# %%
405-130
# Out:
# [1] 275

# %%
posterior_samples(m3_brm)[,405-length(unique(df$HenID)):405]
# Out:
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# Error in .subset(x, j): les indices négatifs ne peuvent être mélangés qu'à des 0
# Traceback:
#
# 1. posterior_samples(m3_brm)[, 404 - length(unique(df$HenID)):405]
# 2. `[.data.frame`(posterior_samples(m3_brm), , 404 - length(unique(df$HenID)):405)

# %%
posterior_samples(m3_brm)[,276:405]
# Out:
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
#   r_HenID__sigma[hen_1,Intercept] r_HenID__sigma[hen_10,Intercept]
# 1  0.1657946                      -0.03279148
# 2  0.7523571                       0.62303922
# 3  0.6885952                       0.47856454
# 4 -2.4582295                      -2.80113940
#   r_HenID__sigma[hen_101,Intercept] r_HenID__sigma[hen_102,Intercept]
# 1 -0.41225487                       0.2531721
# 2  1.09573347                       0.3479047
# 3  0.09526898                       0.2015617
# 4  0.39198433                       1.1789295
#   r_HenID__sigma[hen_103,Intercept] r_HenID__sigma[hen_104,Intercept]
# 1  0.1368931                        -0.4037475
# 2 -0.7957929                        -1.4418455
# 3 -0.7173957                         0.3395767
# 4 -0.2030726                        -2.3214755
#   r_HenID__sigma[hen_105,Intercept] r_HenID__sigma[hen_106,Intercept]
# 1  0.1452734                        -0.2177066
# 2  1.1720132                        -0.4324233
# 3 -0.4682242                        -0.7333726
# 4  1.0611909                         1.0945075
#   r_HenID__sigma[hen_107,Intercept] r_HenID__sigma[hen_108,Intercept] ...
# 1 -0.4200689                         0.33913240                       ...
# 2 -0.4238139                        -0.77256166                       ...
# 3 -0.2509807                         0.03930428                       ...
# 4 -0.4933495                        -1.00042910                       ...
#   r_HenID__sigma[hen_89,Intercept] r_HenID__sigma[hen_9,Intercept]
# 1  0.41086821                      -0.25115330
# 2 -1.45873016                       0.05654343
# 3  0.05161266                      -0.32966337
# 4  2.25439954                       0.57371065
#   r_HenID__sigma[hen_90,Intercept] r_HenID__sigma[hen_91,Intercept]
# 1 0.04588597                        0.47131301
# 2 0.60619991                        0.13544063
# 3 0.77620637                       -0.31244553
# 4 2.88917913                       -0.07215873
#   r_HenID__sigma[hen_92,Intercept] r_HenID__sigma[hen_94,Intercept]
# 1  0.43175488                      -0.4712885
# 2 -0.09399944                       0.6167401
# 3 -0.22012630                      -0.2617460
# 4 -0.29599024                       1.9089400
#   r_HenID__sigma[hen_95,Intercept] r_HenID__sigma[hen_97,Intercept]
# 1  0.3987895                        0.1441560
# 2 -1.5413983                       -0.6045164
# 3 -0.4925163                       -0.7226242
# 4  1.1248047                       -1.2177764
#   r_HenID__sigma[hen_98,Intercept] r_HenID__sigma[hen_99,Intercept]
# 1 -0.1771026                        0.3719903
# 2  1.4970981                        0.4466710
# 3  0.6317279                        0.2204447
# 4  3.4700390                       -1.8966866

# %% [markdown]
# posteriorIIV = posterior_samples(m3_brm)[,276:405]%>%
# gather(animal_id, value,
#        "r_animal_id__sigma[elephant1,Intercept]":"r_animal_id__sigma[elephant9,Intercept]")%>%
# separate(animal_id,c(NA,NA,NA,NA,NA,"animal_id",NA),sep = "([\\__\\[\\,])", fill = "right")%>%
# dplyr::left_join(dplyr::select(data, animal_id, Sex))
# #backtransform as calculated on the log scale
# posteriorIIV$value.exp = exp(posteriorIIV$value)
