# %%
library(lindia)
library(tidyverse)
library(caret)
library(sjPlot) #plot estiamte
#library(leaps)
#library(MASS)
#library(lme4) #random effect
library(lmerTest) #like lmer but with p-value
library(effects)#calculate and display model estimates
library(ggplot2)
library(pbkrtest) #backward test for glmer
library(DHARMa) #simulaed residual for glmer

# %%
#install.packages("emmeans")
library(DHARMa)
library(lindia)
library(modEvA)
library(dplyr)
library(lme4) #random effect
library(broom)
library(ggpubr) 
library(rstatix)
library(WRS2) #robust ancova
library(emmeans)
# Out:
# This is DHARMa 0.3.3.0. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa') Note: Syntax of plotResiduals has changed in 0.3.0, see ?plotResiduals for details
#
# Registered S3 methods overwritten by 'car':
#   method                          from
#   influence.merMod                lme4
#   cooks.distance.influence.merMod lme4
#   dfbeta.influence.merMod         lme4
#   dfbetas.influence.merMod        lme4
#
#
# Attaching package: 'rstatix'
#
#
# The following object is masked from 'package:stats':
#
#     filter

# %% [raw]
# "Model assumptions (normality of errors and homoscedasticity) were checked through graphical analysis of residuals.
# For GLMER models, residuals were simulated using package‘DHARMa’(Hartig, 2018).
# The final models were obtained by a stepwise backwards reduction of the full model using parametric bootstrap tests with package ‘pbkrtest’(Halekohand Højsgaard, 2014) for model comparison and a p-value of > 0.05 as the criterion for exclusion.
# The package‘effects’(Fox,2003) was used to calculate and display model estimates."
# pb-modcomp: Model comparison using parametric bootstrap methods.
# "Final model selection for non-random effects followed a  backwards  stepwise  procedure  where  the  most  non-significant  term  in  the  model  was  removed  at  each  step,  three-way  then  two-way  interactions  were  removed  first  followed  by  non-interacting  terms,  until  obtaining  a  final  model  where  terms  that  explained  a  significant  amount  of   variation  were  retained."

# %%
#df_ = df[ which(df$PenID %in% c('pen3','pen4','pen5','pen10','pen11','pen12')), ]

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/correctlightschedule_'
path_adapt = file.path(path_,'Adaptability')
df = read.csv(file.path(path_,'Adaptability_Stat.csv'), header = TRUE, sep = ";")
df$Person_feather = as.factor(df$Person_feather)   
df$Person_toe = as.factor(df$Person_toe) 
df$PenID = as.factor(df$PenID) 
print(dim(df))
summary(df)
# Out:
# [1] 98 42
#     HenID           perc_duration_5_Zone perc_duration_4_Zone
#  Length:98          Length:98            Length:98
#  Class :character   Class :character     Class :character
#  Mode  :character   Mode  :character     Mode  :character
#
#
#
#
#  perc_duration_3_Zone perc_duration_2_Zone
#  Length:98            Length:98
#  Class :character     Class :character
#  Mode  :character     Mode  :character
#
#
#
#
#  percentage_time_outside_while_WG_open latency_1_Zone
#  Length:98                             Length:98
#  Class :character                      Class :character
#  Mode  :character                      Mode  :character
#
#
#
#
#  vertical_travel_distance_perh    nbr_obs      mssd_perc_duration_5_Zone
#  Length:98                     Min.   :37.00   Min.   : 12.93
#  Class :character              1st Qu.:42.00   1st Qu.: 62.70
#  Mode  :character              Median :45.00   Median :100.09
#                                Mean   :43.13   Mean   :123.86
#                                3rd Qu.:45.00   3rd Qu.:140.98
#                                Max.   :45.00   Max.   :472.55
#
#  mean_perc_duration_5_Zone nbr_obs_perc_duration_5_Zone
#  Min.   : 1.805            Min.   :37.00
#  1st Qu.:23.479            1st Qu.:42.00
#  Median :36.589            Median :45.00
#  Mean   :39.646            Mean   :43.13
#  3rd Qu.:53.233            3rd Qu.:45.00
#  Max.   :85.881            Max.   :45.00
#
#  mssd_perc_duration_4_Zone mean_perc_duration_4_Zone
#  Min.   :  1.295           Min.   : 2.786
#  1st Qu.:  7.364           1st Qu.: 5.157
#  Median : 13.577           Median : 6.500
#  Mean   : 20.020           Mean   : 7.628
#  3rd Qu.: 24.702           3rd Qu.: 8.618
#  Max.   :102.110           Max.   :26.156
#
#  nbr_obs_perc_duration_4_Zone mssd_perc_duration_3_Zone
#  Min.   :37.00                Min.   : 0.5366
#  1st Qu.:42.00                1st Qu.:14.0421
#  Median :45.00                Median :20.7393
#  Mean   :43.13                Mean   :25.6216
#  3rd Qu.:45.00                3rd Qu.:34.3400
#  Max.   :45.00                Max.   :96.0698
#
#  mean_perc_duration_3_Zone nbr_obs_perc_duration_3_Zone
#  Min.   : 0.4048           Min.   :37.00
#  1st Qu.:11.1944           1st Qu.:42.00
#  Median :17.5825           Median :45.00
#  Mean   :17.4658           Mean   :43.13
#  3rd Qu.:22.9956           3rd Qu.:45.00
#  Max.   :35.1892           Max.   :45.00
#
#  mssd_perc_duration_2_Zone mean_perc_duration_2_Zone
#  Min.   : 10.96            Min.   : 2.667
#  1st Qu.: 35.50            1st Qu.:20.056
#  Median : 48.44            Median :30.275
#  Mean   : 60.54            Mean   :30.466
#  3rd Qu.: 64.95            3rd Qu.:39.942
#  Max.   :360.03            Max.   :59.022
#
#  nbr_obs_perc_duration_2_Zone mssd_percentage_time_outside_while_WG_open
#  Min.   :37.00                Min.   :  0.000
#  1st Qu.:42.00                1st Qu.:  5.981
#  Median :45.00                Median : 15.635
#  Mean   :43.13                Mean   : 29.142
#  3rd Qu.:45.00                3rd Qu.: 42.401
#  Max.   :45.00                Max.   :141.059
#
#  mean_percentage_time_outside_while_WG_open
#  Min.   : 0.000
#  1st Qu.: 1.581
#  Median : 4.721
#  Mean   : 6.664
#  3rd Qu.: 9.430
#  Max.   :39.060
#
#  nbr_obs_percentage_time_outside_while_WG_open mssd_latency_1_Zone
#  Min.   :36.00                                 Min.   :    0
#  1st Qu.:41.00                                 1st Qu.: 5597
#  Median :44.00                                 Median : 9304
#  Mean   :42.13                                 Mean   : 9782
#  3rd Qu.:44.00                                 3rd Qu.:13978
#  Max.   :44.00                                 Max.   :25925
#
#  mean_latency_1_Zone nbr_obs_latency_1_Zone mssd_vertical_travel_distance_perh
#  Min.   :  0.0       Min.   :36.00          Min.   :0.1375
#  1st Qu.:100.9       1st Qu.:41.00          1st Qu.:0.4823
#  Median :188.0       Median :44.00          Median :0.6576
#  Mean   :177.9       Mean   :42.13          Mean   :0.7220
#  3rd Qu.:262.9       3rd Qu.:44.00          3rd Qu.:0.8270
#  Max.   :377.5       Max.   :44.00          Max.   :2.3857
#
#  mean_vertical_travel_distance_perh nbr_obs_vertical_travel_distance_perh
#  Min.   :0.8834                     Min.   :37.00
#  1st Qu.:2.7511                     1st Qu.:42.00
#  Median :3.6602                     Median :45.00
#  Mean   :3.5607                     Mean   :43.13
#  3rd Qu.:4.2648                     3rd Qu.:45.00
#  Max.   :6.2368                     Max.   :45.00
#
#     severity        Feathers     Pododermatitis   Pododermatitis_bin
#  Min.   : 0.00   Min.   :60.25   Min.   :  0.00   Min.   :0.0000
#  1st Qu.:16.50   1st Qu.:77.50   1st Qu.: 25.00   1st Qu.:1.0000
#  Median :30.00   Median :83.75   Median : 50.00   Median :1.0000
#  Mean   :28.49   Mean   :82.97   Mean   : 71.53   Mean   :0.7653
#  3rd Qu.:37.50   3rd Qu.:89.50   3rd Qu.:121.25   3rd Qu.:1.0000
#  Max.   :70.00   Max.   :97.75   Max.   :265.00   Max.   :1.0000
#
#  BumblefootMax      Bumblefoot     Person_toe Person_feather     PenID
#  Min.   :0.0000   Min.   :0.0000   C:91       Sabine:57      pen10  :14
#  1st Qu.:0.0000   1st Qu.:0.0000   M: 7       Satar :41      pen11  :14
#  Median :0.0000   Median :0.0000                             pen5   :13
#  Mean   :0.0102   Mean   :0.0102                             pen4   :12
#  3rd Qu.:0.0000   3rd Qu.:0.0000                             pen8   :12
#  Max.   :1.0000   Max.   :1.0000                             pen9   :12
#                                                              (Other):21
#   Treatment         nbr_days_4zonevisited nbr_days_nomvt
#  Length:98          Min.   :0.000         Min.   :0.000
#  Class :character   1st Qu.:1.000         1st Qu.:0.000
#  Mode  :character   Median :2.000         Median :0.000
#                     Mean   :1.643         Mean   :0.602
#                     3rd Qu.:3.000         3rd Qu.:1.000
#                     Max.   :3.000         Max.   :3.000

# %% [markdown]
# # Linear mixed effect model

# %% [markdown]
# # Pododermatitis

# %%
hist(df$Pododermatitis)
# Out:
# Plot with title "Histogram of df$Pododermatitis"

# %% [markdown]
# #PBmodcomp from pbkrtest
# fit1 = glmer(Pododermatitis_bin ~  nbr_days_4zonevisited + nbr_obs_perc_duration_5_Zone+(1|PenID), data=df, family=binomial)
# fit2 = glmer(Pododermatitis_bin ~  nbr_days_4zonevisited + (1|PenID), data=df, family=binomial)
# PBmodcomp(fit1,fit2)

# %% [markdown]
# #only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
# #fit_ = glmer(Pododermatitis ~ Person_toe + nbr_obs_perc_duration_5_Zone +nbr_days_4zonevisited + nbr_days_nomvt + Treatment + mean_perc_duration_5_Zone + mean_perc_duration_3_Zone + mean_perc_duration_2_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID), data=df, family=poisson)
# fit_ = glmer(Pododermatitis_bin ~  nbr_days_4zonevisited + (1|PenID), data=df, family=binomial)
# summary(fit_)
# simulationOutput = simulateResiduals(fittedModel = fit_, plot = F)
# plot(simulationOutput)

# %% [markdown]
# #Poisson: not working
# #only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
# #fit_ = glmer(Pododermatitis ~ Person_toe + nbr_obs_perc_duration_5_Zone +nbr_days_4zonevisited + nbr_days_nomvt + Treatment + mean_perc_duration_5_Zone + mean_perc_duration_3_Zone + mean_perc_duration_2_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID), data=df, family=poisson)
# fit_ = glmer(Pododermatitis ~ mean_perc_duration_3_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID),
#            data=df, family=poisson)
# summary(fit_)
# simulationOutput = simulateResiduals(fittedModel = fit_, plot = F)
# plot(simulationOutput)

# %% [markdown]
# ## Feather

# %%
#only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
fit_ = lmerTest::lmer(Feathers ~ Person_feather + nbr_obs_perc_duration_5_Zone +nbr_days_4zonevisited + nbr_days_nomvt + Treatment + mean_perc_duration_5_Zone + mean_perc_duration_3_Zone + mean_perc_duration_2_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID), 
           data=df)
# Backward elimination using terms with default alpha-levels:
step_res = step(fit_)
#show elimination results
step_res
fit = get_model(step_res)
anova(fit)
effCoef(fit)

#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
#Assumptions
###### normally distributed residuals
#qqmath(fit, id=0.05)
qqnorm(resid(fit), main = "Residuals")
qqline(resid(fit))
###### normally of random effects
qqmath(ranef(fit,postVar = TRUE))
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(fit)

#plot estimates
plot_model(fit, vline.color = "red")
# Out:
# Backward reduced random-effect table:
#
#             Eliminated npar  logLik    AIC    LRT Df Pr(>Chisq)
# <none>                   13 -334.19 694.38
# (1 | PenID)          0   12 -336.76 697.51 5.1279  1    0.02354 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Backward reduced fixed-effect table:
# Degrees of freedom method: Satterthwaite
#
#                                            Eliminated Sum Sq Mean Sq NumDF
# Person_feather                                      1   0.49    0.49     1
# Treatment                                           2   1.05    1.05     1
# mean_perc_duration_2_Zone                           3   7.70    7.70     1
# nbr_days_nomvt                                      4   9.90    9.90     1
# mean_vertical_travel_distance_perh                  5  11.03   11.03     1
# mean_perc_duration_5_Zone                           6  10.60   10.60     1
# nbr_obs_perc_duration_5_Zone                        7  25.28   25.28     1
# nbr_days_4zonevisited                               0 258.97  258.97     1
# mean_perc_duration_3_Zone                           0 218.74  218.74     1
# mean_percentage_time_outside_while_WG_open          0 416.97  416.97     1
#                                             DenDF F value   Pr(>F)
# Person_feather                             84.229  0.0086 0.926421
# Treatment                                   5.178  0.0188 0.896226
# mean_perc_duration_2_Zone                  87.487  0.1372 0.711970
# nbr_days_nomvt                             89.048  0.1786 0.673630
# mean_vertical_travel_distance_perh         89.578  0.2011 0.654912
# mean_perc_duration_5_Zone                  89.716  0.1953 0.659615
# nbr_obs_perc_duration_5_Zone                6.695  0.4695 0.516226
# nbr_days_4zonevisited                      93.767  4.8076 0.030808 *
# mean_perc_duration_3_Zone                  89.433  4.0608 0.046891 *
# mean_percentage_time_outside_while_WG_open 89.987  7.7408 0.006577 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Model found:
# Feathers ~ nbr_days_4zonevisited + mean_perc_duration_3_Zone + mean_percentage_time_outside_while_WG_open + (1 | PenID)
#                                            Sum Sq   Mean Sq  NumDF DenDF
# nbr_days_4zonevisited                      258.9715 258.9715 1     93.76744
# mean_perc_duration_3_Zone                  218.7449 218.7449 1     89.43259
# mean_percentage_time_outside_while_WG_open 416.9712 416.9712 1     89.98687
#                                            F value  Pr(>F)
# nbr_days_4zonevisited                      4.807626 0.030808420
# mean_perc_duration_3_Zone                  4.060847 0.046891062
# mean_percentage_time_outside_while_WG_open 7.740780 0.006577286
#                                (Intercept)
#                                 81.6014648
#                      nbr_days_4zonevisited
#                                  1.5782628
#                  mean_perc_duration_3_Zone
#                                 -0.1939506
# mean_percentage_time_outside_while_WG_open
#                                  0.3048927
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: Feathers ~ nbr_days_4zonevisited + mean_perc_duration_3_Zone +
#     mean_percentage_time_outside_while_WG_open + (1 | PenID)
#    Data: df
#
# REML criterion at convergence: 676.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4289 -0.5839  0.1081  0.6450  1.9488
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PenID    (Intercept) 10.63    3.261
#  Residual             53.87    7.339
# Number of obs: 98, groups:  PenID, 8
#
# Fixed effects:
#                                            Estimate Std. Error       df t value
# (Intercept)                                81.60146    2.40303 39.51527  33.958
# nbr_days_4zonevisited                       1.57826    0.71980 93.76744   2.193
# mean_perc_duration_3_Zone                  -0.19395    0.09625 89.43259  -2.015
# mean_percentage_time_outside_while_WG_open  0.30489    0.10959 89.98687   2.782
#                                            Pr(>|t|)
# (Intercept)                                 < 2e-16 ***
# nbr_days_4zonevisited                       0.03081 *
# mean_perc_duration_3_Zone                   0.04689 *
# mean_percentage_time_outside_while_WG_open  0.00658 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) nbr__4 m___3_
# nbr_dys_4zn -0.445
# mn_prc__3_Z -0.583 -0.086
# mn_p____WG_ -0.149  0.030 -0.243
# Warning message in ranef.merMod(fit, postVar = TRUE):
# "'postVar' is deprecated: please use 'condVar' instead"
# $PenID
# Plot with title "Residuals"
# plot without title
# plot without title
# plot without title

# %%
ggscatter(
  df, x = "mean_perc_duration_3_Zone", y = "Feathers",
  color = "PenID", add = "reg.line"
  )+
  stat_regline_equation(
    aes(label =  paste(..eq.label.., ..rr.label.., sep = "~~~~"), color = PenID)
    )
ggsave(file.path(path_adapt,'Feather_mean_perc_duration_3_Zone.png'),width=5, height=5)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggscatter(
  df, x = "nbr_days_4zonevisited", y = "Feathers",
  color = "PenID", add = "reg.line"
  )+
  stat_regline_equation(
    aes(label =  paste(..eq.label.., ..rr.label.., sep = "~~~~"), color = PenID)
    )
ggsave(file.path(path_adapt,'Feather_nbr_days_4zonevisited.png'),width=5, height=5)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggscatter(
  df, x = "mean_percentage_time_outside_while_WG_open", y = "Feathers",
  color = "PenID", add = "reg.line"
  )+
  stat_regline_equation(
    aes(label =  paste(..eq.label.., ..rr.label.., sep = "~~~~"), color = PenID)
    )
ggsave(file.path(path_adapt,'Feather_WG.png'),width=5, height=5)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ## KBF

# %%
hist(df$severity)
# Out:
# Plot with title "Histogram of df$severity"

# %%
#only two groups so treatment as fixed effect (otherwise (1|Treatment/PenID) lead to boundary (singular) fit: see ?isSingular)
fit_ = lmerTest::lmer(severity ~ nbr_obs_perc_duration_5_Zone +nbr_days_4zonevisited + nbr_days_nomvt + Treatment + mean_perc_duration_5_Zone + mean_perc_duration_3_Zone + mean_perc_duration_2_Zone + mean_percentage_time_outside_while_WG_open + mean_vertical_travel_distance_perh + (1|PenID), 
           data=df)
# Backward elimination using terms with default alpha-levels:
step_res = step(fit_)
#show elimination results
step_res
# Out:
# Backward reduced random-effect table:
#
#             Eliminated npar  logLik    AIC   LRT Df Pr(>Chisq)
# <none>                   12 -389.98 803.95
# (1 | PenID)          1   11 -391.06 804.12 2.173  1     0.1405
#
# Backward reduced fixed-effect table:
#                                            Eliminated Df Sum of Sq   RSS    AIC
# mean_perc_duration_2_Zone                           1  1      0.05 18802 533.16
# mean_perc_duration_5_Zone                           2  1     25.09 18827 531.29
# nbr_days_4zonevisited                               3  1     84.59 18912 529.73
# mean_vertical_travel_distance_perh                  4  1    149.05 19061 528.50
# mean_percentage_time_outside_while_WG_open          5  1    160.49 19221 527.32
# mean_perc_duration_3_Zone                           6  1    216.79 19438 526.42
# nbr_days_nomvt                                      7  1    232.00 19670 525.58
# nbr_obs_perc_duration_5_Zone                        8  1    358.17 20028 525.35
# Treatment                                           9  1    404.34 20433 525.31
#                                            F value Pr(>F)
# mean_perc_duration_2_Zone                   0.0002 0.9881
# mean_perc_duration_5_Zone                   0.1188 0.7312
# nbr_days_4zonevisited                       0.4044 0.5265
# mean_vertical_travel_distance_perh          0.7172 0.3993
# mean_percentage_time_outside_while_WG_open  0.7746 0.3811
# mean_perc_duration_3_Zone                   1.0489 0.3084
# nbr_days_nomvt                              1.1219 0.2922
# nbr_obs_perc_duration_5_Zone                1.7299 0.1916
# Treatment                                   1.9381 0.1671
#
# Model found:
# severity ~ 1
