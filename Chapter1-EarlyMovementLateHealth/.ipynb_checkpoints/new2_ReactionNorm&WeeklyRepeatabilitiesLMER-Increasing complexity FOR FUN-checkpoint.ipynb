# %%
#install.packages("MuMIn")
library(MCMCglmm)
library(lme4) #random effect 
#'lmerTest' should be used in place of 'lme4', If lmer model p-values are desired 
library(rptR) 

library(ggplot2)
library(MuMIn) #r.squaredGLMM

library(dplyr) #to work easier with df (%>%)
# Out:
# Warning message:
# "package 'MCMCglmm' was built under R version 4.0.5"
# Loading required package: Matrix
#
# Loading required package: coda
#
# Warning message:
# "package 'coda' was built under R version 4.0.5"
# Loading required package: ape
#
# Warning message:
# "package 'rptR' was built under R version 4.0.5"
# Warning message:
# "package 'MuMIn' was built under R version 4.0.5"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
path_adapt = file.path(path_,'Adaptability')
path_model = file.path(path_adapt,'repeatability_model')
df = read.csv(file.path(path_adapt,'df_MVT_4individuality.csv'), header = TRUE, sep = ";")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID) 
df$WIB = as.factor(df$WIB) 
df$TrackingSystemID = as.factor(df$TrackingSystemID) 
#ean-centring of the environmental variable so that intercepts reflect average values for the population and individuals
#df$cDIB = scale(df$temperatute) #TODO
df$cDIB = as.integer(df$DIB) 
df$cDIBfact = as.factor(df$cDIB) 
df$RearingPenID = as.factor(df$RearingPenID) 
#mean-centre temperatures using the scalefunction, 
#mean-centring of the environmental variable so that intercepts reflect avg values for the population and individuals

#li_var_cont = c('ID0','ID1','ID2','ID3','ID4','ID5','ID6','ID7')
#df$maxsevGap0_divided_maxsev_round = round(df$maxsevGap0_divided_maxsev, 1)
#df$maxsevGap0_divided_maxsev_round_log <- log(df$maxsevGap0_divided_maxsev_round)
#print(as.data.frame(table(df$maxsevGap0_divided_maxsev_round)))
#df_ = df[,c(li_var_cont, 'maxsevGap0_divided_maxsev_round','maxsevGap0_divided_maxsev_round_log')] 
print(dim(df))
summary(df)
# Out:
# [1] 5259   40
#  WIB         HenID           DIB            avgDIB         CLASS
#  2:328   hen_1  :  43   Min.   :11.00   Min.   :11.00   Length:5259
#  3:777   hen_105:  43   1st Qu.:23.00   1st Qu.:25.00   Class :character
#  4:874   hen_110:  43   Median :34.00   Median :32.00   Mode  :character
#  5:910   hen_113:  43   Mean   :33.58   Mean   :33.58
#  6:814   hen_114:  43   3rd Qu.:44.00   3rd Qu.:46.00
#  7:910   hen_116:  43   Max.   :54.00   Max.   :52.00
#  8:646   (Other):5001
#              TrackingSystemID     PenID      temperature_C_avg  early_death
#  TrackingSystem 10-12:2138    pen10  : 756   Min.   : 4.000    Min.   :0.0000
#  TrackingSystem 3-5  :1746    pen11  : 756   1st Qu.: 8.667    1st Qu.:0.0000
#  TrackingSystem 8-9  :1375    pen8   : 688   Median :11.000    Median :0.0000
#                               pen9   : 687   Mean   :10.841    Mean   :0.0308
#                               pen12  : 626   3rd Qu.:12.667    3rd Qu.:0.0000
# ...

# %% [markdown]
# # Models

# %% [raw]
# TODO:
# RearingPenID? annoying to prediction after... which one to use?
# temporal autocorrlation???!!!https://bbolker.github.io/mixedmodels-misc/notes/corr_braindump.html

# %% [raw]
# ADD initial conditions: rearing penID; initial weight ; class

# %% [raw]
# "Further, we specify that the mixed model is to be fitted using maximum likelihood (ML) rather than restricted maximum likelihood (REML) with the term REML = FALSEso that models that contain different fixed effects can be compared directly (Zuuret al., 2009)."
# we also added date as a random effect to take accountof the repeated measures at each day.
# "We can evaluate the model fit with an R2function from the MuMIn package(Bartoń, 2018), called r.squaredGLMM, which has been specifically designed for calculating model fit of linear mixed-effects models with a revised statistic (Nakagawa & Schielzeth, 2013; Johnson, 2014)."
# "We can now compare the two models using two methods. The first is to compare the log-likelihoods of the two models and perform a likelihood ratio test (LRT). We can also then balance the goodness-of-fit against the complexity of the
# 14models by comparing AkaikeInformation Criterion (AIC) values to help guide the model selectionprocess. The lower the AIC value, the more parsimonious the fitof the model is to the data."
#
# Interpreting the models outpus
# "Thus, model2 has an improved fit (if LRT better) to the dataand is more parsimonious than model. (If AIC better) "
# "Adding the random intercepts term in model3 explains far more residual variance than model2 without trading-off against increased model complexity: so much so that the p-value for the LRT is essentially zero and the difference in AIC values between model2 and model3 is huge."
# "The value of R2csuggests that the random regression that also allows genotype to vary in quadratic curvature has very marginally improved the model fit over the standard random regression model4 from R2=0.931 to R2= 0.933."
# "The additional complexity of curvature in model5 results in a non-significant LRT p-value and a larger AIC value over model4, so the slight improvement of model fit in terms of R2comes at a cost of model parsimony."
# "At this point, we have compared five models of increasing complexity and quantitatively determined that of these models, model4 is the best model for these data"

# %%
#"Let us first fit a simple linear mixed model and observe the average population-level reaction norm."
model1 = lmer(PC1 ~ cDIB + temperature_C_avg + InitialWeight + (1|WIB) + (1|PenID), REML = FALSE, data = df)
#"So, let us fit a quadratic fixed-effect of temperature to model to these data"
model2 = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg + InitialWeight + (1|WIB) + (1|PenID), REML = FALSE, data = df)
#"To further develop the model, the overall population-level reaction norm as model2is kept the same, but with an
#additional term of(1|genotype),which specifies that we are allowing the 𝑦-intercept value to vary among genotypes."
model3.a = lmer(PC1 ~ cDIB + temperature_C_avg + InitialWeight + (1|WIB) + (1|PenID/HenID), REML = FALSE, data = df)
model3.b = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg + InitialWeight + (1|WIB) + (1|PenID/HenID), REML = FALSE, data = df)
#To evaluate whether model fit can be improved further, we can allow the slopes of genotypes to vary in addition to the 
#intercepts, allowing the slopes of the random HenID regressions to vary across #days post-transfer. 
#"Thus, the random component of the random regression mixed model is now written as (1+ctemperature|genotype), which specifies 
#that the random component that genotype can vary both in intercept and in slope"
model4 = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg + InitialWeight + (1|WIB) + (1+cDIB|PenID/HenID), REML = FALSE, data = df)
#Afinal attempt to improve the model fit is to allow the random effect of genotypeto vary in not only intercept and slope, 
#but also in curvature, by fitting an additionalquadratic random effect term.
model5.a = lmer(PC1 ~ cDIB + temperature_C_avg+ (1|WIB) + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)
model5.b = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg + InitialWeight + (1|WIB) + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)
model5.c = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg + InitialWeight + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)

# %% [markdown]
# model5.c = lmer(PC1 ~ poly(cDIB, 2, raw = T) + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)

# %% [markdown]
# #smal summary to view all
# summary(model)$logLik
# summary(model2)$logLik
# summary(model3.a)$logLik
# summary(model3.b)$logLik
# summary(model4)$logLik
# summary(model5.a)$logLik
# summary(model5.b)$logLik
# summary(model5.c)$logLik
# print('test')
# chi2 = 2*(summary(model2)$logLik -summary(model)$logLik)
# 1-pchisq(chi2, 1)
# chi2 = 2*(summary(model3.b)$logLik -summary(model3.a)$logLik)
# 1-pchisq(chi2, 1)
# chi2 = 2*(summary(model3.b)$logLik -summary(model2)$logLik)
# 1-pchisq(chi2, 1)
# chi2 = 2*(summary(model4)$logLik -summary(model3.b)$logLik)
# 1-pchisq(chi2, 1)
# chi2 = 2*(summary(model5.b)$logLik -summary(model5.a)$logLik)
# 1-pchisq(chi2, 0)
# chi2 = 2*(summary(model5.b)$logLik -summary(model4)$logLik)
# 1-pchisq(chi2, 0)
# chi2 = 2*(summary(model5.b)$logLik -summary(model5.c)$logLik)
# 1-pchisq(chi2, 0)
# AIC(model, model2, model3.a, model3.b, model4, model5.a, model5.b, model5.c)

# %% [markdown]
# ### model 1

# %%
model1 = lmer(PC1 ~ cDIB + RearingPenID + temperature_C_avg + InitialWeight + (1|PenID), REML = FALSE, data = df)
summary(model1)
r.squaredGLMM(model1)
# Out:
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1 ~ cDIB + temperature_C_avg + InitialWeight + (1 | PenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6914.4   6953.8  -3451.2   6902.4     5253
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1243 -0.9359  0.1241  0.8793  2.2213
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PenID    (Intercept) 0.01614  0.127
#  Residual             0.21625  0.465
# Number of obs: 5259, groups:  PenID, 8
#
# Fixed effects:
#                     Estimate Std. Error t value
# (Intercept)       -3.612e-01  1.380e-01  -2.618
# cDIB               7.582e-03  5.439e-04  13.941
# temperature_C_avg  4.520e-03  2.103e-03   2.149
# InitialWeight      8.503e-05  1.078e-04   0.789
#
# Correlation of Fixed Effects:
#             (Intr) cDIB   tmp_C_
# cDIB        -0.179
# tmprtr_C_vg -0.204  0.281
# InitialWght -0.914  0.000  0.002
#      R2m        R2c
# ...

# %%
###### normally distributed residuals
qqnorm(resid(model1))
qqline(resid(model1))
hist(resid(model1))
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(model1)
# Out:
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(model1)"
# plot without title

# %%
#visually assess how well the lm model fits the raw data by overlaying the regression line from
#model as an average population-level reaction norm.
#predict PC1 across the DIB, and plot the fixed effect of #days post-transfer over the raw individuals' reactions norms.
cDIB_pred = data.frame(cDIB = seq(from = min(df$cDIB), to = max(df$cDIB), length.out = max(df$cDIB)-min(df$cDIB)+1),
                      temperature_C_avg = rep(mean(df$temperature_C_avg), max(df$cDIB)-min(df$cDIB)+1),
                      InitialWeight = rep(mean(df$InitialWeight), max(df$cDIB)-min(df$cDIB)+1))
cDIB_pred$fit = predict(model1, newdata = cDIB_pred, re.form = NA)
# Plot the raw data and overlay the fit of Model
ggplot(cDIB_pred, aes(x = cDIB, y = fit)) +
geom_line(data = df, aes(y = PC1)) +
geom_line(size = 2) +
ylab("average vertical travel distance") + xlab("Mean-centred number of days post-transfer") +
theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### model 2

# %%
#fit a quadratic fixed-effect of #days-post transfer to model to these data (3 would be cubic)
model2 = lmer(PC1 ~ poly(cDIB, 2, raw = T) + temperature_C_avg  +(1|WIB) + (1|PenID), REML = FALSE, data = df)
summary(model2)
r.squaredGLMM(model2)
# Out:
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1_standardized ~ poly(cDIB, 2, raw = T) + temperature_C_avg +
#     (1 | WIB) + (1 | PenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   8545.0   8587.3  -4265.5   8531.0     3106
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.0680 -0.8410 -0.1930  0.9588  1.9935
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  WIB      (Intercept) 0.01410  0.1187
#  PenID    (Intercept) 0.02297  0.1515
#  Residual             0.89961  0.9485
# Number of obs: 3113, groups:  WIB, 8; PenID, 4
#
# Fixed effects:
#                           Estimate Std. Error t value
# (Intercept)              0.5925167  0.1724628   3.436
# poly(cDIB, 2, raw = T)1 -0.0337223  0.0099297  -3.396
# poly(cDIB, 2, raw = T)2  0.0003384  0.0001709   1.980
# temperature_C_avg        0.0041362  0.0073024   0.566
#
# Correlation of Fixed Effects:
#               (Intr) p(DIB,2,r=T)1 p(DIB,2,r=T)2
# ...

# %%
cDIB_pred$fit1.2 = predict(model2, newdata = cDIB_pred, re.form = NA)
ggplot(cDIB_pred, aes(x = cDIB, y = fit1.2)) +
geom_line(data = df, aes(y = PC1)) +
geom_line(size = 2) +
ylab("average vertical travel distance") + xlab("Mean-centred number of days post-transfer") +
theme_classic()
# Out:
# plot without title

# %%
#compare the log-likelihoods of the two models and perform a likelihood ratio test (LRT).
#Here, we take 2 ×the log-likelihood values from the model summaries to determine a 𝜒+value, 
#and then determine the p-value of the LRT from the 𝜒+value and the difference of the degrees of freedom(df) between the two models using the function 1-pchisq(chi2, df)
#CHECK df difference between models (by looking at the df within the models being compared)
summary(model)$logLik
summary(model2)$logLik
chi2 = 2*(summary(model2)$logLik -summary(model)$logLik)
1-pchisq(chi2,1) # chi2, df
AIC(model, model2)
#--> not clear R2 did not change test say yes. try both in the model 3
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# Error in h(simpleError(msg, call)): erreur d'évaluation de l'argument 'object' lors de la sélection d'une méthode pour la fonction 'summary' : objet 'model' introuvable
# Traceback:
#
# 1. summary(model)
# 2. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "objet 'model' introuvable",
#  .     base::quote(summary(model)))
# 3. h(simpleError(msg, call))

# %% [markdown]
# ### model 3

# %%
#random intercept model with "the overall population-level reaction norm as model2is kept the same"
#model3 = lmer(PC1 ~ poly(cDIB, 2, raw = T) + (1|cDIBfact) + (1|PenID/HenID), REML = FALSE, data = df)
model3.a = lmer(PC1 ~ cDIB + temperature_C_avg + (1|WIB) + (1|PenID/HenID), REML = FALSE, data = df)
summary(model3.a)
r.squaredGLMM(model3.a)

# %%
model3.b = lmer(PC1 ~ poly(cDIB, 2, raw = T) + (1|WIB) + (1|PenID/HenID), REML = FALSE, data = df)
summary(model3.b)
r.squaredGLMM(model3.b)

# %%
#CHECK df difference between models (by looking at the df within the models being compared)
summary(model2)$logLik
summary(model3.a)$logLik
summary(model3.b)$logLik
chi2 = 2*(summary(model3.b)$logLik -summary(model3.a)$logLik)
1-pchisq(chi2, 1)
chi2 = 2*(summary(model3.b)$logLik -summary(model2)$logLik)
1-pchisq(chi2, 0)
AIC(model, model2, model3.a, model3.b)
#"Adding the random intercepts term in model3 explains far more residual variance than model2 without trading-off against increased model complexity: so much so that the p-value for the LRT is essentially zero and the difference in AIC values between model2 and model3 is huge.""

# %%
model3 = model3.a

# %%
cDIB_pred$fit1.3 = predict(model3, newdata = cDIB_pred, re.form = NA)
df$pred_pop1.3  = predict(model3, re.form = NA)
df$pred_HenID1.3 = predict(model3, re.form = ~(1|PenID/HenID))

# %%
li_selected_hen = c('hen_131', 'hen_134', 'hen_138', 'hen_139', 'hen_140')
li_selected_henpens = c('hen_131:pen10', 'hen_134:pen10', 'hen_138:pen10', 'hen_139:pen10', 'hen_140:pen10')
df_plot = df[ which(df$HenID %in% li_selected_hen), ]

# %%
ggplot(cDIB_pred, aes(x = cDIB, y = fit1.3)) +
geom_line(data = df_plot, 
          aes(y = pred_HenID1.3, group = HenID, colour = HenID), lty = 2) +
geom_line(data = df_plot, 
          aes(y = PC1, group = HenID, colour = HenID)) +
geom_line(size = 2) +
ylab("average vertical travel distance") + xlab("Mean-centred number of days post-transfer") +
theme_classic()

# %% [markdown]
# ### model 4

# %%
model4 = lmer(PC1 ~ poly(cDIB, 2, raw = T)+ temperature_C_avg + (1|WIB) + (1+cDIB|PenID/HenID), REML = FALSE, data = df)
summary(model4)
r.squaredGLMM(model3)

# %%
`%notin%` = Negate(`%in%`)
#df_plot$HenIDcolors = df_plot$HenID
#df_plot$HenIDcolors = replace(df_plot$HenIDcolors, df_plot$HenIDcolors %notin% li_selected_henpens, "#FF6666")
#choose color
#http://www.stat.columbia.edu/~tzheng/files/Rcolor.pdf find color

# %%
cDIB_pred$fit1.4 = predict(model4, newdata = cDIB_pred, re.form = NA)
df$pred_pop1.4  = predict(model4, re.form = NA)
df$pred_HenID1.4 = predict(model4, re.form = ~(1+cDIB|PenID/HenID))

# %%
li_selected_hen = c('hen_131', 'hen_134', 'hen_138', 'hen_139', 'hen_140')
li_selected_henpens = c('hen_131:pen10', 'hen_134:pen10', 'hen_138:pen10', 'hen_139:pen10', 'hen_140:pen10')
df_plot = df[ which(df$HenID %in% li_selected_hen), ]

# %%
ggplot(cDIB_pred, aes(x = cDIB, y = fit1.4)) +
geom_line(data = df_plot,
          aes(y = pred_HenID1.4, group = HenID, colour = HenID), lty = 2) +
geom_line(data = df_plot,
          aes(y = PC1, group = HenID, colour = HenID)) + 
geom_line(size = 2) +
ylab("average vertical travel distance") + xlab("Mean-centred number of days post-transfer") +
theme_classic()
#ggsave(file.path(path_,'Adaptability','IndividualPlasticity.png'),width=12, height=4, bg = "transparent")

# %%
chi2 <-2*(summary(model4)$logLik -summary(model3)$logLik)
summary(model3)$logLik
summary(model4)$logLik
1-pchisq(chi2, 5)
AIC(model, model2, model3, model4)

# %%
#save
write.csv(df, file.path(path_,'Adaptability','IndividualPlasticity.csv'), row.names = FALSE)

# %% [markdown]
# ### model 5

# %%
model5 = lmer(PC1 ~ cDIB + temperature_C_avg + (1|WIB) + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)
summary(model5)
r.squaredGLMM(model5)
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "unable to evaluate scaled gradient"
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge: degenerate  Hessian with 2 negative eigenvalues"
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1_standardized ~ cDIB + temperature_C_avg + (1 | WIB) + (1 +
#     cDIB + I(cDIB^2) | PenID/HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  11346.8  11461.0  -5656.4  11312.8     6088
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.8121 -0.5653 -0.0062  0.5278  4.6302
#
# Random effects:
#  Groups      Name        Variance  Std.Dev. Corr
#  HenID:PenID (Intercept) 5.447e-01 0.738040
#              cDIB        3.978e-03 0.063068 -0.34
#              I(cDIB^2)   1.497e-06 0.001223  0.12 -0.93
#  PenID       (Intercept) 2.044e-01 0.452121
# ...

# %% [markdown]
# OR?? TODO

# %%
model5 = lmer(PC1 ~ poly(cDIB, 2, raw = T) + (1|WIB) + (1 + cDIB + I(cDIB^2)|PenID/HenID), REML = FALSE, data = df)
summary(model5)
r.squaredGLMM(model5)
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "unable to evaluate scaled gradient"
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge: degenerate  Hessian with 4 negative eigenvalues"
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: PC1_standardized ~ poly(cDIB, 2, raw = T) + (1 | WIB) + (1 +
#     cDIB + I(cDIB^2) | PenID/HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   5971.0   6073.7  -2968.5   5937.0     3096
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.7781 -0.5595 -0.0224  0.5906  4.0056
#
# Random effects:
#  Groups      Name        Variance  Std.Dev. Corr
#  HenID:PenID (Intercept) 4.500e-01 0.670800
#              cDIB        7.449e-02 0.272934 -0.21
#              I(cDIB^2)   3.116e-05 0.005582  0.16 -1.00
#  WIB         (Intercept) 1.819e-01 0.426525
#  PenID       (Intercept) 2.956e-01 0.543650
# ...

# %%
chi2 = 2*(summary(model5)$logLik -summary(model4)$logLik)
summary(model4)$logLik
summary(model5)$logLik
1-pchisq(chi2, 5)
AIC(model, model2, model3, model4, model5)
# Out:
# Error in h(simpleError(msg, call)): erreur d'évaluation de l'argument 'object' lors de la sélection d'une méthode pour la fonction 'summary' : objet 'model4' introuvable
# Traceback:
#
# 1. summary(model4)
# 2. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "objet 'model4' introuvable",
#  .     base::quote(summary(model4)))
# 3. h(simpleError(msg, call))

# %% [markdown]
# # Rank plasticity

# %%
TODO link it with health: 
if link with rank: perfect.
if no link with ranked and value we perhaps dont care and keep ranked only, if only assocation with value, we
must copute uncertainty and remove the uncertain observation perhaps?

# %% [raw]
# "We will proceed hereafter with model4 to demonstrate how a random regression model can be used to rank plasticity, if desired, by extracting the best linear unbiased predictors (BLUPs) for each genotype."
# "BLUPs estimated from linear mixed-effects regression models fitted in lme4are single point estimates that do not have associated measures of uncertainty. As a result, any derived statistics or formal interpretation of plasticity based on these BLUPs is potentially very dangerous and anti-conservative without properly accounting for estimation uncertainty. For using BLUPs beyond simple ranking (e.g., of the least to most plastic genotypes), we strongly encourage readers to read the references we provide here to avoid the misuse of BLUPs by using a Bayesian MCMC framework (e.g., by using the MCMCglmmpackage in R) to generate estimates of uncertainty around BLUPs (Hadfield, 2010; Hadfieldet al., 2010; Houslay & Wilson, 2017)."

# %% [raw]
# TODO
# "The BLUP intercept and slope estimates are sometimes correlated. The correlation coefficient is given in the random effects correlation from the model4 summary, which is 0.8."
# "This positive relationship can clearly be seen in Fig. J, where the genotype with the most positive BLUP slope estimate has the highest positive intercept (Fig. J) and has the leastplasticity across growth temperatures (Fig. E): once the population-level average linear slope is added to the BLUP slope estimate, this estimate is closest to zero among all 20 genotypes (Fig. I)"

# %%
#ranef(model5)$HenID

# %%
#ranef: Extract the modes of the random effects: If you want to be precise, these are the conditional modes of the 
#random effects B given Y = y, evaluated at the parameter estimates.
#BLUPs: best linear unbiased predictions
HenID_results = ranef(model5, postVar=TRUE)$HenID
#colnames(HenID_data) <- c("HenID", "BLUP_int")
HenID_results = cbind(HenID = rownames(HenID_results), HenID_results)
rownames(HenID_results) = 1:nrow(HenID_results)
#rename intercept into BLUP_int
colnames(HenID_results) <- c("HenID", "BLUP_int", "BLUP_slopes", "BLUP_quadratiqueslopes")
HenID_results

# %%
#ranef: Extract the modes of the random effects: If you want to be precise, these are the conditional modes of the 
#random effects B given Y = y, evaluated at the parameter estimates.
#BLUPs: best linear unbiased predictions
HenID_results = ranef(model5)$HenID
#colnames(HenID_data) <- c("HenID", "BLUP_int")
HenID_results = cbind(HenID = rownames(HenID_results), HenID_results)
rownames(HenID_results) = 1:nrow(HenID_results)
#rename intercept into BLUP_int
colnames(HenID_results) <- c("HenID", "BLUP_int", "BLUP_slopes", "BLUP_quadratiqueslopes")
HenID_results

# %%
ggplot(HenID_results, aes(HenID, BLUP_int)) + 
geom_point(aes(group = HenID, colour = HenID), size = 4, show.legend = FALSE) + 
ylab("BLUP intercept estimate") +
geom_hline(yintercept = 0, lty = 2) + theme_classic()

# %% [raw]
# "s a reminder, because the population-level average response is negative, the most negative BLUP slope estimates represent steeper reaction norm slopes and hence greater plasticity, andmore positive BLUP slope estimates represent flatter reaction norms and less plasticity in the relative date of flowering in response to growth temperatures"

# %%
ggplot(HenID_results, aes(HenID, BLUP_quadratiqueslopes)) + 
geom_point(aes(group = HenID, colour = HenID), size = 4, show.legend = FALSE) + 
ylab("Plasticity (BLUP slope estimate)") +
geom_hline(yintercept = 0, lty = 2) + 
theme_classic()

# %%
ggplot(HenID_results, aes(BLUP_int, BLUP_slopes)) +
geom_point(aes(group = HenID, colour = HenID), size = 4, show.legend = FALSE) +
xlab("BLUP intercept estimate") +
ylab("BLUP slope estimate") +
theme_classic()
#--> greater intercept

# %% [raw]
# This negative relationship between the intercepts and slopes estimates shows that hens with the most positive BLUP interccepts has the lowest BLUP slopes estimate and thus the greatest plasticity across # days post-transfer (mine).

# %%
HenID_results$HenIDcolors = HenID_results$HenID
HenID_results$HenIDcolors = replace(HenID_results$HenIDcolors, HenID_results$HenIDcolors %notin% li_selected_henpens, "#FF6666")

# %%
# Rank the BLUPs in order
# Sort BLUPs by interecepts 
HenID_results$res_ordered = factor(HenID_results$HenID, levels = HenID_results$HenID[order(HenID_results$BLUP_int)])
ggplot(HenID_results, aes(res_ordered, BLUP_int)) +
scale_fill_manual(values=c("#999999", "lightslateblue", "lightsalmon", "palegreen2", "yellow", "turquoise")) +
#scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9", "#999999", "#E69F00", "#56B4E9")) +
geom_bar(stat = "identity", aes(group=HenID, fill=HenIDcolors), show.legend = TRUE, col='black') +
xlab("HenID") +
ylab("Behavioural type (BLUP intercept estimate)") +
theme_classic()
#rep("black",dim(HenID_results)[[1]])
#ggsave(file.path(path_,'Adaptability','BLUPestimates.png'),width=12, height=4, bg = "transparent")

# %%
# Rank the BLUPs in order
# Sort BLUPs by slope of most to least plastic
HenID_results$res_ordered = factor(HenID_results$HenID, levels = HenID_results$HenID[order(HenID_results$BLUP_slopes)])
ggplot(HenID_results, aes(res_ordered, BLUP_slopes)) +
scale_fill_manual(values=c("#999999", "lightslateblue", "lightsalmon", "palegreen2", "yellow", "turquoise")) +
geom_bar(stat = "identity", aes(group = HenID, fill = HenIDcolors), show.legend = TRUE, col='black') +
xlab("HenID") +
ylab("Plasticity (BLUP slope estimate)") +
theme_classic()
#ggsave(file.path(path_,'Adaptability','BLUPslopes.png'),width=12, height=4, bg = "transparent")

# %%
ggplot(df_plot, aes(PC1, fill = HenID, colour = HenID)) + geom_density(alpha = 0.1) +
scale_fill_manual(values=c("lightslateblue", "lightsalmon", "palegreen2", "yellow", "turquoise"))
#ggsave(file.path(path_,'Adaptability','MvtVarDensities.png'),width=12, height=4, bg = "transparent")

# %%
#save
write.csv(HenID_results, file.path(path_,'Adaptability','Individualbehavoiuraltype.csv'), row.names = FALSE)

# %% [markdown]
# # Repeatabilities / week

# %% [markdown]
# ### week 1

# %%
df_ = df[ which(df$WIB==1), ] 
modelWIB1 = lmer(PC1 ~ weeklyavgDIB + (1|HenID), REML = FALSE, data = df_)
summary(modelWIB1)
r.squaredGLMM(modelWIB1)
0.8323    /(0.8323   +0.37807)

# %%
modelWIB1

# %%
#visualise
hist(df_$PC1)
###### normally distributed residuals
qqnorm(resid(model_$mod), main = "Residuals")
qqline(resid(model_$mod))
hist(resid(model_$mod))
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(model_$mod)

# %%
df_ = df[ which(df$WIB==2), ] 
modelWIB2 = lmer(PC1 ~ weeklyavgDIB + (1|HenID), REML = FALSE, data = df_)
summary(modelWIB2)
r.squaredGLMM(modelWIB2)
0.900018/(0.900018+0.192036)

# %%
df_ = df[ which(df$WIB==3), ] 
modelWIB3 = lmer(PC1 ~ weeklyavgDIB + (1|HenID), REML = FALSE, data = df_)
summary(modelWIB3)
r.squaredGLMM(modelWIB3)
0.8471   /(0.8471 +0.2230)

# %%
df_ = df[ which(df$WIB==4), ] 
modelWIB4 = lmer(PC1 ~ weeklyavgDIB + (1|HenID), REML = FALSE, data = df_)
summary(modelWIB4)
r.squaredGLMM(modelWIB4)
0.5743      /(0.5743    +0.2963   )

# %%
df_ = df[ which(df$WIB==5), ] 
modelWIB5 = lmer(PC1 ~  (1|HenID), REML = FALSE, data = df_)
summary(modelWIB5)
r.squaredGLMM(modelWIB5)
0.504293    /(0.504293  +0.164689)

# %%
df_ = df[ which(df$WIB==6), ] 
modelWIB6 = lmer(PC1 ~  (1|HenID), REML = FALSE, data = df_)
summary(modelWIB6)
r.squaredGLMM(modelWIB6)
0.5419   /(0.5419 +0.1590)

# %%
df_ = df[ which(df$WIB==7), ] 
modelWIB7 = lmer(PC1 ~  (1|HenID), REML = FALSE, data = df_)
summary(modelWIB7)
r.squaredGLMM(modelWIB7)
0.8471   /(0.8471 +0.2230)

# %%
df_ = df[ which(df$WIB==8), ] 
modelWIB8 = lmer(PC1 ~ (1|HenID), REML = FALSE, data = df_)
summary(modelWIB8)
r.squaredGLMM(modelWIB8)
0.8471   /(0.8471 +0.2230)

# %% [markdown]
# ### WEEK 1

# %%
#all wih CI = 0.95
name = 'PC1_Week1'
df_ = df[ which((df$WIB==1)&(df$CLASS %in% c('Other'))), ]  
model_ = rpt(PC1 ~ avgDIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian", nboot = nb, npermut = 0, CI=0.95)
model_

# %%
#all wih CI = 0.95
name = 'PC1_Week1'
df_ = df[ which((df$WIB %in% c(1,2,3,4))&(df$CLASS %in% c('Other'))), ]  
model_ = rpt(PC1 ~ DIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian", nboot = nb, npermut = 0, CI=0.95)
model_

# %%
#all wih CI = 0.95
name = 'PC1_Week1'
df_ = df[ which((df$WIB %in% c(5,6,7,8))&(df$CLASS %in% c('Other'))), ]  
model_ = rpt(PC1 ~ DIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian", nboot = nb, npermut = 0, CI=0.95)
model_

# %%
#visualise
hist(df_$PC1)
###### normally distributed residuals
qqnorm(resid(model_$mod), main = "Residuals")
qqline(resid(model_$mod))
hist(resid(model_$mod))
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(model_$mod)

# %%
#SAVE all
li_R_org = append(li_R_org, model_$R[[1]])
li_CIL_org = append(li_CIL_org, model_$CI_emp[,'2.5%'])
li_CIU_org = append(li_CIU_org, model_$CI_emp[,'97.5%'])
li_P = append(li_P, model_$P$LRT_P)
li_se_org = append(li_se_org, model_$se[[1]])
li_ngroup = append(li_ngroup, model_$ngroups[['HenID']])
li_nobs = append(li_nobs, model_$nobs)
li_mod = append(li_mod, model_$mod)
li_wib = append(li_wib, name)
#save model assumption verification 
###### histogram of dep var 
#variance of the residuals is equal across groups. Even spread around the centered line?
jpeg(file.path(path_model,paste0(name,'_Histrogram.jpg')))
hist(df_$PC1)
dev.off()
###### normally distributed residuals
jpeg(file.path(path_model, paste(name,'_diagnostic_normally_distributed_residual.jpg', sep='')))
qqnorm(resid(model_$mod), main = "Residuals")
qqline(resid(model_$mod))
dev.off()
jpeg(file.path(path_model, paste(name,'_diagnostic_normally_distributed_residual_histogram_.jpg', sep='')))
hist(resid(model_$mod))
dev.off()
######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
jpeg(file.path(path_model, paste(name,'_diagnostic_homogeneity_variance.jpg', sep='')))
plot(model_$mod)
dev.off()

# %% [markdown]
# #per class MEXP with 84%
# df_ = df[ which((df$WIB==1)&(df$CLASS %in% c('MEXP'))), ]
# model_ = rpt(PC1 ~  avgDIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian",nboot = nb, npermut = 0, CI=0.84)
# print(model_)
#
# #per class LEXP with 84%
# df_ = df[ which((df$WIB==1)&(df$CLASS %in% c('LEXP'))), ]
# model_ = rpt(PC1 ~  avgDIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian",nboot = nb, npermut = 0, CI=0.84)
# print(model_)
#
# #per class other with 84%
# df_ = df[ which((df$WIB==1)&(df$CLASS %in% c('Other'))), ]
# model_ = rpt(PC1 ~  avgDIB + (1|HenID), grname = c("HenID"), data = df_, datatype = "Gaussian",nboot = nb, npermut = 0, CI=0.84)
# print(model_)
