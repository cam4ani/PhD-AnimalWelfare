# %%
#install.packages("emmeans")
library(DHARMa)
library(lindia)
library(tidyverse)
library(caret)
library(leaps)
library(MASS)
library(modEvA)
library(dplyr)
library(lme4) #random effect
library(broom)
library(ggpubr) 
library(rstatix)
library(WRS2) #robust ancova
library(lmerTest) #like lmer but with p-value
library(emmeans) #visualize interaction term

#levenetest
library(car)

library(rstanarm) #r2 in mixed effect models
library(performance) #r2 in mixed effect models
# Out:
# Loading required package: Rcpp
#
# This is rstanarm version 2.21.1
#
# - See https://mc-stan.org/rstanarm/articles/priors for changes to default priors!
#
# - Default priors may change, so it's safest to specify priors, even if equivalent to the defaults.
#
# - For execution on a local, multicore CPU with excess RAM we recommend calling
#
#   options(mc.cores = parallel::detectCores())
#
#
# Attaching package: 'rstanarm'
#
#
# The following object is masked from 'package:car':
#
#     logit
#
#
# The following objects are masked from 'package:caret':
#
#     compare_models, R2
#
#
#
# Attaching package: 'performance'
#
#
# The following object is masked from 'package:rstanarm':
#
#     pp_check

# %% [raw]
# https://www.datanovia.com/en/lessons/ancova-in-r/
#
# https://statistics.laerd.com/spss-tutorials/ancova-using-spss-statistics.php
# "Like the one-way ANOVA, the one-way ANCOVA is used to determine whether there are any significant differences between two or more independent (unrelated) groups on a dependent variable. However, whereas the ANOVA looks for differences in the group means, the ANCOVA looks for differences in adjusted means (i.e., adjusted for the covariate). As such, compared to the one-way ANOVA, the one-way ANCOVA has the additional benefit of allowing you to "statistically control" for a third variable (sometimes known as a "confounding variable"), which you believe will affect your results. This third variable that could be confounding your results is called the covariate and you include it in your one-way ANCOVA analysis."

# %% [markdown]
# # Download data

# %%
#path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/chapter0_final_/visual/Treatment&Classs/adaptability/chapter0_final__percentgaeHensNotMovingTreatment.csv'
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/correctlightschedule_/visual/Treatment&Classs/adaptability'
df = read.csv(file.path(path_,'STATInterIntraDifferences.csv'), header = TRUE, sep = ";")
#df = read.csv(file.path(path_,'STATpercentgaeHensNotMovingTreatmentPenmonth1.csv'), header = TRUE, sep = ";")
#df$SQRTPercentagenotmoving <- sqrt(df$Percentagenotmoving)
df$Treatment = as.factor(df$Treatment)  
df$PenID = as.factor(df$PenID)
df$henID1 = as.factor(df$henID1)
df$henID2 = as.factor(df$henID2)
df$DOA = as.factor(df$DOA) #as factor as within a week its not th etime taht we want to take into acount, but the event
df$weeks_in_laying_barn  = as.factor(df$weeks_in_laying_barn)
df$sqrtchi2distance = sqrt(df$chi2distance)
name = 'firsttry'
print(dim(df))
summary(df)
head(df, 3)
# Out:
# [1] 11905    19
#        X              DOA           CLASS           Treatment       henID1
#  Min.   :    0   120    :  264   Length:11905       OFH :5805   hen_10 :   96
#  1st Qu.: 2976   125    :  264   Class :character   TRAN:6100   hen_108:   96
#  Median : 5952   143    :  264   Mode  :character               hen_111:   96
#  Mean   : 5952   144    :  264                                  hen_112:   96
#  3rd Qu.: 8928   145    :  264                                  hen_117:   96
#  Max.   :11904   146    :  264                                  hen_118:   96
#                  (Other):10321                                  (Other):11329
#      henID2      weeks_in_laying_barn is_same_ind         chi2distance
#  hen_118:  108   7      :1848         Length:11905       Min.   :0.00000
#  hen_69 :  107   5      :1844         Class :character   1st Qu.:0.02297
#  hen_9  :  107   4      :1828         Mode  :character   Median :0.07159
#  hen_143:  106   3      :1822                            Mean   :0.16143
#  hen_99 :  106   6      :1656                            3rd Qu.:0.21294
#  hen_113:  105   1      :1187                            Max.   :1.00000
#  (Other):11266   (Other):1720
#  DTW_15_1_Zone   DTW_15_2_Zone    DTW_15_3_Zone    DTW_15_4_Zone
#  Min.   : 0.00   Min.   :  0.00   Min.   :  0.00   Min.   :  0.0
#  1st Qu.: 0.00   1st Qu.: 25.90   1st Qu.: 22.40   1st Qu.:  9.4
#  Median : 8.10   Median : 34.80   Median : 35.40   Median : 24.0
#  Mean   :10.35   Mean   : 37.25   Mean   : 48.06   Mean   : 34.5
#  3rd Qu.:17.50   3rd Qu.: 46.30   3rd Qu.: 78.20   3rd Qu.: 49.7
#  Max.   :67.10   Max.   :145.00   Max.   :145.40   Max.   :143.2
#
#  DTW_15_5_Zone       PenID      henID1_Total_number_transition
#  Min.   :  0.0   pen10  :1728   Min.   :  0.0
#  1st Qu.: 37.5   pen11  :1728   1st Qu.: 23.0
#  Median : 69.6   pen12  :1512   Median : 44.0
#  Mean   : 67.7   pen8   :1472   Mean   : 43.8
#  3rd Qu.: 95.4   pen9   :1468   3rd Qu.: 63.0
#  Max.   :147.0   pen3   :1393   Max.   :159.0
#                  (Other):2604
#  henID2_Total_number_transition   is_MEXP          sqrtchi2distance
#  Min.   :  0.00                 Length:11905       Min.   :0.0000
#  1st Qu.: 22.00                 Class :character   1st Qu.:0.1516
#  Median : 44.00                 Mode  :character   Median :0.2676
#  Mean   : 43.68                                    Mean   :0.3292
#  3rd Qu.: 63.00                                    3rd Qu.:0.4615
#  Max.   :159.00                                    Max.   :1.0000
#   X DOA CLASS Treatment henID1  henID2  weeks_in_laying_barn is_same_ind
# 1 0 119 MEXP  OFH       hen_102 hen_102 1                    intra
# 2 1 119 Other OFH       hen_104 hen_102 1                    inter
# 3 2 119 Other OFH       hen_102 hen_94  1                    inter
# 4 3 119 LEXP  OFH       hen_94  hen_94  1                    intra
# 5 4 119 Other OFH       hen_6   hen_9   1                    inter
# 6 5 119 Other OFH       hen_22  hen_9   1                    inter
#   chi2distance DTW_15_1_Zone DTW_15_2_Zone DTW_15_3_Zone DTW_15_4_Zone
# 1 0.12899116   0              4.7          97.6           8.9
# 2 0.22199593   0             30.5          18.1          30.1
# 3 0.12899116   0              4.7          31.1           9.9
# 4 0.00497252   0              0.6          72.9           1.6
# 5 0.13456170   0             46.2          32.3          17.0
# 6 0.06025430   0             50.2          31.9          25.1
#   DTW_15_5_Zone PenID henID1_Total_number_transition
# 1 99.1          pen3   7
# 2 50.5          pen3  12
# 3 34.1          pen3   7
# 4 72.9          pen3   7
# 5 62.2          pen11 16
# 6 67.2          pen11  5
#   henID2_Total_number_transition is_MEXP sqrtchi2distance
# 1  7                             True    0.3591534
# 2  7                             False   0.4711644
# 3  7                             False   0.3591534
# 4  7                             False   0.0705161
# 5 52                             False   0.3668265
# 6 52                             False   0.2454675

# %% [raw]
# 259 rows: one row per animal intra, one row per animal inter and we will test if, once taking into account the pen and the number of transitions of both hens, if the inter and intra are statistically different at specfic DOA. We will then test if this is different for the treatments (inter TRAN same dim as intra OFH) and later on (?) for the classes
# --> we want to test if the mean is statistically different: ANOVA
# --> we want to take into account the number of transistion of hen1 and hen2: ANCOVA
# --> we want the PenID to be a random factor: ANCOVA with random factor
# --> we have 6 outcomes and 53 days: 6*53=318 ANCOVA with random factors: pens are nested within treatment
#                outcome_diff ~ nbr_trans_henDI1 + nbr_trans_henDI2 + treatment + is_same_ind + 1|PenID
# OR: weeks_inlaying_barn instead of DOA (obs may differ: 1822- 600 obs) & 6*8=48 models
#
# pens are nested within treatment and hens are nested within pens
# outcome_diff ~ nbr_trans_henDI1 + nbr_trans_henDI2 + treatment + is_same_ind + (1|pen/henid1) + (1|treatment/pen) + (1/DOA)
# Note: pens are nested within treatment and hens are nested within pens: (1|pen/hen)
#
# OR: weeks of age in the laying barn as categorical data and only 6 models!
# outcome_diff ~ henID1_Total_number_transition + henID2_Total_number_transition + Treatment + is_MEXP + weeks_in_laying_barn*is_same_ind + treatment + (1|PenID/henID1) + (1|DOA)
# #Note: does not cvg with: (1|PenID/henID2) and I dont think we should add it. Also, DOA is considered as categorical as within a week its not th etime taht we want to take into acount, but the event

# %% [markdown]
# # Mixed effect models

# %%
#does not converge with: (1|PenID/henID2)
fit = lmer(DTW_15_3_Zone ~ henID1_Total_number_transition + henID2_Total_number_transition + DOA*is_same_ind + Treatment + is_MEXP + (1|PenID/henID1), data=df)
#Hence, this boils down to comparing the variation between different PenID (having 7 degrees of freedom) to the variation 
#due to the interaction between Trackingsystem_Zone and HenID (having  5*159=795  degrees of freedom).
#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
# Out:
# Correlation matrix not shown by default, as p = 104 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# DTW_15_3_Zone ~ henID1_Total_number_transition + henID2_Total_number_transition +
#     DOA * is_same_ind + Treatment + is_MEXP + (1 | PenID/henID1)
#    Data: df
#
# REML criterion at convergence: 113726.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.6717 -0.7373 -0.2451  0.7565  3.1725
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  henID1:PenID (Intercept)  90.50    9.513
#  PenID        (Intercept)  11.09    3.330
#  Residual                 835.85   28.911
# Number of obs: 11905, groups:  henID1:PenID, 132; PenID, 8
#
# Fixed effects:
#                                  Estimate Std. Error         df t value
# (Intercept)                     6.320e+01  3.282e+00  3.697e+01  19.256
# henID1_Total_number_transition  9.758e-02  1.636e-02  1.010e+04   5.965
# henID2_Total_number_transition  1.045e-01  1.357e-02  1.169e+04   7.705
# DOA120                         -1.922e+00  3.587e+00  1.167e+04  -0.536
# DOA121                         -1.522e+01  4.908e+00  1.168e+04  -3.100
# TreatmentTRAN                  0.111225
# is_MEXPTrue                    0.005686 **
# DOA120:is_same_indintra        0.265520
# DOA121:is_same_indintra        0.557037
# DOA122:is_same_indintra        0.125650
# DOA123:is_same_indintra        0.155018
# DOA124:is_same_indintra        0.975365
# DOA125:is_same_indintra        0.067552 .
# DOA129:is_same_indintra        0.649990
# DOA130:is_same_indintra        0.304693
# DOA131:is_same_indintra        0.136437
# DOA132:is_same_indintra        0.019292 *
# DOA133:is_same_indintra        0.299588
# DOA134:is_same_indintra        0.766214
# DOA135:is_same_indintra        0.006392 **
# DOA136:is_same_indintra        0.136794
# DOA137:is_same_indintra        0.129893
# DOA138:is_same_indintra        0.082981 .
# DOA139:is_same_indintra        0.127243
# DOA140:is_same_indintra        0.079196 .
# DOA141:is_same_indintra        0.040568 *
# DOA142:is_same_indintra        0.208530
# DOA143:is_same_indintra        0.118182
# DOA144:is_same_indintra        0.025652 *
# DOA145:is_same_indintra        0.200947
# DOA146:is_same_indintra        0.051317 .
# DOA147:is_same_indintra        0.044616 *
# DOA148:is_same_indintra        0.027930 *
# DOA149:is_same_indintra        0.041693 *
# DOA150:is_same_indintra        0.078512 .
# DOA151:is_same_indintra        0.000846 ***
# DOA152:is_same_indintra        0.008437 **
# DOA153:is_same_indintra        0.014246 *
# DOA154:is_same_indintra        0.247786
# DOA155:is_same_indintra        0.260137
# DOA156:is_same_indintra        0.194507
# DOA157:is_same_indintra        0.047851 *
# DOA158:is_same_indintra        0.136649
# DOA159:is_same_indintra        0.346765
# DOA160:is_same_indintra        0.021289 *
# DOA161:is_same_indintra        0.032054 *
# DOA162:is_same_indintra        0.056181 .
# DOA163:is_same_indintra        0.020206 *
# DOA164:is_same_indintra        0.012716 *
# DOA165:is_same_indintra        0.104947
# DOA166:is_same_indintra        0.010172 *
# DOA167:is_same_indintra        0.000428 ***
# DOA168:is_same_indintra        0.009064 **
# DOA169:is_same_indintra        0.005730 **
# DOA170:is_same_indintra        0.023328 *
# DOA171:is_same_indintra        0.004209 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# #weeks in the laying barn
# #does not converge with: (1|PenID/henID2)
# fit = lmer(DTW_15_3_Zone ~ henID1_Total_number_transition + henID2_Total_number_transition + weeks_in_laying_barn*is_same_ind + Treatment + is_MEXP + (1|PenID/henID1)+(1|DOA), data=df)
# #Hence, this boils down to comparing the variation between different PenID (having 7 degrees of freedom) to the variation
# #due to the interaction between Trackingsystem_Zone and HenID (having  5*159=795  degrees of freedom).
# #capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
# summary(fit)

# %% [markdown]
# #one model per DOA
# #does not converge with: (1|PenID/henID2)
# df_DOA = subset(df, DOA == 140)
# print(dim(df_DOA))
# #head(df_DOA1, 3)
# fit = lmer(DTW_15_3_Zone ~ henID1_Total_number_transition + henID2_Total_number_transition + is_same_ind + Treatment + is_MEXP + (1|PenID), data=df_DOA)
# #Hence, this boils down to comparing the variation between different PenID (having 7 degrees of freedom) to the variation
# #due to the interaction between Trackingsystem_Zone and HenID (having  5*159=795  degrees of freedom).
# #capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
# summary(fit)

# %%
emmip(fit, is_same_ind ~ DOA)
# Out:
# Note: D.f. calculations have been disabled because the number of observations exceeds 3000.
# To enable adjustments, add the argument 'pbkrtest.limit = 11905' (or larger)
# [or, globally, 'set emm_options(pbkrtest.limit = 11905)' or larger];
# but be warned that this may result in large computation time and memory use.
#
# Note: D.f. calculations have been disabled because the number of observations exceeds 3000.
# To enable adjustments, add the argument 'lmerTest.limit = 11905' (or larger)
# [or, globally, 'set emm_options(lmerTest.limit = 11905)' or larger];
# but be warned that this may result in large computation time and memory use.
# plot without title

# %%
M = emmeans(fit, pairwise ~ DOA : is_same_ind, lmerTest.limit = 12000, adjust = "bonf")
# Out:
# Note: D.f. calculations have been disabled because the number of observations exceeds 3000.
# To enable adjustments, add the argument 'pbkrtest.limit = 11905' (or larger)
# [or, globally, 'set emm_options(pbkrtest.limit = 11905)' or larger];
# but be warned that this may result in large computation time and memory use.

# %%
summary(M, adjust = "tukey")
# Out:
# Note: adjust = "tukey" was changed to "sidak"
# because "tukey" is only appropriate for one set of pairwise comparisons
# $emmeans
#  DOA is_same_ind emmean   SE    df lower.CL upper.CL
#  119 inter         76.3 3.01 104.6     65.5     87.1
#  120 inter         74.4 2.97  99.3     63.7     85.0
#  121 inter         61.1 4.47 492.4     45.4     76.7
#  122 inter         60.5 4.48 495.7     44.9     76.2
#  123 inter         68.7 4.33 430.9     53.6     83.9
#  124 inter         57.0 4.33 432.5     41.8     72.1
#  125 inter         66.8 2.97  99.4     56.1     77.5
#  129 inter         61.1 3.52 193.6     48.6     73.5
#  130 inter         56.0 3.53 194.3     43.5     68.4
#  131 inter         55.5 3.52 192.7     43.0     67.9
#  132 inter         62.8 3.51 191.2     50.4     75.2
#  133 inter         52.2 2.96  97.7     41.5     62.8
#  134 inter         44.6 2.98 100.4     33.9     55.3
#  135 inter         56.4 2.96  98.1     45.8     67.1
#  136 inter         50.7 2.97  98.2     40.1     61.4
#  137 inter         53.2 2.94  95.5     42.6     63.8
#  138 inter         54.2 2.96  97.7     43.5     64.8
#  139 inter         54.8 2.97  98.3     44.2     65.5
#  140 inter         58.4 2.94  95.0     47.8     69.0
#  141 inter         61.3 2.97  99.1     50.6     72.0
#  142 inter         56.2 3.00 102.2     45.5     67.0
#  143 inter         54.2 2.93  94.0     43.7     64.8
#  144 inter         58.6 2.94  94.6     48.0     69.2
#  145 inter         57.9 2.93  94.2     47.4     68.5
#  146 inter         60.2 2.94  94.3     49.7     70.8
#  147 inter         60.3 2.94  94.9     49.7     70.9
#  148 inter         58.0 2.95  95.6     47.4     68.6
#  149 inter         52.8 2.96  97.4     42.2     63.4
#  150 inter         51.8 2.95  96.7     41.2     62.4
#  151 inter         60.4 2.94  95.1     49.8     71.0
#  152 inter         58.4 2.95  96.2     47.8     69.0
#  153 inter         59.2 2.95  95.8     48.6     69.8
#  154 inter         53.8 3.09 115.9     42.7     64.8
#  155 inter         50.5 3.09 115.9     39.5     61.6
#  163 intra - 168 intra   4.14466 3.57 11671  1.162  1.0000
#  163 intra - 169 intra  -0.29757 3.57 11671 -0.083  1.0000
#  163 intra - 170 intra  -0.92997 3.57 11672 -0.261  1.0000
#  163 intra - 171 intra   0.21352 3.57 11672  0.060  1.0000
#  164 intra - 165 intra  -2.80871 3.56 11671 -0.789  1.0000
#  164 intra - 166 intra  -1.32821 3.56 11671 -0.373  1.0000
#  164 intra - 167 intra   2.36547 3.56 11671  0.665  1.0000
#  164 intra - 168 intra   3.70251 3.57 11671  1.038  1.0000
#  164 intra - 169 intra  -0.73971 3.57 11672 -0.207  1.0000
#  164 intra - 170 intra  -1.37212 3.57 11671 -0.385  1.0000
#  164 intra - 171 intra  -0.22863 3.57 11672 -0.064  1.0000
#  165 intra - 166 intra   1.48049 3.56 11671  0.416  1.0000
#  165 intra - 167 intra   5.17418 3.56 11671  1.454  1.0000
#  165 intra - 168 intra   6.51122 3.57 11671  1.826  1.0000
#  165 intra - 169 intra   2.06899 3.57 11671  0.580  1.0000
#  165 intra - 170 intra   1.43659 3.57 11671  0.403  1.0000
#  165 intra - 171 intra   2.58008 3.57 11672  0.723  1.0000
#  166 intra - 167 intra   3.69368 3.56 11671  1.038  1.0000
#  166 intra - 168 intra   5.03073 3.57 11671  1.411  1.0000
#  166 intra - 169 intra   0.58850 3.57 11671  0.165  1.0000
#  166 intra - 170 intra  -0.04390 3.57 11672 -0.012  1.0000
#  166 intra - 171 intra   1.09959 3.57 11672  0.308  1.0000
#  167 intra - 168 intra   1.33704 3.57 11671  0.375  1.0000
#  167 intra - 169 intra  -3.10518 3.57 11672 -0.871  1.0000
#  167 intra - 170 intra  -3.73759 3.57 11671 -1.048  1.0000
#  167 intra - 171 intra  -2.59410 3.57 11671 -0.727  1.0000
#  168 intra - 169 intra  -4.44223 3.57 11672 -1.243  1.0000
#  168 intra - 170 intra  -5.07463 3.57 11671 -1.421  1.0000
#  168 intra - 171 intra  -3.93114 3.57 11671 -1.100  1.0000
#  169 intra - 170 intra  -0.63240 3.57 11672 -0.177  1.0000
#  169 intra - 171 intra   0.51109 3.58 11673  0.143  1.0000
#  170 intra - 171 intra   1.14349 3.57 11671  0.320  1.0000
#
# Results are averaged over the levels of: Treatment, is_MEXP
# Degrees-of-freedom method: satterthwaite
# P value adjustment: tukey method for comparing a family of 100 estimates

# %%
Anova(fit)
# Out:
#                                Chisq      Df Pr(>Chisq)
# henID1_Total_number_transition  35.581071  1  2.446533e-09
# henID2_Total_number_transition  59.364890  1  1.309853e-14
# DOA                            422.859848 49  5.876370e-61
# is_same_ind                    761.877050  1 1.049373e-167
# Treatment                        3.503386  1  6.124350e-02
# is_MEXP                          7.653074  1  5.667568e-03
# DOA:is_same_ind                 54.450384 49  2.748547e-01

# %%
#rand: Likelihood Ratio Test On Random Effects Of Linear Mixed Effects Model
#tests the hypothesis that the random effect variation is significant versus the null that there is no between group-level 
#variation
rand(fit)
# Out:
#                    npar logLik    AIC      LRT        Df Pr(>Chisq)
# <none>             107  -56863.43 113940.9         NA NA            NA
# (1 | henID1:PenID) 106  -57290.07 114792.1 853.277673  1 1.409272e-187
# (1 | PenID)        106  -56865.49 113943.0   4.104253  1  4.277548e-02

# %%
#ranef(fit)

# %%
confint(fit)
# Out:
# Computing profile confidence intervals ...

# %% [markdown]
# # Assumptions

# %%
#linearity
#jpeg(file.path(path_, paste('diagnostic_plot_linearity_',name,'.jpg', sep='')))
plot(resid(fit),df$DTW_15_3_Zone)
#dev.off()

# %%
#check homogeneity of variance
#variance of the residuals is equal across groups
plot(fit)

# %%
#normally distributed residuals
#qqmath(fit) #same
qqnorm(resid(fit))

# %%
#qqplot
qqmath(ranef(fit))

# %% [markdown]
# ### Linearity assumption

# %%
qplot(year, lifeExp, data = gapminder.sub, main = paste("Life expectancy in", country.name)) +
  geom_smooth(method = "lm")

# %%
qplot(x = weeks_in_laying_barn, y = chi2distance, color = is_same_ind, data = df) +
  stat_smooth(method = "lm", se = TRUE, fullrange = TRUE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggscatter(
  df, x = "weeks_in_laying_barn", y = "chi2distance",
  color = "is_same_ind", add = "reg.line"
  )+
  stat_regline_equation(
    aes(label =  paste(..eq.label.., ..rr.label.., sep = "~~~~"), color = is_same_ind)
    )
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [raw]
# There was a linear relationship between pre-test and post-test anxiety score for each training group, as assessed by visual inspection of a scatter plot.

# %% [markdown]
# ### Homogeneity of regression slopes

# %%
df %>% anova_test(SQRTPercentagenotmoving ~ Treatment*DOA)
# Out:
# Coefficient covariances computed by hccm()
#   Effect        DFn DFd F       p        p<.05 ges
# 1 Treatment     1   52   31.343 8.23e-07 *     0.376000
# 2 DOA           1   52  136.758 3.56e-16 *     0.725000
# 3 Treatment:DOA 1   52    0.016 9.00e-01       0.000305

# %% [raw]
# There was homogeneity of regression slopes as the interaction term is not statistically significant, F(1, 52) = 1.169, p = 0.28

# %% [markdown]
# ### Normality of residuals

# %%
# Fit the model, the covariate goes first
model <- lm(SQRTPercentagenotmoving ~ DOA + Treatment, data = df)
# Inspect the model diagnostic metrics
model.metrics <- augment(model)
head(model.metrics, 3)
# Out:
#   SQRTPercentagenotmoving DOA Treatment .fitted  .resid    .hat       .sigma
# 1 7.288690                119 OFH       6.276508  1.012182 0.08706841 0.8599265
# 2 7.806247                119 TRAN      4.971391  2.834856 0.08706841 0.7692652
# 3 4.677072                120 OFH       6.121666 -1.444594 0.08041887 0.8470026
#   .cooksd    .std.resid
# 1 0.04777896  1.225936
# 2 0.37478458  3.433526
# 3 0.08859416 -1.743329

# %%
# Assess normality of residuals using shapiro wilk test
shapiro_test(model.metrics$.resid)
# Out:
#   variable             statistic p.value
# 1 model.metrics$.resid 0.9746566 0.2845212

# %% [raw]
# The Shapiro Wilk test is not significant (p > 0.05), so we CAN assume normality of residuals

# %%
plot(model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# ### Homogeneity of variances

# %%
leveneTest(.resid ~ Treatment, data=model.metrics)
# Out:
# Loading required package: carData
#
#
# Attaching package: 'car'
#
#
# The following object is masked from 'package:dplyr':
#
#     recode
#
#
# The following object is masked from 'package:purrr':
#
#     some
#       Df F value   Pr(>F)
# group  1 0.3975178 0.5310332
#       54        NA        NA

# %% [raw]
# The Levene’s test was not significant (p > 0.05), so we can assume homogeneity of the residual variances for all groups.

# %% [markdown]
# ### outliers

# %%
model.metrics %>% 
  filter(abs(.std.resid) > 3) %>%
  as.data.frame()
# Out:
#   SQRTPercentagenotmoving DOA Treatment .fitted  .resid   .hat       .sigma
# 1 7.806247                119 TRAN      4.971391 2.834856 0.08706841 0.7692652
#   .cooksd   .std.resid
# 1 0.3747846 3.433526

# %% [markdown]
# There is one outliers in the data the first day, should I remove it?

# %% [markdown]
# # ANCOVA

# %%
res.aov <- df %>% anova_test(SQRTPercentagenotmoving ~ DOA + Treatment)
get_anova_table(res.aov)
# Out:
# Coefficient covariances computed by hccm()
#   Effect    DFn DFd F       p        p<.05 ges
# 1 DOA       1   53  139.346 1.86e-16 *     0.724
# 2 Treatment 1   53   31.936 6.46e-07 *     0.376

# %%
summary(res.aov)
# Out:
#     Effect               DFn         DFd           F
#  Length:2           Min.   :1   Min.   :53   Min.   : 31.94
#  Class :character   1st Qu.:1   1st Qu.:53   1st Qu.: 58.79
#  Mode  :character   Median :1   Median :53   Median : 85.64
#                     Mean   :1   Mean   :53   Mean   : 85.64
#                     3rd Qu.:1   3rd Qu.:53   3rd Qu.:112.49
#                     Max.   :1   Max.   :53   Max.   :139.35
#        p                p<.05                ges
#  Min.   :0.000e+00   Length:2           Min.   :0.376
#  1st Qu.:1.615e-07   Class :character   1st Qu.:0.463
#  Median :3.230e-07   Mode  :character   Median :0.550
#  Mean   :3.230e-07                      Mean   :0.550
#  3rd Qu.:4.845e-07                      3rd Qu.:0.637
#  Max.   :6.460e-07                      Max.   :0.724

# %% [raw]
# An ANCOVA was run to determine the effect of the treatment on the percentgae of animals that are not transitioning after controlling for the day of age of the animal.
# After adjustment for DOA, there was a statistically significant difference in the percentage of hens not moving between the groups OFH and TRAN, F(1, 53) = 17.26, p < 0.0001

# %%
emmeans_test(SQRTPercentagenotmoving ~ Treatment, covariate = DOA, data=df, p.adjust.method = "bonferroni")
# Out:
# Error: Column name `std.error` must not be duplicated.
# Traceback:
#
# 1. emmeans_test(SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
#  .     data = df, p.adjust.method = "bonferroni")
# 2. pairwise_emmeans_test(res.emmeans, grouping.vars, method = method,
#  .     p.adjust.method = p.adjust.method, conf.level = conf.level)
# 3. tidy(comparisons, conf.int = TRUE, conf.level = conf.level) %>%
#  .     add_column(std.error = std.error, .after = "estimate")
# 4. add_column(., std.error = std.error, .after = "estimate")
# 5. set_repaired_names(out, .name_repair)
# 6. set_names(x, repaired_names(names2(x), .name_repair = .name_repair,
#  .     quiet = quiet))
# 7. repaired_names(names2(x), .name_repair = .name_repair, quiet = quiet)
# 8. subclass_name_repair_errors(name = name, details = details, vec_as_names(name,
#  .     repair = .name_repair, quiet = quiet || !is_character(.name_repair)))
# 9. withCallingHandlers(expr, vctrs_error_names_cannot_be_empty = function(cnd) {
#  .     cnd <- error_column_names_cannot_be_empty(detect_empty_names(name),
#  .         parent = cnd)
#  .     cnd$body <- details
#  .     cnd_signal(cnd)
#  . }, vctrs_error_names_cannot_be_dot_dot = function(cnd) {
#  .     cnd <- error_column_names_cannot_be_dot_dot(detect_dot_dot(name),
#  .         parent = cnd)
#  .     cnd_signal(cnd)
#  . }, vctrs_error_names_must_be_unique = function(cnd) {
#  .     cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#  .         parent = cnd)
#  .     cnd_signal(cnd)
#  . })
# 10. vec_as_names(name, repair = .name_repair, quiet = quiet || !is_character(.name_repair))
# 11. (function ()
#   . validate_unique(names = names, arg = arg))()
# 12. validate_unique(names = names, arg = arg)
# 13. stop_names_must_be_unique(names, arg)
# 14. stop_names(class = "vctrs_error_names_must_be_unique", arg = arg,
#   .     names = names)
# 15. stop_vctrs(class = c(class, "vctrs_error_names"), ...)
# 16. abort(message, class = c(class, "vctrs_error"), ...)
# 17. signal_abort(cnd)
# 18. signalCondition(cnd)
# 19. (function (cnd)
#   . {
#   .     cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#   .         parent = cnd)
#   .     cnd_signal(cnd)
#   . })(structure(list(message = "", trace = structure(list(calls = list(
#   .     IRkernel::main(), kernel$run(), IRkernel:::handle_shell(),
#   .     executor$execute(msg), base::tryCatch(evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .         interrupt = function(cond) {
#   .             log_debug("Interrupt during execution")
#   .             interrupted <<- TRUE
#   .         }, error = .self$handle_error), base:::tryCatchList(expr,
#   .         classes, parentenv, handlers), base:::tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), base:::doTryCatch(return(expr), name,
#   .         parentenv, handler), base:::tryCatchList(expr, names[-nh],
#   .         parentenv, handlers[-nh]), base:::tryCatchOne(expr, names,
#   .         parentenv, handlers[[1L]]), base:::doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate::evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate:::evaluate_call(expr, parsed$src[[i]], envir = envir,
#   .         enclos = enclos, debug = debug, last = i == length(out),
#   .         use_try = stop_on_error != 2L, keep_warning = keep_warning,
#   .         keep_message = keep_message, output_handler = output_handler,
#   .         include_timing = include_timing), evaluate:::timing_fn(handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .         envir, enclos)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), evaluate:::handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .         envir, enclos)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), base::try(f, silent = TRUE), base::tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call)[1L]
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), base:::tryCatchList(expr, classes, parentenv, handlers),
#   .     base:::tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#   .     base:::doTryCatch(return(expr), name, parentenv, handler),
#   .     base::withCallingHandlers(withVisible(eval(expr, envir, enclos)),
#   .         warning = wHandler, error = eHandler, message = mHandler),
#   .     base::withVisible(eval(expr, envir, enclos)), base::eval(expr,
#   .         envir, enclos), base::eval(expr, envir, enclos), rstatix::emmeans_test(SQRTPercentagenotmoving ~
#   .         Treatment, covariate = DOA, data = df, p.adjust.method = "bonferroni"),
#   .     rstatix:::pairwise_emmeans_test(res.emmeans, grouping.vars,
#   .         method = method, p.adjust.method = p.adjust.method, conf.level = conf.level),
#   .     tidy(comparisons, conf.int = TRUE, conf.level = conf.level) %>%
#   .         add_column(std.error = std.error, .after = "estimate"),
#   .     tibble::add_column(., std.error = std.error, .after = "estimate"),
#   .     tibble:::set_repaired_names(out, .name_repair), rlang::set_names(x,
#   .         repaired_names(names2(x), .name_repair = .name_repair,
#   .             quiet = quiet)), tibble:::repaired_names(names2(x),
#   .         .name_repair = .name_repair, quiet = quiet), tibble:::subclass_name_repair_errors(name = name,
#   .         details = details, vec_as_names(name, repair = .name_repair,
#   .             quiet = quiet || !is_character(.name_repair))), base::withCallingHandlers(expr,
#   .         vctrs_error_names_cannot_be_empty = function(cnd) {
#   .             cnd <- error_column_names_cannot_be_empty(detect_empty_names(name),
#   .                 parent = cnd)
#   .             cnd$body <- details
#   .             cnd_signal(cnd)
#   .         }, vctrs_error_names_cannot_be_dot_dot = function(cnd) {
#   .             cnd <- error_column_names_cannot_be_dot_dot(detect_dot_dot(name),
#   .                 parent = cnd)
#   .             cnd_signal(cnd)
#   .         }, vctrs_error_names_must_be_unique = function(cnd) {
#   .             cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#   .                 parent = cnd)
#   .             cnd_signal(cnd)
#   .         }), vctrs::vec_as_names(name, repair = .name_repair,
#   .         quiet = quiet || !is_character(.name_repair)), (function ()
#   .     validate_unique(names = names, arg = arg))(), vctrs:::validate_unique(names = names,
#   .         arg = arg), vctrs:::stop_names_must_be_unique(names,
#   .         arg), vctrs:::stop_names(class = "vctrs_error_names_must_be_unique",
#   .         arg = arg, names = names), vctrs:::stop_vctrs(class = c(class,
#   .         "vctrs_error_names"), ...)), parents = c(0L, 1L, 2L,
#   . 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L, 4L, 12L, 13L, 13L, 15L, 16L,
#   . 17L, 18L, 19L, 13L, 13L, 13L, 23L, 0L, 25L, 26L, 0L, 28L, 29L,
#   . 29L, 31L, 32L, 31L, 34L, 35L, 36L, 37L, 38L), indices = 1:39), class = "rlang_trace", version = 1L),
#   .     parent = NULL, arg = "", names = c("term", "contrast", "null.value",
#   .     "estimate", "std.error", "std.error", "df", "conf.low", "conf.high",
#   .     "statistic", "p.value")), class = c("vctrs_error_names_must_be_unique",
#   . "vctrs_error_names", "vctrs_error", "rlang_error", "error", "condition"
#   . )))
# 20. cnd_signal(cnd)
# 21. signal_abort(cnd)

# %%
pwc <- df %>% 
  emmeans_test(
    SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
    p.adjust.method = "bonferroni"
    )
pwc
# Out:
# Error: Column name `std.error` must not be duplicated.
# Traceback:
#
# 1. df %>% emmeans_test(SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
#  .     p.adjust.method = "bonferroni")
# 2. emmeans_test(., SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
#  .     p.adjust.method = "bonferroni")
# 3. pairwise_emmeans_test(res.emmeans, grouping.vars, method = method,
#  .     p.adjust.method = p.adjust.method, conf.level = conf.level)
# 4. tidy(comparisons, conf.int = TRUE, conf.level = conf.level) %>%
#  .     add_column(std.error = std.error, .after = "estimate")
# 5. add_column(., std.error = std.error, .after = "estimate")
# 6. set_repaired_names(out, .name_repair)
# 7. set_names(x, repaired_names(names2(x), .name_repair = .name_repair,
#  .     quiet = quiet))
# 8. repaired_names(names2(x), .name_repair = .name_repair, quiet = quiet)
# 9. subclass_name_repair_errors(name = name, details = details, vec_as_names(name,
#  .     repair = .name_repair, quiet = quiet || !is_character(.name_repair)))
# 10. withCallingHandlers(expr, vctrs_error_names_cannot_be_empty = function(cnd) {
#   .     cnd <- error_column_names_cannot_be_empty(detect_empty_names(name),
#   .         parent = cnd)
#   .     cnd$body <- details
#   .     cnd_signal(cnd)
#   . }, vctrs_error_names_cannot_be_dot_dot = function(cnd) {
#   .     cnd <- error_column_names_cannot_be_dot_dot(detect_dot_dot(name),
#   .         parent = cnd)
#   .     cnd_signal(cnd)
#   . }, vctrs_error_names_must_be_unique = function(cnd) {
#   .     cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#   .         parent = cnd)
#   .     cnd_signal(cnd)
#   . })
# 11. vec_as_names(name, repair = .name_repair, quiet = quiet || !is_character(.name_repair))
# 12. (function ()
#   . validate_unique(names = names, arg = arg))()
# 13. validate_unique(names = names, arg = arg)
# 14. stop_names_must_be_unique(names, arg)
# 15. stop_names(class = "vctrs_error_names_must_be_unique", arg = arg,
#   .     names = names)
# 16. stop_vctrs(class = c(class, "vctrs_error_names"), ...)
# 17. abort(message, class = c(class, "vctrs_error"), ...)
# 18. signal_abort(cnd)
# 19. signalCondition(cnd)
# 20. (function (cnd)
#   . {
#   .     cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#   .         parent = cnd)
#   .     cnd_signal(cnd)
#   . })(structure(list(message = "", trace = structure(list(calls = list(
#   .     IRkernel::main(), kernel$run(), IRkernel:::handle_shell(),
#   .     executor$execute(msg), base::tryCatch(evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .         interrupt = function(cond) {
#   .             log_debug("Interrupt during execution")
#   .             interrupted <<- TRUE
#   .         }, error = .self$handle_error), base:::tryCatchList(expr,
#   .         classes, parentenv, handlers), base:::tryCatchOne(tryCatchList(expr,
#   .         names[-nh], parentenv, handlers[-nh]), names[nh], parentenv,
#   .         handlers[[nh]]), base:::doTryCatch(return(expr), name,
#   .         parentenv, handler), base:::tryCatchList(expr, names[-nh],
#   .         parentenv, handlers[-nh]), base:::tryCatchOne(expr, names,
#   .         parentenv, handlers[[1L]]), base:::doTryCatch(return(expr),
#   .         name, parentenv, handler), evaluate::evaluate(request$content$code,
#   .         envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .     evaluate:::evaluate_call(expr, parsed$src[[i]], envir = envir,
#   .         enclos = enclos, debug = debug, last = i == length(out),
#   .         use_try = stop_on_error != 2L, keep_warning = keep_warning,
#   .         keep_message = keep_message, output_handler = output_handler,
#   .         include_timing = include_timing), evaluate:::timing_fn(handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .         envir, enclos)), warning = wHandler, error = eHandler,
#   .         message = mHandler))), evaluate:::handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .         envir, enclos)), warning = wHandler, error = eHandler,
#   .         message = mHandler)), base::try(f, silent = TRUE), base::tryCatch(expr,
#   .         error = function(e) {
#   .             call <- conditionCall(e)
#   .             if (!is.null(call)) {
#   .                 if (identical(call[[1L]], quote(doTryCatch)))
#   .                   call <- sys.call(-4L)
#   .                 dcall <- deparse(call)[1L]
#   .                 prefix <- paste("Error in", dcall, ": ")
#   .                 LONG <- 75L
#   .                 sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                 w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                   type = "w")
#   .                 if (is.na(w))
#   .                   w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                     type = "b")
#   .                 if (w > LONG)
#   .                   prefix <- paste0(prefix, "\n  ")
#   .             }
#   .             else prefix <- "Error : "
#   .             msg <- paste0(prefix, conditionMessage(e), "\n")
#   .             .Internal(seterrmessage(msg[1L]))
#   .             if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                 cat(msg, file = outFile)
#   .                 .Internal(printDeferredWarnings())
#   .             }
#   .             invisible(structure(msg, class = "try-error", condition = e))
#   .         }), base:::tryCatchList(expr, classes, parentenv, handlers),
#   .     base:::tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#   .     base:::doTryCatch(return(expr), name, parentenv, handler),
#   .     base::withCallingHandlers(withVisible(eval(expr, envir, enclos)),
#   .         warning = wHandler, error = eHandler, message = mHandler),
#   .     base::withVisible(eval(expr, envir, enclos)), base::eval(expr,
#   .         envir, enclos), base::eval(expr, envir, enclos), df %>%
#   .         emmeans_test(SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
#   .             p.adjust.method = "bonferroni"), rstatix::emmeans_test(.,
#   .         SQRTPercentagenotmoving ~ Treatment, covariate = DOA,
#   .         p.adjust.method = "bonferroni"), rstatix:::pairwise_emmeans_test(res.emmeans,
#   .         grouping.vars, method = method, p.adjust.method = p.adjust.method,
#   .         conf.level = conf.level), tidy(comparisons, conf.int = TRUE,
#   .         conf.level = conf.level) %>% add_column(std.error = std.error,
#   .         .after = "estimate"), tibble::add_column(., std.error = std.error,
#   .         .after = "estimate"), tibble:::set_repaired_names(out,
#   .         .name_repair), rlang::set_names(x, repaired_names(names2(x),
#   .         .name_repair = .name_repair, quiet = quiet)), tibble:::repaired_names(names2(x),
#   .         .name_repair = .name_repair, quiet = quiet), tibble:::subclass_name_repair_errors(name = name,
#   .         details = details, vec_as_names(name, repair = .name_repair,
#   .             quiet = quiet || !is_character(.name_repair))), base::withCallingHandlers(expr,
#   .         vctrs_error_names_cannot_be_empty = function(cnd) {
#   .             cnd <- error_column_names_cannot_be_empty(detect_empty_names(name),
#   .                 parent = cnd)
#   .             cnd$body <- details
#   .             cnd_signal(cnd)
#   .         }, vctrs_error_names_cannot_be_dot_dot = function(cnd) {
#   .             cnd <- error_column_names_cannot_be_dot_dot(detect_dot_dot(name),
#   .                 parent = cnd)
#   .             cnd_signal(cnd)
#   .         }, vctrs_error_names_must_be_unique = function(cnd) {
#   .             cnd <- error_column_names_must_be_unique(detect_duplicates(name),
#   .                 parent = cnd)
#   .             cnd_signal(cnd)
#   .         }), vctrs::vec_as_names(name, repair = .name_repair,
#   .         quiet = quiet || !is_character(.name_repair)), (function ()
#   .     validate_unique(names = names, arg = arg))(), vctrs:::validate_unique(names = names,
#   .         arg = arg), vctrs:::stop_names_must_be_unique(names,
#   .         arg), vctrs:::stop_names(class = "vctrs_error_names_must_be_unique",
#   .         arg = arg, names = names), vctrs:::stop_vctrs(class = c(class,
#   .         "vctrs_error_names"), ...)), parents = c(0L, 1L, 2L,
#   . 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L, 4L, 12L, 13L, 13L, 15L, 16L,
#   . 17L, 18L, 19L, 13L, 13L, 13L, 23L, 0L, 0L, 26L, 27L, 0L, 29L,
#   . 30L, 30L, 32L, 33L, 32L, 35L, 36L, 37L, 38L, 39L), indices = 1:40), class = "rlang_trace", version = 1L),
#   .     parent = NULL, arg = "", names = c("term", "contrast", "null.value",
#   .     "estimate", "std.error", "std.error", "df", "conf.low", "conf.high",
#   .     "statistic", "p.value")), class = c("vctrs_error_names_must_be_unique",
#   . "vctrs_error_names", "vctrs_error", "rlang_error", "error", "condition"
#   . )))
# 21. cnd_signal(cnd)
# 22. signal_abort(cnd)

# %%
sessionInfo()
# Out:
# R version 4.0.3 (2020-10-10)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 18363)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=French_Switzerland.1252  LC_CTYPE=French_Switzerland.1252
# [3] LC_MONETARY=French_Switzerland.1252 LC_NUMERIC=C
# [5] LC_TIME=French_Switzerland.1252
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] car_3.0-10      carData_3.0-4   reshape2_1.4.4  emmeans_1.5.4
#  [5] lmerTest_3.1-3  WRS2_1.1-0      rstatix_0.6.0   ggpubr_0.4.0
#  [9] broom_0.7.4     lme4_1.1-26     Matrix_1.2-18   modEvA_2.0
# [13] MASS_7.3-53     leaps_3.1       caret_6.0-86    lattice_0.20-41
# [17] forcats_0.5.1   stringr_1.4.0   dplyr_1.0.3     purrr_0.3.4
# [21] readr_1.4.0     tidyr_1.1.2     tibble_3.0.6    ggplot2_3.3.3
# [25] tidyverse_1.3.0 lindia_0.9      DHARMa_0.3.3.0
#
# loaded via a namespace (and not attached):
#  [1] minqa_1.2.4          colorspace_2.0-0     ggsignif_0.6.0
#  [4] ellipsis_0.3.1       class_7.3-17         rio_0.5.16
#  [7] estimability_1.3     IRdisplay_1.0        base64enc_0.1-3
# [10] fs_1.5.0             mc2d_0.1-18          rstudioapi_0.13
# [13] farver_2.0.3         mvtnorm_1.1-1        prodlim_2019.11.13
# [16] lubridate_1.7.9.2    xml2_1.3.2           codetools_0.2-16
# [19] splines_4.0.3        IRkernel_1.1.1       polynom_1.4-0
# [22] jsonlite_1.7.2       nloptr_1.2.2.2       pROC_1.17.0.1
# [25] dbplyr_2.1.0         compiler_4.0.3       httr_1.4.2
# [28] backports_1.2.0      assertthat_0.2.1     cli_2.3.0
# [31] htmltools_0.5.1.1    tools_4.0.3          gtable_0.3.0
# [34] glue_1.4.2           Rcpp_1.0.6           cellranger_1.1.0
# [37] vctrs_0.3.6          nlme_3.1-149         iterators_1.0.13
# [40] timeDate_3043.102    gower_0.2.2          ps_1.5.0
# [43] openxlsx_4.2.3       rvest_0.3.6          lifecycle_0.2.0
# [46] statmod_1.4.35       scales_1.1.1         ipred_0.9-9
# [49] hms_1.0.0            curl_4.3             gridExtra_2.3
# [52] rpart_4.1-15         reshape_0.8.8        stringi_1.5.3
# [55] foreach_1.5.1        boot_1.3-25          zip_2.1.1
# [58] lava_1.6.8.1         repr_1.1.3           rlang_0.4.10
# [61] pkgconfig_2.0.3      evaluate_0.14        labeling_0.4.2
# [64] recipes_0.1.15       tidyselect_1.1.0     plyr_1.8.6
# [67] magrittr_2.0.1       R6_2.5.0             generics_0.1.0
# [70] pbdZMQ_0.3-4         DBI_1.1.1            mgcv_1.8-33
# [73] pillar_1.4.7         haven_2.3.1          foreign_0.8-81
# [76] withr_2.4.1          survival_3.2-7       abind_1.4-5
# [79] nnet_7.3-14          modelr_0.1.8         crayon_1.4.0
# [82] uuid_0.1-4           grid_4.0.3           readxl_1.3.1
# [85] data.table_1.13.6    ModelMetrics_1.2.2.2 reprex_1.0.0
# [88] digest_0.6.27        xtable_1.8-4         numDeriv_2016.8-1.1
# [91] stats4_4.0.3         munsell_0.5.0
