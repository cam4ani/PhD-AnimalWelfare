# %%
library(lme4)
library(MCMCglmm)
library(broom)
library(nadiv)
library(tidyverse) #%>%
# Out:
# Warning message:
# "package 'lme4' was built under R version 3.6.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 3.6.3"
# Warning message:
# "package 'MCMCglmm' was built under R version 3.6.3"
# Loading required package: coda
#
# Warning message:
# "package 'coda' was built under R version 3.6.3"
# Loading required package: ape
#
# Warning message:
# "package 'ape' was built under R version 3.6.3"
# Warning message:
# "package 'nadiv' was built under R version 3.6.3"
#
# Attaching package: 'nadiv'
#
#
# The following object is masked from 'package:MCMCglmm':
#
#     prunePed
#
#
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# Warning message:
# "package 'tibble' was built under R version 3.6.3"
# Warning message:
# "package 'tidyr' was built under R version 3.6.3"
# Warning message:
# "package 'readr' was built under R version 3.6.3"
# Warning message:
# "package 'purrr' was built under R version 3.6.3"
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Warning message:
# "package 'stringr' was built under R version 3.6.3"
# Warning message:
# "package 'forcats' was built under R version 3.6.3"
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x tidyr::expand() masks Matrix::expand()
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# x tidyr::pack()   masks Matrix::pack()
# x tidyr::unpack() masks Matrix::unpack()

# %%
citation('MCMCglmm')
# Out:
# To cite MCMCglmm in publications use:
#
#   Jarrod D Hadfield (2010). MCMC Methods for Multi-Response Generalized
#   Linear Mixed Models: The MCMCglmm R Package. Journal of Statistical
#   Software, 33(2), 1-22. URL https://www.jstatsoft.org/v33/i02/.
#
# A BibTeX entry for LaTeX users is
#
#   @Article{,
#     title = {MCMC Methods for Multi-Response Generalized Linear Mixed Models: The {MCMCglmm} {R} Package},
#     author = {Jarrod D Hadfield},
#     journal = {Journal of Statistical Software},
#     year = {2010},
#     volume = {33},
#     number = {2},
#     pages = {1--22},
#     url = {https://www.jstatsoft.org/v33/i02/},
#   }

# %%
library(parallel)
my.cores = detectCores()

# %%
#FROM INTERNET!!!
clean.MCMC <- function(x) {
    sols <- summary(x)$solutions  ## pull out relevant info from model summary
    Gcovs <- summary(x)$Gcovariances
    Rcovs <- summary(x)$Rcovariances
    fixed <- data.frame(row.names(sols), sols, row.names = NULL)  ## convert to dataframes with the row.names as the first col
    random <- data.frame(row.names(Gcovs), Gcovs, row.names = NULL)
    residual <- data.frame(row.names(Rcovs), Rcovs, row.names = NULL)
    names(fixed)[names(fixed) == "row.names.sols."] <- "variable"  ## change the columns names to variable, so they all match
    names(random)[names(random) == "row.names.Gcovs."] <- "variable"
    names(residual)[names(residual) == "row.names.Rcovs."] <- "variable"
    fixed$effect <- "fixed"  ## add ID column for type of effect (fixed, random, residual)
    random$effect <- "random"
    residual$effect <- "residual"
    modelTerms <- as.data.frame(bind_rows(fixed, random, residual))  # merge it all together
}
getName.MCMC <- function(x) deparse(substitute(x))  # add the model name

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
path_adapt = file.path(path_,'Adaptability')
path_model = file.path(path_adapt,'repeatability_model')
df = read.csv(file.path(path_adapt,'df_MVT_4stat_BI.csv'), header = TRUE, sep = ";")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID) 
df$cDIB = as.integer(df$DIB_startat11)
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment)
#scale: mean-centering of the environmental variable so that intercepts reflect average values for the population and ind. 
df$temperature_C_avg_scale = scale(df$temperature_C_avg, center=TRUE, scale=TRUE)
df$time = scale(df$cDIB, center=FALSE, scale=TRUE)
df$time2 = poly(df$time, degree=2, raw=TRUE)[,2]
df$avgDIB_scale = scale(df$avgDIB, center=TRUE, scale=TRUE)
df$InitialWeight_scale = scale(df$InitialWeight, center=TRUE, scale=TRUE)

#setting reference group
contrasts(df$Treatment)
df <- df %>% mutate(Treatment = relevel(Treatment, ref = "TRAN"))
contrasts(df$Treatment)
contrasts(df$CLASS)
df <- df %>% mutate(CLASS = relevel(CLASS, ref = "LEXP"))
contrasts(df$CLASS)

print(dim(df))
summary(df)
head(df,3)
# Out:
#      TRAN
# OFH  0
# TRAN 1
#      OFH
# TRAN 0
# OFH  1
#      MEXP REXP
# LEXP 0    0
# MEXP 1    0
# REXP 0    1
#      MEXP REXP
# LEXP 0    0
# MEXP 1    0
# REXP 0    1
# [1] 3230   35
#      HenID           DIB         CLASS          PenID     temperature_C_avg
#  hen_116:  43   Min.   :11.00   LEXP: 965   pen10  :504   Min.   : 4.000
#  hen_124:  43   1st Qu.:23.00   MEXP:1379   pen11  :504   1st Qu.: 8.667
#  hen_127:  43   Median :33.00   REXP: 886   pen8   :430   Median :11.000
#  hen_136:  43   Mean   :33.59               pen9   :429   Mean   :10.838
#  hen_147:  43   3rd Qu.:44.00               pen4   :388   3rd Qu.:12.667
#  hen_151:  43   Max.   :54.00               pen5   :363   Max.   :19.333
#  (Other):2972                               (Other):612
#   tobeusedPCA     InitialWeight  Treatment   perc_duration_5_Zone
#  Min.   :0.0000   Min.   :1046   TRAN:1616   Min.   :  0.00
#  1st Qu.:0.0000   1st Qu.:1130   OFH :1614   1st Qu.: 11.00
#  Median :0.0000   Median :1164               Median : 33.00
#  Mean   :0.1734   Mean   :1169               Mean   : 39.21
#  3rd Qu.:0.0000   3rd Qu.:1200               3rd Qu.: 66.00
#  Max.   :1.0000   Max.   :1350               Max.   :100.00
#
#  perc_duration_4_Zone perc_duration_3_Zone perc_duration_2_Zone
#  Min.   : 0.000       Min.   : 0.00        Min.   : 0.00
#  1st Qu.: 4.000       1st Qu.: 7.00        1st Qu.:14.00
#  Median : 6.000       Median :17.00        Median :32.00
#  Mean   : 8.136       Mean   :18.27        Mean   :31.24
#  3rd Qu.:10.000       3rd Qu.:28.00        3rd Qu.:46.00
#  Max.   :73.000       Max.   :70.00        Max.   :91.00
#
#  perc_1_Zone_while_WG_open nbr_stays_2_Zone_perh nbr_stays_4_Zone_perh
#  Min.   : 0.000            Min.   :0.0000        Min.   :0.0000
#  1st Qu.: 0.000            1st Qu.:0.4545        1st Qu.:0.2857
#  Median : 1.388            Median :1.0714        Median :0.5714
#  Mean   : 6.932            Mean   :1.1062        Mean   :0.7059
#  3rd Qu.: 9.572            3rd Qu.:1.6667        3rd Qu.:1.0000
#  Max.   :87.949            Max.   :5.0909        Max.   :5.2500
#
#  nbr_stays_3_Zone_perh nbr_stays_5_Zone_perh nbr_stays_1_Zone_perh
#  Min.   :0.0000        Min.   :0.0000        Min.   :0.0000
#  1st Qu.:0.6923        1st Qu.:0.2000        1st Qu.:0.0000
#  Median :1.3333        Median :0.3571        Median :0.1622
#  Mean   :1.3227        Mean   :0.4352        Mean   :0.4060
#  3rd Qu.:1.8333        3rd Qu.:0.6000        3rd Qu.:0.6316
#  Max.   :5.1818        Max.   :3.1667        Max.   :3.5789
#
#  in_WG_15mnAfterOpening SleepingHeight  vertical_travel_distance_perh
#  Min.   :0.0000         Min.   :0.000   Min.   : 0.000
#  1st Qu.:0.0000         1st Qu.:2.000   1st Qu.: 2.286
#  Median :0.0000         Median :3.000   Median : 3.600
#  Mean   :0.2065         Mean   :2.481   Mean   : 3.595
#  3rd Qu.:0.0000         3rd Qu.:3.000   3rd Qu.: 4.800
#  Max.   :1.0000         Max.   :3.000   Max.   :12.308
#
#  DIB_startat11       avgDIB         severity        Feathers
#  Min.   : 0.00   Min.   :21.91   Min.   : 6.00   Min.   :35.00
#  1st Qu.:12.00   1st Qu.:21.91   1st Qu.:24.00   1st Qu.:58.67
#  Median :22.00   Median :22.36   Median :36.00   Median :66.33
#  Mean   :22.59   Mean   :22.59   Mean   :35.72   Mean   :65.81
#  3rd Qu.:33.00   3rd Qu.:23.00   3rd Qu.:46.00   3rd Qu.:73.67
#  Max.   :43.00   Max.   :24.18   Max.   :84.00   Max.   :86.67
#                                                  NA's   :42
#       PC1          nbr_daysnomvt_over_3days Predictability_mean
#  Min.   :-1.7397   Min.   :0.0000           Min.   :-1.6899
#  1st Qu.:-0.6194   1st Qu.:0.0000           1st Qu.:-1.1798
#  Median : 0.3173   Median :0.0000           Median :-1.0246
#  Mean   : 0.1554   Mean   :0.5582           Mean   :-1.0302
#  3rd Qu.: 0.8750   3rd Qu.:1.0000           3rd Qu.:-0.8581
#  Max.   : 2.9867   Max.   :3.0000           Max.   :-0.5534
#
#  Predictability_sd      cDIB       temperature_C_avg_scale.V1
#  Min.   :0.06994   Min.   : 0.00   Min.   :-2.1505151
#  1st Qu.:0.09715   1st Qu.:12.00   1st Qu.:-0.6829345
#  Median :0.11018   Median :22.00   Median : 0.0508558
#  Mean   :0.11283   Mean   :22.59   Mean   : 0.0000000
#  3rd Qu.:0.12822   3rd Qu.:33.00   3rd Qu.: 0.5749917
#  Max.   :0.19202   Max.   :43.00   Max.   : 2.6715354
#
#        time.V1           time2          avgDIB_scale.V1
#  Min.   :0.0000000   Min.   :0.0000   Min.   :-1.0681873
#  1st Qu.:0.4662313   1st Qu.:0.2174   1st Qu.:-1.0681873
#  Median :0.8547574   Median :0.7306   Median :-0.3677554
#  Mean   :0.8778164   Mean   :0.9997   Mean   : 0.0000000
#  3rd Qu.:1.2821361   3rd Qu.:1.6439   3rd Qu.: 0.6324925
#  Max.   :1.6706623   Max.   :2.7911   Max.   : 2.4750543
#
#  InitialWeight_scale.V1
#  Min.   :-1.9742093
#  1st Qu.:-0.6252286
#  Median :-0.0792126
#  Mean   : 0.0000000
#  3rd Qu.: 0.4989220
#  Max.   : 2.9078162
#   HenID   DIB CLASS PenID temperature_C_avg tobeusedPCA InitialWeight Treatment
# 1 hen_134 11  MEXP  pen10 11.50000          1           1112          TRAN
# 2 hen_134 12  MEXP  pen10 10.16667          0           1112          TRAN
# 3 hen_134 13  MEXP  pen10  9.00000          0           1112          TRAN
#   perc_duration_5_Zone perc_duration_4_Zone ... PC1
# 1 100                  0                    ... -1.738433
# 2  86                  0                    ... -1.455477
# 3 100                  0                    ... -1.738433
#   nbr_daysnomvt_over_3days Predictability_mean Predictability_sd cDIB
# 1 1                        -0.8601897          0.0958994         0
# 2 1                        -0.8601897          0.0958994         1
# 3 1                        -0.8601897          0.0958994         2
#   temperature_C_avg_scale time       time2       avgDIB_scale
# 1  0.2080966              0.00000000 0.000000000 -0.3677554
# 2 -0.2112122              0.03885261 0.001509525 -0.3677554
# 3 -0.5781073              0.07770522 0.006038101 -0.3677554
#   InitialWeight_scale
# 1 -0.9142959
# 2 -0.9142959
# 3 -0.9142959

# %%
length(unique(df[['HenID']]))
# Out:
# [1] 80

# %%
nsamp = 7000 #check EffctSize almost this number
thin = 100
nitt = nsamp * thin
nitt
burn = nitt*0.15
burn
# Out:
# [1] 7e+05
# [1] 105000

# %% [markdown]
# # KB Severity

# %% [raw]
# default: a single chain. If we want two, we have to run it twice.

# %%
#R: 2 response, 2 residuals
#QUESTION: nu=0.002 or 1.002
#G: only G1: only one random effect: of size 4: trait (2), cdib (1) and cdib2 (1)
prior_biv = list(R = list(V = diag(c(1, 0.0001), 2, 2), nu = 1.002, fix = 2),
                 G = list(G1 = list(V = diag(4),
                                        nu = 4,
                                        alpha.mu = rep(0,4),
                                        alpha.V = diag(25^2,4,4))))

#trait:scale: interact trait with fixed effects to get estimates for the effect of these variables on each of our mvt var
#"trait-1" tells the model to give us a distinct intercept for each trait"
#us: unstructured covariance matrix for the grouping variable henid: to calculate the variance in mvt var 1 due to differences among individuals, the varianc ein mvtvar2 due to differences among individulas and the covariance between these variances.
#rcov: idh: as we dont want COV_pc1:severity, as severity has not repeated measure on individuals
#random: unstructure covariance matrix of effects (intercepts & slope DIB), meaning that we fit variance in intercetps, in slopes but also their covariance: we want to know their correlations!
#random: without both trait with intercept, we wont be able to compute the correlation we want to! as we need the health intercept!
set.seed(123)
BV_model_S2 = MCMCglmm(cbind(PC1, severity) ~ trait-1 +
                       trait:Treatment + 
                       at.level(trait,1):time +
                       at.level(trait,1):time2 +
                       at.level(trait,1):temperature_C_avg_scale +
                       at.level(trait,2):Predictability_mean +
                       at.level(trait,2):nbr_daysnomvt_over_3days +
                       at.level(trait,2):InitialWeight_scale +
                       at.level(trait,2):CLASS,
                       random=~us(trait + at.level(trait,1):time + at.level(trait,1):time2):HenID, 
                       rcov=~idh(trait):units, 
                       family=c("gaussian","gaussian"),
                       prior=prior_biv,
                       data=df,
                       pr = TRUE, verbose = TRUE, saveX = TRUE, saveZ = TRUE,thin = thin, burnin= burn, nitt= nitt)
#G-structure: random effects (co)variances
#R-structure : the residual (co)variances, 
#Location : fixed effects results information
plot(BV_model_S2$VCV)
#trace plots for fixed effect
plot(BV_model_S2$Sol)
summary(BV_model_S2)

#################################### correlations HA & random effects
###correlation between intercept and health###
corr_int_health = BV_model_S2$VCV[,"traitseverity:traitPC1.HenID"]/
  (sqrt(BV_model_S2$VCV[,"traitseverity:traitseverity.HenID"])*
     sqrt(BV_model_S2$VCV[,"traitPC1:traitPC1.HenID"]))
posterior.mode(corr_int_health)
HPDinterval(corr_int_health)

###correlation between linear slope and health###
corr_Lslope_health = BV_model_S2$VCV[,"at.level(trait, 1):time:traitseverity.HenID"]/
  (sqrt(BV_model_S2$VCV[,"traitseverity:traitseverity.HenID"])*
     sqrt(BV_model_S2$VCV[,"at.level(trait, 1):time:at.level(trait, 1):time.HenID"]))
posterior.mode(corr_Lslope_health)
HPDinterval(corr_Lslope_health)

###correlation between quadratic slope and health###
corr_Qslope_health = BV_model_S2$VCV[,"at.level(trait, 1):time2:traitseverity.HenID"]/
  (sqrt(BV_model_S2$VCV[,"traitseverity:traitseverity.HenID"])*
     sqrt(BV_model_S2$VCV[,"at.level(trait, 1):time2:at.level(trait, 1):time2.HenID"]))
posterior.mode(corr_Lslope_health)
HPDinterval(corr_Lslope_health)

#save
df_saved = clean.MCMC(BV_model_S2)  # get all the info from summary(modelName)
df_saved$modelName = getName.MCMC(BV_model_S2)  # add the model's name in a new column
head(df_saved,3)  # check out the created dataframe
write.csv(df_saved, file.path(path_adapt,'BV_model_severity_nopen.csv'))

# %%
autocorr.diag(BV_model_S2$Sol)
# Out:
#          traitPC1     traitseverity traitPC1:TreatmentOFH
# Lag 0     1.000000000  1.000000000   1.000000000
# Lag 100  -0.009457706 -0.010192019  -0.016711243
# Lag 500  -0.016359910  0.004401394  -0.032361185
# Lag 1000 -0.017757445  0.004403815  -0.001673224
# Lag 5000  0.002923431  0.006124556   0.026525646
#          traitseverity:TreatmentOFH at.level(trait, 1):time
# Lag 0     1.000000000                1.00000000
# Lag 100   0.002223838               -0.01865035
# Lag 500   0.020411038               -0.02229381
# Lag 1000 -0.040985909               -0.01932451
# Lag 5000  0.002997904                0.02292128
#          at.level(trait, 1):time2 at.level(trait, 1):temperature_C_avg_scale
# Lag 0     1.000000000              1.000000000
# Lag 100  -0.017438509             -0.009752662
# Lag 500  -0.021284373             -0.008895673
# Lag 1000 -0.008715528              0.010110857
# Lag 5000  0.013966697              0.014385337
#          at.level(trait, 2):Predictability_mean
# Lag 0     1.000000000
# Lag 100  -0.009068829
# Lag 500  -0.003188259
# Lag 1000  0.006640196
# Lag 5000  0.004280546
#          at.level(trait, 2):nbr_daysnomvt_over_3days
# Lag 0     1.000000000
# Lag 100   0.014177168
# Lag 500  -0.014748596
# Lag 1000 -0.001980237
# Lag 5000  0.010484452
#          at.level(trait, 2):InitialWeight_scale ...
# Lag 0     1.000000000                           ...
# Lag 100   0.014618411                           ...
# Lag 500  -0.012786065                           ...
# Lag 1000 -0.007488541                           ...
# Lag 5000  0.013720525                           ...
#          at.level(trait, 1):time2.HenID.hen_84
# Lag 0     1.000000000
# Lag 100   0.011391549
# Lag 500   0.002483822
# Lag 1000 -0.017468095
# Lag 5000 -0.009848587
#          at.level(trait, 1):time2.HenID.hen_85
# Lag 0     1.0000000000
# Lag 100  -0.0005875607
# Lag 500   0.0030335068
# Lag 1000 -0.0068825000
# Lag 5000 -0.0220051148
#          at.level(trait, 1):time2.HenID.hen_87
# Lag 0     1.0000000000
# Lag 100  -0.0028267444
# Lag 500   0.0006811113
# Lag 1000  0.0020993418
# Lag 5000  0.0100819296
#          at.level(trait, 1):time2.HenID.hen_9
# Lag 0     1.000000000
# Lag 100  -0.031797655
# Lag 500  -0.011559151
# Lag 1000 -0.007580717
# Lag 5000  0.025553214
#          at.level(trait, 1):time2.HenID.hen_90
# Lag 0     1.000000000
# Lag 100  -0.035435033
# Lag 500   0.001917651
# Lag 1000  0.027244738
# Lag 5000  0.028344787
#          at.level(trait, 1):time2.HenID.hen_92
# Lag 0     1.000000000
# Lag 100  -0.016226726
# Lag 500   0.007618605
# Lag 1000  0.004242571
# Lag 5000 -0.023162022
#          at.level(trait, 1):time2.HenID.hen_95
# Lag 0     1.000000000
# Lag 100  -0.013271756
# Lag 500  -0.018137694
# Lag 1000  0.006411496
# Lag 5000 -0.021672637
#          at.level(trait, 1):time2.HenID.hen_97
# Lag 0     1.0000000000
# Lag 100  -0.0226357303
# Lag 500   0.0229521694
# Lag 1000 -0.0133234600
# Lag 5000 -0.0004332142
#          at.level(trait, 1):time2.HenID.hen_98
# Lag 0     1.000000000
# Lag 100  -0.005476304
# Lag 500   0.002441483
# Lag 1000  0.005895218
# Lag 5000 -0.027518365
#          at.level(trait, 1):time2.HenID.hen_99
# Lag 0     1.000000000
# Lag 100  -0.010683045
# Lag 500  -0.005778494
# Lag 1000 -0.002408906
# Lag 5000 -0.014067276

# %%
autocorr.diag(BV_model_S2$Sol[,1:9]) #8 fixed effect and intercept
autocorr.diag(BV_model_S2$VCV)
# Out:
#          traitPC1     traitseverity traitPC1:TreatmentOFH
# Lag 0     1.000000000  1.000000000   1.000000000
# Lag 100  -0.009457706 -0.010192019  -0.016711243
# Lag 500  -0.016359910  0.004401394  -0.032361185
# Lag 1000 -0.017757445  0.004403815  -0.001673224
# Lag 5000  0.002923431  0.006124556   0.026525646
#          traitseverity:TreatmentOFH at.level(trait, 1):time
# Lag 0     1.000000000                1.00000000
# Lag 100   0.002223838               -0.01865035
# Lag 500   0.020411038               -0.02229381
# Lag 1000 -0.040985909               -0.01932451
# Lag 5000  0.002997904                0.02292128
#          at.level(trait, 1):time2 at.level(trait, 1):temperature_C_avg_scale
# Lag 0     1.000000000              1.000000000
# Lag 100  -0.017438509             -0.009752662
# Lag 500  -0.021284373             -0.008895673
# Lag 1000 -0.008715528              0.010110857
# Lag 5000  0.013966697              0.014385337
#          at.level(trait, 2):Predictability_mean
# Lag 0     1.000000000
# Lag 100  -0.009068829
# Lag 500  -0.003188259
# Lag 1000  0.006640196
# Lag 5000  0.004280546
#          at.level(trait, 2):nbr_daysnomvt_over_3days
# Lag 0     1.000000000
# Lag 100   0.014177168
# Lag 500  -0.014748596
# Lag 1000 -0.001980237
# Lag 5000  0.010484452
#          traitPC1:traitPC1.HenID traitseverity:traitPC1.HenID
# Lag 0     1.0000000000           1.000000000
# Lag 100   0.0106786338           0.014656618
# Lag 500   0.0004138137           0.009173109
# Lag 1000  0.0102558414           0.017982454
# Lag 5000 -0.0047950083           0.008420184
#          at.level(trait, 1):time:traitPC1.HenID
# Lag 0     1.000000000
# Lag 100  -0.009035705
# Lag 500  -0.008301581
# Lag 1000  0.006123609
# Lag 5000  0.001431131
#          at.level(trait, 1):time2:traitPC1.HenID traitPC1:traitseverity.HenID
# Lag 0     1.0000000000                           1.000000000
# Lag 100  -0.0103418170                           0.014656618
# Lag 500   0.0023199508                           0.009173109
# Lag 1000  0.0031901856                           0.017982454
# Lag 5000  0.0002752549                           0.008420184
#          traitseverity:traitseverity.HenID
# Lag 0     1.000000000
# Lag 100  -0.008611092
# Lag 500  -0.033004029
# Lag 1000 -0.011005427
# Lag 5000 -0.003194688
#          at.level(trait, 1):time:traitseverity.HenID
# Lag 0     1.0000000000
# Lag 100  -0.0024747852
# Lag 500   0.0008599359
# Lag 1000 -0.0106664689
# Lag 5000  0.0094255107
#          at.level(trait, 1):time2:traitseverity.HenID
# Lag 0     1.000000000
# Lag 100  -0.004997281
# Lag 500   0.008941187
# Lag 1000 -0.013330740
# Lag 5000 -0.001750832
#          traitPC1:at.level(trait, 1):time.HenID
# Lag 0     1.000000000
# Lag 100  -0.009035705
# Lag 500  -0.008301581
# Lag 1000  0.006123609
# Lag 5000  0.001431131
#          traitseverity:at.level(trait, 1):time.HenID
# Lag 0     1.0000000000
# Lag 100  -0.0024747852
# Lag 500   0.0008599359
# Lag 1000 -0.0106664689
# Lag 5000  0.0094255107
#          at.level(trait, 1):time:at.level(trait, 1):time.HenID
# Lag 0     1.000000000
# Lag 100  -0.009497314
# Lag 500   0.006851306
# Lag 1000 -0.004337905
# Lag 5000  0.003461067
#          at.level(trait, 1):time2:at.level(trait, 1):time.HenID
# Lag 0     1.000000000
# Lag 100  -0.013557215
# Lag 500   0.010916834
# Lag 1000 -0.005775590
# Lag 5000  0.006376492
#          traitPC1:at.level(trait, 1):time2.HenID
# Lag 0     1.0000000000
# Lag 100  -0.0103418170
# Lag 500   0.0023199508
# Lag 1000  0.0031901856
# Lag 5000  0.0002752549
#          traitseverity:at.level(trait, 1):time2.HenID
# Lag 0     1.000000000
# Lag 100  -0.004997281
# Lag 500   0.008941187
# Lag 1000 -0.013330740
# Lag 5000 -0.001750832
#          at.level(trait, 1):time:at.level(trait, 1):time2.HenID
# Lag 0     1.000000000
# Lag 100  -0.013557215
# Lag 500   0.010916834
# Lag 1000 -0.005775590
# Lag 5000  0.006376492
#          at.level(trait, 1):time2:at.level(trait, 1):time2.HenID traitPC1.units
# Lag 0     1.000000000                                             1.000000000
# Lag 100  -0.016442113                                             0.010267715
# Lag 500   0.007482445                                            -0.003501670
# Lag 1000  0.001284267                                             0.003569889
# Lag 5000  0.008178534                                            -0.008838825
#          traitseverity.units
# Lag 0    1.0000000
# Lag 100  0.9998319
# Lag 500  0.9991597
# Lag 1000 0.9983193
# Lag 5000 0.9915966

# %%
path_adapt = 'C:/Users/camil/Desktop/animals_code/PhD-AnimalWelfare/Chapter1-EarlyMovementLateHealth/FICHIER'
save(BV_model_S2, file = file.path(path_adapt,"BV_model_severity_nopen.RData"))
#load(coda.samples.RData)

# %% [markdown]
# # Check model cvg - 3 chains

# %% [raw]
# gelman: #https://r-sig-mixed-models.r-project.narkive.com/rGHgRMmI/r-sig-me-convergence-diagnostics-for-mcmcglmm:
# #"Ideally the models should have over-dispersed starting values, which you can specify in the start argument"
# #Values substantially above 1 indicate lack of convergence. If the chains have not converged, Bayesian credible intervals
# #based on the t-distribution are too wide, and have the potential to shrink by this factor if the MCMC run is continued.""
#
# If you want over-dispersed starting values to make sure the chain is converging to the same distribution you can  specify starting values in the start argument of MCMCglmm.  start=list(QUASI=FALSE) is a quick way of getting sei-overdispersed  starting values.
# from: https://www.r-bloggers.com/2011/12/mcmc-chain-analysis-and-convergence-diagnostics-with-coda-in-r/
# "The gelman.diag gives you the scale reduction factors for each parameter. A factor of 1 means that between variance and within chain variance are equal, larger values mean that there is still a notable difference between chains. Often, it is said that everything below 1.1 or so is OK, but note that this is more a rule of thumb. The gelman,plot shows you the development of the scale-reduction over time (chain steps), which is useful to see whether a low chain reduction is also stable (sometimes, the factors go down and then up again, as you will see). Also, note that for any real analysis, you have to make sure to discard any bias that arises from the starting point of your chain (burn-in), typical values here are a few 1000-10000 steps. The gelman plot is also a nice tool to see roughly where this point is, that is, from which point on the chains seem roughly converged."
#
#
# geweke:
# The Geweke diagnostic is pretty simple. It compares the mean of the samples drawn from the end of a chain of MCMC output to the mean of the samples at the beginning of the chain using a z-test like statistic. The variance of the two means is computed using spectral densities (b/c the MCMC output is not independent).
#
# As for a cut-off you can compare to the standard normal critical values zα/2 where α=0.05 or something similar.

# %%
#trait:scale: interact trait with fixed effects to get estimates for the effect of these variables on each of our mvt var
#"trait-1" tells the model to give us a distinct intercept for each trait"
#us: unstructured covariance matrix for the grouping variable henid: to calculate the variance in mvt var 1 due to differences among individuals, the varianc ein mvtvar2 due to differences among individulas and the covariance between these variances.
#rcov: idh: as we dont want COV_pc1:severity, as severity has not repeated measure on individuals
#random: unstructure covariance matrix of effects (intercepts & slope DIB), meaning that we fit variance in intercetps, in slopes but also their covariance: we want to know their correlations!
#random: without both trait with intercept, we wont be able to compute the correlation we want to! as we need the health intercept!
chain1 = MCMCglmm(cbind(PC1, severity) ~ trait-1 +
                       trait:Treatment + 
                       at.level(trait,1):time +
                       at.level(trait,1):time2 +
                       at.level(trait,1):temperature_C_avg_scale +
                       at.level(trait,2):Predictability_mean +
                       at.level(trait,2):nbr_daysnomvt_over_3days +
                       at.level(trait,2):InitialWeight_scale +
                       at.level(trait,2):CLASS,
                       random=~us(trait + at.level(trait,1):time + at.level(trait,1):time2):HenID, 
                       rcov=~idh(trait):units, 
                       family=c("gaussian","gaussian"),
                       prior=prior_biv,
                       data=df,
                       pr = TRUE, verbose = TRUE, saveX = TRUE, saveZ = TRUE,thin = thin, burnin= burn, nitt= nitt)
summary(chain1)

chain2 = MCMCglmm(cbind(PC1, severity) ~ trait-1 +
                       trait:Treatment + 
                       at.level(trait,1):time +
                       at.level(trait,1):time2 +
                       at.level(trait,1):temperature_C_avg_scale +
                       at.level(trait,2):Predictability_mean +
                       at.level(trait,2):nbr_daysnomvt_over_3days +
                       at.level(trait,2):InitialWeight_scale +
                       at.level(trait,2):CLASS,
                       random=~us(trait + at.level(trait,1):time + at.level(trait,1):time2):HenID, 
                       rcov=~idh(trait):units, 
                       family=c("gaussian","gaussian"),
                       prior=prior_biv,
                       data=df,
                       pr = TRUE, verbose = TRUE, saveX = TRUE, saveZ = TRUE,thin = thin, burnin= burn, nitt= nitt)
summary(chain2)

chain3 = MCMCglmm(cbind(PC1, severity) ~ trait-1 +
                       trait:Treatment + 
                       at.level(trait,1):time +
                       at.level(trait,1):time2 +
                       at.level(trait,1):temperature_C_avg_scale +
                       at.level(trait,2):Predictability_mean +
                       at.level(trait,2):nbr_daysnomvt_over_3days +
                       at.level(trait,2):InitialWeight_scale +
                       at.level(trait,2):CLASS,
                       random=~us(trait + at.level(trait,1):time + at.level(trait,1):time2):HenID, 
                       rcov=~idh(trait):units, 
                       family=c("gaussian","gaussian"),
                       prior=prior_biv,
                       data=df,
                       pr = TRUE, verbose = TRUE, saveX = TRUE, saveZ = TRUE,thin = thin, burnin= burn, nitt= nitt)
summary(chain3)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#
#                        MCMC iteration = 61000
#
#                        MCMC iteration = 62000
#
#                        MCMC iteration = 63000
#
#                        MCMC iteration = 64000
#
#                        MCMC iteration = 65000
#
#                        MCMC iteration = 66000
#
#                        MCMC iteration = 67000
#
#                        MCMC iteration = 68000
#
#                        MCMC iteration = 69000
#
#                        MCMC iteration = 70000
#
#                        MCMC iteration = 71000
#
#                        MCMC iteration = 72000
#
#                        MCMC iteration = 73000
#
#                        MCMC iteration = 74000
#
#                        MCMC iteration = 75000
#
#                        MCMC iteration = 76000
#
#                        MCMC iteration = 77000
#
#                        MCMC iteration = 78000
#
#                        MCMC iteration = 79000
#
#                        MCMC iteration = 80000
#
#                        MCMC iteration = 81000
#
#                        MCMC iteration = 82000
#
#                        MCMC iteration = 83000
#
#                        MCMC iteration = 84000
#
#                        MCMC iteration = 85000
#
#                        MCMC iteration = 86000
#
#                        MCMC iteration = 87000
#
#                        MCMC iteration = 88000
#
#                        MCMC iteration = 89000
#
#                        MCMC iteration = 90000
#
#                        MCMC iteration = 91000
#
#                        MCMC iteration = 92000
#
#                        MCMC iteration = 93000
#
#                        MCMC iteration = 94000
#
#                        MCMC iteration = 95000
#
#                        MCMC iteration = 96000
#
#                        MCMC iteration = 97000
#
#                        MCMC iteration = 98000
#
#                        MCMC iteration = 99000
#
#                        MCMC iteration = 100000
#
#                        MCMC iteration = 101000
#
#                        MCMC iteration = 102000
#
#                        MCMC iteration = 103000
#
#                        MCMC iteration = 104000
#
#                        MCMC iteration = 105000
#
#                        MCMC iteration = 106000
#
#                        MCMC iteration = 107000
#
#                        MCMC iteration = 108000
#
#                        MCMC iteration = 109000
#
#                        MCMC iteration = 110000
#
#                        MCMC iteration = 111000
#
#                        MCMC iteration = 112000
#
#                        MCMC iteration = 113000
#
#                        MCMC iteration = 114000
#
#                        MCMC iteration = 115000
#
#                        MCMC iteration = 116000
#
#                        MCMC iteration = 117000
#
#                        MCMC iteration = 118000
#
#                        MCMC iteration = 119000
#
#                        MCMC iteration = 120000
#
#                        MCMC iteration = 121000
#
#                        MCMC iteration = 122000
#
#                        MCMC iteration = 123000
#
#                        MCMC iteration = 124000
#
#                        MCMC iteration = 125000
#
#                        MCMC iteration = 126000
#
#                        MCMC iteration = 127000
#
#                        MCMC iteration = 128000
#
#                        MCMC iteration = 129000
#
#                        MCMC iteration = 130000
#
#                        MCMC iteration = 131000
#
#                        MCMC iteration = 132000
#
#                        MCMC iteration = 133000
#
#                        MCMC iteration = 134000
#
#                        MCMC iteration = 135000
#
#                        MCMC iteration = 136000
#
#                        MCMC iteration = 137000
#
#                        MCMC iteration = 138000
#
#                        MCMC iteration = 139000
#
#                        MCMC iteration = 140000
#
#                        MCMC iteration = 141000
#
#                        MCMC iteration = 142000
#
#                        MCMC iteration = 143000
#
#                        MCMC iteration = 144000
#
#                        MCMC iteration = 145000
#
#                        MCMC iteration = 146000
#
#                        MCMC iteration = 147000
#
#                        MCMC iteration = 148000
#
#                        MCMC iteration = 149000
#
#                        MCMC iteration = 150000
#
#                        MCMC iteration = 151000
#
#                        MCMC iteration = 152000
#
#                        MCMC iteration = 153000
#
#                        MCMC iteration = 154000
#
#                        MCMC iteration = 155000
#
#                        MCMC iteration = 156000
#
#                        MCMC iteration = 157000
#
#                        MCMC iteration = 158000
#
#                        MCMC iteration = 159000
#
#                        MCMC iteration = 160000
#
#                        MCMC iteration = 161000
#
#                        MCMC iteration = 162000
#
#                        MCMC iteration = 163000
#
#                        MCMC iteration = 164000
#
#                        MCMC iteration = 165000
#
#                        MCMC iteration = 166000
#
#                        MCMC iteration = 167000
#
#                        MCMC iteration = 168000
#
#                        MCMC iteration = 169000
#
#                        MCMC iteration = 170000
#
#                        MCMC iteration = 171000
#
#                        MCMC iteration = 172000
#
#                        MCMC iteration = 173000
#
#                        MCMC iteration = 174000
#
#                        MCMC iteration = 175000
#
#                        MCMC iteration = 176000
#
#                        MCMC iteration = 177000
#
#                        MCMC iteration = 178000
#
#                        MCMC iteration = 179000
#
#                        MCMC iteration = 180000
#
#                        MCMC iteration = 181000
#
#                        MCMC iteration = 182000
#
#                        MCMC iteration = 183000
#
#                        MCMC iteration = 184000
#
#                        MCMC iteration = 185000
#
#                        MCMC iteration = 186000
#
#                        MCMC iteration = 187000
#
#                        MCMC iteration = 188000
#
#                        MCMC iteration = 189000
#
#                        MCMC iteration = 190000
#
#                        MCMC iteration = 191000
#
#                        MCMC iteration = 192000
#
#                        MCMC iteration = 193000
#
#                        MCMC iteration = 194000
#
#                        MCMC iteration = 195000
#
#                        MCMC iteration = 196000
#
#                        MCMC iteration = 197000
#
#                        MCMC iteration = 198000
#
#                        MCMC iteration = 199000
#
#                        MCMC iteration = 200000
#
#                        MCMC iteration = 201000
#
#                        MCMC iteration = 202000
#
#                        MCMC iteration = 203000
#
#                        MCMC iteration = 204000
#
#                        MCMC iteration = 205000
#
#                        MCMC iteration = 206000
#
#                        MCMC iteration = 207000
#
#                        MCMC iteration = 208000
#
#                        MCMC iteration = 209000
#
#                        MCMC iteration = 210000
#
#                        MCMC iteration = 211000
#
#                        MCMC iteration = 212000
#
#                        MCMC iteration = 213000
#
#                        MCMC iteration = 214000
#
#                        MCMC iteration = 215000
#
#                        MCMC iteration = 216000
#
#                        MCMC iteration = 217000
#
#                        MCMC iteration = 218000
#
#                        MCMC iteration = 219000
#
#                        MCMC iteration = 220000
#
#                        MCMC iteration = 221000
#
#                        MCMC iteration = 222000
#
#                        MCMC iteration = 223000
#
#                        MCMC iteration = 224000
#
#                        MCMC iteration = 225000
#
#                        MCMC iteration = 226000
#
#                        MCMC iteration = 227000
#
#                        MCMC iteration = 228000
#
#                        MCMC iteration = 229000
#
#                        MCMC iteration = 230000
#
#                        MCMC iteration = 231000
#
#                        MCMC iteration = 232000
#
#                        MCMC iteration = 233000
#
#                        MCMC iteration = 234000
#
#                        MCMC iteration = 235000
#
#                        MCMC iteration = 236000
#
#                        MCMC iteration = 237000
#
#                        MCMC iteration = 238000
#
#                        MCMC iteration = 239000
#
#                        MCMC iteration = 240000
#
#                        MCMC iteration = 241000
#
#                        MCMC iteration = 242000
#
#                        MCMC iteration = 243000
#
#                        MCMC iteration = 244000
#
#                        MCMC iteration = 245000
#
#                        MCMC iteration = 246000
#
#                        MCMC iteration = 247000
#
#                        MCMC iteration = 248000
#
#                        MCMC iteration = 249000
#
#                        MCMC iteration = 250000
#
#                        MCMC iteration = 251000
#
#                        MCMC iteration = 252000
#
#                        MCMC iteration = 253000
#
#                        MCMC iteration = 254000
#
#                        MCMC iteration = 255000
#
#                        MCMC iteration = 256000
#
#                        MCMC iteration = 257000
#
#                        MCMC iteration = 258000
#
#                        MCMC iteration = 259000
#
#                        MCMC iteration = 260000
#
#                        MCMC iteration = 261000
#
#                        MCMC iteration = 262000
#
#                        MCMC iteration = 263000
#
#                        MCMC iteration = 264000
#
#                        MCMC iteration = 265000
#
#                        MCMC iteration = 266000
#
#                        MCMC iteration = 267000
#
#                        MCMC iteration = 268000
#
#                        MCMC iteration = 269000
#
#                        MCMC iteration = 270000
#
#                        MCMC iteration = 271000
#
#                        MCMC iteration = 272000
#
#                        MCMC iteration = 273000
#
#                        MCMC iteration = 274000
#
#                        MCMC iteration = 275000
#
#                        MCMC iteration = 276000
#
#                        MCMC iteration = 277000
#
#                        MCMC iteration = 278000
#
#                        MCMC iteration = 279000
#
#                        MCMC iteration = 280000
#
#                        MCMC iteration = 281000
#
#                        MCMC iteration = 282000
#
#                        MCMC iteration = 283000
#
#                        MCMC iteration = 284000
#
#                        MCMC iteration = 285000
#
#                        MCMC iteration = 286000
#
#                        MCMC iteration = 287000
#
#                        MCMC iteration = 288000
#
#                        MCMC iteration = 289000
#
#                        MCMC iteration = 290000
#
#                        MCMC iteration = 291000
#
#                        MCMC iteration = 292000
#
#                        MCMC iteration = 293000
#
#                        MCMC iteration = 294000
#
#                        MCMC iteration = 295000
#
#                        MCMC iteration = 296000
#
#                        MCMC iteration = 297000
#
#                        MCMC iteration = 298000
#
#                        MCMC iteration = 299000
#
#                        MCMC iteration = 300000
#
#                        MCMC iteration = 301000
#
#                        MCMC iteration = 302000
#
#                        MCMC iteration = 303000
#
#                        MCMC iteration = 304000
#
#                        MCMC iteration = 305000
#
#                        MCMC iteration = 306000
#
#                        MCMC iteration = 307000
#
#                        MCMC iteration = 308000
#
#                        MCMC iteration = 309000
#
#                        MCMC iteration = 310000
#
#                        MCMC iteration = 311000
#
#                        MCMC iteration = 312000
#
#                        MCMC iteration = 313000
#
#                        MCMC iteration = 314000
#
#                        MCMC iteration = 315000
#
#                        MCMC iteration = 316000
#
#                        MCMC iteration = 317000
#
#                        MCMC iteration = 318000
#
#                        MCMC iteration = 319000
#
#                        MCMC iteration = 320000
#
#                        MCMC iteration = 321000
#
#                        MCMC iteration = 322000
#
#                        MCMC iteration = 323000
#
#                        MCMC iteration = 324000
#
#                        MCMC iteration = 325000
#
#                        MCMC iteration = 326000
#
#                        MCMC iteration = 327000
#
#                        MCMC iteration = 328000
#
#                        MCMC iteration = 329000
#
#                        MCMC iteration = 330000
#
#                        MCMC iteration = 331000
#
#                        MCMC iteration = 332000
#
#                        MCMC iteration = 333000
#
#                        MCMC iteration = 334000
#
#                        MCMC iteration = 335000
#
#                        MCMC iteration = 336000
#
#                        MCMC iteration = 337000
#
#                        MCMC iteration = 338000
#
#                        MCMC iteration = 339000
#
#                        MCMC iteration = 340000
#
#                        MCMC iteration = 341000
#
#                        MCMC iteration = 342000
#
#                        MCMC iteration = 343000
#
#                        MCMC iteration = 344000
#
#                        MCMC iteration = 345000
#
#                        MCMC iteration = 346000
#
#                        MCMC iteration = 347000
#
#                        MCMC iteration = 348000
#
#                        MCMC iteration = 349000
#
#                        MCMC iteration = 350000
#
#                        MCMC iteration = 351000
#
#                        MCMC iteration = 352000
#
#                        MCMC iteration = 353000
#
#                        MCMC iteration = 354000
#
#                        MCMC iteration = 355000
#
#                        MCMC iteration = 356000
#
#                        MCMC iteration = 357000
#
#                        MCMC iteration = 358000
#
#                        MCMC iteration = 359000
#
#                        MCMC iteration = 360000
#
#                        MCMC iteration = 361000
#
#                        MCMC iteration = 362000
#
#                        MCMC iteration = 363000
#
#                        MCMC iteration = 364000
#
#                        MCMC iteration = 365000
#
#                        MCMC iteration = 366000
#
#                        MCMC iteration = 367000
#
#                        MCMC iteration = 368000
#
#                        MCMC iteration = 369000
#
#                        MCMC iteration = 370000
#
#                        MCMC iteration = 371000
#
#                        MCMC iteration = 372000
#
#                        MCMC iteration = 373000
#
#                        MCMC iteration = 374000
#
#                        MCMC iteration = 375000
#
#                        MCMC iteration = 376000
#
#                        MCMC iteration = 377000
#
#                        MCMC iteration = 378000
#
#                        MCMC iteration = 379000
#
#                        MCMC iteration = 380000
#
#                        MCMC iteration = 381000
#
#                        MCMC iteration = 382000
#
#                        MCMC iteration = 383000
#
#                        MCMC iteration = 384000
#
#                        MCMC iteration = 385000
#
#                        MCMC iteration = 386000
#
#                        MCMC iteration = 387000
#
#                        MCMC iteration = 388000
#
#                        MCMC iteration = 389000
#
#                        MCMC iteration = 390000
#
#                        MCMC iteration = 391000
#
#                        MCMC iteration = 392000
#
#                        MCMC iteration = 393000
#
#                        MCMC iteration = 394000
#
#                        MCMC iteration = 395000
#
#                        MCMC iteration = 396000
#
#                        MCMC iteration = 397000
#
#                        MCMC iteration = 398000
#
#                        MCMC iteration = 399000
#
#                        MCMC iteration = 400000
#
#                        MCMC iteration = 401000
#
#                        MCMC iteration = 402000
#
#                        MCMC iteration = 403000
#
#                        MCMC iteration = 404000
#
#                        MCMC iteration = 405000
#
#                        MCMC iteration = 406000
#
#                        MCMC iteration = 407000
#
#                        MCMC iteration = 408000
#
#                        MCMC iteration = 409000
#
#                        MCMC iteration = 410000
#
#                        MCMC iteration = 411000
#
#                        MCMC iteration = 412000
#
#                        MCMC iteration = 413000
#
#                        MCMC iteration = 414000
#
#                        MCMC iteration = 415000
#
#                        MCMC iteration = 416000
#
#                        MCMC iteration = 417000
#
#                        MCMC iteration = 418000
#
#                        MCMC iteration = 419000
#
#                        MCMC iteration = 420000
#
#                        MCMC iteration = 421000
#
#                        MCMC iteration = 422000
#
#                        MCMC iteration = 423000
#
#                        MCMC iteration = 424000
#
#                        MCMC iteration = 425000
#
#                        MCMC iteration = 426000
#
#                        MCMC iteration = 427000
#
#                        MCMC iteration = 428000
#
#                        MCMC iteration = 429000
#
#                        MCMC iteration = 430000
#
#                        MCMC iteration = 431000
#
#                        MCMC iteration = 432000
#
#                        MCMC iteration = 433000
#
#                        MCMC iteration = 434000
#
#                        MCMC iteration = 435000
#
#                        MCMC iteration = 436000
#
#                        MCMC iteration = 437000
#
#                        MCMC iteration = 438000
#
#                        MCMC iteration = 439000
#
#                        MCMC iteration = 440000
#
#                        MCMC iteration = 441000
#
#                        MCMC iteration = 442000
#
#                        MCMC iteration = 443000
#
#                        MCMC iteration = 444000
#
#                        MCMC iteration = 445000
#
#                        MCMC iteration = 446000
#
#                        MCMC iteration = 447000
#
#                        MCMC iteration = 448000
#
#                        MCMC iteration = 449000
#
#                        MCMC iteration = 450000
#
#                        MCMC iteration = 451000
#
#                        MCMC iteration = 452000
#
#                        MCMC iteration = 453000
#
#                        MCMC iteration = 454000
#
#                        MCMC iteration = 455000
#
#                        MCMC iteration = 456000
#
#                        MCMC iteration = 457000
#
#                        MCMC iteration = 458000
#
#                        MCMC iteration = 459000
#
#                        MCMC iteration = 460000
#
#                        MCMC iteration = 461000
#
#                        MCMC iteration = 462000
#
#                        MCMC iteration = 463000
#
#                        MCMC iteration = 464000
#
#                        MCMC iteration = 465000
#
#                        MCMC iteration = 466000
#
#                        MCMC iteration = 467000
#
#                        MCMC iteration = 468000
#
#                        MCMC iteration = 469000
#
#                        MCMC iteration = 470000
#
#                        MCMC iteration = 471000
#
#                        MCMC iteration = 472000
#
#                        MCMC iteration = 473000
#
#                        MCMC iteration = 474000
#
#                        MCMC iteration = 475000
#
#                        MCMC iteration = 476000
#
#                        MCMC iteration = 477000
#
#                        MCMC iteration = 478000
#
#                        MCMC iteration = 479000
#
#                        MCMC iteration = 480000
#
#                        MCMC iteration = 481000
#
#                        MCMC iteration = 482000
#
#                        MCMC iteration = 483000
#
#                        MCMC iteration = 484000
#
#                        MCMC iteration = 485000
#
#                        MCMC iteration = 486000
#
#                        MCMC iteration = 487000
#
#                        MCMC iteration = 488000
#
#                        MCMC iteration = 489000
#
#                        MCMC iteration = 490000
#
#                        MCMC iteration = 491000
#
#                        MCMC iteration = 492000
#
#                        MCMC iteration = 493000
#
#                        MCMC iteration = 494000
#
#                        MCMC iteration = 495000
#
#                        MCMC iteration = 496000
#
#                        MCMC iteration = 497000
#
#                        MCMC iteration = 498000
#
#                        MCMC iteration = 499000
#
#                        MCMC iteration = 500000
#
#                        MCMC iteration = 501000
#
#                        MCMC iteration = 502000
#
#                        MCMC iteration = 503000
#
#                        MCMC iteration = 504000
#
#                        MCMC iteration = 505000
#
#                        MCMC iteration = 506000
#
#                        MCMC iteration = 507000
#
#                        MCMC iteration = 508000
#
#                        MCMC iteration = 509000
#
#                        MCMC iteration = 510000
#
#                        MCMC iteration = 511000
#
#                        MCMC iteration = 512000
#
#                        MCMC iteration = 513000
#
#                        MCMC iteration = 514000
#
#                        MCMC iteration = 515000
#
#                        MCMC iteration = 516000
#
#                        MCMC iteration = 517000
#
#                        MCMC iteration = 518000
#
#                        MCMC iteration = 519000
#
#                        MCMC iteration = 520000
#
#                        MCMC iteration = 521000
#
#                        MCMC iteration = 522000
#
#                        MCMC iteration = 523000
#
#                        MCMC iteration = 524000
#
#                        MCMC iteration = 525000
#
#                        MCMC iteration = 526000
#
#                        MCMC iteration = 527000
#
#                        MCMC iteration = 528000
#
#                        MCMC iteration = 529000
#
#                        MCMC iteration = 530000
#
#                        MCMC iteration = 531000
#
#                        MCMC iteration = 532000
#
#                        MCMC iteration = 533000
#
#                        MCMC iteration = 534000
#
#                        MCMC iteration = 535000
#
#                        MCMC iteration = 536000
#
#                        MCMC iteration = 537000
#
#                        MCMC iteration = 538000
#
#                        MCMC iteration = 539000
#
#                        MCMC iteration = 540000
#
#                        MCMC iteration = 541000
#
#                        MCMC iteration = 542000
#
#                        MCMC iteration = 543000
#
#                        MCMC iteration = 544000
#
#                        MCMC iteration = 545000
#
#                        MCMC iteration = 546000
#
#                        MCMC iteration = 547000
#
#                        MCMC iteration = 548000
#
#                        MCMC iteration = 549000
#
#                        MCMC iteration = 550000
#
#                        MCMC iteration = 551000
#
#                        MCMC iteration = 552000
#
#                        MCMC iteration = 553000
#
#                        MCMC iteration = 554000
#
#                        MCMC iteration = 555000
#
#                        MCMC iteration = 556000
#
#                        MCMC iteration = 557000
#
#                        MCMC iteration = 558000
#
#                        MCMC iteration = 559000
#
#                        MCMC iteration = 560000
#
#                        MCMC iteration = 561000
#
#                        MCMC iteration = 562000
#
#                        MCMC iteration = 563000
#
#                        MCMC iteration = 564000
#
#                        MCMC iteration = 565000
#
#                        MCMC iteration = 566000
#
#                        MCMC iteration = 567000
#
#                        MCMC iteration = 568000
#
#                        MCMC iteration = 569000
#
#                        MCMC iteration = 570000
#
#                        MCMC iteration = 571000
#
#                        MCMC iteration = 572000
#
#                        MCMC iteration = 573000
#
#                        MCMC iteration = 574000
#
#                        MCMC iteration = 575000
#
#                        MCMC iteration = 576000
#
#                        MCMC iteration = 577000
#
#                        MCMC iteration = 578000
#
#                        MCMC iteration = 579000
#
#                        MCMC iteration = 580000
#
#                        MCMC iteration = 581000
#
#                        MCMC iteration = 582000
#
#                        MCMC iteration = 583000
#
#                        MCMC iteration = 584000
#
#                        MCMC iteration = 585000
#
#                        MCMC iteration = 586000
#
#                        MCMC iteration = 587000
#
#                        MCMC iteration = 588000
#
#                        MCMC iteration = 589000
#
#                        MCMC iteration = 590000
#
#                        MCMC iteration = 591000
#
#                        MCMC iteration = 592000
#
#                        MCMC iteration = 593000
#
#                        MCMC iteration = 594000
#
#                        MCMC iteration = 595000
#
#                        MCMC iteration = 596000
#
#                        MCMC iteration = 597000
#
#                        MCMC iteration = 598000
#
#                        MCMC iteration = 599000
#
#                        MCMC iteration = 600000
#
#                        MCMC iteration = 601000
#
#                        MCMC iteration = 602000
#
#                        MCMC iteration = 603000
#
#                        MCMC iteration = 604000
#
#                        MCMC iteration = 605000
#
#                        MCMC iteration = 606000
#
#                        MCMC iteration = 607000
#
#                        MCMC iteration = 608000
#
#                        MCMC iteration = 609000
#
#                        MCMC iteration = 610000
#
#                        MCMC iteration = 611000
#
#                        MCMC iteration = 612000
#
#                        MCMC iteration = 613000
#
#                        MCMC iteration = 614000
#
#                        MCMC iteration = 615000
#
#                        MCMC iteration = 616000
#
#                        MCMC iteration = 617000
#
#                        MCMC iteration = 618000
#
#                        MCMC iteration = 619000
#
#                        MCMC iteration = 620000
#
#                        MCMC iteration = 621000
#
#                        MCMC iteration = 622000
#
#                        MCMC iteration = 623000
#
#                        MCMC iteration = 624000
#
#                        MCMC iteration = 625000
#
#                        MCMC iteration = 626000
#
#                        MCMC iteration = 627000
#
#                        MCMC iteration = 628000
#
#                        MCMC iteration = 629000
#
#                        MCMC iteration = 630000
#
#                        MCMC iteration = 631000
#
#                        MCMC iteration = 632000
#
#                        MCMC iteration = 633000
#
#                        MCMC iteration = 634000
#
#                        MCMC iteration = 635000
#
#                        MCMC iteration = 636000
#
#                        MCMC iteration = 637000
#
#                        MCMC iteration = 638000
#
#                        MCMC iteration = 639000
#
#                        MCMC iteration = 640000
#
#                        MCMC iteration = 641000
#
#                        MCMC iteration = 642000
#
#                        MCMC iteration = 643000
#
#                        MCMC iteration = 644000
#
#                        MCMC iteration = 645000
#
#                        MCMC iteration = 646000
#
#                        MCMC iteration = 647000
#
#                        MCMC iteration = 648000
#
#                        MCMC iteration = 649000
#
#                        MCMC iteration = 650000
#
#                        MCMC iteration = 651000
#
#                        MCMC iteration = 652000
#
#                        MCMC iteration = 653000
#
#                        MCMC iteration = 654000
#
#                        MCMC iteration = 655000
#
#                        MCMC iteration = 656000
#
#                        MCMC iteration = 657000
#
#                        MCMC iteration = 658000
#
#                        MCMC iteration = 659000
#
#                        MCMC iteration = 660000
#
#                        MCMC iteration = 661000
#
#                        MCMC iteration = 662000
#
#                        MCMC iteration = 663000
#
#                        MCMC iteration = 664000
#
#                        MCMC iteration = 665000
#
#                        MCMC iteration = 666000
#
#                        MCMC iteration = 667000
#
#                        MCMC iteration = 668000
#
#                        MCMC iteration = 669000
#
#                        MCMC iteration = 670000
#
#                        MCMC iteration = 671000
#
#                        MCMC iteration = 672000
#
#                        MCMC iteration = 673000
#
#                        MCMC iteration = 674000
#
#                        MCMC iteration = 675000
#
#                        MCMC iteration = 676000
#
#                        MCMC iteration = 677000
#
#                        MCMC iteration = 678000
#
#                        MCMC iteration = 679000
#
#                        MCMC iteration = 680000
#
#                        MCMC iteration = 681000
#
#                        MCMC iteration = 682000
#
#                        MCMC iteration = 683000
#
#                        MCMC iteration = 684000
#
#                        MCMC iteration = 685000
#
#                        MCMC iteration = 686000
#
#                        MCMC iteration = 687000
#
#                        MCMC iteration = 688000
#
#                        MCMC iteration = 689000
#
#                        MCMC iteration = 690000
#
#                        MCMC iteration = 691000
#
#                        MCMC iteration = 692000
#
#                        MCMC iteration = 693000
#
#                        MCMC iteration = 694000
#
#                        MCMC iteration = 695000
#
#                        MCMC iteration = 696000
#
#                        MCMC iteration = 697000
#
#                        MCMC iteration = 698000
#
#                        MCMC iteration = 699000
#
#                        MCMC iteration = 700000
#  Iterations = 105001:699901
#  Thinning interval  = 100
#  Sample size  = 5950
#
#  DIC: 100368.2
#
#  G-structure:  ~us(trait + at.level(trait, 1):time + at.level(trait, 1):time2):HenID
#
#                                                         post.mean l-95% CI
# traitPC1:traitPC1.HenID                                    1.2296   0.8612
# traitseverity:traitPC1.HenID                               0.5743  -3.6958
# at.level(trait, 1):time:traitPC1.HenID                    -1.3810  -2.0270
# at.level(trait, 1):time2:traitPC1.HenID                    0.4040   0.1122
# traitPC1:traitseverity.HenID                               0.5743  -3.6958
# traitseverity:traitseverity.HenID                        222.6717 155.6307
# at.level(trait, 1):time:traitseverity.HenID                4.9527  -2.1951
# at.level(trait, 1):time2:traitseverity.HenID              -3.6135  -7.4144
# traitPC1:at.level(trait, 1):time.HenID                    -1.3810  -2.0270
# traitseverity:at.level(trait, 1):time.HenID                4.9527  -2.1951
# at.level(trait, 1):time:at.level(trait, 1):time.HenID      3.4851   2.3435
# at.level(trait, 1):time2:at.level(trait, 1):time.HenID    -1.5671  -2.2005
# traitPC1:at.level(trait, 1):time2.HenID                    0.4040   0.1122
# traitseverity:at.level(trait, 1):time2.HenID              -3.6135  -7.4144
# at.level(trait, 1):time:at.level(trait, 1):time2.HenID    -1.5671  -2.2005
# at.level(trait, 1):time2:at.level(trait, 1):time2.HenID    0.8966   0.5910
#                                                          u-95% CI eff.samp
# traitPC1:traitPC1.HenID                                   1.66767     5950
# traitseverity:traitPC1.HenID                              4.70631     6230
# at.level(trait, 1):time:traitPC1.HenID                   -0.79167     6282
# at.level(trait, 1):time2:traitPC1.HenID                   0.67753     6252
# traitPC1:traitseverity.HenID                              4.70631     6230
# traitseverity:traitseverity.HenID                       297.14918     5697
# at.level(trait, 1):time:traitseverity.HenID              12.49122     5950
# at.level(trait, 1):time2:traitseverity.HenID              0.03571     5950
# traitPC1:at.level(trait, 1):time.HenID                   -0.79167     6282
# traitseverity:at.level(trait, 1):time.HenID              12.49122     5950
# at.level(trait, 1):time:at.level(trait, 1):time.HenID     4.79739     5950
# at.level(trait, 1):time2:at.level(trait, 1):time.HenID   -1.00258     5950
# traitPC1:at.level(trait, 1):time2.HenID                   0.67753     6252
# traitseverity:at.level(trait, 1):time2.HenID              0.03571     5950
# at.level(trait, 1):time:at.level(trait, 1):time2.HenID   -1.00258     5950
# at.level(trait, 1):time2:at.level(trait, 1):time2.HenID   1.23743     5950
#
#  R-structure:  ~idh(trait):units
#
#                     post.mean l-95% CI u-95% CI eff.samp
# traitPC1.units         0.2589   0.2463   0.2723     5950
# traitseverity.units    0.0001   0.0001   0.0001        0
#
#  Location effects: cbind(PC1, severity) ~ trait - 1 + trait:Treatment + at.level(trait, 1):time + at.level(trait, 1):time2 + at.level(trait, 1):temperature_C_avg_scale + at.level(trait, 2):Predictability_mean + at.level(trait, 2):nbr_daysnomvt_over_3days + at.level(trait, 2):InitialWeight_scale + at.level(trait, 2):CLASS
#
#                                              post.mean   l-95% CI   u-95% CI
# traitPC1                                     -0.657174  -0.931665  -0.348566
# traitseverity                                48.653117  30.769112  65.688168
# traitPC1:TreatmentOFH                        -0.305425  -0.587923  -0.002322
# traitseverity:TreatmentOFH                    6.849587   0.282800  13.108952
# at.level(trait, 1):time                       2.337655   1.873762   2.761149
# at.level(trait, 1):time2                     -1.089219  -1.315658  -0.852309
# at.level(trait, 1):temperature_C_avg_scale   -0.028820  -0.049275  -0.008243
# at.level(trait, 2):Predictability_mean       17.620178   2.165170  33.416667
# at.level(trait, 2):nbr_daysnomvt_over_3days   5.383058   1.611393   9.255091
# at.level(trait, 2):InitialWeight_scale        2.399108  -1.052104   5.481646
# at.level(trait, 2):CLASSMEXP                 -2.514285 -10.402845   5.129241
# at.level(trait, 2):CLASSREXP                 -0.622072  -8.681901   7.796979
#                                             eff.samp   pMCMC
# traitPC1                                        4942 < 2e-04 ***
# traitseverity                                   6441 < 2e-04 ***
# traitPC1:TreatmentOFH                           5950 0.04168 *
# traitseverity:TreatmentOFH                      5950 0.03664 *
# at.level(trait, 1):time                         5950 < 2e-04 ***
# at.level(trait, 1):time2                        5950 < 2e-04 ***
# at.level(trait, 1):temperature_C_avg_scale      5950 0.00739 **
# at.level(trait, 2):Predictability_mean          5950 0.02824 *
# at.level(trait, 2):nbr_daysnomvt_over_3days     6049 0.00975 **
# at.level(trait, 2):InitialWeight_scale          6192 0.15429
# at.level(trait, 2):CLASSMEXP                    5950 0.51966
# at.level(trait, 2):CLASSREXP                    5950 0.88605
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#
#                        MCMC iteration = 61000
#
#                        MCMC iteration = 62000
#
#                        MCMC iteration = 63000
#
#                        MCMC iteration = 64000
#
#                        MCMC iteration = 65000
#
#                        MCMC iteration = 66000
#
#                        MCMC iteration = 67000
#
#                        MCMC iteration = 68000
#
#                        MCMC iteration = 69000
#
#                        MCMC iteration = 70000
#
#                        MCMC iteration = 71000
#
#                        MCMC iteration = 72000
#
#                        MCMC iteration = 73000
#
#                        MCMC iteration = 74000
#
#                        MCMC iteration = 75000
#
#                        MCMC iteration = 76000
#
#                        MCMC iteration = 77000
#
#                        MCMC iteration = 78000
#
#                        MCMC iteration = 79000
#
#                        MCMC iteration = 80000
#
#                        MCMC iteration = 81000
#
#                        MCMC iteration = 82000
#
#                        MCMC iteration = 83000
#
#                        MCMC iteration = 84000
#
#                        MCMC iteration = 85000
#
#                        MCMC iteration = 86000
#
#                        MCMC iteration = 87000
#
#                        MCMC iteration = 88000
#
#                        MCMC iteration = 89000
#
#                        MCMC iteration = 90000
#
#                        MCMC iteration = 91000
#
#                        MCMC iteration = 92000
#
#                        MCMC iteration = 93000
#
#                        MCMC iteration = 94000
#
#                        MCMC iteration = 95000
#
#                        MCMC iteration = 96000
#
#                        MCMC iteration = 97000
#
#                        MCMC iteration = 98000
#
#                        MCMC iteration = 99000
#
#                        MCMC iteration = 100000
#
#                        MCMC iteration = 101000
#
#                        MCMC iteration = 102000
#
#                        MCMC iteration = 103000
#
#                        MCMC iteration = 104000
#
#                        MCMC iteration = 105000
#
#                        MCMC iteration = 106000
#
#                        MCMC iteration = 107000
#
#                        MCMC iteration = 108000
#
#                        MCMC iteration = 109000
#
#                        MCMC iteration = 110000
#
#                        MCMC iteration = 111000
#
#                        MCMC iteration = 112000
#
#                        MCMC iteration = 113000
#
#                        MCMC iteration = 114000
#
#                        MCMC iteration = 115000
#
#                        MCMC iteration = 116000
#
#                        MCMC iteration = 117000
#
#                        MCMC iteration = 118000
#
#                        MCMC iteration = 119000
#
#                        MCMC iteration = 120000
#
#                        MCMC iteration = 121000
#
#                        MCMC iteration = 122000
#
#                        MCMC iteration = 123000
#
#                        MCMC iteration = 124000
#
#                        MCMC iteration = 125000
#
#                        MCMC iteration = 126000
#
#                        MCMC iteration = 127000
#
#                        MCMC iteration = 128000
#
#                        MCMC iteration = 129000
#
#                        MCMC iteration = 130000
#
#                        MCMC iteration = 131000
#
#                        MCMC iteration = 132000
#
#                        MCMC iteration = 133000
#
#                        MCMC iteration = 134000
#
#                        MCMC iteration = 135000
#
#                        MCMC iteration = 136000
#
#                        MCMC iteration = 137000
#
#                        MCMC iteration = 138000
#
#                        MCMC iteration = 139000
#
#                        MCMC iteration = 140000
#
#                        MCMC iteration = 141000
#
#                        MCMC iteration = 142000
#
#                        MCMC iteration = 143000
#
#                        MCMC iteration = 144000
#
#                        MCMC iteration = 145000
#
#                        MCMC iteration = 146000
#
#                        MCMC iteration = 147000
#
#                        MCMC iteration = 148000
#
#                        MCMC iteration = 149000
#
#                        MCMC iteration = 150000
#
#                        MCMC iteration = 151000
#
#                        MCMC iteration = 152000
#
#                        MCMC iteration = 153000
#
#                        MCMC iteration = 154000
#
#                        MCMC iteration = 155000
#
#                        MCMC iteration = 156000
#
#                        MCMC iteration = 157000
#
#                        MCMC iteration = 158000
#
#                        MCMC iteration = 159000
#
#                        MCMC iteration = 160000
#
#                        MCMC iteration = 161000
#
#                        MCMC iteration = 162000
#
#                        MCMC iteration = 163000
#
#                        MCMC iteration = 164000
#
#                        MCMC iteration = 165000
#
#                        MCMC iteration = 166000
#
#                        MCMC iteration = 167000
#
#                        MCMC iteration = 168000
#
#                        MCMC iteration = 169000
#
#                        MCMC iteration = 170000
#
#                        MCMC iteration = 171000
#
#                        MCMC iteration = 172000
#
#                        MCMC iteration = 173000
#
#                        MCMC iteration = 174000
#
#                        MCMC iteration = 175000
#
#                        MCMC iteration = 176000
#
#                        MCMC iteration = 177000
#
#                        MCMC iteration = 178000
#
#                        MCMC iteration = 179000
#
#                        MCMC iteration = 180000
#
#                        MCMC iteration = 181000
#
#                        MCMC iteration = 182000
#
#                        MCMC iteration = 183000
#
#                        MCMC iteration = 184000
#
#                        MCMC iteration = 185000
#
#                        MCMC iteration = 186000
#
#                        MCMC iteration = 187000
#
#                        MCMC iteration = 188000
#
#                        MCMC iteration = 189000
#
#                        MCMC iteration = 190000
#
#                        MCMC iteration = 191000
#
#                        MCMC iteration = 192000
#
#                        MCMC iteration = 193000
#
#                        MCMC iteration = 194000
#
# ...
#
#                        MCMC iteration = 476000
#
#                        MCMC iteration = 477000
#
#                        MCMC iteration = 478000
#
#                        MCMC iteration = 479000
#
#                        MCMC iteration = 480000
#
#                        MCMC iteration = 481000
#
#                        MCMC iteration = 482000
#
#                        MCMC iteration = 483000
#
#                        MCMC iteration = 484000
#
#                        MCMC iteration = 485000
#
#                        MCMC iteration = 486000
#
#                        MCMC iteration = 487000
#
#                        MCMC iteration = 488000
#
#                        MCMC iteration = 489000
#
#                        MCMC iteration = 490000
#
#                        MCMC iteration = 491000
#
#                        MCMC iteration = 492000
#
#                        MCMC iteration = 493000
#
#                        MCMC iteration = 494000
#
#                        MCMC iteration = 495000
#
#                        MCMC iteration = 496000
#
#                        MCMC iteration = 497000
#
#                        MCMC iteration = 498000
#
#                        MCMC iteration = 499000
#
#                        MCMC iteration = 500000
#
#                        MCMC iteration = 501000
#
#                        MCMC iteration = 502000
#
#                        MCMC iteration = 503000
#
#                        MCMC iteration = 504000
#
#                        MCMC iteration = 505000
#
#                        MCMC iteration = 506000
#
#                        MCMC iteration = 507000
#
#                        MCMC iteration = 508000
#
#                        MCMC iteration = 509000
#
#                        MCMC iteration = 510000
#
#                        MCMC iteration = 511000
#
#                        MCMC iteration = 512000
#
#                        MCMC iteration = 513000
#
#                        MCMC iteration = 514000
#
#                        MCMC iteration = 515000
#
#                        MCMC iteration = 516000
#
#                        MCMC iteration = 517000
#
#                        MCMC iteration = 518000
#
#                        MCMC iteration = 519000
#
#                        MCMC iteration = 520000
#
#                        MCMC iteration = 521000
#
#                        MCMC iteration = 522000
#
#                        MCMC iteration = 523000
#
#                        MCMC iteration = 524000
#
#                        MCMC iteration = 525000
#
#                        MCMC iteration = 526000
#
#                        MCMC iteration = 527000
#
#                        MCMC iteration = 528000
#
#                        MCMC iteration = 529000
#
#                        MCMC iteration = 530000
#
#                        MCMC iteration = 531000
#
#                        MCMC iteration = 532000
#
#                        MCMC iteration = 533000
#
#                        MCMC iteration = 534000
#
#                        MCMC iteration = 535000
#
#                        MCMC iteration = 536000
#
#                        MCMC iteration = 537000
#
#                        MCMC iteration = 538000
#
#                        MCMC iteration = 539000
#
#                        MCMC iteration = 540000
#
#                        MCMC iteration = 541000
#
#                        MCMC iteration = 542000
#
#                        MCMC iteration = 543000
#
#                        MCMC iteration = 544000
#
#                        MCMC iteration = 545000
#
#                        MCMC iteration = 546000
#
#                        MCMC iteration = 547000
#
#                        MCMC iteration = 548000
#
#                        MCMC iteration = 549000
#
#                        MCMC iteration = 550000
#
#                        MCMC iteration = 551000
#
#                        MCMC iteration = 552000
#
#                        MCMC iteration = 553000
#
#                        MCMC iteration = 554000
#
#                        MCMC iteration = 555000
#
#                        MCMC iteration = 556000
#
#                        MCMC iteration = 557000
#
#                        MCMC iteration = 558000
#
#                        MCMC iteration = 559000
#
#                        MCMC iteration = 560000
#
#                        MCMC iteration = 561000
#
#                        MCMC iteration = 562000
#
#                        MCMC iteration = 563000
#
#                        MCMC iteration = 564000
#
#                        MCMC iteration = 565000
#
#                        MCMC iteration = 566000
#
#                        MCMC iteration = 567000
#
#                        MCMC iteration = 568000
#
#                        MCMC iteration = 569000
#
#                        MCMC iteration = 570000
#
#                        MCMC iteration = 571000
#
#                        MCMC iteration = 572000
#
#                        MCMC iteration = 573000
#
#                        MCMC iteration = 574000
#
#                        MCMC iteration = 575000
#
#                        MCMC iteration = 576000
#
#                        MCMC iteration = 577000
#
#                        MCMC iteration = 578000
#
#                        MCMC iteration = 579000
#
#                        MCMC iteration = 580000
#
#                        MCMC iteration = 581000
#
#                        MCMC iteration = 582000
#
#                        MCMC iteration = 583000
#
#                        MCMC iteration = 584000
#
#                        MCMC iteration = 585000
#
#                        MCMC iteration = 586000
#
#                        MCMC iteration = 587000
#
#                        MCMC iteration = 588000
#
#                        MCMC iteration = 589000
#
#                        MCMC iteration = 590000
#
#                        MCMC iteration = 591000
#
#                        MCMC iteration = 592000
#
#                        MCMC iteration = 593000
#
#                        MCMC iteration = 594000
#
#                        MCMC iteration = 595000
#
#                        MCMC iteration = 596000
#
#                        MCMC iteration = 597000
#
#                        MCMC iteration = 598000
#
#                        MCMC iteration = 599000
#
#                        MCMC iteration = 600000
#
#                        MCMC iteration = 601000
#
#                        MCMC iteration = 602000
#
#                        MCMC iteration = 603000
#
#                        MCMC iteration = 604000
#
#                        MCMC iteration = 605000
#
#                        MCMC iteration = 606000
#
#                        MCMC iteration = 607000
#
#                        MCMC iteration = 608000
#
#                        MCMC iteration = 609000
#
#                        MCMC iteration = 610000
#
#                        MCMC iteration = 611000
#
#                        MCMC iteration = 612000
#
#                        MCMC iteration = 613000
#
#                        MCMC iteration = 614000
#
#                        MCMC iteration = 615000
#
#                        MCMC iteration = 616000
#
#                        MCMC iteration = 617000
#
#                        MCMC iteration = 618000
#
#                        MCMC iteration = 619000
#
#                        MCMC iteration = 620000
#
#                        MCMC iteration = 621000
#
#                        MCMC iteration = 622000
#
#                        MCMC iteration = 623000
#
#                        MCMC iteration = 624000
#
#                        MCMC iteration = 625000
#
#                        MCMC iteration = 626000
#
#                        MCMC iteration = 627000
#
#                        MCMC iteration = 628000
#
#                        MCMC iteration = 629000
#
#                        MCMC iteration = 630000
#
#                        MCMC iteration = 631000
#
#                        MCMC iteration = 632000
#
#                        MCMC iteration = 633000
#
#                        MCMC iteration = 634000
#
#                        MCMC iteration = 635000
#
#                        MCMC iteration = 636000
#
#                        MCMC iteration = 637000
#
#                        MCMC iteration = 638000
#
#                        MCMC iteration = 639000
#
#                        MCMC iteration = 640000
#
#                        MCMC iteration = 641000
#
#                        MCMC iteration = 642000
#
#                        MCMC iteration = 643000
#
#                        MCMC iteration = 644000
#
#                        MCMC iteration = 645000
#
#                        MCMC iteration = 646000
#
#                        MCMC iteration = 647000
#
#                        MCMC iteration = 648000
#
#                        MCMC iteration = 649000
#
#                        MCMC iteration = 650000
#
#                        MCMC iteration = 651000
#
#                        MCMC iteration = 652000
#
#                        MCMC iteration = 653000
#
#                        MCMC iteration = 654000
#
#                        MCMC iteration = 655000
#
#                        MCMC iteration = 656000
#
#                        MCMC iteration = 657000
#
#                        MCMC iteration = 658000
#
#                        MCMC iteration = 659000
#
#                        MCMC iteration = 660000
#
#                        MCMC iteration = 661000
#
#                        MCMC iteration = 662000
#
#                        MCMC iteration = 663000
#
#                        MCMC iteration = 664000
#
#                        MCMC iteration = 665000
#
#                        MCMC iteration = 666000
#
#                        MCMC iteration = 667000
#
#                        MCMC iteration = 668000
#
#                        MCMC iteration = 669000
#
#                        MCMC iteration = 670000
#
#                        MCMC iteration = 671000
#
#                        MCMC iteration = 672000
#
#                        MCMC iteration = 673000
#
#                        MCMC iteration = 674000
#
#                        MCMC iteration = 675000
#
#                        MCMC iteration = 676000
#
#                        MCMC iteration = 677000
#
#                        MCMC iteration = 678000
#
#                        MCMC iteration = 679000
#
#                        MCMC iteration = 680000
#
#                        MCMC iteration = 681000
#
#                        MCMC iteration = 682000
#
#                        MCMC iteration = 683000
#
#                        MCMC iteration = 684000
#
#                        MCMC iteration = 685000
#
#                        MCMC iteration = 686000
#
#                        MCMC iteration = 687000
#
#                        MCMC iteration = 688000
#
#                        MCMC iteration = 689000
#
#                        MCMC iteration = 690000
#
#                        MCMC iteration = 691000
#
#                        MCMC iteration = 692000
#
#                        MCMC iteration = 693000
#
#                        MCMC iteration = 694000
#
#                        MCMC iteration = 695000
#
#                        MCMC iteration = 696000
#
#                        MCMC iteration = 697000
#
#                        MCMC iteration = 698000
#
#                        MCMC iteration = 699000
#
#                        MCMC iteration = 700000
#  Iterations = 105001:699901
#  Thinning interval  = 100
#  Sample size  = 5950
#
#  DIC: 100368.4
#
#  G-structure:  ~us(trait + at.level(trait, 1):time + at.level(trait, 1):time2):HenID
#
#                                                         post.mean l-95% CI
# traitPC1:traitPC1.HenID                                    1.2334   0.8537
# traitseverity:traitPC1.HenID                               0.6052  -3.4449
# at.level(trait, 1):time:traitPC1.HenID                    -1.3817  -2.0545
# at.level(trait, 1):time2:traitPC1.HenID                    0.4036   0.1193
# traitPC1:traitseverity.HenID                               0.6052  -3.4449
# traitseverity:traitseverity.HenID                        222.2249 156.3945
# at.level(trait, 1):time:traitseverity.HenID                4.9256  -2.3709
# at.level(trait, 1):time2:traitseverity.HenID              -3.5939  -7.5335
# traitPC1:at.level(trait, 1):time.HenID                    -1.3817  -2.0545
# traitseverity:at.level(trait, 1):time.HenID                4.9256  -2.3709
# at.level(trait, 1):time:at.level(trait, 1):time.HenID      3.4853   2.2672
# at.level(trait, 1):time2:at.level(trait, 1):time.HenID    -1.5686  -2.2153
# traitPC1:at.level(trait, 1):time2.HenID                    0.4036   0.1193
# traitseverity:at.level(trait, 1):time2.HenID              -3.5939  -7.5335
# at.level(trait, 1):time:at.level(trait, 1):time2.HenID    -1.5686  -2.2153
# at.level(trait, 1):time2:at.level(trait, 1):time2.HenID    0.8974   0.5915
#                                                          u-95% CI eff.samp
# traitPC1:traitPC1.HenID                                   1.67720     5950
# traitseverity:traitPC1.HenID                              4.87148     5950
# at.level(trait, 1):time:traitPC1.HenID                   -0.81447     5950
# at.level(trait, 1):time2:traitPC1.HenID                   0.68816     6054
# traitPC1:traitseverity.HenID                              4.87148     5950
# traitseverity:traitseverity.HenID                       297.89672     5950
# at.level(trait, 1):time:traitseverity.HenID              12.30335     6184
# at.level(trait, 1):time2:traitseverity.HenID              0.04326     5950
# traitPC1:at.level(trait, 1):time.HenID                   -0.81447     5950
# traitseverity:at.level(trait, 1):time.HenID              12.30335     6184
# at.level(trait, 1):time:at.level(trait, 1):time.HenID     4.72184     5673
# at.level(trait, 1):time2:at.level(trait, 1):time.HenID   -1.02229     5535
# traitPC1:at.level(trait, 1):time2.HenID                   0.68816     6054
# traitseverity:at.level(trait, 1):time2.HenID              0.04326     5950
# at.level(trait, 1):time:at.level(trait, 1):time2.HenID   -1.02229     5535
# at.level(trait, 1):time2:at.level(trait, 1):time2.HenID   1.23737     5453
#
#  R-structure:  ~idh(trait):units
#
#                     post.mean l-95% CI u-95% CI eff.samp
# traitPC1.units         0.2589   0.2461   0.2720     5484
# traitseverity.units    0.0001   0.0001   0.0001        0
#
#  Location effects: cbind(PC1, severity) ~ trait - 1 + trait:Treatment + at.level(trait, 1):time + at.level(trait, 1):time2 + at.level(trait, 1):temperature_C_avg_scale + at.level(trait, 2):Predictability_mean + at.level(trait, 2):nbr_daysnomvt_over_3days + at.level(trait, 2):InitialWeight_scale + at.level(trait, 2):CLASS
#
#                                              post.mean   l-95% CI   u-95% CI
# traitPC1                                     -0.658766  -0.948401  -0.368076
# traitseverity                                48.504460  29.774187  65.448164
# traitPC1:TreatmentOFH                        -0.305238  -0.598220  -0.012626
# traitseverity:TreatmentOFH                    6.953425   0.138185  13.244135
# at.level(trait, 1):time                       2.335769   1.905764   2.774029
# at.level(trait, 1):time2                     -1.088994  -1.313931  -0.859404
# at.level(trait, 1):temperature_C_avg_scale   -0.028766  -0.048938  -0.007573
# at.level(trait, 2):Predictability_mean       17.609000   1.826917  33.837080
# at.level(trait, 2):nbr_daysnomvt_over_3days   5.448188   1.600115   9.480642
# at.level(trait, 2):InitialWeight_scale        2.398239  -1.142636   5.520969
# at.level(trait, 2):CLASSMEXP                 -2.363995 -10.182651   5.689042
# at.level(trait, 2):CLASSREXP                 -0.555828  -8.965661   7.757400
#                                             eff.samp    pMCMC
# traitPC1                                        5950 0.000336 ***
# traitseverity                                   5711  < 2e-04 ***
# traitPC1:TreatmentOFH                           5950 0.041008 *
# traitseverity:TreatmentOFH                      5703 0.037983 *
# at.level(trait, 1):time                         5950  < 2e-04 ***
# at.level(trait, 1):time2                        5950  < 2e-04 ***
# at.level(trait, 1):temperature_C_avg_scale      5950 0.006387 **
# at.level(trait, 2):Predictability_mean          5950 0.029244 *
# at.level(trait, 2):nbr_daysnomvt_over_3days     5950 0.004706 **
# at.level(trait, 2):InitialWeight_scale          5950 0.148908
# at.level(trait, 2):CLASSMEXP                    5950 0.536134
# at.level(trait, 2):CLASSREXP                    5727 0.884706
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
combinedchains = mcmc.list(chain1$Sol, chain2$Sol, chain3$Sol) 
plot(combinedchains)
gelman.plot(combinedchains)
#checked all paramters one by one instead of the less reliable Multivariate PSRF (which grows with number of var)
# Out:
# Plot with title "Density of traitseverity:TreatmentOFH"
# Plot with title "Density of at.level(trait, 2):Predictability_mean"
# Plot with title "Density of at.level(trait, 2):CLASSREXP"
# Plot with title "Density of traitPC1.HenID.hen_106"
# Plot with title "Density of traitPC1.HenID.hen_116"
# Plot with title "Density of traitPC1.HenID.hen_127"
# Plot with title "Density of traitPC1.HenID.hen_136"
# Plot with title "Density of traitPC1.HenID.hen_14"
# Plot with title "Density of traitPC1.HenID.hen_145"
# Plot with title "Density of traitPC1.HenID.hen_151"
# Plot with title "Density of traitPC1.HenID.hen_17"
# Plot with title "Density of traitPC1.HenID.hen_20"
# Plot with title "Density of traitPC1.HenID.hen_25"
# Plot with title "Density of traitPC1.HenID.hen_32"
# Plot with title "Density of traitPC1.HenID.hen_5"
# Plot with title "Density of traitPC1.HenID.hen_58"
# Plot with title "Density of traitPC1.HenID.hen_61"
# Plot with title "Density of traitPC1.HenID.hen_67"
# Plot with title "Density of traitPC1.HenID.hen_73"
# Plot with title "Density of traitPC1.HenID.hen_8"
# Plot with title "Density of traitPC1.HenID.hen_85"
# Plot with title "Density of traitPC1.HenID.hen_92"
# Plot with title "Density of traitPC1.HenID.hen_99"
# Plot with title "Density of traitseverity.HenID.hen_106"
# Plot with title "Density of traitseverity.HenID.hen_116"
# Plot with title "Density of traitseverity.HenID.hen_127"
# Plot with title "Density of traitseverity.HenID.hen_136"
# Plot with title "Density of traitseverity.HenID.hen_14"
# Plot with title "Density of traitseverity.HenID.hen_145"
# Plot with title "Density of traitseverity.HenID.hen_151"
# Plot with title "Density of traitseverity.HenID.hen_17"
# Plot with title "Density of traitseverity.HenID.hen_20"
# Plot with title "Density of traitseverity.HenID.hen_25"
# Plot with title "Density of traitseverity.HenID.hen_32"
# Plot with title "Density of traitseverity.HenID.hen_5"
# Plot with title "Density of traitseverity.HenID.hen_58"
# Plot with title "Density of traitseverity.HenID.hen_61"
# Plot with title "Density of traitseverity.HenID.hen_67"
# Plot with title "Density of traitseverity.HenID.hen_73"
# Plot with title "Density of traitseverity.HenID.hen_8"
# Plot with title "Density of traitseverity.HenID.hen_85"
# Plot with title "Density of traitseverity.HenID.hen_92"
# Plot with title "Density of traitseverity.HenID.hen_99"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_106"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_116"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_127"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_136"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_14"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_145"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_151"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_17"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_20"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_25"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_32"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_5"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_58"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_61"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_67"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_73"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_8"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_85"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_92"
# Plot with title "Density of at.level(trait, 1):time.HenID.hen_99"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_106"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_116"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_127"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_136"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_14"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_145"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_151"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_17"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_20"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_25"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_32"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_5"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_58"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_61"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_67"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_73"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_8"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_85"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_92"
# Plot with title "Density of at.level(trait, 1):time2.HenID.hen_99"
# Plot with title "at.level(trait, 2):nbr_daysnomvt_over_3days"
# Plot with title "traitPC1.HenID.hen_109"
# Plot with title "traitPC1.HenID.hen_134"
# Plot with title "traitPC1.HenID.hen_145"
# Plot with title "traitPC1.HenID.hen_18"
# Plot with title "traitPC1.HenID.hen_28"
# Plot with title "traitPC1.HenID.hen_57"
# Plot with title "traitPC1.HenID.hen_67"
# Plot with title "traitPC1.HenID.hen_80"
# Plot with title "traitPC1.HenID.hen_97"
# Plot with title "traitseverity.HenID.hen_112"
# Plot with title "traitseverity.HenID.hen_136"
# Plot with title "traitseverity.HenID.hen_147"
# Plot with title "traitseverity.HenID.hen_19"
# Plot with title "traitseverity.HenID.hen_3"
# Plot with title "traitseverity.HenID.hen_58"
# Plot with title "traitseverity.HenID.hen_68"
# Plot with title "traitseverity.HenID.hen_83"
# Plot with title "traitseverity.HenID.hen_98"
# Plot with title "at.level(trait, 1):time.HenID.hen_116"
# Plot with title "at.level(trait, 1):time.HenID.hen_137"
# Plot with title "at.level(trait, 1):time.HenID.hen_149"
# Plot with title "at.level(trait, 1):time.HenID.hen_2"
# Plot with title "at.level(trait, 1):time.HenID.hen_32"
# Plot with title "at.level(trait, 1):time.HenID.hen_59"
# Plot with title "at.level(trait, 1):time.HenID.hen_69"
# Plot with title "at.level(trait, 1):time.HenID.hen_84"
# Plot with title "at.level(trait, 1):time.HenID.hen_99"
# Plot with title "at.level(trait, 1):time2.HenID.hen_118"
# Plot with title "at.level(trait, 1):time2.HenID.hen_138"
# Plot with title "at.level(trait, 1):time2.HenID.hen_150"
# Plot with title "at.level(trait, 1):time2.HenID.hen_20"
# Plot with title "at.level(trait, 1):time2.HenID.hen_4"
# Plot with title "at.level(trait, 1):time2.HenID.hen_6"
# Plot with title "at.level(trait, 1):time2.HenID.hen_7"
# Plot with title "at.level(trait, 1):time2.HenID.hen_85"
# Plot with title "at.level(trait, 1):time2.HenID.hen_99"

# %%
#only for a list of models
gelman.diag(combinedchains)
# Out:
# Potential scale reduction factors:
#
#                                             Point est. Upper C.I.
# traitPC1                                             1          1
# traitseverity                                        1          1
# traitPC1:TreatmentOFH                                1          1
# traitseverity:TreatmentOFH                           1          1
# at.level(trait, 1):time                              1          1
# at.level(trait, 1):time2                             1          1
# at.level(trait, 1):temperature_C_avg_scale           1          1
# at.level(trait, 2):Predictability_mean               1          1
# at.level(trait, 2):nbr_daysnomvt_over_3days          1          1
# at.level(trait, 2):InitialWeight_scale               1          1
# at.level(trait, 2):CLASSMEXP                         1          1
# at.level(trait, 2):CLASSREXP                         1          1
# traitPC1.HenID.hen_10                                1          1
# traitPC1.HenID.hen_101                               1          1
# traitPC1.HenID.hen_102                               1          1
# traitPC1.HenID.hen_106                               1          1
# traitPC1.HenID.hen_107                               1          1
# traitPC1.HenID.hen_109                               1          1
# traitPC1.HenID.hen_112                               1          1
# traitPC1.HenID.hen_116                               1          1
# traitPC1.HenID.hen_118                               1          1
# traitPC1.HenID.hen_119                               1          1
# traitPC1.HenID.hen_124                               1          1
# traitPC1.HenID.hen_127                               1          1
# traitPC1.HenID.hen_128                               1          1
# traitPC1.HenID.hen_13                                1          1
# traitPC1.HenID.hen_134                               1          1
# traitPC1.HenID.hen_136                               1          1
# traitPC1.HenID.hen_137                               1          1
# traitPC1.HenID.hen_138                               1          1
# traitPC1.HenID.hen_139                               1          1
# traitPC1.HenID.hen_14                                1          1
# traitPC1.HenID.hen_140                               1          1
# traitPC1.HenID.hen_143                               1          1
# traitPC1.HenID.hen_144                               1          1
# traitPC1.HenID.hen_145                               1          1
# traitPC1.HenID.hen_147                               1          1
# traitPC1.HenID.hen_149                               1          1
# traitPC1.HenID.hen_150                               1          1
# traitPC1.HenID.hen_151                               1          1
# traitPC1.HenID.hen_153                               1          1
# traitPC1.HenID.hen_155                               1          1
# traitPC1.HenID.hen_158                               1          1
# traitPC1.HenID.hen_17                                1          1
# traitPC1.HenID.hen_18                                1          1
# traitPC1.HenID.hen_19                                1          1
# traitPC1.HenID.hen_2                                 1          1
# traitPC1.HenID.hen_20                                1          1
# traitPC1.HenID.hen_21                                1          1
# traitPC1.HenID.hen_23                                1          1
# traitPC1.HenID.hen_24                                1          1
# traitPC1.HenID.hen_25                                1          1
# traitPC1.HenID.hen_26                                1          1
# traitPC1.HenID.hen_28                                1          1
# traitPC1.HenID.hen_3                                 1          1
# traitPC1.HenID.hen_32                                1          1
# traitPC1.HenID.hen_4                                 1          1
# traitPC1.HenID.hen_42                                1          1
# traitPC1.HenID.hen_48                                1          1
# traitPC1.HenID.hen_5                                 1          1
# traitPC1.HenID.hen_51                                1          1
# traitPC1.HenID.hen_56                                1          1
# traitPC1.HenID.hen_57                                1          1
# traitPC1.HenID.hen_58                                1          1
# traitPC1.HenID.hen_59                                1          1
# traitPC1.HenID.hen_6                                 1          1
# traitPC1.HenID.hen_60                                1          1
# traitPC1.HenID.hen_61                                1          1
# traitPC1.HenID.hen_64                                1          1
# traitPC1.HenID.hen_65                                1          1
# traitPC1.HenID.hen_66                                1          1
# traitPC1.HenID.hen_67                                1          1
# traitPC1.HenID.hen_68                                1          1
# traitPC1.HenID.hen_69                                1          1
# traitPC1.HenID.hen_7                                 1          1
# traitPC1.HenID.hen_73                                1          1
# traitPC1.HenID.hen_76                                1          1
# traitPC1.HenID.hen_78                                1          1
# traitPC1.HenID.hen_79                                1          1
# traitPC1.HenID.hen_8                                 1          1
# traitPC1.HenID.hen_80                                1          1
# traitPC1.HenID.hen_83                                1          1
# traitPC1.HenID.hen_84                                1          1
# traitPC1.HenID.hen_85                                1          1
# traitPC1.HenID.hen_87                                1          1
# traitPC1.HenID.hen_9                                 1          1
# traitPC1.HenID.hen_90                                1          1
# traitPC1.HenID.hen_92                                1          1
# traitPC1.HenID.hen_95                                1          1
# traitPC1.HenID.hen_97                                1          1
# traitPC1.HenID.hen_98                                1          1
# traitPC1.HenID.hen_99                                1          1
# traitseverity.HenID.hen_10                           1          1
# traitseverity.HenID.hen_101                          1          1
# traitseverity.HenID.hen_102                          1          1
# traitseverity.HenID.hen_106                          1          1
# traitseverity.HenID.hen_107                          1          1
# traitseverity.HenID.hen_109                          1          1
# traitseverity.HenID.hen_112                          1          1
# traitseverity.HenID.hen_116                          1          1
# traitseverity.HenID.hen_118                          1          1
# traitseverity.HenID.hen_119                          1          1
# traitseverity.HenID.hen_124                          1          1
# traitseverity.HenID.hen_127                          1          1
# traitseverity.HenID.hen_128                          1          1
# traitseverity.HenID.hen_13                           1          1
# traitseverity.HenID.hen_134                          1          1
# traitseverity.HenID.hen_136                          1          1
# traitseverity.HenID.hen_137                          1          1
# traitseverity.HenID.hen_138                          1          1
# traitseverity.HenID.hen_139                          1          1
# traitseverity.HenID.hen_14                           1          1
# traitseverity.HenID.hen_140                          1          1
# traitseverity.HenID.hen_143                          1          1
# traitseverity.HenID.hen_144                          1          1
# traitseverity.HenID.hen_145                          1          1
# traitseverity.HenID.hen_147                          1          1
# traitseverity.HenID.hen_149                          1          1
# traitseverity.HenID.hen_150                          1          1
# traitseverity.HenID.hen_151                          1          1
# traitseverity.HenID.hen_153                          1          1
# traitseverity.HenID.hen_155                          1          1
# traitseverity.HenID.hen_158                          1          1
# traitseverity.HenID.hen_17                           1          1
# traitseverity.HenID.hen_18                           1          1
# traitseverity.HenID.hen_19                           1          1
# traitseverity.HenID.hen_2                            1          1
# traitseverity.HenID.hen_20                           1          1
# traitseverity.HenID.hen_21                           1          1
# traitseverity.HenID.hen_23                           1          1
# traitseverity.HenID.hen_24                           1          1
# traitseverity.HenID.hen_25                           1          1
# traitseverity.HenID.hen_26                           1          1
# traitseverity.HenID.hen_28                           1          1
# traitseverity.HenID.hen_3                            1          1
# traitseverity.HenID.hen_32                           1          1
# traitseverity.HenID.hen_4                            1          1
# traitseverity.HenID.hen_42                           1          1
# traitseverity.HenID.hen_48                           1          1
# traitseverity.HenID.hen_5                            1          1
# traitseverity.HenID.hen_51                           1          1
# traitseverity.HenID.hen_56                           1          1
# traitseverity.HenID.hen_57                           1          1
# traitseverity.HenID.hen_58                           1          1
# traitseverity.HenID.hen_59                           1          1
# traitseverity.HenID.hen_6                            1          1
# traitseverity.HenID.hen_60                           1          1
# traitseverity.HenID.hen_61                           1          1
# traitseverity.HenID.hen_64                           1          1
# traitseverity.HenID.hen_65                           1          1
# traitseverity.HenID.hen_66                           1          1
# traitseverity.HenID.hen_67                           1          1
# traitseverity.HenID.hen_68                           1          1
# traitseverity.HenID.hen_69                           1          1
# traitseverity.HenID.hen_7                            1          1
# traitseverity.HenID.hen_73                           1          1
# traitseverity.HenID.hen_76                           1          1
# traitseverity.HenID.hen_78                           1          1
# traitseverity.HenID.hen_79                           1          1
# traitseverity.HenID.hen_8                            1          1
# traitseverity.HenID.hen_80                           1          1
# traitseverity.HenID.hen_83                           1          1
# traitseverity.HenID.hen_84                           1          1
# traitseverity.HenID.hen_85                           1          1
# traitseverity.HenID.hen_87                           1          1
# traitseverity.HenID.hen_9                            1          1
# traitseverity.HenID.hen_90                           1          1
# traitseverity.HenID.hen_92                           1          1
# traitseverity.HenID.hen_95                           1          1
# traitseverity.HenID.hen_97                           1          1
# traitseverity.HenID.hen_98                           1          1
# traitseverity.HenID.hen_99                           1          1
# at.level(trait, 1):time.HenID.hen_10                 1          1
# at.level(trait, 1):time.HenID.hen_101                1          1
# at.level(trait, 1):time.HenID.hen_102                1          1
# at.level(trait, 1):time.HenID.hen_106                1          1
# at.level(trait, 1):time.HenID.hen_107                1          1
# at.level(trait, 1):time.HenID.hen_109                1          1
# at.level(trait, 1):time.HenID.hen_112                1          1
# at.level(trait, 1):time.HenID.hen_116                1          1
# at.level(trait, 1):time.HenID.hen_118                1          1
# at.level(trait, 1):time.HenID.hen_119                1          1
# at.level(trait, 1):time.HenID.hen_124                1          1
# at.level(trait, 1):time.HenID.hen_127                1          1
# at.level(trait, 1):time.HenID.hen_128                1          1
# at.level(trait, 1):time.HenID.hen_13                 1          1
# at.level(trait, 1):time.HenID.hen_134                1          1
# at.level(trait, 1):time.HenID.hen_136                1          1
# at.level(trait, 1):time.HenID.hen_137                1          1
# at.level(trait, 1):time.HenID.hen_138                1          1
# at.level(trait, 1):time.HenID.hen_139                1          1
# at.level(trait, 1):time.HenID.hen_14                 1          1
# at.level(trait, 1):time.HenID.hen_140                1          1
# at.level(trait, 1):time.HenID.hen_143                1          1
# at.level(trait, 1):time.HenID.hen_144                1          1
# at.level(trait, 1):time.HenID.hen_145                1          1
# at.level(trait, 1):time.HenID.hen_147                1          1
# at.level(trait, 1):time.HenID.hen_149                1          1
# at.level(trait, 1):time.HenID.hen_150                1          1
# at.level(trait, 1):time.HenID.hen_151                1          1
# at.level(trait, 1):time.HenID.hen_153                1          1
# at.level(trait, 1):time.HenID.hen_155                1          1
# at.level(trait, 1):time.HenID.hen_158                1          1
# at.level(trait, 1):time.HenID.hen_17                 1          1
# at.level(trait, 1):time.HenID.hen_18                 1          1
# at.level(trait, 1):time.HenID.hen_19                 1          1
# at.level(trait, 1):time.HenID.hen_2                  1          1
# at.level(trait, 1):time.HenID.hen_20                 1          1
# at.level(trait, 1):time.HenID.hen_21                 1          1
# at.level(trait, 1):time.HenID.hen_23                 1          1
# at.level(trait, 1):time.HenID.hen_24                 1          1
# at.level(trait, 1):time.HenID.hen_25                 1          1
# at.level(trait, 1):time.HenID.hen_26                 1          1
# at.level(trait, 1):time.HenID.hen_28                 1          1
# at.level(trait, 1):time.HenID.hen_3                  1          1
# at.level(trait, 1):time.HenID.hen_32                 1          1
# at.level(trait, 1):time.HenID.hen_4                  1          1
# at.level(trait, 1):time.HenID.hen_42                 1          1
# at.level(trait, 1):time.HenID.hen_48                 1          1
# at.level(trait, 1):time.HenID.hen_5                  1          1
# at.level(trait, 1):time.HenID.hen_51                 1          1
# at.level(trait, 1):time.HenID.hen_56                 1          1
# at.level(trait, 1):time.HenID.hen_57                 1          1
# at.level(trait, 1):time.HenID.hen_58                 1          1
# at.level(trait, 1):time.HenID.hen_59                 1          1
# at.level(trait, 1):time.HenID.hen_6                  1          1
# at.level(trait, 1):time.HenID.hen_60                 1          1
# at.level(trait, 1):time.HenID.hen_61                 1          1
# at.level(trait, 1):time.HenID.hen_64                 1          1
# at.level(trait, 1):time.HenID.hen_65                 1          1
# at.level(trait, 1):time.HenID.hen_66                 1          1
# at.level(trait, 1):time.HenID.hen_67                 1          1
# at.level(trait, 1):time.HenID.hen_68                 1          1
# at.level(trait, 1):time.HenID.hen_69                 1          1
# at.level(trait, 1):time.HenID.hen_7                  1          1
# at.level(trait, 1):time.HenID.hen_73                 1          1
# at.level(trait, 1):time.HenID.hen_76                 1          1
# at.level(trait, 1):time.HenID.hen_78                 1          1
# at.level(trait, 1):time.HenID.hen_79                 1          1
# at.level(trait, 1):time.HenID.hen_8                  1          1
# at.level(trait, 1):time.HenID.hen_80                 1          1
# at.level(trait, 1):time.HenID.hen_83                 1          1
# at.level(trait, 1):time.HenID.hen_84                 1          1
# at.level(trait, 1):time.HenID.hen_85                 1          1
# at.level(trait, 1):time.HenID.hen_87                 1          1
# at.level(trait, 1):time.HenID.hen_9                  1          1
# at.level(trait, 1):time.HenID.hen_90                 1          1
# at.level(trait, 1):time.HenID.hen_92                 1          1
# at.level(trait, 1):time.HenID.hen_95                 1          1
# at.level(trait, 1):time.HenID.hen_97                 1          1
# at.level(trait, 1):time.HenID.hen_98                 1          1
# at.level(trait, 1):time.HenID.hen_99                 1          1
# at.level(trait, 1):time2.HenID.hen_10                1          1
# at.level(trait, 1):time2.HenID.hen_101               1          1
# at.level(trait, 1):time2.HenID.hen_102               1          1
# at.level(trait, 1):time2.HenID.hen_106               1          1
# at.level(trait, 1):time2.HenID.hen_107               1          1
# at.level(trait, 1):time2.HenID.hen_109               1          1
# at.level(trait, 1):time2.HenID.hen_112               1          1
# at.level(trait, 1):time2.HenID.hen_116               1          1
# at.level(trait, 1):time2.HenID.hen_118               1          1
# at.level(trait, 1):time2.HenID.hen_119               1          1
# at.level(trait, 1):time2.HenID.hen_124               1          1
# at.level(trait, 1):time2.HenID.hen_127               1          1
# at.level(trait, 1):time2.HenID.hen_128               1          1
# at.level(trait, 1):time2.HenID.hen_13                1          1
# at.level(trait, 1):time2.HenID.hen_134               1          1
# at.level(trait, 1):time2.HenID.hen_136               1          1
# at.level(trait, 1):time2.HenID.hen_137               1          1
# at.level(trait, 1):time2.HenID.hen_138               1          1
# at.level(trait, 1):time2.HenID.hen_139               1          1
# at.level(trait, 1):time2.HenID.hen_14                1          1
# at.level(trait, 1):time2.HenID.hen_140               1          1
# at.level(trait, 1):time2.HenID.hen_143               1          1
# at.level(trait, 1):time2.HenID.hen_144               1          1
# at.level(trait, 1):time2.HenID.hen_145               1          1
# at.level(trait, 1):time2.HenID.hen_147               1          1
# at.level(trait, 1):time2.HenID.hen_149               1          1
# at.level(trait, 1):time2.HenID.hen_150               1          1
# at.level(trait, 1):time2.HenID.hen_151               1          1
# at.level(trait, 1):time2.HenID.hen_153               1          1
# at.level(trait, 1):time2.HenID.hen_155               1          1
# at.level(trait, 1):time2.HenID.hen_158               1          1
# at.level(trait, 1):time2.HenID.hen_17                1          1
# at.level(trait, 1):time2.HenID.hen_18                1          1
# at.level(trait, 1):time2.HenID.hen_19                1          1
# at.level(trait, 1):time2.HenID.hen_2                 1          1
# at.level(trait, 1):time2.HenID.hen_20                1          1
# at.level(trait, 1):time2.HenID.hen_21                1          1
# at.level(trait, 1):time2.HenID.hen_23                1          1
# at.level(trait, 1):time2.HenID.hen_24                1          1
# at.level(trait, 1):time2.HenID.hen_25                1          1
# at.level(trait, 1):time2.HenID.hen_26                1          1
# at.level(trait, 1):time2.HenID.hen_28                1          1
# at.level(trait, 1):time2.HenID.hen_3                 1          1
# at.level(trait, 1):time2.HenID.hen_32                1          1
# at.level(trait, 1):time2.HenID.hen_4                 1          1
# at.level(trait, 1):time2.HenID.hen_42                1          1
# at.level(trait, 1):time2.HenID.hen_48                1          1
# at.level(trait, 1):time2.HenID.hen_5                 1          1
# at.level(trait, 1):time2.HenID.hen_51                1          1
# at.level(trait, 1):time2.HenID.hen_56                1          1
# at.level(trait, 1):time2.HenID.hen_57                1          1
# at.level(trait, 1):time2.HenID.hen_58                1          1
# at.level(trait, 1):time2.HenID.hen_59                1          1
# at.level(trait, 1):time2.HenID.hen_6                 1          1
# at.level(trait, 1):time2.HenID.hen_60                1          1
# at.level(trait, 1):time2.HenID.hen_61                1          1
# at.level(trait, 1):time2.HenID.hen_64                1          1
# at.level(trait, 1):time2.HenID.hen_65                1          1
# at.level(trait, 1):time2.HenID.hen_66                1          1
# at.level(trait, 1):time2.HenID.hen_67                1          1
# at.level(trait, 1):time2.HenID.hen_68                1          1
# at.level(trait, 1):time2.HenID.hen_69                1          1
# at.level(trait, 1):time2.HenID.hen_7                 1          1
# at.level(trait, 1):time2.HenID.hen_73                1          1
# at.level(trait, 1):time2.HenID.hen_76                1          1
# at.level(trait, 1):time2.HenID.hen_78                1          1
# at.level(trait, 1):time2.HenID.hen_79                1          1
# at.level(trait, 1):time2.HenID.hen_8                 1          1
# at.level(trait, 1):time2.HenID.hen_80                1          1
# at.level(trait, 1):time2.HenID.hen_83                1          1
# at.level(trait, 1):time2.HenID.hen_84                1          1
# at.level(trait, 1):time2.HenID.hen_85                1          1
# at.level(trait, 1):time2.HenID.hen_87                1          1
# at.level(trait, 1):time2.HenID.hen_9                 1          1
# at.level(trait, 1):time2.HenID.hen_90                1          1
# at.level(trait, 1):time2.HenID.hen_92                1          1
# at.level(trait, 1):time2.HenID.hen_95                1          1
# at.level(trait, 1):time2.HenID.hen_97                1          1
# at.level(trait, 1):time2.HenID.hen_98                1          1
# at.level(trait, 1):time2.HenID.hen_99                1          1
#
# Multivariate psrf
#
# 1.02
