# %%
#install.packages("scales")
library(jtools)
library(scales)
library(DHARMa)
library(lindia)
library(tidyverse)
library(caret)
library(leaps)
library(MASS)
library(modEvA)
library(dplyr)
library(lme4) #random effect
library(broom)
library(ggpubr) 
library(rstatix)
library(WRS2) #robust ancova
library(lmerTest) #like lmer but with p-value
library(emmeans) #visualize interaction term
library(betareg) #beta regression: for modeling beta-distributed dependent variables, e.g., rates and proportions
library(diptest)
library(glmmTMB) #beta regression
library(rgr) #logit
#levenetest
library(car)
library(rstanarm) #r2 in mixed effect models
library(performance) #r2 in mixed effect models
# Out:
# Warning message:
# "package 'jtools' was built under R version 4.0.4"
# Warning message:
# "package 'scales' was built under R version 4.0.4"
# This is DHARMa 0.3.3.0. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa') Note: Syntax of plotResiduals has changed in 0.3.0, see ?plotResiduals for details
#
# Registered S3 methods overwritten by 'broom':
#   method            from
#   tidy.glht         jtools
#   tidy.summary.glht jtools
#
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.0.6     v dplyr   1.0.3
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x readr::col_factor() masks scales::col_factor()
# x purrr::discard()    masks scales::discard()
# x dplyr::filter()     masks stats::filter()
# x dplyr::lag()        masks stats::lag()
#
# Loading required package: lattice
#
#
# Attaching package: 'caret'
#
#
# The following object is masked from 'package:purrr':
#
#     lift
#
#
#
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:dplyr':
#
#     select
#
#
# Loading required package: Matrix
#
#
# Attaching package: 'Matrix'
#
#
# The following objects are masked from 'package:tidyr':
#
#     expand, pack, unpack
#
#
# Registered S3 methods overwritten by 'car':
#   method                          from
#   influence.merMod                lme4
#   cooks.distance.influence.merMod lme4
#   dfbeta.influence.merMod         lme4
#   dfbetas.influence.merMod        lme4
#
#
# Attaching package: 'rstatix'
#
#
# The following object is masked from 'package:MASS':
#
#     select
#
#
# The following object is masked from 'package:stats':
#
#     filter
#
#
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Warning message:
# "package 'betareg' was built under R version 4.0.4"
# Warning message:
# "package 'glmmTMB' was built under R version 4.0.4"
# Warning message:
# "package 'rgr' was built under R version 4.0.4"
# Loading required package: fastICA
#
# Warning message:
# "package 'fastICA' was built under R version 4.0.4"
#
# Attaching package: 'rgr'
#
#
# The following object is masked from 'package:dplyr':
#
#     syms
#
#
# The following object is masked from 'package:ggplot2':
#
#     syms
#
#
# Loading required package: carData
#
#
# Attaching package: 'car'
#
#
# The following object is masked from 'package:rgr':
#
#     logit
#
#
# The following object is masked from 'package:dplyr':
#
#     recode
#
#
# The following object is masked from 'package:purrr':
#
#     some
#
#
# Loading required package: Rcpp
#
# This is rstanarm version 2.21.1
#
# - See https://mc-stan.org/rstanarm/articles/priors for changes to default priors!
#
# - Default priors may change, so it's safest to specify priors, even if equivalent to the defaults.
#
# - For execution on a local, multicore CPU with excess RAM we recommend calling
#
#   options(mc.cores = parallel::detectCores())
#
#
# Attaching package: 'rstanarm'
#
#
# The following object is masked from 'package:car':
#
#     logit
#
#
# The following object is masked from 'package:rgr':
#
#     logit
#
#
# The following objects are masked from 'package:caret':
#
#     compare_models, R2
#
#
#
# Attaching package: 'performance'
#
#
# The following object is masked from 'package:rstanarm':
#
#     pp_check

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/correctlightschedule_/visual/Treatment&Classs/adaptability'
df = read.csv(file.path(path_,'STATInterIntraDifferences.csv'), header = TRUE, sep = ";")
df$Treatment = as.factor(df$Treatment) 
df$PenID = as.factor(df$PenID)
df$henID1 = as.factor(df$henID1)
df$henID2 = as.factor(df$henID2)
df$inter_intra = as.factor(df$inter_intra)
df$DIB = as.integer(df$DIB) #as factor as within a week its not th etime taht we want to take into acount, but the event
df$factDIB = as.factor(df$DIB)
df$sqrtchi2distance = sqrt(df$chi2distance)
df$sqrtsqrtchi2distance = sqrt(df$sqrtchi2distance)
df$logchi2distance = log(df$chi2distance+1)
print(dim(df))
summary(df)
head(df, 3)
# Out:
# [1] 11918    51
#        X              DIB             DOA        Treatment       henID1
#  Min.   :    0   Min.   : 1.00   Min.   :119.0   OFH :5810   hen_10 :   96
#  1st Qu.: 2979   1st Qu.:19.00   1st Qu.:137.0   TRAN:6108   hen_108:   96
#  Median : 5958   Median :30.00   Median :148.0               hen_111:   96
#  Mean   : 5958   Mean   :29.72   Mean   :147.7               hen_112:   96
#  3rd Qu.: 8938   3rd Qu.:42.00   3rd Qu.:160.0               hen_117:   96
#  Max.   :11917   Max.   :53.00   Max.   :171.0               hen_118:   96
#                                                              (Other):11342
#      henID2      inter_intra      PenID      HenID1_CLASS
#  hen_118:  108   inter:5959   pen10  :1728   Length:11918
#  hen_69 :  107   intra:5959   pen11  :1728   Class :character
#  hen_9  :  107                pen12  :1516   Mode  :character
#  hen_143:  106                pen8   :1472
#  hen_99 :  106                pen9   :1468
#  hen_113:  105                pen3   :1398
#  (Other):11279                (Other):2608
#  HenID2_CLASS       weeks_in_laying_barn  chi2distance     DTW_15_1_Zone
#  Length:11918       Min.   :1.000        Min.   :0.00000   Min.   : 0.00
#  Class :character   1st Qu.:3.000        1st Qu.:0.02302   1st Qu.: 0.00
#  Mode  :character   Median :5.000        Median :0.07164   Median : 8.10
#                     Mean   :4.684        Mean   :0.16164   Mean   :10.35
#                     3rd Qu.:6.000        3rd Qu.:0.21340   3rd Qu.:17.50
#                     Max.   :8.000        Max.   :1.00000   Max.   :67.10
#
#  DTW_15_2_Zone    DTW_15_3_Zone    DTW_15_4_Zone    DTW_15_5_Zone
#  Min.   :  0.00   Min.   :  0.00   Min.   :  0.00   Min.   :  0.00
#  1st Qu.: 25.90   1st Qu.: 22.40   1st Qu.:  9.50   1st Qu.: 37.60
#  Median : 34.80   Median : 35.40   Median : 24.00   Median : 69.65
#  Mean   : 37.27   Mean   : 48.07   Mean   : 34.51   Mean   : 67.73
#  3rd Qu.: 46.30   3rd Qu.: 78.20   3rd Qu.: 49.67   3rd Qu.: 95.50
#  Max.   :145.00   Max.   :145.40   Max.   :143.20   Max.   :147.00
#
#  henID1_Total_number_transition henID1_nbr_stays_3_Zone henID1_nbr_stays_4_Zone
#  Min.   :  0.0                  Min.   : 0.0            Min.   : 0.000
#  1st Qu.: 23.0                  1st Qu.: 7.0            1st Qu.: 3.000
#  Median : 44.0                  Median :15.0            Median : 7.000
#  Mean   : 43.8                  Mean   :15.7            Mean   : 8.311
#  3rd Qu.: 63.0                  3rd Qu.:23.0            3rd Qu.:12.000
#  Max.   :159.0                  Max.   :64.0            Max.   :64.000
#
#  henID1_nbr_stays_5_Zone henID1_nbr_stays_2_Zone henID1_nbr_stays_1_Zone
#  Min.   : 0.000          Min.   : 0.0            Min.   : 0.000
#  1st Qu.: 2.000          1st Qu.: 4.0            1st Qu.: 0.000
#  Median : 4.000          Median :12.0            Median : 1.000
#  Mean   : 5.262          Mean   :13.3            Mean   : 2.226
#  3rd Qu.: 7.000          3rd Qu.:21.0            3rd Qu.: 4.000
#  Max.   :38.000          Max.   :56.0            Max.   :23.000
#
#      DOA.1       henID2_Total_number_transition henID2_nbr_stays_3_Zone
#  Min.   :120.0   Min.   :  0.00                 Min.   : 0.00
#  1st Qu.:138.0   1st Qu.: 24.00                 1st Qu.: 7.00
#  Median :149.0   Median : 45.00                 Median :16.00
#  Mean   :148.7   Mean   : 44.61                 Mean   :16.02
#  3rd Qu.:161.0   3rd Qu.: 63.00                 3rd Qu.:23.00
#  Max.   :172.0   Max.   :159.00                 Max.   :64.00
#
#  henID2_nbr_stays_4_Zone henID2_nbr_stays_5_Zone henID2_nbr_stays_2_Zone
#  Min.   : 0.000          Min.   : 0.000          Min.   : 0.00
#  1st Qu.: 3.000          1st Qu.: 2.000          1st Qu.: 4.00
#  Median : 7.000          Median : 4.000          Median :13.00
#  Mean   : 8.343          Mean   : 5.254          Mean   :13.67
#  3rd Qu.:12.000          3rd Qu.: 7.000          3rd Qu.:21.00
#  Max.   :64.000          Max.   :38.000          Max.   :56.00
#
#  henID2_nbr_stays_1_Zone min_Total_number_transition
#  Min.   : 0.000          Min.   :  0.00
#  1st Qu.: 0.000          1st Qu.: 15.00
#  Median : 1.000          Median : 35.00
#  Mean   : 2.316          Mean   : 35.19
#  3rd Qu.: 4.000          3rd Qu.: 53.00
#  Max.   :23.000          Max.   :144.00
#
#  max_Total_number_transition min_nbr_stays_3_Zone max_nbr_stays_3_Zone
#  Min.   :  0.00              Min.   : 0.00        Min.   : 0.00
#  1st Qu.: 34.00              1st Qu.: 4.00        1st Qu.:11.00
#  Median : 55.00              Median :12.00        Median :20.00
#  Mean   : 53.21              Mean   :12.25        Mean   :19.47
#  3rd Qu.: 72.00              3rd Qu.:19.00        3rd Qu.:27.00
#  Max.   :159.00              Max.   :52.00        Max.   :64.00
#
#  min_nbr_stays_4_Zone max_nbr_stays_4_Zone min_nbr_stays_5_Zone
#  Min.   : 0.000       Min.   : 0.00        Min.   : 0.000
#  1st Qu.: 2.000       1st Qu.: 5.00        1st Qu.: 2.000
#  Median : 5.000       Median :10.00        Median : 3.000
#  Mean   : 5.848       Mean   :10.81        Mean   : 3.814
#  3rd Qu.: 8.000       3rd Qu.:15.00        3rd Qu.: 5.000
#  Max.   :43.000       Max.   :64.00        Max.   :29.000
#
#  max_nbr_stays_5_Zone min_nbr_stays_2_Zone max_nbr_stays_2_Zone
#  Min.   : 0.000       Min.   : 0.00        Min.   : 0.00
#  1st Qu.: 3.000       1st Qu.: 2.00        1st Qu.: 8.00
#  Median : 6.000       Median : 8.00        Median :16.00
#  Mean   : 6.702       Mean   :10.17        Mean   :16.81
#  3rd Qu.: 9.000       3rd Qu.:16.00        3rd Qu.:24.00
#  Max.   :38.000       Max.   :48.00        Max.   :56.00
#
#  min_nbr_stays_1_Zone max_nbr_stays_1_Zone min_nbr_stays_5_Zone_cat
#  Min.   : 0.000       Min.   : 0.000       Length:11918
#  1st Qu.: 0.000       1st Qu.: 0.000       Class :character
#  Median : 0.000       Median : 2.000       Mode  :character
#  Mean   : 1.236       Mean   : 3.305
#  3rd Qu.: 2.000       3rd Qu.: 5.000
#  Max.   :20.000       Max.   :23.000
#
#  max_nbr_stays_5_Zone_cat X5_Zone_is_samerange is_only_other
#  Length:11918             Length:11918         Length:11918
#  Class :character         Class :character     Class :character
#  Mode  :character         Mode  :character     Mode  :character
#
#
#
#
#  overallCLASS          factDIB      sqrtchi2distance sqrtsqrtchi2distance
#  Length:11918       2      :  264   Min.   :0.0000   Min.   :0.0000
#  Class :character   7      :  264   1st Qu.:0.1517   1st Qu.:0.3895
#  Mode  :character   25     :  264   Median :0.2677   Median :0.5174
#                     26     :  264   Mean   :0.3295   Mean   :0.5357
#                     27     :  264   3rd Qu.:0.4619   3rd Qu.:0.6797
#                     28     :  264   Max.   :1.0000   Max.   :1.0000
#                     (Other):10334
#  logchi2distance
#  Min.   :0.00000
#  1st Qu.:0.02276
#  Median :0.06919
#  Mean   :0.13617
#  3rd Qu.:0.19342
#  Max.   :0.69315
#   X DIB DOA Treatment henID1  henID2  inter_intra PenID HenID1_CLASS
# 1 0 1   119 OFH       hen_102 hen_102 intra       pen3  MEXP
# 2 1 1   119 OFH       hen_104 hen_102 inter       pen3  Other
# 3 2 1   119 OFH       hen_102 hen_94  inter       pen3  MEXP
#   HenID2_CLASS ... max_nbr_stays_1_Zone min_nbr_stays_5_Zone_cat
# 1 MEXP         ... 0                    0-4
# 2 MEXP         ... 0                    0-4
# 3 LEXP         ... 0                    0-4
#   max_nbr_stays_5_Zone_cat X5_Zone_is_samerange is_only_other overallCLASS
# 1 0-4                      True                 False         MEXP-MEXP
# 2 0-4                      True                 False         MEXP-Other
# 3 0-4                      True                 False         LEXP-MEXP
#   factDIB sqrtchi2distance sqrtsqrtchi2distance logchi2distance
# 1 1       0.3591534        0.5992941            0.1213245
# 2 1       0.4711644        0.6864142            0.2004855
# 3 1       0.3591534        0.5992941            0.1213245

# %% [markdown]
# # Starting point of movement routine development

# %%
#choose data: with only non mexp 
df_DIB1 = df[ which(df$DIB==1), ]
df_DIB1 = df_DIB1[which(df_DIB1$is_only_other=='True'), ] #only involving 2 non MEXP birds
df_DIB1$max_Total_number_transition2 = df_DIB1$max_Total_number_transition**2
df_DIB1$min_Total_number_transition2 = df_DIB1$min_Total_number_transition**2
df_DIB1$sqrtmax_Total_number_transition = sqrt(df_DIB1$max_Total_number_transition)
df_DIB1$sqrtmin_Total_number_transition = sqrt(df_DIB1$min_Total_number_transition)
#df_DIB1$logitchi2distance = logit(df_DIB1$chi2distance) #, adjust=.025)#, percents=max(df_DIB1$chi2distance, na.rm = TRUE) > 1, adjust)
summary(df_DIB1)
dim(df_DIB1)
tail(df_DIB1,3)

#modelling
fit = lmerTest::lmer(sqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition + inter_intra + (1|PenID), 
           data=df_DIB1)
#PenID
#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
#tests the hypothesis that the random effect variation is significant versus the null that there is no between group-level 
#variation
rand(fit)
confint(fit)

#Assumptions
######linearity of predictors: plot residual vs observed
plot(resid(fit), df_DIB1$sqrtchi2distance)

###### normally distributed residuals
#qqmath(fit, id=0.05)
qqnorm(resid(fit), main = "Residuals")
qqline(resid(fit))
hist(resid(fit))
###### normally of random effects
qqmath(ranef(fit,condVar = TRUE))

######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(fit)

###### check if the residuals are independent. This can be checked by plotting residuals against covariates
plot(resid(fit),df_DIB1$max_Total_number_transition)
plot(resid(fit),df_DIB1$min_Total_number_transition)
# Out:
#        X               DIB         DOA      Treatment     henID1       henID2
#  Min.   : 13.00   Min.   :1   Min.   :119   OFH :46   hen_103: 2   hen_126: 3
#  1st Qu.: 73.75   1st Qu.:1   1st Qu.:119   TRAN:54   hen_105: 2   hen_155: 3
#  Median :126.50   Median :1   Median :119             hen_107: 2   hen_104: 2
#  Mean   :131.24   Mean   :1   Mean   :119             hen_111: 2   hen_107: 2
#  3rd Qu.:183.25   3rd Qu.:1   3rd Qu.:119             hen_112: 2   hen_108: 2
#  Max.   :260.00   Max.   :1   Max.   :119             hen_114: 2   hen_110: 2
#                                                       (Other):88   (Other):86
#  inter_intra     PenID    HenID1_CLASS       HenID2_CLASS
#  inter:31    pen11  :16   Length:100         Length:100
#  intra:69    pen8   :16   Class :character   Class :character
#              pen4   :14   Mode  :character   Mode  :character
#              pen12  :13
#              pen10  :11
#              pen5   :11
#              (Other):19
#  weeks_in_laying_barn  chi2distance     DTW_15_1_Zone DTW_15_2_Zone
#  Min.   :1            Min.   :0.00000   Min.   :0     Min.   :  0.00
#  1st Qu.:1            1st Qu.:0.04504   1st Qu.:0     1st Qu.: 26.32
#  Median :1            Median :0.12737   Median :0     Median : 40.95
#  Mean   :1            Mean   :0.23166   Mean   :0     Mean   : 49.08
#  3rd Qu.:1            3rd Qu.:0.32227   3rd Qu.:0     3rd Qu.: 75.83
#  Max.   :1            Max.   :1.00000   Max.   :0     Max.   :135.50
#
#  DTW_15_3_Zone    DTW_15_4_Zone   DTW_15_5_Zone
#  Min.   :  0.00   Min.   : 0.00   Min.   :  0.00
#  1st Qu.: 30.62   1st Qu.: 2.00   1st Qu.: 54.40
#  Median : 75.00   Median :13.15   Median : 92.10
#  Mean   : 65.24   Mean   :14.90   Mean   : 81.64
#  3rd Qu.: 94.92   3rd Qu.:22.38   3rd Qu.:112.30
#  Max.   :127.40   Max.   :90.60   Max.   :147.00
#
#  henID1_Total_number_transition henID1_nbr_stays_3_Zone henID1_nbr_stays_4_Zone
#  Min.   : 0.00                  Min.   : 0.00           Min.   : 0.00
#  1st Qu.: 5.00                  1st Qu.: 2.00           1st Qu.: 0.00
#  Median : 9.00                  Median : 4.00           Median : 1.00
#  Mean   :11.69                  Mean   : 4.75           Mean   : 2.38
#  3rd Qu.:15.00                  3rd Qu.: 7.00           3rd Qu.: 3.00
#  Max.   :46.00                  Max.   :19.00           Max.   :12.00
#
#  henID1_nbr_stays_5_Zone henID1_nbr_stays_2_Zone henID1_nbr_stays_1_Zone
#  Min.   :0.00            Min.   : 0.00           Min.   :0
#  1st Qu.:1.00            1st Qu.: 1.00           1st Qu.:0
#  Median :1.00            Median : 3.00           Median :0
#  Mean   :2.15            Mean   : 3.41           Mean   :0
#  3rd Qu.:3.00            3rd Qu.: 5.00           3rd Qu.:0
#  Max.   :8.00            Max.   :14.00           Max.   :0
#
#      DOA.1     henID2_Total_number_transition henID2_nbr_stays_3_Zone
#  Min.   :120   Min.   : 0.00                  Min.   : 0.00
#  1st Qu.:120   1st Qu.: 3.75                  1st Qu.: 1.00
#  Median :120   Median :10.00                  Median : 3.50
#  Mean   :120   Mean   :11.70                  Mean   : 4.96
#  3rd Qu.:120   3rd Qu.:19.00                  3rd Qu.: 8.00
#  Max.   :120   Max.   :41.00                  Max.   :16.00
#
#  henID2_nbr_stays_4_Zone henID2_nbr_stays_5_Zone henID2_nbr_stays_2_Zone
#  Min.   : 0.00           Min.   :0.00            Min.   : 0.00
#  1st Qu.: 0.00           1st Qu.:1.00            1st Qu.: 0.00
#  Median : 1.00           Median :1.00            Median : 3.00
#  Mean   : 1.94           Mean   :1.74            Mean   : 4.06
#  3rd Qu.: 2.00           3rd Qu.:2.00            3rd Qu.: 6.00
#  Max.   :17.00           Max.   :8.00            Max.   :15.00
#
#  henID2_nbr_stays_1_Zone min_Total_number_transition
#  Min.   :0               Min.   : 0.00
#  1st Qu.:0               1st Qu.: 0.00
#  Median :0               Median : 5.00
#  Mean   :0               Mean   : 7.69
#  3rd Qu.:0               3rd Qu.:12.25
#  Max.   :0               Max.   :37.00
#
#  max_Total_number_transition min_nbr_stays_3_Zone max_nbr_stays_3_Zone
#  Min.   : 0.00               Min.   : 0.00        Min.   : 0.00
#  1st Qu.: 8.00               1st Qu.: 0.00        1st Qu.: 3.00
#  Median :13.50               Median : 2.00        Median : 6.00
#  Mean   :15.70               Mean   : 2.95        Mean   : 6.76
#  3rd Qu.:22.25               3rd Qu.: 5.00        3rd Qu.:10.00
#  Max.   :46.00               Max.   :12.00        Max.   :19.00
#
#  min_nbr_stays_4_Zone max_nbr_stays_4_Zone min_nbr_stays_5_Zone
#  Min.   : 0.00        Min.   : 0.00        Min.   :0.00
#  1st Qu.: 0.00        1st Qu.: 1.00        1st Qu.:0.75
#  Median : 0.00        Median : 2.00        Median :1.00
#  Mean   : 1.21        Mean   : 3.11        Mean   :1.30
#  3rd Qu.: 2.00        3rd Qu.: 4.00        3rd Qu.:2.00
#  Max.   :12.00        Max.   :17.00        Max.   :7.00
#
#  max_nbr_stays_5_Zone min_nbr_stays_2_Zone max_nbr_stays_2_Zone
#  Min.   :0.00         Min.   : 0.00        Min.   : 0.00
#  1st Qu.:1.00         1st Qu.: 0.00        1st Qu.: 2.00
#  Median :2.00         Median : 1.00        Median : 5.00
#  Mean   :2.59         Mean   : 2.15        Mean   : 5.32
#  3rd Qu.:3.00         3rd Qu.: 3.00        3rd Qu.: 8.00
#  Max.   :8.00         Max.   :10.00        Max.   :15.00
#
#  min_nbr_stays_1_Zone max_nbr_stays_1_Zone min_nbr_stays_5_Zone_cat
#  Min.   :0            Min.   :0            Length:100
#  1st Qu.:0            1st Qu.:0            Class :character
#  Median :0            Median :0            Mode  :character
#  Mean   :0            Mean   :0
#  3rd Qu.:0            3rd Qu.:0
#  Max.   :0            Max.   :0
#
#  max_nbr_stays_5_Zone_cat X5_Zone_is_samerange is_only_other
#  Length:100               Length:100           Length:100
#  Class :character         Class :character     Class :character
#  Mode  :character         Mode  :character     Mode  :character
#
#
#
#
#  overallCLASS          factDIB    sqrtchi2distance sqrtsqrtchi2distance
#  Length:100         1      :100   Min.   :0.0000   Min.   :0.0000
#  Class :character   2      :  0   1st Qu.:0.2122   1st Qu.:0.4606
#  Mode  :character   3      :  0   Median :0.3569   Median :0.5974
#                     4      :  0   Mean   :0.4017   Mean   :0.5884
#                     5      :  0   3rd Qu.:0.5677   3rd Qu.:0.7534
#                     6      :  0   Max.   :1.0000   Max.   :1.0000
#                     (Other):  0
#  logchi2distance   max_Total_number_transition2 min_Total_number_transition2
#  Min.   :0.00000   Min.   :   0.0               Min.   :   0.0
#  1st Qu.:0.04405   1st Qu.:  64.0               1st Qu.:   0.0
#  Median :0.11989   Median : 182.5               Median :  25.0
#  Mean   :0.18796   Mean   : 354.8               Mean   : 118.3
#  3rd Qu.:0.27935   3rd Qu.: 495.2               3rd Qu.: 150.2
#  Max.   :0.69315   Max.   :2116.0               Max.   :1369.0
#
#  sqrtmax_Total_number_transition sqrtmin_Total_number_transition
#  Min.   :0.000                   Min.   :0.000
#  1st Qu.:2.828                   1st Qu.:0.000
#  Median :3.674                   Median :2.236
#  Mean   :3.688                   Mean   :2.234
#  3rd Qu.:4.717                   3rd Qu.:3.499
#  Max.   :6.782                   Max.   :6.083
# [1] 100  55
#     X   DIB DOA Treatment henID1  henID2  inter_intra PenID HenID1_CLASS
# 258 257 1   119 OFH       hen_92  hen_92  intra       pen3  Other
# 260 259 1   119 OFH       hen_20  hen_20  intra       pen3  Other
# 261 260 1   119 OFH       hen_103 hen_103 intra       pen3  Other
#     HenID2_CLASS ... is_only_other overallCLASS factDIB sqrtchi2distance
# 258 Other        ... True          Other-Other  1       0.3554090
# 260 Other        ... True          Other-Other  1       0.4264601
# 261 Other        ... True          Other-Other  1       0.4404819
#     sqrtsqrtchi2distance logchi2distance max_Total_number_transition2
# 258 0.5961619            0.1189518        841
# 260 0.6530392            0.1670965       1296
# 261 0.6636881            0.1773293        841
#     min_Total_number_transition2 sqrtmax_Total_number_transition
# 258 400                          5.385165
# 260 225                          6.000000
# 261 529                          5.385165
#     sqrtmin_Total_number_transition
# 258 4.472136
# 260 3.872983
# 261 4.795832
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# sqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition +
#     inter_intra + (1 | PenID)
#    Data: df_DIB1
#
# REML criterion at convergence: 13.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2357 -0.6681 -0.0537  0.5961  2.5850
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PenID    (Intercept) 0.003651 0.06043
#  Residual             0.049602 0.22272
# Number of obs: 100, groups:  PenID, 8
#
# Fixed effects:
#                              Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)                  0.523582   0.062878 48.661680   8.327 6.40e-11 ***
# max_Total_number_transition  0.009082   0.003445 92.114224   2.636  0.00983 **
# min_Total_number_transition -0.013435   0.004654 94.742600  -2.887  0.00482 **
# inter_intraintra            -0.228374   0.050610 91.843130  -4.512 1.89e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) mx_T__ mn_T__
# mx_Ttl_nmb_ -0.584
# mn_Ttl_nmb_  0.212 -0.758
# intr_ntrntr -0.664  0.274 -0.232
#             npar logLik    AIC      LRT      Df Pr(>Chisq)
# <none>      6    -6.587717 25.17543       NA NA        NA
# (1 | PenID) 5    -7.124730 24.24946 1.074024  1 0.3000382
# Computing profile confidence intervals ...
#                             2.5 %        97.5 %
# .sig01                       0.000000000  0.137421935
# .sigma                       0.190997099  0.256555576
# (Intercept)                  0.399460015  0.646138904
# max_Total_number_transition  0.002468399  0.016082907
# min_Total_number_transition -0.022538118 -0.004434068
# inter_intraintra            -0.325927105 -0.127948315
# plot without title
# Plot with title "Residuals"
# $PenID
# Plot with title "Histogram of resid(fit)"
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#get F values
#By default, the DFs in lmerTest (vs lme4: as its adding the p-value, not provided by lme4) are based on the Satterthwaite 
#approximation: https://en.wikipedia.org/wiki/Welch%E2%80%93Satterthwaite_equation
anova(fit)
# Out:
#                             Sum Sq    Mean Sq   NumDF DenDF    F value
# max_Total_number_transition 0.3447538 0.3447538 1     92.11422  6.950368
# min_Total_number_transition 0.4133682 0.4133682 1     94.74260  8.333660
# inter_intra                 1.0099945 1.0099945 1     91.84313 20.361874
#                             Pr(>F)
# max_Total_number_transition 9.834745e-03
# min_Total_number_transition 4.820538e-03
# inter_intra                 1.894017e-05

# %% [raw]
# After adjsutement for the number of transition of the animals compared, there was a statistically significant difference in the inter- and intra-similarity of the total duration of stays in each zone, (F(1,92)=20, p<0.00005)    (=0.000019)

# %% [markdown]
# # OHF as drivers of routine development

# %%
df_NOMEXP = df[ which(df$is_only_other=='True'), ]
df_NOMEXP$hoDIB = df_NOMEXP$DIB**2
df_NOMEXP$sqrtmin_Total_number_transition = sqrt(df_NOMEXP$min_Total_number_transition)
df_NOMEXP$sqrtmax_Total_number_transition = sqrt(df_NOMEXP$max_Total_number_transition)
df_NOMEXP$min_Total_number_transition2 = df_NOMEXP$min_Total_number_transition**2
df_NOMEXP$max_Total_number_transition2 = df_NOMEXP$max_Total_number_transition**2
df_NOMEXP$max_Total_number_transition2 = scale(df_NOMEXP$max_Total_number_transition2, center = FALSE, 
                                               scale = max(df_NOMEXP$max_Total_number_transition2, na.rm = TRUE)/100)
df_NOMEXP$min_Total_number_transition2 = scale(df_NOMEXP$min_Total_number_transition2, center = FALSE, 
                                               scale = max(df_NOMEXP$min_Total_number_transition2, na.rm = TRUE)/100)
dim(df_NOMEXP)
summary(df_NOMEXP)
tail(df_NOMEXP,3)
# Out:
# [1] 4678   56
#        X              DIB             DOA        Treatment       henID1
#  Min.   :   13   Min.   : 1.00   Min.   :119.0   OFH :2252   hen_87 :  84
#  1st Qu.: 3025   1st Qu.:19.00   1st Qu.:137.0   TRAN:2426   hen_118:  80
#  Median : 5962   Median :30.00   Median :148.0               hen_14 :  77
#  Mean   : 5964   Mean   :29.73   Mean   :147.7               hen_22 :  77
#  3rd Qu.: 8936   3rd Qu.:42.00   3rd Qu.:160.0               hen_108:  76
#  Max.   :11916   Max.   :53.00   Max.   :171.0               hen_112:  76
#                                                              (Other):4208
#      henID2     inter_intra      PenID     HenID1_CLASS
#  hen_118:  85   inter:1554   pen11  :837   Length:4678
#  hen_111:  81   intra:3124   pen8   :634   Class :character
#  hen_62 :  80                pen10  :623   Mode  :character
#  hen_87 :  79                pen4   :607
#  hen_112:  78                pen12  :562
#  hen_28 :  78                pen3   :499
#  (Other):4197                (Other):916
#  HenID2_CLASS       weeks_in_laying_barn  chi2distance     DTW_15_1_Zone
#  Length:4678        Min.   :1.000        Min.   :0.00000   Min.   : 0.000
#  Class :character   1st Qu.:3.000        1st Qu.:0.01634   1st Qu.: 0.000
#  Mode  :character   Median :5.000        Median :0.04697   Median : 8.100
#                     Mean   :4.686        Mean   :0.12283   Mean   : 9.704
#                     3rd Qu.:6.000        3rd Qu.:0.13943   3rd Qu.:16.100
#                     Max.   :8.000        Max.   :1.00000   Max.   :53.500
#
#  DTW_15_2_Zone    DTW_15_3_Zone    DTW_15_4_Zone    DTW_15_5_Zone
#  Min.   :  0.00   Min.   :  0.00   Min.   :  0.00   Min.   :  0.00
#  1st Qu.: 24.60   1st Qu.: 20.62   1st Qu.:  7.90   1st Qu.: 31.32
#  Median : 32.20   Median : 30.65   Median : 19.70   Median : 57.00
#  Mean   : 34.65   Mean   : 43.40   Mean   : 30.83   Mean   : 60.92
#  3rd Qu.: 42.70   3rd Qu.: 73.08   3rd Qu.: 41.50   3rd Qu.: 89.50
#  Max.   :135.50   Max.   :145.40   Max.   :127.70   Max.   :147.00
#
#  henID1_Total_number_transition henID1_nbr_stays_3_Zone henID1_nbr_stays_4_Zone
#  Min.   :  0.00                 Min.   : 0.00           Min.   : 0.000
#  1st Qu.: 23.00                 1st Qu.: 7.00           1st Qu.: 3.000
#  Median : 44.00                 Median :15.00           Median : 7.000
#  Mean   : 43.76                 Mean   :15.53           Mean   : 8.126
#  3rd Qu.: 62.00                 3rd Qu.:23.00           3rd Qu.:12.000
#  Max.   :150.00                 Max.   :64.00           Max.   :41.000
#
#  henID1_nbr_stays_5_Zone henID1_nbr_stays_2_Zone henID1_nbr_stays_1_Zone
#  Min.   : 0.000          Min.   : 0.00           Min.   : 0.000
#  1st Qu.: 2.000          1st Qu.: 5.00           1st Qu.: 0.000
#  Median : 4.000          Median :13.00           Median : 1.000
#  Mean   : 5.266          Mean   :13.46           Mean   : 2.388
#  3rd Qu.: 7.000          3rd Qu.:20.00           3rd Qu.: 4.000
#  Max.   :25.000          Max.   :55.00           Max.   :23.000
#
#      DOA.1       henID2_Total_number_transition henID2_nbr_stays_3_Zone
#  Min.   :120.0   Min.   :  0.00                 Min.   : 0.00
#  1st Qu.:138.0   1st Qu.: 24.00                 1st Qu.: 8.00
#  Median :149.0   Median : 46.00                 Median :16.00
#  Mean   :148.7   Mean   : 44.62                 Mean   :15.82
#  3rd Qu.:161.0   3rd Qu.: 63.00                 3rd Qu.:23.00
#  Max.   :172.0   Max.   :150.00                 Max.   :64.00
#
#  henID2_nbr_stays_4_Zone henID2_nbr_stays_5_Zone henID2_nbr_stays_2_Zone
#  Min.   : 0.000          Min.   : 0.0            Min.   : 0.00
#  1st Qu.: 3.000          1st Qu.: 2.0            1st Qu.: 5.00
#  Median : 7.000          Median : 4.0            Median :13.00
#  Mean   : 8.184          Mean   : 5.3            Mean   :13.82
#  3rd Qu.:12.000          3rd Qu.: 7.0            3rd Qu.:20.00
#  Max.   :41.000          Max.   :25.0            Max.   :55.00
#
#  henID2_nbr_stays_1_Zone min_Total_number_transition
#  Min.   : 0.000          Min.   :  0.00
#  1st Qu.: 0.000          1st Qu.: 17.00
#  Median : 1.000          Median : 38.00
#  Mean   : 2.492          Mean   : 36.63
#  3rd Qu.: 4.000          3rd Qu.: 54.00
#  Max.   :23.000          Max.   :131.00
#
#  max_Total_number_transition min_nbr_stays_3_Zone max_nbr_stays_3_Zone
#  Min.   :  0.00              Min.   : 0.00        Min.   : 0.0
#  1st Qu.: 32.00              1st Qu.: 5.00        1st Qu.:10.0
#  Median : 54.00              Median :12.00        Median :19.0
#  Mean   : 51.75              Mean   :12.65        Mean   :18.7
#  3rd Qu.: 71.00              3rd Qu.:19.00        3rd Qu.:26.0
#  Max.   :150.00              Max.   :50.00        Max.   :64.0
#
#  min_nbr_stays_4_Zone max_nbr_stays_4_Zone min_nbr_stays_5_Zone
#  Min.   : 0.000       Min.   : 0.00        Min.   : 0.000
#  1st Qu.: 2.000       1st Qu.: 5.00        1st Qu.: 2.000
#  Median : 5.000       Median : 9.00        Median : 3.000
#  Mean   : 6.053       Mean   :10.26        Mean   : 4.066
#  3rd Qu.: 9.000       3rd Qu.:14.00        3rd Qu.: 6.000
#  Max.   :37.000       Max.   :41.00        Max.   :21.000
#
#  max_nbr_stays_5_Zone min_nbr_stays_2_Zone max_nbr_stays_2_Zone
#  Min.   : 0.0         Min.   : 0.0         Min.   : 0.00
#  1st Qu.: 3.0         1st Qu.: 3.0         1st Qu.: 8.00
#  Median : 6.0         Median :10.0         Median :16.00
#  Mean   : 6.5         Mean   :10.9         Mean   :16.38
#  3rd Qu.: 9.0         3rd Qu.:17.0         3rd Qu.:24.00
#  Max.   :25.0         Max.   :47.0         Max.   :55.00
#
#  min_nbr_stays_1_Zone max_nbr_stays_1_Zone min_nbr_stays_5_Zone_cat
#  Min.   : 0.000       Min.   : 0.000       Length:4678
#  1st Qu.: 0.000       1st Qu.: 0.000       Class :character
#  Median : 0.000       Median : 2.000       Mode  :character
#  Mean   : 1.506       Mean   : 3.374
#  3rd Qu.: 2.000       3rd Qu.: 5.000
#  Max.   :20.000       Max.   :23.000
#
#  max_nbr_stays_5_Zone_cat X5_Zone_is_samerange is_only_other
#  Length:4678              Length:4678          Length:4678
#  Class :character         Class :character     Class :character
#  Mode  :character         Mode  :character     Mode  :character
#
#
#
#
#  overallCLASS          factDIB     sqrtchi2distance sqrtsqrtchi2distance
#  Length:4678        2      : 111   Min.   :0.0000   Min.   :0.0000
#  Class :character   46     : 109   1st Qu.:0.1278   1st Qu.:0.3575
#  Mode  :character   19     : 108   Median :0.2167   Median :0.4655
#                     32     : 108   Mean   :0.2789   Mean   :0.4889
#                     21     : 107   3rd Qu.:0.3734   3rd Qu.:0.6111
#                     22     : 107   Max.   :1.0000   Max.   :1.0000
#                     (Other):4028
#  logchi2distance       hoDIB      sqrtmin_Total_number_transition
#  Min.   :0.00000   Min.   :   1   Min.   : 0.000
#  1st Qu.:0.01621   1st Qu.: 361   1st Qu.: 4.123
#  Median :0.04590   Median : 900   Median : 6.164
#  Mean   :0.10483   Mean   :1091   Mean   : 5.466
#  3rd Qu.:0.13053   3rd Qu.:1764   3rd Qu.: 7.348
#  Max.   :0.69315   Max.   :2809   Max.   :11.446
#
#  sqrtmax_Total_number_transition min_Total_number_transition2.V1
#  Min.   : 0.000                  Min.   :  0.00000
#  1st Qu.: 5.657                  1st Qu.:  1.68405
#  Median : 7.348                  Median :  8.41443
#  Mean   : 6.806                  Mean   : 11.24505
#  3rd Qu.: 8.426                  3rd Qu.: 16.99202
#  Max.   :12.247                  Max.   :100.00000
#
#  max_Total_number_transition2.V1
#  Min.   :  0.00000
#  1st Qu.:  4.55111
#  Median : 12.96000
#  Mean   : 15.23442
#  3rd Qu.: 22.40444
#  Max.   :100.00000
#       X     DIB DOA Treatment henID1 henID2 inter_intra PenID HenID1_CLASS
# 11915 11914 53  171 TRAN      hen_58 hen_50 inter       pen4  Other
# 11916 11915 53  171 TRAN      hen_58 hen_58 intra       pen4  Other
# 11917 11916 53  171 TRAN      hen_48 hen_48 intra       pen4  Other
#       HenID2_CLASS ... overallCLASS factDIB sqrtchi2distance
# 11915 Other        ... Other-Other  53      0.35676844
# 11916 Other        ... Other-Other  53      0.04018854
# 11917 Other        ... Other-Other  53      0.07229873
#       sqrtsqrtchi2distance logchi2distance hoDIB
# 11915 0.5973010            0.119810954     2809
# 11916 0.2004708            0.001613816     2809
# 11917 0.2688842            0.005213493     2809
#       sqrtmin_Total_number_transition sqrtmax_Total_number_transition
# 11915 7.745967                        9.433981
# 11916 7.745967                        8.831761
# 11917 8.000000                        8.774964
#       min_Total_number_transition2 max_Total_number_transition2
# 11915 20.97780                     35.20444
# 11916 20.97780                     27.04000
# 11917 23.86807                     26.35111

# %%
#choosing data: ONLY inter to compare treatment FINAL 1
#with only non mexp
df_NOMEXPINTER = df_NOMEXP[ which(df_NOMEXP$inter_intra=='inter'), ]
dim(df_NOMEXPINTER)
tail(df_NOMEXPINTER,3)

#modelling
fit = lmerTest::lmer(sqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition + DIB + Treatment*DIB + (1|PenID/henID1), 
           data=df_NOMEXPINTER)
#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
#tests the hypothesis that the random effect variation is significant versus the null that there is no between group-level 
#variation
rand(fit)
confint(fit)

#Assumptions
######linearity of predictors: plot residual vs observed
plot(resid(fit), df_NOMEXPINTER$sqrtchi2distance)

###### normally distributed residuals
#qqmath(fit, id=0.05)
qqnorm(resid(fit), main = "Residuals")
qqline(resid(fit))
hist(resid(fit))
###### normally of random effects
qqmath(ranef(fit,condVar = TRUE))

######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(fit)

###### check if the residuals are independent. This can be checked by plotting residuals against covariates - especially time-varying or spatial covariates. There should not be any systematic pattern
plot(resid(fit),df_NOMEXPINTER$DIB)
plot(resid(fit),df_NOMEXPINTER$max_Total_number_transition)
plot(resid(fit),df_NOMEXPINTER$min_Total_number_transition)
# Out:
# [1] 1554   56
#       X     DIB DOA Treatment henID1  henID2 inter_intra PenID HenID1_CLASS
# 11909 11908 53  171 TRAN      hen_131 hen_49 inter       pen10 Other
# 11913 11912 53  171 TRAN      hen_142 hen_43 inter       pen4  Other
# 11915 11914 53  171 TRAN      hen_58  hen_50 inter       pen4  Other
#       HenID2_CLASS ... overallCLASS factDIB sqrtchi2distance
# 11909 Other        ... Other-Other  53      0.6743549
# 11913 Other        ... Other-Other  53      0.1114562
# 11915 Other        ... Other-Other  53      0.3567684
#       sqrtsqrtchi2distance logchi2distance hoDIB
# 11909 0.8211912            0.37483720      2809
# 11913 0.3338506            0.01234597      2809
# 11915 0.5973010            0.11981095      2809
#       sqrtmin_Total_number_transition sqrtmax_Total_number_transition
# 11909 6.324555                        8.831761
# 11913 6.855655                        9.165151
# 11915 7.745967                        9.433981
#       min_Total_number_transition2 max_Total_number_transition2
# 11909  9.323466                    27.04000
# 11913 12.872210                    31.36000
# 11915 20.977798                    35.20444
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# sqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition +
#     DIB + Treatment * DIB + (1 | PenID/henID1)
#    Data: df_NOMEXPINTER
#
# REML criterion at convergence: -528.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.73233 -0.67236 -0.04265  0.67904  2.60534
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  henID1:PenID (Intercept) 0.001042 0.03228
#  PenID        (Intercept) 0.001615 0.04019
#  Residual                 0.038879 0.19718
# Number of obs: 1554, groups:  henID1:PenID, 69; PenID, 8
#
# Fixed effects:
#                               Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)                  5.194e-01  2.729e-02  1.304e+01  19.037 6.77e-11
# max_Total_number_transition  3.309e-03  2.828e-04  1.542e+03  11.701  < 2e-16
# min_Total_number_transition -6.463e-03  3.423e-04  1.488e+03 -18.879  < 2e-16
# DIB                         -1.368e-03  5.598e-04  1.540e+03  -2.444   0.0146
# TreatmentTRAN               -1.648e-02  3.775e-02  1.197e+01  -0.437   0.6702
# DIB:TreatmentTRAN            6.190e-04  7.048e-04  1.511e+03   0.878   0.3800
#
# (Intercept)                 ***
# max_Total_number_transition ***
# min_Total_number_transition ***
# DIB                         *
# TreatmentTRAN
# DIB:TreatmentTRAN
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) mx_T__ mn_T__ DIB    TrTRAN
# mx_Ttl_nmb_ -0.200
# mn_Ttl_nmb_  0.053 -0.537
# DIB         -0.408 -0.258 -0.175
# TretmntTRAN -0.674 -0.064 -0.025  0.392
# DIB:TrtTRAN  0.366  0.088 -0.049 -0.653 -0.557
#                    npar logLik   AIC       LRT       Df Pr(>Chisq)
# <none>             9    264.1824 -510.3648        NA NA           NA
# (1 | henID1:PenID) 8    260.4141 -504.8282  7.536557  1 0.0060459460
# (1 | PenID)        8    258.2945 -500.5890 11.775778  1 0.0006000644
# Computing profile confidence intervals ...
#                             2.5 %         97.5 %
# .sig01                       0.0152362992  0.0483165351
# .sig02                       0.0150941613  0.0663444748
# .sigma                       0.1900585343  0.2042464930
# (Intercept)                  0.4683101920  0.5706802017
# max_Total_number_transition  0.0027586689  0.0038689793
# min_Total_number_transition -0.0071173428 -0.0057717722
# DIB                         -0.0024801037 -0.0002850045
# TreatmentTRAN               -0.0872969700  0.0543712088
# DIB:TreatmentTRAN           -0.0007642115  0.0019971254
# plot without title
# Plot with title "Residuals"
# Plot with title "Histogram of resid(fit)"
# $`henID1:PenID`
#
# $PenID
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#choosing data: ONLY inter to compare treatment FINAL 1
#with only non mexp
df_NOMEXP = df[ which(df$is_only_other=='True'), ]
df_NOMEXPINTRA = df_NOMEXP[which(df_NOMEXP$inter_intra=='intra'), ]
dim(df_NOMEXPINTRA)
tail(df_NOMEXPINTRA,3)

#modelling
fit = lmerTest::lmer(sqrtsqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition + DIB + Treatment*DIB + (1|henID1), 
           data=df_NOMEXPINTRA)
#capture.output(summary(fit), file=file.path(path_,paste(name,'.txt', sep='')), append=TRUE)
summary(fit)
#tests the hypothesis that the random effect variation is significant versus the null that there is no between group-level 
#variation
rand(fit)
confint(fit)

#Assumptions
######linearity of predictors: plot residual vs observed
plot(resid(fit), df_NOMEXPINTRA$sqrtsqrtchi2distance)

###### normally distributed residuals
#qqmath(fit, id=0.05)
qqnorm(resid(fit), main = "Residuals")
qqline(resid(fit))
hist(resid(fit))
###### normally of random effects
qqmath(ranef(fit,condVar = TRUE))

######check homogeneity of variance (residuals has constant variance)
#variance of the residuals is equal across groups. Even spread around the centered line?
plot(fit)

###### check if the residuals are independent. This can be checked by plotting residuals against covariates - especially time-varying or spatial covariates. There should not be any systematic pattern
plot(resid(fit), df_NOMEXPINTRA$DIB)
plot(resid(fit), df_NOMEXPINTRA$max_Total_number_transition)
plot(resid(fit), df_NOMEXPINTRA$min_Total_number_transition)
# Out:
# [1] 3124   51
#       X     DIB DOA Treatment henID1 henID2 inter_intra PenID HenID1_CLASS
# 11914 11913 53  171 TRAN      hen_50 hen_50 intra       pen4  Other
# 11916 11915 53  171 TRAN      hen_58 hen_58 intra       pen4  Other
# 11917 11916 53  171 TRAN      hen_48 hen_48 intra       pen4  Other
#       HenID2_CLASS ... max_nbr_stays_1_Zone min_nbr_stays_5_Zone_cat
# 11914 Other        ... 12                   5-9
# 11916 Other        ...  0                   0-4
# 11917 Other        ...  2                   0-4
#       max_nbr_stays_5_Zone_cat X5_Zone_is_samerange is_only_other overallCLASS
# 11914 5-9                      True                 True          Other-Other
# 11916 0-4                      True                 True          Other-Other
# 11917 0-4                      True                 True          Other-Other
#       factDIB sqrtchi2distance sqrtsqrtchi2distance logchi2distance
# 11914 53      0.12403856       0.3521911            0.015268407
# 11916 53      0.04018854       0.2004708            0.001613816
# 11917 53      0.07229873       0.2688842            0.005213493
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# sqrtsqrtchi2distance ~ max_Total_number_transition + min_Total_number_transition +
#     DIB + Treatment * DIB + (1 | henID1)
#    Data: df_NOMEXPINTRA
#
# REML criterion at convergence: -3322.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1523 -0.5458  0.0027  0.5916  4.0488
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  henID1   (Intercept) 0.001313 0.03623
#  Residual             0.019155 0.13840
# Number of obs: 3124, groups:  henID1, 69
#
# Fixed effects:
#                               Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)                  4.061e-01  1.054e-02  2.963e+02  38.543  < 2e-16
# max_Total_number_transition  5.188e-03  2.671e-04  3.114e+03  19.422  < 2e-16
# min_Total_number_transition -5.613e-03  3.064e-04  3.115e+03 -18.321  < 2e-16
# DIB                         -1.342e-03  2.693e-04  3.118e+03  -4.984 6.57e-07
# TreatmentTRAN                1.612e-02  1.439e-02  2.716e+02   1.120    0.264
# DIB:TreatmentTRAN           -3.306e-04  3.438e-04  3.054e+03  -0.962    0.336
#
# (Intercept)                 ***
# max_Total_number_transition ***
# min_Total_number_transition ***
# DIB                         ***
# TreatmentTRAN
# DIB:TreatmentTRAN
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) mx_T__ mn_T__ DIB    TrTRAN
# mx_Ttl_nmb_ -0.182
# mn_Ttl_nmb_  0.100 -0.897
# DIB         -0.567 -0.065 -0.118
# TretmntTRAN -0.673 -0.031 -0.014  0.505
# DIB:TrtTRAN  0.489  0.033 -0.019 -0.667 -0.712
#              npar logLik   AIC       LRT      Df Pr(>Chisq)
# <none>       8    1661.443 -3306.886       NA NA           NA
# (1 | henID1) 7    1609.347 -3204.695 104.1919  1 1.836442e-24
# Computing profile confidence intervals ...
#                             2.5 %        97.5 %
# .sig01                       0.028264585  0.0444547454
# .sigma                       0.134917241  0.1418571598
# (Intercept)                  0.385498959  0.4266180430
# max_Total_number_transition  0.004666546  0.0057140489
# min_Total_number_transition -0.006212237 -0.0050121967
# DIB                         -0.001872044 -0.0008162309
# TreatmentTRAN               -0.011966055  0.0441906822
# DIB:TreatmentTRAN           -0.001003991  0.0003432481
# plot without title
# Plot with title "Residuals"
# $henID1
# Plot with title "Histogram of resid(fit)"
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [raw]
# after abstract obsrvation:
# with sqrtsqrtchi2distance assumptions are better met, and the Treatment is not significant. with sqrtchi2distance assumptions aren't met and the treatment is slightly significant
