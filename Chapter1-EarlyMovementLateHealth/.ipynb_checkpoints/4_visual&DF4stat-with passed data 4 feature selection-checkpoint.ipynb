# %%
#basic package
import tqdm
import os
import numpy as np
import glob
import pandas as pd
import sys
import time
import datetime as dt
import itertools
import re
import math
from collections import Counter
import operator
from scipy import stats
import random
import pickle
from scipy.stats import pearsonr, spearmanr
#repeated measures correlation
import pingouin as pg
from sklearn.utils import shuffle
import random
from scipy import stats

#plot
import joypy # for ridgeplot
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.8, the latest is 0.5.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# C:\Users\camil\anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
PACKAGE_PARENT = '../'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))
from UTILS import kmeans_clustering, sampen, chi2_distance, ts_visual, correct_key, chi2_distance, most_frequent, mssd
import config_origins as config
# Out:
# 2
# C:\Users\camil\anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %% [markdown]
# # Define parameters

# %%
path_extracted_data = config.path_extracted_data
id_run = config.id_run
path_extracted_data_adap = os.path.join(path_extracted_data,'Adaptability')
print(id_run)
# Out:
# ALLDATA_
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Download estimates - Individuality plasticity, intercept, variability

# %%
#download ind.plasticity over time
df_pred = pd.read_csv(os.path.join(path_extracted_data_adap,'IndividualPredictability.csv'), sep=',')
print(df_pred.shape)
display(df_pred.head(3))
print(list(df_pred.columns))
#sd_HenID__sigma_Intercept: is the estimate for individual differences in residual variance
#b_sigma_Intercept: is the population level estimate of the residual variance
li_col = [x for x in df_pred.columns if 'r_HenID__sigma' in x]
df_pred = df_pred[li_col]#+ ['b_sigma_Intercept']]
#add population level estimate of the residual variance
#for c in li_col:
#    df_pred[c] = df_pred.apply(lambda x: x[c]+x['b_sigma_Intercept'], axis=1)
#doe snot change anything, to keep simple we wont add the pop. level estiamte
display(df_pred.head(3))
#melt data for simplicity
df_pred['run'] = df_pred.index
df_pred = pd.melt(df_pred, id_vars=['run'], value_vars=li_col)
df_pred['HenID'] = df_pred['variable'].map(lambda x: x.split('r_HenID__sigma.')[1].split('.')[0])
#"Importantly, in order to assess whether individuals differ in variance the residual part of the model iscalculated on the log 
#scale! In order to interpret rIIV in biological terms we backtransform rIIV by takingit’s original scale by taking its exponent"
df_pred['Predictability'] = df_pred['value'].map(lambda x: np.exp(x))
print(df_pred.shape)
df_pred.head(3)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (2500, 5340)
#    X1.b_Intercept  X1.b_sigma_Intercept  X1.b_cDIB_scale  X1.b_IcDIB_scaleE2  \
# 0        0.282680             -0.775720         0.133729           -0.266303
# 1        0.335173             -0.821186         0.120627           -0.272111
# 2        0.308617             -0.755026         0.107183           -0.245811
#
#    X1.b_Treatment_encoded  X1.b_temperature_C_avg_scale  \
# 0               -0.231259                     -0.035204
# 1               -0.205126                     -0.037319
# 2               -0.195027                     -0.031603
#
#    X1.sd_HenID__Intercept  X1.sd_HenID__cDIB_scale  \
# 0                0.770372                 0.323380
# 1                0.798852                 0.334838
# 2                0.688947                 0.390002
#
#    X1.sd_HenID__IcDIB_scaleE2  X1.sd_HenID__sigma_Intercept  ...  \
# 0                    0.196165                      0.325706  ...
# 1                    0.194752                      0.370416  ...
# 2                    0.233084                      0.329125  ...
#
#    X10.r_HenID__sigma.hen_9.Intercept.  X10.r_HenID__sigma.hen_90.Intercept.  \
# 0                            -0.457754                             -0.143113
# 1                            -0.372533                             -0.028809
# 2                            -0.335472                             -0.102084
#
#    X10.r_HenID__sigma.hen_91.Intercept.  X10.r_HenID__sigma.hen_92.Intercept.  \
# 0                              0.121054                              0.034033
# 1                              0.156037                             -0.046329
# 2                              0.138843                              0.056368
#
#    X10.r_HenID__sigma.hen_94.Intercept.  X10.r_HenID__sigma.hen_95.Intercept.  \
# 0                              0.056074                             -0.472108
# 1                              0.221265                             -0.331144
# 2                              0.143238                             -0.392572
#
#    X10.r_HenID__sigma.hen_97.Intercept.  X10.r_HenID__sigma.hen_98.Intercept.  \
# 0                             -0.172787                              0.046222
# 1                             -0.284158                              0.008143
# 2                             -0.136007                             -0.038475
#
#    X10.r_HenID__sigma.hen_99.Intercept.     X10.lp__
# 0                             -0.321071 -4278.262562
# 1                             -0.207100 -4292.755704
# 2                             -0.348943 -4297.327739
#
# [3 rows x 5340 columns]
# ['X1.b_Intercept', 'X1.b_sigma_Intercept', 'X1.b_cDIB_scale', 'X1.b_IcDIB_scaleE2', 'X1.b_Treatment_encoded', 'X1.b_temperature_C_avg_scale', 'X1.sd_HenID__Intercept', 'X1.sd_HenID__cDIB_scale', 'X1.sd_HenID__IcDIB_scaleE2', 'X1.sd_HenID__sigma_Intercept', 'X1.cor_HenID__Intercept__cDIB_scale', 'X1.cor_HenID__Intercept__IcDIB_scaleE2', 'X1.cor_HenID__cDIB_scale__IcDIB_scaleE2', 'X1.r_HenID.hen_1.Intercept.', 'X1.r_HenID.hen_10.Intercept.', 'X1.r_HenID.hen_101.Intercept.', 'X1.r_HenID.hen_102.Intercept.', 'X1.r_HenID.hen_103.Intercept.', 'X1.r_HenID.hen_104.Intercept.', 'X1.r_HenID.hen_105.Intercept.', 'X1.r_HenID.hen_106.Intercept.', 'X1.r_HenID.hen_107.Intercept.', 'X1.r_HenID.hen_108.Intercept.', 'X1.r_HenID.hen_109.Intercept.', 'X1.r_HenID.hen_110.Intercept.', 'X1.r_HenID.hen_111.Intercept.', 'X1.r_HenID.hen_112.Intercept.', 'X1.r_HenID.hen_113.Intercept.', 'X1.r_HenID.hen_114.Intercept.', 'X1.r_HenID.hen_116.Intercept.', 'X1.r_HenID.hen_117.Intercept.', 'X1.r_HenID.hen_118.Intercept.', 'X1.r_HenID.hen_119.Intercept.', 'X1.r_HenID.hen_12.Intercept.', 'X1.r_HenID.hen_123.Intercept.', 'X1.r_HenID.hen_124.Intercept.', 'X1.r_HenID.hen_126.Intercept.', 'X1.r_HenID.hen_127.Intercept.', 'X1.r_HenID.hen_128.Intercept.', 'X1.r_HenID.hen_13.Intercept.', 'X1.r_HenID.hen_131.Intercept.', 'X1.r_HenID.hen_134.Intercept.', 'X1.r_HenID.hen_135.Intercept.', 'X1.r_HenID.hen_136.Intercept.', 'X1.r_HenID.hen_137.Intercept.', 'X1.r_HenID.hen_138.Intercept.', 'X1.r_HenID.hen_139.Intercept.', 'X1.r_HenID.hen_14.Intercept.', 'X1.r_HenID.hen_140.Intercept.', 'X1.r_HenID.hen_141.Intercept.', 'X1.r_HenID.hen_142.Intercept.', 'X1.r_HenID.hen_143.Intercept.', 'X1.r_HenID.hen_144.Intercept.', 'X1.r_HenID.hen_145.Intercept.', 'X1.r_HenID.hen_146.Intercept.', 'X1.r_HenID.hen_147.Intercept.', 'X1.r_HenID.hen_149.Intercept.', 'X1.r_HenID.hen_150.Intercept.', 'X1.r_HenID.hen_151.Intercept.', 'X1.r_HenID.hen_153.Intercept.', 'X1.r_HenID.hen_154.Intercept.', 'X1.r_HenID.hen_155.Intercept.', 'X1.r_HenID.hen_158.Intercept.', 'X1.r_HenID.hen_159.Intercept.', 'X1.r_HenID.hen_17.Intercept.', 'X1.r_HenID.hen_18.Intercept.', 'X1.r_HenID.hen_19.Intercept.', 'X1.r_HenID.hen_2.Intercept.', 'X1.r_HenID.hen_20.Intercept.', 'X1.r_HenID.hen_21.Intercept.', 'X1.r_HenID.hen_22.Intercept.', 'X1.r_HenID.hen_23.Intercept.', 'X1.r_HenID.hen_24.Intercept.', 'X1.r_HenID.hen_25.Intercept.', 'X1.r_HenID.hen_26.Intercept.', 'X1.r_HenID.hen_27.Intercept.', 'X1.r_HenID.hen_28.Intercept.', 'X1.r_HenID.hen_29.Intercept.', 'X1.r_HenID.hen_3.Intercept.', 'X1.r_HenID.hen_32.Intercept.', 'X1.r_HenID.hen_34.Intercept.', 'X1.r_HenID.hen_39.Intercept.', 'X1.r_HenID.hen_4.Intercept.', 'X1.r_HenID.hen_40.Intercept.', 'X1.r_HenID.hen_41.Intercept.', 'X1.r_HenID.hen_42.Intercept.', 'X1.r_HenID.hen_43.Intercept.', 'X1.r_HenID.hen_44.Intercept.', 'X1.r_HenID.hen_46.Intercept.', 'X1.r_HenID.hen_47.Intercept.', 'X1.r_HenID.hen_48.Intercept.', 'X1.r_HenID.hen_49.Intercept.', 'X1.r_HenID.hen_5.Intercept.', 'X1.r_HenID.hen_50.Intercept.', 'X1.r_HenID.hen_51.Intercept.', 'X1.r_HenID.hen_53.Intercept.', 'X1.r_HenID.hen_54.Intercept.', 'X1.r_HenID.hen_55.Intercept.', 'X1.r_HenID.hen_56.Intercept.', 'X1.r_HenID.hen_57.Intercept.', 'X1.r_HenID.hen_58.Intercept.', 'X1.r_HenID.hen_59.Intercept.', 'X1.r_HenID.hen_6.Intercept.', 'X1.r_HenID.hen_60.Intercept.', 'X1.r_HenID.hen_61.Intercept.', 'X1.r_HenID.hen_62.Intercept.', 'X1.r_HenID.hen_63.Intercept.', 'X1.r_HenID.hen_64.Intercept.', 'X1.r_HenID.hen_65.Intercept.', 'X1.r_HenID.hen_66.Intercept.', 'X1.r_HenID.hen_67.Intercept.', 'X1.r_HenID.hen_68.Intercept.', 'X1.r_HenID.hen_69.Intercept.', 'X1.r_HenID.hen_7.Intercept.', 'X1.r_HenID.hen_70.Intercept.', 'X1.r_HenID.hen_71.Intercept.', 'X1.r_HenID.hen_73.Intercept.', 'X1.r_HenID.hen_74.Intercept.', 'X1.r_HenID.hen_75.Intercept.', 'X1.r_HenID.hen_76.Intercept.', 'X1.r_HenID.hen_77.Intercept.', 'X1.r_HenID.hen_78.Intercept.', 'X1.r_HenID.hen_79.Intercept.', 'X1.r_HenID.hen_8.Intercept.', 'X1.r_HenID.hen_80.Intercept. ...
#    X1.r_HenID__sigma.hen_1.Intercept.  X1.r_HenID__sigma.hen_10.Intercept.  \
# 0                           -0.005904                             0.047861
# 1                           -0.170412                            -0.098106
# 2                           -0.169915                             0.364136
#
#    X1.r_HenID__sigma.hen_101.Intercept.  X1.r_HenID__sigma.hen_102.Intercept.  \
# 0                              0.173210                             -0.614399
# 1                              0.437964                             -0.634846
# 2                              0.305162                             -0.555484
#
#    X1.r_HenID__sigma.hen_103.Intercept.  X1.r_HenID__sigma.hen_104.Intercept.  \
# 0                              0.159587                              0.432441
# 1                              0.126732                              0.317560
# 2                              0.324370                              0.701538
#
#    X1.r_HenID__sigma.hen_105.Intercept.  X1.r_HenID__sigma.hen_106.Intercept.  \
# 0                              0.562305                              0.279357
# 1                              0.434647                              0.396280
# 2                              0.208931                              0.203863
#
#    X1.r_HenID__sigma.hen_107.Intercept.  X1.r_HenID__sigma.hen_108.Intercept.  \
# 0                              0.443795                              0.088944
# 1                              0.583353                              0.202645
# 2                              0.403434                             -0.078094
#
#    ...  X10.r_HenID__sigma.hen_89.Intercept.  \
# 0  ...                             -0.433353
# 1  ...                             -0.371251
# 2  ...                             -0.621434
#
#    X10.r_HenID__sigma.hen_9.Intercept.  X10.r_HenID__sigma.hen_90.Intercept.  \
# 0                            -0.457754                             -0.143113
# 1                            -0.372533                             -0.028809
# 2                            -0.335472                             -0.102084
#
#    X10.r_HenID__sigma.hen_91.Intercept.  X10.r_HenID__sigma.hen_92.Intercept.  \
# 0                              0.121054                              0.034033
# 1                              0.156037                             -0.046329
# 2                              0.138843                              0.056368
#
#    X10.r_HenID__sigma.hen_94.Intercept.  X10.r_HenID__sigma.hen_95.Intercept.  \
# 0                              0.056074                             -0.472108
# 1                              0.221265                             -0.331144
# 2                              0.143238                             -0.392572
#
#    X10.r_HenID__sigma.hen_97.Intercept.  X10.r_HenID__sigma.hen_98.Intercept.  \
# 0                             -0.172787                              0.046222
# 1                             -0.284158                              0.008143
# 2                             -0.136007                             -0.038475
#
#    X10.r_HenID__sigma.hen_99.Intercept.
# 0                             -0.321071
# 1                             -0.207100
# 2                             -0.348943
#
# [3 rows x 1300 columns]
# (3250000, 5)
#    run                            variable     value  HenID  Predictability
# 0    0  X1.r_HenID__sigma.hen_1.Intercept. -0.005904  hen_1        0.994114
# 1    1  X1.r_HenID__sigma.hen_1.Intercept. -0.170412  hen_1        0.843317
# 2    2  X1.r_HenID__sigma.hen_1.Intercept. -0.169915  hen_1        0.843737

# %% [markdown]
# #download ind.plasticity over time
# df_pred = pd.read_csv(os.path.join(path_extracted_data_adap,'IndividualPredictability.csv'), sep=',')
# print(df_pred.shape)
# display(df_pred.head(3))
# print(list(df_pred.columns))
# li_col = [x for x in df_pred.columns if 'r_HenID__sigma' in x]
# df_pred = df_pred[li_col]
# df_pred['run'] = df_pred.index
# df_pred = pd.melt(df_pred, id_vars=['run'], value_vars=li_col)
# df_pred['HenID'] = df_pred['variable'].map(lambda x: x.split('[')[1].split(',')[0])
# #"Importantly, in order to assess whether individuals differ in variance the residual part of the model iscalculated on the log
# #scale! In order to interpret rIIV in biological terms we backtransform rIIV by takingit’s original scale by taking its exponent"
# df_pred['Predictability'] = df_pred['value'].map(lambda x: np.exp(x))
# print(df_pred.shape)
# df_pred.head(3)

# %%
#download ind plasticity and intercepts
df_BT = pd.read_csv(os.path.join(path_extracted_data_adap,'IndividualBehaviouralType.csv'), sep=',')
print(df_BT.shape)
df_BT.head(3)
# Out:
# (130, 6)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   groupFctr  groupID         term      mean    median        sd
# 0     HenID    hen_1  (Intercept) -0.852194 -0.847932  0.124761
# 1     HenID   hen_10  (Intercept) -0.366230 -0.371412  0.132275
# 2     HenID  hen_101  (Intercept)  0.669667  0.673175  0.134817

# %%
#download ind plasticity and intercepts
df_ind = pd.read_csv(os.path.join(path_extracted_data_adap,'IndividualPlasticity.csv'), sep=',')
display(df_ind['term'].unique())
dico_ = {'(Intercept)':'BLUP_int', 
         'cDIB_scale':'BLUP_slopes1', 
         'I(cDIB_scale^2)':'BLUP_slopes2'}
df_ind['term'] = df_ind['term'].map(lambda x: dico_[x])
print(df_ind.shape)
print(df_ind['groupFctr'].unique(), df_ind['term'].unique())
df_ind.head(3)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['(Intercept)', 'cDIB_scale', 'I(cDIB_scale^2)'], dtype=object)
# (390, 6)
# ['HenID'] ['BLUP_int' 'BLUP_slopes1' 'BLUP_slopes2']
#   groupFctr  groupID      term      mean    median        sd
# 0     HenID    hen_1  BLUP_int -1.189385 -1.189729  0.164508
# 1     HenID   hen_10  BLUP_int -0.586497 -0.587552  0.152073
# 2     HenID  hen_101  BLUP_int  0.653292  0.653099  0.171215

# %% [markdown]
# # Select individuals to highlight in visuals

# %%
#select 5 hens to highlight within the plot: two most extremes intercept (min, max), two most extreme plasticity (min, max) 
#and one?

#Behavioural type
li = df_BT.sort_values('mean', ascending=True)['groupID'].tolist()
li_int = [li[-1], li[0]]
print(li_int)

#Plasticity
li = df_ind[df_ind['term']=='BLUP_slopes2'].sort_values('mean', ascending=True)['groupID'].tolist()
li_plasticity = [li[-1], li[0]]
print(li_plasticity)

#predictability
li = df_pred.groupby('HenID')['Predictability'].agg(lambda x: np.mean(x)).reset_index().sort_values('Predictability')['HenID'].tolist()
li_pred = [li[-1], li[0]]
print(li_pred)
li_hen_visual = list(set(li_int+li_plasticity+li_pred))

#add random ones s that total sum to 5
#random.seed(0)
#li_r = random.sample([x for x in df_ind['groupID'].unique() if x not in li_hen_visual], 5-len(li_hen_visual))
#li_hen_visual = li_hen_visual + li_r
print('selected hens: %s' %' '.join(li_hen_visual))
#df_ind['HenID '] = df_ind['HenID'].map(lambda x: 'Others' if x not in li_hen_visual else x)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['hen_9', 'hen_146']
# ['hen_69', 'hen_154']
# ['hen_62', 'hen_39']
# selected hens: hen_146 hen_39 hen_69 hen_9 hen_62 hen_154

# %% [markdown]
# #as we have 6 animals
# pal_ = {henID:'black' for henID in li_all_hen}
# pal_ = {'Other Hens':'black'}
# pal_[li_int[0]] = 'royalblue' #cornflowerblue
# pal_[li_int[1]] = 'blue'
# pal_[li_plasticity[0]] = 'lime'
# pal_[li_plasticity[1]] = 'green'
# pal_[li_pred[0]] = 'orange'
# pal_[li_pred[1]] = 'orangered'
# #'fuchsia','purple'

# %%
#choose color: https://matplotlib.org/stable/gallery/color/named_colors.html
li_nicecolor = ['blue','lime','yellow','fuchsia','orange','cyan','crimson','olive','orangered']
li_all_hen =  df_ind['groupID'].unique()
pal_ = {henID:'black' for henID in li_all_hen}
pal_ = {'Other Hens':'black'}
for i,henID in enumerate(li_hen_visual):
    pal_[henID] = li_nicecolor[i]
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Visualise Estimates

# %%
#behavioural type
df_plt = df_BT.sort_values(['mean'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
#hue_order = li_hen_visual + ['Other Hens']
plt.figure(figsize=(3,6))
ax = sns.boxplot(x='groupID', y='mean', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'], fmt=' ', zorder=-1, alpha=0.2, 
            color=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['mean'], yerr=df_plt_['sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            color=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('HenID')
plt.ylabel('Intercepts BLUP estimates');
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_extracted_data_adap,'estimatesintercepts.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#plasticity
df_plt = df_ind[df_ind['term']=='BLUP_slopes1'].sort_values(['mean'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
plt.figure(figsize=(3,6))
ax = sns.boxplot(x='groupID', y='mean', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2, 
            color=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['mean'], yerr=df_plt_['sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            color=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('HenID')
plt.ylabel('Slope BLUP estimates');
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_extracted_data_adap,'estimatesplasticitySlope.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#plasticity
df_plt = df_ind[df_ind['term']=='BLUP_slopes2'].sort_values(['mean'])
df_plt[' '] = df_plt['groupID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
plt.figure(figsize=(3,6))
ax = sns.boxplot(x='groupID', y='mean', data=df_plt, color='grey');
ax.errorbar(df_plt['groupID'], df_plt['mean'], yerr=df_plt['sd'],fmt=' ', zorder=-1, alpha=0.2, 
            color=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['groupID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['groupID'], df_plt_['mean'], yerr=df_plt_['sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            color=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('HenID')
plt.ylabel('Curvature BLUP estimates');
plt.axhline(y=0, linewidth=2, color = 'k')
plt.savefig(os.path.join(path_extracted_data_adap,'estimatesplasticitycurvature.png'), bbox_inches='tight')
plt.show();
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#predictability
df_pred_summarized = df_pred.groupby('HenID')['Predictability'].agg(lambda x: list(x)).reset_index()
df_pred_summarized['Predictability_mean'] = df_pred_summarized['Predictability'].map(lambda x: np.mean(x))
df_pred_summarized['Predictability_sd'] = df_pred_summarized['Predictability'].map(lambda x: np.std(x))
display(df_pred_summarized.head(3))
df_plt = df_pred_summarized.sort_values(['Predictability_mean']).copy()
df_plt[' '] = df_plt['HenID'].map(lambda x: x if x in li_hen_visual else 'Other Hens')
df_plt['color'] = df_plt[' '].map(lambda x: pal_[x])
#hue_order = li_hen_visual + ['Other Hens']
plt.figure(figsize=(3,6))
ax = sns.boxplot(x='HenID', y='Predictability_mean', data=df_plt, color='grey');
ax.errorbar(df_plt['HenID'], df_plt['Predictability_mean'], yerr=df_plt['Predictability_sd'],fmt=' ', zorder=-1, alpha=0.2, 
            color=df_plt['color'].tolist());
#bigger error bars
df_plt_ = df_plt[df_plt['HenID'].isin(li_hen_visual)]
ax.errorbar(df_plt_['HenID'], df_plt_['Predictability_mean'], yerr=df_plt_['Predictability_sd'], fmt=' ', zorder=-1, alpha=0.9, elinewidth=10,
            color=df_plt_['color'].tolist());
plt.xticks([]) #remove xlabel annotations
plt.xlabel('HenID')
plt.ylabel('Variability BLUP estimates');
plt.savefig(os.path.join(path_extracted_data_adap,'estimatespredictability.png'), bbox_inches='tight')
plt.show();
df_predorder = df_pred_summarized[df_pred_summarized['HenID'].isin(li_hen_visual)].sort_values(['Predictability_mean'], ascending=True).copy()
display(df_predorder)
#li_orderedhenselected_pred = df_predorder['HenID'].tolist()
#hens with higher rIIV are less predictable than individualswith lower rIIV (Fig )
#The most predictable individual (hen 39) has an average residual variance of 0.01 around its behavioral mean, whereas the 
#least predictable individual (hen 109) has an average residual variance of 0.27km
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      HenID                                     Predictability  \
# 0    hen_1  [0.9941138560785111, 0.8433169548986118, 0.843...
# 1   hen_10  [1.049024422762113, 0.9065532151518607, 1.4392...
# 2  hen_101  [1.1891160321446288, 1.5495497810506302, 1.356...
#
#    Predictability_mean  Predictability_sd
# 0             0.900299           0.100825
# 1             1.074071           0.118514
# 2             1.311825           0.155223
#        HenID                                     Predictability  \
# 68    hen_39  [0.26296972895526627, 0.24910965673115523, 0.2...
# 121    hen_9  [0.6766565873412991, 0.9118153660318171, 0.673...
# 41   hen_146  [0.9093586879667866, 1.071831737989991, 1.0769...
# 99    hen_69  [1.3671008809398464, 1.7390391892755876, 1.426...
# 47   hen_154  [1.6746224444169857, 1.509058039656321, 1.5485...
# 92    hen_62  [1.8817493214037961, 2.1968100234506824, 1.826...
#
#      Predictability_mean  Predictability_sd
# 68              0.260152           0.037344
# 121             0.717726           0.083629
# 41              0.957425           0.105481
# 99              1.315056           0.146953
# 47              1.475151           0.162600
# 92              1.848369           0.189302

# %% [markdown]
# # Visualise raw data

# %%
pal_all = {k.split(':')[0]:v for k,v in pal_.items()}
hue_order_all=[h.split(':')[0] for h in li_hen_visual]+['Other Hens']
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_extracted_data_adap,'EstimatedPlasticity_int.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='cDIB_scale', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='cDIB_scale', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.text(28, 2.8, '─ ─ ─ MAVG1 predictions of PC1', color='black')
plt.savefig(os.path.join(path_extracted_data_adap,'RawAdnEstimatedPlasticty_int.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Other Hens    5004
# hen_69          43
# hen_62          43
# hen_146         43
# hen_39          42
# hen_9           42
# hen_154         42
# Name: HenID , dtype: int64
# (5259, 35)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131     4   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131     4   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131     4   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  \
# 0          11.500000      TRAN            1  ...
# 1          10.166667      TRAN            0  ...
# 2           9.000000      TRAN            0  ...
#
#    vertical_travel_distance_perh  cDIB  cDIBfact  InitialWeight_kg       PC1  \
# 0                            2.5    11        11             1.202  0.083445
# 1                            2.1    12        12             1.202 -0.019014
# 2                            2.4    13        13             1.202 -0.331134
#
#    temperature_C_avg_scale  cDIB_scale  pred_pop  pred_HenID      HenID
# 0                 0.207243   -1.835419 -0.088320    0.240762  Other Hens
# 1                -0.212289   -1.754145 -0.105490    0.223592  Other Hens
# 2                -0.579379   -1.672870 -0.118791    0.210290  Other Hens
#
# [3 rows x 35 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_extracted_data_adap,'EstimatedPlasticity_int.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.text(28, 2.8, '─ ─ ─ MAVG1 predictions of PC1', color='black')
plt.savefig(os.path.join(path_extracted_data_adap,'RawAdnEstimatedPlasticty_int.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Other Hens    5004
# hen_69          43
# hen_62          43
# hen_146         43
# hen_39          42
# hen_9           42
# hen_154         42
# Name: HenID , dtype: int64
# (5259, 35)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131     4   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131     4   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131     4   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  \
# 0          11.500000      TRAN            1  ...
# 1          10.166667      TRAN            0  ...
# 2           9.000000      TRAN            0  ...
#
#    vertical_travel_distance_perh  cDIB  cDIBfact  InitialWeight_kg       PC1  \
# 0                            2.5    11        11             1.202  0.083445
# 1                            2.1    12        12             1.202 -0.019014
# 2                            2.4    13        13             1.202 -0.331134
#
#    temperature_C_avg_scale  cDIB_scale  pred_pop  pred_HenID      HenID
# 0                 0.207243   -1.835419 -0.088320    0.240762  Other Hens
# 1                -0.212289   -1.754145 -0.105490    0.223592  Other Hens
# 2                -0.579379   -1.672870 -0.118791    0.210290  Other Hens
#
# [3 rows x 35 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_extracted_data_adap,'EstimatedPlasticity_intquad.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.text(28, 2.8, '─ ─ ─ MAVG2 predictions of PC1', color='black')
plt.savefig(os.path.join(path_extracted_data_adap,'RawAdnEstimatedPlasticty_intquad.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Other Hens    5004
# hen_69          43
# hen_62          43
# hen_146         43
# hen_39          42
# hen_9           42
# hen_154         42
# Name: HenID , dtype: int64
# (5259, 35)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131     4   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131     4   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131     4   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  \
# 0          11.500000      TRAN            1  ...
# 1          10.166667      TRAN            0  ...
# 2           9.000000      TRAN            0  ...
#
#    vertical_travel_distance_perh  cDIB  cDIBfact  InitialWeight_kg       PC1  \
# 0                            2.5    11        11             1.202  0.083445
# 1                            2.1    12        12             1.202 -0.019014
# 2                            2.4    13        13             1.202 -0.331134
#
#    temperature_C_avg_scale  cDIB_scale  pred_pop  pred_HenID      HenID
# 0                 0.207243   -1.835419 -0.591406   -0.258148  Other Hens
# 1                -0.212289   -1.754145 -0.501151   -0.167893  Other Hens
# 2                -0.579379   -1.672870 -0.415425   -0.082167  Other Hens
#
# [3 rows x 35 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_extracted_data_adap,'EstimatedPlasticity_curve.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.text(28, 2.8, '─ ─ ─ MPL1 predictions of PC1', color='black')
plt.savefig(os.path.join(path_extracted_data_adap,'RawAdnEstimatedPlasticty_slope.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Other Hens    5004
# hen_69          43
# hen_62          43
# hen_146         43
# hen_39          42
# hen_9           42
# hen_154         42
# Name: HenID , dtype: int64
# (5259, 35)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131     4   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131     4   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131     4   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  \
# 0          11.500000      TRAN            1  ...
# 1          10.166667      TRAN            0  ...
# 2           9.000000      TRAN            0  ...
#
#    vertical_travel_distance_perh  cDIB  cDIBfact  InitialWeight_kg       PC1  \
# 0                            2.5    11        11             1.202  0.083445
# 1                            2.1    12        12             1.202 -0.019014
# 2                            2.4    13        13             1.202 -0.331134
#
#    temperature_C_avg_scale  cDIB_scale  pred_pop  pred_HenID      HenID
# 0                 0.207243   -1.835419 -0.613201   -0.052561  Other Hens
# 1                -0.212289   -1.754145 -0.521361    0.029670  Other Hens
# 2                -0.579379   -1.672870 -0.434131    0.107289  Other Hens
#
# [3 rows x 35 columns]

# %%
# download ind.plasticity over time
df_PL = pd.read_csv(os.path.join(path_extracted_data_adap,'EstimatedPlasticity.csv'), sep=',')
#adapt hen and colors
df_PL['HenID '] = df_PL['HenID'].map(lambda x: 'Other Hens' if x not in [h.split(':')[0] for h in li_hen_visual] else x)
display(df_PL['HenID '].value_counts())
print(df_PL.shape)
display(df_PL.head(3))
#plot plasticity over time
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False, alpha=1);
sns.lineplot(x='DIB', y='pred_HenID', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
            legend=False, alpha=1);
#remove all borders
sns.despine(bottom = True, left = True)
#plt.title('Individual plasticity');
plt.grid()
plt.text(28, 2.8, '─ ─ ─ MPL2 predictions of PC1', color='black')
plt.savefig(os.path.join(path_extracted_data_adap,'RawAdnEstimatedPlasticty.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Other Hens    5004
# hen_69          43
# hen_62          43
# hen_146         43
# hen_39          42
# hen_9           42
# hen_154         42
# Name: HenID , dtype: int64
# (5259, 35)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131     4   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131     4   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131     4   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  \
# 0          11.500000      TRAN            1  ...
# 1          10.166667      TRAN            0  ...
# 2           9.000000      TRAN            0  ...
#
#    vertical_travel_distance_perh  cDIB  cDIBfact  InitialWeight_kg       PC1  \
# 0                            2.5    11        11             1.202  0.083445
# 1                            2.1    12        12             1.202 -0.019014
# 2                            2.4    13        13             1.202 -0.331134
#
#    temperature_C_avg_scale  cDIB_scale  pred_pop  pred_HenID      HenID
# 0                 0.207243   -1.835419 -0.641352   -0.251928  Other Hens
# 1                -0.212289   -1.754145 -0.547928   -0.143184  Other Hens
# 2                -0.579379   -1.672870 -0.459219   -0.040322  Other Hens
#
# [3 rows x 35 columns]

# %% [raw]
# We observe a general positive trend in the average vertical travel distance per hour as number of days post-transfer increases, but also that variance in the average vertical travel distance per hour is greater at the first days post-transferd compared to the 40th day post-transfer onward and there appears to be some non-linearity, and therefore we will investigate whether the fixed effect of number of days post-transfer on the average vertical travel distance per hour could be modelled with either a linear model or a quadratic model.

# %% [markdown]
# #plot plasticity over time
# #TODO: add pred_HenID1.4
# sns.lineplot(x='DIB', y='pred_HenID1.4', data=df_PL, hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all);
# plt.title('Individual plasticity');
# plt.savefig(os.path.join(path_extracted_data_adap,'EstimatedPlastictyOvertime.png'), bbox_inches='tight')

# %%
#all in once
#change order of hen just for visual purpose
df_PL = df_PL.sort_values(['HenID '], ascending=False)
#behavioural type
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
g = sns.FacetGrid(df_PL, row="HenID ", hue="HenID ", aspect=8, height=0.8, palette=pal_all)
#densities
g.map(sns.kdeplot, "PC1", clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "PC1", clip_on=False, color="w", lw=2)
#Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(-0.3, .2, label, fontweight="bold", fontsize=16, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "PC1")
#Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.8)

#Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True);
plt.savefig(os.path.join(path_extracted_data_adap,'Rawdensity.png'), bbox_inches='tight')
plt.show()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#predictability
sns.set(rc={'figure.figsize':(6.5,5)})
sns.set_theme(style="ticks", font_scale=1.25)
sns.scatterplot(x='DIB', y='PC1', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', palette=pal_all, 
                hue_order=hue_order_all, legend=False);
#sns.lineplot(x='DIB', y='pred_HenID', data=df_PL[df_PL['HenID ']!='Other Hens'], hue='HenID ', linestyle="dashed", palette=pal_all, hue_order=hue_order_all,
#            legend=False);
#add max error
df_PL = df_PL.sort_values(['DIB'], ascending=False)
df_ = df_PL.groupby('HenID')[['pred_HenID','PC1']].agg(lambda x: list(x)).reset_index()
df_['diff'] = df_.apply(lambda x: [abs(x['pred_HenID'][i]-x['PC1'][i]) for i in range(0,len(x['pred_HenID']))], axis=1)
df_['max_error'] = df_['diff'].map(lambda x: max(x))
display(df_.head(3))
df_PL['max_error'] = df_PL['HenID'].map(lambda x: df_[df_['HenID']==x]['max_error'].values[0])
for henID in li_hen_visual:
    y = df_PL[df_PL['HenID ']==henID]['pred_HenID']
    err = df_PL[df_PL['HenID ']==henID]['max_error']
    x = df_PL[df_PL['HenID ']==henID]['DIB']
    plt.plot(x, y-err, color=pal_[henID])
    plt.plot(x, y+err, color=pal_[henID])
    plt.fill_between(x, y-err, y+err, alpha=0.1, color=pal_[henID])
#plt.text(11, 1.4, '─ ─ ─ estimated slopes', color='black')
#remove all borders
sns.despine(bottom = True, left = True)
plt.grid()
plt.savefig(os.path.join(path_extracted_data_adap,'RawVariability.png'), bbox_inches='tight')
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      HenID                                         pred_HenID  \
# 0    hen_1  [0.292250415984591, 0.22892194088401602, 0.140...
# 1   hen_10  [0.223821664631925, 0.20803125717900797, 0.165...
# 2  hen_101  [-0.16844795107924695, -0.08204144564977, -0.0...
#
#                                                  PC1  \
# 0  [0.23178205900797502, 0.0804739638450276, 0.62...
# 1  [-0.0964765748504578, 0.345492975132909, 0.438...
# 2  [0.587997660413702, 0.5687399786136379, 0.3897...
#
#                                                 diff  max_error
# 0  [0.06046835697661598, 0.14844797703898843, 0.4...   1.008741
# 1  [0.3202982394823828, 0.13746171795390102, 0.27...   1.077666
# 2  [0.756445611492949, 0.6507814242634079, 0.4141...   1.480576

# %% [markdown]
# # Merge all individual information

# %%
df_BT.rename(columns={'mean':'BehaviouralType'},inplace=True)
print(df_BT.shape)
df_BT.head(3)
# Out:
# (130, 6)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   groupFctr  groupID         term  BehaviouralType    median        sd
# 0     HenID    hen_1  (Intercept)        -0.852194 -0.847932  0.124761
# 1     HenID   hen_10  (Intercept)        -0.366230 -0.371412  0.132275
# 2     HenID  hen_101  (Intercept)         0.669667  0.673175  0.134817

# %%
df_indall = pd.merge(df_ind.pivot(columns='term', index='groupID',values='mean').reset_index(), 
                     df_pred_summarized, left_on='groupID', right_on='HenID', how='outer')
df_indall.rename(columns={'mean':'predictability'}, inplace=True)
print(df_indall.shape)
df_indall = pd.merge(df_indall, df_BT[['groupID','BehaviouralType']], on='groupID', how='outer')
print(df_indall.shape)
df_indall.head(3)
# Out:
# (130, 8)
# (130, 9)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    groupID  BLUP_int  BLUP_slopes1  BLUP_slopes2    HenID  \
# 0    hen_1 -1.189385      0.587122      0.306218    hen_1
# 1   hen_10 -0.586497      0.379040      0.189643   hen_10
# 2  hen_101  0.653292     -0.318522      0.014147  hen_101
#
#                                       Predictability  Predictability_mean  \
# 0  [0.9941138560785111, 0.8433169548986118, 0.843...             0.900299
# 1  [1.049024422762113, 0.9065532151518607, 1.4392...             1.074071
# 2  [1.1891160321446288, 1.5495497810506302, 1.356...             1.311825
#
#    Predictability_sd  BehaviouralType
# 0           0.100825        -0.852194
# 1           0.118514        -0.366230
# 2           0.155223         0.669667

# %%
#UNTILL PREDICTABILITY not run on the new elected hens (i.e. with 3 less animals)
df_indall = df_indall[~df_indall['groupID'].isnull()]
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(pearsonr(df_indall['BLUP_int'].tolist(), df_indall['BehaviouralType'].tolist()))
print(pearsonr(df_indall['BehaviouralType'].tolist(), df_indall['BLUP_slopes1'].tolist()))
print(pearsonr(df_indall['BehaviouralType'].tolist(), df_indall['BLUP_slopes2'].tolist()))
print(pearsonr(df_indall['BehaviouralType'].tolist(), df_indall['Predictability_mean'].tolist()))
print('')
print(pearsonr(df_indall['BLUP_slopes1'].tolist(), df_indall['BLUP_slopes2'].tolist()))
print(pearsonr(df_indall['BLUP_slopes1'].tolist(), df_indall['Predictability_mean'].tolist()))
print(pearsonr(df_indall['BLUP_slopes2'].tolist(), df_indall['Predictability_mean'].tolist()))
# Out:
# (0.9541604660463632, 6.432266094693348e-69)
# (-0.16693892855503492, 0.05764905198863031)
# (-0.1377315861875078, 0.11812980788752414)
# (0.1949222792016955, 0.02625945701383817)
#
# (-0.09504999756045004, 0.28205815780660565)
# (0.10395252306665363, 0.2392012583867698)
# (-0.26221242798770866, 0.0025806389306281307)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_indall['HenID '] = df_indall['HenID'].map(lambda x: 'Other Hens' if x not in li_hen_visual else x)
sns.pairplot(df_indall[['HenID ','BLUP_int','BLUP_slopes1','BLUP_slopes2','Predictability_mean','BehaviouralType']], hue='HenID ', palette=pal_all, diag_kind="hist");
plt.savefig(os.path.join(path_extracted_data_adap,'BLUPestiamtes.png'), bbox_inches='tight')
plt.show()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #correaltion
# sns.set(rc={'figure.figsize':(6.5,5)})
# df_corr = df_ind.pivot(columns='term',index='groupID', values='mean').reset_index()
# df_corr['HenID '] = df_corr['groupID'].map(lambda x: 'Other Hens' if x not in li_hen_visual else x)
# sns.scatterplot(x='BLUP_int', y='BLUP_slopes', data=df_corr, hue='HenID ', palette=pal_all, hue_order=hue_order_all,
#                legend=False);
# plt.text(-1.3, -0.037, 'corr=-0.85', size=15)
# plt.savefig(os.path.join(path_extracted_data_adap,'RSlopesVSestiamtes.png'), bbox_inches='tight')

# %% [markdown]
# # Dataframe for stats ~ health

# %%
li_selected_hens = pickle.load(open(os.path.join(path_extracted_data_adap, 'li_selected_hens.pkl'), 'rb'))
print(len(li_selected_hens))
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 130

# %%
df_MVT = pd.read_csv(os.path.join(path_extracted_data_adap,'df_MVT_4individuality.csv'), sep=';')
print(df_MVT.shape)
df_MVT[df_MVT['HenID']=='hen_39']
df_MVT.head(3)
# Out:
# (5259, 26)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    WIB    HenID  RPen  DIB  CLASS      TrackingSystemID  PenID  \
# 0    2  hen_131   4.0   11  Other  TrackingSystem 10-12  pen10
# 1    2  hen_131   4.0   12  Other  TrackingSystem 10-12  pen10
# 2    2  hen_131   4.0   13  Other  TrackingSystem 10-12  pen10
#
#    temperature_C_avg Treatment  tobeusedPCA  ...  perc_duration_2_Zone  \
# 0          11.500000      TRAN            1  ...                  57.0
# 1          10.166667      TRAN            0  ...                  61.0
# 2           9.000000      TRAN            0  ...                  37.0
#
#    perc_1_Zone_while_WG_open  nbr_stays_2_Zone_perh  nbr_stays_4_Zone_perh  \
# 0                        0.0                    0.9                    0.4
# 1                        0.0                    0.9                    0.2
# 2                        0.0                    0.6                    0.5
#
#    nbr_stays_3_Zone_perh  nbr_stays_5_Zone_perh  nbr_stays_1_Zone_perh  \
# 0                    1.0                    0.3                    0.0
# 1                    1.0                    0.1                    0.0
# 2                    0.8                    0.4                    0.0
#
#    in_WG_15mnAfterOpening  SleepingHeight  vertical_travel_distance_perh
# 0                       0               3                            2.5
# 1                       0               3                            2.1
# 2                       0               1                            2.4
#
# [3 rows x 26 columns]

# %%
#to add info on the first week
df_MVT_ALL = pd.read_csv(os.path.join(path_extracted_data, id_run+'_daily_ALL_variables_verified.csv'), sep=';', 
                     parse_dates=['level'], dayfirst=True) 
print(df_MVT_ALL.shape)
df_MVT_ALL = df_MVT_ALL[df_MVT_ALL['HenID'].isin(li_selected_hens)]
#restrict to the adaptability study timeframe
df_MVT_ALL = df_MVT_ALL[df_MVT_ALL['level']<=config.max_date_adaptability]
print(df_MVT_ALL.shape)
#make sure we have their mvt
df_MVT_ALL = df_MVT_ALL[~df_MVT_ALL['perc_duration_5_Zone'].isnull()]
print(df_MVT_ALL.shape)
#df_HA[['HAID','date']].drop_duplicates()
df_MVT_ALL.head(3)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (42300, 63)
# (6105, 63)
# (6105, 63)
#      HenID  PenID CLASS    TagID FocalLegringName  R-Pen     InitialStartDate  \
# 3  hen_131  pen10   EPI  tag_128          19black    4.0  2020-06-10 00:00:00
# 4  hen_131  pen10   EPI  tag_128          19black    4.0  2020-06-10 00:00:00
# 5  hen_131  pen10   EPI  tag_128          19black    4.0  2020-06-10 00:00:00
#
#   Treatment      level  DIB  ...  percChaoticTransition  \
# 3      TRAN 2020-09-30    1  ...                    0.0
# 4      TRAN 2020-10-01    2  ...                    0.0
# 5      TRAN 2020-10-02    3  ...                    8.0
#
#    night_Max_duration_zones  is_mvt_night  empproba_3_Zone empproba_4_Zone  \
# 3                    5_Zone           1.0         0.000000        0.000000
# 4                    3_Zone           1.0        33.333333       50.000000
# 5                    5_Zone           0.0        33.333333       66.666667
#
#    empproba_2_Zone  in_WG_15mnAfterOpening  Max_duration_WG_h  \
# 3            100.0                     NaN                NaN
# 4            100.0                     NaN                NaN
# 5            100.0                     NaN                NaN
#
#    perc_1_Zone_while_WG_open  SleepingHeight
# 3                        NaN               3
# 4                        NaN               1
# 5                        NaN               3
#
# [3 rows x 63 columns]

# %%
#HA&KBF&weight
df_HA = pd.read_csv(os.path.join(path_extracted_data, 'df_all_HA.csv'), sep=';', parse_dates=['date'], dayfirst=True) 
print(df_HA.shape)
df_HA = df_HA[df_HA['HenID'].isin(li_selected_hens)]
#display(df_HA.groupby(['HAID'])['date'].agg(lambda x: set(x)).reset_index())
display(df_HA['HAID'].value_counts())
print(df_HA.shape)
df_HA.head(3)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (846, 58)
# HA1    129
# HA3    114
# HA2    114
# HA4     97
# HA5     80
# Name: HAID, dtype: int64
# (534, 58)
#   Person_toe   Time  PenID FocalLegringName BirdType  CombPecks Toes  \
# 2    Camille  10:30   pen5           2green   normal      130.0  NaN
# 3          M  16:26   pen3           51grey   normal      100.0  NaN
# 4          C  08:58  pen12         32orange   normal       25.0  NaN
#
#    RFPododermatitis  RFBumblefoot  RFinjuries  ...  \
# 2              25.0           0.0         0.0  ...
# 3               0.0           0.0         0.0  ...
# 4               0.0           0.0         0.0  ...
#
#                                      actual_path_img  imageID  random_order1  \
# 2  G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...    482.0          428.0
# 3  G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...    214.0          238.0
# 4  G:\VPHI\Welfare\2- Research Projects\OFHE2.Ori...     68.0          319.0
#
#    severity  has_gap        BirdID uncertainty (0:certain:1 random)  \
# 2         4      0.0     2green5pp                              NaN
# 3        40      1.0     51grey3sp                              NaN
# 4         2      0.0  32orange12sb                              NaN
#
#   Unnamed: 9                              Info backpack
# 2        NaN     ['', '2', 'green', '5', 'pp']       pp
# 3        NaN     ['', '51', 'grey', '3', 'sp']       sp
# 4        NaN  ['', '32', 'orange', '12', 'sb']       sb
#
# [3 rows x 58 columns]

# %%
sns.lineplot(x='HAID', y='weight', data=df_HA.sort_values(['HAID']), hue='HenID', legend=False);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#dataframe
#################### add commn mvt var ####################
df_MVT['InitialWeight_kg'] = df_MVT['InitialWeight'].map(lambda x: x/1000)
df_4stat = df_MVT.groupby(['HenID'])[['perc_1_Zone_while_WG_open','vertical_travel_distance_perh',
                                      'perc_duration_5_Zone','InitialWeight_kg','RPen']].agg(lambda x: np.nanmedian(x)).reset_index()
#note: InitialWeight and RPen: have same value all the time, so mean/median is good too
print(df_4stat.shape)
df_4stat.head(3)

#################### add nbr days within first three without mvt ####################
'''m = df_MVT_ALL['DIB'].min()
df_nomvt = df_MVT_ALL[df_MVT_ALL['DIB'].isin([m,m+1,m+2])].groupby('HenID')['Total_number_zone'].agg(lambda x: list(x)).reset_index()
df_nomvt['nbr_first3days_no_mvt'] = df_nomvt['Total_number_zone'].agg(lambda x: sum([i==1 for i in list(x)]))
display(df_nomvt['nbr_first3days_no_mvt'].value_counts(normalize=True))
print(df_nomvt.shape)
df_nomvt.head(3)
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_nomvt[['HenID','nbr_first3days_no_mvt']], on='HenID', how='outer')
print(df_4stat.shape)
'''
#################### add nbr days within first three without mvt ####################
m = df_MVT_ALL['DIB'].min()
df_nomvt = df_MVT_ALL[df_MVT_ALL['DIB'].isin([m,m+1,m+2])].groupby('HenID')['Total_number_zone'].agg(lambda x: list(x)).reset_index()
df_nomvt['nbr_nbrzonevisisted_over_3days'] = df_nomvt['Total_number_zone'].agg(lambda x: sum(x))
display(df_nomvt['nbr_nbrzonevisisted_over_3days'].value_counts(normalize=True))
print(df_nomvt.shape)
df_nomvt.head(3)
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_nomvt[['HenID','nbr_nbrzonevisisted_over_3days']], on='HenID', how='outer')
print(df_4stat.shape)

#################### add BLUP estimates ####################
print(df_4stat.shape)
df_4stat = pd.merge(df_4stat, df_indall[['HenID','BehaviouralType','BLUP_slopes1','BLUP_slopes2','Predictability_mean']], on='HenID', how='inner')
print(df_4stat.shape)
# Out:
# (130, 6)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 12.0    0.269231
# 9.0     0.161538
# 10.0    0.115385
# 8.0     0.115385
# 11.0    0.100000
# 6.0     0.092308
# 7.0     0.076923
# 3.0     0.038462
# 5.0     0.030769
# Name: nbr_nbrzonevisisted_over_3days, dtype: float64
# (130, 3)
# (130, 6)
# (130, 7)
# (130, 7)
# (130, 11)

# %% [markdown]
# ### Dataframe for feature selection stats ~ health

# %% [markdown]
# display(df_HA[['date','HAID']].drop_duplicates())
# df_HA = df_HA.sort_values(['date'], ascending=True)
# display(df_HA[['date','HAID','HenID','severity','weight','Feathers','PenID']].head(3))
# df_lastHAperBird = df_HA.groupby(['PenID','HenID'])[['severity','weight','Feathers','HAID']].agg(lambda x: list(x)[-1]).reset_index()
# #remove birds that have HA5 as last health assessment, as we will use it in the model (i.e. not for the feature selection)
# display(df_lastHAperBird['HAID'].value_counts())
# print(df_lastHAperBird.shape)
# df_lastHAperBird = df_lastHAperBird[df_lastHAperBird['HAID']!='HA5']
# print(df_lastHAperBird.shape)
# df_lastHAperBird.tail(3) #note: HA1 had no feather values
#
# #we have ~50 (133-81) more animals that can be used to select features, so lets use them
# #################### add all HA except HA5 ####################
# print(df_4stat.shape)
# df_4featureselec = pd.merge(df_4stat, df_lastHAperBird, on='HenID', how='right')
# display(df_4featureselec.head(3))
# print(df_4featureselec.shape)
#
# #save
# df_4featureselec = df_4featureselec[~df_4featureselec['severity'].isnull()]
# print(df_4featureselec.shape)
# df_4featureselec = df_4featureselec[~df_4featureselec['nbr_first3days_no_mvt'].isnull()]
# print(df_4featureselec.shape)
#
# df_4featureselec.to_csv(os.path.join(path_extracted_data_adap,'df_MVT_4Featureselect.csv'), index=False, sep=';')
# print(df_4featureselec.shape)
# df_4featureselec.head(3)

# %% [markdown]
# ### Dataframe for stats ~ health

# %%
################### add HA5 ####################
print(df_4stat.shape)
df_4statmodel = pd.merge(df_4stat, df_HA[df_HA['HAID']=='HA5'][['HenID','PenID','CLASS','Treatment','severity','weight',
                                                           'Feathers']], on='HenID', how='inner')
#save
df_4statmodel.to_csv(os.path.join(path_extracted_data_adap,'df_MVT_4stat.csv'), index=False, sep=';')
print(df_4statmodel.shape)
df_4statmodel.head(3)
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (130, 11)
# (80, 17)
#      HenID  perc_1_Zone_while_WG_open  vertical_travel_distance_perh  \
# 0   hen_10                   0.000000                       1.933333
# 1  hen_101                   1.372807                       4.000000
# 2  hen_102                   0.418699                       1.000000
#
#    perc_duration_5_Zone  InitialWeight_kg  RPen  \
# 0                  35.0             1.070   1.0
# 1                  10.0             1.082   3.0
# 2                  86.5             1.158   3.0
#
#    nbr_nbrzonevisisted_over_3days  BehaviouralType  BLUP_slopes1  \
# 0                             7.0        -0.366230      0.379040
# 1                             7.0         0.669667     -0.318522
# 2                             6.0        -1.288175      0.076622
#
#    BLUP_slopes2  Predictability_mean  PenID CLASS Treatment  severity  weight  \
# 0      0.189643             1.074071  pen11  LEXP       OFH        40  1713.4
# 1      0.014147             1.311825   pen5  MEXP       OFH        28  1755.3
# 2      0.119137             0.546264   pen3  MEXP       OFH        50  2042.7
#
#     Feathers
# 0  67.000000
# 1  72.666667
# 2  61.666667

# %%
li_mvtvar = ['nbr_nbrzonevisisted_over_3days','perc_duration_5_Zone','perc_1_Zone_while_WG_open','BLUP_slopes1',
             'BLUP_slopes2','Predictability_mean','BehaviouralType','vertical_travel_distance_perh']
li_df = []
for i in range(0,len(li_mvtvar)-1):
    for j in range(i+1,len(li_mvtvar)):
        v1 = li_mvtvar[i]
        v2 = li_mvtvar[j]
        coeff, pval = pearsonr(df_4statmodel[v1].tolist(), df_4statmodel[v2].tolist())
        li_df.append({'coeff':coeff, 'abscoeff':abs(coeff), 'pval':pval,'var1':v1,'var2':v2})
df_corr = pd.DataFrame(li_df)
print(df_corr.shape)
df_corr = df_corr.sort_values('abscoeff', ascending=False)
df_corr.head(10)
#--> BehaviouralType is as expected very correlated so we will remove it. However we still have vertical_travel_distance_perh 
#highly correlated with perc_duration_5_Zone. we will remove vertical_travel_distance_perh as no "adapted to our settings" 
#literature and we already have nbr_first3days_no_mvt which capture a little of the idea -->vertical_travel_distance_perh is
#also removed
# Out:
# (28, 5)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        coeff  abscoeff          pval                            var1  \
# 11 -0.852182  0.852182  1.205103e-23            perc_duration_5_Zone
# 27  0.772143  0.772143  5.051863e-17                 BehaviouralType
# 12 -0.646962  0.646962  8.954827e-11            perc_duration_5_Zone
# 6   0.388709  0.388709  3.663496e-04  nbr_nbrzonevisisted_over_3days
# 16  0.383107  0.383107  4.523112e-04       perc_1_Zone_while_WG_open
# 5   0.309537  0.309537  5.206304e-03  nbr_nbrzonevisisted_over_3days
# 2  -0.307486  0.307486  5.528466e-03  nbr_nbrzonevisisted_over_3days
# 4  -0.285779  0.285779  1.017903e-02  nbr_nbrzonevisisted_over_3days
# 7  -0.242171  0.242171  3.044316e-02            perc_duration_5_Zone
# 0  -0.198926  0.198926  7.689922e-02  nbr_nbrzonevisisted_over_3days
#
#                              var2
# 11                BehaviouralType
# 27  vertical_travel_distance_perh
# 12  vertical_travel_distance_perh
# 6   vertical_travel_distance_perh
# 16                BehaviouralType
# 5                 BehaviouralType
# 2                    BLUP_slopes1
# 4             Predictability_mean
# 7       perc_1_Zone_while_WG_open
# 0            perc_duration_5_Zone

# %%
df_4statmodel[df_4statmodel.isna().any(axis=1)]
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      HenID  perc_1_Zone_while_WG_open  vertical_travel_distance_perh  \
# 65  hen_78                   8.889601                       3.333333
#
#     perc_duration_5_Zone  InitialWeight_kg  RPen  \
# 65                  59.5              1.06   2.0
#
#     nbr_nbrzonevisisted_over_3days  BehaviouralType  BLUP_slopes1  \
# 65                             9.0        -0.565868      0.177804
#
#     BLUP_slopes2  Predictability_mean  PenID CLASS Treatment  severity  \
# 65     -0.127854             1.259738  pen10  LEXP      TRAN        30
#
#     weight  Feathers
# 65  1626.2       NaN

# %%
sns.boxplot(y='Predictability_mean', x='Treatment', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.boxplot(y='Predictability_mean', x='CLASS', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.boxplot(y='Feathers', x='Treatment', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.boxplot(y='severity', x='Treatment', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.boxplot(y='Feathers', x='PenID', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.boxplot(y='severity', x='PenID', data=df_4statmodel);
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #verify no commun animals
# li_hen4FS = df_4featureselec['HenID'].tolist()
# li_hen4model = df_4statmodel['HenID'].tolist()
# li_commun_hen = [i for i in li_hen4FS if i in li_hen4model]
# if len(li_commun_hen)>0:
#     print('ERROR: some animals are in both feature selection process and in the model')
#     sys.exit()

# %%
sns.pairplot(df_4statmodel[['nbr_nbrzonevisisted_over_3days','perc_duration_5_Zone','perc_1_Zone_while_WG_open','BLUP_slopes1',
                            'BLUP_slopes2','Predictability_mean','BehaviouralType','vertical_travel_distance_perh']], 
             diag_kind="hist");
plt.savefig(os.path.join(path_extracted_data_adap,'MVTVar.png'), bbox_inches='tight')
plt.show()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(df_4statmodel.shape)
df_4statmodel.head(3)
# Out:
# (80, 17)
# C:\Users\camil\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      HenID  perc_1_Zone_while_WG_open  vertical_travel_distance_perh  \
# 0   hen_10                   0.000000                       1.933333
# 1  hen_101                   1.372807                       4.000000
# 2  hen_102                   0.418699                       1.000000
#
#    perc_duration_5_Zone  InitialWeight_kg  RPen  \
# 0                  35.0             1.070   1.0
# 1                  10.0             1.082   3.0
# 2                  86.5             1.158   3.0
#
#    nbr_nbrzonevisisted_over_3days  BehaviouralType  BLUP_slopes1  \
# 0                             7.0        -0.366230      0.379040
# 1                             7.0         0.669667     -0.318522
# 2                             6.0        -1.288175      0.076622
#
#    BLUP_slopes2  Predictability_mean  PenID CLASS Treatment  severity  weight  \
# 0      0.189643             1.074071  pen11  LEXP       OFH        40  1713.4
# 1      0.014147             1.311825   pen5  MEXP       OFH        28  1755.3
# 2      0.119137             0.546264   pen3  MEXP       OFH        50  2042.7
#
#     Feathers
# 0  67.000000
# 1  72.666667
# 2  61.666667
