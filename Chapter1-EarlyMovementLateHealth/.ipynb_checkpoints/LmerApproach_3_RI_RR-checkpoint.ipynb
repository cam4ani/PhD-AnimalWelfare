# %%
#library(lme4)
#library(MCMCglmm)
#library(tidyverse)
#library(broom)
#library(nadiv)
library(lmerTest) #lmer with pvalues
library(MuMIn) #R2
library(merTools) #sim
# Out:
# Warning message:
# "package 'lmerTest' was built under R version 3.6.3"
# Loading required package: lme4
#
# Warning message:
# "package 'lme4' was built under R version 3.6.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 3.6.3"
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Warning message:
# "package 'MuMIn' was built under R version 3.6.3"
# Warning message:
# "package 'merTools' was built under R version 3.6.3"
# Loading required package: arm
#
# Loading required package: MASS
#
# Warning message:
# "package 'MASS' was built under R version 3.6.3"
#
# arm (Version 1.12-2, built: 2021-10-15)
#
#
# Working directory is C:/Users/camil/Desktop/animals_code/PhD-AnimalWelfare/Chapter1-EarlyMovementLateHealth

# %%
#install.packages("dplyr")

# %%
#citation("merTools")

# %%
library(parallel)
my.cores = detectCores()

# %% [markdown]
# library(lme4)
# library(arm)
# library(MuMIn)
# library(tidyverse)
# library(plyr)
# library(broom)
# library(coda)
# library(grid)
# library(gridExtra)
# library(brms)
# library(broom.mixed)
# library(merTools)
# library(tidybayes)
# library(parallel)

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
path_adapt = file.path(path_,'Adaptability')
df = read.csv(file.path(path_adapt,'df_MVT_4individuality_withPCA.csv'), header = TRUE, sep = ",")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID) 
df$cDIB = as.integer(df$DIB) 
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment)
#scale: mean-centering of the environmental variable so that intercepts reflect average values for the population and ind. 
df$temperature_C_avg_scale = scale(df$temperature_C_avg, center=TRUE, scale=TRUE)
df$time = scale(df$cDIB, center=FALSE, scale=TRUE)
df$time2 = poly(df$time, degree=2,raw=TRUE)[,2]
df$avgDIB_scale = scale(df$avgDIB, center=TRUE, scale=TRUE)
df$InitialWeight_scale = scale(df$InitialWeight, center=TRUE, scale=TRUE)
print(dim(df))
summary(df)
# Out:
# [1] 3230   32
#      HenID           DIB             CLASS          PenID     temperature_C_avg
#  hen_116:  43   Min.   :11.00   EPI     : 478   pen10  :504   Min.   : 4.000
#  hen_124:  43   1st Qu.:23.00   LEXP    : 965   pen11  :504   1st Qu.: 8.667
#  hen_127:  43   Median :33.00   LEXPLOST: 366   pen8   :430   Median :11.000
#  hen_136:  43   Mean   :33.59   MEXP    :1379   pen9   :429   Mean   :10.838
#  hen_147:  43   3rd Qu.:44.00   MEXPLOST:  42   pen4   :388   3rd Qu.:12.667
#  hen_151:  43   Max.   :54.00                   pen5   :363   Max.   :19.333
#  (Other):2972                                   (Other):612
#   tobeusedPCA     InitialWeight  Treatment_encoded    perc_duration_5_Zone
#  Min.   :0.0000   Min.   :1046   Min.   :-1.0000000   Min.   :  0.00
#  1st Qu.:0.0000   1st Qu.:1130   1st Qu.:-1.0000000   1st Qu.: 11.00
#  Median :0.0000   Median :1164   Median :-1.0000000   Median : 33.00
#  Mean   :0.1734   Mean   :1169   Mean   :-0.0006192   Mean   : 39.21
#  3rd Qu.:0.0000   3rd Qu.:1200   3rd Qu.: 1.0000000   3rd Qu.: 66.00
#  Max.   :1.0000   Max.   :1350   Max.   : 1.0000000   Max.   :100.00
#
#  perc_duration_4_Zone perc_duration_3_Zone perc_duration_2_Zone
#  Min.   : 0.000       Min.   : 0.00        Min.   : 0.00
#  1st Qu.: 4.000       1st Qu.: 7.00        1st Qu.:14.00
#  Median : 6.000       Median :17.00        Median :32.00
#  Mean   : 8.136       Mean   :18.27        Mean   :31.24
#  3rd Qu.:10.000       3rd Qu.:28.00        3rd Qu.:46.00
#  Max.   :73.000       Max.   :70.00        Max.   :91.00
#
#  perc_1_Zone_while_WG_open nbr_stays_2_Zone_perh nbr_stays_4_Zone_perh
#  Min.   : 0.000            Min.   :0.0000        Min.   :0.0000
#  1st Qu.: 0.000            1st Qu.:0.4545        1st Qu.:0.2857
#  Median : 1.388            Median :1.0714        Median :0.5714
#  Mean   : 6.932            Mean   :1.1062        Mean   :0.7059
#  3rd Qu.: 9.572            3rd Qu.:1.6667        3rd Qu.:1.0000
#  Max.   :87.949            Max.   :5.0909        Max.   :5.2500
#
#  nbr_stays_3_Zone_perh nbr_stays_5_Zone_perh nbr_stays_1_Zone_perh
#  Min.   :0.0000        Min.   :0.0000        Min.   :0.0000
#  1st Qu.:0.6923        1st Qu.:0.2000        1st Qu.:0.0000
#  Median :1.3333        Median :0.3571        Median :0.1622
#  Mean   :1.3227        Mean   :0.4352        Mean   :0.4060
#  3rd Qu.:1.8333        3rd Qu.:0.6000        3rd Qu.:0.6316
#  Max.   :5.1818        Max.   :3.1667        Max.   :3.5789
#
#  in_WG_15mnAfterOpening SleepingHeight  vertical_travel_distance_perh
#  Min.   :0.0000         Min.   :0.000   Min.   : 0.000
#  1st Qu.:0.0000         1st Qu.:2.000   1st Qu.: 2.286
#  Median :0.0000         Median :3.000   Median : 3.600
#  Mean   :0.2065         Mean   :2.481   Mean   : 3.595
#  3rd Qu.:0.0000         3rd Qu.:3.000   3rd Qu.: 4.800
#  Max.   :1.0000         Max.   :3.000   Max.   :12.308
#
#      avgDIB         severity        Feathers     Treatment      PC1
#  Min.   :32.91   Min.   : 6.00   Min.   :35.00   -1:1616   Min.   :-1.9150
#  1st Qu.:32.91   1st Qu.:24.00   1st Qu.:58.67   1 :1614   1st Qu.:-0.7772
#  Median :33.36   Median :36.00   Median :66.33             Median : 0.1694
#  Mean   :33.59   Mean   :35.72   Mean   :65.81             Mean   : 0.0000
#  3rd Qu.:34.00   3rd Qu.:46.00   3rd Qu.:73.67             3rd Qu.: 0.7268
#  Max.   :35.18   Max.   :84.00   Max.   :86.67             Max.   : 2.7714
#                                  NA's   :42
#       cDIB       temperature_C_avg_scale.V1       time.V1
#  Min.   :11.00   Min.   :-2.1505151         Min.   :0.3073743
#  1st Qu.:23.00   1st Qu.:-0.6829345         1st Qu.:0.6426918
#  Median :33.00   Median : 0.0508558         Median :0.9221230
#  Mean   :33.59   Mean   : 0.0000000         Mean   :0.9387072
#  3rd Qu.:44.00   3rd Qu.: 0.5749917         3rd Qu.:1.2294973
#  Max.   :54.00   Max.   : 2.6715354         Max.   :1.5089285
#
#      time2           avgDIB_scale.V1    InitialWeight_scale.V1
#  Min.   :0.09448   Min.   :-1.0681873   Min.   :-1.9742093
#  1st Qu.:0.41305   1st Qu.:-1.0681873   1st Qu.:-0.6252286
#  Median :0.85031   Median :-0.3677554   Median :-0.0792126
#  Mean   :0.99969   Mean   : 0.0000000   Mean   : 0.0000000
#  3rd Qu.:1.51166   3rd Qu.: 0.6324925   3rd Qu.: 0.4989220
#  Max.   :2.27687   Max.   : 2.4750543   Max.   : 2.9078162

# %%
length(unique(df[['HenID']]))
# Out:
# [1] 80

# %% [markdown]
# # Random Intercept

# %%
MAVG_pen_class = lmerTest::lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_scale + (1|PenID/HenID), REML=FALSE, data = df)
summary(MAVG_pen_class)
r.squaredGLMM(MAVG_pen_class)
###### normally distributed residuals
qqnorm(resid(MAVG_pen_class))
qqline(resid(MAVG_pen_class))
hist(resid(MAVG_pen_class))
######check homogeneity of variance (residuals has constant variance)
plot(MAVG_pen_class)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula: PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + CLASS +
#     temperature_C_avg_scale + InitialWeight_scale + (1 | PenID/HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6954.4   7039.5  -3463.2   6926.4     3216
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0746 -0.5996  0.0138  0.6226  3.9421
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  HenID:PenID (Intercept) 0.346544 0.58868
#  PenID       (Intercept) 0.004875 0.06982
#  Residual                0.458795 0.67734
# Number of obs: 3230, groups:  HenID:PenID, 80; PenID, 8
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.12417    0.19901  119.11728 -10.674   <2e-16 ***
# time                       4.29763    0.22457 3150.33228  19.137   <2e-16 ***
# time2                     -1.98361    0.12197 3150.35107 -16.263   <2e-16 ***
# avgDIB_scale               0.06152    0.07163    8.94614   0.859   0.4129
# Treatment_encoded         -0.15337    0.07327    8.67625  -2.093   0.0670 .
# CLASSLEXP                 -0.07877    0.21305   75.23569  -0.370   0.7126
# CLASSLEXPLOST              0.02933    0.26876   79.82029   0.109   0.9134
# CLASSMEXP                  0.20024    0.20228   75.54948   0.990   0.3254
# CLASSMEXPLOST              0.23441    0.63362   77.60909   0.370   0.7124
# temperature_C_avg_scale   -0.02850    0.01392 3150.24989  -2.047   0.0407 *
# InitialWeight_scale       -0.07342    0.06965   76.07576  -1.054   0.2952
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ CLASSLEXP CLASSLEXPL CLASSMEXP
# time        -0.454
# time2        0.433 -0.987
# avgDIB_scal -0.089 -0.007  0.006
# Trtmnt_ncdd -0.047  0.003 -0.003 -0.050
# CLASSLEXP   -0.717  0.000  0.000  0.086  0.013
# CLASSLEXPLO -0.578  0.000  0.000  0.078  0.106  0.538
# CLASSMEXP   -0.755  0.000  0.000  0.078  0.050  0.703     0.566
# CLASSMEXPLO -0.235 -0.001  0.001  0.053 -0.065  0.216     0.165      0.234
# tmprtr_C_v_  0.152 -0.404  0.450 -0.001 -0.003  0.000     0.000      0.000
# IntlWght_sc -0.024  0.001 -0.001  0.108 -0.149  0.062     0.067     -0.006
#             CLASSMEXPL tm_C__
# time
# time2
# avgDIB_scal
# Trtmnt_ncdd
# CLASSLEXP
# CLASSLEXPLO
# CLASSMEXP
# CLASSMEXPLO
# tmprtr_C_v_  0.000
# IntlWght_sc -0.124      0.000
# Warning message:
# "'r.squaredGLMM' now calculates a revised statistic. See the help page."
#      R2m       R2c
# [1,] 0.1508003 0.519129
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG_pen_class)"
# plot without title

# %%
MAVG_pen_noclass = lmerTest::lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale + InitialWeight_scale + (1|PenID/HenID), REML=FALSE, data = df)
summary(MAVG_pen_noclass)
r.squaredGLMM(MAVG_pen_noclass)
###### normally distributed residuals
qqnorm(resid(MAVG_pen_noclass))
qqline(resid(MAVG_pen_noclass))
hist(resid(MAVG_pen_noclass))
######check homogeneity of variance (residuals has constant variance)
plot(MAVG_pen_noclass)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula:
# PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale +
#     InitialWeight_scale + (1 | PenID/HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6949.7   7010.5  -3464.8   6929.7     3220
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0774 -0.5972  0.0146  0.6227  3.9339
#
# Random effects:
#  Groups      Name        Variance Std.Dev.
#  HenID:PenID (Intercept) 0.363204 0.60266
#  PenID       (Intercept) 0.003054 0.05527
#  Residual                0.458796 0.67734
# Number of obs: 3230, groups:  HenID:PenID, 80; PenID, 8
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.05573    0.11685   63.25977 -17.593   <2e-16 ***
# time                       4.29783    0.22457 3150.32198  19.138   <2e-16 ***
# time2                     -1.98372    0.12197 3150.34111 -16.264   <2e-16 ***
# avgDIB_scale               0.05978    0.07122   10.17307   0.839   0.4205
# Treatment_encoded         -0.15681    0.07238    9.50511  -2.166   0.0569 .
# temperature_C_avg_scale   -0.02851    0.01392 3150.23819  -2.048   0.0406 *
# InitialWeight_scale       -0.05943    0.07009   76.34717  -0.848   0.3991
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ tm_C__
# time        -0.774
# time2        0.737 -0.987
# avgDIB_scal -0.024 -0.007  0.006
# Trtmnt_ncdd -0.014  0.003 -0.003 -0.053
# tmprtr_C_v_  0.258 -0.404  0.450 -0.001 -0.003
# IntlWght_sc -0.003  0.001 -0.001  0.110 -0.172  0.000
#      R2m       R2c
# [1,] 0.1349907 0.5189857
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG_pen_noclass)"
# plot without title

# %%
anova(MAVG_pen_class, MAVG_pen_noclass, Test='Chisq')
# Out:
#                  npar AIC      BIC      logLik    deviance Chisq   Df
# MAVG_pen_noclass 10   6949.680 7010.482 -3464.840 6929.680      NA NA
# MAVG_pen_class   14   6954.427 7039.550 -3463.213 6926.427 3.25305  4
#                  Pr(>Chisq)
# MAVG_pen_noclass        NA
# MAVG_pen_class   0.5164054

# %%
MAVG_nopen_class = lmerTest::lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_scale + (1|HenID), REML=FALSE, data = df)
summary(MAVG_nopen_class)
r.squaredGLMM(MAVG_nopen_class)
###### normally distributed residuals
qqnorm(resid(MAVG_nopen_class))
qqline(resid(MAVG_nopen_class))
hist(resid(MAVG_nopen_class))
######check homogeneity of variance (residuals has constant variance)
plot(MAVG_nopen_class)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula: PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + CLASS +
#     temperature_C_avg_scale + InitialWeight_scale + (1 | HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6952.5   7031.5  -3463.2   6926.5     3217
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0726 -0.6002  0.0134  0.6233  3.9409
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.3514   0.5928
#  Residual             0.4588   0.6773
# Number of obs: 3230, groups:  HenID, 80
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.12114    0.19823  130.65417 -10.701   <2e-16 ***
# time                       4.29778    0.22457 3150.37413  19.138   <2e-16 ***
# time2                     -1.98369    0.12197 3150.39573 -16.264   <2e-16 ***
# avgDIB_scale               0.06011    0.06787   80.07571   0.886   0.3784
# Treatment_encoded         -0.15190    0.06935   80.02774  -2.190   0.0314 *
# CLASSLEXP                 -0.08168    0.21416   80.09713  -0.381   0.7039
# CLASSLEXPLOST              0.03516    0.26907   80.04109   0.131   0.8964
# CLASSMEXP                  0.19607    0.20330   80.07838   0.964   0.3377
# CLASSMEXPLOST              0.28440    0.63579   79.83268   0.447   0.6559
# temperature_C_avg_scale   -0.02851    0.01392 3150.28097  -2.048   0.0406 *
# InitialWeight_scale       -0.07234    0.06998   80.04270  -1.034   0.3044
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ CLASSLEXP CLASSLEXPL CLASSMEXP
# time        -0.456
# time2        0.434 -0.987
# avgDIB_scal -0.089 -0.008  0.006
# Trtmnt_ncdd -0.051  0.003 -0.003 -0.048
# CLASSLEXP   -0.723  0.000  0.000  0.087  0.014
# CLASSLEXPLO -0.583  0.000  0.000  0.079  0.113  0.538
# CLASSMEXP   -0.761  0.000  0.000  0.080  0.054  0.702     0.566
# CLASSMEXPLO -0.238 -0.001  0.001  0.057 -0.071  0.218     0.163      0.236
# tmprtr_C_v_  0.152 -0.404  0.450 -0.001 -0.003  0.000     0.000      0.000
# IntlWght_sc -0.023  0.001 -0.001  0.110 -0.160  0.060     0.063     -0.008
#             CLASSMEXPL tm_C__
# time
# time2
# avgDIB_scal
# Trtmnt_ncdd
# CLASSLEXP
# CLASSLEXPLO
# CLASSMEXP
# CLASSMEXPLO
# tmprtr_C_v_  0.001
# IntlWght_sc -0.125      0.000
#      R2m      R2c
# [1,] 0.149744 0.5185309
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG_nopen_class)"
# plot without title

# %%
MAVG_nopen_noclass = lmerTest::lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale + InitialWeight_scale + (1|HenID), REML=FALSE, data = df)
summary(MAVG_nopen_noclass)
r.squaredGLMM(MAVG_nopen_noclass)
###### normally distributed residuals
qqnorm(resid(MAVG_nopen_noclass))
qqline(resid(MAVG_nopen_noclass))
hist(resid(MAVG_nopen_noclass))
######check homogeneity of variance (residuals has constant variance)
plot(MAVG_nopen_noclass)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula:
# PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale +
#     InitialWeight_scale + (1 | HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6947.7   7002.4  -3464.9   6929.7     3221
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0761 -0.5976  0.0144  0.6235  3.9332
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.3663   0.6052
#  Residual             0.4588   0.6773
# Number of obs: 3230, groups:  HenID, 80
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.05472    0.11532  582.45736 -17.818   <2e-16 ***
# time                       4.29794    0.22457 3150.34834  19.139   <2e-16 ***
# time2                     -1.98378    0.12197 3150.36931 -16.264   <2e-16 ***
# avgDIB_scale               0.05862    0.06888   80.05629   0.851   0.3973
# Treatment_encoded         -0.15575    0.06991   80.00675  -2.228   0.0287 *
# temperature_C_avg_scale   -0.02852    0.01392 3150.25735  -2.049   0.0406 *
# InitialWeight_scale       -0.05842    0.07030   80.00922  -0.831   0.4084
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ tm_C__
# time        -0.784
# time2        0.747 -0.987
# avgDIB_scal -0.021 -0.008  0.006
# Trtmnt_ncdd -0.015  0.003 -0.003 -0.052
# tmprtr_C_v_  0.262 -0.404  0.450 -0.001 -0.003
# IntlWght_sc -0.003  0.001 -0.001  0.112 -0.180  0.000
#      R2m       R2c
# [1,] 0.1343224 0.5186242
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG_nopen_noclass)"
# plot without title

# %%
anova(MAVG_nopen_class, MAVG_nopen_noclass, Test='Chisq')
# Out:
#                    npar AIC      BIC      logLik    deviance Chisq   Df
# MAVG_nopen_noclass  9   6947.707 7002.429 -3464.853 6929.707      NA NA
# MAVG_nopen_class   13   6952.488 7031.532 -3463.244 6926.488 3.21827  4
#                    Pr(>Chisq)
# MAVG_nopen_noclass       NA
# MAVG_nopen_class   0.521985

# %% [markdown]
# # Repeatabilities

# %%
################################################ PC1 SHORT term ################################################
print(VarCorr(MAVG_nopen_noclass),comp =c("Variance","Std.Dev."))
rep = VarCorr(MAVG_nopen_noclass)$"HenID"[1]/
(VarCorr(MAVG_nopen_noclass)$"HenID"[1]+
 attr(VarCorr(MAVG_nopen_noclass), "sc")^2) # equal to the variance of residual
#alternatively: 0.39815  /(0.39815  +0.47685)
rep

#or with posterior distribtion with 1000 simulations and credible interval
set.seed(1)
simulated = sim(MAVG_nopen_noclass, n.sim = 1000)
posterior_HenID = apply(simulated@ranef$"HenID"[ , , 1],1,var)
posterior_residual  = simulated@sigma^2
quantile(posterior_HenID/
         (posterior_HenID+posterior_residual), prob=c(0.025, 0.5, 0.975))
# Out:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.36628  0.60521
#  Residual             0.45880  0.67734
# [1] 0.4439317
#      2.5%       50%     97.5%
# 0.4305358 0.4538661 0.4801440

# %% [markdown]
# # Plasticity

# %%
#random interecepts and slopes over DIB for each animal (interactio between DIB and henID as a random effect)
MPL1 = lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale + InitialWeight_scale + (1 + time|HenID), 
                REML=TRUE, data=df)
           #control = lmerControl(optimizer ='optimx', optCtrl=list(method='L-BFGS-B')))
summary(MPL1)
r.squaredGLMM(MPL1)
###### normally distributed residuals
qqnorm(resid(MPL1))
qqline(resid(MPL1))
hist(resid(MPL1))
######check homogeneity of variance (residuals has constant variance)
plot(MPL1)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale +
#     InitialWeight_scale + (1 + time | HenID)
#    Data: df
#
# REML criterion at convergence: 5859.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.7453 -0.5877 -0.0165  0.5797  4.3983
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 1.7351   1.3172
#           time        1.3271   1.1520   -0.88
#  Residual             0.2998   0.5476
# Number of obs: 3230, groups:  HenID, 80
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.11305    0.16584  115.21350 -12.742  < 2e-16 ***
# time                       4.41857    0.22358  597.85606  19.763  < 2e-16 ***
# time2                     -2.04109    0.09909 3071.33585 -20.598  < 2e-16 ***
# avgDIB_scale               0.06447    0.07039   75.99169   0.916  0.36261
# Treatment_encoded         -0.15362    0.07146   75.99986  -2.150  0.03476 *
# temperature_C_avg_scale   -0.02945    0.01126 3068.23990  -2.616  0.00893 **
# InitialWeight_scale       -0.07792    0.07185   76.00246  -1.085  0.28156
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ tm_C__
# time        -0.815
# time2        0.424 -0.807
# avgDIB_scal -0.018 -0.003  0.003
# Trtmnt_ncdd -0.010  0.002 -0.003 -0.052
# tmprtr_C_v_  0.148 -0.329  0.449 -0.001 -0.002
# IntlWght_sc -0.002  0.000 -0.001  0.112 -0.180  0.000
#      R2m       R2c
# [1,] 0.1389651 0.696393
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MPL1)"
# plot without title

# %%
#test whether a nonlinear random slope over DIB improve model fit
MPL2 = lmer(PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale + InitialWeight_scale + (1 + time + time2|HenID), 
                REML=TRUE, data=df, control = lmerControl(optimizer ='optimx', optCtrl=list(method='nlminb')))
summary(MPL2)
r.squaredGLMM(MPL2)
###### normally distributed residuals
qqnorm(resid(MPL2))
qqline(resid(MPL2))
hist(resid(MPL2))
######check homogeneity of variance (residuals has constant variance)
plot(MPL2)
# Out:
# Loading required namespace: optimx
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# PC1 ~ time + time2 + avgDIB_scale + Treatment_encoded + temperature_C_avg_scale +
#     InitialWeight_scale + (1 + time + time2 | HenID)
#    Data: df
# Control: lmerControl(optimizer = "optimx", optCtrl = list(method = "nlminb"))
#
# REML criterion at convergence: 5543.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2797 -0.5822 -0.0195  0.5672  4.4944
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept)  3.666   1.915
#           time        13.476   3.671    -0.88
#           time2        3.379   1.838     0.72 -0.95
#  Residual              0.257   0.507
# Number of obs: 3230, groups:  HenID, 80
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -2.16548    0.22575   78.47259  -9.592 7.27e-15 ***
# time                       4.53170    0.44476   83.27838  10.189 2.67e-16 ***
# time2                     -2.09563    0.22545   85.32578  -9.295 1.32e-14 ***
# avgDIB_scale               0.05477    0.07017   76.04697   0.781  0.43748
# Treatment_encoded         -0.14423    0.07122   76.00167  -2.025  0.04636 *
# temperature_C_avg_scale   -0.03042    0.01043 2991.78578  -2.916  0.00357 **
# InitialWeight_scale       -0.07039    0.07161   75.99784  -0.983  0.32873
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) time   time2  avDIB_ Trtmn_ tm_C__
# time        -0.887
# time2        0.744 -0.954
# avgDIB_scal -0.012 -0.003  0.003
# Trtmnt_ncdd -0.007  0.001 -0.001 -0.052
# tmprtr_C_v_  0.102 -0.155  0.184 -0.001 -0.002
# IntlWght_sc -0.002  0.000  0.000  0.111 -0.180  0.000
#      R2m       R2c
# [1,] 0.1370176 0.7398228
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MPL2)"
# plot without title

# %% [markdown]
# ## Comparing models

# %%
#LRT from anova is not correct anymore as we compare parameters that are on the boundery (random effects)
#LRT MAVG2 and MPL1 (i.e. compare  model with the random intercept and the model with random intercept and slope)
#Same as my citation from: https://link.springer.com/content/pdf/10.1007%2F978-0-387-87458-6_5.pdf (chapter 5 of the book)
summary(MAVG_nopen_noclass)$logLik
summary(MPL1)$logLik
AIC(MAVG_nopen_noclass, MPL1)
L = -2*(summary(MAVG_nopen_noclass)$logLik -summary(MPL1)$logLik)
L
pval = 0.5 * ((1 - pchisq(L, df=1)) + (1 - pchisq(L, df=2))) 
pval
#if p-value < 0.001. reject H0, This means that adding random slope to the model is a significant improvement
# Out:
# 'log Lik.' -3464.853 (df=9)
# 'log Lik.' -2929.865 (df=11)
#                    df AIC
# MAVG_nopen_noclass  9 6947.707
# MPL1               11 5881.730
# 'log Lik.' 1069.977 (df=9)
# 'log Lik.' 0 (df=9)

# %%
#LRT MPL1 and MPL2 (i.e. with DPT compared to DPT2)
#Same as before as its a special case of only one parameter hitting the boundary
#should be correct based on https://stats.stackexchange.com/questions/16013/allowed-comparisons-of-mixed-effects-models-random-effects-primarily/16015#16015
AIC(MPL2, MPL1)
L = -2*(summary(MPL1)$logLik -summary(MPL2)$logLik)
L
pval = 0.5 * ((1 - pchisq(L, df=1)) + (1 - pchisq(L, df=2))) 
pval
#if p-value < 0.001. reject H0, This means that adding quadratic term to the model is a significant improvement: use the more complex model!
# Out:
#      df AIC
# MPL2 14 5571.816
# MPL1 11 5881.730
# 'log Lik.' 315.9141 (df=11)
# 'log Lik.' 0 (df=11)

# %% [markdown]
# # Save BLUPS estimates

# %%
#BLUP intercepts: behavioural type individual estiamtes with mer-Tools (obtaining repeated samples from the posterior distribution
#of the model from which we can calculate the stdev for each individual)
#as PC1 is not interpretable as much as "total distance travelled" would, we wont add the population-level estimate
#done in "studing..."
#as for our purpose it wont change anything
set.seed(1)
simulated_individualbehaviouraltype = REsim(MAVG_nopen_noclass, n.sims = 1000)
head(simulated_individualbehaviouraltype,3)
write.csv(simulated_individualbehaviouraltype,file.path(path_adapt,'BLUP_RI.csv'),row.names = FALSE)
# Out:
#   groupFctr groupID term        mean       median     sd
# 1 HenID     hen_10  (Intercept) -0.4484469 -0.4433746 0.1933244
# 2 HenID     hen_101 (Intercept)  0.5084917  0.5077327 0.1866675
# 3 HenID     hen_102 (Intercept) -1.3936283 -1.3873102 0.1704212

# %%
#BLUP: individual estimates with uncertainty values
set.seed(1)
#REsim already synthesis results compare to the sim(). I verified manually
simulated_individualplasticity = REsim(MPL2, n.sim = 1000)
head(simulated_individualplasticity,3)
write.csv(simulated_individualplasticity, file.path(path_adapt,'BLUP_RR.csv'), row.names = FALSE)
# Out:
#   groupFctr groupID term        mean        median      sd
# 1 HenID     hen_10  (Intercept) -0.02924959  0.01742582 1.509874
# 2 HenID     hen_101 (Intercept)  1.85279835  1.88749970 1.661585
# 3 HenID     hen_102 (Intercept) -0.57626161 -0.62452675 1.519838

# %% [markdown]
# # Save predictions

# %%
#daily predicted value, done in "phenotypic plant..."
df$pred_pop  = predict(MAVG_nopen_noclass, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MAVG_nopen_noclass, re.form = NULL)
write.csv(df, file.path(path_adapt,'Prediction_RI.csv'), row.names = FALSE)
head(df,3)
# Out:
#   HenID   DIB CLASS PenID temperature_C_avg tobeusedPCA InitialWeight
# 1 hen_134 11  MEXP  pen10 11.50000          1           1112
# 2 hen_134 12  MEXP  pen10 10.16667          0           1112
# 3 hen_134 13  MEXP  pen10  9.00000          0           1112
#   Treatment_encoded perc_duration_5_Zone perc_duration_4_Zone ... Treatment
# 1 -1                100                  0                    ... -1
# 2 -1                 86                  0                    ... -1
# 3 -1                100                  0                    ... -1
#   PC1       cDIB temperature_C_avg_scale time      time2      avgDIB_scale
# 1 -1.913797 11    0.2080966              0.3073743 0.09447897 -0.3677554
# 2 -1.621394 12   -0.2112122              0.3353174 0.11243778 -0.3677554
# 3 -1.913797 13   -0.5781073              0.3632606 0.13195823 -0.3677554
#   InitialWeight_scale pred_pop   pred_HenID
# 1 -0.9142959          -0.7394022 -1.190963
# 2 -0.9142959          -0.6429736 -1.094534
# 3 -0.9142959          -0.5511375 -1.002698

# %%
#daily predicted value
df$pred_pop  = predict(MPL1, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MPL1, re.form = NULL)
write.csv(df, file.path(path_adapt,'Prediction_RR_linear.csv'), row.names = FALSE)
head(df,3)
# Out:
#   HenID   DIB CLASS PenID temperature_C_avg tobeusedPCA InitialWeight
# 1 hen_134 11  MEXP  pen10 11.50000          1           1112
# 2 hen_134 12  MEXP  pen10 10.16667          0           1112
# 3 hen_134 13  MEXP  pen10  9.00000          0           1112
#   Treatment_encoded perc_duration_5_Zone perc_duration_4_Zone ... Treatment
# 1 -1                100                  0                    ... -1
# 2 -1                 86                  0                    ... -1
# 3 -1                100                  0                    ... -1
#   PC1       cDIB temperature_C_avg_scale time      time2      avgDIB_scale
# 1 -1.913797 11    0.2080966              0.3073743 0.09447897 -0.3677554
# 2 -1.621394 12   -0.2112122              0.3353174 0.11243778 -0.3677554
# 3 -1.913797 13   -0.5781073              0.3632606 0.13195823 -0.3677554
#   InitialWeight_scale pred_pop   pred_HenID
# 1 -0.9142959          -0.7527089 -2.022671
# 2 -0.9142959          -0.6535486 -1.887694
# 3 -0.9142959          -0.5591192 -1.757447

# %%
#daily predicted value
df$pred_pop  = predict(MPL2, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MPL2, re.form = NULL)
write.csv(df, file.path(path_adapt,'Prediction_RR_quadratic.csv'), row.names = FALSE)
head(df,3)
# Out:
#   HenID   DIB CLASS PenID temperature_C_avg tobeusedPCA InitialWeight
# 1 hen_134 11  MEXP  pen10 11.50000          1           1112
# 2 hen_134 12  MEXP  pen10 10.16667          0           1112
# 3 hen_134 13  MEXP  pen10  9.00000          0           1112
#   Treatment_encoded perc_duration_5_Zone perc_duration_4_Zone ... Treatment
# 1 -1                100                  0                    ... -1
# 2 -1                 86                  0                    ... -1
# 3 -1                100                  0                    ... -1
#   PC1       cDIB temperature_C_avg_scale time      time2      avgDIB_scale
# 1 -1.913797 11    0.2080966              0.3073743 0.09447897 -0.3677554
# 2 -1.621394 12   -0.2112122              0.3353174 0.11243778 -0.3677554
# 3 -1.913797 13   -0.5781073              0.3632606 0.13195823 -0.3677554
#   InitialWeight_scale pred_pop   pred_HenID
# 1 -0.9142959          -0.7884313 -2.089964
# 2 -0.9142959          -0.6866809 -1.946434
# 3 -0.9142959          -0.5897976 -1.808054
