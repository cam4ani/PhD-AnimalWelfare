# %%
library(MCMCglmm)
library(lme4) #random effect'lmerTest' should be used in place of 'lme4', If lmer model p-values are desired 
library(brms) #preditability with baysian approach
library(ggplot2) #plot
library(MuMIn) #r.squaredGLMM
library(merTools) #simulations
library(optimx) #different optimizer to help model to converge 
#library("posterior") #not sue I am using it as brms should have it already in its package, althought it is base don this package
# Out:
# Warning message:
# "package 'MCMCglmm' was built under R version 4.0.5"
# Loading required package: Matrix
#
# Loading required package: coda
#
# Warning message:
# "package 'coda' was built under R version 4.0.5"
# Loading required package: ape
#
# Warning message:
# "package 'brms' was built under R version 4.0.5"
# Loading required package: Rcpp
#
# Loading 'brms' package (version 2.16.1). Useful instructions
# can be found by typing help('brms'). A more detailed introduction
# to the package is available through vignette('brms_overview').
#
#
# Attaching package: 'brms'
#
#
# The following object is masked from 'package:lme4':
#
#     ngrps
#
#
# The following object is masked from 'package:MCMCglmm':
#
#     me
#
#
# The following object is masked from 'package:stats':
#
#     ar
#
#
# Warning message:
# "package 'MuMIn' was built under R version 4.0.5"
#
# Attaching package: 'MuMIn'
#
#
# The following object is masked from 'package:brms':
#
#     loo
#
#
# Warning message:
# "package 'merTools' was built under R version 4.0.5"
# Loading required package: arm
#
# Warning message:
# "package 'arm' was built under R version 4.0.5"
# Loading required package: MASS
#
#
# arm (Version 1.11-2, built: 2020-7-27)
#
#
# Working directory is C:/Users/camil/Desktop/animals_code/PhD-AnimalWelfare/Chapter1-EarlyMovementLateHealth
#
#
#
# Attaching package: 'arm'
#
#
# The following object is masked from 'package:ape':
#
#     balance
#
#
# The following object is masked from 'package:coda':
#
#     traceplot
#
#
# Warning message:
# "package 'optimx' was built under R version 4.0.5"

# %%
#citation("merTools")

# %%
library(parallel)
my.cores = detectCores()

# %% [markdown]
# library(lme4)
# library(arm)
# library(MuMIn)
# library(tidyverse)
# library(plyr)
# library(broom)
# library(coda)
# library(grid)
# library(gridExtra)
# library(brms)
# library(broom.mixed)
# library(merTools)
# library(tidybayes)
# library(parallel)

# %% [markdown]
# # Download data

# %%
path_ = 'G:/VPHI/Welfare/2- Research Projects/OFHE2.OriginsE2/DataOutput/TrackingSystem/ALLDATA_'
path_adapt = file.path(path_,'Adaptability')
path_model = file.path(path_adapt,'repeatability_model')
df = read.csv(file.path(path_adapt,'df_MVT_4individuality_withPCA.csv'), header = TRUE, sep = ",")
df$HenID = as.factor(df$HenID)   
df$PenID = as.factor(df$PenID) 
#mean-centering of the environmental variable so that intercepts reflect average values for the population and individuals
df$cDIB = as.integer(df$DIB) 
df$cDIB2 = poly(df$cDIB, degree=2,raw=TRUE)[,2]
df$RearingPenID = as.factor(df$RearingPenID) 
df$CLASS = as.factor(df$CLASS) 
df$Treatment = as.factor(df$Treatment) 
#scale all continuous fixed effectcs
df$temperature_C_avg_scale = scale(df$temperature_C_avg, center=TRUE, scale=TRUE)
df$cDIB2_scale = scale(df$cDIB2, center=TRUE, scale=TRUE)
df$cDIB_scale = scale(df$cDIB, center=TRUE, scale=TRUE)
df$avgDIB_scale = scale(df$avgDIB, center=TRUE, scale=TRUE)
df$InitialWeight_kg_scale = scale(df$InitialWeight_kg, center=TRUE, scale=TRUE)
print(dim(df))
summary(df)
# Out:
# [1] 5259   36
#       WIB            HenID           RPen            DIB          CLASS
#  Min.   :2.000   hen_1  :  43   Min.   :1.000   Min.   :11.00   LEXP :1043
#  1st Qu.:4.000   hen_105:  43   1st Qu.:2.000   1st Qu.:23.00   MEXP :1421
#  Median :5.000   hen_110:  43   Median :2.000   Median :34.00   Other:2795
#  Mean   :5.221   hen_113:  43   Mean   :2.479   Mean   :33.58
#  3rd Qu.:7.000   hen_114:  43   3rd Qu.:3.000   3rd Qu.:44.00
#  Max.   :8.000   hen_116:  43   Max.   :4.000   Max.   :54.00
#                  (Other):5001
#  TrackingSystemID       PenID      temperature_C_avg Treatment
#  Length:5259        pen10  : 756   Min.   : 4.000    OFH :2569
#  Class :character   pen11  : 756   1st Qu.: 8.667    TRAN:2690
#  Mode  :character   pen8   : 688   Median :11.000
#                     pen9   : 687   Mean   :10.841
#                     pen12  : 626   3rd Qu.:12.667
#                     pen4   : 620   Max.   :19.333
#                     (Other):1126
#   tobeusedPCA    RearingPenID InitialWeight  Treatment_encoded
#  Min.   :0.000   1:1190       Min.   :1024   Min.   :-1.00000
#  1st Qu.:0.000   2:1525       1st Qu.:1132   1st Qu.:-1.00000
#  Median :0.000   3:1379       Median :1168   Median :-1.00000
#  Mean   :0.173   4:1165       Mean   :1169   Mean   :-0.02301
#  3rd Qu.:0.000                3rd Qu.:1202   3rd Qu.: 1.00000
#  Max.   :1.000                Max.   :1350   Max.   : 1.00000
#
#  perc_duration_5_Zone perc_duration_4_Zone perc_duration_3_Zone
#  Min.   :  0.00       Min.   :  0.000      Min.   : 0.00
#  1st Qu.: 12.00       1st Qu.:  4.000      1st Qu.: 7.00
#  Median : 32.00       Median :  6.000      Median :17.00
#  Mean   : 38.81       Mean   :  7.956      Mean   :18.01
#  3rd Qu.: 63.00       3rd Qu.: 10.000      3rd Qu.:27.00
#  Max.   :100.00       Max.   :100.000      Max.   :70.00
#
#  perc_duration_2_Zone perc_1_Zone_while_WG_open nbr_stays_2_Zone_perh
#  Min.   : 0.0         Min.   : 0.000            Min.   :0.000
#  1st Qu.:15.0         1st Qu.: 0.000            1st Qu.:0.500
#  Median :33.0         Median : 1.619            Median :1.083
#  Mean   :32.1         Mean   : 6.889            Mean   :1.117
#  3rd Qu.:47.0         3rd Qu.: 9.983            3rd Qu.:1.643
#  Max.   :95.0         Max.   :91.194            Max.   :5.091
#
#  nbr_stays_4_Zone_perh nbr_stays_3_Zone_perh nbr_stays_5_Zone_perh
#  Min.   :0.0000        Min.   :0.0000        Min.   :0.0000
#  1st Qu.:0.2857        1st Qu.:0.7143        1st Qu.:0.2000
#  Median :0.5714        Median :1.3333        Median :0.3636
#  Mean   :0.6995        Mean   :1.3145        Mean   :0.4369
#  3rd Qu.:0.9333        3rd Qu.:1.8333        3rd Qu.:0.6000
#  Max.   :5.2500        Max.   :5.1818        Max.   :3.1667
#
#  nbr_stays_1_Zone_perh in_WG_15mnAfterOpening SleepingHeight
#  Min.   :0.0000        Min.   :0.0000         Min.   :0.000
#  1st Qu.:0.0000        1st Qu.:0.0000         1st Qu.:2.000
#  Median :0.1667        Median :0.0000         Median :3.000
#  Mean   :0.4320        Mean   :0.2124         Mean   :2.515
#  3rd Qu.:0.6795        3rd Qu.:0.0000         3rd Qu.:3.000
#  Max.   :3.8333        Max.   :1.0000         Max.   :3.000
#
#  vertical_travel_distance_perh     avgDIB           cDIB          cDIBfact
#  Min.   : 0.000                Min.   :31.34   Min.   :11.00   Min.   :11.00
#  1st Qu.: 2.286                1st Qu.:32.91   1st Qu.:23.00   1st Qu.:23.00
#  Median : 3.600                Median :33.36   Median :34.00   Median :34.00
#  Mean   : 3.599                Mean   :33.58   Mean   :33.58   Mean   :33.58
#  3rd Qu.: 4.833                3rd Qu.:34.00   3rd Qu.:44.00   3rd Qu.:44.00
#  Max.   :13.300                Max.   :35.38   Max.   :54.00   Max.   :54.00
#
#  InitialWeight_kg      PC1              cDIB2      temperature_C_avg_scale.V1
#  Min.   :1.024    Min.   :-1.9691   Min.   : 121   Min.   :-2.1526244
#  1st Qu.:1.132    1st Qu.:-0.6968   1st Qu.: 529   1st Qu.:-0.6842624
#  Median :1.168    Median : 0.1678   Median :1156   Median : 0.0499186
#  Mean   :1.169    Mean   : 0.0000   Mean   :1279   Mean   : 0.0000000
#  3rd Qu.:1.202    3rd Qu.: 0.7068   3rd Qu.:1936   3rd Qu.: 0.5743337
#  Max.   :1.350    Max.   : 2.9775   Max.   :2916   Max.   : 2.6719937
#
#     cDIB2_scale.V1       cDIB_scale.V1       avgDIB_scale.V1
#  Min.   :-1.3954094   Min.   :-1.8354192   Min.   :-3.333362
#  1st Qu.:-0.9038380   1st Qu.:-0.8601267   1st Qu.:-1.005595
#  Median :-0.1484083   Median : 0.0338914   Median :-0.335966
#  Mean   : 0.0000000   Mean   : 0.0000000   Mean   : 0.000000
#  3rd Qu.: 0.7913606   3rd Qu.: 0.8466351   3rd Qu.: 0.620292
#  Max.   : 1.9720960   Max.   : 1.6593788   Max.   : 2.670649

# %%
length(unique(df[['HenID']]))
# Out:
# [1] 130

# %% [markdown]
# # Individual personality

# %%
MAVG0 = lmerTest::lmer(PC1 ~ cDIB_scale + avgDIB_scale + Treatment_encoded + CLASS + PenID + temperature_C_avg_scale + InitialWeight_kg_scale + (1|HenID), 
                       REML=FALSE, data=df)
summary(MAVG0)
r.squaredGLMM(MAVG0)
###### normally distributed residuals
qqnorm(resid(MAVG0))
qqline(resid(MAVG0))
hist(resid(MAVG0))
###### check homogeneity of variance (residuals has constant variance)
plot(MAVG0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
#
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula: PC1 ~ cDIB_scale + avgDIB_scale + Treatment_encoded + CLASS +
#     PenID + temperature_C_avg_scale + (1 | HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  11578.8  11677.3  -5774.4  11548.8     5244
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2823 -0.5963  0.0245  0.6364  4.0354
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.375    0.6123
#  Residual             0.483    0.6950
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)             -1.263e-01  2.137e-01  1.301e+02  -0.591  0.55546
# cDIB_scale               1.694e-01  1.000e-02  5.129e+03  16.931  < 2e-16 ***
# avgDIB_scale             5.622e-02  1.968e-01  1.305e+02   0.286  0.77555
# Treatment_encoded       -3.328e-01  1.242e-01  1.299e+02  -2.679  0.00834 **
# CLASSMEXP                2.127e-01  1.646e-01  1.301e+02   1.292  0.19848
# CLASSOther               1.100e-01  1.468e-01  1.301e+02   0.749  0.45495
# PenIDpen11               2.863e-01  2.483e-01  1.299e+02   1.153  0.25106
# PenIDpen12              -6.114e-02  2.210e-01  1.297e+02  -0.277  0.78248
# PenIDpen3                1.759e-01  4.984e-01  1.304e+02   0.353  0.72475
# PenIDpen4               -5.199e-02  4.683e-01  1.304e+02  -0.111  0.91177
# PenIDpen5                2.794e-02  3.851e-01  1.306e+02   0.073  0.94227
# PenIDpen8               -3.601e-01  2.528e-01  1.299e+02  -1.424  0.15676
# temperature_C_avg_scale  7.373e-02  9.991e-03  5.129e+03   7.380 1.84e-13 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Warning message:
# "'r.squaredGLMM' now calculates a revised statistic. See the help page."
#      R2m       R2c
# [1,] 0.1062034 0.4968424
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG0)"
# plot without title

# %%
MAVG1 = lmerTest::lmer(PC1 ~ cDIB_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_kg_scale +(1|HenID), 
                       REML=FALSE, data=df)
summary(MAVG1)
r.squaredGLMM(MAVG1)
###### normally distributed residuals
qqnorm(resid(MAVG1))
qqline(resid(MAVG1))
hist(resid(MAVG1))
###### check homogeneity of variance (residuals has constant variance)
plot(MAVG1)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula: PC1 ~ cDIB_scale + avgDIB_scale + Treatment_encoded + CLASS +
#     temperature_C_avg_scale + (1 | HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  11571.8  11630.9  -5776.9  11553.8     5250
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2839 -0.5938  0.0267  0.6370  4.0264
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.3901   0.6246
#  Residual             0.4830   0.6950
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -0.11627    0.12450  130.15724  -0.934 0.352093
# cDIB_scale                 0.16935    0.01000 5129.10070  16.931  < 2e-16 ***
# avgDIB_scale               0.09899    0.05538  130.19812   1.788 0.076171 .
# Treatment_encoded         -0.21462    0.05580  130.07674  -3.846 0.000187 ***
# CLASSMEXP                  0.19648    0.16437  130.11149   1.195 0.234115
# CLASSOther                 0.10643    0.14625  130.13097   0.728 0.468112
# temperature_C_avg_scale    0.07372    0.00999 5129.27730   7.379 1.85e-13 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) cDIB_s avDIB_ Trtmn_ CLASSM CLASSO
# cDIB_scale   0.000
# avgDIB_scal  0.025 -0.010
# Trtmnt_ncdd -0.036  0.000 -0.070
# CLASSMEXP   -0.758  0.000 -0.029  0.038
# CLASSOther  -0.852  0.000 -0.055  0.039  0.646
# tmprtr_C_v_ -0.001  0.281 -0.003 -0.002  0.001  0.001
#      R2m        R2c
# [1,] 0.09092401 0.4971249
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG1)"
# plot without title

# %%
anova(MAVG0, MAVG1, test="Chisq")
# Out:
#       npar AIC      BIC      logLik    deviance Chisq    Df Pr(>Chisq)
# MAVG1  9   11571.76 11630.87 -5776.882 11553.76       NA NA        NA
# MAVG0 15   11578.77 11677.28 -5774.384 11548.77 4.995769  6 0.5443559

# %%
#we use raw=TRUE to be comparable, but then we will set it to FALSE to avoid collineartiy issues
#poly(cDIB, 2, raw = FALSE)1 is the slope coefficient of the quadratic function 
#poly(cDIB, 2, raw = FALSE)2 is the quadratic coefficient of the quadratic functionthat reflects the curvature of the regression
MAVG2 = lmerTest::lmer(PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_kg_scale+ (1|HenID), 
                       REML=FALSE, data = df)
# I(cDIB_scale^2)
summary(MAVG2)
r.squaredGLMM(MAVG2)
###### normally distributed residuals
qqnorm(resid(MAVG2))
qqline(resid(MAVG2))
hist(resid(MAVG2))
######check homogeneity of variance (residuals has constant variance)
plot(MAVG2)
# Out:
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula: PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded +
#     CLASS + temperature_C_avg_scale + (1 | HenID)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#  11148.5  11214.2  -5564.3  11128.5     5249
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1766 -0.5869  0.0095  0.5988  4.2389
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.3900   0.6245
#  Residual             0.4446   0.6668
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -0.11678    0.12433  130.14758  -0.939 0.349339
# cDIB_scale                 1.40652    0.05954 5129.66191  23.625  < 2e-16 ***
# cDIB2_scale               -1.28365    0.06097 5129.68536 -21.055  < 2e-16 ***
# avgDIB_scale               0.09273    0.05530  130.19258   1.677 0.095973 .
# Treatment_encoded         -0.21153    0.05573  130.07501  -3.796 0.000225 ***
# CLASSMEXP                  0.19783    0.16415  130.10538   1.205 0.230328
# CLASSOther                 0.10754    0.14606  130.12336   0.736 0.462914
# temperature_C_avg_scale   -0.02735    0.01072 5129.41682  -2.551 0.010759 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) cDIB_s cDIB2_ avDIB_ Trtmn_ CLASSM CLASSO
# cDIB_scale   0.000
# cDIB2_scale  0.000 -0.987
# avgDIB_scal  0.025 -0.007  0.005
# Trtmnt_ncdd -0.036  0.003 -0.003 -0.070
# CLASSMEXP   -0.758  0.000  0.000 -0.029  0.038
# CLASSOther  -0.852  0.000  0.000 -0.055  0.039  0.646
# tmprtr_C_v_  0.000 -0.401  0.448  0.000 -0.003  0.000  0.000
#      R2m      R2c
# [1,] 0.129996 0.536566
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MAVG2)"
# plot without title

# %% [markdown]
# ## Comparing models & repeatabilities & save corresponding data

# %%
anova(MAVG2, MAVG1, test="Chisq")
# Out:
#       npar AIC      BIC      logLik    deviance Chisq    Df Pr(>Chisq)
# MAVG1  9   11571.76 11630.87 -5776.882 11553.76       NA NA           NA
# MAVG2 10   11148.53 11214.20 -5564.263 11128.53 425.2369  1 1.768456e-94

# %%
#repeatabilities
print(VarCorr(MAVG2), comp=c("Variance","Std.Dev."))
rep = VarCorr(MAVG2)$"HenID"[1]/
(VarCorr(MAVG2)$"HenID"[1]+
 attr(VarCorr(MAVG2), "sc")^2) # equal to the variance of residual
#alternatively: 0.39815  /(0.39815  +0.47685)
rep
# Out:
#  Groups   Name        Variance Std.Dev.
#  HenID    (Intercept) 0.39003  0.62452
#  Residual             0.44458  0.66677
# [1] 0.4673197

# %%
#or with posterior distribution with 1000 simulations and credible interval
set.seed(1)
simulated = sim(MAVG2, n.sim = 1000)
#compute among-individual variance at each iteration (and for a total of 1000)
posterior_HenIDvar = apply(simulated@ranef$"HenID"[ , , 1],1,var)
#small verification
#simulated@ranef$"HenID"[ ,1:3, 1]
#apply(simulated@ranef$"HenID"[ ,1:3, 1],1,var)
#var(c(-0.6410735,-0.20762568,0.7243839))
posterior_residual  = simulated@sigma^2
quantile(posterior_HenIDvar/
         (posterior_HenIDvar+posterior_residual), prob=c(0.025, 0.5, 0.975))
# Out:
#      2.5%       50%     97.5%
# 0.4574751 0.4752794 0.4964397

# %%
summary(MAVG2)$coefficients
# Out:
#                         Estimate    Std. Error df        t value
# (Intercept)             -0.11677993 0.12433232  130.1476  -0.9392564
# cDIB_scale               1.40652327 0.05953630 5129.6619  23.6246353
# cDIB2_scale             -1.28364758 0.06096500 5129.6854 -21.0554830
# avgDIB_scale             0.09273385 0.05530273  130.1926   1.6768404
# Treatment_encoded       -0.21153172 0.05572671  130.0750  -3.7958769
# CLASSMEXP                0.19783279 0.16415446  130.1054   1.2051625
# CLASSOther               0.10753519 0.14606120  130.1234   0.7362338
# temperature_C_avg_scale -0.02735016 0.01071988 5129.4168  -2.5513484
#                         Pr(>|t|)
# (Intercept)              3.493390e-01
# cDIB_scale              3.207143e-117
# cDIB2_scale              1.827348e-94
# avgDIB_scale             9.597320e-02
# Treatment_encoded        2.246115e-04
# CLASSMEXP                2.303280e-01
# CLASSOther               4.629136e-01
# temperature_C_avg_scale  1.075947e-02

# %%
summary(MAVG2)$coefficients[1]
# Out:
# [1] -0.1167799

# %%
#coefficient of variation: square root of the among-individual variance / intercept (i.e. mean trait value)
CVi = sqrt(posterior_HenIDvar)/summary(MAVG2)$coefficients[1]
quantile(CVi,prob=c(0.025, 0.5, 0.975))
# Out:
#      2.5%       50%     97.5%
# -5.660112 -5.443145 -5.267970

# %%
set.seed(1)
simulated = sim(MAVG2, n.sim = 1000)
posterior_HenIDvar = apply(simulated@ranef$"HenID"[ , , 1],1,var)
posterior_HenIDmean = apply(simulated@ranef$"HenID"[ , , 1],1,mean)
CVi = sqrt(posterior_HenIDvar)/posterior_HenIDmean
quantile(CVi,prob=c(0.025, 0.5, 0.975))
# Out:
#        2.5%         50%       97.5%
# -180.802302    4.901595  228.674571

# %%
#BLUP intercepts: behavioural type individual estiamtes with mer-Tools (obtaining repeated samples from the posterior distribution
#of the model from which we can calculate the stdev for each individual)
#as PC1 is not interpretable as much as "total distance travelled" would, we wont add the population-level estimate
#done in "studying..."
#as for our purpose it wont change anything
set.seed(1)
simulated_individualbehaviouraltype = REsim(MAVG2, n.sims=1000)
head(simulated_individualbehaviouraltype,3)
write.csv(simulated_individualbehaviouraltype,file.path(path_,'Adaptability','IndividualBehaviouralType.csv'),row.names = FALSE)
# Out:
#   groupFctr groupID term        mean       median     sd
# 1 HenID     hen_1   (Intercept) -0.7547911 -0.7551207 0.1500564
# 2 HenID     hen_10  (Intercept) -0.2094269 -0.2058306 0.1665161
# 3 HenID     hen_101 (Intercept)  0.5415260  0.5443554 0.1610954

# %% [markdown]
# df_BLUPS_B = data_frame(ID=row.names(ranef(MAVG2)$HenID),
#                         BLUP_B=ranef(MAVG2)$HenID[,"(Intercept)"]) #tidyverse missing!!! fucking R version

# %% [markdown]
# ### early short-term consistency

# %% [markdown]
# modelSTCon = lmer(vertical_travel_distance_perh ~ cDIB + Treatment + temperature_C_avg + InitialWeight_kg + (1|HenID),
#                REML=TRUE, data=df[ which(df$WIB==1), ])
# summary(modelSTCon)
# r.squaredGLMM(modelSTCon)

# %% [markdown]
# #normally distributed residuals
# qqnorm(resid(modelBT))
# qqline(resid(modelBT))
# hist(resid(modelBT))
# #check homogeneity of variance (residuals has constant variance)
# plot(modelBT)

# %% [markdown]
# #repeatabilities
# print(VarCorr(modelBT),comp =c("Variance","Std.Dev."))
# rep = VarCorr(modelBT)$"HenID"[1]/
# (VarCorr(modelBT)$"HenID"[1]+
#  attr(VarCorr(modelBT), "sc")^2) # equal to the variance of residual
# #alternatively: 0.39815  /(0.39815  +0.47685)
# rep

# %% [markdown]
# # Plasticity

# %%
#random interecepts and slopes over DIB for each animal (interactio between DIB and henID as a random effect)
MPL1 = lmerTest::lmer(PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_kg_scale+ (1 + cDIB_scale|HenID), 
                REML=TRUE, data=df)
           #control = lmerControl(optimizer ='optimx', optCtrl=list(method='L-BFGS-B')))
summary(MPL1)
r.squaredGLMM(MPL1)
###### normally distributed residuals
qqnorm(resid(MPL1))
qqline(resid(MPL1))
hist(resid(MPL1))
######check homogeneity of variance (residuals has constant variance)
plot(MPL1)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded +
#     CLASS + temperature_C_avg_scale + (1 + cDIB_scale | HenID)
#    Data: df
#
# REML criterion at convergence: 9594.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.8273 -0.5856 -0.0240  0.5649  5.2391
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 0.4092   0.6397
#           cDIB_scale  0.1388   0.3726   -0.18
#  Residual             0.3043   0.5516
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)               -0.12979    0.12514  126.40836  -1.037 0.301624
# cDIB_scale                 1.43292    0.05938 1128.09675  24.130  < 2e-16 ***
# cDIB2_scale               -1.30926    0.05069 5003.55603 -25.828  < 2e-16 ***
# avgDIB_scale               0.10049    0.05547  125.08974   1.811 0.072488 .
# Treatment_encoded         -0.20248    0.05591  125.03736  -3.622 0.000424 ***
# CLASSMEXP                  0.23410    0.16469  125.07614   1.421 0.157673
# CLASSOther                 0.11128    0.14654  125.08865   0.759 0.449041
# temperature_C_avg_scale   -0.02777    0.00887 4997.51597  -3.131 0.001752 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) cDIB_s cDIB2_ avDIB_ Trtmn_ CLASSM CLASSO
# cDIB_scale  -0.046
# cDIB2_scale  0.001 -0.824
# avgDIB_scal  0.025 -0.001  0.001
# Trtmnt_ncdd -0.036  0.003 -0.003 -0.070
# CLASSMEXP   -0.756  0.000  0.000 -0.029  0.038
# CLASSOther  -0.850  0.000  0.000 -0.055  0.039  0.646
# tmprtr_C_v_ -0.001 -0.334  0.446  0.000 -0.002  0.000  0.000
#      R2m       R2c
# [1,] 0.1294631 0.6892049
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MPL1)"
# plot without title

# %%
#test whether a nonlinear random slope over DIB improve model fit
MPL2 = lmerTest::lmer(PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale +InitialWeight_kg_scale+ (1 + cDIB_scale + cDIB2_scale|HenID), 
                REML=TRUE, data=df)
#control = lmerControl(optimizer ='optimx', optCtrl=list(method='nlminb'))
summary(MPL2)
r.squaredGLMM(MPL2)
###### normally distributed residuals
qqnorm(resid(MPL2))
qqline(resid(MPL2))
hist(resid(MPL2))
######check homogeneity of variance (residuals has constant variance)
plot(MPL2)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded +
#     CLASS + temperature_C_avg_scale + (1 + cDIB_scale + cDIB2_scale |
#     HenID)
#    Data: df
#
# REML criterion at convergence: 9093.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.3054 -0.5723 -0.0164  0.5432  5.6484
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  HenID    (Intercept) 0.4116   0.6416
#           cDIB_scale  1.6170   1.2716    0.07
#           cDIB2_scale 1.4134   1.1889   -0.13 -0.96
#  Residual             0.2619   0.5117
# Number of obs: 5259, groups:  HenID, 130
#
# Fixed effects:
#                           Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)             -1.377e-01  1.242e-01  1.274e+02  -1.109 0.269733
# cDIB_scale               1.452e+00  1.209e-01  1.358e+02  12.016  < 2e-16 ***
# cDIB2_scale             -1.327e+00  1.146e-01  1.391e+02 -11.579  < 2e-16 ***
# avgDIB_scale             9.097e-02  5.495e-02  1.254e+02   1.655 0.100373
# Treatment_encoded       -1.844e-01  5.535e-02  1.250e+02  -3.332 0.001132 **
# CLASSMEXP                2.605e-01  1.630e-01  1.251e+02   1.598 0.112566
# CLASSOther               1.142e-01  1.451e-01  1.251e+02   0.787 0.432658
# temperature_C_avg_scale -2.890e-02  8.236e-03  4.873e+03  -3.509 0.000455 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) cDIB_s cDIB2_ avDIB_ Trtmn_ CLASSM CLASSO
# cDIB_scale   0.028
# cDIB2_scale -0.055 -0.960
# avgDIB_scal  0.024 -0.003  0.002
# Trtmnt_ncdd -0.036  0.000 -0.001 -0.070
# CLASSMEXP   -0.754  0.000  0.000 -0.029  0.038
# CLASSOther  -0.848  0.000  0.000 -0.054  0.039  0.647
# tmprtr_C_v_ -0.001 -0.154  0.185  0.000 -0.001  0.000  0.001
#      R2m       R2c
# [1,] 0.1244881 0.731841
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of resid(MPL2)"
# plot without title

# %% [markdown]
# ## Comparing models & save corresponding data

# %%
#LRT from anova is not correct anymore as we compare parameters that are on the boundery (random effects)
#LRT MAVG2 and MPL1 (i.e. compare  model with the random intercept and the model with random intercept and slope)
#Same as my citation from: https://link.springer.com/content/pdf/10.1007%2F978-0-387-87458-6_5.pdf (chapter 5 of the book)
summary(MAVG2)$logLik
summary(MPL1)$logLik
AIC(MAVG2, MPL1)
L = -2*(summary(MAVG2)$logLik -summary(MPL1)$logLik)
L
pval = 0.5 * ((1 - pchisq(L, df=1)) + (1 - pchisq(L, df=2))) 
pval
#if p-value < 0.001. reject H0, This means that adding random slope to the model is a significant improvement
# Out:
# 'log Lik.' -5564.263 (df=10)
# 'log Lik.' -4797.346 (df=12)
#       df AIC
# MAVG2 10 11148.526
# MPL1  12  9618.691
# 'log Lik.' 1533.835 (df=10)
# 'log Lik.' 0 (df=10)

# %%
#LRT MPL1 and MPL2 (i.e. with DPT compared to DPT2)
#Same as before as its a special case of only one parameter hitting the boundary
#should be correct based on https://stats.stackexchange.com/questions/16013/allowed-comparisons-of-mixed-effects-models-random-effects-primarily/16015#16015
AIC(MPL2, MPL1)
L = -2*(summary(MPL1)$logLik -summary(MPL2)$logLik)
L
pval = 0.5 * ((1 - pchisq(L, df=1)) + (1 - pchisq(L, df=2))) 
pval
#if p-value < 0.001. reject H0, This means that adding quadratic term to the model is a significant improvement: use the more complex model!
# Out:
#      df AIC
# MPL2 15 9123.640
# MPL1 12 9618.691
# 'log Lik.' 501.0508 (df=12)
# 'log Lik.' 0 (df=12)

# %% [markdown]
# #### daily predicted value

# %%
#daily predicted value
df$pred_pop  = predict(MAVG1, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MAVG1, re.form = NULL)
write.csv(df, file.path(path_,'Adaptability','EstimatedPlasticity_int.csv'), row.names = FALSE)
head(df,3)
# Out:
#   WIB HenID   RPen DIB CLASS TrackingSystemID     PenID temperature_C_avg
# 1 2   hen_131 4    11  Other TrackingSystem 10-12 pen10 11.50000
# 2 2   hen_131 4    12  Other TrackingSystem 10-12 pen10 10.16667
# 3 2   hen_131 4    13  Other TrackingSystem 10-12 pen10  9.00000
#   Treatment tobeusedPCA ... cDIBfact InitialWeight_kg PC1         cDIB2
# 1 TRAN      1           ... 11       1.202             0.08344469 121
# 2 TRAN      0           ... 12       1.202            -0.01901373 144
# 3 TRAN      0           ... 13       1.202            -0.33113438 169
#   temperature_C_avg_scale cDIB2_scale cDIB_scale avgDIB_scale pred_pop
# 1  0.2072431              -1.395409   -1.835419  -0.3359664   -0.1240231
# 2 -0.2122889              -1.367698   -1.754145  -0.3359664   -0.1411882
# 3 -0.5793794              -1.337577   -1.672870  -0.3359664   -0.1544872
#   pred_HenID
# 1 0.2396932
# 2 0.2225281
# 3 0.2092291

# %%
#daily predicted value
df$pred_pop  = predict(MAVG2, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MAVG2, re.form = NULL)
write.csv(df, file.path(path_,'Adaptability','EstimatedPlasticity_intquad.csv'), row.names = FALSE)
head(df,3)
# Out:
#   WIB HenID   RPen DIB CLASS TrackingSystemID     PenID temperature_C_avg
# 1 2   hen_131 4    11  Other TrackingSystem 10-12 pen10 11.50000
# 2 2   hen_131 4    12  Other TrackingSystem 10-12 pen10 10.16667
# 3 2   hen_131 4    13  Other TrackingSystem 10-12 pen10  9.00000
#   Treatment tobeusedPCA ... cDIBfact InitialWeight_kg PC1         cDIB2
# 1 TRAN      1           ... 11       1.202             0.08344469 121
# 2 TRAN      0           ... 12       1.202            -0.01901373 144
# 3 TRAN      0           ... 13       1.202            -0.33113438 169
#   temperature_C_avg_scale cDIB2_scale cDIB_scale avgDIB_scale pred_pop
# 1  0.2072431              -1.395409   -1.835419  -0.3359664   -0.6248824
# 2 -0.2122889              -1.367698   -1.754145  -0.3359664   -0.5346652
# 3 -0.5793794              -1.337577   -1.672870  -0.3359664   -0.4489754
#   pred_HenID
# 1 -0.25888145
# 2 -0.16866422
# 3 -0.08297443

# %%
#daily predicted value
df$pred_pop  = predict(MPL1, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MPL1, re.form = NULL)
write.csv(df, file.path(path_,'Adaptability','EstimatedPlasticity_curve.csv'), row.names = FALSE)
head(df,3)
# Out:
#   WIB HenID   RPen DIB CLASS TrackingSystemID     PenID temperature_C_avg
# 1 2   hen_131 4    11  Other TrackingSystem 10-12 pen10 11.50000
# 2 2   hen_131 4    12  Other TrackingSystem 10-12 pen10 10.16667
# 3 2   hen_131 4    13  Other TrackingSystem 10-12 pen10  9.00000
#   Treatment tobeusedPCA ... cDIBfact InitialWeight_kg PC1         cDIB2
# 1 TRAN      1           ... 11       1.202             0.08344469 121
# 2 TRAN      0           ... 12       1.202            -0.01901373 144
# 3 TRAN      0           ... 13       1.202            -0.33113438 169
#   temperature_C_avg_scale cDIB2_scale cDIB_scale avgDIB_scale pred_pop
# 1  0.2072431              -1.395409   -1.835419  -0.3359664   -0.6586017
# 2 -0.2122889              -1.367698   -1.754145  -0.3359664   -0.5667715
# 3 -0.5793794              -1.337577   -1.672870  -0.3359664   -0.4795525
#   pred_HenID
# 1 -0.05263103
# 2  0.02956094
# 3  0.10714159

# %%
#done in "phenotypic plant..."
#daily predicted value
df$pred_pop  = predict(MPL2, re.form = NA) #no random effect
#prediction for the individuals-level "reaction norm"
df$pred_HenID = predict(MPL2, re.form = NULL)
write.csv(df, file.path(path_,'Adaptability','EstimatedPlasticity.csv'), row.names = FALSE)
head(df,3)
# Out:
#   WIB HenID   RPen DIB CLASS TrackingSystemID     PenID temperature_C_avg
# 1 2   hen_131 4    11  Other TrackingSystem 10-12 pen10 11.50000
# 2 2   hen_131 4    12  Other TrackingSystem 10-12 pen10 10.16667
# 3 2   hen_131 4    13  Other TrackingSystem 10-12 pen10  9.00000
#   Treatment tobeusedPCA ... cDIBfact InitialWeight_kg PC1         cDIB2
# 1 TRAN      1           ... 11       1.202             0.08344469 121
# 2 TRAN      0           ... 12       1.202            -0.01901373 144
# 3 TRAN      0           ... 13       1.202            -0.33113438 169
#   temperature_C_avg_scale cDIB2_scale cDIB_scale avgDIB_scale pred_pop
# 1  0.2072431              -1.395409   -1.835419  -0.3359664   -0.6897823
# 2 -0.2122889              -1.367698   -1.754145  -0.3359664   -0.5963944
# 3 -0.5793794              -1.337577   -1.672870  -0.3359664   -0.5077187
#   pred_HenID
# 1 -0.25277119
# 2 -0.14396030
# 3 -0.04103664

# %% [markdown]
# #### BLUP: individual estimates with uncertainty values

# %%
set.seed(1)
#REsim already synthesis results compare to the sim(). I verified manually
simulated_individualplasticity = REsim(MPL2, n.sim = 1000)
head(simulated_individualplasticity,3)
write.csv(simulated_individualplasticity, file.path(path_,'Adaptability','IndividualPlasticity.csv'), row.names = FALSE)
# Out:
#   groupFctr groupID term        mean       median     sd
# 1 HenID     hen_1   (Intercept) -0.7723016 -0.7746552 0.1482065
# 2 HenID     hen_10  (Intercept) -0.2353460 -0.2343080 0.1552140
# 3 HenID     hen_101 (Intercept)  0.4873434  0.4925217 0.1510693

# %% [markdown]
# # Predictibility

# %%
#Get information on all parameters (and parameter classes) for which priors may be specified including default priors:
get_prior(formula= PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + InitialWeight_kg_scale+ (1+ cDIB_scale + cDIB2_scale|HenID), 
          data=df, family = gaussian())
# Out:
#    prior                  class     coef                    group resp dpar
# 1                         b
# 2                         b         avgDIB_scale
# 3                         b         cDIB_scale
# 4                         b         cDIB2_scale
# 5                         b         CLASSMEXP
# 6                         b         CLASSOther
# 7                         b         temperature_C_avg_scale
# 8                         b         Treatment_encoded
# 9  lkj(1)                 cor
# 10                        cor                               HenID
# 11 student_t(3, 0.2, 2.5) Intercept
# 12 student_t(3, 0, 2.5)   sd
# 13                        sd                                HenID
# 14                        sd        cDIB_scale              HenID
# 15                        sd        cDIB2_scale             HenID
# 16                        sd        Intercept               HenID
# 17 student_t(3, 0, 2.5)   sigma
#    nlpar bound source
# 1              default
# 2              default
# 3              default
# 4              default
# 5              default
# 6              default
# 7              default
# 8              default
# 9              default
# 10             default
# 11             default
# 12             default
# 13             default
# 14             default
# 15             default
# 16             default
# 17             default

# %%
#help(brms) #to cite STAN for the following info:
### bulk-ESS: We recommend requiring that the bulk-ESS is greater than 100 times the number of chains. For example, when running 
#4 chains, this corresponds to having a rank-normalized effective sample size of at least 400.
### R-hat: We recommend running at least four chains by default and only using the sample if R-hat is less than 1.01.
#more info: #https://mc-stan.org/misc/warnings.html#bulk-ess%22
double_model = bf(PC1~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + (1+ cDIB_scale + cDIB2_scale|HenID), 
                  sigma~(1|HenID))
modelPred = brm(double_model, data=df, iter=15000, inits="random", seed=12345, control = list(max_treedepth = 15), 
                cores=my.cores, chains=10, thin=3)
             #prior = c(set_prior("student_t(1, 0.01, 0.001)", coef = "temperature_C_avg_scale"),
             #         set_prior("student_t(1, 0.01, 0.001)", coef = "cDIB_scale")))
#modelPred = add_criterion(modelPred, "waic")
summary(modelPred)
pairs(modelPred)
#head(get_variables(modelPred),10)

#coefficient of variation in predictability” (CVP)
log.norm.res = exp(posterior_samples(modelPred)$"sd_HenID__sigma_Intercept"^2)
CVP = sqrt(log.norm.res-1)
mean(CVP);HPDinterval(as.mcmc(CVP),0.95)
#df_pred = posterior_samples(modelPred) #depreciated but still work well. we will instead use:
#extract samples (draw) from the posterior distribution, including all variables
df_pred = as_draws(modelPred)
write.csv(df_pred, file.path(path_,'Adaptability','IndividualPredictability_avgDIB.csv'), row.names = FALSE)
prior_summary(modelPred)
# Out:
# Compiling Stan program...
#
# Start sampling
#  Family: gaussian
#   Links: mu = identity; sigma = log
# Formula: PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + (1 + cDIB_scale + cDIB2_scale | HenID)
#          sigma ~ (1 | HenID)
#    Data: df (Number of observations: 5259)
#   Draws: 10 chains, each with iter = 5000; warmup = 2500; thin = 3;
#          total post-warmup draws = 8334
#
# Group-Level Effects:
# ~HenID (Number of levels: 130)
#                             Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS
# sd(Intercept)                   0.66      0.04     0.58     0.75 1.00     6109
# sd(cDIB_scale)                  1.22      0.09     1.06     1.41 1.00    11093
# sd(cDIB2_scale)                 1.14      0.09     0.98     1.32 1.00     9429
# sd(sigma_Intercept)             0.30      0.02     0.26     0.35 1.00    13505
# cor(Intercept,cDIB_scale)       0.07      0.09    -0.11     0.26 1.00     6894
# cor(Intercept,cDIB2_scale)     -0.14      0.09    -0.32     0.04 1.00     6510
# cor(cDIB_scale,cDIB2_scale)    -0.95      0.01    -0.97    -0.93 1.00     9648
#                             Tail_ESS
# sd(Intercept)                  11716
# sd(cDIB_scale)                 17332
# sd(cDIB2_scale)                15023
# sd(sigma_Intercept)            19131
# cor(Intercept,cDIB_scale)      12130
# cor(Intercept,cDIB2_scale)     12404
# cor(cDIB_scale,cDIB2_scale)    15446
#
# Population-Level Effects:
#                         Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS
# Intercept                  -0.14      0.13    -0.39     0.11 1.00     4892
# sigma_Intercept            -0.75      0.03    -0.80    -0.69 1.00     9288
# cDIB_scale                  1.43      0.12     1.20     1.65 1.00     7661
# cDIB2_scale                -1.30      0.11    -1.52    -1.09 1.00     7436
# avgDIB_scale                0.09      0.06    -0.02     0.20 1.00     4360
# Treatment_encoded          -0.18      0.06    -0.30    -0.07 1.00     3365
# CLASSMEXP                   0.26      0.17    -0.06     0.59 1.00     4551
# CLASSOther                  0.11      0.15    -0.17     0.40 1.00     4326
# temperature_C_avg_scale    -0.03      0.01    -0.04    -0.02 1.00    24803
#                         Tail_ESS
# Intercept                   9315
# sigma_Intercept            14833
# cDIB_scale                 13152
# cDIB2_scale                12392
# avgDIB_scale                8345
# Treatment_encoded           6237
# CLASSMEXP                   8562
# CLASSOther                  8696
# temperature_C_avg_scale    24242
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).
# Warning message:
# "Method 'posterior_samples' is deprecated. Please see ?as_draws for recommended alternatives."
# [1] 0.3085494
#      lower     upper
# var1 0.2625852 0.3550638
#    prior                  class     coef                    group resp dpar
# 1                         b
# 2                         b         avgDIB_scale
# 3                         b         cDIB_scale
# 4                         b         cDIB2_scale
# 5                         b         CLASSMEXP
# 6                         b         CLASSOther
# 7                         b         temperature_C_avg_scale
# 8                         b         Treatment_encoded
# 9  student_t(3, 0.2, 2.5) Intercept
# 10 student_t(3, 0, 2.5)   Intercept                                    sigma
# 11 lkj_corr_cholesky(1)   L
# 12                        L                                 HenID
# 13 student_t(3, 0, 2.5)   sd
# 14 student_t(3, 0, 2.5)   sd                                           sigma
# 15                        sd                                HenID
# 16                        sd        cDIB_scale              HenID
# 17                        sd        cDIB2_scale             HenID
# 18                        sd        Intercept               HenID
# 19                        sd                                HenID      sigma
# 20                        sd        Intercept               HenID      sigma
#    nlpar bound source
# 1              default
# 2              default
# 3              default
# 4              default
# 5              default
# 6              default
# 7              default
# 8              default
# 9              default
# 10             default
# 11             default
# 12             default
# 13             default
# 14             default
# 15             default
# 16             default
# 17             default
# 18             default
# 19             default
# 20             default
# plot without title

# %%
#mean population-level residual variance
fixef(modelPred, pars = "sigma_Intercept")[1]
# Out:
# [1] -0.7459285

# %%
#add score and save model
add_criterion(modelPred, criterion='bayes_R2', file=file.path(path_adapt,'BRMS_Model_variance_avgDIB_scale_LAST'))
#model can be retrieve like this: 
#modelPred = readRDS(file.path(path_adapt,'BRMS_Model_variance_avgDIB_scale.rds'))
#summary(modelPred)
# Out:
#  Family: gaussian
#   Links: mu = identity; sigma = log
# Formula: PC1 ~ cDIB_scale + cDIB2_scale + avgDIB_scale + Treatment_encoded + CLASS + temperature_C_avg_scale + (1 + cDIB_scale + cDIB2_scale | HenID)
#          sigma ~ (1 | HenID)
#    Data: df (Number of observations: 5259)
#   Draws: 10 chains, each with iter = 5000; warmup = 2500; thin = 3;
#          total post-warmup draws = 8334
#
# Group-Level Effects:
# ~HenID (Number of levels: 130)
#                             Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS
# sd(Intercept)                   0.66      0.04     0.58     0.75 1.00     6109
# sd(cDIB_scale)                  1.22      0.09     1.06     1.41 1.00    11093
# sd(cDIB2_scale)                 1.14      0.09     0.98     1.32 1.00     9429
# sd(sigma_Intercept)             0.30      0.02     0.26     0.35 1.00    13505
# cor(Intercept,cDIB_scale)       0.07      0.09    -0.11     0.26 1.00     6894
# cor(Intercept,cDIB2_scale)     -0.14      0.09    -0.32     0.04 1.00     6510
# cor(cDIB_scale,cDIB2_scale)    -0.95      0.01    -0.97    -0.93 1.00     9648
#                             Tail_ESS
# sd(Intercept)                  11716
# sd(cDIB_scale)                 17332
# sd(cDIB2_scale)                15023
# sd(sigma_Intercept)            19131
# cor(Intercept,cDIB_scale)      12130
# cor(Intercept,cDIB2_scale)     12404
# cor(cDIB_scale,cDIB2_scale)    15446
#
# Population-Level Effects:
#                         Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS
# Intercept                  -0.14      0.13    -0.39     0.11 1.00     4892
# sigma_Intercept            -0.75      0.03    -0.80    -0.69 1.00     9288
# cDIB_scale                  1.43      0.12     1.20     1.65 1.00     7661
# cDIB2_scale                -1.30      0.11    -1.52    -1.09 1.00     7436
# avgDIB_scale                0.09      0.06    -0.02     0.20 1.00     4360
# Treatment_encoded          -0.18      0.06    -0.30    -0.07 1.00     3365
# CLASSMEXP                   0.26      0.17    -0.06     0.59 1.00     4551
# CLASSOther                  0.11      0.15    -0.17     0.40 1.00     4326
# temperature_C_avg_scale    -0.03      0.01    -0.04    -0.02 1.00    24803
#                         Tail_ESS
# Intercept                   9315
# sigma_Intercept            14833
# cDIB_scale                 13152
# cDIB2_scale                12392
# avgDIB_scale                8345
# Treatment_encoded           6237
# CLASSMEXP                   8562
# CLASSOther                  8696
# temperature_C_avg_scale    24242
#
# Draws were sampled using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %%
#https://bookdown.org/marklhc/notes_bookdown/model-diagnostics.html

# %% [markdown]
# #### posterior predictive check

# %%
pp_check(modelPred, ndraws = 100)
#-->we don't see any major systematic discrepancies of our data from what can be predicted with modelPred
# Out:
# plot without title

# %%
#additonally marginal model plots could be done with : https://github.com/marklhc/usc-psyc621-notes/blob/master/mmp_brm.R
#as explained here: https://bookdown.org/marklhc/notes_bookdown/model-diagnostics.html#diagnostic-tools

# %%
#TODO: https: "A trace plot shows the history of a parameter value across iterations of the chain."
#https://rdrr.io/cran/brms/man/plot.brmsfit.html//rdrr.io/cran/brms/man/plot.brmsfit.html
