# %%
library("MCMCglmm")
#library("asreml")
data("BTdata")      # load data
data("BTped")       # load pedigree

nitt <- 60000
burnin <- 10000
thin <- 25


usP<-list(V = diag(2)/3, nu = 2)
idhP<-list(V = diag(2)*2/3, nu = 2)

# %%
# marginal prior: nu* = 1 ,  V* diag(2)*(2/3)
# so idh structures should have nu = 2 V = diag(2)*(2/3)

prior1 <- list(R = usP, G = list(G1 = usP, G2 = usP))                 

m1 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ us(trait):animal + us(trait):fosternest, 
      rcov = ~ us(trait):units, 
      prior = prior1,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m1)
# Out:
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4045.286
#
#  G-structure:  ~us(trait):animal
#
#                                post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.animal    0.4497  0.27650  0.64545    646.2
# traitback:traittarsus.animal     -0.1025 -0.21522  0.01409    468.7
# traittarsus:traitback.animal     -0.1025 -0.21522  0.01409    468.7
# traitback:traitback.animal        0.1697  0.07312  0.28428    386.6
#
#                ~us(trait):fosternest
#
#                                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.fosternest   0.10783  0.05415   0.1649     2000
# traitback:traittarsus.fosternest     0.04631  0.00317   0.0971     2000
# traittarsus:traitback.fosternest     0.04631  0.00317   0.0971     2000
# traitback:traitback.fosternest       0.13985  0.07546   0.2133     1484
#
#  R-structure:  ~us(trait):units
#
#                               post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.units   0.33851  0.22020  0.44986    664.1
# traitback:traittarsus.units     0.01704 -0.06558  0.09601    699.9
# traittarsus:traitback.units     0.01704 -0.06558  0.09601    699.9
# traitback:traitback.units       0.71805  0.60730  0.81578    726.8
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.409453 -0.527771 -0.262090     2000 <5e-04 ***
# traitback:sexFem      -0.010529 -0.138089  0.127579     2000  0.872
# traittarsus:sexMale    0.359646  0.236938  0.503791     2000 <5e-04 ***
# traitback:sexMale     -0.001015 -0.128351  0.124528     2000  0.993
# traittarsus:sexUNK    -0.175740 -0.401132  0.103972     2000  0.165
# traitback:sexUNK       0.134085 -0.130306  0.444938     2000  0.365
# traittarsus:hatchdate -0.040544 -0.153356  0.087508     2159  0.505
# traitback:hatchdate   -0.091337 -0.188949  0.023673     2300  0.098 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior2 <- list(R = usP, G = list(G1 = idhP, G2 = usP))                 

m2 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ idh(trait):animal + us(trait):fosternest, 
      rcov = ~ us(trait):units, 
      prior = prior2,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped, verbose=FALSE)
summary(m2)
# Out:
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4043.538
#
#  G-structure:  ~idh(trait):animal
#
#                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus.animal    0.4619  0.28351   0.6548    734.7
# traitback.animal      0.2123  0.09363   0.3401    503.5
#
#                ~us(trait):fosternest
#
#                                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.fosternest   0.10607  0.05243  0.16253     2221
# traitback:traittarsus.fosternest     0.03692 -0.00782  0.08343     2000
# traittarsus:traitback.fosternest     0.03692 -0.00782  0.08343     2000
# traitback:traitback.fosternest       0.12845  0.06271  0.19495     1648
#
#  R-structure:  ~us(trait):units
#
#                               post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.units   0.33397  0.22204  0.45582    740.9
# traitback:traittarsus.units    -0.03777 -0.08579  0.01384   2000.0
# traittarsus:traitback.units    -0.03777 -0.08579  0.01384   2000.0
# traitback:traitback.units       0.69391  0.58082  0.80283    852.3
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.405326 -0.552999 -0.274794     2000 <5e-04 ***
# traitback:sexFem      -0.009656 -0.140175  0.127292     2508  0.877
# traittarsus:sexMale    0.363427  0.225392  0.498095     2000 <5e-04 ***
# traitback:sexMale     -0.003896 -0.135376  0.120374     2000  0.951
# traittarsus:sexUNK    -0.172169 -0.443997  0.063844     2000  0.169
# traitback:sexUNK       0.113481 -0.170688  0.412192     2000  0.424
# traittarsus:hatchdate -0.042333 -0.159611  0.069695     2000  0.473
# traitback:hatchdate   -0.084408 -0.192031  0.019039     2000  0.114
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior3 <- list(R = usP, G = list(G1 = idhP, G2 = idhP))  

m3 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ idh(trait):animal + idh(trait):fosternest, 
      rcov = ~ us(trait):units, 
      prior = prior3,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m3)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4059.795
#
#  G-structure:  ~idh(trait):animal
#
#                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus.animal    0.4481   0.2736   0.6516    579.2
# traitback.animal      0.1928   0.0856   0.3081    486.3
#
#                ~idh(trait):fosternest
#
#                        post.mean l-95% CI u-95% CI eff.samp
# traittarsus.fosternest    0.1264  0.06869   0.1896     1838
# traitback.fosternest      0.1513  0.07888   0.2239     1547
#
#  R-structure:  ~us(trait):units
#
#                               post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.units   0.34063  0.23112   0.4678    641.7
# traitback:traittarsus.units    -0.03599 -0.08622   0.0128   1845.3
# traittarsus:traitback.units    -0.03599 -0.08622   0.0128   1845.3
# traitback:traitback.units       0.70328  0.60277   0.8141    918.2
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                        post.mean   l-95% CI   u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.4054617 -0.5431791 -0.2651667     2000 <5e-04 ***
# traitback:sexFem      -0.0065596 -0.1432056  0.1249588     2000  0.934
# traittarsus:sexMale    0.3627452  0.2205822  0.5001562     2000 <5e-04 ***
# traitback:sexMale      0.0001754 -0.1346785  0.1262732     2000  0.990
# traittarsus:sexUNK    -0.1758888 -0.4464497  0.0796443     2000  0.191
# traitback:sexUNK       0.1105310 -0.1643149  0.4046673     2000  0.467
# traittarsus:hatchdate -0.0403164 -0.1597548  0.0805512     2298  0.501
# traitback:hatchdate   -0.0839162 -0.1862566  0.0278195     2000  0.131
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior4 <- list(R = idhP, G = list(G1 = idhP, G2 = idhP))  

m4 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ idh(trait):animal + idh(trait):fosternest, 
      rcov = ~ idh(trait):units, 
      prior = prior4,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m4)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4087.112
#
#  G-structure:  ~idh(trait):animal
#
#                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus.animal    0.4247  0.26282   0.5945    807.1
# traitback.animal      0.1934  0.08885   0.3091    447.6
#
#                ~idh(trait):fosternest
#
#                        post.mean l-95% CI u-95% CI eff.samp
# traittarsus.fosternest    0.1255  0.07230   0.1866     2000
# traitback.fosternest      0.1482  0.08447   0.2215     1494
#
#  R-structure:  ~idh(trait):units
#
#                   post.mean l-95% CI u-95% CI eff.samp
# traittarsus.units    0.3539   0.2577   0.4651    964.1
# traitback.units      0.7028   0.5974   0.8083    850.6
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.402622 -0.535829 -0.260352     2000 <5e-04 ***
# traitback:sexFem      -0.007561 -0.133481  0.126475     2000  0.907
# traittarsus:sexMale    0.364885  0.230133  0.500444     2327 <5e-04 ***
# traitback:sexMale      0.003016 -0.127532  0.127971     2000  0.970
# traittarsus:sexUNK    -0.172482 -0.453401  0.066412     2161  0.194
# traitback:sexUNK       0.111584 -0.159691  0.410052     2250  0.440
# traittarsus:hatchdate -0.044512 -0.165852  0.065492     2108  0.448
# traitback:hatchdate   -0.084397 -0.186875  0.027399     2000  0.117
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior5 <- list(R = usP, G = list(G1 = usP, G2 = idhP))  

m5 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ us(trait):animal + idh(trait):fosternest, 
      rcov = ~ us(trait):units, 
      prior = prior5,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m5)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4055.085
#
#  G-structure:  ~us(trait):animal
#
#                                post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.animal   0.44511  0.27467  0.64230    628.6
# traitback:traittarsus.animal    -0.07714 -0.18612  0.02198    583.6
# traittarsus:traitback.animal    -0.07714 -0.18612  0.02198    583.6
# traitback:traitback.animal       0.15743  0.05953  0.27095    356.4
#
#                ~idh(trait):fosternest
#
#                        post.mean l-95% CI u-95% CI eff.samp
# traittarsus.fosternest    0.1275  0.07327   0.1922     2000
# traitback.fosternest      0.1599  0.08567   0.2309     1576
#
#  R-structure:  ~us(trait):units
#
#                               post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.units  0.341434   0.2155  0.45267    703.9
# traitback:traittarsus.units    0.004512  -0.0696  0.07879    849.1
# traittarsus:traitback.units    0.004512  -0.0696  0.07879    849.1
# traitback:traitback.units      0.722971   0.6191  0.82742    849.1
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean l-95% CI u-95% CI eff.samp  pMCMC
# traittarsus:sexFem     -0.40619 -0.54869 -0.27395     2000 <5e-04 ***
# traitback:sexFem       -0.00889 -0.14134  0.11097     2000  0.889
# traittarsus:sexMale     0.36313  0.22737  0.49632     2000 <5e-04 ***
# traitback:sexMale      -0.00142 -0.12565  0.13059     2045  0.949
# traittarsus:sexUNK     -0.17596 -0.42258  0.07929     2000  0.183
# traitback:sexUNK        0.11831 -0.16748  0.40887     2000  0.443
# traittarsus:hatchdate  -0.04318 -0.15825  0.07648     2000  0.468
# traitback:hatchdate    -0.08697 -0.19541  0.02194     1834  0.128
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior6 <- list(R = idhP, G = list(G1 = usP, G2 = idhP))  

m6 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ us(trait):animal + idh(trait):fosternest, 
      rcov = ~ idh(trait):units, 
      prior = prior6,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m6)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4097.832
#
#  G-structure:  ~us(trait):animal
#
#                                post.mean l-95% CI  u-95% CI eff.samp
# traittarsus:traittarsus.animal   0.41100  0.24271  0.588963    753.8
# traitback:traittarsus.animal    -0.06933 -0.13877 -0.003254   1095.7
# traittarsus:traitback.animal    -0.06933 -0.13877 -0.003254   1095.7
# traitback:traitback.animal       0.15370  0.06554  0.267241    388.3
#
#                ~idh(trait):fosternest
#
#                        post.mean l-95% CI u-95% CI eff.samp
# traittarsus.fosternest    0.1292  0.07178   0.1963     2000
# traitback.fosternest      0.1583  0.08988   0.2385     1454
#
#  R-structure:  ~idh(trait):units
#
#                   post.mean l-95% CI u-95% CI eff.samp
# traittarsus.units    0.3613   0.2455   0.4620    807.2
# traitback.units      0.7262   0.6223   0.8319    958.8
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.404954 -0.536132 -0.257490     2000 <5e-04 ***
# traitback:sexFem      -0.012952 -0.149228  0.124369     1999  0.836
# traittarsus:sexMale    0.363941  0.226574  0.502376     2000 <5e-04 ***
# traitback:sexMale     -0.001964 -0.125465  0.128947     2000  0.980
# traittarsus:sexUNK    -0.169102 -0.434204  0.094786     2000  0.207
# traitback:sexUNK       0.119192 -0.150206  0.451324     2147  0.410
# traittarsus:hatchdate -0.045080 -0.157666  0.071226     2000  0.471
# traitback:hatchdate   -0.087135 -0.195315  0.024483     2000  0.116
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior7 <- list(R = idhP, G = list(G1 = idhP, G2 = usP))  

m7 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ us(trait):animal + idh(trait):fosternest, 
      rcov = ~ idh(trait):units, 
      prior = prior7,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m7)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4081.347
#
#  G-structure:  ~us(trait):animal
#
#                                post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.animal   0.43517   0.2751 0.611654    885.7
# traitback:traittarsus.animal    -0.06652  -0.1346 0.001947   1522.2
# traittarsus:traitback.animal    -0.06652  -0.1346 0.001947   1522.2
# traitback:traitback.animal       0.20044   0.1005 0.324575    499.7
#
#                ~idh(trait):fosternest
#
#                        post.mean l-95% CI u-95% CI eff.samp
# traittarsus.fosternest    0.1045  0.05426   0.1671     2000
# traitback.fosternest      0.1283  0.06853   0.1986     1768
#
#  R-structure:  ~idh(trait):units
#
#                   post.mean l-95% CI u-95% CI eff.samp
# traittarsus.units    0.3528   0.2434   0.4555    991.8
# traitback.units      0.7008   0.6040   0.8170   1004.0
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                        post.mean   l-95% CI   u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.4048411 -0.5460694 -0.2871433     2000 <5e-04 ***
# traitback:sexFem      -0.0089035 -0.1424175  0.1248444     2000  0.921
# traittarsus:sexMale    0.3645302  0.2367504  0.4985423     2000 <5e-04 ***
# traitback:sexMale      0.0005568 -0.1269074  0.1267233     2000  0.999
# traittarsus:sexUNK    -0.1736913 -0.4451943  0.0753055     1957  0.184
# traitback:sexUNK       0.1159824 -0.1688627  0.3952608     2000  0.434
# traittarsus:hatchdate -0.0417451 -0.1453368  0.0813200     2000  0.476
# traitback:hatchdate   -0.0875282 -0.2015411  0.0168102     2000  0.120
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
prior8 <- list(R = idhP, G = list(G1 = usP, G2 = usP))  

m8 <- MCMCglmm(
      fixed = cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1, 
      random = ~ us(trait):animal + us(trait):fosternest, 
      rcov = ~ idh(trait):units, 
      prior = prior8,
      family = c("gaussian", "gaussian"),
      nitt = nitt, burnin = burnin, thin = thin,
      data = BTdata, pedigree = BTped)
summary(m8)
# Out:
#                        MCMC iteration = 0
#
#                        MCMC iteration = 1000
#
#                        MCMC iteration = 2000
#
#                        MCMC iteration = 3000
#
#                        MCMC iteration = 4000
#
#                        MCMC iteration = 5000
#
#                        MCMC iteration = 6000
#
#                        MCMC iteration = 7000
#
#                        MCMC iteration = 8000
#
#                        MCMC iteration = 9000
#
#                        MCMC iteration = 10000
#
#                        MCMC iteration = 11000
#
#                        MCMC iteration = 12000
#
#                        MCMC iteration = 13000
#
#                        MCMC iteration = 14000
#
#                        MCMC iteration = 15000
#
#                        MCMC iteration = 16000
#
#                        MCMC iteration = 17000
#
#                        MCMC iteration = 18000
#
#                        MCMC iteration = 19000
#
#                        MCMC iteration = 20000
#
#                        MCMC iteration = 21000
#
#                        MCMC iteration = 22000
#
#                        MCMC iteration = 23000
#
#                        MCMC iteration = 24000
#
#                        MCMC iteration = 25000
#
#                        MCMC iteration = 26000
#
#                        MCMC iteration = 27000
#
#                        MCMC iteration = 28000
#
#                        MCMC iteration = 29000
#
#                        MCMC iteration = 30000
#
#                        MCMC iteration = 31000
#
#                        MCMC iteration = 32000
#
#                        MCMC iteration = 33000
#
#                        MCMC iteration = 34000
#
#                        MCMC iteration = 35000
#
#                        MCMC iteration = 36000
#
#                        MCMC iteration = 37000
#
#                        MCMC iteration = 38000
#
#                        MCMC iteration = 39000
#
#                        MCMC iteration = 40000
#
#                        MCMC iteration = 41000
#
#                        MCMC iteration = 42000
#
#                        MCMC iteration = 43000
#
#                        MCMC iteration = 44000
#
#                        MCMC iteration = 45000
#
#                        MCMC iteration = 46000
#
#                        MCMC iteration = 47000
#
#                        MCMC iteration = 48000
#
#                        MCMC iteration = 49000
#
#                        MCMC iteration = 50000
#
#                        MCMC iteration = 51000
#
#                        MCMC iteration = 52000
#
#                        MCMC iteration = 53000
#
#                        MCMC iteration = 54000
#
#                        MCMC iteration = 55000
#
#                        MCMC iteration = 56000
#
#                        MCMC iteration = 57000
#
#                        MCMC iteration = 58000
#
#                        MCMC iteration = 59000
#
#                        MCMC iteration = 60000
#  Iterations = 10001:59976
#  Thinning interval  = 25
#  Sample size  = 2000
#
#  DIC: 4092.597
#
#  G-structure:  ~us(trait):animal
#
#                                post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.animal   0.41468  0.25181  0.57928    816.6
# traitback:traittarsus.animal    -0.08279 -0.14459 -0.01145   1116.3
# traittarsus:traitback.animal    -0.08279 -0.14459 -0.01145   1116.3
# traitback:traitback.animal       0.16066  0.06541  0.27773    425.5
#
#                ~us(trait):fosternest
#
#                                    post.mean l-95% CI u-95% CI eff.samp
# traittarsus:traittarsus.fosternest    0.1084 0.055543  0.16626     2000
# traitback:traittarsus.fosternest      0.0455 0.002888  0.09395     2000
# traittarsus:traitback.fosternest      0.0455 0.002888  0.09395     2000
# traitback:traitback.fosternest        0.1395 0.074645  0.21528     1280
#
#  R-structure:  ~idh(trait):units
#
#                   post.mean l-95% CI u-95% CI eff.samp
# traittarsus.units    0.3603   0.2587   0.4636    793.0
# traitback.units      0.7205   0.6113   0.8190    838.6
#
#  Location effects: cbind(tarsus, back) ~ trait:sex + trait:hatchdate - 1
#
#                       post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# traittarsus:sexFem    -0.405406 -0.541127 -0.275476     2000 <5e-04 ***
# traitback:sexFem      -0.010358 -0.148516  0.109489     2000  0.877
# traittarsus:sexMale    0.362829  0.233132  0.497057     2059 <5e-04 ***
# traitback:sexMale     -0.003356 -0.128421  0.117769     2000  0.955
# traittarsus:sexUNK    -0.172582 -0.425303  0.102930     2494  0.197
# traitback:sexUNK       0.124833 -0.198274  0.385697     2000  0.390
# traittarsus:hatchdate -0.044774 -0.159479  0.070774     2135  0.452
# traitback:hatchdate   -0.086633 -0.189154  0.023891     2000  0.106
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
